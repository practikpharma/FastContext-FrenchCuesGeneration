# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 101
#  French Term     : par \ w + famille
#  English Term(s) : ['by \\w+ family']
#  Index(es)       : [203, 204]
#  Grouping(s)     : [170, 171]


cfg_grammar= """
S ->  Adposition1 Adjective2 Noun3 Adposition4 Noun5 Trigger_Rule
Adposition1 -> "par"
Adjective2 -> "\"
Noun3 -> "w"
Adposition4 -> "+"
Noun5 -> "famille" | "foyer" | "lignée" | "descendance" | "extraction" | "race" | "origine" | "classe" | "parenté" | "souche"
Trigger_Rule -> "|both|termination|historical|30|Group[170, 171]" |"|both|termination|nonpatient|30|Group[170, 171]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 102
#  French Term     : par famille
#  English Term(s) : ['by family']
#  Index(es)       : [205, 206]
#  Grouping(s)     : [172, 173]


cfg_grammar= """
S ->  Adposition1 Noun2 Trigger_Rule
Adposition1 -> "par"
Noun2 -> "famille" | "foyer" | "lignée" | "descendance" | "extraction" | "race" | "origine" | "classe" | "parenté" | "souche"
Trigger_Rule -> "|both|termination|historical|30|Group[172, 173]" |"|both|termination|nonpatient|30|Group[172, 173]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 103
#  French Term     : par le
#  English Term(s) : ['by the']
#  Index(es)       : [207]
#  Grouping(s)     : [174]


cfg_grammar= """
S ->  Adposition1 Determiner2 Trigger_Rule
Adposition1 -> "par"
Determiner2 -> "le"
Trigger_Rule -> "|forward|termination|negated|10|Group[174]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 104
#  French Term     : c w
#  English Term(s) : ['c w']
#  Index(es)       : [208]
#  Grouping(s)     : [175]


cfg_grammar= """
S ->  Adposition1 Verb2 Trigger_Rule
Adposition1 -> "c"
Verb2 -> "w"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[175]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 105
#  French Term     : peut être exclu pour
#  English Term(s) : ['can be ruled out for', 'may be ruled out for']
#  Index(es)       : [220, 221]
#  Grouping(s)     : [176]


cfg_grammar= """
S ->  Verb1 Auxiliary2 Verb3 Adposition4 Trigger_Rule
Verb1 -> "peut"
Auxiliary2 -> "être"
Verb3 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Adposition4 -> "pour"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[176]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 106
#  French Term     : peut être exclu
#  English Term(s) : ['can be ruled out', 'may be ruled out']
#  Index(es)       : [209, 210]
#  Grouping(s)     : [177]


cfg_grammar= """
S ->  Verb1 Auxiliary2 Verb3 Trigger_Rule
Verb1 -> "peut"
Auxiliary2 -> "être"
Verb3 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[177]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 107
#  French Term     : peut l'éliminer contre
#  English Term(s) : ['can rule her out against']
#  Index(es)       : [211]
#  Grouping(s)     : [179]


cfg_grammar= """
S ->  Auxiliary1 Pronoun2 Verb3 Adposition4 Trigger_Rule
Auxiliary1 -> "peut"
Pronoun2 -> "l'"
Verb3 -> "éliminer" | "proscrire" | "repousser" | "rejeter" | "chasser" | "évincer" | "exclure" | "retrancher" | "recaler" | "évacuer"
Adposition4 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[179]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 108
#  French Term     : peut exclure contre
#  English Term(s) : ['can rule out against']
#  Index(es)       : [217]
#  Grouping(s)     : [179]


cfg_grammar= """
S ->  Auxiliary1 Noun2 Adposition3 Trigger_Rule
Auxiliary1 -> "peut"
Noun2 -> "exclure" | "expulser" | "écarter" | "renvoyer" | "repousser" | "rejeter" | "chasser" | "retrancher" | "excepter" | "bannir"
Adposition3 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[179]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 109
#  French Term     : peut l'exclure
#  English Term(s) : ['can rule her out for', 'can rule him out for']
#  Index(es)       : [212, 215]
#  Grouping(s)     : [179]


cfg_grammar= """
S ->  Auxiliary1 Determiner2 Noun3 Trigger_Rule
Auxiliary1 -> "peut"
Determiner2 -> "l'"
Noun3 -> "exclure" | "expulser" | "écarter" | "renvoyer" | "repousser" | "rejeter" | "chasser" | "retrancher" | "excepter" | "bannir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[179]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 110
#  French Term     : peut exclure pour
#  English Term(s) : ['can rule out for']
#  Index(es)       : [218]
#  Grouping(s)     : [179]


cfg_grammar= """
S ->  Auxiliary1 Noun2 Adposition3 Trigger_Rule
Auxiliary1 -> "peut"
Noun2 -> "exclure" | "expulser" | "écarter" | "renvoyer" | "repousser" | "rejeter" | "chasser" | "retrancher" | "excepter" | "bannir"
Adposition3 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[179]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 111
#  French Term     : peut exclure
#  English Term(s) : ['can rule out']
#  Index(es)       : [219]
#  Grouping(s)     : [179]


cfg_grammar= """
S ->  Auxiliary1 Noun2 Trigger_Rule
Auxiliary1 -> "peut"
Noun2 -> "exclure" | "expulser" | "écarter" | "renvoyer" | "repousser" | "rejeter" | "chasser" | "retrancher" | "excepter" | "bannir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[179]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 112
#  French Term     : peut l'éliminer
#  English Term(s) : ['can rule her out', 'can rule him out']
#  Index(es)       : [213, 216]
#  Grouping(s)     : [179]


cfg_grammar= """
S ->  Auxiliary1 Pronoun2 Verb3 Trigger_Rule
Auxiliary1 -> "peut"
Pronoun2 -> "l'"
Verb3 -> "éliminer" | "proscrire" | "repousser" | "rejeter" | "chasser" | "évincer" | "exclure" | "retrancher" | "recaler" | "évacuer"
Trigger_Rule -> "|forward|trigger|negated|10|Group[179]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 113
#  French Term     : peut l'exclure contre
#  English Term(s) : ['can rule him out against']
#  Index(es)       : [214]
#  Grouping(s)     : [179]


cfg_grammar= """
S ->  Auxiliary1 Determiner2 Noun3 Adposition4 Trigger_Rule
Auxiliary1 -> "peut"
Determiner2 -> "l'"
Noun3 -> "exclure" | "expulser" | "écarter" | "renvoyer" | "repousser" | "rejeter" | "chasser" | "retrancher" | "excepter" | "bannir"
Adposition4 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[179]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 114
#  French Term     : peut exclure la patinet contre
#  English Term(s) : ['can rule the patinet out against']
#  Index(es)       : [232]
#  Grouping(s)     : [196]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Noun4 Adposition5 Trigger_Rule
Auxiliary1 -> "peut"
Verb2 -> "exclure" | "expulser" | "écarter" | "renvoyer" | "repousser" | "rejeter" | "chasser" | "retrancher" | "excepter" | "bannir"
Determiner3 -> "la"
Noun4 -> "patinet"
Adposition5 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[196]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 115
#  French Term     : peut exclure la patinet pour
#  English Term(s) : ['can rule the patinet out for']
#  Index(es)       : [233]
#  Grouping(s)     : [196]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Noun4 Adposition5 Trigger_Rule
Auxiliary1 -> "peut"
Verb2 -> "exclure" | "expulser" | "écarter" | "renvoyer" | "repousser" | "rejeter" | "chasser" | "retrancher" | "excepter" | "bannir"
Determiner3 -> "la"
Noun4 -> "patinet"
Adposition5 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[196]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 116
#  French Term     : peut exclure le patient
#  English Term(s) : ['can rule the patient out']
#  Index(es)       : [231]
#  Grouping(s)     : [196]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Noun4 Trigger_Rule
Auxiliary1 -> "peut"
Verb2 -> "exclure" | "expulser" | "écarter" | "renvoyer" | "repousser" | "rejeter" | "chasser" | "retrancher" | "excepter" | "bannir"
Determiner3 -> "le"
Noun4 -> "patient" | "persévérant" | "client" | "infatigable" | "constant" | "calme" | "imperturbable" | "impassible" | "résigné" | "courageux"
Trigger_Rule -> "|forward|trigger|negated|10|Group[196]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 117
#  French Term     : ne peut pas être totalement exclu
#  English Term(s) : ['cannot be fully excluded']
#  Index(es)       : [239]
#  Grouping(s)     : [202]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Auxiliary4 Adverb5 Verb6 Trigger_Rule
Adverb1 -> "ne"
Auxiliary2 -> "peut"
Adverb3 -> "pas"
Auxiliary4 -> "être"
Adverb5 -> "totalement"
Verb6 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[202]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 118
#  French Term     : ne peut pas être complètement exclu
#  English Term(s) : ['cannot be completely excluded']
#  Index(es)       : [237]
#  Grouping(s)     : [202]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Auxiliary4 Adverb5 Verb6 Trigger_Rule
Adverb1 -> "ne"
Auxiliary2 -> "peut"
Adverb3 -> "pas"
Auxiliary4 -> "être"
Adverb5 -> "complètement"
Verb6 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[202]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 119
#  French Term     : ne peut être exclu
#  English Term(s) : ['cannot be excluded']
#  Index(es)       : [238]
#  Grouping(s)     : [202]


cfg_grammar= """
S ->  Adverb1 Verb2 Auxiliary3 Verb4 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "peut"
Auxiliary3 -> "être"
Verb4 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[202]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 120
#  French Term     : Ne peux voir
#  English Term(s) : ['cannot see']
#  Index(es)       : [240]
#  Grouping(s)     : [205]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Verb3 Trigger_Rule
Adverb1 -> "Ne"
Auxiliary2 -> "peux"
Verb3 -> "voir" | "saisir" | "percevoir" | "considérer" | "examiner" | "regarder" | "comprendre" | "apercevoir" | "concevoir" | "entendre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[205]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 121
#  French Term     : ne peux pas
#  English Term(s) : ['cannot']
#  Index(es)       : [242]
#  Grouping(s)     : [207]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Trigger_Rule
Adverb1 -> "ne"
Auxiliary2 -> "peux"
Adverb3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[207]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 122
#  French Term     : cause de
#  English Term(s) : ['cause for', 'cause of']
#  Index(es)       : [244, 245]
#  Grouping(s)     : [209]


cfg_grammar= """
S ->  Noun1 Adposition2 Trigger_Rule
Noun1 -> "cause" | "motif" | "raison" | "ferment" | "procès" | "sujet" | "prétexte" | "moteur" | "fondement" | "germe"
Adposition2 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[209]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 123
#  French Term     : causes de
#  English Term(s) : ['causes for', 'causes of']
#  Index(es)       : [246, 247]
#  Grouping(s)     : [209]


cfg_grammar= """
S ->  Noun1 Adposition2 Trigger_Rule
Noun1 -> "causes" | "motif" | "raison" | "ferment" | "procès" | "sujet" | "prétexte" | "moteur" | "fondement" | "germe"
Adposition2 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[209]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 124
#  French Term     : vérifié pour
#  English Term(s) : ['checked for']
#  Index(es)       : [248]
#  Grouping(s)     : [213]


cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "vérifié" | "reconnu" | "constaté" | "étalonné" | "prouvé" | "contrôlé" | "revu" | "examiné" | "avéré" | "compte"
Adposition2 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[213]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 125
#  French Term     : libre de
#  English Term(s) : ['clear of', 'free of']
#  Index(es)       : [250, 251]
#  Grouping(s)     : [215]


cfg_grammar= """
S ->  Adjective1 Adposition2 Trigger_Rule
Adjective1 -> "libre"
Adposition2 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[215]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 126
#  French Term     : revenir à
#  English Term(s) : ['come back to']
#  Index(es)       : [255]
#  Grouping(s)     : [217]


cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "revenir" | "rentrer" | "reprendre" | "reparaître" | "échoir" | "regagner" | "incomber" | "refluer" | "réintégrer" | "repasser"
Adposition2 -> "à"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[217]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 127
#  French Term     : reviens pour
#  English Term(s) : ['come back for']
#  Index(es)       : [254]
#  Grouping(s)     : [217]


cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "reviens"
Adposition2 -> "pour"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[217]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 128
#  French Term     : Se plaint
#  English Term(s) : ['complains']
#  Index(es)       : [256, 257]
#  Grouping(s)     : [219, 220]


cfg_grammar= """
S ->  Pronoun1 Verb2 Trigger_Rule
Pronoun1 -> "Se"
Verb2 -> "plaint" | "regarder" | "marchander" | "regretter" | "pleurer" | "craindre" | "économiser" | "compatir" | "économisé" | "regretté"
Trigger_Rule -> "|both|termination|historical|30|Group[219, 220]" |"|both|termination|nonpatient|30|Group[219, 220]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 129
#  French Term     : concerné pour
#  English Term(s) : ['concern for', 'concerned for']
#  Index(es)       : [258, 260]
#  Grouping(s)     : [221, 223]


cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "concerné" | "toucher" | "regarder" | "intéresser" | "ressortir" | "viser" | "aller" | "dépendre" | "impliquer" | "être du rayon"
Adposition2 -> "pour"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[221, 223]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 130
#  French Term     : préoccupé par
#  English Term(s) : ['concerned about']
#  Index(es)       : [259]
#  Grouping(s)     : [222]


cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "préoccupé" | "anxieux" | "tourmenté" | "soucieux" | "songeur" | "hanté" | "rêveur" | "inquiet" | "tracassé" | "abstrait"
Adposition2 -> "par"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[222]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 131
#  French Term     : concernant pour
#  English Term(s) : ['concerning for']
#  Index(es)       : [261]
#  Grouping(s)     : [224]


cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "concernant" | "relatif" | "exécutant" | "à" | "de" | "relatif à" | "au" | "sujet" | "relativement à" | "propos"
Adposition2 -> "pour"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[224]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 132
#  French Term     : cohérent avec
#  English Term(s) : ['consistent with']
#  Index(es)       : [262]
#  Grouping(s)     : [225]


cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "cohérent" | "harmonieux" | "homogène" | "ordonné" | "suivi" | "consistant" | "compréhensible" | "rationnel" | "conséquent" | "uni"
Adposition2 -> "avec"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[225]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 133
#  French Term     : pourrait être soit
#  English Term(s) : ['could be either']
#  Index(es)       : [263]
#  Grouping(s)     : [226]


cfg_grammar= """
S ->  Verb1 Auxiliary2 Verb3 Trigger_Rule
Verb1 -> "pourrait"
Auxiliary2 -> "être"
Verb3 -> "soit"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[226]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 134
#  French Term     : pourrait être
#  English Term(s) : ['could be', 'might be']
#  Index(es)       : [264, 714]
#  Grouping(s)     : [227, 665]


cfg_grammar= """
S ->  Verb1 Auxiliary2 Trigger_Rule
Verb1 -> "pourrait"
Auxiliary2 -> "être"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[227, 665]" |"|forward|trigger|uncertain|30|Group[227, 665]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 135
#  French Term     : pourrait être exclu
#  English Term(s) : ['could be ruled out', 'might be ruled out']
#  Index(es)       : [265, 268, 269]
#  Grouping(s)     : [228, 230]


cfg_grammar= """
S ->  Verb1 Auxiliary2 Verb3 Trigger_Rule
Verb1 -> "pourrait"
Auxiliary2 -> "être"
Verb3 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[228, 230]" |"|backward|trigger|uncertain|30|Group[228, 230]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 136
#  French Term     : pourrait être exclu pour
#  English Term(s) : ['could be ruled out for', 'might be ruled out for']
#  Index(es)       : [266, 267]
#  Grouping(s)     : [229]


cfg_grammar= """
S ->  Verb1 Auxiliary2 Verb3 Adposition4 Trigger_Rule
Verb1 -> "pourrait"
Auxiliary2 -> "être"
Verb3 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Adposition4 -> "pour"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[229]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 137
#  French Term     : actuellement
#  English Term(s) : ['currently']
#  Index(es)       : [270, 271]
#  Grouping(s)     : [231, 232]


cfg_grammar= """
S ->  Adverb1 Trigger_Rule
Adverb1 -> "actuellement"
Trigger_Rule -> "|both|termination|historical|30|Group[231, 232]" |"|both|termination|nonpatient|30|Group[231, 232]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 138
#  French Term     : papa appelé
#  English Term(s) : ['dad called']
#  Index(es)       : [272, 273]
#  Grouping(s)     : [233, 234]


cfg_grammar= """
S ->  Noun1 Auxiliary2 Trigger_Rule
Noun1 -> "papa" | "vieux" | "paternel" | "pépé" | "parent" | "papa" | "dieu" | "papas" | "sonorisation" | "ancien"
Auxiliary2 -> "appelé"
Trigger_Rule -> "|both|termination|historical|30|Group[233, 234]" |"|both|termination|nonpatient|30|Group[233, 234]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 139
#  French Term     : papa
#  English Term(s) : ["dad's", 'dad']
#  Index(es)       : [274, 275]
#  Grouping(s)     : [235]


cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "papa" | "vieux" | "paternel" | "pépé" | "parent" | "papa" | "dieu" | "papas" | "sonorisation" | "ancien"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[235]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 140
#  French Term     : fille a signalé
#  English Term(s) : ['daughter reported']
#  Index(es)       : [277, 280]
#  Grouping(s)     : [237, 238]


cfg_grammar= """
S ->  Noun1 Auxiliary2 Verb3 Trigger_Rule
Noun1 -> "fille" | "nana" | "fillette" | "adolescente" | "poulette" | "tendron" | "gonzesse" | "gamine" | "jouvencelle" | "héritière"
Auxiliary2 -> "a"
Verb3 -> "signalé" | "insigne" | "distingué" | "important" | "glorieux" | "marquant" | "émérite" | "mémorable" | "notable" | "saillant"
Trigger_Rule -> "|both|termination|historical|30|Group[237, 238]" |"|both|termination|nonpatient|30|Group[237, 238]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 141
#  French Term     : fille a appelé
#  English Term(s) : ['daughter called']
#  Index(es)       : [276, 279]
#  Grouping(s)     : [237, 238]


cfg_grammar= """
S ->  Noun1 Auxiliary2 Auxiliary3 Trigger_Rule
Noun1 -> "fille" | "nana" | "fillette" | "adolescente" | "poulette" | "tendron" | "gonzesse" | "gamine" | "jouvencelle" | "héritière"
Auxiliary2 -> "a"
Auxiliary3 -> "appelé"
Trigger_Rule -> "|both|termination|historical|30|Group[237, 238]" |"|both|termination|nonpatient|30|Group[237, 238]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 142
#  French Term     : rapports de fille
#  English Term(s) : ['daughter reports']
#  Index(es)       : [278, 281]
#  Grouping(s)     : [237, 238]


cfg_grammar= """
S ->  Noun1 Adposition2 Noun3 Trigger_Rule
Noun1 -> "rapports" | "liaison" | "commerce" | "connexion" | "contact" | "analogie" | "affinité" | "similitude" | "union" | "correspondance"
Adposition2 -> "de"
Noun3 -> "fille" | "nana" | "fillette" | "adolescente" | "poulette" | "tendron" | "gonzesse" | "gamine" | "jouvencelle" | "héritière"
Trigger_Rule -> "|both|termination|historical|30|Group[237, 238]" |"|both|termination|nonpatient|30|Group[237, 238]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 143
#  French Term     : fille
#  English Term(s) : ['daughter']
#  Index(es)       : [283]
#  Grouping(s)     : [243]


cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "fille" | "nana" | "fillette" | "adolescente" | "poulette" | "tendron" | "gonzesse" | "gamine" | "jouvencelle" | "héritière"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[243]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 144
#  French Term     : les filles
#  English Term(s) : ['daughters']
#  Index(es)       : [282]
#  Grouping(s)     : [243]


cfg_grammar= """
S ->  Determiner1 Noun2 Trigger_Rule
Determiner1 -> "les"
Noun2 -> "filles" | "nana" | "fillette" | "adolescente" | "poulette" | "tendron" | "gonzesse" | "gamine" | "jouvencelle" | "héritière"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[243]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 145
#  French Term     : décide
#  English Term(s) : ['decides']
#  Index(es)       : [285, 288]
#  Grouping(s)     : [245, 246]


cfg_grammar= """
S ->  Verb1 Trigger_Rule
Verb1 -> "décide" | "irrévocable" | "arrêté" | "déterminé" | "ferme" | "hardi" | "réglé" | "prononcé" | "volontaire" | "résolu"
Trigger_Rule -> "|both|termination|historical|30|Group[245, 246]" |"|both|termination|nonpatient|30|Group[245, 246]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 146
#  French Term     : décidé
#  English Term(s) : ['decided']
#  Index(es)       : [284, 287]
#  Grouping(s)     : [245, 246]


cfg_grammar= """
S ->  Verb1 Trigger_Rule
Verb1 -> "décidé" | "déterminé" | "hardi" | "réglé" | "prononcé" | "résolu" | "audacieux" | "délibéré" | "prêt" | "confiant"
Trigger_Rule -> "|both|termination|historical|30|Group[245, 246]" |"|both|termination|nonpatient|30|Group[245, 246]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 147
#  French Term     : décider
#  English Term(s) : ['decide']
#  Index(es)       : [286, 289]
#  Grouping(s)     : [245, 246]


cfg_grammar= """
S ->  Verb1 Trigger_Rule
Verb1 -> "décider" | "juger" | "régler" | "disposer" | "trancher" | "prononcer" | "conclure" | "arrêter" | "statuer" | "déterminer"
Trigger_Rule -> "|both|termination|historical|30|Group[245, 246]" |"|both|termination|nonpatient|30|Group[245, 246]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 148
#  French Term     : décline
#  English Term(s) : ['declines']
#  Index(es)       : [293]
#  Grouping(s)     : [252]


cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "décline" | "diminuer" | "déchoir" | "énoncer" | "empirer" | "décroître" | "renvoyer" | "repousser" | "remercier" | "fléchir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[252]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 149
#  French Term     : diminué
#  English Term(s) : ['declined']
#  Index(es)       : [292]
#  Grouping(s)     : [252]


cfg_grammar= """
S ->  Verb1 Trigger_Rule
Verb1 -> "diminué" | "baisser" | "amoindrir" | "réduire" | "abaisser" | "déprécier" | "fondre" | "descendre" | "abréger" | "avilir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[252]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 150
#  French Term     : refusé actif
#  English Term(s) : ['denied active']
#  Index(es)       : [294]
#  Grouping(s)     : [255]


cfg_grammar= """
S ->  Verb1 Adjective2 Trigger_Rule
Verb1 -> "refusé" | "rejeter" | "renvoyer" | "contester" | "nier" | "débouter" | "évincer" | "éconduire" | "exclure" | "dédaigner"
Adjective2 -> "actif"
Trigger_Rule -> "|forward|trigger|negated|10|Group[255]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 151
#  French Term     : nié toute anormale
#  English Term(s) : ['denied any abnormal']
#  Index(es)       : [296]
#  Grouping(s)     : [257]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Determiner2 -> "toute"
Noun3 -> "anormale" | "bizarre" | "aberrant" | "étonnant" | "inaccoutumé" | "étrange" | "irrationnel" | "irrégulier" | "inadapté" | "paradoxal"
Trigger_Rule -> "|forward|trigger|negated|10|Group[257]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 152
#  French Term     : a nié tout changement dans le
#  English Term(s) : ['denied any changes in the']
#  Index(es)       : [301]
#  Grouping(s)     : [260]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Adverb3 Adverb4 Adposition5 Determiner6 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Adverb3 -> "tout"
Adverb4 -> "changement"
Adposition5 -> "dans"
Determiner6 -> "le"
Trigger_Rule -> "|forward|trigger|negated|10|Group[260]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 153
#  French Term     : a nié tout changement dans la
#  English Term(s) : ['denied any change in the']
#  Index(es)       : [300]
#  Grouping(s)     : [260]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Adverb3 Adverb4 Adposition5 Determiner6 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Adverb3 -> "tout"
Adverb4 -> "changement"
Adposition5 -> "dans"
Determiner6 -> "la"
Trigger_Rule -> "|forward|trigger|negated|10|Group[260]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 154
#  French Term     : a nié tout risque élevé
#  English Term(s) : ['denied any high-risk']
#  Index(es)       : [304]
#  Grouping(s)     : [264]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Noun4 Adjective5 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Determiner3 -> "tout"
Noun4 -> "risque" | "danger" | "responsabilité" | "aléa" | "hasard" | "inconvénient" | "gageure" | "menace" | "chance" | "fortune"
Adjective5 -> "élevé"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 155
#  French Term     : nié toute récente
#  English Term(s) : ['denied any recent']
#  Index(es)       : [309]
#  Grouping(s)     : [264]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Determiner2 -> "toute"
Noun3 -> "récente" | "neuf" | "nouveau" | "jeune" | "moderne" | "original" | "dernier" | "proche" | "actuel" | "jeunes"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 156
#  French Term     : nié tout problème
#  English Term(s) : ['denied any problems']
#  Index(es)       : [308]
#  Grouping(s)     : [264]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Determiner2 -> "tout"
Noun3 -> "problème" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 157
#  French Term     : a nié toute histoire de
#  English Term(s) : ['denied any history of']
#  Index(es)       : [305]
#  Grouping(s)     : [264]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Noun4 Adposition5 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Determiner3 -> "toute"
Noun4 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Adposition5 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 158
#  French Term     : nié tout risque élevé
#  English Term(s) : ['denied any high risk']
#  Index(es)       : [303]
#  Grouping(s)     : [264]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adjective4 Trigger_Rule
Noun1 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Determiner2 -> "tout"
Noun3 -> "risque" | "danger" | "responsabilité" | "aléa" | "hasard" | "inconvénient" | "gageure" | "menace" | "chance" | "fortune"
Adjective4 -> "élevé"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 159
#  French Term     : nié tout symptôme de
#  English Term(s) : ['denied any symptom of', 'denied any symptoms of']
#  Index(es)       : [311, 312]
#  Grouping(s)     : [264]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adposition4 Trigger_Rule
Noun1 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Determiner2 -> "tout"
Noun3 -> "symptôme"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 160
#  French Term     : nié tout problème de
#  English Term(s) : ['denied any problems of']
#  Index(es)       : [307]
#  Grouping(s)     : [264]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adposition4 Trigger_Rule
Noun1 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Determiner2 -> "tout"
Noun3 -> "problème" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 161
#  French Term     : nié toute importance
#  English Term(s) : ['denied any significant']
#  Index(es)       : [310]
#  Grouping(s)     : [264]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Determiner2 -> "toute"
Noun3 -> "importance" | "grandeur" | "intérêt" | "gravité" | "portée" | "prestige" | "influence" | "étendue" | "dimension" | "poids"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 162
#  French Term     : refusé tout courant
#  English Term(s) : ['denied any current']
#  Index(es)       : [302]
#  Grouping(s)     : [264]


cfg_grammar= """
S ->  Verb1 Adverb2 Noun3 Trigger_Rule
Verb1 -> "refusé" | "rejeter" | "renvoyer" | "contester" | "nier" | "débouter" | "évincer" | "éconduire" | "exclure" | "dédaigner"
Adverb2 -> "tout"
Noun3 -> "courant" | "cours" | "usuel" | "commun" | "fréquent" | "banal" | "habituel" | "usité" | "fil" | "flot"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 163
#  French Term     : refusé tout autre
#  English Term(s) : ['denied any other']
#  Index(es)       : [306]
#  Grouping(s)     : [264]


cfg_grammar= """
S ->  Verb1 Adverb2 Adjective3 Trigger_Rule
Verb1 -> "refusé" | "rejeter" | "renvoyer" | "contester" | "nier" | "débouter" | "évincer" | "éconduire" | "exclure" | "dédaigner"
Adverb2 -> "tout"
Adjective3 -> "autre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 164
#  French Term     : refusé tout
#  English Term(s) : ['denied any']
#  Index(es)       : [324]
#  Grouping(s)     : [285]


cfg_grammar= """
S ->  Verb1 Adverb2 Trigger_Rule
Verb1 -> "refusé" | "rejeter" | "renvoyer" | "contester" | "nier" | "débouter" | "évincer" | "éconduire" | "exclure" | "dédaigner"
Adverb2 -> "tout"
Trigger_Rule -> "|forward|trigger|negated|10|Group[285]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 165
#  French Term     : courant refusé
#  English Term(s) : ['denied current']
#  Index(es)       : [326]
#  Grouping(s)     : [287]


cfg_grammar= """
S ->  Verb1 Verb2 Trigger_Rule
Verb1 -> "courant" | "cours" | "usuel" | "commun" | "fréquent" | "banal" | "habituel" | "usité" | "fil" | "flot"
Verb2 -> "refusé" | "rejeter" | "renvoyer" | "contester" | "nier" | "débouter" | "évincer" | "éconduire" | "exclure" | "dédaigner"
Trigger_Rule -> "|forward|trigger|negated|10|Group[287]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 166
#  French Term     : jamais nié
#  English Term(s) : ['denied ever']
#  Index(es)       : [328]
#  Grouping(s)     : [289]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "jamais"
Verb2 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Trigger_Rule -> "|forward|trigger|negated|10|Group[289]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 167
#  French Term     : nié d'autres symptômes de
#  English Term(s) : ['denied other symptoms of']
#  Index(es)       : [330]
#  Grouping(s)     : [291]


cfg_grammar= """
S ->  Noun1 Determiner2 Adjective3 Noun4 Adposition5 Trigger_Rule
Noun1 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Determiner2 -> "d'"
Adjective3 -> "autres"
Noun4 -> "symptômes" | "présage" | "indice" | "marque" | "manifestation" | "syndrome" | "stigmate" | "diagnostique" | "prodrome" | "signal"
Adposition5 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[291]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 168
#  French Term     : nié problèmes avec
#  English Term(s) : ['denied problems with']
#  Index(es)       : [332]
#  Grouping(s)     : [293]


cfg_grammar= """
S ->  Adverb1 Noun2 Adposition3 Trigger_Rule
Adverb1 -> "nié"
Noun2 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition3 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[293]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 169
#  French Term     : nié symptômes de
#  English Term(s) : ['denied symptoms of']
#  Index(es)       : [334]
#  Grouping(s)     : [295]


cfg_grammar= """
S ->  Adverb1 Noun2 Adposition3 Trigger_Rule
Adverb1 -> "nié"
Noun2 -> "symptômes" | "présage" | "indice" | "marque" | "manifestation" | "syndrome" | "stigmate" | "diagnostique" | "prodrome" | "signal"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[295]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 170
#  French Term     : a nié qu'il y avait un courant
#  English Term(s) : ['denied that there was any current']
#  Index(es)       : [336]
#  Grouping(s)     : [297]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Subordinating_conjunction3 Pronoun4 Pronoun5 Verb6 Determiner7 Noun8 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Subordinating_conjunction3 -> "qu'"
Pronoun4 -> "il"
Pronoun5 -> "y"
Verb6 -> "avait"
Determiner7 -> "un"
Noun8 -> "courant" | "cours" | "usuel" | "commun" | "fréquent" | "banal" | "habituel" | "usité" | "fil" | "flot"
Trigger_Rule -> "|forward|trigger|negated|10|Group[297]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 171
#  French Term     : a nié qu'il y avait une histoire de
#  English Term(s) : ['denied that there was any history of', 'denied that there was history of', 'denied that there were any history of', 'denied that there were history of']
#  Index(es)       : [338, 339, 340, 341]
#  Grouping(s)     : [300]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Subordinating_conjunction3 Pronoun4 Pronoun5 Verb6 Determiner7 Noun8 Adposition9 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Subordinating_conjunction3 -> "qu'"
Pronoun4 -> "il"
Pronoun5 -> "y"
Verb6 -> "avait"
Determiner7 -> "une"
Noun8 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Adposition9 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[300]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 172
#  French Term     : a nié qu'il y avait
#  English Term(s) : ['denied that there was any', 'denied that there were any']
#  Index(es)       : [346, 347]
#  Grouping(s)     : [301]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Subordinating_conjunction3 Pronoun4 Pronoun5 Verb6 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Subordinating_conjunction3 -> "qu'"
Pronoun4 -> "il"
Pronoun5 -> "y"
Verb6 -> "avait"
Trigger_Rule -> "|forward|trigger|negated|10|Group[301]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 173
#  French Term     : nié qu'il y ait jamais eu l'histoire de
#  English Term(s) : ['denied that there was ever history of', 'denied that there were ever history of']
#  Index(es)       : [350, 351]
#  Grouping(s)     : [303]


cfg_grammar= """
S ->  Adverb1 Subordinating_conjunction2 Pronoun3 Pronoun4 Auxiliary5 Adverb6 Verb7 Determiner8 Noun9 Adposition10 Trigger_Rule
Adverb1 -> "nié"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Auxiliary5 -> "ait"
Adverb6 -> "jamais"
Verb7 -> "eu"
Determiner8 -> "l'"
Noun9 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Adposition10 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[303]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 174
#  French Term     : a nié qu'il y avait jamais
#  English Term(s) : ['denied that there was ever', 'denied that there were ever']
#  Index(es)       : [354, 355]
#  Grouping(s)     : [305]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Subordinating_conjunction3 Pronoun4 Pronoun5 Verb6 Adverb7 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Subordinating_conjunction3 -> "qu'"
Pronoun4 -> "il"
Pronoun5 -> "y"
Verb6 -> "avait"
Adverb7 -> "jamais"
Trigger_Rule -> "|forward|trigger|negated|10|Group[305]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 175
#  French Term     : a nié qu'il y avait des problèmes de
#  English Term(s) : ['denied that there was problems of']
#  Index(es)       : [358]
#  Grouping(s)     : [309]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Subordinating_conjunction3 Pronoun4 Pronoun5 Verb6 Determiner7 Noun8 Adposition9 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Subordinating_conjunction3 -> "qu'"
Pronoun4 -> "il"
Pronoun5 -> "y"
Verb6 -> "avait"
Determiner7 -> "des"
Noun8 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition9 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[309]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 176
#  French Term     : nié qu'il y avait des problèmes
#  English Term(s) : ['denied that there was problems', 'denied that there were problems']
#  Index(es)       : [360, 361]
#  Grouping(s)     : [311]


cfg_grammar= """
S ->  Adverb1 Subordinating_conjunction2 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Trigger_Rule
Adverb1 -> "nié"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Verb5 -> "avait"
Determiner6 -> "des"
Noun7 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Trigger_Rule -> "|forward|trigger|negated|10|Group[311]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 177
#  French Term     : nié qu'il y avait des problèmes de
#  English Term(s) : ['denied that there were problems of']
#  Index(es)       : [364]
#  Grouping(s)     : [323]


cfg_grammar= """
S ->  Adverb1 Subordinating_conjunction2 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Adposition8 Trigger_Rule
Adverb1 -> "nié"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Verb5 -> "avait"
Determiner6 -> "des"
Noun7 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition8 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[323]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 178
#  French Term     : a nié cette
#  English Term(s) : ['denied this']
#  Index(es)       : [366]
#  Grouping(s)     : [327]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Determiner3 -> "cette"
Trigger_Rule -> "|forward|trigger|negated|10|Group[327]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 179
#  French Term     : refusé l'utilisation d'autres
#  English Term(s) : ['denied use of other']
#  Index(es)       : [368]
#  Grouping(s)     : [329]


cfg_grammar= """
S ->  Verb1 Determiner2 Noun3 Adposition4 Adjective5 Trigger_Rule
Verb1 -> "refusé" | "rejeter" | "renvoyer" | "contester" | "nier" | "débouter" | "évincer" | "éconduire" | "exclure" | "dédaigner"
Determiner2 -> "l'"
Noun3 -> "utilisation" | "emploi" | "maniement" | "destination" | "exploitation" | "consommation" | "exercice" | "usage" | "amortissement" | "adoption"
Adposition4 -> "d'"
Adjective5 -> "autres"
Trigger_Rule -> "|forward|trigger|negated|10|Group[329]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 180
#  French Term     : utilisation refusée de
#  English Term(s) : ['denied use of']
#  Index(es)       : [370]
#  Grouping(s)     : [331]


cfg_grammar= """
S ->  Noun1 Verb2 Adposition3 Trigger_Rule
Noun1 -> "utilisation" | "emploi" | "maniement" | "destination" | "exploitation" | "consommation" | "exercice" | "usage" | "amortissement" | "adoption"
Verb2 -> "refusée" | "rejeter" | "renvoyer" | "contester" | "nier" | "débouter" | "évincer" | "éconduire" | "exclure" | "dédaigner"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[331]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 181
#  French Term     : nié
#  English Term(s) : ['denied']
#  Index(es)       : [372]
#  Grouping(s)     : [333]


cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "nié" | "dénié" | "réfuter" | "contredit" | "renier" | "disconvenir" | "rejeter" | "discuter" | "disputer" | "rejeté"
Trigger_Rule -> "|forward|trigger|negated|10|Group[333]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 182
#  French Term     : nie actif
#  English Term(s) : ['denies active']
#  Index(es)       : [374]
#  Grouping(s)     : [335]


cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Adjective2 -> "actif"
Trigger_Rule -> "|forward|trigger|negated|10|Group[335]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 183
#  French Term     : nie tout anormal
#  English Term(s) : ['denies any abnormal']
#  Index(es)       : [376]
#  Grouping(s)     : [337]


cfg_grammar= """
S ->  Noun1 Adverb2 Adjective3 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Adverb2 -> "tout"
Adjective3 -> "anormal"
Trigger_Rule -> "|forward|trigger|negated|10|Group[337]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 184
#  French Term     : refuse tout changement dans la
#  English Term(s) : ['denies any changes in the']
#  Index(es)       : [378]
#  Grouping(s)     : [337]


cfg_grammar= """
S ->  Verb1 Adverb2 Adverb3 Adposition4 Determiner5 Trigger_Rule
Verb1 -> "refuse" | "ajourner" | "compte" | "non" | "ajourné" | "blackbouler" | "décliner" | "nier" | "battu" | "renvoyer"
Adverb2 -> "tout"
Adverb3 -> "changement"
Adposition4 -> "dans"
Determiner5 -> "la"
Trigger_Rule -> "|forward|trigger|negated|10|Group[337]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 185
#  French Term     : nie tout changement dans la
#  English Term(s) : ['denies any change in the']
#  Index(es)       : [377]
#  Grouping(s)     : [337]


cfg_grammar= """
S ->  Noun1 Adverb2 Adverb3 Adposition4 Determiner5 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Adverb2 -> "tout"
Adverb3 -> "changement"
Adposition4 -> "dans"
Determiner5 -> "la"
Trigger_Rule -> "|forward|trigger|negated|10|Group[337]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 186
#  French Term     : nie tout courant
#  English Term(s) : ['denies any current']
#  Index(es)       : [382]
#  Grouping(s)     : [343]


cfg_grammar= """
S ->  Noun1 Adverb2 Adjective3 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Adverb2 -> "tout"
Adjective3 -> "courant"
Trigger_Rule -> "|forward|trigger|negated|10|Group[343]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 187
#  French Term     : nie tout risque élevé
#  English Term(s) : ['denies any high risk', 'denies any high-risk']
#  Index(es)       : [384, 385]
#  Grouping(s)     : [345]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adjective4 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Determiner2 -> "tout"
Noun3 -> "risque" | "danger" | "responsabilité" | "aléa" | "hasard" | "inconvénient" | "gageure" | "menace" | "chance" | "fortune"
Adjective4 -> "élevé"
Trigger_Rule -> "|forward|trigger|negated|10|Group[345]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 188
#  French Term     : nie toute histoire de
#  English Term(s) : ['denies any history of']
#  Index(es)       : [388]
#  Grouping(s)     : [349]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adposition4 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Determiner2 -> "toute"
Noun3 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[349]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 189
#  French Term     : nie toute autre
#  English Term(s) : ['denies any other']
#  Index(es)       : [390]
#  Grouping(s)     : [351]


cfg_grammar= """
S ->  Noun1 Adjective2 Adjective3 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Adjective2 -> "toute"
Adjective3 -> "autre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[351]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 190
#  French Term     : nie tout problème de
#  English Term(s) : ['denies any problems of']
#  Index(es)       : [392]
#  Grouping(s)     : [353]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adposition4 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Determiner2 -> "tout"
Noun3 -> "problème" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[353]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 191
#  French Term     : nie tout problème avec
#  English Term(s) : ['denies any problems with']
#  Index(es)       : [394]
#  Grouping(s)     : [355]


cfg_grammar= """
S ->  Noun1 Adverb2 Noun3 Adposition4 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Adverb2 -> "tout"
Noun3 -> "problème" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition4 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[355]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 192
#  French Term     : nie tout problème
#  English Term(s) : ['denies any problems']
#  Index(es)       : [396]
#  Grouping(s)     : [357]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Determiner2 -> "tout"
Noun3 -> "problème" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Trigger_Rule -> "|forward|trigger|negated|10|Group[357]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 193
#  French Term     : nie toute récente
#  English Term(s) : ['denies any recent']
#  Index(es)       : [398]
#  Grouping(s)     : [359]


cfg_grammar= """
S ->  Noun1 Determiner2 Adjective3 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Determiner2 -> "toute"
Adjective3 -> "récente"
Trigger_Rule -> "|forward|trigger|negated|10|Group[359]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 194
#  French Term     : nie toute importance
#  English Term(s) : ['denies any significant']
#  Index(es)       : [400]
#  Grouping(s)     : [361]


cfg_grammar= """
S ->  Noun1 Adjective2 Noun3 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Adjective2 -> "toute"
Noun3 -> "importance" | "grandeur" | "intérêt" | "gravité" | "portée" | "prestige" | "influence" | "étendue" | "dimension" | "poids"
Trigger_Rule -> "|forward|trigger|negated|10|Group[361]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 195
#  French Term     : nie tout symptôme de
#  English Term(s) : ['denies any symptom of', 'denies any symptoms of']
#  Index(es)       : [402, 403]
#  Grouping(s)     : [363]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adposition4 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Determiner2 -> "tout"
Noun3 -> "symptôme"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[363]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 196
#  French Term     : nie tout abus
#  English Term(s) : ['denies any undue']
#  Index(es)       : [406]
#  Grouping(s)     : [367]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Determiner2 -> "tout"
Noun3 -> "abus" | "illégalité" | "injustice" | "excès" | "intempérance" | "exagération" | "féodalité" | "empiètement" | "profanation" | "inconduite"
Trigger_Rule -> "|forward|trigger|negated|10|Group[367]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 197
#  French Term     : nie tout
#  English Term(s) : ['denies any']
#  Index(es)       : [408]
#  Grouping(s)     : [369]


cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Adjective2 -> "tout"
Trigger_Rule -> "|forward|trigger|negated|10|Group[369]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 198
#  French Term     : nie courant
#  English Term(s) : ['denies current']
#  Index(es)       : [410]
#  Grouping(s)     : [371]


cfg_grammar= """
S ->  Noun1 Verb2 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Verb2 -> "courant" | "cours" | "usuel" | "commun" | "fréquent" | "banal" | "habituel" | "usité" | "fil" | "flot"
Trigger_Rule -> "|forward|trigger|negated|10|Group[371]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 199
#  French Term     : nie jamais
#  English Term(s) : ['denies ever']
#  Index(es)       : [412]
#  Grouping(s)     : [373]


cfg_grammar= """
S ->  Noun1 Adverb2 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Adverb2 -> "jamais"
Trigger_Rule -> "|forward|trigger|negated|10|Group[373]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 200
#  French Term     : nie les problèmes avec
#  English Term(s) : ['denies problems with']
#  Index(es)       : [414]
#  Grouping(s)     : [375]


cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Adposition4 Trigger_Rule
Adverb1 -> "nie"
Determiner2 -> "les"
Noun3 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition4 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[375]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
