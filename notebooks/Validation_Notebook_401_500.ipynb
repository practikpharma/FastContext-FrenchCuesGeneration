# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 401
#  French Term     : nég
#  English Term(s) : ['neg']
#  Index(es)       : [739]
#  Grouping(s)     : [688]


cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "nég"
Trigger_Rule -> "|backward|trigger|negated|10|Group[688]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 402
#  French Term     : voisin appelé
#  English Term(s) : ['neighbor called', 'neighbour called']
#  Index(es)       : [741, 743, 745, 747]
#  Grouping(s)     : [690, 691]


cfg_grammar= """
S ->  Adjective1 Auxiliary2 Trigger_Rule
Adjective1 -> "voisin"
Auxiliary2 -> "appelé"
Trigger_Rule -> "|both|termination|historical|30|Group[690, 691]" |"|both|termination|nonpatient|30|Group[690, 691]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 403
#  French Term     : voisins appelés
#  English Term(s) : ['neighbors called', 'neighbours called']
#  Index(es)       : [742, 744, 746, 748]
#  Grouping(s)     : [690, 691]


cfg_grammar= """
S ->  Adjective1 Verb2 Trigger_Rule
Adjective1 -> "voisins"
Verb2 -> "appelés" | "inviter" | "citer" | "demander" | "crier" | "réclamer" | "convier" | "solliciter" | "exiger" | "baptiser"
Trigger_Rule -> "|both|termination|historical|30|Group[690, 691]" |"|both|termination|nonpatient|30|Group[690, 691]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 404
#  French Term     : voisins
#  English Term(s) : ['neighbors', 'neighbours']
#  Index(es)       : [749, 751]
#  Grouping(s)     : [694]


cfg_grammar= """
S ->  Adjective1 Trigger_Rule
Adjective1 -> "voisins"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[694]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 405
#  French Term     : voisin
#  English Term(s) : ['neighbor', 'neighbour']
#  Index(es)       : [750, 752]
#  Grouping(s)     : [694, 695]


cfg_grammar= """
S ->  Adjective1 Trigger_Rule
Adjective1 -> "voisin"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[694, 695]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 406
#  French Term     : jamais aucun
#  English Term(s) : ['never any']
#  Index(es)       : [753]
#  Grouping(s)     : [702]


cfg_grammar= """
S ->  Adverb1 Determiner2 Trigger_Rule
Adverb1 -> "jamais"
Determiner2 -> "aucun"
Trigger_Rule -> "|forward|trigger|negated|10|Group[702]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 407
#  French Term     : jamais développé
#  English Term(s) : ['never developed']
#  Index(es)       : [755]
#  Grouping(s)     : [704]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "jamais"
Verb2 -> "développé" | "ample" | "grand" | "évolué" | "découplé" | "précis" | "épanoui" | "fort" | "mûr" | "gros"
Trigger_Rule -> "|forward|trigger|negated|10|Group[704]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 408
#  French Term     : jamais eu
#  English Term(s) : ['never had']
#  Index(es)       : [757]
#  Grouping(s)     : [706]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "jamais"
Verb2 -> "eu"
Trigger_Rule -> "|forward|trigger|negated|10|Group[706]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 409
#  French Term     : Néanmoins
#  English Term(s) : ['nevertheless']
#  Index(es)       : [759]
#  Grouping(s)     : [708]


cfg_grammar= """
S ->  Adverb1 Trigger_Rule
Adverb1 -> "Néanmoins"
Trigger_Rule -> "|forward|termination|negated|10|Group[708]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 410
#  French Term     : non \ w + évident de
#  English Term(s) : ['no \\w+ evid of']
#  Index(es)       : [760]
#  Grouping(s)     : [709]


cfg_grammar= """
S ->  Adverb1 Adjective2 Noun3 Adposition4 Noun5 Adposition6 Trigger_Rule
Adverb1 -> "non"
Adjective2 -> "\"
Noun3 -> "w"
Adposition4 -> "+"
Noun5 -> "évident" | "indubitable" | "apparent" | "patent" | "certain" | "flagrant" | "authentique" | "notoire" | "incontestable" | "clair"
Adposition6 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[709]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 411
#  French Term     : non \ w + évident de suggérer
#  English Term(s) : ['no \\w+ evid to suggest']
#  Index(es)       : [762]
#  Grouping(s)     : [711]


cfg_grammar= """
S ->  Adverb1 Adjective2 Noun3 Adposition4 Noun5 Adposition6 Verb7 Trigger_Rule
Adverb1 -> "non"
Adjective2 -> "\"
Noun3 -> "w"
Adposition4 -> "+"
Noun5 -> "évident" | "indubitable" | "apparent" | "patent" | "certain" | "flagrant" | "authentique" | "notoire" | "incontestable" | "clair"
Adposition6 -> "de"
Verb7 -> "suggérer" | "proposer" | "inspirer" | "insinuer" | "souffler" | "évoquer" | "effleurer" | "dicter" | "persuader" | "susciter"
Trigger_Rule -> "|forward|trigger|negated|10|Group[711]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 412
#  French Term     : non \ w + évident pour
#  English Term(s) : ['no \\w+ evid to']
#  Index(es)       : [764]
#  Grouping(s)     : [713]


cfg_grammar= """
S ->  Adverb1 Adjective2 Noun3 Adposition4 Noun5 Adposition6 Trigger_Rule
Adverb1 -> "non"
Adjective2 -> "\"
Noun3 -> "w"
Adposition4 -> "+"
Noun5 -> "évident" | "indubitable" | "apparent" | "patent" | "certain" | "flagrant" | "authentique" | "notoire" | "incontestable" | "clair"
Adposition6 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[713]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 413
#  French Term     : aucun \ w + preuve de
#  English Term(s) : ['no \\w+ evidence of']
#  Index(es)       : [766]
#  Grouping(s)     : [715]


cfg_grammar= """
S ->  Determiner1 Adjective2 Noun3 Adposition4 Noun5 Adposition6 Trigger_Rule
Determiner1 -> "aucun"
Adjective2 -> "\"
Noun3 -> "w"
Adposition4 -> "+"
Noun5 -> "preuve" | "indice" | "confirmation" | "conviction" | "constatation" | "document" | "gage" | "critère" | "argument" | "signe"
Adposition6 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[715]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 414
#  French Term     : aucune preuve à suggérer
#  English Term(s) : ['no \\w+ evidence to suggest', 'no evidence to suggest']
#  Index(es)       : [768, 769]
#  Grouping(s)     : [717]


cfg_grammar= """
S ->  Determiner1 Noun2 Adposition3 Verb4 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "preuve" | "indice" | "confirmation" | "conviction" | "constatation" | "document" | "gage" | "critère" | "argument" | "signe"
Adposition3 -> "à"
Verb4 -> "suggérer" | "proposer" | "inspirer" | "insinuer" | "souffler" | "évoquer" | "effleurer" | "dicter" | "persuader" | "susciter"
Trigger_Rule -> "|forward|trigger|negated|10|Group[717]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 415
#  French Term     : aucun \ w + preuve à
#  English Term(s) : ['no \\w+ evidence to']
#  Index(es)       : [772]
#  Grouping(s)     : [719]


cfg_grammar= """
S ->  Determiner1 Adjective2 Noun3 Adposition4 Noun5 Adposition6 Trigger_Rule
Determiner1 -> "aucun"
Adjective2 -> "\"
Noun3 -> "w"
Adposition4 -> "+"
Noun5 -> "preuve" | "indice" | "confirmation" | "conviction" | "constatation" | "document" | "gage" | "critère" | "argument" | "signe"
Adposition6 -> "à"
Trigger_Rule -> "|forward|trigger|negated|10|Group[719]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 416
#  French Term     : aucune preuve
#  English Term(s) : ['no \\w+ evidence', 'no evidence']
#  Index(es)       : [774, 775]
#  Grouping(s)     : [721]


cfg_grammar= """
S ->  Determiner1 Noun2 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "preuve" | "indice" | "confirmation" | "conviction" | "constatation" | "document" | "gage" | "critère" | "argument" | "signe"
Trigger_Rule -> "|forward|trigger|negated|10|Group[721]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 417
#  French Term     : non \ w + evid
#  English Term(s) : ['no \\w+ evid']
#  Index(es)       : [778]
#  Grouping(s)     : [723]


cfg_grammar= """
S ->  Adverb1 Adjective2 Noun3 Adposition4 Noun5 Trigger_Rule
Adverb1 -> "non"
Adjective2 -> "\"
Noun3 -> "w"
Adposition4 -> "+"
Noun5 -> "evid"
Trigger_Rule -> "|forward|trigger|negated|10|Group[723]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 418
#  French Term     : no \ w + a été donné
#  English Term(s) : ['no \\w+ was given']
#  Index(es)       : [780]
#  Grouping(s)     : [725]


cfg_grammar= """
S ->  Noun1 Adjective2 Noun3 Adposition4 Auxiliary5 Auxiliary6 Verb7 Trigger_Rule
Noun1 -> "no"
Adjective2 -> "\"
Noun3 -> "w"
Adposition4 -> "+"
Auxiliary5 -> "a"
Auxiliary6 -> "été"
Verb7 -> "donné" | "déterminé" | "fixé" | "offert" | "foutre" | "fixer" | "porter" | "certain" | "attribué" | "dire"
Trigger_Rule -> "|forward|termination|negated|10|Group[725]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 419
#  French Term     : pas anormal
#  English Term(s) : ['no abnormal']
#  Index(es)       : [781]
#  Grouping(s)     : [726]


cfg_grammar= """
S ->  Adverb1 Adjective2 Trigger_Rule
Adverb1 -> "pas"
Adjective2 -> "anormal"
Trigger_Rule -> "|forward|trigger|negated|10|Group[726]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 420
#  French Term     : pas d'aigu
#  English Term(s) : ['no acute']
#  Index(es)       : [783]
#  Grouping(s)     : [728]


cfg_grammar= """
S ->  Adverb1 Adposition2 Noun3 Trigger_Rule
Adverb1 -> "pas"
Adposition2 -> "d'"
Noun3 -> "aigu" | "vif" | "pénétrant" | "cuisant" | "incisif" | "piquant" | "tranchant" | "perçant" | "aigre" | "strident"
Trigger_Rule -> "|forward|trigger|negated|10|Group[728]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 421
#  French Term     : aucun autre significatif
#  English Term(s) : ['no additional significant']
#  Index(es)       : [785]
#  Grouping(s)     : [730]


cfg_grammar= """
S ->  Determiner1 Adjective2 Noun3 Trigger_Rule
Determiner1 -> "aucun"
Adjective2 -> "autre"
Noun3 -> "significatif" | "évocateur" | "caractéristique" | "éloquent" | "expressif" | "formel" | "clair" | "notoire" | "parlant" | "marquant"
Trigger_Rule -> "|forward|trigger|negated|10|Group[730]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 422
#  French Term     : pas apparent
#  English Term(s) : ['no apparent']
#  Index(es)       : [787]
#  Grouping(s)     : [732]


cfg_grammar= """
S ->  Adverb1 Adjective2 Trigger_Rule
Adverb1 -> "pas"
Adjective2 -> "apparent"
Trigger_Rule -> "|forward|trigger|negated|10|Group[732]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 423
#  French Term     : aucune cause de
#  English Term(s) : ['no cause of']
#  Index(es)       : [789]
#  Grouping(s)     : [734]


cfg_grammar= """
S ->  Determiner1 Noun2 Adposition3 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "cause" | "motif" | "raison" | "ferment" | "procès" | "sujet" | "prétexte" | "moteur" | "fondement" | "germe"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[734]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 424
#  French Term     : pas de changement
#  English Term(s) : ['no change']
#  Index(es)       : [791]
#  Grouping(s)     : [736]


cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Trigger_Rule
Adverb1 -> "pas"
Determiner2 -> "de"
Noun3 -> "changement" | "modification" | "altération" | "évolution" | "inversion" | "fluctuation" | "transformation" | "métamorphose" | "mutation" | "retour"
Trigger_Rule -> "|both|pseudo|negated|10|Group[736]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 425
#  French Term     : aucune plainte de
#  English Term(s) : ['no complaints of']
#  Index(es)       : [792]
#  Grouping(s)     : [737]


cfg_grammar= """
S ->  Determiner1 Noun2 Adposition3 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "plainte" | "grief" | "complainte" | "jérémiade" | "pleur" | "hurlement" | "cri" | "lamentation" | "gémissement" | "criaillerie"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[737]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 426
#  French Term     : aucun courant
#  English Term(s) : ['no current']
#  Index(es)       : [794]
#  Grouping(s)     : [739]


cfg_grammar= """
S ->  Determiner1 Noun2 Trigger_Rule
Determiner1 -> "aucun"
Noun2 -> "courant" | "cours" | "usuel" | "commun" | "fréquent" | "banal" | "habituel" | "usité" | "fil" | "flot"
Trigger_Rule -> "|forward|trigger|negated|10|Group[739]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 427
#  French Term     : pas de changement définitif
#  English Term(s) : ['no definite change']
#  Index(es)       : [796]
#  Grouping(s)     : [741]


cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Adjective4 Trigger_Rule
Adverb1 -> "pas"
Determiner2 -> "de"
Noun3 -> "changement" | "modification" | "altération" | "évolution" | "inversion" | "fluctuation" | "transformation" | "métamorphose" | "mutation" | "retour"
Adjective4 -> "définitif"
Trigger_Rule -> "|both|pseudo|negated|10|Group[741]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 428
#  French Term     : non e / o
#  English Term(s) : ['no e/o', 'no e / o']
#  Index(es)       : [797, 798]
#  Grouping(s)     : [742]


cfg_grammar= """
S ->  Adverb1 Noun2 Adposition3 Noun4 Trigger_Rule
Adverb1 -> "non"
Noun2 -> "e"
Adposition3 -> "/"
Noun4 -> "o"
Trigger_Rule -> "|forward|trigger|negated|10|Group[742]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 429
#  French Term     : non e o
#  English Term(s) : ['no e o']
#  Index(es)       : [801]
#  Grouping(s)     : [744]


cfg_grammar= """
S ->  Adverb1 Adposition2 Noun3 Trigger_Rule
Adverb1 -> "non"
Adposition2 -> "e"
Noun3 -> "o"
Trigger_Rule -> "|forward|trigger|negated|10|Group[744]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 430
#  French Term     : aucune preuve de
#  English Term(s) : ['no evidence of']
#  Index(es)       : [803]
#  Grouping(s)     : [746]


cfg_grammar= """
S ->  Determiner1 Noun2 Adposition3 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "preuve" | "indice" | "confirmation" | "conviction" | "constatation" | "document" | "gage" | "critère" | "argument" | "signe"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[746]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 431
#  French Term     : aucune découverte de
#  English Term(s) : ['no findings of']
#  Index(es)       : [805]
#  Grouping(s)     : [752]


cfg_grammar= """
S ->  Determiner1 Noun2 Adposition3 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "découverte" | "exploration" | "reconnaissance" | "initiation" | "trouvaille" | "discernement" | "innovation" | "pêche" | "décèlement" | "révélation"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[752]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 432
#  French Term     : aucun résultat à indiquer
#  English Term(s) : ['no findings to indicate']
#  Index(es)       : [807]
#  Grouping(s)     : [754]


cfg_grammar= """
S ->  Determiner1 Noun2 Adposition3 Verb4 Trigger_Rule
Determiner1 -> "aucun"
Noun2 -> "résultat" | "suite" | "solution" | "conclusion" | "conséquence" | "effet" | "dénouement" | "fruit" | "produit" | "réponse"
Adposition3 -> "à"
Verb4 -> "indiquer" | "signifier" | "prouver" | "montrer" | "désigner" | "témoigner" | "afficher" | "signaler" | "démontrer" | "révéler"
Trigger_Rule -> "|forward|trigger|negated|10|Group[754]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 433
#  French Term     : aucun résultat à suggérer
#  English Term(s) : ['no findings to suggest']
#  Index(es)       : [808]
#  Grouping(s)     : [754]


cfg_grammar= """
S ->  Determiner1 Noun2 Adposition3 Verb4 Trigger_Rule
Determiner1 -> "aucun"
Noun2 -> "résultat" | "suite" | "solution" | "conclusion" | "conséquence" | "effet" | "dénouement" | "fruit" | "produit" | "réponse"
Adposition3 -> "à"
Verb4 -> "suggérer" | "proposer" | "inspirer" | "insinuer" | "souffler" | "évoquer" | "effleurer" | "dicter" | "persuader" | "susciter"
Trigger_Rule -> "|forward|trigger|negated|10|Group[754]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 434
#  French Term     : pas h o
#  English Term(s) : ['no h o']
#  Index(es)       : [811]
#  Grouping(s)     : [758]


cfg_grammar= """
S ->  Adverb1 Noun2 Noun3 Trigger_Rule
Adverb1 -> "pas"
Noun2 -> "h" | "âge" | "période" | "tantôt" | "constante de Planck" | "h" | "moment" | "jours" | "liturgie" | "instant"
Noun3 -> "o"
Trigger_Rule -> "|forward|trigger|negated|10|Group[758]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 435
#  French Term     : pas d'histoire de
#  English Term(s) : ['no history of']
#  Index(es)       : [813]
#  Grouping(s)     : [760]


cfg_grammar= """
S ->  Adverb1 Adposition2 Noun3 Adposition4 Trigger_Rule
Adverb1 -> "pas"
Adposition2 -> "d'"
Noun3 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[760]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 436
#  French Term     : pas de hx
#  English Term(s) : ['no hx of']
#  Index(es)       : [815]
#  Grouping(s)     : [762]


cfg_grammar= """
S ->  Adverb1 Adposition2 Verb3 Trigger_Rule
Adverb1 -> "pas"
Adposition2 -> "de"
Verb3 -> "hx"
Trigger_Rule -> "|forward|trigger|negated|10|Group[762]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 437
#  French Term     : pas d'augmentation
#  English Term(s) : ['no increase']
#  Index(es)       : [817]
#  Grouping(s)     : [764]


cfg_grammar= """
S ->  Adverb1 Adposition2 Noun3 Trigger_Rule
Adverb1 -> "pas"
Adposition2 -> "d'"
Noun3 -> "augmentation" | "hausse" | "agrandissement" | "développement" | "élévation" | "croissance" | "extension" | "amplification" | "addition" | "dilatation"
Trigger_Rule -> "|both|pseudo|negated|10|Group[764]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 438
#  French Term     : aucune indication de
#  English Term(s) : ['no indication of', 'no indications of']
#  Index(es)       : [818, 819]
#  Grouping(s)     : [765]


cfg_grammar= """
S ->  Determiner1 Noun2 Adposition3 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "indication" | "renseignement" | "avis" | "indice" | "annonce" | "recommandation" | "note" | "directive" | "critère" | "prescription"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[765]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 439
#  French Term     : pas de changement d'intervalle
#  English Term(s) : ['no interval change']
#  Index(es)       : [822]
#  Grouping(s)     : [769]


cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Adposition4 Noun5 Trigger_Rule
Adverb1 -> "pas"
Determiner2 -> "de"
Noun3 -> "changement" | "modification" | "altération" | "évolution" | "inversion" | "fluctuation" | "transformation" | "métamorphose" | "mutation" | "retour"
Adposition4 -> "d'"
Noun5 -> "intervalle" | "pause" | "espace" | "entracte" | "écart" | "interstice" | "intermède" | "période" | "marge" | "fente"
Trigger_Rule -> "|both|pseudo|negated|10|Group[769]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 440
#  French Term     : aucune histoire connue de
#  English Term(s) : ['no known history of']
#  Index(es)       : [823]
#  Grouping(s)     : [770]


cfg_grammar= """
S ->  Determiner1 Noun2 Verb3 Adposition4 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Verb3 -> "connue" | "révélé" | "présenté" | "lancé" | "illustre" | "commun" | "notoire" | "public" | "renommé" | "proverbial"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[770]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 441
#  French Term     : aucun hx connu de
#  English Term(s) : ['no known hx of']
#  Index(es)       : [825]
#  Grouping(s)     : [772]


cfg_grammar= """
S ->  Determiner1 Auxiliary2 Verb3 Adposition4 Trigger_Rule
Determiner1 -> "aucun"
Auxiliary2 -> "hx"
Verb3 -> "connu" | "commun" | "notoire" | "familier" | "public" | "réputé" | "courant" | "répandu" | "historique" | "révélé"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[772]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 442
#  French Term     : n'est plus présent
#  English Term(s) : ['no longer present']
#  Index(es)       : [827]
#  Grouping(s)     : [774]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Adjective4 Trigger_Rule
Adverb1 -> "n'"
Auxiliary2 -> "est"
Adverb3 -> "plus"
Adjective4 -> "présent"
Trigger_Rule -> "|backward|trigger|negated|10|Group[774]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 443
#  French Term     : plus maintenant
#  English Term(s) : ['no longer']
#  Index(es)       : [829]
#  Grouping(s)     : [776]


cfg_grammar= """
S ->  Adverb1 Adverb2 Trigger_Rule
Adverb1 -> "plus"
Adverb2 -> "maintenant"
Trigger_Rule -> "|forward|trigger|negated|10|Group[776]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 444
#  French Term     : pas majeur
#  English Term(s) : ['no major']
#  Index(es)       : [831]
#  Grouping(s)     : [778]


cfg_grammar= """
S ->  Adverb1 Adjective2 Trigger_Rule
Adverb1 -> "pas"
Adjective2 -> "majeur"
Trigger_Rule -> "|forward|trigger|negated|10|Group[778]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 445
#  French Term     : aucune preuve mammographique de
#  English Term(s) : ['no mammographic evidence of']
#  Index(es)       : [833]
#  Grouping(s)     : [780]


cfg_grammar= """
S ->  Determiner1 Noun2 Adjective3 Adposition4 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "preuve" | "indice" | "confirmation" | "conviction" | "constatation" | "document" | "gage" | "critère" | "argument" | "signe"
Adjective3 -> "mammographique"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[780]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 446
#  French Term     : aucune mention de
#  English Term(s) : ['no mention of']
#  Index(es)       : [835]
#  Grouping(s)     : [782]


cfg_grammar= """
S ->  Determiner1 Noun2 Adposition3 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "mention" | "citation" | "inscription" | "évocation" | "mémoire" | "autonymie" | "énonciation" | "notation" | "récompense" | "nomination"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[782]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 447
#  French Term     : aucune nouvelle preuve
#  English Term(s) : ['no new evidence']
#  Index(es)       : [837]
#  Grouping(s)     : [784]


cfg_grammar= """
S ->  Determiner1 Adjective2 Noun3 Trigger_Rule
Determiner1 -> "aucune"
Adjective2 -> "nouvelle"
Noun3 -> "preuve" | "indice" | "confirmation" | "conviction" | "constatation" | "document" | "gage" | "critère" | "argument" | "signe"
Trigger_Rule -> "|forward|trigger|negated|10|Group[784]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 448
#  French Term     : pas de nouveau
#  English Term(s) : ['no new']
#  Index(es)       : [839]
#  Grouping(s)     : [786]


cfg_grammar= """
S ->  Adverb1 Adposition2 Noun3 Trigger_Rule
Adverb1 -> "pas"
Adposition2 -> "de"
Noun3 -> "nouveau" | "jeune" | "frais" | "original" | "novice" | "récent" | "inédit" | "vert" | "inexpérimenté" | "autre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[786]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 449
#  French Term     : aucune autre preuve
#  English Term(s) : ['no other evidence']
#  Index(es)       : [841]
#  Grouping(s)     : [788]


cfg_grammar= """
S ->  Determiner1 Adjective2 Noun3 Trigger_Rule
Determiner1 -> "aucune"
Adjective2 -> "autre"
Noun3 -> "preuve" | "indice" | "confirmation" | "conviction" | "constatation" | "document" | "gage" | "critère" | "argument" | "signe"
Trigger_Rule -> "|forward|trigger|negated|10|Group[788]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 450
#  French Term     : pas d'autres symptômes de
#  English Term(s) : ['no other symptoms of']
#  Index(es)       : [843]
#  Grouping(s)     : [790]


cfg_grammar= """
S ->  Adverb1 Determiner2 Adjective3 Noun4 Adposition5 Trigger_Rule
Adverb1 -> "pas"
Determiner2 -> "d'"
Adjective3 -> "autres"
Noun4 -> "symptômes" | "présage" | "indice" | "marque" | "manifestation" | "syndrome" | "stigmate" | "diagnostique" | "prodrome" | "signal"
Adposition5 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[790]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 451
#  French Term     : aucun autre
#  English Term(s) : ['no other']
#  Index(es)       : [845]
#  Grouping(s)     : [792]


cfg_grammar= """
S ->  Determiner1 Adjective2 Trigger_Rule
Determiner1 -> "aucun"
Adjective2 -> "autre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[792]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 452
#  French Term     : pas de problèmes avec '
#  English Term(s) : ["no problems with '"]
#  Index(es)       : [847]
#  Grouping(s)     : [794]


cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Adposition4 Punctuation5 Trigger_Rule
Adverb1 -> "pas"
Determiner2 -> "de"
Noun3 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition4 -> "avec"
Punctuation5 -> "'"
Trigger_Rule -> "|forward|trigger|negated|10|Group[794]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 453
#  French Term     : aucune preuve radiographique de
#  English Term(s) : ['no radiographic evidence of']
#  Index(es)       : [849]
#  Grouping(s)     : [796]


cfg_grammar= """
S ->  Determiner1 Noun2 Adjective3 Adposition4 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "preuve" | "indice" | "confirmation" | "conviction" | "constatation" | "document" | "gage" | "critère" | "argument" | "signe"
Adjective3 -> "radiographique"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[796]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 454
#  French Term     : pas récurrent
#  English Term(s) : ['no recurrent']
#  Index(es)       : [851]
#  Grouping(s)     : [798]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "pas"
Verb2 -> "récurrent" | "alternatif" | "alternant" | "épidémique" | "récidivant" | "séquentiel" | "répétitif" | "récurrent" | "périodique" | "pérenne"
Trigger_Rule -> "|forward|trigger|negated|10|Group[798]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 455
#  French Term     : aucune mention signalée
#  English Term(s) : ['no reported mention']
#  Index(es)       : [853]
#  Grouping(s)     : [800]


cfg_grammar= """
S ->  Determiner1 Noun2 Adjective3 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "mention" | "citation" | "inscription" | "évocation" | "mémoire" | "autonymie" | "énonciation" | "notation" | "récompense" | "nomination"
Adjective3 -> "signalée"
Trigger_Rule -> "|forward|trigger|negated|10|Group[800]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 456
#  French Term     : non rapporté
#  English Term(s) : ['no reported']
#  Index(es)       : [855]
#  Grouping(s)     : [802]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "non"
Verb2 -> "rapporté" | "rendre" | "dénoncer" | "porter" | "remettre" | "produire" | "ramener" | "citer" | "dire" | "apporter"
Trigger_Rule -> "|forward|trigger|negated|10|Group[802]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 457
#  French Term     : pas de résidu
#  English Term(s) : ['no residual']
#  Index(es)       : [857]
#  Grouping(s)     : [804]


cfg_grammar= """
S ->  Adverb1 Determiner2 Verb3 Trigger_Rule
Adverb1 -> "pas"
Determiner2 -> "de"
Verb3 -> "résidu" | "reliquat" | "déchet" | "rebut" | "lie" | "ordure" | "copeau" | "détritus" | "cadmie" | "rognure"
Trigger_Rule -> "|forward|trigger|negated|10|Group[804]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 458
#  French Term     : aucun signe de
#  English Term(s) : ['no sign of', 'no signs of']
#  Index(es)       : [859, 860]
#  Grouping(s)     : [806]


cfg_grammar= """
S ->  Determiner1 Noun2 Adposition3 Trigger_Rule
Determiner1 -> "aucun"
Noun2 -> "signe" | "symptôme" | "marque" | "signal" | "symbole" | "emblème" | "présage" | "attribut" | "témoignage" | "empreinte"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[806]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 459
#  French Term     : pas de changement significatif
#  English Term(s) : ['no significant change']
#  Index(es)       : [863]
#  Grouping(s)     : [808]


cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Adjective4 Trigger_Rule
Adverb1 -> "pas"
Determiner2 -> "de"
Noun3 -> "changement" | "modification" | "altération" | "évolution" | "inversion" | "fluctuation" | "transformation" | "métamorphose" | "mutation" | "retour"
Adjective4 -> "significatif"
Trigger_Rule -> "|both|pseudo|negated|10|Group[808]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 460
#  French Term     : pas de changement d'intervalle significatif
#  English Term(s) : ['no significant interval change']
#  Index(es)       : [864]
#  Grouping(s)     : [809]


cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Adposition4 Noun5 Adjective6 Trigger_Rule
Adverb1 -> "pas"
Determiner2 -> "de"
Noun3 -> "changement" | "modification" | "altération" | "évolution" | "inversion" | "fluctuation" | "transformation" | "métamorphose" | "mutation" | "retour"
Adposition4 -> "d'"
Noun5 -> "intervalle" | "pause" | "espace" | "entracte" | "écart" | "interstice" | "intermède" | "période" | "marge" | "fente"
Adjective6 -> "significatif"
Trigger_Rule -> "|both|pseudo|negated|10|Group[809]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 461
#  French Term     : non significatif
#  English Term(s) : ['no significant']
#  Index(es)       : [865]
#  Grouping(s)     : [810]


cfg_grammar= """
S ->  Adverb1 Adjective2 Trigger_Rule
Adverb1 -> "non"
Adjective2 -> "significatif"
Trigger_Rule -> "|forward|trigger|negated|10|Group[810]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 462
#  French Term     : aucun signe ou symptôme de
#  English Term(s) : ['no signs or symptoms of']
#  Index(es)       : [867]
#  Grouping(s)     : [814]


cfg_grammar= """
S ->  Determiner1 Noun2 Coordinating_conjunction3 Noun4 Adposition5 Trigger_Rule
Determiner1 -> "aucun"
Noun2 -> "signe" | "symptôme" | "marque" | "signal" | "symbole" | "emblème" | "présage" | "attribut" | "témoignage" | "empreinte"
Coordinating_conjunction3 -> "ou"
Noun4 -> "symptôme"
Adposition5 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[814]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 463
#  French Term     : pas de signe
#  English Term(s) : ['no sign']
#  Index(es)       : [869]
#  Grouping(s)     : [816]


cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Trigger_Rule
Adverb1 -> "pas"
Determiner2 -> "de"
Noun3 -> "signe" | "symptôme" | "marque" | "signal" | "symbole" | "emblème" | "présage" | "attribut" | "témoignage" | "empreinte"
Trigger_Rule -> "|forward|trigger|negated|10|Group[816]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 464
#  French Term     : aucune suggestion de
#  English Term(s) : ['no suggestion of']
#  Index(es)       : [871]
#  Grouping(s)     : [818]


cfg_grammar= """
S ->  Determiner1 Noun2 Adposition3 Trigger_Rule
Determiner1 -> "aucune"
Noun2 -> "suggestion" | "conseil" | "proposition" | "insinuation" | "évocation" | "captation" | "envoûtement" | "suscitation" | "persuasion" | "incitation"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[818]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 465
#  French Term     : pas de changement suspect
#  English Term(s) : ['no suspicious change']
#  Index(es)       : [873]
#  Grouping(s)     : [820]


cfg_grammar= """
S ->  Adverb1 Determiner2 Adverb3 Adjective4 Trigger_Rule
Adverb1 -> "pas"
Determiner2 -> "de"
Adverb3 -> "changement"
Adjective4 -> "suspect"
Trigger_Rule -> "|both|pseudo|negated|10|Group[820]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 466
#  French Term     : pas méfiant
#  English Term(s) : ['no suspicious']
#  Index(es)       : [874]
#  Grouping(s)     : [821]


cfg_grammar= """
S ->  Adverb1 Adjective2 Trigger_Rule
Adverb1 -> "pas"
Adjective2 -> "méfiant"
Trigger_Rule -> "|forward|trigger|negated|10|Group[821]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 467
#  French Term     : pas de sxs de
#  English Term(s) : ['no sxs of']
#  Index(es)       : [876]
#  Grouping(s)     : [823]


cfg_grammar= """
S ->  Adverb1 Adposition2 Noun3 Adposition4 Trigger_Rule
Adverb1 -> "pas"
Adposition2 -> "de"
Noun3 -> "sxs"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[823]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 468
#  French Term     : pas visible
#  English Term(s) : ['no visable']
#  Index(es)       : [878]
#  Grouping(s)     : [825]


cfg_grammar= """
S ->  Adverb1 Adjective2 Trigger_Rule
Adverb1 -> "pas"
Adjective2 -> "visible"
Trigger_Rule -> "|forward|trigger|negated|10|Group[825]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 469
#  French Term     : non diagnostique
#  English Term(s) : ['non diagnostic']
#  Index(es)       : [880]
#  Grouping(s)     : [827]


cfg_grammar= """
S ->  Adverb1 Adjective2 Trigger_Rule
Adverb1 -> "non"
Adjective2 -> "diagnostique"
Trigger_Rule -> "|backward|trigger|negated|10|Group[827]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 470
#  French Term     : aucun
#  English Term(s) : ['none']
#  Index(es)       : [882]
#  Grouping(s)     : [829]


cfg_grammar= """
S ->  Determiner1 Trigger_Rule
Determiner1 -> "aucun"
Trigger_Rule -> "|forward|trigger|negated|10|Group[829]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 471
#  French Term     : ni tout
#  English Term(s) : ['nor all']
#  Index(es)       : [884]
#  Grouping(s)     : [831]


cfg_grammar= """
S ->  Coordinating_conjunction1 Adverb2 Trigger_Rule
Coordinating_conjunction1 -> "ni"
Adverb2 -> "tout"
Trigger_Rule -> "|forward|trigger|negated|10|Group[831]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 472
#  French Term     : ni aucun
#  English Term(s) : ['nor any']
#  Index(es)       : [886]
#  Grouping(s)     : [833]


cfg_grammar= """
S ->  Coordinating_conjunction1 Determiner2 Trigger_Rule
Coordinating_conjunction1 -> "ni"
Determiner2 -> "aucun"
Trigger_Rule -> "|forward|trigger|negated|10|Group[833]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 473
#  French Term     : ni
#  English Term(s) : ['nor']
#  Index(es)       : [888]
#  Grouping(s)     : [835]


cfg_grammar= """
S ->  Coordinating_conjunction1 Trigger_Rule
Coordinating_conjunction1 -> "ni"
Trigger_Rule -> "|forward|trigger|negated|10|Group[835]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 474
#  French Term     : pas un courant
#  English Term(s) : ['not a current']
#  Index(es)       : [890]
#  Grouping(s)     : [837]


cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Trigger_Rule
Adverb1 -> "pas"
Determiner2 -> "un"
Noun3 -> "courant" | "cours" | "usuel" | "commun" | "fréquent" | "banal" | "habituel" | "usité" | "fil" | "flot"
Trigger_Rule -> "|forward|trigger|negated|10|Group[837]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 475
#  French Term     : ne pas apparaître
#  English Term(s) : ['not appear']
#  Index(es)       : [892]
#  Grouping(s)     : [839]


cfg_grammar= """
S ->  Adverb1 Adverb2 Verb3 Trigger_Rule
Adverb1 -> "ne"
Adverb2 -> "pas"
Verb3 -> "apparaître" | "paraître" | "poindre" | "ressortir" | "pointer" | "survenir" | "naître" | "sortir" | "transparaître" | "éclore"
Trigger_Rule -> "|forward|trigger|negated|10|Group[839]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 476
#  French Term     : pas apprécier
#  English Term(s) : ['not appreciate']
#  Index(es)       : [894]
#  Grouping(s)     : [841]


cfg_grammar= """
S ->  Adverb1 Adjective2 Trigger_Rule
Adverb1 -> "pas"
Adjective2 -> "apprécier"
Trigger_Rule -> "|forward|trigger|negated|10|Group[841]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 477
#  French Term     : non associé à
#  English Term(s) : ['not associated with']
#  Index(es)       : [896]
#  Grouping(s)     : [843]


cfg_grammar= """
S ->  Adverb1 Verb2 Adposition3 Trigger_Rule
Adverb1 -> "non"
Verb2 -> "associé" | "collègue" | "sociétaire" | "collaborateur" | "adhérent" | "partenaire" | "allié" | "actionnaire" | "compagnon" | "confrère"
Adposition3 -> "à"
Trigger_Rule -> "|forward|trigger|negated|10|Group[843]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 478
#  French Term     : pas tenté donné
#  English Term(s) : ['not attempted given']
#  Index(es)       : [898]
#  Grouping(s)     : [845]


cfg_grammar= """
S ->  Adverb1 Adjective2 Verb3 Trigger_Rule
Adverb1 -> "pas"
Adjective2 -> "tenté"
Verb3 -> "donné" | "déterminé" | "fixé" | "offert" | "foutre" | "fixer" | "porter" | "certain" | "attribué" | "dire"
Trigger_Rule -> "|forward|termination|negated|10|Group[845]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 479
#  French Term     : pas été exclu
#  English Term(s) : ['not been ruled out']
#  Index(es)       : [899]
#  Grouping(s)     : [846]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Verb3 Trigger_Rule
Adverb1 -> "pas"
Auxiliary2 -> "été"
Verb3 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[846]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 480
#  French Term     : pas causer
#  English Term(s) : ['not cause']
#  Index(es)       : [900]
#  Grouping(s)     : [847]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "pas"
Verb2 -> "causer" | "provoquer" | "apporter" | "parler" | "amener" | "produire" | "faire" | "susciter" | "déterminer" | "procurer"
Trigger_Rule -> "|both|pseudo|negated|10|Group[847]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 481
#  French Term     : pas certain si
#  English Term(s) : ['not certain if', 'not certain whether']
#  Index(es)       : [901, 902]
#  Grouping(s)     : [848]


cfg_grammar= """
S ->  Adverb1 Adjective2 Subordinating_conjunction3 Trigger_Rule
Adverb1 -> "pas"
Adjective2 -> "certain"
Subordinating_conjunction3 -> "si"
Trigger_Rule -> "|both|pseudo|negated|10|Group[848]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 482
#  French Term     : pas se plaindre de
#  English Term(s) : ['not complain of']
#  Index(es)       : [903]
#  Grouping(s)     : [850]


cfg_grammar= """
S ->  Adverb1 Pronoun2 Verb3 Adposition4 Trigger_Rule
Adverb1 -> "pas"
Pronoun2 -> "se"
Verb3 -> "plaindre" | "compatir" | "lésiner" | "regarder" | "marchander" | "craindre" | "économiser" | "pleurer" | "déplorer" | "attendrir"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[850]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 483
#  French Term     : Non courant
#  English Term(s) : ['not current']
#  Index(es)       : [905]
#  Grouping(s)     : [852]


cfg_grammar= """
S ->  Adverb1 Adjective2 Trigger_Rule
Adverb1 -> "Non"
Adjective2 -> "courant"
Trigger_Rule -> "|forward|trigger|negated|10|Group[852]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 484
#  French Term     : pas démontrer
#  English Term(s) : ['not demonstrate']
#  Index(es)       : [907]
#  Grouping(s)     : [854]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "pas"
Verb2 -> "démontrer" | "attester" | "témoigner" | "prouver" | "montrer" | "indiquer" | "convaincre" | "illustrer" | "révéler" | "justifier"
Trigger_Rule -> "|forward|trigger|negated|10|Group[854]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 485
#  French Term     : pas drainer
#  English Term(s) : ['not drain']
#  Index(es)       : [909]
#  Grouping(s)     : [856]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "pas"
Verb2 -> "drainer" | "assainir" | "attirer" | "égoutter" | "conduire" | "dessécher" | "sécher" | "épuiser" | "débiliter" | "imbiber"
Trigger_Rule -> "|both|pseudo|negated|10|Group[856]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 486
#  French Term     : ne pas exposer
#  English Term(s) : ['not exhibit']
#  Index(es)       : [910]
#  Grouping(s)     : [857]


cfg_grammar= """
S ->  Adverb1 Adverb2 Verb3 Trigger_Rule
Adverb1 -> "ne"
Adverb2 -> "pas"
Verb3 -> "exposer" | "montrer" | "raconter" | "donner" | "expliquer" | "risquer" | "représenter" | "afficher" | "compromettre" | "placer"
Trigger_Rule -> "|forward|trigger|negated|10|Group[857]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 487
#  French Term     : pas étendre
#  English Term(s) : ['not extend']
#  Index(es)       : [912]
#  Grouping(s)     : [859]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "pas"
Verb2 -> "étendre" | "étirer" | "augmenter" | "allonger" | "propager" | "appliquer" | "dérouler" | "délayer" | "accroître" | "élargir"
Trigger_Rule -> "|both|pseudo|negated|10|Group[859]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 488
#  French Term     : ne pas ressentir
#  English Term(s) : ['not feel']
#  Index(es)       : [913]
#  Grouping(s)     : [860]


cfg_grammar= """
S ->  Adverb1 Adverb2 Verb3 Trigger_Rule
Adverb1 -> "ne"
Adverb2 -> "pas"
Verb3 -> "ressentir" | "sentir" | "goûter" | "souffrir" | "endurer" | "subir" | "concevoir" | "discerner" | "connaître" | "pleurer"
Trigger_Rule -> "|forward|trigger|negated|10|Group[860]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 489
#  French Term     : Pas eu
#  English Term(s) : ['not had']
#  Index(es)       : [915]
#  Grouping(s)     : [862]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "Pas"
Verb2 -> "eu"
Trigger_Rule -> "|forward|trigger|negated|10|Group[862]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 490
#  French Term     : ne pas avoir la preuve de
#  English Term(s) : ['not have evidence of']
#  Index(es)       : [917]
#  Grouping(s)     : [864]


cfg_grammar= """
S ->  Adverb1 Adverb2 Verb3 Determiner4 Noun5 Adposition6 Trigger_Rule
Adverb1 -> "ne"
Adverb2 -> "pas"
Verb3 -> "avoir"
Determiner4 -> "la"
Noun5 -> "preuve" | "indice" | "confirmation" | "conviction" | "constatation" | "document" | "gage" | "critère" | "argument" | "signe"
Adposition6 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[864]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 491
#  French Term     : ne pas avoir
#  English Term(s) : ['not have']
#  Index(es)       : [919]
#  Grouping(s)     : [866]


cfg_grammar= """
S ->  Adverb1 Adverb2 Verb3 Trigger_Rule
Adverb1 -> "ne"
Adverb2 -> "pas"
Verb3 -> "avoir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[866]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 492
#  French Term     : pas en aigu
#  English Term(s) : ['not in acute']
#  Index(es)       : [921]
#  Grouping(s)     : [868]


cfg_grammar= """
S ->  Adverb1 Adposition2 Noun3 Trigger_Rule
Adverb1 -> "pas"
Adposition2 -> "en"
Noun3 -> "aigu" | "vif" | "pénétrant" | "cuisant" | "incisif" | "piquant" | "tranchant" | "perçant" | "aigre" | "strident"
Trigger_Rule -> "|forward|trigger|negated|10|Group[868]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 493
#  French Term     : pas intéressé
#  English Term(s) : ['not interested']
#  Index(es)       : [923]
#  Grouping(s)     : [870]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "pas"
Verb2 -> "intéressé" | "captivé" | "avare" | "séduit" | "avide" | "cupide" | "concerné" | "insatiable" | "mercenaire" | "intrigué"
Trigger_Rule -> "|both|pseudo|negated|10|Group[870]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 494
#  French Term     : pas dedans
#  English Term(s) : ['not in']
#  Index(es)       : [924]
#  Grouping(s)     : [871]


cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "pas"
Verb2 -> "dedans" | "dans" | "intérieurement" | "âme" | "coeur" | "intime" | "céans" | "intrinsèque" | "à" | "dedans"
Trigger_Rule -> "|forward|trigger|negated|10|Group[871]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 495
#  French Term     : pas au courant de
#  English Term(s) : ['not know of']
#  Index(es)       : [926]
#  Grouping(s)     : [873]


cfg_grammar= """
S ->  Adverb1 Noun2 Verb3 Adposition4 Trigger_Rule
Adverb1 -> "pas"
Noun2 -> "au"
Verb3 -> "courant" | "cours" | "usuel" | "commun" | "fréquent" | "banal" | "habituel" | "usité" | "fil" | "flot"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[873]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 496
#  French Term     : pas connu pour avoir
#  English Term(s) : ['not known to have']
#  Index(es)       : [928]
#  Grouping(s)     : [875]


cfg_grammar= """
S ->  Adverb1 Verb2 Adposition3 Verb4 Trigger_Rule
Adverb1 -> "pas"
Verb2 -> "connu" | "commun" | "notoire" | "familier" | "public" | "réputé" | "courant" | "répandu" | "historique" | "révélé"
Adposition3 -> "pour"
Verb4 -> "avoir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[875]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 497
#  French Term     : pas nécessairement
#  English Term(s) : ['not necessarily']
#  Index(es)       : [930]
#  Grouping(s)     : [877]


cfg_grammar= """
S ->  Adverb1 Adverb2 Trigger_Rule
Adverb1 -> "pas"
Adverb2 -> "nécessairement"
Trigger_Rule -> "|both|pseudo|negated|10|Group[877]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 498
#  French Term     : pas seulement
#  English Term(s) : ['not only']
#  Index(es)       : [931]
#  Grouping(s)     : [877]


cfg_grammar= """
S ->  Adverb1 Adverb2 Trigger_Rule
Adverb1 -> "pas"
Adverb2 -> "seulement"
Trigger_Rule -> "|both|pseudo|negated|10|Group[877]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 499
#  French Term     : pas sur
#  English Term(s) : ['not on']
#  Index(es)       : [932]
#  Grouping(s)     : [877]


cfg_grammar= """
S ->  Adverb1 Adposition2 Trigger_Rule
Adverb1 -> "pas"
Adposition2 -> "sur"
Trigger_Rule -> "|both|pseudo|negated|10|Group[877]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 500
#  French Term     : ne pas révéler
#  English Term(s) : ['not reveal']
#  Index(es)       : [933]
#  Grouping(s)     : [880]


cfg_grammar= """
S ->  Adverb1 Adverb2 Verb3 Trigger_Rule
Adverb1 -> "ne"
Adverb2 -> "pas"
Verb3 -> "révéler" | "dévoiler" | "indiquer" | "déceler" | "dénoncer" | "trahir" | "divulguer" | "exposer" | "manifester" | "dire"
Trigger_Rule -> "|forward|trigger|negated|10|Group[880]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
