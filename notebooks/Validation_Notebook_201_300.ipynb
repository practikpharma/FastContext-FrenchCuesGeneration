# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 201
#  French Term     : nie significatif
#  English Term(s) : ['denies significant']
#  Index(es)       : [416]
#  Grouping(s)     : [377]


cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Adjective2 -> "significatif"
Trigger_Rule -> "|forward|trigger|negated|10|Group[377]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 202
#  French Term     : nie les symptômes de
#  English Term(s) : ['denies symptoms of']
#  Index(es)       : [418]
#  Grouping(s)     : [379]


cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Adposition4 Trigger_Rule
Adverb1 -> "nie"
Determiner2 -> "les"
Noun3 -> "symptômes" | "présage" | "indice" | "marque" | "manifestation" | "syndrome" | "stigmate" | "diagnostique" | "prodrome" | "signal"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[379]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 203
#  French Term     : nie qu'il y avait du courant
#  English Term(s) : ['denies there was any current']
#  Index(es)       : [420]
#  Grouping(s)     : [381]


cfg_grammar= """
S ->  Noun1 Subordinating_conjunction2 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Verb5 -> "avait"
Determiner6 -> "du"
Noun7 -> "courant" | "cours" | "usuel" | "commun" | "fréquent" | "banal" | "habituel" | "usité" | "fil" | "flot"
Trigger_Rule -> "|forward|trigger|negated|10|Group[381]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 204
#  French Term     : nie qu'il y ait des antécédents de
#  English Term(s) : ['denies there was any history of']
#  Index(es)       : [422]
#  Grouping(s)     : [383]


cfg_grammar= """
S ->  Noun1 Subordinating_conjunction2 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Adposition8 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Verb5 -> "ait"
Determiner6 -> "des"
Noun7 -> "antécédents" | "antérieur" | "préalable" | "préexistant" | "implication" | "enthymème" | "application" | "hérédité" | "passé" | "exemple"
Adposition8 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[383]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 205
#  French Term     : nie il y avait aucune récente
#  English Term(s) : ['denies there was any recent']
#  Index(es)       : [424]
#  Grouping(s)     : [385]


cfg_grammar= """
S ->  Noun1 Pronoun2 Pronoun3 Verb4 Determiner5 Adjective6 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Pronoun2 -> "il"
Pronoun3 -> "y"
Verb4 -> "avait"
Determiner5 -> "aucune"
Adjective6 -> "récente"
Trigger_Rule -> "|forward|trigger|negated|10|Group[385]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 206
#  French Term     : nie qu'il y en ait
#  English Term(s) : ['denies there was any', 'denies there were any']
#  Index(es)       : [426, 427]
#  Grouping(s)     : [387]


cfg_grammar= """
S ->  Noun1 Subordinating_conjunction2 Pronoun3 Pronoun4 Pronoun5 Verb6 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Pronoun5 -> "en"
Verb6 -> "ait"
Trigger_Rule -> "|forward|trigger|negated|10|Group[387]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 207
#  French Term     : nie qu'il y ait jamais eu l'histoire de
#  English Term(s) : ['denies there was ever history of', 'denies there were ever history of']
#  Index(es)       : [430, 431]
#  Grouping(s)     : [389]


cfg_grammar= """
S ->  Noun1 Subordinating_conjunction2 Pronoun3 Pronoun4 Auxiliary5 Adverb6 Verb7 Determiner8 Noun9 Adposition10 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Auxiliary5 -> "ait"
Adverb6 -> "jamais"
Verb7 -> "eu"
Determiner8 -> "l'"
Noun9 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Adposition10 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[389]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 208
#  French Term     : nie il y avait jamais
#  English Term(s) : ['denies there was ever', 'denies there were ever']
#  Index(es)       : [434, 435]
#  Grouping(s)     : [391]


cfg_grammar= """
S ->  Noun1 Pronoun2 Pronoun3 Verb4 Adverb5 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Pronoun2 -> "il"
Pronoun3 -> "y"
Verb4 -> "avait"
Adverb5 -> "jamais"
Trigger_Rule -> "|forward|trigger|negated|10|Group[391]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 209
#  French Term     : nie qu'il y avait une histoire de
#  English Term(s) : ['denies there was history of', 'denies there were history of']
#  Index(es)       : [438, 439]
#  Grouping(s)     : [393]


cfg_grammar= """
S ->  Noun1 Subordinating_conjunction2 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Adposition8 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Verb5 -> "avait"
Determiner6 -> "une"
Noun7 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Adposition8 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[393]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 210
#  French Term     : nie qu'il y avait des problèmes de
#  English Term(s) : ['denies there was problems of', 'denies there were problems of']
#  Index(es)       : [442, 443]
#  Grouping(s)     : [395]


cfg_grammar= """
S ->  Noun1 Subordinating_conjunction2 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Adposition8 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Verb5 -> "avait"
Determiner6 -> "des"
Noun7 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition8 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[395]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 211
#  French Term     : nie qu'il y avait des problèmes
#  English Term(s) : ['denies there was problems', 'denies there were problems']
#  Index(es)       : [446, 447]
#  Grouping(s)     : [397]


cfg_grammar= """
S ->  Noun1 Subordinating_conjunction2 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Verb5 -> "avait"
Determiner6 -> "des"
Noun7 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Trigger_Rule -> "|forward|trigger|negated|10|Group[397]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 212
#  French Term     : nie qu'il y ait eu des antécédents de
#  English Term(s) : ['denies there were any history of']
#  Index(es)       : [450]
#  Grouping(s)     : [399]


cfg_grammar= """
S ->  Noun1 Subordinating_conjunction2 Pronoun3 Pronoun4 Auxiliary5 Verb6 Determiner7 Noun8 Adposition9 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Auxiliary5 -> "ait"
Verb6 -> "eu"
Determiner7 -> "des"
Noun8 -> "antécédents" | "antérieur" | "préalable" | "préexistant" | "implication" | "enthymème" | "application" | "hérédité" | "passé" | "exemple"
Adposition9 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[399]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 213
#  French Term     : nie cela
#  English Term(s) : ['denies this']
#  Index(es)       : [452]
#  Grouping(s)     : [413]


cfg_grammar= """
S ->  Noun1 Pronoun2 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Pronoun2 -> "cela"
Trigger_Rule -> "|forward|trigger|negated|10|Group[413]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 214
#  French Term     : nie vrai
#  English Term(s) : ['denies true']
#  Index(es)       : [454]
#  Grouping(s)     : [415]


cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Adjective2 -> "vrai"
Trigger_Rule -> "|forward|trigger|negated|10|Group[415]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 215
#  French Term     : refuse l'utilisation d'autres
#  English Term(s) : ['denies use of other']
#  Index(es)       : [456]
#  Grouping(s)     : [417]


cfg_grammar= """
S ->  Verb1 Determiner2 Noun3 Adposition4 Adjective5 Trigger_Rule
Verb1 -> "refuse" | "ajourner" | "compte" | "non" | "ajourné" | "blackbouler" | "décliner" | "nier" | "battu" | "renvoyer"
Determiner2 -> "l'"
Noun3 -> "utilisation" | "emploi" | "maniement" | "destination" | "exploitation" | "consommation" | "exercice" | "usage" | "amortissement" | "adoption"
Adposition4 -> "d'"
Adjective5 -> "autres"
Trigger_Rule -> "|forward|trigger|negated|10|Group[417]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 216
#  French Term     : nie l'utilisation de
#  English Term(s) : ['denies use of']
#  Index(es)       : [458]
#  Grouping(s)     : [419]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adposition4 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Determiner2 -> "l'"
Noun3 -> "utilisation" | "emploi" | "maniement" | "destination" | "exploitation" | "consommation" | "exercice" | "usage" | "amortissement" | "adoption"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[419]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 217
#  French Term     : nie
#  English Term(s) : ['denies']
#  Index(es)       : [460]
#  Grouping(s)     : [421]


cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "nie" | "désavouer" | "réfuter" | "contredire" | "renier" | "disconvenir" | "refuser" | "démentir" | "démonter" | "discuter"
Trigger_Rule -> "|forward|trigger|negated|10|Group[421]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 218
#  French Term     : nier
#  English Term(s) : ['denying']
#  Index(es)       : [462]
#  Grouping(s)     : [421]


cfg_grammar= """
S ->  Adverb1 Trigger_Rule
Adverb1 -> "nier"
Trigger_Rule -> "|forward|trigger|negated|10|Group[421]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 219
#  French Term     : Denise
#  English Term(s) : ['denise']
#  Index(es)       : [461]
#  Grouping(s)     : [421]


cfg_grammar= """
S ->  Proper_noun1 Trigger_Rule
Proper_noun1 -> "Denise"
Trigger_Rule -> "|forward|trigger|negated|10|Group[421]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 220
#  French Term     : Nier
#  English Term(s) : ['deny']
#  Index(es)       : [463]
#  Grouping(s)     : [421]


cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "Nier"
Trigger_Rule -> "|forward|trigger|negated|10|Group[421]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 221
#  French Term     : a eu
#  English Term(s) : ['did have']
#  Index(es)       : [468]
#  Grouping(s)     : [429]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "eu"
Trigger_Rule -> "|forward|termination|negated|10|Group[429]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 222
#  French Term     : n'a eu aucun épisode de
#  English Term(s) : ['did not have any episodes of']
#  Index(es)       : [469]
#  Grouping(s)     : [430]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Verb3 Determiner4 Noun5 Adposition6 Trigger_Rule
Adverb1 -> "n'"
Auxiliary2 -> "a"
Verb3 -> "eu"
Determiner4 -> "aucun"
Noun5 -> "épisode" | "péripétie" | "incident" | "aventure" | "digression" | "affaire" | "histoire" | "fait" | "circonstance" | "moment"
Adposition6 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[430]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 223
#  French Term     : n'a plus d'épisodes de
#  English Term(s) : ['did not have any more episodes of']
#  Index(es)       : [471]
#  Grouping(s)     : [432]


cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Determiner4 Noun5 Adposition6 Trigger_Rule
Adverb1 -> "n'"
Verb2 -> "a"
Adverb3 -> "plus"
Determiner4 -> "d'"
Noun5 -> "épisodes" | "péripétie" | "incident" | "aventure" | "digression" | "affaire" | "histoire" | "fait" | "circonstance" | "moment"
Adposition6 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[432]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 224
#  French Term     : n'a pas eu de problèmes
#  English Term(s) : ['has not had any problems']
#  Index(es)       : [477]
#  Grouping(s)     : [434]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Verb4 Adposition5 Noun6 Trigger_Rule
Adverb1 -> "n'"
Auxiliary2 -> "a"
Adverb3 -> "pas"
Verb4 -> "eu"
Adposition5 -> "de"
Noun6 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Trigger_Rule -> "|forward|trigger|negated|10|Group[434]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 225
#  French Term     : n'a pas eu de problèmes avec
#  English Term(s) : ['did not have any problems with', "didn't have any problems with", 'has not had any problems with']
#  Index(es)       : [473, 474, 476]
#  Grouping(s)     : [434]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Verb4 Adposition5 Noun6 Adposition7 Trigger_Rule
Adverb1 -> "n'"
Auxiliary2 -> "a"
Adverb3 -> "pas"
Verb4 -> "eu"
Adposition5 -> "de"
Noun6 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition7 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[434]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 226
#  French Term     : n'a signalé aucun problème avec
#  English Term(s) : ["didn't report any problems with"]
#  Index(es)       : [475]
#  Grouping(s)     : [434]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Verb3 Determiner4 Noun5 Adposition6 Trigger_Rule
Adverb1 -> "n'"
Auxiliary2 -> "a"
Verb3 -> "signalé" | "insigne" | "distingué" | "important" | "glorieux" | "marquant" | "émérite" | "mémorable" | "notable" | "saillant"
Determiner4 -> "aucun"
Noun5 -> "problème" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition6 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[434]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 227
#  French Term     : n'a pas observé un
#  English Term(s) : ['did not observe a']
#  Index(es)       : [483]
#  Grouping(s)     : [436]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Verb4 Determiner5 Trigger_Rule
Adverb1 -> "n'"
Auxiliary2 -> "a"
Adverb3 -> "pas"
Verb4 -> "observé" | "constater" | "regarder" | "accomplir" | "obéir" | "remarquer" | "examiner" | "étudier" | "considérer" | "épier"
Determiner5 -> "un"
Trigger_Rule -> "|forward|trigger|negated|10|Group[436]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 228
#  French Term     : n'a pas exclu
#  English Term(s) : ['did not rule out']
#  Index(es)       : [485]
#  Grouping(s)     : [438]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Verb4 Trigger_Rule
Adverb1 -> "n'"
Auxiliary2 -> "a"
Adverb3 -> "pas"
Verb4 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[438]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 229
#  French Term     : l'a exclue contre
#  English Term(s) : ['did rule her out against', 'ruled her out against']
#  Index(es)       : [486, 495]
#  Grouping(s)     : [439]


cfg_grammar= """
S ->  Pronoun1 Auxiliary2 Verb3 Adposition4 Trigger_Rule
Pronoun1 -> "l'"
Auxiliary2 -> "a"
Verb3 -> "exclue" | "paria" | "forclos" | "exclusivement" | "renvoyé" | "prohibé" | "inenvisageable" | "irréalisable" | "mise à l'écart" | "marginal"
Adposition4 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 230
#  French Term     : a exclu pour
#  English Term(s) : ['did rule out for']
#  Index(es)       : [493]
#  Grouping(s)     : [439]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Adposition3 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Adposition3 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 231
#  French Term     : a exclu contre
#  English Term(s) : ['did rule out against']
#  Index(es)       : [492]
#  Grouping(s)     : [439]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Adposition3 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Adposition3 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 232
#  French Term     : a exclu
#  English Term(s) : ['did rule out']
#  Index(es)       : [494]
#  Grouping(s)     : [439]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 233
#  French Term     : l'a exclue pour
#  English Term(s) : ['did rule her out for', 'ruled her out for']
#  Index(es)       : [487, 506]
#  Grouping(s)     : [439, 441]


cfg_grammar= """
S ->  Pronoun1 Auxiliary2 Verb3 Adposition4 Trigger_Rule
Pronoun1 -> "l'"
Auxiliary2 -> "a"
Verb3 -> "exclue" | "paria" | "forclos" | "exclusivement" | "renvoyé" | "prohibé" | "inenvisageable" | "irréalisable" | "mise à l'écart" | "marginal"
Adposition4 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439, 441]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 234
#  French Term     : l'a exclue
#  English Term(s) : ['did rule her out', 'ruled her out']
#  Index(es)       : [488, 508]
#  Grouping(s)     : [439, 443]


cfg_grammar= """
S ->  Pronoun1 Auxiliary2 Verb3 Trigger_Rule
Pronoun1 -> "l'"
Auxiliary2 -> "a"
Verb3 -> "exclue" | "paria" | "forclos" | "exclusivement" | "renvoyé" | "prohibé" | "inenvisageable" | "irréalisable" | "mise à l'écart" | "marginal"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439, 443]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 235
#  French Term     : l'a exclu contre
#  English Term(s) : ['did rule him out against', 'ruled him out against']
#  Index(es)       : [489, 510]
#  Grouping(s)     : [439, 445]


cfg_grammar= """
S ->  Pronoun1 Auxiliary2 Verb3 Adposition4 Trigger_Rule
Pronoun1 -> "l'"
Auxiliary2 -> "a"
Verb3 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Adposition4 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439, 445]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 236
#  French Term     : l'a exclu pour
#  English Term(s) : ['did rule him out for', 'ruled him out for']
#  Index(es)       : [490, 512]
#  Grouping(s)     : [439, 447]


cfg_grammar= """
S ->  Pronoun1 Auxiliary2 Verb3 Adposition4 Trigger_Rule
Pronoun1 -> "l'"
Auxiliary2 -> "a"
Verb3 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Adposition4 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439, 447]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 237
#  French Term     : l'a exclu
#  English Term(s) : ['did rule him out', 'ruled him out']
#  Index(es)       : [491, 514]
#  Grouping(s)     : [439, 449]


cfg_grammar= """
S ->  Pronoun1 Auxiliary2 Verb3 Trigger_Rule
Pronoun1 -> "l'"
Auxiliary2 -> "a"
Verb3 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439, 449]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 238
#  French Term     : a exclu le patient
#  English Term(s) : ['did rule the patient out']
#  Index(es)       : [518]
#  Grouping(s)     : [457]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Noun4 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Determiner3 -> "le"
Noun4 -> "patient" | "persévérant" | "client" | "infatigable" | "constant" | "calme" | "imperturbable" | "impassible" | "résigné" | "courageux"
Trigger_Rule -> "|forward|trigger|negated|10|Group[457]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 239
#  French Term     : a exclu le patient pour
#  English Term(s) : ['did rule the patient out for']
#  Index(es)       : [517]
#  Grouping(s)     : [457]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Noun4 Adposition5 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Determiner3 -> "le"
Noun4 -> "patient" | "persévérant" | "client" | "infatigable" | "constant" | "calme" | "imperturbable" | "impassible" | "résigné" | "courageux"
Adposition5 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[457]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 240
#  French Term     : a exclu le patient contre
#  English Term(s) : ['did rule the patient out against']
#  Index(es)       : [516]
#  Grouping(s)     : [457]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Noun4 Adposition5 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "exclusivement" | "expulsé" | "paria" | "renvoyé" | "prohibé" | "refusé" | "chassé" | "éconduit" | "inenvisageable"
Determiner3 -> "le"
Noun4 -> "patient" | "persévérant" | "client" | "infatigable" | "constant" | "calme" | "imperturbable" | "impassible" | "résigné" | "courageux"
Adposition5 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[457]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 241
#  French Term     : a montré
#  English Term(s) : ['did show']
#  Index(es)       : [522]
#  Grouping(s)     : [463]


cfg_grammar= """
S ->  Auxiliary1 Verb2 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "montré" | "chronomètre" | "affiché" | "éventaire" | "désigné" | "averti" | "indiquer" | "affecter" | "révélé" | "donné"
Trigger_Rule -> "|forward|termination|negated|10|Group[463]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 242
#  French Term     : n'a pas exprimer
#  English Term(s) : ["didn't express any"]
#  Index(es)       : [523]
#  Grouping(s)     : [464]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Verb4 Trigger_Rule
Adverb1 -> "n'"
Auxiliary2 -> "a"
Adverb3 -> "pas"
Verb4 -> "exprimer" | "manifester" | "représenter" | "signifier" | "témoigner" | "articuler" | "rendre" | "dire" | "extraire" | "montrer"
Trigger_Rule -> "|forward|trigger|negated|10|Group[464]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 243
#  French Term     : n'a exprimé aucune
#  English Term(s) : ["didn't expressed any"]
#  Index(es)       : [525]
#  Grouping(s)     : [466]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Verb3 Determiner4 Trigger_Rule
Adverb1 -> "n'"
Auxiliary2 -> "a"
Verb3 -> "exprimé" | "manifester" | "représenter" | "signifier" | "témoigner" | "articuler" | "rendre" | "dire" | "extraire" | "montrer"
Determiner4 -> "aucune"
Trigger_Rule -> "|forward|trigger|negated|10|Group[466]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 244
#  French Term     : n'a signalé aucun
#  English Term(s) : ["didn't report any"]
#  Index(es)       : [527]
#  Grouping(s)     : [472]


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Verb3 Determiner4 Trigger_Rule
Adverb1 -> "n'"
Auxiliary2 -> "a"
Verb3 -> "signalé" | "insigne" | "distingué" | "important" | "glorieux" | "marquant" | "émérite" | "mémorable" | "notable" | "saillant"
Determiner4 -> "aucun"
Trigger_Rule -> "|forward|trigger|negated|10|Group[472]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 246
#  French Term     : différentiel comprend également
#  English Term(s) : ['differential also includes']
#  Index(es)       : [530]
#  Grouping(s)     : [475]


cfg_grammar= """
S ->  Adjective1 Verb2 Adverb3 Trigger_Rule
Adjective1 -> "différentiel"
Verb2 -> "comprend" | "saisir" | "inclure" | "contenir" | "pénétrer" | "connaître" | "voir" | "interpréter" | "englober" | "comporter"
Adverb3 -> "également"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[475]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 247
#  French Term     : diagnostics différentiels comprend également
#  English Term(s) : ['differential diagnoses also includes']
#  Index(es)       : [531]
#  Grouping(s)     : [476]


cfg_grammar= """
S ->  Pronoun1 Adjective2 Verb3 Adverb4 Trigger_Rule
Pronoun1 -> "diagnostics"
Adjective2 -> "différentiels"
Verb3 -> "comprend" | "saisir" | "inclure" | "contenir" | "pénétrer" | "connaître" | "voir" | "interpréter" | "englober" | "comporter"
Adverb4 -> "également"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[476]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 248
#  French Term     : les diagnostics différentiels comprennent
#  English Term(s) : ['differential diagnoses includes']
#  Index(es)       : [532]
#  Grouping(s)     : [477]


cfg_grammar= """
S ->  Determiner1 Noun2 Adjective3 Verb4 Trigger_Rule
Determiner1 -> "les"
Noun2 -> "diagnostics" | "évaluation" | "symptomatique" | "symptôme" | "clinique" | "nosologie" | "diagnose" | "constat" | "diagnostic" | "les critères de classification des maladies"
Adjective3 -> "différentiels"
Verb4 -> "comprennent" | "décoder" | "entendre" | "interpréter" | "approuver" | "englober" | "imaginer" | "comporter" | "découvrir" | "déchiffrer"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[477]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 249
#  French Term     : différentiel comprend
#  English Term(s) : ['differential includes']
#  Index(es)       : [533]
#  Grouping(s)     : [478]


cfg_grammar= """
S ->  Adjective1 Verb2 Trigger_Rule
Adjective1 -> "différentiel"
Verb2 -> "comprend" | "saisir" | "inclure" | "contenir" | "pénétrer" | "connaître" | "voir" | "interpréter" | "englober" | "comporter"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[478]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 250
#  French Term     : ne semble pas avoir de problèmes de
#  English Term(s) : ['does not appear to have any issues of']
#  Index(es)       : [535]
#  Grouping(s)     : [479]


cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Verb4 Adposition5 Noun6 Adposition7 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "semble"
Adverb3 -> "pas"
Verb4 -> "avoir"
Adposition5 -> "de"
Noun6 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition7 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[479]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 251
#  French Term     : ne semble pas avoir d'étrange
#  English Term(s) : ['does not appear to have any bizarre']
#  Index(es)       : [534]
#  Grouping(s)     : [479]


cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Verb4 Adposition5 Noun6 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "semble"
Adverb3 -> "pas"
Verb4 -> "avoir"
Adposition5 -> "d'"
Noun6 -> "étrange" | "extraordinaire" | "abracadabrant" | "exceptionnel" | "louche" | "curieux" | "drôle" | "incroyable" | "bizarre" | "étonnant"
Trigger_Rule -> "|forward|trigger|negated|10|Group[479]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 252
#  French Term     : ne semble pas avoir de
#  English Term(s) : ['does not appear to have any']
#  Index(es)       : [537]
#  Grouping(s)     : [479]


cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Verb4 Adposition5 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "semble"
Adverb3 -> "pas"
Verb4 -> "avoir"
Adposition5 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[479]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 253
#  French Term     : ne semble pas avoir de problèmes avec
#  English Term(s) : ['does not appear to have any issues with']
#  Index(es)       : [536]
#  Grouping(s)     : [479]


cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Verb4 Adposition5 Noun6 Adposition7 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "semble"
Adverb3 -> "pas"
Verb4 -> "avoir"
Adposition5 -> "de"
Noun6 -> "problèmes" | "difficulté" | "affaire" | "ennui" | "sujet" | "énigme" | "souci" | "colle" | "complication" | "histoire"
Adposition7 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[479]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 254
#  French Term     : n'exprime pas
#  English Term(s) : ['does not express']
#  Index(es)       : [542]
#  Grouping(s)     : [487]


cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Trigger_Rule
Adverb1 -> "n'"
Verb2 -> "exprime" | "énoncer" | "prononcer" | "révéler" | "émettre" | "signifier" | "manifester" | "témoigner" | "dire" | "afficher"
Adverb3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[487]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 255
#  French Term     : n'utilise pas
#  English Term(s) : ['does not use']
#  Index(es)       : [544]
#  Grouping(s)     : [489]


cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Trigger_Rule
Adverb1 -> "n'"
Verb2 -> "utilise" | "employé" | "disposer" | "recourir" | "parti" | "employer" | "assimiler" | "profit" | "manipuler" | "pratiquer"
Adverb3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[489]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 256
#  French Term     : généralement pas
#  English Term(s) : ['does not usually']
#  Index(es)       : [546]
#  Grouping(s)     : [491]


cfg_grammar= """
S ->  Adverb1 Adverb2 Trigger_Rule
Adverb1 -> "généralement"
Adverb2 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[491]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 257
#  French Term     : ne fait pas
#  English Term(s) : ['does not']
#  Index(es)       : [548]
#  Grouping(s)     : [493]


cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "fait"
Adverb3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[493]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 258
#  French Term     : ne ressemble pas
#  English Term(s) : ["doesn't look like"]
#  Index(es)       : [550]
#  Grouping(s)     : [495]


cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "ressemble" | "approximer" | "correspondre" | "sembler" | "rappeler" | "représenter" | "procéder" | "retirer" | "participer" | "imiter"
Adverb3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[495]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 259
#  French Term     : doute
#  English Term(s) : ['doubt']
#  Index(es)       : [552]
#  Grouping(s)     : [497]


cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "doute" | "indétermination" | "incrédulité" | "perplexité" | "indécision" | "méfiance" | "défiance" | "hésitation" | "soupçon" | "pyrrhonisme"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[497]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 260
#  French Term     : en raison de
#  English Term(s) : ['due to']
#  Index(es)       : [553]
#  Grouping(s)     : [498]


cfg_grammar= """
S ->  Adposition1 Noun2 Adposition3 Trigger_Rule
Adposition1 -> "en"
Noun2 -> "raison" | "cause" | "modération" | "intelligence" | "entendement" | "discernement" | "compréhension" | "prétexte" | "sagesse" | "lucidité"
Adposition3 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[498]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 261
#  French Term     : ecchymoses à
#  English Term(s) : ['ecchymoses to']
#  Index(es)       : [554]
#  Grouping(s)     : [499]


cfg_grammar= """
S ->  Noun1 Adposition2 Trigger_Rule
Noun1 -> "ecchymoses" | "bleu" | "beigne" | "hématome" | "meurtrissure" | "hémorragie" | "coup" | "extravasation" | "pinçon" | "blessure"
Adposition2 -> "à"
Trigger_Rule -> "|forward|termination|negated|10|Group[499]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 262
#  French Term     : ed
#  English Term(s) : ['ed']
#  Index(es)       : [555]
#  Grouping(s)     : [500]


cfg_grammar= """
S ->  Verb1 Trigger_Rule
Verb1 -> "ed"
Trigger_Rule -> "|both|termination|historical|30|Group[500]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 263
#  French Term     : département d'urgence
#  English Term(s) : ['emergency department']
#  Index(es)       : [556]
#  Grouping(s)     : [501]


cfg_grammar= """
S ->  Verb1 Adposition2 Noun3 Trigger_Rule
Verb1 -> "département" | "domaine" | "secteur" | "partie" | "charge" | "sphère" | "préfecture" | "institut" | "service" | "division"
Adposition2 -> "d'"
Noun3 -> "urgence" | "nécessité" | "acuité" | "engagement" | "tâche" | "crise" | "exigence" | "priorité" | "obligation" | "importance"
Trigger_Rule -> "|both|termination|historical|30|Group[501]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 264
#  French Term     : étiologie de
#  English Term(s) : ['etiology of']
#  Index(es)       : [558]
#  Grouping(s)     : [502]


cfg_grammar= """
S ->  Noun1 Adposition2 Trigger_Rule
Noun1 -> "étiologie" | "étiopathie" | "causalité" | "étiologie"
Adposition2 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[502]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 265
#  French Term     : étiologie pour
#  English Term(s) : ['etiology for']
#  Index(es)       : [557]
#  Grouping(s)     : [502]


cfg_grammar= """
S ->  Noun1 Adposition2 Trigger_Rule
Noun1 -> "étiologie" | "étiopathie" | "causalité" | "étiologie"
Adposition2 -> "pour"
Trigger_Rule -> "|forward|termination|negated|10|Group[502]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 266
#  French Term     : exacerbation de
#  English Term(s) : ['exacerbation from']
#  Index(es)       : [559]
#  Grouping(s)     : [504]


cfg_grammar= """
S ->  Noun1 Adposition2 Trigger_Rule
Noun1 -> "exacerbation" | "exaspération" | "paroxysme" | "recrudescence" | "excitation" | "irritation" | "intensification" | "augmentation" | "agacement" | "accès"
Adposition2 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[504]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 267
#  French Term     : examens à évaluer
#  English Term(s) : ['examinations to assess', 'exams to assess']
#  Index(es)       : [562, 563]
#  Grouping(s)     : [505]


cfg_grammar= """
S ->  Noun1 Adposition2 Verb3 Trigger_Rule
Noun1 -> "examens" | "analyse" | "essai" | "étude" | "vérification" | "exploration" | "enquête" | "inspection" | "observation" | "investigation"
Adposition2 -> "à"
Verb3 -> "évaluer" | "quantifier" | "calculer" | "mesurer" | "apprécier" | "chiffrer" | "juger" | "surestimer" | "nombrer" | "jauger"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[505]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 268
#  French Term     : examen évaluer
#  English Term(s) : ['examination assess']
#  Index(es)       : [564]
#  Grouping(s)     : [505]


cfg_grammar= """
S ->  Noun1 Verb2 Trigger_Rule
Noun1 -> "examen" | "analyse" | "essai" | "étude" | "vérification" | "exploration" | "enquête" | "inspection" | "observation" | "investigation"
Verb2 -> "évaluer" | "quantifier" | "calculer" | "mesurer" | "apprécier" | "chiffrer" | "juger" | "surestimer" | "nombrer" | "jauger"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[505]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 269
#  French Term     : examen pour évaluer
#  English Term(s) : ['exam to assess', 'examination to assess']
#  Index(es)       : [560, 561]
#  Grouping(s)     : [505]


cfg_grammar= """
S ->  Noun1 Adposition2 Verb3 Trigger_Rule
Noun1 -> "examen" | "analyse" | "essai" | "étude" | "vérification" | "exploration" | "enquête" | "inspection" | "observation" | "investigation"
Adposition2 -> "pour"
Verb3 -> "évaluer" | "quantifier" | "calculer" | "mesurer" | "apprécier" | "chiffrer" | "juger" | "surestimer" | "nombrer" | "jauger"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[505]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 270
#  French Term     : sauf
#  English Term(s) : ['except']
#  Index(es)       : [565]
#  Grouping(s)     : [510]


cfg_grammar= """
S ->  Adposition1 Trigger_Rule
Adposition1 -> "sauf"
Trigger_Rule -> "|forward|termination|negated|10|Group[510]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 271
#  French Term     : f / h
#  English Term(s) : ['f/h', 'f / h']
#  Index(es)       : [566, 567]
#  Grouping(s)     : [511]


cfg_grammar= """
S ->  Noun1 Adposition2 Noun3 Trigger_Rule
Noun1 -> "f"
Adposition2 -> "/"
Noun3 -> "h" | "âge" | "période" | "tantôt" | "constante de Planck" | "h" | "moment" | "jours" | "liturgie" | "instant"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[511]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 272
#  French Term     : ne parvient pas à révéler
#  English Term(s) : ['fails to reveal']
#  Index(es)       : [568]
#  Grouping(s)     : [512]


cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Adposition4 Verb5 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "parvient" | "atteindre" | "arriver" | "accéder" | "venir" | "entrer" | "aborder" | "accoster" | "égaler" | "rencontrer"
Adverb3 -> "pas"
Adposition4 -> "à"
Verb5 -> "révéler" | "dévoiler" | "indiquer" | "déceler" | "dénoncer" | "trahir" | "divulguer" | "exposer" | "manifester" | "dire"
Trigger_Rule -> "|forward|trigger|negated|10|Group[512]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 273
#  French Term     : faux négatif
#  English Term(s) : ['false negative']
#  Index(es)       : [570]
#  Grouping(s)     : [514]


cfg_grammar= """
S ->  Adjective1 Adjective2 Trigger_Rule
Adjective1 -> "faux"
Adjective2 -> "négatif"
Trigger_Rule -> "|both|pseudo|negated|10|Group[514]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 274
#  French Term     : fam hx
#  English Term(s) : ['fam hx']
#  Index(es)       : [571]
#  Grouping(s)     : [515]


cfg_grammar= """
S ->  Noun1 Noun2 Trigger_Rule
Noun1 -> "fam"
Noun2 -> "hx"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[515]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 275
#  French Term     : la famille a dit
#  English Term(s) : ['family said', 'family told']
#  Index(es)       : [573, 575, 577, 579]
#  Grouping(s)     : [516, 517]


cfg_grammar= """
S ->  Determiner1 Noun2 Auxiliary3 Verb4 Trigger_Rule
Determiner1 -> "la"
Noun2 -> "famille" | "foyer" | "lignée" | "descendance" | "extraction" | "race" | "origine" | "classe" | "parenté" | "souche"
Auxiliary3 -> "a"
Verb4 -> "dit"
Trigger_Rule -> "|both|termination|historical|30|Group[516, 517]" |"|both|termination|nonpatient|30|Group[516, 517]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 276
#  French Term     : famille trouvée
#  English Term(s) : ['family found']
#  Index(es)       : [572, 576]
#  Grouping(s)     : [516, 517]


cfg_grammar= """
S ->  Noun1 Verb2 Trigger_Rule
Noun1 -> "famille" | "foyer" | "lignée" | "descendance" | "extraction" | "race" | "origine" | "classe" | "parenté" | "souche"
Verb2 -> "trouvée" | "rencontrer" | "juger" | "penser" | "imaginer" | "découvrir" | "deviner" | "concevoir" | "estimer" | "dénicher"
Trigger_Rule -> "|both|termination|historical|30|Group[516, 517]" |"|both|termination|nonpatient|30|Group[516, 517]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 277
#  French Term     : la famille a déclaré
#  English Term(s) : ['family stated']
#  Index(es)       : [574, 578]
#  Grouping(s)     : [516, 517]


cfg_grammar= """
S ->  Determiner1 Noun2 Auxiliary3 Verb4 Trigger_Rule
Determiner1 -> "la"
Noun2 -> "famille" | "foyer" | "lignée" | "descendance" | "extraction" | "race" | "origine" | "classe" | "parenté" | "souche"
Auxiliary3 -> "a"
Verb4 -> "déclaré" | "franc" | "certain" | "avoué" | "notoire" | "formel" | "ouvert" | "annoncé" | "décidé" | "patent"
Trigger_Rule -> "|both|termination|historical|30|Group[516, 517]" |"|both|termination|nonpatient|30|Group[516, 517]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 278
#  French Term     : histoire de famille
#  English Term(s) : ['family history']
#  Index(es)       : [580]
#  Grouping(s)     : [518]


cfg_grammar= """
S ->  Noun1 Adposition2 Noun3 Trigger_Rule
Noun1 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Adposition2 -> "de"
Noun3 -> "famille" | "foyer" | "lignée" | "descendance" | "extraction" | "race" | "origine" | "classe" | "parenté" | "souche"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[518]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 279
#  French Term     : famille
#  English Term(s) : ['family']
#  Index(es)       : [581]
#  Grouping(s)     : [525]


cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "famille" | "foyer" | "lignée" | "descendance" | "extraction" | "race" | "origine" | "classe" | "parenté" | "souche"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[525]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 280
#  French Term     : père a appelé
#  English Term(s) : ['father called']
#  Index(es)       : [582, 583]
#  Grouping(s)     : [526, 527]


cfg_grammar= """
S ->  Noun1 Auxiliary2 Auxiliary3 Trigger_Rule
Noun1 -> "père" | "ancêtre" | "fondateur" | "inventeur" | "patriarche" | "géniteur" | "générateur" | "souche" | "ascendant" | "Dieu"
Auxiliary2 -> "a"
Auxiliary3 -> "appelé"
Trigger_Rule -> "|both|termination|historical|30|Group[526, 527]" |"|both|termination|nonpatient|30|Group[526, 527]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 281
#  French Term     : du père
#  English Term(s) : ["father's"]
#  Index(es)       : [584]
#  Grouping(s)     : [528]


cfg_grammar= """
S ->  Determiner1 Noun2 Trigger_Rule
Determiner1 -> "du"
Noun2 -> "père" | "ancêtre" | "fondateur" | "inventeur" | "patriarche" | "géniteur" | "générateur" | "souche" | "ascendant" | "Dieu"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[528]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 282
#  French Term     : père
#  English Term(s) : ['father']
#  Index(es)       : [585]
#  Grouping(s)     : [529]


cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "père" | "ancêtre" | "fondateur" | "inventeur" | "patriarche" | "géniteur" | "générateur" | "souche" | "ascendant" | "Dieu"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[529]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 283
#  French Term     : fh
#  English Term(s) : ['fh']
#  Index(es)       : [586]
#  Grouping(s)     : [530]


cfg_grammar= """
S ->  Adposition1 Trigger_Rule
Adposition1 -> "fh"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[530]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 284
#  French Term     : indication du rapport final
#  English Term(s) : ['final report indication']
#  Index(es)       : [587]
#  Grouping(s)     : [531]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adjective4 Trigger_Rule
Noun1 -> "indication" | "renseignement" | "avis" | "indice" | "annonce" | "recommandation" | "note" | "directive" | "critère" | "prescription"
Determiner2 -> "du"
Noun3 -> "rapport" | "relation" | "correspondance" | "accord" | "corrélation" | "concordance" | "récit" | "proportion" | "analogie" | "affinité"
Adjective4 -> "final"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[531]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 285
#  French Term     : pour présumé
#  English Term(s) : ['for presumed']
#  Index(es)       : [588]
#  Grouping(s)     : [532]


cfg_grammar= """
S ->  Adposition1 Noun2 Trigger_Rule
Adposition1 -> "pour"
Noun2 -> "présumé" | "augurer" | "croire" | "prévoir" | "soupçonner" | "penser" | "présager" | "espérer" | "pressentir" | "conjecturer"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[532]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 286
#  French Term     : mur libre
#  English Term(s) : ['free wall']
#  Index(es)       : [592]
#  Grouping(s)     : [533]


cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "mur" | "cloison" | "clôture" | "rempart" | "muret" | "courtine" | "fortification" | "murette" | "barrière" | "parapet"
Adjective2 -> "libre"
Trigger_Rule -> "|both|pseudo|negated|10|Group[533]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 287
#  French Term     : air gratuit
#  English Term(s) : ['free air']
#  Index(es)       : [589]
#  Grouping(s)     : [533]


cfg_grammar= """
S ->  Noun1 Verb2 Trigger_Rule
Noun1 -> "air" | "allure" | "apparence" | "contenance" | "aspect" | "expression" | "atmosphère" | "figure" | "genre" | "attitude"
Verb2 -> "gratuit" | "irrationnel" | "hasardeux" | "libre" | "arbitraire" | "désintéressé" | "bénévole" | "injustifié" | "hasardé" | "injustifiable"
Trigger_Rule -> "|both|pseudo|negated|10|Group[533]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 288
#  French Term     : libre t
#  English Term(s) : ['free t']
#  Index(es)       : [591]
#  Grouping(s)     : [533]


cfg_grammar= """
S ->  Adjective1 Noun2 Trigger_Rule
Adjective1 -> "libre"
Noun2 -> "t"
Trigger_Rule -> "|both|pseudo|negated|10|Group[533]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 289
#  French Term     : fluide libre
#  English Term(s) : ['free fluid']
#  Index(es)       : [590]
#  Grouping(s)     : [533]


cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "fluide" | "indécis" | "fluctuant" | "émanation" | "flux" | "radiation" | "inconsistant" | "coulant" | "limpide" | "rayonnement"
Adjective2 -> "libre"
Trigger_Rule -> "|both|pseudo|negated|10|Group[533]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 290
#  French Term     : eau gratuite
#  English Term(s) : ['free water']
#  Index(es)       : [593]
#  Grouping(s)     : [533]


cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "eau" | "flotte" | "orient" | "lavure" | "flot" | "larme" | "lustre" | "baille" | "pisse" | "lotion"
Adjective2 -> "gratuite"
Trigger_Rule -> "|both|pseudo|negated|10|Group[533]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 291
#  French Term     : libre
#  English Term(s) : ['free']
#  Index(es)       : [594]
#  Grouping(s)     : [540]


cfg_grammar= """
S ->  Adjective1 Trigger_Rule
Adjective1 -> "libre"
Trigger_Rule -> "|backward|trigger|negated|10|Group[540]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 292
#  French Term     : de
#  English Term(s) : ['from']
#  Index(es)       : [595]
#  Grouping(s)     : [541]


cfg_grammar= """
S ->  Adposition1 Trigger_Rule
Adposition1 -> "de"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[541]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 293
#  French Term     : donné \ w + histoire
#  English Term(s) : ['given \\w+ history']
#  Index(es)       : [596]
#  Grouping(s)     : [542]


cfg_grammar= """
S ->  Verb1 Adjective2 Adposition3 Adposition4 Noun5 Trigger_Rule
Verb1 -> "donné" | "déterminé" | "fixé" | "offert" | "foutre" | "fixer" | "porter" | "certain" | "attribué" | "dire"
Adjective2 -> "\"
Adposition3 -> "w"
Adposition4 -> "+"
Noun5 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[542]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 294
#  French Term     : histoire du patient
#  English Term(s) : ['given patient s history']
#  Index(es)       : [597]
#  Grouping(s)     : [542]


cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Determiner2 -> "du"
Noun3 -> "patient" | "persévérant" | "client" | "infatigable" | "constant" | "calme" | "imperturbable" | "impassible" | "résigné" | "courageux"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[542]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 295
#  French Term     : compte tenu de l'histoire
#  English Term(s) : ['given the history']
#  Index(es)       : [602]
#  Grouping(s)     : [543]


cfg_grammar= """
S ->  Noun1 Verb2 Adposition3 Determiner4 Noun5 Trigger_Rule
Noun1 -> "compte" | "profit" | "relevé" | "bénéfice" | "dénombrement" | "facture" | "bordereau" | "énumération" | "boni" | "intérêt"
Verb2 -> "tenu" | "travaillé" | "pris" | "réputé" | "absorbé" | "défendu" | "prolongé" | "occupé" | "accaparé" | "responsable"
Adposition3 -> "de"
Determiner4 -> "l'"
Noun5 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 296
#  French Term     : compte tenu du fait
#  English Term(s) : ['given the fact']
#  Index(es)       : [601]
#  Grouping(s)     : [543]


cfg_grammar= """
S ->  Noun1 Verb2 Determiner3 Noun4 Trigger_Rule
Noun1 -> "compte" | "profit" | "relevé" | "bénéfice" | "dénombrement" | "facture" | "bordereau" | "énumération" | "boni" | "intérêt"
Verb2 -> "tenu" | "travaillé" | "pris" | "réputé" | "absorbé" | "défendu" | "prolongé" | "occupé" | "accaparé" | "responsable"
Determiner3 -> "du"
Noun4 -> "fait"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 297
#  French Term     : compte tenu de son histoire
#  English Term(s) : ['given her history', 'given his history']
#  Index(es)       : [598, 599]
#  Grouping(s)     : [543]


cfg_grammar= """
S ->  Noun1 Verb2 Adposition3 Determiner4 Noun5 Trigger_Rule
Noun1 -> "compte" | "profit" | "relevé" | "bénéfice" | "dénombrement" | "facture" | "bordereau" | "énumération" | "boni" | "intérêt"
Verb2 -> "tenu" | "travaillé" | "pris" | "réputé" | "absorbé" | "défendu" | "prolongé" | "occupé" | "accaparé" | "responsable"
Adposition3 -> "de"
Determiner4 -> "son"
Noun5 -> "histoire" | "conte" | "mensonge" | "annales" | "chronique" | "aventure" | "anecdote" | "description" | "légende" | "fastes"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 298
#  French Term     : compte tenu de la gravité de
#  English Term(s) : ['given the severity of']
#  Index(es)       : [603]
#  Grouping(s)     : [543]


cfg_grammar= """
S ->  Noun1 Verb2 Adposition3 Determiner4 Noun5 Adposition6 Trigger_Rule
Noun1 -> "compte" | "profit" | "relevé" | "bénéfice" | "dénombrement" | "facture" | "bordereau" | "énumération" | "boni" | "intérêt"
Verb2 -> "tenu" | "travaillé" | "pris" | "réputé" | "absorbé" | "défendu" | "prolongé" | "occupé" | "accaparé" | "responsable"
Adposition3 -> "de"
Determiner4 -> "la"
Noun5 -> "gravité" | "gravitation" | "dignité" | "solennité" | "décence" | "importance" | "retenue" | "sérieux" | "sévérité" | "austérité"
Adposition6 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 299
#  French Term     : étant donné que
#  English Term(s) : ['given that']
#  Index(es)       : [600]
#  Grouping(s)     : [543]


cfg_grammar= """
S ->  Verb1 Verb2 Subordinating_conjunction3 Trigger_Rule
Verb1 -> "étant"
Verb2 -> "donné" | "déterminé" | "fixé" | "offert" | "foutre" | "fixer" | "porter" | "certain" | "attribué" | "dire"
Subordinating_conjunction3 -> "que"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 300
#  French Term     : gram négatif
#  English Term(s) : ['gram negative']
#  Index(es)       : [604]
#  Grouping(s)     : [550]


cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "gram"
Adjective2 -> "négatif"
Trigger_Rule -> "|both|pseudo|negated|10|Group[550]" 
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
