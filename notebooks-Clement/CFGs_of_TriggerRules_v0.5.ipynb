# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Trigger_Rule
Var1 -> "\\> 0 mois" | "\\> 0 ans" | "\\> 0 année" | "\\> 0 années" | "\\> 1 semaines" | "\\> 13 jours"
Var2 -> "de"
Trigger_Rule -> "|forward|trigger|historical|30|Group[2]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# \> 0 mois de |forward|trigger|historical|30|Group[2]|Clement
# \> 0 ans de |forward|trigger|historical|30|Group[2]|Clement
# \> 0 année de |forward|trigger|historical|30|Group[2]|Clement
# \> 0 années de |forward|trigger|historical|30|Group[2]|Clement
# \> 1 semaines de |forward|trigger|historical|30|Group[2]|Clement
# \> 13 jours de |forward|trigger|historical|30|Group[2]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> "il y a \\> 0 mois" | "il y a \\> 0 an" | "il y a \\> 0 ans" | "il y a \\> 1 semaines" 
Trigger_Rule -> "|backward|trigger|historical|30|Group[4]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# il y a \> 0 mois |backward|trigger|historical|30|Group[4]|Clement
# il y a \> 0 an |backward|trigger|historical|30|Group[4]|Clement
# il y a \> 0 ans |backward|trigger|historical|30|Group[4]|Clement
# il y a \> 1 semaines |backward|trigger|historical|30|Group[4]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> ": non" | ": neg" | ": nég"| ": négatif" | ": negatif" | ": négative" | ": nul" | ": nulle"
Trigger_Rule -> "|backward|trigger|negated|10|Group[23]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# : non |backward|trigger|negated|10|Group[23]|Clement
# : neg |backward|trigger|negated|10|Group[23]|Clement
# : nég |backward|trigger|negated|10|Group[23]|Clement
# : négatif |backward|trigger|negated|10|Group[23]|Clement
# : negatif |backward|trigger|negated|10|Group[23]|Clement
# : négative |backward|trigger|negated|10|Group[23]|Clement
# : nul |backward|trigger|negated|10|Group[23]|Clement
# : nulle |backward|trigger|negated|10|Group[23]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Word Var1 Trigger_Rule
Word -> "\\w+"
Var1 -> "pas" | "aucun" | "aucune" | "nul" | "nulle" | "sans"
Trigger_Rule -> "|forward|trigger|negated|10|Group[24]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# \w+ pas |forward|trigger|negated|10|Group[24]|Clement
# \w+ aucun |forward|trigger|negated|10|Group[24]|Clement
# \w+ aucune |forward|trigger|negated|10|Group[24]|Clement
# \w+ nul |forward|trigger|negated|10|Group[24]|Clement
# \w+ nulle |forward|trigger|negated|10|Group[24]|Clement
# \w+ sans |forward|trigger|negated|10|Group[24]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "absence" | "manque" | "omission" | "privation" | "carence" | "défaillance" | "défection" | "lacune" | "déficit" | "déficience"
Var2 -> "de" | "d'un" | "d'une" | "d'"
Trigger_Rule -> "|forward|trigger|negated|10|Group[26]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# absence de |forward|trigger|negated|10|Group[26]|Clement
# absence d'un |forward|trigger|negated|10|Group[26]|Clement
# absence d'une |forward|trigger|negated|10|Group[26]|Clement
# absence d' |forward|trigger|negated|10|Group[26]|Clement
# manque de |forward|trigger|negated|10|Group[26]|Clement
# manque d'un |forward|trigger|negated|10|Group[26]|Clement
# manque d'une |forward|trigger|negated|10|Group[26]|Clement
# manque d' |forward|trigger|negated|10|Group[26]|Clement
# omission de |forward|trigger|negated|10|Group[26]|Clement
# omission d'un |forward|trigger|negated|10|Group[26]|Clement
# omission d'une |forward|trigger|negated|10|Group[26]|Clement
# omission d' |forward|trigger|negated|10|Group[26]|Clement
# privation de |forward|trigger|negated|10|Group[26]|Clement
# privation d'un |forward|trigger|negated|10|Group[26]|Clement
# privation d'une |forward|trigger|negated|10|Group[26]|Clement
# privation d' |forward|trigger|negated|10|Group[26]|Clement
# carence de |forward|trigger|negated|10|Group[26]|Clement
# carence d'un |forward|trigger|negated|10|Group[26]|Clement
# carence d'une |forward|trigger|negated|10|Group[26]|Clement
# carence d' |forward|trigger|negated|10|Group[26]|Clement
# défaillance de |forward|trigger|negated|10|Group[26]|Clement
# défaillance d'un |forward|trigger|negated|10|Group[26]|Clement
# défaillance d'une |forward|trigger|negated|10|Group[26]|Clement
# défaillance d' |forward|trigger|negated|10|Group[26]|Clement
# défection de |forward|trigger|negated|10|Group[26]|Clement
# défection d'un |forward|trigger|negated|10|Group[26]|Clement
# défection d'une |forward|trigger|negated|10|Group[26]|Clement
# défection d' |forward|trigger|negated|10|Group[26]|Clement
# lacune de |forward|trigger|negated|10|Group[26]|Clement
# lacune d'un |forward|trigger|negated|10|Group[26]|Clement
# lacune d'une |forward|trigger|negated|10|Group[26]|Clement
# lacune d' |forward|trigger|negated|10|Group[26]|Clement
# déficit de |forward|trigger|negated|10|Group[26]|Clement
# déficit d'un |forward|trigger|negated|10|Group[26]|Clement
# déficit d'une |forward|trigger|negated|10|Group[26]|Clement
# déficit d' |forward|trigger|negated|10|Group[26]|Clement
# déficience de |forward|trigger|negated|10|Group[26]|Clement
# déficience d'un |forward|trigger|negated|10|Group[26]|Clement
# déficience d'une |forward|trigger|negated|10|Group[26]|Clement
# déficience d' |forward|trigger|negated|10|Group[26]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "suffisant" | "suffisante" | "passable" | "satisfaisant" | "satisfaisante" | "supportable" | "raisonnable" | "acceptable" | "assez" | "correct" | "correcte" | "tolérable" | "bon" | "pas mal" | "bien" | "adéquat" | "adéquate" | "assez bien"
Var2 -> "pour"
Var3 -> "écarter" | "rejeter" | "éliminer" | "évincer" | "supprimer" | "proscrire" | "ôter" | "exclure" | "éloigner" | "refuser" | "se défaire"
Trigger_Rule -> "|forward|trigger|negated|10|Group[30]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# suffisant pour écarter |forward|trigger|negated|10|Group[30]|Clement
# suffisant pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# suffisant pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# suffisant pour évincer |forward|trigger|negated|10|Group[30]|Clement
# suffisant pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# suffisant pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# suffisant pour ôter |forward|trigger|negated|10|Group[30]|Clement
# suffisant pour exclure |forward|trigger|negated|10|Group[30]|Clement
# suffisant pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# suffisant pour refuser |forward|trigger|negated|10|Group[30]|Clement
# suffisant pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# suffisante pour écarter |forward|trigger|negated|10|Group[30]|Clement
# suffisante pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# suffisante pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# suffisante pour évincer |forward|trigger|negated|10|Group[30]|Clement
# suffisante pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# suffisante pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# suffisante pour ôter |forward|trigger|negated|10|Group[30]|Clement
# suffisante pour exclure |forward|trigger|negated|10|Group[30]|Clement
# suffisante pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# suffisante pour refuser |forward|trigger|negated|10|Group[30]|Clement
# suffisante pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# passable pour écarter |forward|trigger|negated|10|Group[30]|Clement
# passable pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# passable pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# passable pour évincer |forward|trigger|negated|10|Group[30]|Clement
# passable pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# passable pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# passable pour ôter |forward|trigger|negated|10|Group[30]|Clement
# passable pour exclure |forward|trigger|negated|10|Group[30]|Clement
# passable pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# passable pour refuser |forward|trigger|negated|10|Group[30]|Clement
# passable pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# satisfaisant pour écarter |forward|trigger|negated|10|Group[30]|Clement
# satisfaisant pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# satisfaisant pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# satisfaisant pour évincer |forward|trigger|negated|10|Group[30]|Clement
# satisfaisant pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# satisfaisant pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# satisfaisant pour ôter |forward|trigger|negated|10|Group[30]|Clement
# satisfaisant pour exclure |forward|trigger|negated|10|Group[30]|Clement
# satisfaisant pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# satisfaisant pour refuser |forward|trigger|negated|10|Group[30]|Clement
# satisfaisant pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# satisfaisante pour écarter |forward|trigger|negated|10|Group[30]|Clement
# satisfaisante pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# satisfaisante pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# satisfaisante pour évincer |forward|trigger|negated|10|Group[30]|Clement
# satisfaisante pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# satisfaisante pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# satisfaisante pour ôter |forward|trigger|negated|10|Group[30]|Clement
# satisfaisante pour exclure |forward|trigger|negated|10|Group[30]|Clement
# satisfaisante pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# satisfaisante pour refuser |forward|trigger|negated|10|Group[30]|Clement
# satisfaisante pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# supportable pour écarter |forward|trigger|negated|10|Group[30]|Clement
# supportable pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# supportable pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# supportable pour évincer |forward|trigger|negated|10|Group[30]|Clement
# supportable pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# supportable pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# supportable pour ôter |forward|trigger|negated|10|Group[30]|Clement
# supportable pour exclure |forward|trigger|negated|10|Group[30]|Clement
# supportable pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# supportable pour refuser |forward|trigger|negated|10|Group[30]|Clement
# supportable pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# raisonnable pour écarter |forward|trigger|negated|10|Group[30]|Clement
# raisonnable pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# raisonnable pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# raisonnable pour évincer |forward|trigger|negated|10|Group[30]|Clement
# raisonnable pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# raisonnable pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# raisonnable pour ôter |forward|trigger|negated|10|Group[30]|Clement
# raisonnable pour exclure |forward|trigger|negated|10|Group[30]|Clement
# raisonnable pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# raisonnable pour refuser |forward|trigger|negated|10|Group[30]|Clement
# raisonnable pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# acceptable pour écarter |forward|trigger|negated|10|Group[30]|Clement
# acceptable pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# acceptable pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# acceptable pour évincer |forward|trigger|negated|10|Group[30]|Clement
# acceptable pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# acceptable pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# acceptable pour ôter |forward|trigger|negated|10|Group[30]|Clement
# acceptable pour exclure |forward|trigger|negated|10|Group[30]|Clement
# acceptable pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# acceptable pour refuser |forward|trigger|negated|10|Group[30]|Clement
# acceptable pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# assez pour écarter |forward|trigger|negated|10|Group[30]|Clement
# assez pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# assez pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# assez pour évincer |forward|trigger|negated|10|Group[30]|Clement
# assez pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# assez pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# assez pour ôter |forward|trigger|negated|10|Group[30]|Clement
# assez pour exclure |forward|trigger|negated|10|Group[30]|Clement
# assez pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# assez pour refuser |forward|trigger|negated|10|Group[30]|Clement
# assez pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# correct pour écarter |forward|trigger|negated|10|Group[30]|Clement
# correct pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# correct pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# correct pour évincer |forward|trigger|negated|10|Group[30]|Clement
# correct pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# correct pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# correct pour ôter |forward|trigger|negated|10|Group[30]|Clement
# correct pour exclure |forward|trigger|negated|10|Group[30]|Clement
# correct pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# correct pour refuser |forward|trigger|negated|10|Group[30]|Clement
# correct pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# correcte pour écarter |forward|trigger|negated|10|Group[30]|Clement
# correcte pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# correcte pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# correcte pour évincer |forward|trigger|negated|10|Group[30]|Clement
# correcte pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# correcte pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# correcte pour ôter |forward|trigger|negated|10|Group[30]|Clement
# correcte pour exclure |forward|trigger|negated|10|Group[30]|Clement
# correcte pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# correcte pour refuser |forward|trigger|negated|10|Group[30]|Clement
# correcte pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# tolérable pour écarter |forward|trigger|negated|10|Group[30]|Clement
# tolérable pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# tolérable pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# tolérable pour évincer |forward|trigger|negated|10|Group[30]|Clement
# tolérable pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# tolérable pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# tolérable pour ôter |forward|trigger|negated|10|Group[30]|Clement
# tolérable pour exclure |forward|trigger|negated|10|Group[30]|Clement
# tolérable pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# tolérable pour refuser |forward|trigger|negated|10|Group[30]|Clement
# tolérable pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# bon pour écarter |forward|trigger|negated|10|Group[30]|Clement
# bon pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# bon pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# bon pour évincer |forward|trigger|negated|10|Group[30]|Clement
# bon pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# bon pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# bon pour ôter |forward|trigger|negated|10|Group[30]|Clement
# bon pour exclure |forward|trigger|negated|10|Group[30]|Clement
# bon pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# bon pour refuser |forward|trigger|negated|10|Group[30]|Clement
# bon pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# pas mal pour écarter |forward|trigger|negated|10|Group[30]|Clement
# pas mal pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# pas mal pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# pas mal pour évincer |forward|trigger|negated|10|Group[30]|Clement
# pas mal pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# pas mal pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# pas mal pour ôter |forward|trigger|negated|10|Group[30]|Clement
# pas mal pour exclure |forward|trigger|negated|10|Group[30]|Clement
# pas mal pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# pas mal pour refuser |forward|trigger|negated|10|Group[30]|Clement
# pas mal pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# bien pour écarter |forward|trigger|negated|10|Group[30]|Clement
# bien pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# bien pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# bien pour évincer |forward|trigger|negated|10|Group[30]|Clement
# bien pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# bien pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# bien pour ôter |forward|trigger|negated|10|Group[30]|Clement
# bien pour exclure |forward|trigger|negated|10|Group[30]|Clement
# bien pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# bien pour refuser |forward|trigger|negated|10|Group[30]|Clement
# bien pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# adéquat pour écarter |forward|trigger|negated|10|Group[30]|Clement
# adéquat pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# adéquat pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# adéquat pour évincer |forward|trigger|negated|10|Group[30]|Clement
# adéquat pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# adéquat pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# adéquat pour ôter |forward|trigger|negated|10|Group[30]|Clement
# adéquat pour exclure |forward|trigger|negated|10|Group[30]|Clement
# adéquat pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# adéquat pour refuser |forward|trigger|negated|10|Group[30]|Clement
# adéquat pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# adéquate pour écarter |forward|trigger|negated|10|Group[30]|Clement
# adéquate pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# adéquate pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# adéquate pour évincer |forward|trigger|negated|10|Group[30]|Clement
# adéquate pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# adéquate pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# adéquate pour ôter |forward|trigger|negated|10|Group[30]|Clement
# adéquate pour exclure |forward|trigger|negated|10|Group[30]|Clement
# adéquate pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# adéquate pour refuser |forward|trigger|negated|10|Group[30]|Clement
# adéquate pour se défaire |forward|trigger|negated|10|Group[30]|Clement
# assez bien pour écarter |forward|trigger|negated|10|Group[30]|Clement
# assez bien pour rejeter |forward|trigger|negated|10|Group[30]|Clement
# assez bien pour éliminer |forward|trigger|negated|10|Group[30]|Clement
# assez bien pour évincer |forward|trigger|negated|10|Group[30]|Clement
# assez bien pour supprimer |forward|trigger|negated|10|Group[30]|Clement
# assez bien pour proscrire |forward|trigger|negated|10|Group[30]|Clement
# assez bien pour ôter |forward|trigger|negated|10|Group[30]|Clement
# assez bien pour exclure |forward|trigger|negated|10|Group[30]|Clement
# assez bien pour éloigner |forward|trigger|negated|10|Group[30]|Clement
# assez bien pour refuser |forward|trigger|negated|10|Group[30]|Clement
# assez bien pour se défaire |forward|trigger|negated|10|Group[30]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Patient Trigger_Rule
Var1 -> "suffisant" | "suffisante" | "passable" | "satisfaisant" | "satisfaisante" | "supportable" | "raisonnable" | "acceptable" | "assez" | "correct" | "correcte" | "tolérable" | "bon" | "pas mal" | "bien" | "adéquat" | "adéquate" | "assez bien"
Var2 -> "pour"
Var3 -> "exclure" | "éliminer" | "rejeter" | "proscrire" | "éloigner" | "supprimer" | "radier"
Patient -> "le patient" | "la patiente"| "le souffrant" | "la souffrante"| "le sujet"
Trigger_Rule -> "|forward|trigger|negated|10|Group[42]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# suffisant pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisant pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# suffisante pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# passable pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# passable pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# passable pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# passable pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# passable pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# passable pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# passable pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# passable pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# passable pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# passable pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# passable pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# passable pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# passable pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# passable pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# passable pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# passable pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# passable pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# passable pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# passable pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# passable pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# passable pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# passable pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# passable pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# passable pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# passable pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# passable pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# passable pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# passable pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# passable pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# passable pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# passable pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# passable pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# passable pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# passable pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# passable pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisant pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# satisfaisante pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# supportable pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# supportable pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# supportable pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# supportable pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# supportable pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# supportable pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# supportable pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# supportable pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# supportable pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# supportable pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# supportable pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# supportable pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# supportable pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# supportable pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# supportable pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# supportable pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# supportable pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# supportable pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# supportable pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# supportable pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# supportable pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# supportable pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# supportable pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# supportable pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# supportable pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# supportable pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# supportable pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# supportable pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# supportable pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# supportable pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# supportable pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# supportable pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# supportable pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# supportable pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# supportable pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# raisonnable pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# acceptable pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# assez pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# assez pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# assez pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# assez pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# assez pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# assez pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# assez pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# correct pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# correct pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# correct pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correct pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correct pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# correct pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# correct pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# correct pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correct pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correct pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# correct pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# correct pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# correct pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correct pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correct pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# correct pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# correct pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# correct pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correct pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correct pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# correct pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# correct pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# correct pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correct pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correct pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# correct pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# correct pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# correct pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correct pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correct pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# correct pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# correct pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# correct pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correct pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correct pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# correcte pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# correcte pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# correcte pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correcte pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correcte pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# correcte pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# correcte pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# correcte pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correcte pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correcte pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# correcte pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# correcte pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# correcte pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correcte pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correcte pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# correcte pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# correcte pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# correcte pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correcte pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correcte pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# correcte pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# correcte pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# correcte pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correcte pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correcte pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# correcte pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# correcte pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# correcte pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correcte pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correcte pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# correcte pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# correcte pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# correcte pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# correcte pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# correcte pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# tolérable pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# bon pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# bon pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# bon pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bon pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bon pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# bon pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# bon pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# bon pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bon pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bon pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# bon pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# bon pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# bon pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bon pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bon pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# bon pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# bon pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# bon pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bon pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bon pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# bon pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# bon pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# bon pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bon pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bon pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# bon pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# bon pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# bon pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bon pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bon pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# bon pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# bon pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# bon pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bon pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bon pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# pas mal pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# bien pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# bien pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# bien pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bien pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bien pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# bien pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# bien pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# bien pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bien pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bien pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# bien pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# bien pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# bien pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bien pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bien pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# bien pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# bien pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# bien pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bien pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bien pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# bien pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# bien pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# bien pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bien pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bien pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# bien pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# bien pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# bien pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bien pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bien pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# bien pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# bien pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# bien pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# bien pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# bien pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquat pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# adéquate pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour exclure le patient |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour exclure la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour exclure le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour exclure la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour exclure le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour éliminer le patient |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour éliminer la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour éliminer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour éliminer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour éliminer le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour rejeter le patient |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour rejeter la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour rejeter le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour rejeter la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour rejeter le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour proscrire le patient |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour proscrire la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour proscrire le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour proscrire la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour proscrire le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour éloigner le patient |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour éloigner la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour éloigner le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour éloigner la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour éloigner le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour supprimer le patient |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour supprimer la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour supprimer le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour supprimer la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour supprimer le sujet |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour radier le patient |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour radier la patiente |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour radier le souffrant |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour radier la souffrante |forward|trigger|negated|10|Group[42]|Clement
# assez bien pour radier le sujet |forward|trigger|negated|10|Group[42]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "après"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[47]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# après |both|pseudo|uncertain|30|Group[47]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "bien"
Var2 -> "que"
Trigger_Rule -> "|forward|termination|negated|10|Group[48]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# bien que |forward|termination|negated|10|Group[48]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "présenté"
Var2 -> "_"|"_s" |"_e" |"_es"
Trigger_Rule -> "|forward|termination|historical|10|Group[51]|Clement" | "|forward|termination|negated|10|Group[49]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# présenté _ |forward|termination|historical|10|Group[51]|Clement
# présenté _ |forward|termination|negated|10|Group[49]|Clement
# présenté _s |forward|termination|historical|10|Group[51]|Clement
# présenté _s |forward|termination|negated|10|Group[49]|Clement
# présenté _e |forward|termination|historical|10|Group[51]|Clement
# présenté _e |forward|termination|negated|10|Group[49]|Clement
# présenté _es |forward|termination|historical|10|Group[51]|Clement
# présenté _es |forward|termination|negated|10|Group[49]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "et"
Var2 -> "\\w+ \\w+" | "\\w+"
Var3 -> "montre" | "démontre" | "signale" 
Var4 -> "_"|"_nt"
Trigger_Rule -> "|forward|termination|negated|10|Group[53]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# et \w+ \w+ montre _ |forward|termination|negated|10|Group[53]|Clement
# et \w+ \w+ montre _nt |forward|termination|negated|10|Group[53]|Clement
# et \w+ \w+ démontre _ |forward|termination|negated|10|Group[53]|Clement
# et \w+ \w+ démontre _nt |forward|termination|negated|10|Group[53]|Clement
# et \w+ \w+ signale _ |forward|termination|negated|10|Group[53]|Clement
# et \w+ \w+ signale _nt |forward|termination|negated|10|Group[53]|Clement
# et \w+ montre _ |forward|termination|negated|10|Group[53]|Clement
# et \w+ montre _nt |forward|termination|negated|10|Group[53]|Clement
# et \w+ démontre _ |forward|termination|negated|10|Group[53]|Clement
# et \w+ démontre _nt |forward|termination|negated|10|Group[53]|Clement
# et \w+ signale _ |forward|termination|negated|10|Group[53]|Clement
# et \w+ signale _nt |forward|termination|negated|10|Group[53]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "et"
Var2 -> "a"
Var3 -> "fait"
Trigger_Rule -> "|forward|termination|negated|10|Group[59]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# et a fait |forward|termination|negated|10|Group[59]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Pronoun Var2 Trigger_Rule
Var1 -> "et"
Pronoun -> "il" | "elle"
Var2 -> "avait"
Trigger_Rule -> "|forward|termination|negated|10|Group[60]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# et il avait |forward|termination|negated|10|Group[60]|Clement
# et elle avait |forward|termination|negated|10|Group[60]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Termin Var4 Trigger_Rule
Var1 -> "a"
Var2 -> "été"
Var3 -> "noté" | "remarqué" | "observé" | "consigné" | "classé" | "évalué" | "étiqueté" | "mentionné"
Termin -> "_"|"_e"
Var4 -> "pour"
Trigger_Rule -> "|forward|termination|negated|10|Group[61]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a été noté _ pour |forward|termination|negated|10|Group[61]|Clement
# a été noté _e pour |forward|termination|negated|10|Group[61]|Clement
# a été remarqué _ pour |forward|termination|negated|10|Group[61]|Clement
# a été remarqué _e pour |forward|termination|negated|10|Group[61]|Clement
# a été observé _ pour |forward|termination|negated|10|Group[61]|Clement
# a été observé _e pour |forward|termination|negated|10|Group[61]|Clement
# a été consigné _ pour |forward|termination|negated|10|Group[61]|Clement
# a été consigné _e pour |forward|termination|negated|10|Group[61]|Clement
# a été classé _ pour |forward|termination|negated|10|Group[61]|Clement
# a été classé _e pour |forward|termination|negated|10|Group[61]|Clement
# a été évalué _ pour |forward|termination|negated|10|Group[61]|Clement
# a été évalué _e pour |forward|termination|negated|10|Group[61]|Clement
# a été étiqueté _ pour |forward|termination|negated|10|Group[61]|Clement
# a été étiqueté _e pour |forward|termination|negated|10|Group[61]|Clement
# a été mentionné _ pour |forward|termination|negated|10|Group[61]|Clement
# a été mentionné _e pour |forward|termination|negated|10|Group[61]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Termin Var4 Trigger_Rule
Var1 -> "ont"
Var2 -> "été"
Var3 -> "noté" | "remarqué" | "observé" | "consigné" | "classé" | "évalué" | "étiqueté" | "mentionné"
Termin -> "_s"|"_es"
Var4 -> "pour"
Trigger_Rule -> "|forward|termination|negated|10|Group[61]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ont été noté _s pour |forward|termination|negated|10|Group[61]|Clement
# ont été noté _es pour |forward|termination|negated|10|Group[61]|Clement
# ont été remarqué _s pour |forward|termination|negated|10|Group[61]|Clement
# ont été remarqué _es pour |forward|termination|negated|10|Group[61]|Clement
# ont été observé _s pour |forward|termination|negated|10|Group[61]|Clement
# ont été observé _es pour |forward|termination|negated|10|Group[61]|Clement
# ont été consigné _s pour |forward|termination|negated|10|Group[61]|Clement
# ont été consigné _es pour |forward|termination|negated|10|Group[61]|Clement
# ont été classé _s pour |forward|termination|negated|10|Group[61]|Clement
# ont été classé _es pour |forward|termination|negated|10|Group[61]|Clement
# ont été évalué _s pour |forward|termination|negated|10|Group[61]|Clement
# ont été évalué _es pour |forward|termination|negated|10|Group[61]|Clement
# ont été étiqueté _s pour |forward|termination|negated|10|Group[61]|Clement
# ont été étiqueté _es pour |forward|termination|negated|10|Group[61]|Clement
# ont été mentionné _s pour |forward|termination|negated|10|Group[61]|Clement
# ont été mentionné _es pour |forward|termination|negated|10|Group[61]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "et"
Var2 -> "il" | "elle" 
Var3 -> "était"
Trigger_Rule -> "|forward|termination|negated|10|Group[62]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# et il était |forward|termination|negated|10|Group[62]|Clement
# et elle était |forward|termination|negated|10|Group[62]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "et"
Var2 -> "noté" | "constaté" | "relevé" | "remarqué" | "observé" | "évalué" | "mentionné"
Var3 -> "d'avoir"
Trigger_Rule -> "|forward|termination|negated|10|Group[63]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# et noté d'avoir |forward|termination|negated|10|Group[63]|Clement
# et constaté d'avoir |forward|termination|negated|10|Group[63]|Clement
# et relevé d'avoir |forward|termination|negated|10|Group[63]|Clement
# et remarqué d'avoir |forward|termination|negated|10|Group[63]|Clement
# et observé d'avoir |forward|termination|negated|10|Group[63]|Clement
# et évalué d'avoir |forward|termination|negated|10|Group[63]|Clement
# et mentionné d'avoir |forward|termination|negated|10|Group[63]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "et"
Var2 -> "il" | "elle"
Var3 -> "avait"
Trigger_Rule -> "|forward|termination|negated|10|Group[64]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# et il avait |forward|termination|negated|10|Group[64]|Clement
# et elle avait |forward|termination|negated|10|Group[64]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Patient Var2 Trigger_Rule
Var1 -> "et"
Patient -> "le patient" | "la patiente"| "le souffrant" | "la souffrante"| "le sujet"
Var2 -> "avait" | "était"
Trigger_Rule -> "|forward|termination|negated|10|Group[67]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# et le patient avait |forward|termination|negated|10|Group[67]|Clement
# et le patient était |forward|termination|negated|10|Group[67]|Clement
# et la patiente avait |forward|termination|negated|10|Group[67]|Clement
# et la patiente était |forward|termination|negated|10|Group[67]|Clement
# et le souffrant avait |forward|termination|negated|10|Group[67]|Clement
# et le souffrant était |forward|termination|negated|10|Group[67]|Clement
# et la souffrante avait |forward|termination|negated|10|Group[67]|Clement
# et la souffrante était |forward|termination|negated|10|Group[67]|Clement
# et le sujet avait |forward|termination|negated|10|Group[67]|Clement
# et le sujet était |forward|termination|negated|10|Group[67]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "et"
Var2 -> "avec"
Var3 -> "seulement"
Trigger_Rule -> "|forward|termination|negated|10|Group[69]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# et avec seulement |forward|termination|negated|10|Group[69]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "tout"
Var2 -> "autre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[71]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# tout autre |forward|trigger|negated|10|Group[71]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "excepté" | "sauf" 
Trigger_Rule -> "|forward|termination|negated|10|Group[73]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# excepté |forward|termination|negated|10|Group[73]|Clement
# sauf |forward|termination|negated|10|Group[73]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "semble" | "semblait"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[74]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# semble |forward|trigger|uncertain|30|Group[74]|Clement
# semblait |forward|trigger|uncertain|30|Group[74]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> "est négatif" | "est null" | "sont négatifs" | "sont nulls"
Trigger_Rule -> "|backward|trigger|negated|10|Group[75]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# est négatif |backward|trigger|negated|10|Group[75]|Clement
# est null |backward|trigger|negated|10|Group[75]|Clement
# sont négatifs |backward|trigger|negated|10|Group[75]|Clement
# sont nulls |backward|trigger|negated|10|Group[75]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Trigger_Rule
Var1 -> "n'est" | "ne sont"
Var2 -> "plus"
Trigger_Rule -> "|backward|trigger|negated|10|Group[77]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'est plus |backward|trigger|negated|10|Group[77]|Clement
# ne sont plus |backward|trigger|negated|10|Group[77]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> "est exclu" | "est exclue" | "sont exclus" | "sont exclues"
Trigger_Rule -> "|backward|trigger|negated|10|Group[79]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# est exclu |backward|trigger|negated|10|Group[79]|Clement
# est exclue |backward|trigger|negated|10|Group[79]|Clement
# sont exclus |backward|trigger|negated|10|Group[79]|Clement
# sont exclues |backward|trigger|negated|10|Group[79]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> "sont arrêtés" | "sont stoppés" | "sont enrayés" | "sont contenus" | "sont suspendus" | "sont jugulés" | "sont terminés" | "sont immobilisés" | "sont finis" | "sont endigés" | "ont cessés" | "sont gelés" | "sont coupés" | "sont arrêtées" | "sont stoppées" | "sont enrayées" | "sont contenues" | "sont suspendues" | "sont jugulées" | "sont terminées" | "sont immobilisées" | "sont finies" | "sont endigées" | "ont cessées" | "sont gelées" | "sont coupées" | "est arrêté" | "est stoppé" | "est enrayé" | "est contenu" | "est suspendu" | "est jugulé" | "est terminé" | "est immobilisé" | "est fini" | "est endigé" | "a cessé" | "est gelé" | "est coupé" | "est arrêtée" | "est stoppée" | "est enrayée" | "est contenue" | "est suspendue" | "est jugulée" | "est terminée" | "est immobilisée" | "est finie" | "est endigée" | "est gelée" | "est coupée"
Trigger_Rule -> "|backward|trigger|negated|10|Group[81]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sont arrêtés |backward|trigger|negated|10|Group[81]|Clement
# sont stoppés |backward|trigger|negated|10|Group[81]|Clement
# sont enrayés |backward|trigger|negated|10|Group[81]|Clement
# sont contenus |backward|trigger|negated|10|Group[81]|Clement
# sont suspendus |backward|trigger|negated|10|Group[81]|Clement
# sont jugulés |backward|trigger|negated|10|Group[81]|Clement
# sont terminés |backward|trigger|negated|10|Group[81]|Clement
# sont immobilisés |backward|trigger|negated|10|Group[81]|Clement
# sont finis |backward|trigger|negated|10|Group[81]|Clement
# sont endigés |backward|trigger|negated|10|Group[81]|Clement
# ont cessés |backward|trigger|negated|10|Group[81]|Clement
# sont gelés |backward|trigger|negated|10|Group[81]|Clement
# sont coupés |backward|trigger|negated|10|Group[81]|Clement
# sont arrêtées |backward|trigger|negated|10|Group[81]|Clement
# sont stoppées |backward|trigger|negated|10|Group[81]|Clement
# sont enrayées |backward|trigger|negated|10|Group[81]|Clement
# sont contenues |backward|trigger|negated|10|Group[81]|Clement
# sont suspendues |backward|trigger|negated|10|Group[81]|Clement
# sont jugulées |backward|trigger|negated|10|Group[81]|Clement
# sont terminées |backward|trigger|negated|10|Group[81]|Clement
# sont immobilisées |backward|trigger|negated|10|Group[81]|Clement
# sont finies |backward|trigger|negated|10|Group[81]|Clement
# sont endigées |backward|trigger|negated|10|Group[81]|Clement
# ont cessées |backward|trigger|negated|10|Group[81]|Clement
# sont gelées |backward|trigger|negated|10|Group[81]|Clement
# sont coupées |backward|trigger|negated|10|Group[81]|Clement
# est arrêté |backward|trigger|negated|10|Group[81]|Clement
# est stoppé |backward|trigger|negated|10|Group[81]|Clement
# est enrayé |backward|trigger|negated|10|Group[81]|Clement
# est contenu |backward|trigger|negated|10|Group[81]|Clement
# est suspendu |backward|trigger|negated|10|Group[81]|Clement
# est jugulé |backward|trigger|negated|10|Group[81]|Clement
# est terminé |backward|trigger|negated|10|Group[81]|Clement
# est immobilisé |backward|trigger|negated|10|Group[81]|Clement
# est fini |backward|trigger|negated|10|Group[81]|Clement
# est endigé |backward|trigger|negated|10|Group[81]|Clement
# a cessé |backward|trigger|negated|10|Group[81]|Clement
# est gelé |backward|trigger|negated|10|Group[81]|Clement
# est coupé |backward|trigger|negated|10|Group[81]|Clement
# est arrêtée |backward|trigger|negated|10|Group[81]|Clement
# est stoppée |backward|trigger|negated|10|Group[81]|Clement
# est enrayée |backward|trigger|negated|10|Group[81]|Clement
# est contenue |backward|trigger|negated|10|Group[81]|Clement
# est suspendue |backward|trigger|negated|10|Group[81]|Clement
# est jugulée |backward|trigger|negated|10|Group[81]|Clement
# est terminée |backward|trigger|negated|10|Group[81]|Clement
# est immobilisée |backward|trigger|negated|10|Group[81]|Clement
# est finie |backward|trigger|negated|10|Group[81]|Clement
# est endigée |backward|trigger|negated|10|Group[81]|Clement
# est gelée |backward|trigger|negated|10|Group[81]|Clement
# est coupée |backward|trigger|negated|10|Group[81]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Termin Var2 Trigger_Rule
Var1 -> "origine" | "début" | "commencement" | "provenance" | "cause" | "formation" | "base" | "fondement" | "prédéterminant" | "raison" | "départ" | "étiologie" | "causalité" | "source" | "point de départ" | "prétexte" | "déclencheur" | "mobile" | "explication"
Termin -> "_s"  
Var2 -> "de" | "pour" | "d'"
Trigger_Rule -> "|forward|termination|negated|10|Group[84]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# origine _s de |forward|termination|negated|10|Group[84]|Clement
# origine _s pour |forward|termination|negated|10|Group[84]|Clement
# origine _s d' |forward|termination|negated|10|Group[84]|Clement
# début _s de |forward|termination|negated|10|Group[84]|Clement
# début _s pour |forward|termination|negated|10|Group[84]|Clement
# début _s d' |forward|termination|negated|10|Group[84]|Clement
# commencement _s de |forward|termination|negated|10|Group[84]|Clement
# commencement _s pour |forward|termination|negated|10|Group[84]|Clement
# commencement _s d' |forward|termination|negated|10|Group[84]|Clement
# provenance _s de |forward|termination|negated|10|Group[84]|Clement
# provenance _s pour |forward|termination|negated|10|Group[84]|Clement
# provenance _s d' |forward|termination|negated|10|Group[84]|Clement
# cause _s de |forward|termination|negated|10|Group[84]|Clement
# cause _s pour |forward|termination|negated|10|Group[84]|Clement
# cause _s d' |forward|termination|negated|10|Group[84]|Clement
# formation _s de |forward|termination|negated|10|Group[84]|Clement
# formation _s pour |forward|termination|negated|10|Group[84]|Clement
# formation _s d' |forward|termination|negated|10|Group[84]|Clement
# base _s de |forward|termination|negated|10|Group[84]|Clement
# base _s pour |forward|termination|negated|10|Group[84]|Clement
# base _s d' |forward|termination|negated|10|Group[84]|Clement
# fondement _s de |forward|termination|negated|10|Group[84]|Clement
# fondement _s pour |forward|termination|negated|10|Group[84]|Clement
# fondement _s d' |forward|termination|negated|10|Group[84]|Clement
# prédéterminant _s de |forward|termination|negated|10|Group[84]|Clement
# prédéterminant _s pour |forward|termination|negated|10|Group[84]|Clement
# prédéterminant _s d' |forward|termination|negated|10|Group[84]|Clement
# raison _s de |forward|termination|negated|10|Group[84]|Clement
# raison _s pour |forward|termination|negated|10|Group[84]|Clement
# raison _s d' |forward|termination|negated|10|Group[84]|Clement
# départ _s de |forward|termination|negated|10|Group[84]|Clement
# départ _s pour |forward|termination|negated|10|Group[84]|Clement
# départ _s d' |forward|termination|negated|10|Group[84]|Clement
# étiologie _s de |forward|termination|negated|10|Group[84]|Clement
# étiologie _s pour |forward|termination|negated|10|Group[84]|Clement
# étiologie _s d' |forward|termination|negated|10|Group[84]|Clement
# causalité _s de |forward|termination|negated|10|Group[84]|Clement
# causalité _s pour |forward|termination|negated|10|Group[84]|Clement
# causalité _s d' |forward|termination|negated|10|Group[84]|Clement
# source _s de |forward|termination|negated|10|Group[84]|Clement
# source _s pour |forward|termination|negated|10|Group[84]|Clement
# source _s d' |forward|termination|negated|10|Group[84]|Clement
# point de départ _s de |forward|termination|negated|10|Group[84]|Clement
# point de départ _s pour |forward|termination|negated|10|Group[84]|Clement
# point de départ _s d' |forward|termination|negated|10|Group[84]|Clement
# prétexte _s de |forward|termination|negated|10|Group[84]|Clement
# prétexte _s pour |forward|termination|negated|10|Group[84]|Clement
# prétexte _s d' |forward|termination|negated|10|Group[84]|Clement
# déclencheur _s de |forward|termination|negated|10|Group[84]|Clement
# déclencheur _s pour |forward|termination|negated|10|Group[84]|Clement
# déclencheur _s d' |forward|termination|negated|10|Group[84]|Clement
# mobile _s de |forward|termination|negated|10|Group[84]|Clement
# mobile _s pour |forward|termination|negated|10|Group[84]|Clement
# mobile _s d' |forward|termination|negated|10|Group[84]|Clement
# explication _s de |forward|termination|negated|10|Group[84]|Clement
# explication _s pour |forward|termination|negated|10|Group[84]|Clement
# explication _s d' |forward|termination|negated|10|Group[84]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "comme"
Var2 -> "l'origine" | "le début" | "le commencement" | "la provenance" | "la cause" | "la formation" | "la base" | "le fondement" | "le prédéterminant" | "la raison" | "le départ" | "l'étiologie" | "la causalité" | "la source" | "le point de départ" | "le prétexte" | "le déclencheur" | "le mobile" | "l'explication" |"une origine" | "un début" | "un commencement" | "une provenance" | "une cause" | "une formation" | "une base" | "un fondement" | "un prédéterminant" | "une raison" | "un départ" | "une étiologie" | "une causalité" | "une source" | "un point de départ" | "un prétexte" | "un déclencheur" | "un mobile" | "une explication"
Var3 -> "de" | "pour" |"d'"
Trigger_Rule -> "|forward|termination|negated|10|Group[84]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# comme l'origine de |forward|termination|negated|10|Group[84]|Clement
# comme l'origine pour |forward|termination|negated|10|Group[84]|Clement
# comme l'origine d' |forward|termination|negated|10|Group[84]|Clement
# comme le début de |forward|termination|negated|10|Group[84]|Clement
# comme le début pour |forward|termination|negated|10|Group[84]|Clement
# comme le début d' |forward|termination|negated|10|Group[84]|Clement
# comme le commencement de |forward|termination|negated|10|Group[84]|Clement
# comme le commencement pour |forward|termination|negated|10|Group[84]|Clement
# comme le commencement d' |forward|termination|negated|10|Group[84]|Clement
# comme la provenance de |forward|termination|negated|10|Group[84]|Clement
# comme la provenance pour |forward|termination|negated|10|Group[84]|Clement
# comme la provenance d' |forward|termination|negated|10|Group[84]|Clement
# comme la cause de |forward|termination|negated|10|Group[84]|Clement
# comme la cause pour |forward|termination|negated|10|Group[84]|Clement
# comme la cause d' |forward|termination|negated|10|Group[84]|Clement
# comme la formation de |forward|termination|negated|10|Group[84]|Clement
# comme la formation pour |forward|termination|negated|10|Group[84]|Clement
# comme la formation d' |forward|termination|negated|10|Group[84]|Clement
# comme la base de |forward|termination|negated|10|Group[84]|Clement
# comme la base pour |forward|termination|negated|10|Group[84]|Clement
# comme la base d' |forward|termination|negated|10|Group[84]|Clement
# comme le fondement de |forward|termination|negated|10|Group[84]|Clement
# comme le fondement pour |forward|termination|negated|10|Group[84]|Clement
# comme le fondement d' |forward|termination|negated|10|Group[84]|Clement
# comme le prédéterminant de |forward|termination|negated|10|Group[84]|Clement
# comme le prédéterminant pour |forward|termination|negated|10|Group[84]|Clement
# comme le prédéterminant d' |forward|termination|negated|10|Group[84]|Clement
# comme la raison de |forward|termination|negated|10|Group[84]|Clement
# comme la raison pour |forward|termination|negated|10|Group[84]|Clement
# comme la raison d' |forward|termination|negated|10|Group[84]|Clement
# comme le départ de |forward|termination|negated|10|Group[84]|Clement
# comme le départ pour |forward|termination|negated|10|Group[84]|Clement
# comme le départ d' |forward|termination|negated|10|Group[84]|Clement
# comme l'étiologie de |forward|termination|negated|10|Group[84]|Clement
# comme l'étiologie pour |forward|termination|negated|10|Group[84]|Clement
# comme l'étiologie d' |forward|termination|negated|10|Group[84]|Clement
# comme la causalité de |forward|termination|negated|10|Group[84]|Clement
# comme la causalité pour |forward|termination|negated|10|Group[84]|Clement
# comme la causalité d' |forward|termination|negated|10|Group[84]|Clement
# comme la source de |forward|termination|negated|10|Group[84]|Clement
# comme la source pour |forward|termination|negated|10|Group[84]|Clement
# comme la source d' |forward|termination|negated|10|Group[84]|Clement
# comme le point de départ de |forward|termination|negated|10|Group[84]|Clement
# comme le point de départ pour |forward|termination|negated|10|Group[84]|Clement
# comme le point de départ d' |forward|termination|negated|10|Group[84]|Clement
# comme le prétexte de |forward|termination|negated|10|Group[84]|Clement
# comme le prétexte pour |forward|termination|negated|10|Group[84]|Clement
# comme le prétexte d' |forward|termination|negated|10|Group[84]|Clement
# comme le déclencheur de |forward|termination|negated|10|Group[84]|Clement
# comme le déclencheur pour |forward|termination|negated|10|Group[84]|Clement
# comme le déclencheur d' |forward|termination|negated|10|Group[84]|Clement
# comme le mobile de |forward|termination|negated|10|Group[84]|Clement
# comme le mobile pour |forward|termination|negated|10|Group[84]|Clement
# comme le mobile d' |forward|termination|negated|10|Group[84]|Clement
# comme l'explication de |forward|termination|negated|10|Group[84]|Clement
# comme l'explication pour |forward|termination|negated|10|Group[84]|Clement
# comme l'explication d' |forward|termination|negated|10|Group[84]|Clement
# comme une origine de |forward|termination|negated|10|Group[84]|Clement
# comme une origine pour |forward|termination|negated|10|Group[84]|Clement
# comme une origine d' |forward|termination|negated|10|Group[84]|Clement
# comme un début de |forward|termination|negated|10|Group[84]|Clement
# comme un début pour |forward|termination|negated|10|Group[84]|Clement
# comme un début d' |forward|termination|negated|10|Group[84]|Clement
# comme un commencement de |forward|termination|negated|10|Group[84]|Clement
# comme un commencement pour |forward|termination|negated|10|Group[84]|Clement
# comme un commencement d' |forward|termination|negated|10|Group[84]|Clement
# comme une provenance de |forward|termination|negated|10|Group[84]|Clement
# comme une provenance pour |forward|termination|negated|10|Group[84]|Clement
# comme une provenance d' |forward|termination|negated|10|Group[84]|Clement
# comme une cause de |forward|termination|negated|10|Group[84]|Clement
# comme une cause pour |forward|termination|negated|10|Group[84]|Clement
# comme une cause d' |forward|termination|negated|10|Group[84]|Clement
# comme une formation de |forward|termination|negated|10|Group[84]|Clement
# comme une formation pour |forward|termination|negated|10|Group[84]|Clement
# comme une formation d' |forward|termination|negated|10|Group[84]|Clement
# comme une base de |forward|termination|negated|10|Group[84]|Clement
# comme une base pour |forward|termination|negated|10|Group[84]|Clement
# comme une base d' |forward|termination|negated|10|Group[84]|Clement
# comme un fondement de |forward|termination|negated|10|Group[84]|Clement
# comme un fondement pour |forward|termination|negated|10|Group[84]|Clement
# comme un fondement d' |forward|termination|negated|10|Group[84]|Clement
# comme un prédéterminant de |forward|termination|negated|10|Group[84]|Clement
# comme un prédéterminant pour |forward|termination|negated|10|Group[84]|Clement
# comme un prédéterminant d' |forward|termination|negated|10|Group[84]|Clement
# comme une raison de |forward|termination|negated|10|Group[84]|Clement
# comme une raison pour |forward|termination|negated|10|Group[84]|Clement
# comme une raison d' |forward|termination|negated|10|Group[84]|Clement
# comme un départ de |forward|termination|negated|10|Group[84]|Clement
# comme un départ pour |forward|termination|negated|10|Group[84]|Clement
# comme un départ d' |forward|termination|negated|10|Group[84]|Clement
# comme une étiologie de |forward|termination|negated|10|Group[84]|Clement
# comme une étiologie pour |forward|termination|negated|10|Group[84]|Clement
# comme une étiologie d' |forward|termination|negated|10|Group[84]|Clement
# comme une causalité de |forward|termination|negated|10|Group[84]|Clement
# comme une causalité pour |forward|termination|negated|10|Group[84]|Clement
# comme une causalité d' |forward|termination|negated|10|Group[84]|Clement
# comme une source de |forward|termination|negated|10|Group[84]|Clement
# comme une source pour |forward|termination|negated|10|Group[84]|Clement
# comme une source d' |forward|termination|negated|10|Group[84]|Clement
# comme un point de départ de |forward|termination|negated|10|Group[84]|Clement
# comme un point de départ pour |forward|termination|negated|10|Group[84]|Clement
# comme un point de départ d' |forward|termination|negated|10|Group[84]|Clement
# comme un prétexte de |forward|termination|negated|10|Group[84]|Clement
# comme un prétexte pour |forward|termination|negated|10|Group[84]|Clement
# comme un prétexte d' |forward|termination|negated|10|Group[84]|Clement
# comme un déclencheur de |forward|termination|negated|10|Group[84]|Clement
# comme un déclencheur pour |forward|termination|negated|10|Group[84]|Clement
# comme un déclencheur d' |forward|termination|negated|10|Group[84]|Clement
# comme un mobile de |forward|termination|negated|10|Group[84]|Clement
# comme un mobile pour |forward|termination|negated|10|Group[84]|Clement
# comme un mobile d' |forward|termination|negated|10|Group[84]|Clement
# comme une explication de |forward|termination|negated|10|Group[84]|Clement
# comme une explication pour |forward|termination|negated|10|Group[84]|Clement
# comme une explication d' |forward|termination|negated|10|Group[84]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "comme"
Var2 -> "pour" | "pourquoi"
Trigger_Rule -> "|forward|termination|negated|10|Group[84]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# comme pour |forward|termination|negated|10|Group[84]|Clement
# comme pourquoi |forward|termination|negated|10|Group[84]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "comme"
Var2 -> "origine" | "début" | "commencement" | "provenance" | "cause" | "formation" | "base" | "fondement" | "prédéterminant" | "raison" | "départ" | "étiologie" | "causalité" | "source" | "point de départ" | "prétexte" | "déclencheur" | "mobile" | "explication" |
Var3 -> "\\w+"
Var4 -> "de" | "pour"
Trigger_Rule -> "|forward|termination|negated|10|Group[90]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# comme origine \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme origine \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme début \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme début \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme commencement \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme commencement \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme provenance \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme provenance \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme cause \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme cause \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme formation \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme formation \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme base \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme base \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme fondement \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme fondement \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme prédéterminant \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme prédéterminant \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme raison \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme raison \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme départ \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme départ \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme étiologie \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme étiologie \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme causalité \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme causalité \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme source \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme source \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme point de départ \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme point de départ \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme prétexte \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme prétexte \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme déclencheur \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme déclencheur \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme mobile \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme mobile \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme explication \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme explication \w+ pour |forward|termination|negated|10|Group[90]|Clement
# comme \w+ de |forward|termination|negated|10|Group[90]|Clement
# comme \w+ pour |forward|termination|negated|10|Group[90]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Article Trigger_Rule
Var1 -> "comme"
Article -> "l'" | "le" | "la" | "un" | "une"
Trigger_Rule -> "|forward|termination|negated|10|Group[122]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# comme l' |forward|termination|negated|10|Group[122]|Clement
# comme le |forward|termination|negated|10|Group[122]|Clement
# comme la |forward|termination|negated|10|Group[122]|Clement
# comme un |forward|termination|negated|10|Group[122]|Clement
# comme une |forward|termination|negated|10|Group[122]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "comme" | "tel que"
Var2 -> "requis" | "nécessaire" | "prescrit" | "demandé" | "réclamé" | "souhaitable" | "sollicité" | "commandé" | "nécessité" | "souhaité" | "enjoint"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[123]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# comme requis |forward|trigger|conditional|30|Group[123]|Clement
# comme nécessaire |forward|trigger|conditional|30|Group[123]|Clement
# comme prescrit |forward|trigger|conditional|30|Group[123]|Clement
# comme demandé |forward|trigger|conditional|30|Group[123]|Clement
# comme réclamé |forward|trigger|conditional|30|Group[123]|Clement
# comme souhaitable |forward|trigger|conditional|30|Group[123]|Clement
# comme sollicité |forward|trigger|conditional|30|Group[123]|Clement
# comme commandé |forward|trigger|conditional|30|Group[123]|Clement
# comme nécessité |forward|trigger|conditional|30|Group[123]|Clement
# comme souhaité |forward|trigger|conditional|30|Group[123]|Clement
# comme enjoint |forward|trigger|conditional|30|Group[123]|Clement
# tel que requis |forward|trigger|conditional|30|Group[123]|Clement
# tel que nécessaire |forward|trigger|conditional|30|Group[123]|Clement
# tel que prescrit |forward|trigger|conditional|30|Group[123]|Clement
# tel que demandé |forward|trigger|conditional|30|Group[123]|Clement
# tel que réclamé |forward|trigger|conditional|30|Group[123]|Clement
# tel que souhaitable |forward|trigger|conditional|30|Group[123]|Clement
# tel que sollicité |forward|trigger|conditional|30|Group[123]|Clement
# tel que commandé |forward|trigger|conditional|30|Group[123]|Clement
# tel que nécessité |forward|trigger|conditional|30|Group[123]|Clement
# tel que souhaité |forward|trigger|conditional|30|Group[123]|Clement
# tel que enjoint |forward|trigger|conditional|30|Group[123]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Deter Trigger_Rule
Var1 -> "ainsi"
Var2 -> "que"
Deter -> "tout" | "tous" | "toute" | "toutes"
Trigger_Rule -> "|forward|trigger|negated|10|Group[144]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ainsi que tout |forward|trigger|negated|10|Group[144]|Clement
# ainsi que tous |forward|trigger|negated|10|Group[144]|Clement
# ainsi que toute |forward|trigger|negated|10|Group[144]|Clement
# ainsi que toutes |forward|trigger|negated|10|Group[144]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "à"
Var2 -> "part" | "l'exception"
Trigger_Rule -> "|forward|termination|negated|10|Group[146]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# à part |forward|termination|negated|10|Group[146]|Clement
# à l'exception |forward|termination|negated|10|Group[146]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "comme" | "ainsi"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[147]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# comme |both|pseudo|uncertain|30|Group[147]|Clement
# ainsi |both|pseudo|uncertain|30|Group[147]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "en" | "à" 
Var2 -> "ce"
Var3 -> "moment" | "jour" | "temps" | "stage" | "stade"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[148]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# en ce moment |both|pseudo|uncertain|30|Group[148]|Clement
# en ce jour |both|pseudo|uncertain|30|Group[148]|Clement
# en ce temps |both|pseudo|uncertain|30|Group[148]|Clement
# en ce stage |both|pseudo|uncertain|30|Group[148]|Clement
# en ce stade |both|pseudo|uncertain|30|Group[148]|Clement
# à ce moment |both|pseudo|uncertain|30|Group[148]|Clement
# à ce jour |both|pseudo|uncertain|30|Group[148]|Clement
# à ce temps |both|pseudo|uncertain|30|Group[148]|Clement
# à ce stage |both|pseudo|uncertain|30|Group[148]|Clement
# à ce stade |both|pseudo|uncertain|30|Group[148]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "en" | "à" 
Var2 -> "cet"
Var3 -> "épisode"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[148]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# en cet épisode |both|pseudo|uncertain|30|Group[148]|Clement
# à cet épisode |both|pseudo|uncertain|30|Group[148]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "en" | "à" 
Var2 -> "cette"
Var3 -> "saison" | "époque" | "phase" | "plage de temps"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[148]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# en cette saison |both|pseudo|uncertain|30|Group[148]|Clement
# en cette époque |both|pseudo|uncertain|30|Group[148]|Clement
# en cette phase |both|pseudo|uncertain|30|Group[148]|Clement
# en cette plage de temps |both|pseudo|uncertain|30|Group[148]|Clement
# à cette saison |both|pseudo|uncertain|30|Group[148]|Clement
# à cette époque |both|pseudo|uncertain|30|Group[148]|Clement
# à cette phase |both|pseudo|uncertain|30|Group[148]|Clement
# à cette plage de temps |both|pseudo|uncertain|30|Group[148]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> "pendant que"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[148]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pendant que |both|pseudo|uncertain|30|Group[148]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "tenté" | "expérimenté" | "risqué" | "cherché" | "entrepris" | "osé" | "hasardé"
Trigger_Rule -> "|both|termination|historical|30|Group[150]|Clement"|"|both|termination|nonpatient|30|Group[151]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# tenté |both|termination|historical|30|Group[150]|Clement
# tenté |both|termination|nonpatient|30|Group[151]|Clement
# expérimenté |both|termination|historical|30|Group[150]|Clement
# expérimenté |both|termination|nonpatient|30|Group[151]|Clement
# risqué |both|termination|historical|30|Group[150]|Clement
# risqué |both|termination|nonpatient|30|Group[151]|Clement
# cherché |both|termination|historical|30|Group[150]|Clement
# cherché |both|termination|nonpatient|30|Group[151]|Clement
# entrepris |both|termination|historical|30|Group[150]|Clement
# entrepris |both|termination|nonpatient|30|Group[151]|Clement
# osé |both|termination|historical|30|Group[150]|Clement
# osé |both|termination|nonpatient|30|Group[151]|Clement
# hasardé |both|termination|historical|30|Group[150]|Clement
# hasardé |both|termination|nonpatient|30|Group[151]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "tentative" | "expérience" | "expérimentation"
Trigger_Rule -> "|both|termination|historical|30|Group[152]|Clement"|"|both|termination|nonpatient|30|Group[153]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# tentative |both|termination|historical|30|Group[152]|Clement
# tentative |both|termination|nonpatient|30|Group[153]|Clement
# expérience |both|termination|historical|30|Group[152]|Clement
# expérience |both|termination|nonpatient|30|Group[153]|Clement
# expérimentation |both|termination|historical|30|Group[152]|Clement
# expérimentation |both|termination|nonpatient|30|Group[153]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> "par la famille" |"par \\w+ famille"
Trigger_Rule -> "|both|termination|nonpatient|30|Group[234]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# par la famille |both|termination|nonpatient|30|Group[234]|Clement
# par \w+ famille |both|termination|nonpatient|30|Group[234]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Member Var1 Trigger_Rule
Member -> "parent a" | "parents ont" | "père a" | "beau-père a" | "mère a" |"belle-mère a" | "papa a" | "maman a" |"fils a" | "fils ont" |"beau-fils a" | "beau-fils ont" |"fils a" | "fils ont" | "garçon a" | "garçcons ont" | "fille a" | "filles ont" | "belle-fille a" | "belle-filles ont" | "frère a" | "frères ont" |"soeur a" | "soeurs ont" |"sœur a" |"sœurs ont" | "oncle a" | "tonton a" |"grand-mère a" | "grand-père a" |"tante a" | "tata a"|"cousin a" |"cousins ont" |"famille a" |"colocataire a" | "colocataires ont"|"voisin a"|"voisins ont"  
Var1 -> "rapporté" |"appelé" | "dit" |"déclaré" |"trouvé" | "signalé" | "sollicité" | "requéri" | "téléphoné" | "averti" | "prévenu" | "alerté"
Trigger_Rule -> "|both|termination|nonpatient|30|Group[234]|Clement" | "|both|termination|historical|30|Group[234]|Clement"|"|both|termination|nonpatient|30|Group[153]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# parent a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# parent a rapporté |both|termination|historical|30|Group[234]|Clement
# parent a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# parent a appelé |both|termination|nonpatient|30|Group[234]|Clement
# parent a appelé |both|termination|historical|30|Group[234]|Clement
# parent a appelé |both|termination|nonpatient|30|Group[153]|Clement
# parent a dit |both|termination|nonpatient|30|Group[234]|Clement
# parent a dit |both|termination|historical|30|Group[234]|Clement
# parent a dit |both|termination|nonpatient|30|Group[153]|Clement
# parent a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# parent a déclaré |both|termination|historical|30|Group[234]|Clement
# parent a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# parent a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# parent a trouvé |both|termination|historical|30|Group[234]|Clement
# parent a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# parent a signalé |both|termination|nonpatient|30|Group[234]|Clement
# parent a signalé |both|termination|historical|30|Group[234]|Clement
# parent a signalé |both|termination|nonpatient|30|Group[153]|Clement
# parent a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# parent a sollicité |both|termination|historical|30|Group[234]|Clement
# parent a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# parent a requéri |both|termination|nonpatient|30|Group[234]|Clement
# parent a requéri |both|termination|historical|30|Group[234]|Clement
# parent a requéri |both|termination|nonpatient|30|Group[153]|Clement
# parent a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# parent a téléphoné |both|termination|historical|30|Group[234]|Clement
# parent a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# parent a averti |both|termination|nonpatient|30|Group[234]|Clement
# parent a averti |both|termination|historical|30|Group[234]|Clement
# parent a averti |both|termination|nonpatient|30|Group[153]|Clement
# parent a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# parent a prévenu |both|termination|historical|30|Group[234]|Clement
# parent a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# parent a alerté |both|termination|nonpatient|30|Group[234]|Clement
# parent a alerté |both|termination|historical|30|Group[234]|Clement
# parent a alerté |both|termination|nonpatient|30|Group[153]|Clement
# parents ont rapporté |both|termination|nonpatient|30|Group[234]|Clement
# parents ont rapporté |both|termination|historical|30|Group[234]|Clement
# parents ont rapporté |both|termination|nonpatient|30|Group[153]|Clement
# parents ont appelé |both|termination|nonpatient|30|Group[234]|Clement
# parents ont appelé |both|termination|historical|30|Group[234]|Clement
# parents ont appelé |both|termination|nonpatient|30|Group[153]|Clement
# parents ont dit |both|termination|nonpatient|30|Group[234]|Clement
# parents ont dit |both|termination|historical|30|Group[234]|Clement
# parents ont dit |both|termination|nonpatient|30|Group[153]|Clement
# parents ont déclaré |both|termination|nonpatient|30|Group[234]|Clement
# parents ont déclaré |both|termination|historical|30|Group[234]|Clement
# parents ont déclaré |both|termination|nonpatient|30|Group[153]|Clement
# parents ont trouvé |both|termination|nonpatient|30|Group[234]|Clement
# parents ont trouvé |both|termination|historical|30|Group[234]|Clement
# parents ont trouvé |both|termination|nonpatient|30|Group[153]|Clement
# parents ont signalé |both|termination|nonpatient|30|Group[234]|Clement
# parents ont signalé |both|termination|historical|30|Group[234]|Clement
# parents ont signalé |both|termination|nonpatient|30|Group[153]|Clement
# parents ont sollicité |both|termination|nonpatient|30|Group[234]|Clement
# parents ont sollicité |both|termination|historical|30|Group[234]|Clement
# parents ont sollicité |both|termination|nonpatient|30|Group[153]|Clement
# parents ont requéri |both|termination|nonpatient|30|Group[234]|Clement
# parents ont requéri |both|termination|historical|30|Group[234]|Clement
# parents ont requéri |both|termination|nonpatient|30|Group[153]|Clement
# parents ont téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# parents ont téléphoné |both|termination|historical|30|Group[234]|Clement
# parents ont téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# parents ont averti |both|termination|nonpatient|30|Group[234]|Clement
# parents ont averti |both|termination|historical|30|Group[234]|Clement
# parents ont averti |both|termination|nonpatient|30|Group[153]|Clement
# parents ont prévenu |both|termination|nonpatient|30|Group[234]|Clement
# parents ont prévenu |both|termination|historical|30|Group[234]|Clement
# parents ont prévenu |both|termination|nonpatient|30|Group[153]|Clement
# parents ont alerté |both|termination|nonpatient|30|Group[234]|Clement
# parents ont alerté |both|termination|historical|30|Group[234]|Clement
# parents ont alerté |both|termination|nonpatient|30|Group[153]|Clement
# père a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# père a rapporté |both|termination|historical|30|Group[234]|Clement
# père a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# père a appelé |both|termination|nonpatient|30|Group[234]|Clement
# père a appelé |both|termination|historical|30|Group[234]|Clement
# père a appelé |both|termination|nonpatient|30|Group[153]|Clement
# père a dit |both|termination|nonpatient|30|Group[234]|Clement
# père a dit |both|termination|historical|30|Group[234]|Clement
# père a dit |both|termination|nonpatient|30|Group[153]|Clement
# père a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# père a déclaré |both|termination|historical|30|Group[234]|Clement
# père a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# père a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# père a trouvé |both|termination|historical|30|Group[234]|Clement
# père a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# père a signalé |both|termination|nonpatient|30|Group[234]|Clement
# père a signalé |both|termination|historical|30|Group[234]|Clement
# père a signalé |both|termination|nonpatient|30|Group[153]|Clement
# père a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# père a sollicité |both|termination|historical|30|Group[234]|Clement
# père a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# père a requéri |both|termination|nonpatient|30|Group[234]|Clement
# père a requéri |both|termination|historical|30|Group[234]|Clement
# père a requéri |both|termination|nonpatient|30|Group[153]|Clement
# père a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# père a téléphoné |both|termination|historical|30|Group[234]|Clement
# père a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# père a averti |both|termination|nonpatient|30|Group[234]|Clement
# père a averti |both|termination|historical|30|Group[234]|Clement
# père a averti |both|termination|nonpatient|30|Group[153]|Clement
# père a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# père a prévenu |both|termination|historical|30|Group[234]|Clement
# père a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# père a alerté |both|termination|nonpatient|30|Group[234]|Clement
# père a alerté |both|termination|historical|30|Group[234]|Clement
# père a alerté |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a rapporté |both|termination|historical|30|Group[234]|Clement
# beau-père a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a appelé |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a appelé |both|termination|historical|30|Group[234]|Clement
# beau-père a appelé |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a dit |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a dit |both|termination|historical|30|Group[234]|Clement
# beau-père a dit |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a déclaré |both|termination|historical|30|Group[234]|Clement
# beau-père a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a trouvé |both|termination|historical|30|Group[234]|Clement
# beau-père a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a signalé |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a signalé |both|termination|historical|30|Group[234]|Clement
# beau-père a signalé |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a sollicité |both|termination|historical|30|Group[234]|Clement
# beau-père a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a requéri |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a requéri |both|termination|historical|30|Group[234]|Clement
# beau-père a requéri |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a téléphoné |both|termination|historical|30|Group[234]|Clement
# beau-père a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a averti |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a averti |both|termination|historical|30|Group[234]|Clement
# beau-père a averti |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a prévenu |both|termination|historical|30|Group[234]|Clement
# beau-père a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# beau-père a alerté |both|termination|nonpatient|30|Group[234]|Clement
# beau-père a alerté |both|termination|historical|30|Group[234]|Clement
# beau-père a alerté |both|termination|nonpatient|30|Group[153]|Clement
# mère a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# mère a rapporté |both|termination|historical|30|Group[234]|Clement
# mère a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# mère a appelé |both|termination|nonpatient|30|Group[234]|Clement
# mère a appelé |both|termination|historical|30|Group[234]|Clement
# mère a appelé |both|termination|nonpatient|30|Group[153]|Clement
# mère a dit |both|termination|nonpatient|30|Group[234]|Clement
# mère a dit |both|termination|historical|30|Group[234]|Clement
# mère a dit |both|termination|nonpatient|30|Group[153]|Clement
# mère a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# mère a déclaré |both|termination|historical|30|Group[234]|Clement
# mère a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# mère a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# mère a trouvé |both|termination|historical|30|Group[234]|Clement
# mère a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# mère a signalé |both|termination|nonpatient|30|Group[234]|Clement
# mère a signalé |both|termination|historical|30|Group[234]|Clement
# mère a signalé |both|termination|nonpatient|30|Group[153]|Clement
# mère a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# mère a sollicité |both|termination|historical|30|Group[234]|Clement
# mère a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# mère a requéri |both|termination|nonpatient|30|Group[234]|Clement
# mère a requéri |both|termination|historical|30|Group[234]|Clement
# mère a requéri |both|termination|nonpatient|30|Group[153]|Clement
# mère a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# mère a téléphoné |both|termination|historical|30|Group[234]|Clement
# mère a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# mère a averti |both|termination|nonpatient|30|Group[234]|Clement
# mère a averti |both|termination|historical|30|Group[234]|Clement
# mère a averti |both|termination|nonpatient|30|Group[153]|Clement
# mère a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# mère a prévenu |both|termination|historical|30|Group[234]|Clement
# mère a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# mère a alerté |both|termination|nonpatient|30|Group[234]|Clement
# mère a alerté |both|termination|historical|30|Group[234]|Clement
# mère a alerté |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a rapporté |both|termination|historical|30|Group[234]|Clement
# belle-mère a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a appelé |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a appelé |both|termination|historical|30|Group[234]|Clement
# belle-mère a appelé |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a dit |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a dit |both|termination|historical|30|Group[234]|Clement
# belle-mère a dit |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a déclaré |both|termination|historical|30|Group[234]|Clement
# belle-mère a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a trouvé |both|termination|historical|30|Group[234]|Clement
# belle-mère a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a signalé |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a signalé |both|termination|historical|30|Group[234]|Clement
# belle-mère a signalé |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a sollicité |both|termination|historical|30|Group[234]|Clement
# belle-mère a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a requéri |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a requéri |both|termination|historical|30|Group[234]|Clement
# belle-mère a requéri |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a téléphoné |both|termination|historical|30|Group[234]|Clement
# belle-mère a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a averti |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a averti |both|termination|historical|30|Group[234]|Clement
# belle-mère a averti |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a prévenu |both|termination|historical|30|Group[234]|Clement
# belle-mère a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# belle-mère a alerté |both|termination|nonpatient|30|Group[234]|Clement
# belle-mère a alerté |both|termination|historical|30|Group[234]|Clement
# belle-mère a alerté |both|termination|nonpatient|30|Group[153]|Clement
# papa a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# papa a rapporté |both|termination|historical|30|Group[234]|Clement
# papa a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# papa a appelé |both|termination|nonpatient|30|Group[234]|Clement
# papa a appelé |both|termination|historical|30|Group[234]|Clement
# papa a appelé |both|termination|nonpatient|30|Group[153]|Clement
# papa a dit |both|termination|nonpatient|30|Group[234]|Clement
# papa a dit |both|termination|historical|30|Group[234]|Clement
# papa a dit |both|termination|nonpatient|30|Group[153]|Clement
# papa a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# papa a déclaré |both|termination|historical|30|Group[234]|Clement
# papa a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# papa a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# papa a trouvé |both|termination|historical|30|Group[234]|Clement
# papa a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# papa a signalé |both|termination|nonpatient|30|Group[234]|Clement
# papa a signalé |both|termination|historical|30|Group[234]|Clement
# papa a signalé |both|termination|nonpatient|30|Group[153]|Clement
# papa a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# papa a sollicité |both|termination|historical|30|Group[234]|Clement
# papa a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# papa a requéri |both|termination|nonpatient|30|Group[234]|Clement
# papa a requéri |both|termination|historical|30|Group[234]|Clement
# papa a requéri |both|termination|nonpatient|30|Group[153]|Clement
# papa a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# papa a téléphoné |both|termination|historical|30|Group[234]|Clement
# papa a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# papa a averti |both|termination|nonpatient|30|Group[234]|Clement
# papa a averti |both|termination|historical|30|Group[234]|Clement
# papa a averti |both|termination|nonpatient|30|Group[153]|Clement
# papa a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# papa a prévenu |both|termination|historical|30|Group[234]|Clement
# papa a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# papa a alerté |both|termination|nonpatient|30|Group[234]|Clement
# papa a alerté |both|termination|historical|30|Group[234]|Clement
# papa a alerté |both|termination|nonpatient|30|Group[153]|Clement
# maman a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# maman a rapporté |both|termination|historical|30|Group[234]|Clement
# maman a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# maman a appelé |both|termination|nonpatient|30|Group[234]|Clement
# maman a appelé |both|termination|historical|30|Group[234]|Clement
# maman a appelé |both|termination|nonpatient|30|Group[153]|Clement
# maman a dit |both|termination|nonpatient|30|Group[234]|Clement
# maman a dit |both|termination|historical|30|Group[234]|Clement
# maman a dit |both|termination|nonpatient|30|Group[153]|Clement
# maman a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# maman a déclaré |both|termination|historical|30|Group[234]|Clement
# maman a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# maman a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# maman a trouvé |both|termination|historical|30|Group[234]|Clement
# maman a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# maman a signalé |both|termination|nonpatient|30|Group[234]|Clement
# maman a signalé |both|termination|historical|30|Group[234]|Clement
# maman a signalé |both|termination|nonpatient|30|Group[153]|Clement
# maman a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# maman a sollicité |both|termination|historical|30|Group[234]|Clement
# maman a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# maman a requéri |both|termination|nonpatient|30|Group[234]|Clement
# maman a requéri |both|termination|historical|30|Group[234]|Clement
# maman a requéri |both|termination|nonpatient|30|Group[153]|Clement
# maman a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# maman a téléphoné |both|termination|historical|30|Group[234]|Clement
# maman a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# maman a averti |both|termination|nonpatient|30|Group[234]|Clement
# maman a averti |both|termination|historical|30|Group[234]|Clement
# maman a averti |both|termination|nonpatient|30|Group[153]|Clement
# maman a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# maman a prévenu |both|termination|historical|30|Group[234]|Clement
# maman a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# maman a alerté |both|termination|nonpatient|30|Group[234]|Clement
# maman a alerté |both|termination|historical|30|Group[234]|Clement
# maman a alerté |both|termination|nonpatient|30|Group[153]|Clement
# fils a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# fils a rapporté |both|termination|historical|30|Group[234]|Clement
# fils a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# fils a appelé |both|termination|nonpatient|30|Group[234]|Clement
# fils a appelé |both|termination|historical|30|Group[234]|Clement
# fils a appelé |both|termination|nonpatient|30|Group[153]|Clement
# fils a dit |both|termination|nonpatient|30|Group[234]|Clement
# fils a dit |both|termination|historical|30|Group[234]|Clement
# fils a dit |both|termination|nonpatient|30|Group[153]|Clement
# fils a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# fils a déclaré |both|termination|historical|30|Group[234]|Clement
# fils a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# fils a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# fils a trouvé |both|termination|historical|30|Group[234]|Clement
# fils a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# fils a signalé |both|termination|nonpatient|30|Group[234]|Clement
# fils a signalé |both|termination|historical|30|Group[234]|Clement
# fils a signalé |both|termination|nonpatient|30|Group[153]|Clement
# fils a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# fils a sollicité |both|termination|historical|30|Group[234]|Clement
# fils a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# fils a requéri |both|termination|nonpatient|30|Group[234]|Clement
# fils a requéri |both|termination|historical|30|Group[234]|Clement
# fils a requéri |both|termination|nonpatient|30|Group[153]|Clement
# fils a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# fils a téléphoné |both|termination|historical|30|Group[234]|Clement
# fils a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# fils a averti |both|termination|nonpatient|30|Group[234]|Clement
# fils a averti |both|termination|historical|30|Group[234]|Clement
# fils a averti |both|termination|nonpatient|30|Group[153]|Clement
# fils a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# fils a prévenu |both|termination|historical|30|Group[234]|Clement
# fils a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# fils a alerté |both|termination|nonpatient|30|Group[234]|Clement
# fils a alerté |both|termination|historical|30|Group[234]|Clement
# fils a alerté |both|termination|nonpatient|30|Group[153]|Clement
# fils ont rapporté |both|termination|nonpatient|30|Group[234]|Clement
# fils ont rapporté |both|termination|historical|30|Group[234]|Clement
# fils ont rapporté |both|termination|nonpatient|30|Group[153]|Clement
# fils ont appelé |both|termination|nonpatient|30|Group[234]|Clement
# fils ont appelé |both|termination|historical|30|Group[234]|Clement
# fils ont appelé |both|termination|nonpatient|30|Group[153]|Clement
# fils ont dit |both|termination|nonpatient|30|Group[234]|Clement
# fils ont dit |both|termination|historical|30|Group[234]|Clement
# fils ont dit |both|termination|nonpatient|30|Group[153]|Clement
# fils ont déclaré |both|termination|nonpatient|30|Group[234]|Clement
# fils ont déclaré |both|termination|historical|30|Group[234]|Clement
# fils ont déclaré |both|termination|nonpatient|30|Group[153]|Clement
# fils ont trouvé |both|termination|nonpatient|30|Group[234]|Clement
# fils ont trouvé |both|termination|historical|30|Group[234]|Clement
# fils ont trouvé |both|termination|nonpatient|30|Group[153]|Clement
# fils ont signalé |both|termination|nonpatient|30|Group[234]|Clement
# fils ont signalé |both|termination|historical|30|Group[234]|Clement
# fils ont signalé |both|termination|nonpatient|30|Group[153]|Clement
# fils ont sollicité |both|termination|nonpatient|30|Group[234]|Clement
# fils ont sollicité |both|termination|historical|30|Group[234]|Clement
# fils ont sollicité |both|termination|nonpatient|30|Group[153]|Clement
# fils ont requéri |both|termination|nonpatient|30|Group[234]|Clement
# fils ont requéri |both|termination|historical|30|Group[234]|Clement
# fils ont requéri |both|termination|nonpatient|30|Group[153]|Clement
# fils ont téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# fils ont téléphoné |both|termination|historical|30|Group[234]|Clement
# fils ont téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# fils ont averti |both|termination|nonpatient|30|Group[234]|Clement
# fils ont averti |both|termination|historical|30|Group[234]|Clement
# fils ont averti |both|termination|nonpatient|30|Group[153]|Clement
# fils ont prévenu |both|termination|nonpatient|30|Group[234]|Clement
# fils ont prévenu |both|termination|historical|30|Group[234]|Clement
# fils ont prévenu |both|termination|nonpatient|30|Group[153]|Clement
# fils ont alerté |both|termination|nonpatient|30|Group[234]|Clement
# fils ont alerté |both|termination|historical|30|Group[234]|Clement
# fils ont alerté |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a rapporté |both|termination|historical|30|Group[234]|Clement
# beau-fils a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a appelé |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a appelé |both|termination|historical|30|Group[234]|Clement
# beau-fils a appelé |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a dit |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a dit |both|termination|historical|30|Group[234]|Clement
# beau-fils a dit |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a déclaré |both|termination|historical|30|Group[234]|Clement
# beau-fils a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a trouvé |both|termination|historical|30|Group[234]|Clement
# beau-fils a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a signalé |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a signalé |both|termination|historical|30|Group[234]|Clement
# beau-fils a signalé |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a sollicité |both|termination|historical|30|Group[234]|Clement
# beau-fils a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a requéri |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a requéri |both|termination|historical|30|Group[234]|Clement
# beau-fils a requéri |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a téléphoné |both|termination|historical|30|Group[234]|Clement
# beau-fils a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a averti |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a averti |both|termination|historical|30|Group[234]|Clement
# beau-fils a averti |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a prévenu |both|termination|historical|30|Group[234]|Clement
# beau-fils a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils a alerté |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils a alerté |both|termination|historical|30|Group[234]|Clement
# beau-fils a alerté |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont rapporté |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont rapporté |both|termination|historical|30|Group[234]|Clement
# beau-fils ont rapporté |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont appelé |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont appelé |both|termination|historical|30|Group[234]|Clement
# beau-fils ont appelé |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont dit |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont dit |both|termination|historical|30|Group[234]|Clement
# beau-fils ont dit |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont déclaré |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont déclaré |both|termination|historical|30|Group[234]|Clement
# beau-fils ont déclaré |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont trouvé |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont trouvé |both|termination|historical|30|Group[234]|Clement
# beau-fils ont trouvé |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont signalé |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont signalé |both|termination|historical|30|Group[234]|Clement
# beau-fils ont signalé |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont sollicité |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont sollicité |both|termination|historical|30|Group[234]|Clement
# beau-fils ont sollicité |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont requéri |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont requéri |both|termination|historical|30|Group[234]|Clement
# beau-fils ont requéri |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont téléphoné |both|termination|historical|30|Group[234]|Clement
# beau-fils ont téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont averti |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont averti |both|termination|historical|30|Group[234]|Clement
# beau-fils ont averti |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont prévenu |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont prévenu |both|termination|historical|30|Group[234]|Clement
# beau-fils ont prévenu |both|termination|nonpatient|30|Group[153]|Clement
# beau-fils ont alerté |both|termination|nonpatient|30|Group[234]|Clement
# beau-fils ont alerté |both|termination|historical|30|Group[234]|Clement
# beau-fils ont alerté |both|termination|nonpatient|30|Group[153]|Clement
# fils a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# fils a rapporté |both|termination|historical|30|Group[234]|Clement
# fils a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# fils a appelé |both|termination|nonpatient|30|Group[234]|Clement
# fils a appelé |both|termination|historical|30|Group[234]|Clement
# fils a appelé |both|termination|nonpatient|30|Group[153]|Clement
# fils a dit |both|termination|nonpatient|30|Group[234]|Clement
# fils a dit |both|termination|historical|30|Group[234]|Clement
# fils a dit |both|termination|nonpatient|30|Group[153]|Clement
# fils a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# fils a déclaré |both|termination|historical|30|Group[234]|Clement
# fils a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# fils a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# fils a trouvé |both|termination|historical|30|Group[234]|Clement
# fils a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# fils a signalé |both|termination|nonpatient|30|Group[234]|Clement
# fils a signalé |both|termination|historical|30|Group[234]|Clement
# fils a signalé |both|termination|nonpatient|30|Group[153]|Clement
# fils a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# fils a sollicité |both|termination|historical|30|Group[234]|Clement
# fils a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# fils a requéri |both|termination|nonpatient|30|Group[234]|Clement
# fils a requéri |both|termination|historical|30|Group[234]|Clement
# fils a requéri |both|termination|nonpatient|30|Group[153]|Clement
# fils a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# fils a téléphoné |both|termination|historical|30|Group[234]|Clement
# fils a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# fils a averti |both|termination|nonpatient|30|Group[234]|Clement
# fils a averti |both|termination|historical|30|Group[234]|Clement
# fils a averti |both|termination|nonpatient|30|Group[153]|Clement
# fils a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# fils a prévenu |both|termination|historical|30|Group[234]|Clement
# fils a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# fils a alerté |both|termination|nonpatient|30|Group[234]|Clement
# fils a alerté |both|termination|historical|30|Group[234]|Clement
# fils a alerté |both|termination|nonpatient|30|Group[153]|Clement
# fils ont rapporté |both|termination|nonpatient|30|Group[234]|Clement
# fils ont rapporté |both|termination|historical|30|Group[234]|Clement
# fils ont rapporté |both|termination|nonpatient|30|Group[153]|Clement
# fils ont appelé |both|termination|nonpatient|30|Group[234]|Clement
# fils ont appelé |both|termination|historical|30|Group[234]|Clement
# fils ont appelé |both|termination|nonpatient|30|Group[153]|Clement
# fils ont dit |both|termination|nonpatient|30|Group[234]|Clement
# fils ont dit |both|termination|historical|30|Group[234]|Clement
# fils ont dit |both|termination|nonpatient|30|Group[153]|Clement
# fils ont déclaré |both|termination|nonpatient|30|Group[234]|Clement
# fils ont déclaré |both|termination|historical|30|Group[234]|Clement
# fils ont déclaré |both|termination|nonpatient|30|Group[153]|Clement
# fils ont trouvé |both|termination|nonpatient|30|Group[234]|Clement
# fils ont trouvé |both|termination|historical|30|Group[234]|Clement
# fils ont trouvé |both|termination|nonpatient|30|Group[153]|Clement
# fils ont signalé |both|termination|nonpatient|30|Group[234]|Clement
# fils ont signalé |both|termination|historical|30|Group[234]|Clement
# fils ont signalé |both|termination|nonpatient|30|Group[153]|Clement
# fils ont sollicité |both|termination|nonpatient|30|Group[234]|Clement
# fils ont sollicité |both|termination|historical|30|Group[234]|Clement
# fils ont sollicité |both|termination|nonpatient|30|Group[153]|Clement
# fils ont requéri |both|termination|nonpatient|30|Group[234]|Clement
# fils ont requéri |both|termination|historical|30|Group[234]|Clement
# fils ont requéri |both|termination|nonpatient|30|Group[153]|Clement
# fils ont téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# fils ont téléphoné |both|termination|historical|30|Group[234]|Clement
# fils ont téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# fils ont averti |both|termination|nonpatient|30|Group[234]|Clement
# fils ont averti |both|termination|historical|30|Group[234]|Clement
# fils ont averti |both|termination|nonpatient|30|Group[153]|Clement
# fils ont prévenu |both|termination|nonpatient|30|Group[234]|Clement
# fils ont prévenu |both|termination|historical|30|Group[234]|Clement
# fils ont prévenu |both|termination|nonpatient|30|Group[153]|Clement
# fils ont alerté |both|termination|nonpatient|30|Group[234]|Clement
# fils ont alerté |both|termination|historical|30|Group[234]|Clement
# fils ont alerté |both|termination|nonpatient|30|Group[153]|Clement
# garçon a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# garçon a rapporté |both|termination|historical|30|Group[234]|Clement
# garçon a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# garçon a appelé |both|termination|nonpatient|30|Group[234]|Clement
# garçon a appelé |both|termination|historical|30|Group[234]|Clement
# garçon a appelé |both|termination|nonpatient|30|Group[153]|Clement
# garçon a dit |both|termination|nonpatient|30|Group[234]|Clement
# garçon a dit |both|termination|historical|30|Group[234]|Clement
# garçon a dit |both|termination|nonpatient|30|Group[153]|Clement
# garçon a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# garçon a déclaré |both|termination|historical|30|Group[234]|Clement
# garçon a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# garçon a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# garçon a trouvé |both|termination|historical|30|Group[234]|Clement
# garçon a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# garçon a signalé |both|termination|nonpatient|30|Group[234]|Clement
# garçon a signalé |both|termination|historical|30|Group[234]|Clement
# garçon a signalé |both|termination|nonpatient|30|Group[153]|Clement
# garçon a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# garçon a sollicité |both|termination|historical|30|Group[234]|Clement
# garçon a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# garçon a requéri |both|termination|nonpatient|30|Group[234]|Clement
# garçon a requéri |both|termination|historical|30|Group[234]|Clement
# garçon a requéri |both|termination|nonpatient|30|Group[153]|Clement
# garçon a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# garçon a téléphoné |both|termination|historical|30|Group[234]|Clement
# garçon a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# garçon a averti |both|termination|nonpatient|30|Group[234]|Clement
# garçon a averti |both|termination|historical|30|Group[234]|Clement
# garçon a averti |both|termination|nonpatient|30|Group[153]|Clement
# garçon a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# garçon a prévenu |both|termination|historical|30|Group[234]|Clement
# garçon a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# garçon a alerté |both|termination|nonpatient|30|Group[234]|Clement
# garçon a alerté |both|termination|historical|30|Group[234]|Clement
# garçon a alerté |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont rapporté |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont rapporté |both|termination|historical|30|Group[234]|Clement
# garçcons ont rapporté |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont appelé |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont appelé |both|termination|historical|30|Group[234]|Clement
# garçcons ont appelé |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont dit |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont dit |both|termination|historical|30|Group[234]|Clement
# garçcons ont dit |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont déclaré |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont déclaré |both|termination|historical|30|Group[234]|Clement
# garçcons ont déclaré |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont trouvé |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont trouvé |both|termination|historical|30|Group[234]|Clement
# garçcons ont trouvé |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont signalé |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont signalé |both|termination|historical|30|Group[234]|Clement
# garçcons ont signalé |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont sollicité |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont sollicité |both|termination|historical|30|Group[234]|Clement
# garçcons ont sollicité |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont requéri |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont requéri |both|termination|historical|30|Group[234]|Clement
# garçcons ont requéri |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont téléphoné |both|termination|historical|30|Group[234]|Clement
# garçcons ont téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont averti |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont averti |both|termination|historical|30|Group[234]|Clement
# garçcons ont averti |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont prévenu |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont prévenu |both|termination|historical|30|Group[234]|Clement
# garçcons ont prévenu |both|termination|nonpatient|30|Group[153]|Clement
# garçcons ont alerté |both|termination|nonpatient|30|Group[234]|Clement
# garçcons ont alerté |both|termination|historical|30|Group[234]|Clement
# garçcons ont alerté |both|termination|nonpatient|30|Group[153]|Clement
# fille a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# fille a rapporté |both|termination|historical|30|Group[234]|Clement
# fille a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# fille a appelé |both|termination|nonpatient|30|Group[234]|Clement
# fille a appelé |both|termination|historical|30|Group[234]|Clement
# fille a appelé |both|termination|nonpatient|30|Group[153]|Clement
# fille a dit |both|termination|nonpatient|30|Group[234]|Clement
# fille a dit |both|termination|historical|30|Group[234]|Clement
# fille a dit |both|termination|nonpatient|30|Group[153]|Clement
# fille a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# fille a déclaré |both|termination|historical|30|Group[234]|Clement
# fille a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# fille a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# fille a trouvé |both|termination|historical|30|Group[234]|Clement
# fille a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# fille a signalé |both|termination|nonpatient|30|Group[234]|Clement
# fille a signalé |both|termination|historical|30|Group[234]|Clement
# fille a signalé |both|termination|nonpatient|30|Group[153]|Clement
# fille a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# fille a sollicité |both|termination|historical|30|Group[234]|Clement
# fille a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# fille a requéri |both|termination|nonpatient|30|Group[234]|Clement
# fille a requéri |both|termination|historical|30|Group[234]|Clement
# fille a requéri |both|termination|nonpatient|30|Group[153]|Clement
# fille a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# fille a téléphoné |both|termination|historical|30|Group[234]|Clement
# fille a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# fille a averti |both|termination|nonpatient|30|Group[234]|Clement
# fille a averti |both|termination|historical|30|Group[234]|Clement
# fille a averti |both|termination|nonpatient|30|Group[153]|Clement
# fille a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# fille a prévenu |both|termination|historical|30|Group[234]|Clement
# fille a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# fille a alerté |both|termination|nonpatient|30|Group[234]|Clement
# fille a alerté |both|termination|historical|30|Group[234]|Clement
# fille a alerté |both|termination|nonpatient|30|Group[153]|Clement
# filles ont rapporté |both|termination|nonpatient|30|Group[234]|Clement
# filles ont rapporté |both|termination|historical|30|Group[234]|Clement
# filles ont rapporté |both|termination|nonpatient|30|Group[153]|Clement
# filles ont appelé |both|termination|nonpatient|30|Group[234]|Clement
# filles ont appelé |both|termination|historical|30|Group[234]|Clement
# filles ont appelé |both|termination|nonpatient|30|Group[153]|Clement
# filles ont dit |both|termination|nonpatient|30|Group[234]|Clement
# filles ont dit |both|termination|historical|30|Group[234]|Clement
# filles ont dit |both|termination|nonpatient|30|Group[153]|Clement
# filles ont déclaré |both|termination|nonpatient|30|Group[234]|Clement
# filles ont déclaré |both|termination|historical|30|Group[234]|Clement
# filles ont déclaré |both|termination|nonpatient|30|Group[153]|Clement
# filles ont trouvé |both|termination|nonpatient|30|Group[234]|Clement
# filles ont trouvé |both|termination|historical|30|Group[234]|Clement
# filles ont trouvé |both|termination|nonpatient|30|Group[153]|Clement
# filles ont signalé |both|termination|nonpatient|30|Group[234]|Clement
# filles ont signalé |both|termination|historical|30|Group[234]|Clement
# filles ont signalé |both|termination|nonpatient|30|Group[153]|Clement
# filles ont sollicité |both|termination|nonpatient|30|Group[234]|Clement
# filles ont sollicité |both|termination|historical|30|Group[234]|Clement
# filles ont sollicité |both|termination|nonpatient|30|Group[153]|Clement
# filles ont requéri |both|termination|nonpatient|30|Group[234]|Clement
# filles ont requéri |both|termination|historical|30|Group[234]|Clement
# filles ont requéri |both|termination|nonpatient|30|Group[153]|Clement
# filles ont téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# filles ont téléphoné |both|termination|historical|30|Group[234]|Clement
# filles ont téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# filles ont averti |both|termination|nonpatient|30|Group[234]|Clement
# filles ont averti |both|termination|historical|30|Group[234]|Clement
# filles ont averti |both|termination|nonpatient|30|Group[153]|Clement
# filles ont prévenu |both|termination|nonpatient|30|Group[234]|Clement
# filles ont prévenu |both|termination|historical|30|Group[234]|Clement
# filles ont prévenu |both|termination|nonpatient|30|Group[153]|Clement
# filles ont alerté |both|termination|nonpatient|30|Group[234]|Clement
# filles ont alerté |both|termination|historical|30|Group[234]|Clement
# filles ont alerté |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a rapporté |both|termination|historical|30|Group[234]|Clement
# belle-fille a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a appelé |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a appelé |both|termination|historical|30|Group[234]|Clement
# belle-fille a appelé |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a dit |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a dit |both|termination|historical|30|Group[234]|Clement
# belle-fille a dit |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a déclaré |both|termination|historical|30|Group[234]|Clement
# belle-fille a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a trouvé |both|termination|historical|30|Group[234]|Clement
# belle-fille a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a signalé |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a signalé |both|termination|historical|30|Group[234]|Clement
# belle-fille a signalé |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a sollicité |both|termination|historical|30|Group[234]|Clement
# belle-fille a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a requéri |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a requéri |both|termination|historical|30|Group[234]|Clement
# belle-fille a requéri |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a téléphoné |both|termination|historical|30|Group[234]|Clement
# belle-fille a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a averti |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a averti |both|termination|historical|30|Group[234]|Clement
# belle-fille a averti |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a prévenu |both|termination|historical|30|Group[234]|Clement
# belle-fille a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# belle-fille a alerté |both|termination|nonpatient|30|Group[234]|Clement
# belle-fille a alerté |both|termination|historical|30|Group[234]|Clement
# belle-fille a alerté |both|termination|nonpatient|30|Group[153]|Clement
# belle-filles ont rapporté |both|termination|nonpatient|30|Group[234]|Clement
# belle-filles ont rapporté |both|termination|historical|30|Group[234]|Clement
# belle-filles ont rapporté |both|termination|nonpatient|30|Group[153]|Clement
# belle-filles ont appelé |both|termination|nonpatient|30|Group[234]|Clement
# belle-filles ont appelé |both|termination|historical|30|Group[234]|Clement
# belle-filles ont appelé |both|termination|nonpatient|30|Group[153]|Clement
# belle-filles ont dit |both|termination|nonpatient|30|Group[234]|Clement
# belle-filles ont dit |both|termination|historical|30|Group[234]|Clement
# belle-filles ont dit |both|termination|nonpatient|30|Group[153]|Clement
# belle-filles ont déclaré |both|termination|nonpatient|30|Group[234]|Clement
# belle-filles ont déclaré |both|termination|historical|30|Group[234]|Clement
# belle-filles ont déclaré |both|termination|nonpatient|30|Group[153]|Clement
# belle-filles ont trouvé |both|termination|nonpatient|30|Group[234]|Clement
# ...
# frères ont déclaré |both|termination|nonpatient|30|Group[234]|Clement
# frères ont déclaré |both|termination|historical|30|Group[234]|Clement
# frères ont déclaré |both|termination|nonpatient|30|Group[153]|Clement
# frères ont trouvé |both|termination|nonpatient|30|Group[234]|Clement
# frères ont trouvé |both|termination|historical|30|Group[234]|Clement
# frères ont trouvé |both|termination|nonpatient|30|Group[153]|Clement
# frères ont signalé |both|termination|nonpatient|30|Group[234]|Clement
# frères ont signalé |both|termination|historical|30|Group[234]|Clement
# frères ont signalé |both|termination|nonpatient|30|Group[153]|Clement
# frères ont sollicité |both|termination|nonpatient|30|Group[234]|Clement
# frères ont sollicité |both|termination|historical|30|Group[234]|Clement
# frères ont sollicité |both|termination|nonpatient|30|Group[153]|Clement
# frères ont requéri |both|termination|nonpatient|30|Group[234]|Clement
# frères ont requéri |both|termination|historical|30|Group[234]|Clement
# frères ont requéri |both|termination|nonpatient|30|Group[153]|Clement
# frères ont téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# frères ont téléphoné |both|termination|historical|30|Group[234]|Clement
# frères ont téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# frères ont averti |both|termination|nonpatient|30|Group[234]|Clement
# frères ont averti |both|termination|historical|30|Group[234]|Clement
# frères ont averti |both|termination|nonpatient|30|Group[153]|Clement
# frères ont prévenu |both|termination|nonpatient|30|Group[234]|Clement
# frères ont prévenu |both|termination|historical|30|Group[234]|Clement
# frères ont prévenu |both|termination|nonpatient|30|Group[153]|Clement
# frères ont alerté |both|termination|nonpatient|30|Group[234]|Clement
# frères ont alerté |both|termination|historical|30|Group[234]|Clement
# frères ont alerté |both|termination|nonpatient|30|Group[153]|Clement
# soeur a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# soeur a rapporté |both|termination|historical|30|Group[234]|Clement
# soeur a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# soeur a appelé |both|termination|nonpatient|30|Group[234]|Clement
# soeur a appelé |both|termination|historical|30|Group[234]|Clement
# soeur a appelé |both|termination|nonpatient|30|Group[153]|Clement
# soeur a dit |both|termination|nonpatient|30|Group[234]|Clement
# soeur a dit |both|termination|historical|30|Group[234]|Clement
# soeur a dit |both|termination|nonpatient|30|Group[153]|Clement
# soeur a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# soeur a déclaré |both|termination|historical|30|Group[234]|Clement
# soeur a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# soeur a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# soeur a trouvé |both|termination|historical|30|Group[234]|Clement
# soeur a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# soeur a signalé |both|termination|nonpatient|30|Group[234]|Clement
# soeur a signalé |both|termination|historical|30|Group[234]|Clement
# soeur a signalé |both|termination|nonpatient|30|Group[153]|Clement
# soeur a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# soeur a sollicité |both|termination|historical|30|Group[234]|Clement
# soeur a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# soeur a requéri |both|termination|nonpatient|30|Group[234]|Clement
# soeur a requéri |both|termination|historical|30|Group[234]|Clement
# soeur a requéri |both|termination|nonpatient|30|Group[153]|Clement
# soeur a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# soeur a téléphoné |both|termination|historical|30|Group[234]|Clement
# soeur a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# soeur a averti |both|termination|nonpatient|30|Group[234]|Clement
# soeur a averti |both|termination|historical|30|Group[234]|Clement
# soeur a averti |both|termination|nonpatient|30|Group[153]|Clement
# soeur a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# soeur a prévenu |both|termination|historical|30|Group[234]|Clement
# soeur a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# soeur a alerté |both|termination|nonpatient|30|Group[234]|Clement
# soeur a alerté |both|termination|historical|30|Group[234]|Clement
# soeur a alerté |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont rapporté |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont rapporté |both|termination|historical|30|Group[234]|Clement
# soeurs ont rapporté |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont appelé |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont appelé |both|termination|historical|30|Group[234]|Clement
# soeurs ont appelé |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont dit |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont dit |both|termination|historical|30|Group[234]|Clement
# soeurs ont dit |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont déclaré |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont déclaré |both|termination|historical|30|Group[234]|Clement
# soeurs ont déclaré |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont trouvé |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont trouvé |both|termination|historical|30|Group[234]|Clement
# soeurs ont trouvé |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont signalé |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont signalé |both|termination|historical|30|Group[234]|Clement
# soeurs ont signalé |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont sollicité |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont sollicité |both|termination|historical|30|Group[234]|Clement
# soeurs ont sollicité |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont requéri |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont requéri |both|termination|historical|30|Group[234]|Clement
# soeurs ont requéri |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont téléphoné |both|termination|historical|30|Group[234]|Clement
# soeurs ont téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont averti |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont averti |both|termination|historical|30|Group[234]|Clement
# soeurs ont averti |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont prévenu |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont prévenu |both|termination|historical|30|Group[234]|Clement
# soeurs ont prévenu |both|termination|nonpatient|30|Group[153]|Clement
# soeurs ont alerté |both|termination|nonpatient|30|Group[234]|Clement
# soeurs ont alerté |both|termination|historical|30|Group[234]|Clement
# soeurs ont alerté |both|termination|nonpatient|30|Group[153]|Clement
# sœur a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# sœur a rapporté |both|termination|historical|30|Group[234]|Clement
# sœur a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# sœur a appelé |both|termination|nonpatient|30|Group[234]|Clement
# sœur a appelé |both|termination|historical|30|Group[234]|Clement
# sœur a appelé |both|termination|nonpatient|30|Group[153]|Clement
# sœur a dit |both|termination|nonpatient|30|Group[234]|Clement
# sœur a dit |both|termination|historical|30|Group[234]|Clement
# sœur a dit |both|termination|nonpatient|30|Group[153]|Clement
# sœur a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# sœur a déclaré |both|termination|historical|30|Group[234]|Clement
# sœur a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# sœur a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# sœur a trouvé |both|termination|historical|30|Group[234]|Clement
# sœur a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# sœur a signalé |both|termination|nonpatient|30|Group[234]|Clement
# sœur a signalé |both|termination|historical|30|Group[234]|Clement
# sœur a signalé |both|termination|nonpatient|30|Group[153]|Clement
# sœur a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# sœur a sollicité |both|termination|historical|30|Group[234]|Clement
# sœur a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# sœur a requéri |both|termination|nonpatient|30|Group[234]|Clement
# sœur a requéri |both|termination|historical|30|Group[234]|Clement
# sœur a requéri |both|termination|nonpatient|30|Group[153]|Clement
# sœur a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# sœur a téléphoné |both|termination|historical|30|Group[234]|Clement
# sœur a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# sœur a averti |both|termination|nonpatient|30|Group[234]|Clement
# sœur a averti |both|termination|historical|30|Group[234]|Clement
# sœur a averti |both|termination|nonpatient|30|Group[153]|Clement
# sœur a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# sœur a prévenu |both|termination|historical|30|Group[234]|Clement
# sœur a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# sœur a alerté |both|termination|nonpatient|30|Group[234]|Clement
# sœur a alerté |both|termination|historical|30|Group[234]|Clement
# sœur a alerté |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont rapporté |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont rapporté |both|termination|historical|30|Group[234]|Clement
# sœurs ont rapporté |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont appelé |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont appelé |both|termination|historical|30|Group[234]|Clement
# sœurs ont appelé |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont dit |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont dit |both|termination|historical|30|Group[234]|Clement
# sœurs ont dit |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont déclaré |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont déclaré |both|termination|historical|30|Group[234]|Clement
# sœurs ont déclaré |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont trouvé |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont trouvé |both|termination|historical|30|Group[234]|Clement
# sœurs ont trouvé |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont signalé |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont signalé |both|termination|historical|30|Group[234]|Clement
# sœurs ont signalé |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont sollicité |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont sollicité |both|termination|historical|30|Group[234]|Clement
# sœurs ont sollicité |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont requéri |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont requéri |both|termination|historical|30|Group[234]|Clement
# sœurs ont requéri |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont téléphoné |both|termination|historical|30|Group[234]|Clement
# sœurs ont téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont averti |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont averti |both|termination|historical|30|Group[234]|Clement
# sœurs ont averti |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont prévenu |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont prévenu |both|termination|historical|30|Group[234]|Clement
# sœurs ont prévenu |both|termination|nonpatient|30|Group[153]|Clement
# sœurs ont alerté |both|termination|nonpatient|30|Group[234]|Clement
# sœurs ont alerté |both|termination|historical|30|Group[234]|Clement
# sœurs ont alerté |both|termination|nonpatient|30|Group[153]|Clement
# oncle a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# oncle a rapporté |both|termination|historical|30|Group[234]|Clement
# oncle a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# oncle a appelé |both|termination|nonpatient|30|Group[234]|Clement
# oncle a appelé |both|termination|historical|30|Group[234]|Clement
# oncle a appelé |both|termination|nonpatient|30|Group[153]|Clement
# oncle a dit |both|termination|nonpatient|30|Group[234]|Clement
# oncle a dit |both|termination|historical|30|Group[234]|Clement
# oncle a dit |both|termination|nonpatient|30|Group[153]|Clement
# oncle a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# oncle a déclaré |both|termination|historical|30|Group[234]|Clement
# oncle a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# oncle a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# oncle a trouvé |both|termination|historical|30|Group[234]|Clement
# oncle a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# oncle a signalé |both|termination|nonpatient|30|Group[234]|Clement
# oncle a signalé |both|termination|historical|30|Group[234]|Clement
# oncle a signalé |both|termination|nonpatient|30|Group[153]|Clement
# oncle a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# oncle a sollicité |both|termination|historical|30|Group[234]|Clement
# oncle a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# oncle a requéri |both|termination|nonpatient|30|Group[234]|Clement
# oncle a requéri |both|termination|historical|30|Group[234]|Clement
# oncle a requéri |both|termination|nonpatient|30|Group[153]|Clement
# oncle a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# oncle a téléphoné |both|termination|historical|30|Group[234]|Clement
# oncle a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# oncle a averti |both|termination|nonpatient|30|Group[234]|Clement
# oncle a averti |both|termination|historical|30|Group[234]|Clement
# oncle a averti |both|termination|nonpatient|30|Group[153]|Clement
# oncle a prévenu |both|termination|nonpatient|30|Group[234]|Clement
# oncle a prévenu |both|termination|historical|30|Group[234]|Clement
# oncle a prévenu |both|termination|nonpatient|30|Group[153]|Clement
# oncle a alerté |both|termination|nonpatient|30|Group[234]|Clement
# oncle a alerté |both|termination|historical|30|Group[234]|Clement
# oncle a alerté |both|termination|nonpatient|30|Group[153]|Clement
# tonton a rapporté |both|termination|nonpatient|30|Group[234]|Clement
# tonton a rapporté |both|termination|historical|30|Group[234]|Clement
# tonton a rapporté |both|termination|nonpatient|30|Group[153]|Clement
# tonton a appelé |both|termination|nonpatient|30|Group[234]|Clement
# tonton a appelé |both|termination|historical|30|Group[234]|Clement
# tonton a appelé |both|termination|nonpatient|30|Group[153]|Clement
# tonton a dit |both|termination|nonpatient|30|Group[234]|Clement
# tonton a dit |both|termination|historical|30|Group[234]|Clement
# tonton a dit |both|termination|nonpatient|30|Group[153]|Clement
# tonton a déclaré |both|termination|nonpatient|30|Group[234]|Clement
# tonton a déclaré |both|termination|historical|30|Group[234]|Clement
# tonton a déclaré |both|termination|nonpatient|30|Group[153]|Clement
# tonton a trouvé |both|termination|nonpatient|30|Group[234]|Clement
# tonton a trouvé |both|termination|historical|30|Group[234]|Clement
# tonton a trouvé |both|termination|nonpatient|30|Group[153]|Clement
# tonton a signalé |both|termination|nonpatient|30|Group[234]|Clement
# tonton a signalé |both|termination|historical|30|Group[234]|Clement
# tonton a signalé |both|termination|nonpatient|30|Group[153]|Clement
# tonton a sollicité |both|termination|nonpatient|30|Group[234]|Clement
# tonton a sollicité |both|termination|historical|30|Group[234]|Clement
# tonton a sollicité |both|termination|nonpatient|30|Group[153]|Clement
# tonton a requéri |both|termination|nonpatient|30|Group[234]|Clement
# tonton a requéri |both|termination|historical|30|Group[234]|Clement
# tonton a requéri |both|termination|nonpatient|30|Group[153]|Clement
# tonton a téléphoné |both|termination|nonpatient|30|Group[234]|Clement
# tonton a téléphoné |both|termination|historical|30|Group[234]|Clement
# tonton a téléphoné |both|termination|nonpatient|30|Group[153]|Clement
# tonton a averti |both|termination|nonpatient|30|Group[234]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Member Trigger_Rule
Member -> "parent" | "parents" | "père" | "beau-père" | "mère" |"belle-mère" | "papa" | "maman" |"fils" | "beau-fils" | "garçon" | "garçons" | "fille" | "belle-fille" | "filles" | "frère"| "frères" |"soeur" |"soeurs" |"sœur" |"sœurs" | "fratrie" | "oncle"| "tonton"| "oncles" |"tante" | "tata"| "tantes" |"grand-mère" | "grand-père" |"cousin" |"cousins" |"famille" |"colocataire" | "colocataires" | "voisin" | "voisins"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[154]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# parent |forward|trigger|nonpatient|30|Group[154]|Clement
# parents |forward|trigger|nonpatient|30|Group[154]|Clement
# père |forward|trigger|nonpatient|30|Group[154]|Clement
# beau-père |forward|trigger|nonpatient|30|Group[154]|Clement
# mère |forward|trigger|nonpatient|30|Group[154]|Clement
# belle-mère |forward|trigger|nonpatient|30|Group[154]|Clement
# papa |forward|trigger|nonpatient|30|Group[154]|Clement
# maman |forward|trigger|nonpatient|30|Group[154]|Clement
# fils |forward|trigger|nonpatient|30|Group[154]|Clement
# beau-fils |forward|trigger|nonpatient|30|Group[154]|Clement
# garçon |forward|trigger|nonpatient|30|Group[154]|Clement
# garçons |forward|trigger|nonpatient|30|Group[154]|Clement
# fille |forward|trigger|nonpatient|30|Group[154]|Clement
# belle-fille |forward|trigger|nonpatient|30|Group[154]|Clement
# filles |forward|trigger|nonpatient|30|Group[154]|Clement
# frère |forward|trigger|nonpatient|30|Group[154]|Clement
# frères |forward|trigger|nonpatient|30|Group[154]|Clement
# soeur |forward|trigger|nonpatient|30|Group[154]|Clement
# soeurs |forward|trigger|nonpatient|30|Group[154]|Clement
# sœur |forward|trigger|nonpatient|30|Group[154]|Clement
# sœurs |forward|trigger|nonpatient|30|Group[154]|Clement
# fratrie |forward|trigger|nonpatient|30|Group[154]|Clement
# oncle |forward|trigger|nonpatient|30|Group[154]|Clement
# tonton |forward|trigger|nonpatient|30|Group[154]|Clement
# oncles |forward|trigger|nonpatient|30|Group[154]|Clement
# tante |forward|trigger|nonpatient|30|Group[154]|Clement
# tata |forward|trigger|nonpatient|30|Group[154]|Clement
# tantes |forward|trigger|nonpatient|30|Group[154]|Clement
# grand-mère |forward|trigger|nonpatient|30|Group[154]|Clement
# grand-père |forward|trigger|nonpatient|30|Group[154]|Clement
# cousin |forward|trigger|nonpatient|30|Group[154]|Clement
# cousins |forward|trigger|nonpatient|30|Group[154]|Clement
# famille |forward|trigger|nonpatient|30|Group[154]|Clement
# colocataire |forward|trigger|nonpatient|30|Group[154]|Clement
# colocataires |forward|trigger|nonpatient|30|Group[154]|Clement
# voisin |forward|trigger|nonpatient|30|Group[154]|Clement
# voisins |forward|trigger|nonpatient|30|Group[154]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> "histoire sociale" 
Trigger_Rule -> "|both|pseudo|historical|30|Group[1040]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# histoire sociale |both|pseudo|historical|30|Group[1040]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Var3 Trigger_Rule
Var1 -> "être"
Var2 -> "exclu" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Termin -> "_"|"_s" |"_e" |"_es"
Var3 -> "pour"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[156]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# être exclu _ pour |forward|trigger|uncertain|30|Group[156]|Clement
# être exclu _s pour |forward|trigger|uncertain|30|Group[156]|Clement
# être exclu _e pour |forward|trigger|uncertain|30|Group[156]|Clement
# être exclu _es pour |forward|trigger|uncertain|30|Group[156]|Clement
# être repoussé _ pour |forward|trigger|uncertain|30|Group[156]|Clement
# être repoussé _s pour |forward|trigger|uncertain|30|Group[156]|Clement
# être repoussé _e pour |forward|trigger|uncertain|30|Group[156]|Clement
# être repoussé _es pour |forward|trigger|uncertain|30|Group[156]|Clement
# être rejeté _ pour |forward|trigger|uncertain|30|Group[156]|Clement
# être rejeté _s pour |forward|trigger|uncertain|30|Group[156]|Clement
# être rejeté _e pour |forward|trigger|uncertain|30|Group[156]|Clement
# être rejeté _es pour |forward|trigger|uncertain|30|Group[156]|Clement
# être éliminé _ pour |forward|trigger|uncertain|30|Group[156]|Clement
# être éliminé _s pour |forward|trigger|uncertain|30|Group[156]|Clement
# être éliminé _e pour |forward|trigger|uncertain|30|Group[156]|Clement
# être éliminé _es pour |forward|trigger|uncertain|30|Group[156]|Clement
# être proscrit _ pour |forward|trigger|uncertain|30|Group[156]|Clement
# être proscrit _s pour |forward|trigger|uncertain|30|Group[156]|Clement
# être proscrit _e pour |forward|trigger|uncertain|30|Group[156]|Clement
# être proscrit _es pour |forward|trigger|uncertain|30|Group[156]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Trigger_Rule
Var1 -> "été"
Var2 -> "exclu" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Termin -> "_"|"_s" |"_e" |"_es"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[157]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# été exclu _ |backward|trigger|uncertain|30|Group[157]|Clement
# été exclu _s |backward|trigger|uncertain|30|Group[157]|Clement
# été exclu _e |backward|trigger|uncertain|30|Group[157]|Clement
# été exclu _es |backward|trigger|uncertain|30|Group[157]|Clement
# été repoussé _ |backward|trigger|uncertain|30|Group[157]|Clement
# été repoussé _s |backward|trigger|uncertain|30|Group[157]|Clement
# été repoussé _e |backward|trigger|uncertain|30|Group[157]|Clement
# été repoussé _es |backward|trigger|uncertain|30|Group[157]|Clement
# été rejeté _ |backward|trigger|uncertain|30|Group[157]|Clement
# été rejeté _s |backward|trigger|uncertain|30|Group[157]|Clement
# été rejeté _e |backward|trigger|uncertain|30|Group[157]|Clement
# été rejeté _es |backward|trigger|uncertain|30|Group[157]|Clement
# été éliminé _ |backward|trigger|uncertain|30|Group[157]|Clement
# été éliminé _s |backward|trigger|uncertain|30|Group[157]|Clement
# été éliminé _e |backward|trigger|uncertain|30|Group[157]|Clement
# été éliminé _es |backward|trigger|uncertain|30|Group[157]|Clement
# été proscrit _ |backward|trigger|uncertain|30|Group[157]|Clement
# été proscrit _s |backward|trigger|uncertain|30|Group[157]|Clement
# été proscrit _e |backward|trigger|uncertain|30|Group[157]|Clement
# été proscrit _es |backward|trigger|uncertain|30|Group[157]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "être"
Var2 -> "arrêté" | "stoppé" | "suspendu" | "terminé" | "fini" | "endigué" | "cessé" | "interrompu" | "gelé"
Var3 -> "_"|"_s" |"_e" |"_es"
Trigger_Rule -> "|backward|trigger|negated|10|Group[158]|Clement"|"|forward|termination|negated|10|Group[159]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# être arrêté _ |backward|trigger|negated|10|Group[158]|Clement
# être arrêté _ |forward|termination|negated|10|Group[159]|Clement
# être arrêté _s |backward|trigger|negated|10|Group[158]|Clement
# être arrêté _s |forward|termination|negated|10|Group[159]|Clement
# être arrêté _e |backward|trigger|negated|10|Group[158]|Clement
# être arrêté _e |forward|termination|negated|10|Group[159]|Clement
# être arrêté _es |backward|trigger|negated|10|Group[158]|Clement
# être arrêté _es |forward|termination|negated|10|Group[159]|Clement
# être stoppé _ |backward|trigger|negated|10|Group[158]|Clement
# être stoppé _ |forward|termination|negated|10|Group[159]|Clement
# être stoppé _s |backward|trigger|negated|10|Group[158]|Clement
# être stoppé _s |forward|termination|negated|10|Group[159]|Clement
# être stoppé _e |backward|trigger|negated|10|Group[158]|Clement
# être stoppé _e |forward|termination|negated|10|Group[159]|Clement
# être stoppé _es |backward|trigger|negated|10|Group[158]|Clement
# être stoppé _es |forward|termination|negated|10|Group[159]|Clement
# être suspendu _ |backward|trigger|negated|10|Group[158]|Clement
# être suspendu _ |forward|termination|negated|10|Group[159]|Clement
# être suspendu _s |backward|trigger|negated|10|Group[158]|Clement
# être suspendu _s |forward|termination|negated|10|Group[159]|Clement
# être suspendu _e |backward|trigger|negated|10|Group[158]|Clement
# être suspendu _e |forward|termination|negated|10|Group[159]|Clement
# être suspendu _es |backward|trigger|negated|10|Group[158]|Clement
# être suspendu _es |forward|termination|negated|10|Group[159]|Clement
# être terminé _ |backward|trigger|negated|10|Group[158]|Clement
# être terminé _ |forward|termination|negated|10|Group[159]|Clement
# être terminé _s |backward|trigger|negated|10|Group[158]|Clement
# être terminé _s |forward|termination|negated|10|Group[159]|Clement
# être terminé _e |backward|trigger|negated|10|Group[158]|Clement
# être terminé _e |forward|termination|negated|10|Group[159]|Clement
# être terminé _es |backward|trigger|negated|10|Group[158]|Clement
# être terminé _es |forward|termination|negated|10|Group[159]|Clement
# être fini _ |backward|trigger|negated|10|Group[158]|Clement
# être fini _ |forward|termination|negated|10|Group[159]|Clement
# être fini _s |backward|trigger|negated|10|Group[158]|Clement
# être fini _s |forward|termination|negated|10|Group[159]|Clement
# être fini _e |backward|trigger|negated|10|Group[158]|Clement
# être fini _e |forward|termination|negated|10|Group[159]|Clement
# être fini _es |backward|trigger|negated|10|Group[158]|Clement
# être fini _es |forward|termination|negated|10|Group[159]|Clement
# être endigué _ |backward|trigger|negated|10|Group[158]|Clement
# être endigué _ |forward|termination|negated|10|Group[159]|Clement
# être endigué _s |backward|trigger|negated|10|Group[158]|Clement
# être endigué _s |forward|termination|negated|10|Group[159]|Clement
# être endigué _e |backward|trigger|negated|10|Group[158]|Clement
# être endigué _e |forward|termination|negated|10|Group[159]|Clement
# être endigué _es |backward|trigger|negated|10|Group[158]|Clement
# être endigué _es |forward|termination|negated|10|Group[159]|Clement
# être cessé _ |backward|trigger|negated|10|Group[158]|Clement
# être cessé _ |forward|termination|negated|10|Group[159]|Clement
# être cessé _s |backward|trigger|negated|10|Group[158]|Clement
# être cessé _s |forward|termination|negated|10|Group[159]|Clement
# être cessé _e |backward|trigger|negated|10|Group[158]|Clement
# être cessé _e |forward|termination|negated|10|Group[159]|Clement
# être cessé _es |backward|trigger|negated|10|Group[158]|Clement
# être cessé _es |forward|termination|negated|10|Group[159]|Clement
# être interrompu _ |backward|trigger|negated|10|Group[158]|Clement
# être interrompu _ |forward|termination|negated|10|Group[159]|Clement
# être interrompu _s |backward|trigger|negated|10|Group[158]|Clement
# être interrompu _s |forward|termination|negated|10|Group[159]|Clement
# être interrompu _e |backward|trigger|negated|10|Group[158]|Clement
# être interrompu _e |forward|termination|negated|10|Group[159]|Clement
# être interrompu _es |backward|trigger|negated|10|Group[158]|Clement
# être interrompu _es |forward|termination|negated|10|Group[159]|Clement
# être gelé _ |backward|trigger|negated|10|Group[158]|Clement
# être gelé _ |forward|termination|negated|10|Group[159]|Clement
# être gelé _s |backward|trigger|negated|10|Group[158]|Clement
# être gelé _s |forward|termination|negated|10|Group[159]|Clement
# être gelé _e |backward|trigger|negated|10|Group[158]|Clement
# être gelé _e |forward|termination|negated|10|Group[159]|Clement
# être gelé _es |backward|trigger|negated|10|Group[158]|Clement
# être gelé _es |forward|termination|negated|10|Group[159]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Trigger_Rule
Var1 -> "est"
Var2 -> "arrêté" | "stoppé" | "suspendu" | "terminé" | "fini" | "endigué" | "cessé" | "interrompu" | "gelé"| "arrêtée" | "stoppée" | "suspendue" | "terminée" | "finie" | "endiguée" | "cessée" | "interrompue" | "gelée"
Termin -> "_" | "_e"
Trigger_Rule -> "|backward|trigger|negated|10|Group[158]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# est arrêté _ |backward|trigger|negated|10|Group[158]|Clement
# est arrêté _e |backward|trigger|negated|10|Group[158]|Clement
# est stoppé _ |backward|trigger|negated|10|Group[158]|Clement
# est stoppé _e |backward|trigger|negated|10|Group[158]|Clement
# est suspendu _ |backward|trigger|negated|10|Group[158]|Clement
# est suspendu _e |backward|trigger|negated|10|Group[158]|Clement
# est terminé _ |backward|trigger|negated|10|Group[158]|Clement
# est terminé _e |backward|trigger|negated|10|Group[158]|Clement
# est fini _ |backward|trigger|negated|10|Group[158]|Clement
# est fini _e |backward|trigger|negated|10|Group[158]|Clement
# est endigué _ |backward|trigger|negated|10|Group[158]|Clement
# est endigué _e |backward|trigger|negated|10|Group[158]|Clement
# est cessé _ |backward|trigger|negated|10|Group[158]|Clement
# est cessé _e |backward|trigger|negated|10|Group[158]|Clement
# est interrompu _ |backward|trigger|negated|10|Group[158]|Clement
# est interrompu _e |backward|trigger|negated|10|Group[158]|Clement
# est gelé _ |backward|trigger|negated|10|Group[158]|Clement
# est gelé _e |backward|trigger|negated|10|Group[158]|Clement
# est arrêtée _ |backward|trigger|negated|10|Group[158]|Clement
# est arrêtée _e |backward|trigger|negated|10|Group[158]|Clement
# est stoppée _ |backward|trigger|negated|10|Group[158]|Clement
# est stoppée _e |backward|trigger|negated|10|Group[158]|Clement
# est suspendue _ |backward|trigger|negated|10|Group[158]|Clement
# est suspendue _e |backward|trigger|negated|10|Group[158]|Clement
# est terminée _ |backward|trigger|negated|10|Group[158]|Clement
# est terminée _e |backward|trigger|negated|10|Group[158]|Clement
# est finie _ |backward|trigger|negated|10|Group[158]|Clement
# est finie _e |backward|trigger|negated|10|Group[158]|Clement
# est endiguée _ |backward|trigger|negated|10|Group[158]|Clement
# est endiguée _e |backward|trigger|negated|10|Group[158]|Clement
# est cessée _ |backward|trigger|negated|10|Group[158]|Clement
# est cessée _e |backward|trigger|negated|10|Group[158]|Clement
# est interrompue _ |backward|trigger|negated|10|Group[158]|Clement
# est interrompue _e |backward|trigger|negated|10|Group[158]|Clement
# est gelée _ |backward|trigger|negated|10|Group[158]|Clement
# est gelée _e |backward|trigger|negated|10|Group[158]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Trigger_Rule
Var1 -> "sont"
Var2 -> "arrêtés" | "stoppés" | "suspendus" | "terminés" | "finis" | "endigués" | "cessés" | "interrompus" | "gelés"| "arrêtées" | "stoppées" | "suspendues" | "terminées" | "finies" | "endiguées" | "cessées" | "interrompues" | "gelées"
Termin -> "_s" |"_es"

Trigger_Rule -> "|backward|trigger|negated|10|Group[158]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sont arrêtés _s |backward|trigger|negated|10|Group[158]|Clement
# sont arrêtés _es |backward|trigger|negated|10|Group[158]|Clement
# sont stoppés _s |backward|trigger|negated|10|Group[158]|Clement
# sont stoppés _es |backward|trigger|negated|10|Group[158]|Clement
# sont suspendus _s |backward|trigger|negated|10|Group[158]|Clement
# sont suspendus _es |backward|trigger|negated|10|Group[158]|Clement
# sont terminés _s |backward|trigger|negated|10|Group[158]|Clement
# sont terminés _es |backward|trigger|negated|10|Group[158]|Clement
# sont finis _s |backward|trigger|negated|10|Group[158]|Clement
# sont finis _es |backward|trigger|negated|10|Group[158]|Clement
# sont endigués _s |backward|trigger|negated|10|Group[158]|Clement
# sont endigués _es |backward|trigger|negated|10|Group[158]|Clement
# sont cessés _s |backward|trigger|negated|10|Group[158]|Clement
# sont cessés _es |backward|trigger|negated|10|Group[158]|Clement
# sont interrompus _s |backward|trigger|negated|10|Group[158]|Clement
# sont interrompus _es |backward|trigger|negated|10|Group[158]|Clement
# sont gelés _s |backward|trigger|negated|10|Group[158]|Clement
# sont gelés _es |backward|trigger|negated|10|Group[158]|Clement
# sont arrêtées _s |backward|trigger|negated|10|Group[158]|Clement
# sont arrêtées _es |backward|trigger|negated|10|Group[158]|Clement
# sont stoppées _s |backward|trigger|negated|10|Group[158]|Clement
# sont stoppées _es |backward|trigger|negated|10|Group[158]|Clement
# sont suspendues _s |backward|trigger|negated|10|Group[158]|Clement
# sont suspendues _es |backward|trigger|negated|10|Group[158]|Clement
# sont terminées _s |backward|trigger|negated|10|Group[158]|Clement
# sont terminées _es |backward|trigger|negated|10|Group[158]|Clement
# sont finies _s |backward|trigger|negated|10|Group[158]|Clement
# sont finies _es |backward|trigger|negated|10|Group[158]|Clement
# sont endiguées _s |backward|trigger|negated|10|Group[158]|Clement
# sont endiguées _es |backward|trigger|negated|10|Group[158]|Clement
# sont cessées _s |backward|trigger|negated|10|Group[158]|Clement
# sont cessées _es |backward|trigger|negated|10|Group[158]|Clement
# sont interrompues _s |backward|trigger|negated|10|Group[158]|Clement
# sont interrompues _es |backward|trigger|negated|10|Group[158]|Clement
# sont gelées _s |backward|trigger|negated|10|Group[158]|Clement
# sont gelées _es |backward|trigger|negated|10|Group[158]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "mettre fin" | "mis fin"
Trigger_Rule -> "|forward|termination|negated|10|Group[159]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# mettre fin |forward|termination|negated|10|Group[159]|Clement
# mis fin |forward|termination|negated|10|Group[159]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "parce"
Var2 -> "que"|"qu'il"|"qu'elle"
Trigger_Rule -> "|both|termination|conditional|30|Group[160]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# parce que |both|termination|conditional|30|Group[160]|Clement
# parce qu'il |both|termination|conditional|30|Group[160]|Clement
# parce qu'elle |both|termination|conditional|30|Group[160]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "au-delà"
Trigger_Rule -> "|forward|termination|negated|10|Group[162]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# au-delà |forward|termination|negated|10|Group[162]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "biopsie"
Var2 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[163]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# biopsie de |forward|termination|negated|10|Group[163]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "limite" | "seuil" | "serré"| "serrée"| "juste"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[164]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# limite |forward|trigger|uncertain|30|Group[164]|Clement
# seuil |forward|trigger|uncertain|30|Group[164]|Clement
# serré |forward|trigger|uncertain|30|Group[164]|Clement
# serrée |forward|trigger|uncertain|30|Group[164]|Clement
# juste |forward|trigger|uncertain|30|Group[164]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "mais"
Trigger_Rule -> "|forward|termination|negated|10|Group[168]|Clement"|"|backward|termination|negated|10|Group[169]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# mais |forward|termination|negated|10|Group[168]|Clement
# mais |backward|termination|negated|10|Group[169]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Article Trigger_Rule
Var1 -> "pour" | "par"
Article -> "l'" | "le" | "la" | "un" | "une"
Trigger_Rule -> "|forward|termination|negated|10|Group[174]|Clement"
"""
for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pour l' |forward|termination|negated|10|Group[174]|Clement
# pour le |forward|termination|negated|10|Group[174]|Clement
# pour la |forward|termination|negated|10|Group[174]|Clement
# pour un |forward|termination|negated|10|Group[174]|Clement
# pour une |forward|termination|negated|10|Group[174]|Clement
# par l' |forward|termination|negated|10|Group[174]|Clement
# par le |forward|termination|negated|10|Group[174]|Clement
# par la |forward|termination|negated|10|Group[174]|Clement
# par un |forward|termination|negated|10|Group[174]|Clement
# par une |forward|termination|negated|10|Group[174]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "peut"
Var2 -> "être"
Var3 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[176]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut être exclu |forward|trigger|uncertain|30|Group[176]|Clement
# peut être refusé |forward|trigger|uncertain|30|Group[176]|Clement
# peut être repoussé |forward|trigger|uncertain|30|Group[176]|Clement
# peut être rejeté |forward|trigger|uncertain|30|Group[176]|Clement
# peut être éliminé |forward|trigger|uncertain|30|Group[176]|Clement
# peut être proscrit |forward|trigger|uncertain|30|Group[176]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Termin Trigger_Rule
Var1 -> "peut"
Var2 -> "être"
Var3 -> "exclu" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Termin -> "_"|"_s" |"_e" |"_es"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[177]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut être exclu _ |backward|trigger|uncertain|30|Group[177]|Clement
# peut être exclu _s |backward|trigger|uncertain|30|Group[177]|Clement
# peut être exclu _e |backward|trigger|uncertain|30|Group[177]|Clement
# peut être exclu _es |backward|trigger|uncertain|30|Group[177]|Clement
# peut être repoussé _ |backward|trigger|uncertain|30|Group[177]|Clement
# peut être repoussé _s |backward|trigger|uncertain|30|Group[177]|Clement
# peut être repoussé _e |backward|trigger|uncertain|30|Group[177]|Clement
# peut être repoussé _es |backward|trigger|uncertain|30|Group[177]|Clement
# peut être rejeté _ |backward|trigger|uncertain|30|Group[177]|Clement
# peut être rejeté _s |backward|trigger|uncertain|30|Group[177]|Clement
# peut être rejeté _e |backward|trigger|uncertain|30|Group[177]|Clement
# peut être rejeté _es |backward|trigger|uncertain|30|Group[177]|Clement
# peut être éliminé _ |backward|trigger|uncertain|30|Group[177]|Clement
# peut être éliminé _s |backward|trigger|uncertain|30|Group[177]|Clement
# peut être éliminé _e |backward|trigger|uncertain|30|Group[177]|Clement
# peut être éliminé _es |backward|trigger|uncertain|30|Group[177]|Clement
# peut être proscrit _ |backward|trigger|uncertain|30|Group[177]|Clement
# peut être proscrit _s |backward|trigger|uncertain|30|Group[177]|Clement
# peut être proscrit _e |backward|trigger|uncertain|30|Group[177]|Clement
# peut être proscrit _es |backward|trigger|uncertain|30|Group[177]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "peut"
Var2 -> "éliminer" | "écarter" | "évincer" | "exclure" | "chasser" | "proscrire" | "rejeter" | "repousser" | "enlever" | "éloigner" | "retirer"  | "ôter" | "récuser"
Trigger_Rule -> "|forward|trigger|negated|10|Group[179]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut éliminer |forward|trigger|negated|10|Group[179]|Clement
# peut écarter |forward|trigger|negated|10|Group[179]|Clement
# peut évincer |forward|trigger|negated|10|Group[179]|Clement
# peut exclure |forward|trigger|negated|10|Group[179]|Clement
# peut chasser |forward|trigger|negated|10|Group[179]|Clement
# peut proscrire |forward|trigger|negated|10|Group[179]|Clement
# peut rejeter |forward|trigger|negated|10|Group[179]|Clement
# peut repousser |forward|trigger|negated|10|Group[179]|Clement
# peut enlever |forward|trigger|negated|10|Group[179]|Clement
# peut éloigner |forward|trigger|negated|10|Group[179]|Clement
# peut retirer |forward|trigger|negated|10|Group[179]|Clement
# peut ôter |forward|trigger|negated|10|Group[179]|Clement
# peut récuser |forward|trigger|negated|10|Group[179]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Patient Trigger_Rule
Var1 -> "peut"
Var2 -> "exclure" | "éliminer" | "rejeter" | "proscrire" | "éloigner" | "supprimer" | "radier"
Patient -> "le patient" | "la patiente"| "le souffrant" | "la souffrante"| "le sujet"
Trigger_Rule -> "|forward|trigger|negated|10|Group[196]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut exclure le patient |forward|trigger|negated|10|Group[196]|Clement
# peut exclure la patiente |forward|trigger|negated|10|Group[196]|Clement
# peut exclure le souffrant |forward|trigger|negated|10|Group[196]|Clement
# peut exclure la souffrante |forward|trigger|negated|10|Group[196]|Clement
# peut exclure le sujet |forward|trigger|negated|10|Group[196]|Clement
# peut éliminer le patient |forward|trigger|negated|10|Group[196]|Clement
# peut éliminer la patiente |forward|trigger|negated|10|Group[196]|Clement
# peut éliminer le souffrant |forward|trigger|negated|10|Group[196]|Clement
# peut éliminer la souffrante |forward|trigger|negated|10|Group[196]|Clement
# peut éliminer le sujet |forward|trigger|negated|10|Group[196]|Clement
# peut rejeter le patient |forward|trigger|negated|10|Group[196]|Clement
# peut rejeter la patiente |forward|trigger|negated|10|Group[196]|Clement
# peut rejeter le souffrant |forward|trigger|negated|10|Group[196]|Clement
# peut rejeter la souffrante |forward|trigger|negated|10|Group[196]|Clement
# peut rejeter le sujet |forward|trigger|negated|10|Group[196]|Clement
# peut proscrire le patient |forward|trigger|negated|10|Group[196]|Clement
# peut proscrire la patiente |forward|trigger|negated|10|Group[196]|Clement
# peut proscrire le souffrant |forward|trigger|negated|10|Group[196]|Clement
# peut proscrire la souffrante |forward|trigger|negated|10|Group[196]|Clement
# peut proscrire le sujet |forward|trigger|negated|10|Group[196]|Clement
# peut éloigner le patient |forward|trigger|negated|10|Group[196]|Clement
# peut éloigner la patiente |forward|trigger|negated|10|Group[196]|Clement
# peut éloigner le souffrant |forward|trigger|negated|10|Group[196]|Clement
# peut éloigner la souffrante |forward|trigger|negated|10|Group[196]|Clement
# peut éloigner le sujet |forward|trigger|negated|10|Group[196]|Clement
# peut supprimer le patient |forward|trigger|negated|10|Group[196]|Clement
# peut supprimer la patiente |forward|trigger|negated|10|Group[196]|Clement
# peut supprimer le souffrant |forward|trigger|negated|10|Group[196]|Clement
# peut supprimer la souffrante |forward|trigger|negated|10|Group[196]|Clement
# peut supprimer le sujet |forward|trigger|negated|10|Group[196]|Clement
# peut radier le patient |forward|trigger|negated|10|Group[196]|Clement
# peut radier la patiente |forward|trigger|negated|10|Group[196]|Clement
# peut radier le souffrant |forward|trigger|negated|10|Group[196]|Clement
# peut radier la souffrante |forward|trigger|negated|10|Group[196]|Clement
# peut radier le sujet |forward|trigger|negated|10|Group[196]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Var5 Var6 Termin Trigger_Rule
Var1 -> "ne"
Var2 -> "peut"
Var3 -> "pas"
Var4 -> "être"
Var5 -> "\\w+"
Var6 -> "exclu" | "repoussé" | "rejeté" | "éliminé" | "proscri"
Termin -> "_"|"_e"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[202]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne peut pas être \w+ exclu _ |backward|trigger|uncertain|30|Group[202]|Clement
# ne peut pas être \w+ exclu _e |backward|trigger|uncertain|30|Group[202]|Clement
# ne peut pas être \w+ repoussé _ |backward|trigger|uncertain|30|Group[202]|Clement
# ne peut pas être \w+ repoussé _e |backward|trigger|uncertain|30|Group[202]|Clement
# ne peut pas être \w+ rejeté _ |backward|trigger|uncertain|30|Group[202]|Clement
# ne peut pas être \w+ rejeté _e |backward|trigger|uncertain|30|Group[202]|Clement
# ne peut pas être \w+ éliminé _ |backward|trigger|uncertain|30|Group[202]|Clement
# ne peut pas être \w+ éliminé _e |backward|trigger|uncertain|30|Group[202]|Clement
# ne peut pas être \w+ proscri _ |backward|trigger|uncertain|30|Group[202]|Clement
# ne peut pas être \w+ proscri _e |backward|trigger|uncertain|30|Group[202]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "ne"
Var2 -> "peut"
Var3 -> "voir" | "saisir" | "percevoir" | "constater" | "considérer" | "concevoir" | "remarquer" | "trouver" | "rencontrer" | "découvrir" | "vérifier" | "distinguer" | "entrevoir" | "discerner"
Trigger_Rule -> "|forward|trigger|negated|10|Group[205]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne peut voir |forward|trigger|negated|10|Group[205]|Clement
# ne peut saisir |forward|trigger|negated|10|Group[205]|Clement
# ne peut percevoir |forward|trigger|negated|10|Group[205]|Clement
# ne peut constater |forward|trigger|negated|10|Group[205]|Clement
# ne peut considérer |forward|trigger|negated|10|Group[205]|Clement
# ne peut concevoir |forward|trigger|negated|10|Group[205]|Clement
# ne peut remarquer |forward|trigger|negated|10|Group[205]|Clement
# ne peut trouver |forward|trigger|negated|10|Group[205]|Clement
# ne peut rencontrer |forward|trigger|negated|10|Group[205]|Clement
# ne peut découvrir |forward|trigger|negated|10|Group[205]|Clement
# ne peut vérifier |forward|trigger|negated|10|Group[205]|Clement
# ne peut distinguer |forward|trigger|negated|10|Group[205]|Clement
# ne peut entrevoir |forward|trigger|negated|10|Group[205]|Clement
# ne peut discerner |forward|trigger|negated|10|Group[205]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "ne"
Var2 -> "peux" |"peut"|"pouvait"|"pouvais"
Var3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[207]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne peux pas |forward|trigger|negated|10|Group[207]|Clement
# ne peut pas |forward|trigger|negated|10|Group[207]|Clement
# ne pouvait pas |forward|trigger|negated|10|Group[207]|Clement
# ne pouvais pas |forward|trigger|negated|10|Group[207]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "cause" | "raison" | "prétexte" | "fondement" | "source" | "intention" | "origine" | "déclencheur" | "départ"
Var2 -> "_" | "_s"
Var3 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[209]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# cause _ de |forward|termination|negated|10|Group[209]|Clement
# cause _s de |forward|termination|negated|10|Group[209]|Clement
# raison _ de |forward|termination|negated|10|Group[209]|Clement
# raison _s de |forward|termination|negated|10|Group[209]|Clement
# prétexte _ de |forward|termination|negated|10|Group[209]|Clement
# prétexte _s de |forward|termination|negated|10|Group[209]|Clement
# fondement _ de |forward|termination|negated|10|Group[209]|Clement
# fondement _s de |forward|termination|negated|10|Group[209]|Clement
# source _ de |forward|termination|negated|10|Group[209]|Clement
# source _s de |forward|termination|negated|10|Group[209]|Clement
# intention _ de |forward|termination|negated|10|Group[209]|Clement
# intention _s de |forward|termination|negated|10|Group[209]|Clement
# origine _ de |forward|termination|negated|10|Group[209]|Clement
# origine _s de |forward|termination|negated|10|Group[209]|Clement
# déclencheur _ de |forward|termination|negated|10|Group[209]|Clement
# déclencheur _s de |forward|termination|negated|10|Group[209]|Clement
# départ _ de |forward|termination|negated|10|Group[209]|Clement
# départ _s de |forward|termination|negated|10|Group[209]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "vérifié" | "contrôlé" | "examiné" | "testé" | "expertisé" | "inspecté"
Var2 -> "pour" | "par"
Trigger_Rule -> "|forward|trigger|negated|10|Group[213]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# vérifié pour |forward|trigger|negated|10|Group[213]|Clement
# vérifié par |forward|trigger|negated|10|Group[213]|Clement
# contrôlé pour |forward|trigger|negated|10|Group[213]|Clement
# contrôlé par |forward|trigger|negated|10|Group[213]|Clement
# examiné pour |forward|trigger|negated|10|Group[213]|Clement
# examiné par |forward|trigger|negated|10|Group[213]|Clement
# testé pour |forward|trigger|negated|10|Group[213]|Clement
# testé par |forward|trigger|negated|10|Group[213]|Clement
# expertisé pour |forward|trigger|negated|10|Group[213]|Clement
# expertisé par |forward|trigger|negated|10|Group[213]|Clement
# inspecté pour |forward|trigger|negated|10|Group[213]|Clement
# inspecté par |forward|trigger|negated|10|Group[213]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "libre"
Var2 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[215]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# libre de |forward|trigger|negated|10|Group[215]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "revenir" | "reparaître" | "reprendre" | "repasser"| "remettre"
Var2 -> "à" | "pour"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[217]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# revenir à |forward|trigger|conditional|30|Group[217]|Clement
# revenir pour |forward|trigger|conditional|30|Group[217]|Clement
# reparaître à |forward|trigger|conditional|30|Group[217]|Clement
# reparaître pour |forward|trigger|conditional|30|Group[217]|Clement
# reprendre à |forward|trigger|conditional|30|Group[217]|Clement
# reprendre pour |forward|trigger|conditional|30|Group[217]|Clement
# repasser à |forward|trigger|conditional|30|Group[217]|Clement
# repasser pour |forward|trigger|conditional|30|Group[217]|Clement
# remettre à |forward|trigger|conditional|30|Group[217]|Clement
# remettre pour |forward|trigger|conditional|30|Group[217]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "se"
Var2 -> "plaint"
Trigger_Rule -> "|both|termination|historical|30|Group[219]|Clement"|"|both|termination|nonpatient|30|Group[220]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# se plaint |both|termination|historical|30|Group[219]|Clement
# se plaint |both|termination|nonpatient|30|Group[220]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Termin Var2 Trigger_Rule
Var1 -> "concerné" | "préoccupé" | "tourmenté" | "anxieux" | "inquiet" | "hanté" | "tracassé" | "absorbé" | "ennuyé" | "angoissé" | "embarrassé" | "occupé" | "agité"
Termin -> "_"|"_s" |"_e" |"_es"
Var2 -> "pour"|"par"|"à propos de"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[221, 223]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# concerné _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# concerné _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# concerné _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# concerné _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# concerné _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# concerné _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# concerné _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# concerné _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# concerné _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# concerné _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# concerné _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# concerné _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# préoccupé _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tourmenté _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# anxieux _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# inquiet _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# hanté _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# tracassé _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# absorbé _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# ennuyé _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# angoissé _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# embarrassé _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# occupé _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _ pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _ par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _ à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _s pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _s par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _s à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _e pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _e par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _e à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _es pour |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _es par |forward|trigger|uncertain|30|Group[221, 223]|Clement
# agité _es à propos de |forward|trigger|uncertain|30|Group[221, 223]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "cohérent" | "homogène" | "harmonieux" | "rationnel" | "compréhensible" | "consistant" | "uni" | "en accord" | "rationnelle" 
Var2 -> "avec"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[225]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# cohérent avec |both|pseudo|uncertain|30|Group[225]|Clement
# homogène avec |both|pseudo|uncertain|30|Group[225]|Clement
# harmonieux avec |both|pseudo|uncertain|30|Group[225]|Clement
# rationnel avec |both|pseudo|uncertain|30|Group[225]|Clement
# compréhensible avec |both|pseudo|uncertain|30|Group[225]|Clement
# consistant avec |both|pseudo|uncertain|30|Group[225]|Clement
# uni avec |both|pseudo|uncertain|30|Group[225]|Clement
# en accord avec |both|pseudo|uncertain|30|Group[225]|Clement
# rationnelle avec |both|pseudo|uncertain|30|Group[225]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "pourrait"
Var2 -> "être"
Var3 -> "soit"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[226]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pourrait être soit |forward|trigger|uncertain|30|Group[226]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pourrait"
Var2 -> "être"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[227]|Clement"|"|forward|trigger|uncertain|30|Group[665]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pourrait être |backward|trigger|uncertain|30|Group[227]|Clement
# pourrait être |forward|trigger|uncertain|30|Group[665]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Termin Trigger_Rule
Var1 -> "pourrait"
Var2 -> "être"
Var3 -> "exclu" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Termin -> "_"|"_e"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[228]|Clement"|"|backward|trigger|uncertain|30|Group[230]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pourrait être exclu _ |forward|trigger|uncertain|30|Group[228]|Clement
# pourrait être exclu _ |backward|trigger|uncertain|30|Group[230]|Clement
# pourrait être exclu _e |forward|trigger|uncertain|30|Group[228]|Clement
# pourrait être exclu _e |backward|trigger|uncertain|30|Group[230]|Clement
# pourrait être repoussé _ |forward|trigger|uncertain|30|Group[228]|Clement
# pourrait être repoussé _ |backward|trigger|uncertain|30|Group[230]|Clement
# pourrait être repoussé _e |forward|trigger|uncertain|30|Group[228]|Clement
# pourrait être repoussé _e |backward|trigger|uncertain|30|Group[230]|Clement
# pourrait être rejeté _ |forward|trigger|uncertain|30|Group[228]|Clement
# pourrait être rejeté _ |backward|trigger|uncertain|30|Group[230]|Clement
# pourrait être rejeté _e |forward|trigger|uncertain|30|Group[228]|Clement
# pourrait être rejeté _e |backward|trigger|uncertain|30|Group[230]|Clement
# pourrait être éliminé _ |forward|trigger|uncertain|30|Group[228]|Clement
# pourrait être éliminé _ |backward|trigger|uncertain|30|Group[230]|Clement
# pourrait être éliminé _e |forward|trigger|uncertain|30|Group[228]|Clement
# pourrait être éliminé _e |backward|trigger|uncertain|30|Group[230]|Clement
# pourrait être proscrit _ |forward|trigger|uncertain|30|Group[228]|Clement
# pourrait être proscrit _ |backward|trigger|uncertain|30|Group[230]|Clement
# pourrait être proscrit _e |forward|trigger|uncertain|30|Group[228]|Clement
# pourrait être proscrit _e |backward|trigger|uncertain|30|Group[230]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Termin Trigger_Rule
Var1 -> "pourraient"
Var2 -> "être"
Var3 -> "exclu" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Termin -> "_s"|"_es"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[228]|Clement"|"|backward|trigger|uncertain|30|Group[230]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pourraient être exclu _s |forward|trigger|uncertain|30|Group[228]|Clement
# pourraient être exclu _s |backward|trigger|uncertain|30|Group[230]|Clement
# pourraient être exclu _es |forward|trigger|uncertain|30|Group[228]|Clement
# pourraient être exclu _es |backward|trigger|uncertain|30|Group[230]|Clement
# pourraient être repoussé _s |forward|trigger|uncertain|30|Group[228]|Clement
# pourraient être repoussé _s |backward|trigger|uncertain|30|Group[230]|Clement
# pourraient être repoussé _es |forward|trigger|uncertain|30|Group[228]|Clement
# pourraient être repoussé _es |backward|trigger|uncertain|30|Group[230]|Clement
# pourraient être rejeté _s |forward|trigger|uncertain|30|Group[228]|Clement
# pourraient être rejeté _s |backward|trigger|uncertain|30|Group[230]|Clement
# pourraient être rejeté _es |forward|trigger|uncertain|30|Group[228]|Clement
# pourraient être rejeté _es |backward|trigger|uncertain|30|Group[230]|Clement
# pourraient être éliminé _s |forward|trigger|uncertain|30|Group[228]|Clement
# pourraient être éliminé _s |backward|trigger|uncertain|30|Group[230]|Clement
# pourraient être éliminé _es |forward|trigger|uncertain|30|Group[228]|Clement
# pourraient être éliminé _es |backward|trigger|uncertain|30|Group[230]|Clement
# pourraient être proscrit _s |forward|trigger|uncertain|30|Group[228]|Clement
# pourraient être proscrit _s |backward|trigger|uncertain|30|Group[230]|Clement
# pourraient être proscrit _es |forward|trigger|uncertain|30|Group[228]|Clement
# pourraient être proscrit _es |backward|trigger|uncertain|30|Group[230]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "décide" | "choisi" | "décréte" 
Trigger_Rule -> "|both|termination|historical|30|Group[245]|Clement"|"|both|termination|nonpatient|30|Group[246]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# décide |both|termination|historical|30|Group[245]|Clement
# décide |both|termination|nonpatient|30|Group[246]|Clement
# choisi |both|termination|historical|30|Group[245]|Clement
# choisi |both|termination|nonpatient|30|Group[246]|Clement
# décréte |both|termination|historical|30|Group[245]|Clement
# décréte |both|termination|nonpatient|30|Group[246]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "a décidé" | "a choisi" | "a décrété" 
Trigger_Rule -> "|both|termination|historical|30|Group[245]|Clement"|"|both|termination|nonpatient|30|Group[246]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a décidé |both|termination|historical|30|Group[245]|Clement
# a décidé |both|termination|nonpatient|30|Group[246]|Clement
# a choisi |both|termination|historical|30|Group[245]|Clement
# a choisi |both|termination|nonpatient|30|Group[246]|Clement
# a décrété |both|termination|historical|30|Group[245]|Clement
# a décrété |both|termination|nonpatient|30|Group[246]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "décline" | "dédaigne" | "atténu" | "tombe"
Trigger_Rule -> "|forward|trigger|negated|10|Group[252]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# décline |forward|trigger|negated|10|Group[252]|Clement
# dédaigne |forward|trigger|negated|10|Group[252]|Clement
# atténu |forward|trigger|negated|10|Group[252]|Clement
# tombe |forward|trigger|negated|10|Group[252]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "a décliné"|"a diminué" | "s'affaibli" | "a baissé" | "s'est atténué" | "s'est atténuée" | "a ralenti" | "s'est tempéré" | "s'est tempérée" | "est tombé" | "est tombée" | "a faibli" | "s'est allégé" | "s'est allégée" | "a décru" | "s'est adouci"| "s'est adoucie"
Trigger_Rule -> "|backward|trigger|negated|10|Group[252]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a décliné |backward|trigger|negated|10|Group[252]|Clement
# a diminué |backward|trigger|negated|10|Group[252]|Clement
# s'affaibli |backward|trigger|negated|10|Group[252]|Clement
# a baissé |backward|trigger|negated|10|Group[252]|Clement
# s'est atténué |backward|trigger|negated|10|Group[252]|Clement
# s'est atténuée |backward|trigger|negated|10|Group[252]|Clement
# a ralenti |backward|trigger|negated|10|Group[252]|Clement
# s'est tempéré |backward|trigger|negated|10|Group[252]|Clement
# s'est tempérée |backward|trigger|negated|10|Group[252]|Clement
# est tombé |backward|trigger|negated|10|Group[252]|Clement
# est tombée |backward|trigger|negated|10|Group[252]|Clement
# a faibli |backward|trigger|negated|10|Group[252]|Clement
# s'est allégé |backward|trigger|negated|10|Group[252]|Clement
# s'est allégée |backward|trigger|negated|10|Group[252]|Clement
# a décru |backward|trigger|negated|10|Group[252]|Clement
# s'est adouci |backward|trigger|negated|10|Group[252]|Clement
# s'est adoucie |backward|trigger|negated|10|Group[252]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "nié" |"dénié" | "renié" | "contredit" | "démentit" | "refusé" | "rejeté" |"réfuté" | "renvoyé" | "contesté" | "dédaigné" | "exclu" | "écarté" | "décliné" | "résisté" | "répugné" | "dit non à" | "retoqué" |"désapprouvé" | "opposé" | "opposée"
Trigger_Rule -> "|forward|trigger|negated|10|Group[255]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié |forward|trigger|negated|10|Group[255]|Clement
# dénié |forward|trigger|negated|10|Group[255]|Clement
# renié |forward|trigger|negated|10|Group[255]|Clement
# contredit |forward|trigger|negated|10|Group[255]|Clement
# démentit |forward|trigger|negated|10|Group[255]|Clement
# refusé |forward|trigger|negated|10|Group[255]|Clement
# rejeté |forward|trigger|negated|10|Group[255]|Clement
# réfuté |forward|trigger|negated|10|Group[255]|Clement
# renvoyé |forward|trigger|negated|10|Group[255]|Clement
# contesté |forward|trigger|negated|10|Group[255]|Clement
# dédaigné |forward|trigger|negated|10|Group[255]|Clement
# exclu |forward|trigger|negated|10|Group[255]|Clement
# écarté |forward|trigger|negated|10|Group[255]|Clement
# décliné |forward|trigger|negated|10|Group[255]|Clement
# résisté |forward|trigger|negated|10|Group[255]|Clement
# répugné |forward|trigger|negated|10|Group[255]|Clement
# dit non à |forward|trigger|negated|10|Group[255]|Clement
# retoqué |forward|trigger|negated|10|Group[255]|Clement
# désapprouvé |forward|trigger|negated|10|Group[255]|Clement
# opposé |forward|trigger|negated|10|Group[255]|Clement
# opposée |forward|trigger|negated|10|Group[255]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "nier" |"dénier" | "renier" | "contredire" | "démentir" | "refuser" | "rejeter" |"réfuter" | "renvoyer" | "contester" | "dédaigner" | "exclure" | "écarter" | "décliner" | "résister" | "répugner" | "dire non" | "retoquer" |"désapprouver" | "opposer"
Trigger_Rule -> "|forward|trigger|negated|10|Group[255]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nier |forward|trigger|negated|10|Group[255]|Clement
# dénier |forward|trigger|negated|10|Group[255]|Clement
# renier |forward|trigger|negated|10|Group[255]|Clement
# contredire |forward|trigger|negated|10|Group[255]|Clement
# démentir |forward|trigger|negated|10|Group[255]|Clement
# refuser |forward|trigger|negated|10|Group[255]|Clement
# rejeter |forward|trigger|negated|10|Group[255]|Clement
# réfuter |forward|trigger|negated|10|Group[255]|Clement
# renvoyer |forward|trigger|negated|10|Group[255]|Clement
# contester |forward|trigger|negated|10|Group[255]|Clement
# dédaigner |forward|trigger|negated|10|Group[255]|Clement
# exclure |forward|trigger|negated|10|Group[255]|Clement
# écarter |forward|trigger|negated|10|Group[255]|Clement
# décliner |forward|trigger|negated|10|Group[255]|Clement
# résister |forward|trigger|negated|10|Group[255]|Clement
# répugner |forward|trigger|negated|10|Group[255]|Clement
# dire non |forward|trigger|negated|10|Group[255]|Clement
# retoquer |forward|trigger|negated|10|Group[255]|Clement
# désapprouver |forward|trigger|negated|10|Group[255]|Clement
# opposer |forward|trigger|negated|10|Group[255]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Deter Var2 Var3 Trigger_Rule
Var1 -> "nié" |"dénié" | "renié" | "contredit" | "démentit" | "refusé" | "rejeté" |"réfuté" | "renvoyé" | "contesté" | "dédaigné" | "exclu" | "écarté" | "décliné" | "résisté" | "répugné" | "dit non à" | "retoqué" |"désapprouvé" | "opposé" | "opposée" | "désapprouvé"
Deter -> "tout" | "toute"
Var2 -> "\\w+" 
Var3 -> "significatif" | "important" |"anormale" | "aberrant" | "étonnant" | "inhabituel" | "étrange" | "inaccoutumé" | "singulier" | "insolite" | "irrégulier" | "anomal" | "exceptionnel" | "paradoxal" | "surprenant" | "déséquilibré" | "excentrique" | "courant" | "habituel" | "fréquent" | "connu" | "répandu" | "normal" | "classique" | "présent" | "commune" | "régulier" | "en cours"

Trigger_Rule -> "|forward|trigger|negated|10|Group[257]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# nié tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# nié toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# dénié tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# dénié toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# renié tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# renié toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# contredit tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# contredit toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# démentit tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# démentit toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# refusé tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# refusé toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# rejeté tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# rejeté toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# réfuté tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# réfuté toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# renvoyé tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# renvoyé toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# contesté tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# contesté toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# dédaigné tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# dédaigné toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# exclu tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# exclu toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# exclu toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# exclu toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# exclu toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# exclu toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# exclu toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# exclu toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# exclu toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# exclu toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# ...
# résisté tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# résisté tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# résisté toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# répugné tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# répugné toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# dit non à tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# dit non à toute \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ important |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ connu |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ répandu |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ normal |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ classique |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ présent |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ commune |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ régulier |forward|trigger|negated|10|Group[257]|Clement
# retoqué tout \w+ en cours |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ significatif |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ important |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ anormale |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ aberrant |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ étonnant |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ inhabituel |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ étrange |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ inaccoutumé |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ singulier |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ insolite |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ irrégulier |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ anomal |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ exceptionnel |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ paradoxal |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ surprenant |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ déséquilibré |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ excentrique |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ courant |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ habituel |forward|trigger|negated|10|Group[257]|Clement
# retoqué toute \w+ fréquent |forward|trigger|negated|10|Group[257]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Deter Trigger_Rule
Var1 -> "nié" |"dénié" | "renié" | "contredit" | "démentit" | "refusé" | "rejeté" |"réfuté" | "renvoyé" | "contesté" | "dédaigné" | "exclu" | "écarté" | "décliné" | "résisté à" | "répugné" | "dit non à" | "retoqué" |"désapprouvé" | "opposé" | "opposée"
Deter -> "tout changement" 
Trigger_Rule -> "|forward|trigger|negated|10|Group[260]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié tout changement |forward|trigger|negated|10|Group[260]|Clement
# dénié tout changement |forward|trigger|negated|10|Group[260]|Clement
# renié tout changement |forward|trigger|negated|10|Group[260]|Clement
# contredit tout changement |forward|trigger|negated|10|Group[260]|Clement
# démentit tout changement |forward|trigger|negated|10|Group[260]|Clement
# refusé tout changement |forward|trigger|negated|10|Group[260]|Clement
# rejeté tout changement |forward|trigger|negated|10|Group[260]|Clement
# réfuté tout changement |forward|trigger|negated|10|Group[260]|Clement
# renvoyé tout changement |forward|trigger|negated|10|Group[260]|Clement
# contesté tout changement |forward|trigger|negated|10|Group[260]|Clement
# dédaigné tout changement |forward|trigger|negated|10|Group[260]|Clement
# exclu tout changement |forward|trigger|negated|10|Group[260]|Clement
# écarté tout changement |forward|trigger|negated|10|Group[260]|Clement
# décliné tout changement |forward|trigger|negated|10|Group[260]|Clement
# résisté à tout changement |forward|trigger|negated|10|Group[260]|Clement
# répugné tout changement |forward|trigger|negated|10|Group[260]|Clement
# dit non à tout changement |forward|trigger|negated|10|Group[260]|Clement
# retoqué tout changement |forward|trigger|negated|10|Group[260]|Clement
# désapprouvé tout changement |forward|trigger|negated|10|Group[260]|Clement
# opposé tout changement |forward|trigger|negated|10|Group[260]|Clement
# opposée tout changement |forward|trigger|negated|10|Group[260]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Trigger_Rule
Var1 -> "nié" |"dénié" | "renié" | "contredit" | "démentit" | "refusé" | "rejeté" |"réfuté" | "renvoyé"  | "exclu" | "écarté" | "décliné" | "résisté à" | "dit non à" | "retoqué" |"désapprouvé" | "opposé" | "opposée"
Var2 -> "tout risque élevé" | "toute chance" | "tout danger"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# nié toute chance |forward|trigger|negated|10|Group[264]|Clement
# nié tout danger |forward|trigger|negated|10|Group[264]|Clement
# dénié tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# dénié toute chance |forward|trigger|negated|10|Group[264]|Clement
# dénié tout danger |forward|trigger|negated|10|Group[264]|Clement
# renié tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# renié toute chance |forward|trigger|negated|10|Group[264]|Clement
# renié tout danger |forward|trigger|negated|10|Group[264]|Clement
# contredit tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# contredit toute chance |forward|trigger|negated|10|Group[264]|Clement
# contredit tout danger |forward|trigger|negated|10|Group[264]|Clement
# démentit tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# démentit toute chance |forward|trigger|negated|10|Group[264]|Clement
# démentit tout danger |forward|trigger|negated|10|Group[264]|Clement
# refusé tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# refusé toute chance |forward|trigger|negated|10|Group[264]|Clement
# refusé tout danger |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# rejeté toute chance |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout danger |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# réfuté toute chance |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout danger |forward|trigger|negated|10|Group[264]|Clement
# renvoyé tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# renvoyé toute chance |forward|trigger|negated|10|Group[264]|Clement
# renvoyé tout danger |forward|trigger|negated|10|Group[264]|Clement
# exclu tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# exclu toute chance |forward|trigger|negated|10|Group[264]|Clement
# exclu tout danger |forward|trigger|negated|10|Group[264]|Clement
# écarté tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# écarté toute chance |forward|trigger|negated|10|Group[264]|Clement
# écarté tout danger |forward|trigger|negated|10|Group[264]|Clement
# décliné tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# décliné toute chance |forward|trigger|negated|10|Group[264]|Clement
# décliné tout danger |forward|trigger|negated|10|Group[264]|Clement
# résisté à tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# résisté à toute chance |forward|trigger|negated|10|Group[264]|Clement
# résisté à tout danger |forward|trigger|negated|10|Group[264]|Clement
# dit non à tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# dit non à toute chance |forward|trigger|negated|10|Group[264]|Clement
# dit non à tout danger |forward|trigger|negated|10|Group[264]|Clement
# retoqué tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# retoqué toute chance |forward|trigger|negated|10|Group[264]|Clement
# retoqué tout danger |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé toute chance |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout danger |forward|trigger|negated|10|Group[264]|Clement
# opposé tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# opposé toute chance |forward|trigger|negated|10|Group[264]|Clement
# opposé tout danger |forward|trigger|negated|10|Group[264]|Clement
# opposée tout risque élevé |forward|trigger|negated|10|Group[264]|Clement
# opposée toute chance |forward|trigger|negated|10|Group[264]|Clement
# opposée tout danger |forward|trigger|negated|10|Group[264]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "nié" |"dénié" | "renié" | "contredit" | "démentit" | "rejeté" |"réfuté" | "contesté" | "exclu" | "écarté" | "décliné" | "résisté à" | "dit non à" | "retoqué" |"désapprouvé" | "opposé" | "opposée"
Var2 -> "toute récente" | "tout nouveau" | "tout jeune" | "tout récent"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié toute récente |forward|trigger|negated|10|Group[264]|Clement
# nié tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# nié tout jeune |forward|trigger|negated|10|Group[264]|Clement
# nié tout récent |forward|trigger|negated|10|Group[264]|Clement
# dénié toute récente |forward|trigger|negated|10|Group[264]|Clement
# dénié tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# dénié tout jeune |forward|trigger|negated|10|Group[264]|Clement
# dénié tout récent |forward|trigger|negated|10|Group[264]|Clement
# renié toute récente |forward|trigger|negated|10|Group[264]|Clement
# renié tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# renié tout jeune |forward|trigger|negated|10|Group[264]|Clement
# renié tout récent |forward|trigger|negated|10|Group[264]|Clement
# contredit toute récente |forward|trigger|negated|10|Group[264]|Clement
# contredit tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# contredit tout jeune |forward|trigger|negated|10|Group[264]|Clement
# contredit tout récent |forward|trigger|negated|10|Group[264]|Clement
# démentit toute récente |forward|trigger|negated|10|Group[264]|Clement
# démentit tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# démentit tout jeune |forward|trigger|negated|10|Group[264]|Clement
# démentit tout récent |forward|trigger|negated|10|Group[264]|Clement
# rejeté toute récente |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout jeune |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout récent |forward|trigger|negated|10|Group[264]|Clement
# réfuté toute récente |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout jeune |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout récent |forward|trigger|negated|10|Group[264]|Clement
# contesté toute récente |forward|trigger|negated|10|Group[264]|Clement
# contesté tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# contesté tout jeune |forward|trigger|negated|10|Group[264]|Clement
# contesté tout récent |forward|trigger|negated|10|Group[264]|Clement
# exclu toute récente |forward|trigger|negated|10|Group[264]|Clement
# exclu tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# exclu tout jeune |forward|trigger|negated|10|Group[264]|Clement
# exclu tout récent |forward|trigger|negated|10|Group[264]|Clement
# écarté toute récente |forward|trigger|negated|10|Group[264]|Clement
# écarté tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# écarté tout jeune |forward|trigger|negated|10|Group[264]|Clement
# écarté tout récent |forward|trigger|negated|10|Group[264]|Clement
# décliné toute récente |forward|trigger|negated|10|Group[264]|Clement
# décliné tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# décliné tout jeune |forward|trigger|negated|10|Group[264]|Clement
# décliné tout récent |forward|trigger|negated|10|Group[264]|Clement
# résisté à toute récente |forward|trigger|negated|10|Group[264]|Clement
# résisté à tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# résisté à tout jeune |forward|trigger|negated|10|Group[264]|Clement
# résisté à tout récent |forward|trigger|negated|10|Group[264]|Clement
# dit non à toute récente |forward|trigger|negated|10|Group[264]|Clement
# dit non à tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# dit non à tout jeune |forward|trigger|negated|10|Group[264]|Clement
# dit non à tout récent |forward|trigger|negated|10|Group[264]|Clement
# retoqué toute récente |forward|trigger|negated|10|Group[264]|Clement
# retoqué tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# retoqué tout jeune |forward|trigger|negated|10|Group[264]|Clement
# retoqué tout récent |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé toute récente |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout jeune |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout récent |forward|trigger|negated|10|Group[264]|Clement
# opposé toute récente |forward|trigger|negated|10|Group[264]|Clement
# opposé tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# opposé tout jeune |forward|trigger|negated|10|Group[264]|Clement
# opposé tout récent |forward|trigger|negated|10|Group[264]|Clement
# opposée toute récente |forward|trigger|negated|10|Group[264]|Clement
# opposée tout nouveau |forward|trigger|negated|10|Group[264]|Clement
# opposée tout jeune |forward|trigger|negated|10|Group[264]|Clement
# opposée tout récent |forward|trigger|negated|10|Group[264]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "nié" |"dénié" | "renié" | "contredit" | "démentit" | "rejeté" |"réfuté" | "contesté" | "dédaigné" | "exclu" | "écarté"| "désapprouvé"
Var2 -> "tout problème" | "tout ennui" | "tout souci" | "toute complication" | "toute anomalie" | "tout dysfonctionnement" | "tout disfonctionnement" | "tout soucis" | "tout trouble" | "tout abus" | "tous excès" | "toutes exagérations" | "tous débordements"  | "toutes débauches"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié tout problème |forward|trigger|negated|10|Group[264]|Clement
# nié tout ennui |forward|trigger|negated|10|Group[264]|Clement
# nié tout souci |forward|trigger|negated|10|Group[264]|Clement
# nié toute complication |forward|trigger|negated|10|Group[264]|Clement
# nié toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# nié tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# nié tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# nié tout soucis |forward|trigger|negated|10|Group[264]|Clement
# nié tout trouble |forward|trigger|negated|10|Group[264]|Clement
# nié tout abus |forward|trigger|negated|10|Group[264]|Clement
# nié tous excès |forward|trigger|negated|10|Group[264]|Clement
# nié toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# nié tous débordements |forward|trigger|negated|10|Group[264]|Clement
# nié toutes débauches |forward|trigger|negated|10|Group[264]|Clement
# dénié tout problème |forward|trigger|negated|10|Group[264]|Clement
# dénié tout ennui |forward|trigger|negated|10|Group[264]|Clement
# dénié tout souci |forward|trigger|negated|10|Group[264]|Clement
# dénié toute complication |forward|trigger|negated|10|Group[264]|Clement
# dénié toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# dénié tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# dénié tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# dénié tout soucis |forward|trigger|negated|10|Group[264]|Clement
# dénié tout trouble |forward|trigger|negated|10|Group[264]|Clement
# dénié tout abus |forward|trigger|negated|10|Group[264]|Clement
# dénié tous excès |forward|trigger|negated|10|Group[264]|Clement
# dénié toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# dénié tous débordements |forward|trigger|negated|10|Group[264]|Clement
# dénié toutes débauches |forward|trigger|negated|10|Group[264]|Clement
# renié tout problème |forward|trigger|negated|10|Group[264]|Clement
# renié tout ennui |forward|trigger|negated|10|Group[264]|Clement
# renié tout souci |forward|trigger|negated|10|Group[264]|Clement
# renié toute complication |forward|trigger|negated|10|Group[264]|Clement
# renié toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# renié tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# renié tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# renié tout soucis |forward|trigger|negated|10|Group[264]|Clement
# renié tout trouble |forward|trigger|negated|10|Group[264]|Clement
# renié tout abus |forward|trigger|negated|10|Group[264]|Clement
# renié tous excès |forward|trigger|negated|10|Group[264]|Clement
# renié toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# renié tous débordements |forward|trigger|negated|10|Group[264]|Clement
# renié toutes débauches |forward|trigger|negated|10|Group[264]|Clement
# contredit tout problème |forward|trigger|negated|10|Group[264]|Clement
# contredit tout ennui |forward|trigger|negated|10|Group[264]|Clement
# contredit tout souci |forward|trigger|negated|10|Group[264]|Clement
# contredit toute complication |forward|trigger|negated|10|Group[264]|Clement
# contredit toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# contredit tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# contredit tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# contredit tout soucis |forward|trigger|negated|10|Group[264]|Clement
# contredit tout trouble |forward|trigger|negated|10|Group[264]|Clement
# contredit tout abus |forward|trigger|negated|10|Group[264]|Clement
# contredit tous excès |forward|trigger|negated|10|Group[264]|Clement
# contredit toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# contredit tous débordements |forward|trigger|negated|10|Group[264]|Clement
# contredit toutes débauches |forward|trigger|negated|10|Group[264]|Clement
# démentit tout problème |forward|trigger|negated|10|Group[264]|Clement
# démentit tout ennui |forward|trigger|negated|10|Group[264]|Clement
# démentit tout souci |forward|trigger|negated|10|Group[264]|Clement
# démentit toute complication |forward|trigger|negated|10|Group[264]|Clement
# démentit toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# démentit tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# démentit tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# démentit tout soucis |forward|trigger|negated|10|Group[264]|Clement
# démentit tout trouble |forward|trigger|negated|10|Group[264]|Clement
# démentit tout abus |forward|trigger|negated|10|Group[264]|Clement
# démentit tous excès |forward|trigger|negated|10|Group[264]|Clement
# démentit toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# démentit tous débordements |forward|trigger|negated|10|Group[264]|Clement
# démentit toutes débauches |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout problème |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout ennui |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout souci |forward|trigger|negated|10|Group[264]|Clement
# rejeté toute complication |forward|trigger|negated|10|Group[264]|Clement
# rejeté toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout soucis |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout trouble |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout abus |forward|trigger|negated|10|Group[264]|Clement
# rejeté tous excès |forward|trigger|negated|10|Group[264]|Clement
# rejeté toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# rejeté tous débordements |forward|trigger|negated|10|Group[264]|Clement
# rejeté toutes débauches |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout problème |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout ennui |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout souci |forward|trigger|negated|10|Group[264]|Clement
# réfuté toute complication |forward|trigger|negated|10|Group[264]|Clement
# réfuté toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout soucis |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout trouble |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout abus |forward|trigger|negated|10|Group[264]|Clement
# réfuté tous excès |forward|trigger|negated|10|Group[264]|Clement
# réfuté toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# réfuté tous débordements |forward|trigger|negated|10|Group[264]|Clement
# réfuté toutes débauches |forward|trigger|negated|10|Group[264]|Clement
# contesté tout problème |forward|trigger|negated|10|Group[264]|Clement
# contesté tout ennui |forward|trigger|negated|10|Group[264]|Clement
# contesté tout souci |forward|trigger|negated|10|Group[264]|Clement
# contesté toute complication |forward|trigger|negated|10|Group[264]|Clement
# contesté toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# contesté tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# contesté tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# contesté tout soucis |forward|trigger|negated|10|Group[264]|Clement
# contesté tout trouble |forward|trigger|negated|10|Group[264]|Clement
# contesté tout abus |forward|trigger|negated|10|Group[264]|Clement
# contesté tous excès |forward|trigger|negated|10|Group[264]|Clement
# contesté toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# contesté tous débordements |forward|trigger|negated|10|Group[264]|Clement
# contesté toutes débauches |forward|trigger|negated|10|Group[264]|Clement
# dédaigné tout problème |forward|trigger|negated|10|Group[264]|Clement
# dédaigné tout ennui |forward|trigger|negated|10|Group[264]|Clement
# dédaigné tout souci |forward|trigger|negated|10|Group[264]|Clement
# dédaigné toute complication |forward|trigger|negated|10|Group[264]|Clement
# dédaigné toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# dédaigné tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# dédaigné tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# dédaigné tout soucis |forward|trigger|negated|10|Group[264]|Clement
# dédaigné tout trouble |forward|trigger|negated|10|Group[264]|Clement
# dédaigné tout abus |forward|trigger|negated|10|Group[264]|Clement
# dédaigné tous excès |forward|trigger|negated|10|Group[264]|Clement
# dédaigné toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# dédaigné tous débordements |forward|trigger|negated|10|Group[264]|Clement
# dédaigné toutes débauches |forward|trigger|negated|10|Group[264]|Clement
# exclu tout problème |forward|trigger|negated|10|Group[264]|Clement
# exclu tout ennui |forward|trigger|negated|10|Group[264]|Clement
# exclu tout souci |forward|trigger|negated|10|Group[264]|Clement
# exclu toute complication |forward|trigger|negated|10|Group[264]|Clement
# exclu toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# exclu tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# exclu tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# exclu tout soucis |forward|trigger|negated|10|Group[264]|Clement
# exclu tout trouble |forward|trigger|negated|10|Group[264]|Clement
# exclu tout abus |forward|trigger|negated|10|Group[264]|Clement
# exclu tous excès |forward|trigger|negated|10|Group[264]|Clement
# exclu toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# exclu tous débordements |forward|trigger|negated|10|Group[264]|Clement
# exclu toutes débauches |forward|trigger|negated|10|Group[264]|Clement
# écarté tout problème |forward|trigger|negated|10|Group[264]|Clement
# écarté tout ennui |forward|trigger|negated|10|Group[264]|Clement
# écarté tout souci |forward|trigger|negated|10|Group[264]|Clement
# écarté toute complication |forward|trigger|negated|10|Group[264]|Clement
# écarté toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# écarté tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# écarté tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# écarté tout soucis |forward|trigger|negated|10|Group[264]|Clement
# écarté tout trouble |forward|trigger|negated|10|Group[264]|Clement
# écarté tout abus |forward|trigger|negated|10|Group[264]|Clement
# écarté tous excès |forward|trigger|negated|10|Group[264]|Clement
# écarté toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# écarté tous débordements |forward|trigger|negated|10|Group[264]|Clement
# écarté toutes débauches |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout problème |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout ennui |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout souci |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé toute complication |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé toute anomalie |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout dysfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout disfonctionnement |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout soucis |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout trouble |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tout abus |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tous excès |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé toutes exagérations |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé tous débordements |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé toutes débauches |forward|trigger|negated|10|Group[264]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "nié" |"dénié" | "renié" | "contredit" | "démentit" | "refusé" | "rejeté" |"réfuté" | "contesté" | "exclu" | "écarté"
Var2 -> "toute histoire" | "tout passé" | "tout souvenir" | "toute historique" | "tout antécédent" | "tout symptôme"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié toute histoire |forward|trigger|negated|10|Group[264]|Clement
# nié tout passé |forward|trigger|negated|10|Group[264]|Clement
# nié tout souvenir |forward|trigger|negated|10|Group[264]|Clement
# nié toute historique |forward|trigger|negated|10|Group[264]|Clement
# nié tout antécédent |forward|trigger|negated|10|Group[264]|Clement
# nié tout symptôme |forward|trigger|negated|10|Group[264]|Clement
# dénié toute histoire |forward|trigger|negated|10|Group[264]|Clement
# dénié tout passé |forward|trigger|negated|10|Group[264]|Clement
# dénié tout souvenir |forward|trigger|negated|10|Group[264]|Clement
# dénié toute historique |forward|trigger|negated|10|Group[264]|Clement
# dénié tout antécédent |forward|trigger|negated|10|Group[264]|Clement
# dénié tout symptôme |forward|trigger|negated|10|Group[264]|Clement
# renié toute histoire |forward|trigger|negated|10|Group[264]|Clement
# renié tout passé |forward|trigger|negated|10|Group[264]|Clement
# renié tout souvenir |forward|trigger|negated|10|Group[264]|Clement
# renié toute historique |forward|trigger|negated|10|Group[264]|Clement
# renié tout antécédent |forward|trigger|negated|10|Group[264]|Clement
# renié tout symptôme |forward|trigger|negated|10|Group[264]|Clement
# contredit toute histoire |forward|trigger|negated|10|Group[264]|Clement
# contredit tout passé |forward|trigger|negated|10|Group[264]|Clement
# contredit tout souvenir |forward|trigger|negated|10|Group[264]|Clement
# contredit toute historique |forward|trigger|negated|10|Group[264]|Clement
# contredit tout antécédent |forward|trigger|negated|10|Group[264]|Clement
# contredit tout symptôme |forward|trigger|negated|10|Group[264]|Clement
# démentit toute histoire |forward|trigger|negated|10|Group[264]|Clement
# démentit tout passé |forward|trigger|negated|10|Group[264]|Clement
# démentit tout souvenir |forward|trigger|negated|10|Group[264]|Clement
# démentit toute historique |forward|trigger|negated|10|Group[264]|Clement
# démentit tout antécédent |forward|trigger|negated|10|Group[264]|Clement
# démentit tout symptôme |forward|trigger|negated|10|Group[264]|Clement
# refusé toute histoire |forward|trigger|negated|10|Group[264]|Clement
# refusé tout passé |forward|trigger|negated|10|Group[264]|Clement
# refusé tout souvenir |forward|trigger|negated|10|Group[264]|Clement
# refusé toute historique |forward|trigger|negated|10|Group[264]|Clement
# refusé tout antécédent |forward|trigger|negated|10|Group[264]|Clement
# refusé tout symptôme |forward|trigger|negated|10|Group[264]|Clement
# rejeté toute histoire |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout passé |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout souvenir |forward|trigger|negated|10|Group[264]|Clement
# rejeté toute historique |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout antécédent |forward|trigger|negated|10|Group[264]|Clement
# rejeté tout symptôme |forward|trigger|negated|10|Group[264]|Clement
# réfuté toute histoire |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout passé |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout souvenir |forward|trigger|negated|10|Group[264]|Clement
# réfuté toute historique |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout antécédent |forward|trigger|negated|10|Group[264]|Clement
# réfuté tout symptôme |forward|trigger|negated|10|Group[264]|Clement
# contesté toute histoire |forward|trigger|negated|10|Group[264]|Clement
# contesté tout passé |forward|trigger|negated|10|Group[264]|Clement
# contesté tout souvenir |forward|trigger|negated|10|Group[264]|Clement
# contesté toute historique |forward|trigger|negated|10|Group[264]|Clement
# contesté tout antécédent |forward|trigger|negated|10|Group[264]|Clement
# contesté tout symptôme |forward|trigger|negated|10|Group[264]|Clement
# exclu toute histoire |forward|trigger|negated|10|Group[264]|Clement
# exclu tout passé |forward|trigger|negated|10|Group[264]|Clement
# exclu tout souvenir |forward|trigger|negated|10|Group[264]|Clement
# exclu toute historique |forward|trigger|negated|10|Group[264]|Clement
# exclu tout antécédent |forward|trigger|negated|10|Group[264]|Clement
# exclu tout symptôme |forward|trigger|negated|10|Group[264]|Clement
# écarté toute histoire |forward|trigger|negated|10|Group[264]|Clement
# écarté tout passé |forward|trigger|negated|10|Group[264]|Clement
# écarté tout souvenir |forward|trigger|negated|10|Group[264]|Clement
# écarté toute historique |forward|trigger|negated|10|Group[264]|Clement
# écarté tout antécédent |forward|trigger|negated|10|Group[264]|Clement
# écarté tout symptôme |forward|trigger|negated|10|Group[264]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "nié" |"dénié" | "renié" | "contredit" | "démentit" | "rejeté" |"réfuté" | "contesté" | "dédaigné" | "exclu" | "écarté"| "désapprouvé"
Var2 -> "des problèmes" | "des ennuis" | "des soucis" | "des complications" | "des histoires" | "des anomalies" | "des dysfonctionnements" | "des disfonctionnements" | "des soucis" | "des troubles" | "des abus" | "des excès" | "des exagérations" | "des débordements" | "trop de" | "des débauches"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié des problèmes |forward|trigger|negated|10|Group[264]|Clement
# nié des ennuis |forward|trigger|negated|10|Group[264]|Clement
# nié des soucis |forward|trigger|negated|10|Group[264]|Clement
# nié des complications |forward|trigger|negated|10|Group[264]|Clement
# nié des histoires |forward|trigger|negated|10|Group[264]|Clement
# nié des anomalies |forward|trigger|negated|10|Group[264]|Clement
# nié des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# nié des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# nié des soucis |forward|trigger|negated|10|Group[264]|Clement
# nié des troubles |forward|trigger|negated|10|Group[264]|Clement
# nié des abus |forward|trigger|negated|10|Group[264]|Clement
# nié des excès |forward|trigger|negated|10|Group[264]|Clement
# nié des exagérations |forward|trigger|negated|10|Group[264]|Clement
# nié des débordements |forward|trigger|negated|10|Group[264]|Clement
# nié trop de |forward|trigger|negated|10|Group[264]|Clement
# nié des débauches |forward|trigger|negated|10|Group[264]|Clement
# dénié des problèmes |forward|trigger|negated|10|Group[264]|Clement
# dénié des ennuis |forward|trigger|negated|10|Group[264]|Clement
# dénié des soucis |forward|trigger|negated|10|Group[264]|Clement
# dénié des complications |forward|trigger|negated|10|Group[264]|Clement
# dénié des histoires |forward|trigger|negated|10|Group[264]|Clement
# dénié des anomalies |forward|trigger|negated|10|Group[264]|Clement
# dénié des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# dénié des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# dénié des soucis |forward|trigger|negated|10|Group[264]|Clement
# dénié des troubles |forward|trigger|negated|10|Group[264]|Clement
# dénié des abus |forward|trigger|negated|10|Group[264]|Clement
# dénié des excès |forward|trigger|negated|10|Group[264]|Clement
# dénié des exagérations |forward|trigger|negated|10|Group[264]|Clement
# dénié des débordements |forward|trigger|negated|10|Group[264]|Clement
# dénié trop de |forward|trigger|negated|10|Group[264]|Clement
# dénié des débauches |forward|trigger|negated|10|Group[264]|Clement
# renié des problèmes |forward|trigger|negated|10|Group[264]|Clement
# renié des ennuis |forward|trigger|negated|10|Group[264]|Clement
# renié des soucis |forward|trigger|negated|10|Group[264]|Clement
# renié des complications |forward|trigger|negated|10|Group[264]|Clement
# renié des histoires |forward|trigger|negated|10|Group[264]|Clement
# renié des anomalies |forward|trigger|negated|10|Group[264]|Clement
# renié des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# renié des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# renié des soucis |forward|trigger|negated|10|Group[264]|Clement
# renié des troubles |forward|trigger|negated|10|Group[264]|Clement
# renié des abus |forward|trigger|negated|10|Group[264]|Clement
# renié des excès |forward|trigger|negated|10|Group[264]|Clement
# renié des exagérations |forward|trigger|negated|10|Group[264]|Clement
# renié des débordements |forward|trigger|negated|10|Group[264]|Clement
# renié trop de |forward|trigger|negated|10|Group[264]|Clement
# renié des débauches |forward|trigger|negated|10|Group[264]|Clement
# contredit des problèmes |forward|trigger|negated|10|Group[264]|Clement
# contredit des ennuis |forward|trigger|negated|10|Group[264]|Clement
# contredit des soucis |forward|trigger|negated|10|Group[264]|Clement
# contredit des complications |forward|trigger|negated|10|Group[264]|Clement
# contredit des histoires |forward|trigger|negated|10|Group[264]|Clement
# contredit des anomalies |forward|trigger|negated|10|Group[264]|Clement
# contredit des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# contredit des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# contredit des soucis |forward|trigger|negated|10|Group[264]|Clement
# contredit des troubles |forward|trigger|negated|10|Group[264]|Clement
# contredit des abus |forward|trigger|negated|10|Group[264]|Clement
# contredit des excès |forward|trigger|negated|10|Group[264]|Clement
# contredit des exagérations |forward|trigger|negated|10|Group[264]|Clement
# contredit des débordements |forward|trigger|negated|10|Group[264]|Clement
# contredit trop de |forward|trigger|negated|10|Group[264]|Clement
# contredit des débauches |forward|trigger|negated|10|Group[264]|Clement
# démentit des problèmes |forward|trigger|negated|10|Group[264]|Clement
# démentit des ennuis |forward|trigger|negated|10|Group[264]|Clement
# démentit des soucis |forward|trigger|negated|10|Group[264]|Clement
# démentit des complications |forward|trigger|negated|10|Group[264]|Clement
# démentit des histoires |forward|trigger|negated|10|Group[264]|Clement
# démentit des anomalies |forward|trigger|negated|10|Group[264]|Clement
# démentit des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# démentit des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# démentit des soucis |forward|trigger|negated|10|Group[264]|Clement
# démentit des troubles |forward|trigger|negated|10|Group[264]|Clement
# démentit des abus |forward|trigger|negated|10|Group[264]|Clement
# démentit des excès |forward|trigger|negated|10|Group[264]|Clement
# démentit des exagérations |forward|trigger|negated|10|Group[264]|Clement
# démentit des débordements |forward|trigger|negated|10|Group[264]|Clement
# démentit trop de |forward|trigger|negated|10|Group[264]|Clement
# démentit des débauches |forward|trigger|negated|10|Group[264]|Clement
# rejeté des problèmes |forward|trigger|negated|10|Group[264]|Clement
# rejeté des ennuis |forward|trigger|negated|10|Group[264]|Clement
# rejeté des soucis |forward|trigger|negated|10|Group[264]|Clement
# rejeté des complications |forward|trigger|negated|10|Group[264]|Clement
# rejeté des histoires |forward|trigger|negated|10|Group[264]|Clement
# rejeté des anomalies |forward|trigger|negated|10|Group[264]|Clement
# rejeté des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# rejeté des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# rejeté des soucis |forward|trigger|negated|10|Group[264]|Clement
# rejeté des troubles |forward|trigger|negated|10|Group[264]|Clement
# rejeté des abus |forward|trigger|negated|10|Group[264]|Clement
# rejeté des excès |forward|trigger|negated|10|Group[264]|Clement
# rejeté des exagérations |forward|trigger|negated|10|Group[264]|Clement
# rejeté des débordements |forward|trigger|negated|10|Group[264]|Clement
# rejeté trop de |forward|trigger|negated|10|Group[264]|Clement
# rejeté des débauches |forward|trigger|negated|10|Group[264]|Clement
# réfuté des problèmes |forward|trigger|negated|10|Group[264]|Clement
# réfuté des ennuis |forward|trigger|negated|10|Group[264]|Clement
# réfuté des soucis |forward|trigger|negated|10|Group[264]|Clement
# réfuté des complications |forward|trigger|negated|10|Group[264]|Clement
# réfuté des histoires |forward|trigger|negated|10|Group[264]|Clement
# réfuté des anomalies |forward|trigger|negated|10|Group[264]|Clement
# réfuté des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# réfuté des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# réfuté des soucis |forward|trigger|negated|10|Group[264]|Clement
# réfuté des troubles |forward|trigger|negated|10|Group[264]|Clement
# réfuté des abus |forward|trigger|negated|10|Group[264]|Clement
# réfuté des excès |forward|trigger|negated|10|Group[264]|Clement
# réfuté des exagérations |forward|trigger|negated|10|Group[264]|Clement
# réfuté des débordements |forward|trigger|negated|10|Group[264]|Clement
# réfuté trop de |forward|trigger|negated|10|Group[264]|Clement
# réfuté des débauches |forward|trigger|negated|10|Group[264]|Clement
# contesté des problèmes |forward|trigger|negated|10|Group[264]|Clement
# contesté des ennuis |forward|trigger|negated|10|Group[264]|Clement
# contesté des soucis |forward|trigger|negated|10|Group[264]|Clement
# contesté des complications |forward|trigger|negated|10|Group[264]|Clement
# contesté des histoires |forward|trigger|negated|10|Group[264]|Clement
# contesté des anomalies |forward|trigger|negated|10|Group[264]|Clement
# contesté des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# contesté des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# contesté des soucis |forward|trigger|negated|10|Group[264]|Clement
# contesté des troubles |forward|trigger|negated|10|Group[264]|Clement
# contesté des abus |forward|trigger|negated|10|Group[264]|Clement
# contesté des excès |forward|trigger|negated|10|Group[264]|Clement
# contesté des exagérations |forward|trigger|negated|10|Group[264]|Clement
# contesté des débordements |forward|trigger|negated|10|Group[264]|Clement
# contesté trop de |forward|trigger|negated|10|Group[264]|Clement
# contesté des débauches |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des problèmes |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des ennuis |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des soucis |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des complications |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des histoires |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des anomalies |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des soucis |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des troubles |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des abus |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des excès |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des exagérations |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des débordements |forward|trigger|negated|10|Group[264]|Clement
# dédaigné trop de |forward|trigger|negated|10|Group[264]|Clement
# dédaigné des débauches |forward|trigger|negated|10|Group[264]|Clement
# exclu des problèmes |forward|trigger|negated|10|Group[264]|Clement
# exclu des ennuis |forward|trigger|negated|10|Group[264]|Clement
# exclu des soucis |forward|trigger|negated|10|Group[264]|Clement
# exclu des complications |forward|trigger|negated|10|Group[264]|Clement
# exclu des histoires |forward|trigger|negated|10|Group[264]|Clement
# exclu des anomalies |forward|trigger|negated|10|Group[264]|Clement
# exclu des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# exclu des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# exclu des soucis |forward|trigger|negated|10|Group[264]|Clement
# exclu des troubles |forward|trigger|negated|10|Group[264]|Clement
# exclu des abus |forward|trigger|negated|10|Group[264]|Clement
# exclu des excès |forward|trigger|negated|10|Group[264]|Clement
# exclu des exagérations |forward|trigger|negated|10|Group[264]|Clement
# exclu des débordements |forward|trigger|negated|10|Group[264]|Clement
# exclu trop de |forward|trigger|negated|10|Group[264]|Clement
# exclu des débauches |forward|trigger|negated|10|Group[264]|Clement
# écarté des problèmes |forward|trigger|negated|10|Group[264]|Clement
# écarté des ennuis |forward|trigger|negated|10|Group[264]|Clement
# écarté des soucis |forward|trigger|negated|10|Group[264]|Clement
# écarté des complications |forward|trigger|negated|10|Group[264]|Clement
# écarté des histoires |forward|trigger|negated|10|Group[264]|Clement
# écarté des anomalies |forward|trigger|negated|10|Group[264]|Clement
# écarté des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# écarté des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# écarté des soucis |forward|trigger|negated|10|Group[264]|Clement
# écarté des troubles |forward|trigger|negated|10|Group[264]|Clement
# écarté des abus |forward|trigger|negated|10|Group[264]|Clement
# écarté des excès |forward|trigger|negated|10|Group[264]|Clement
# écarté des exagérations |forward|trigger|negated|10|Group[264]|Clement
# écarté des débordements |forward|trigger|negated|10|Group[264]|Clement
# écarté trop de |forward|trigger|negated|10|Group[264]|Clement
# écarté des débauches |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des problèmes |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des ennuis |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des soucis |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des complications |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des histoires |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des anomalies |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des dysfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des disfonctionnements |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des soucis |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des troubles |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des abus |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des excès |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des exagérations |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des débordements |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé trop de |forward|trigger|negated|10|Group[264]|Clement
# désapprouvé des débauches |forward|trigger|negated|10|Group[264]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "nié" |"dénié" | "renié" | "contredit" | "démentit" | "refusé" | "rejeté" |"réfuté" | "contesté" | "exclu" | "écarté"
Var2 -> "des symptômes" | "des marques" | "des indices" | "des manifestations" | "des présages" | "un syndrome" | "des stigmates" | "des signes"
Trigger_Rule -> "|forward|trigger|negated|10|Group[295]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié des symptômes |forward|trigger|negated|10|Group[295]|Clement
# nié des marques |forward|trigger|negated|10|Group[295]|Clement
# nié des indices |forward|trigger|negated|10|Group[295]|Clement
# nié des manifestations |forward|trigger|negated|10|Group[295]|Clement
# nié des présages |forward|trigger|negated|10|Group[295]|Clement
# nié un syndrome |forward|trigger|negated|10|Group[295]|Clement
# nié des stigmates |forward|trigger|negated|10|Group[295]|Clement
# nié des signes |forward|trigger|negated|10|Group[295]|Clement
# dénié des symptômes |forward|trigger|negated|10|Group[295]|Clement
# dénié des marques |forward|trigger|negated|10|Group[295]|Clement
# dénié des indices |forward|trigger|negated|10|Group[295]|Clement
# dénié des manifestations |forward|trigger|negated|10|Group[295]|Clement
# dénié des présages |forward|trigger|negated|10|Group[295]|Clement
# dénié un syndrome |forward|trigger|negated|10|Group[295]|Clement
# dénié des stigmates |forward|trigger|negated|10|Group[295]|Clement
# dénié des signes |forward|trigger|negated|10|Group[295]|Clement
# renié des symptômes |forward|trigger|negated|10|Group[295]|Clement
# renié des marques |forward|trigger|negated|10|Group[295]|Clement
# renié des indices |forward|trigger|negated|10|Group[295]|Clement
# renié des manifestations |forward|trigger|negated|10|Group[295]|Clement
# renié des présages |forward|trigger|negated|10|Group[295]|Clement
# renié un syndrome |forward|trigger|negated|10|Group[295]|Clement
# renié des stigmates |forward|trigger|negated|10|Group[295]|Clement
# renié des signes |forward|trigger|negated|10|Group[295]|Clement
# contredit des symptômes |forward|trigger|negated|10|Group[295]|Clement
# contredit des marques |forward|trigger|negated|10|Group[295]|Clement
# contredit des indices |forward|trigger|negated|10|Group[295]|Clement
# contredit des manifestations |forward|trigger|negated|10|Group[295]|Clement
# contredit des présages |forward|trigger|negated|10|Group[295]|Clement
# contredit un syndrome |forward|trigger|negated|10|Group[295]|Clement
# contredit des stigmates |forward|trigger|negated|10|Group[295]|Clement
# contredit des signes |forward|trigger|negated|10|Group[295]|Clement
# démentit des symptômes |forward|trigger|negated|10|Group[295]|Clement
# démentit des marques |forward|trigger|negated|10|Group[295]|Clement
# démentit des indices |forward|trigger|negated|10|Group[295]|Clement
# démentit des manifestations |forward|trigger|negated|10|Group[295]|Clement
# démentit des présages |forward|trigger|negated|10|Group[295]|Clement
# démentit un syndrome |forward|trigger|negated|10|Group[295]|Clement
# démentit des stigmates |forward|trigger|negated|10|Group[295]|Clement
# démentit des signes |forward|trigger|negated|10|Group[295]|Clement
# refusé des symptômes |forward|trigger|negated|10|Group[295]|Clement
# refusé des marques |forward|trigger|negated|10|Group[295]|Clement
# refusé des indices |forward|trigger|negated|10|Group[295]|Clement
# refusé des manifestations |forward|trigger|negated|10|Group[295]|Clement
# refusé des présages |forward|trigger|negated|10|Group[295]|Clement
# refusé un syndrome |forward|trigger|negated|10|Group[295]|Clement
# refusé des stigmates |forward|trigger|negated|10|Group[295]|Clement
# refusé des signes |forward|trigger|negated|10|Group[295]|Clement
# rejeté des symptômes |forward|trigger|negated|10|Group[295]|Clement
# rejeté des marques |forward|trigger|negated|10|Group[295]|Clement
# rejeté des indices |forward|trigger|negated|10|Group[295]|Clement
# rejeté des manifestations |forward|trigger|negated|10|Group[295]|Clement
# rejeté des présages |forward|trigger|negated|10|Group[295]|Clement
# rejeté un syndrome |forward|trigger|negated|10|Group[295]|Clement
# rejeté des stigmates |forward|trigger|negated|10|Group[295]|Clement
# rejeté des signes |forward|trigger|negated|10|Group[295]|Clement
# réfuté des symptômes |forward|trigger|negated|10|Group[295]|Clement
# réfuté des marques |forward|trigger|negated|10|Group[295]|Clement
# réfuté des indices |forward|trigger|negated|10|Group[295]|Clement
# réfuté des manifestations |forward|trigger|negated|10|Group[295]|Clement
# réfuté des présages |forward|trigger|negated|10|Group[295]|Clement
# réfuté un syndrome |forward|trigger|negated|10|Group[295]|Clement
# réfuté des stigmates |forward|trigger|negated|10|Group[295]|Clement
# réfuté des signes |forward|trigger|negated|10|Group[295]|Clement
# contesté des symptômes |forward|trigger|negated|10|Group[295]|Clement
# contesté des marques |forward|trigger|negated|10|Group[295]|Clement
# contesté des indices |forward|trigger|negated|10|Group[295]|Clement
# contesté des manifestations |forward|trigger|negated|10|Group[295]|Clement
# contesté des présages |forward|trigger|negated|10|Group[295]|Clement
# contesté un syndrome |forward|trigger|negated|10|Group[295]|Clement
# contesté des stigmates |forward|trigger|negated|10|Group[295]|Clement
# contesté des signes |forward|trigger|negated|10|Group[295]|Clement
# exclu des symptômes |forward|trigger|negated|10|Group[295]|Clement
# exclu des marques |forward|trigger|negated|10|Group[295]|Clement
# exclu des indices |forward|trigger|negated|10|Group[295]|Clement
# exclu des manifestations |forward|trigger|negated|10|Group[295]|Clement
# exclu des présages |forward|trigger|negated|10|Group[295]|Clement
# exclu un syndrome |forward|trigger|negated|10|Group[295]|Clement
# exclu des stigmates |forward|trigger|negated|10|Group[295]|Clement
# exclu des signes |forward|trigger|negated|10|Group[295]|Clement
# écarté des symptômes |forward|trigger|negated|10|Group[295]|Clement
# écarté des marques |forward|trigger|negated|10|Group[295]|Clement
# écarté des indices |forward|trigger|negated|10|Group[295]|Clement
# écarté des manifestations |forward|trigger|negated|10|Group[295]|Clement
# écarté des présages |forward|trigger|negated|10|Group[295]|Clement
# écarté un syndrome |forward|trigger|negated|10|Group[295]|Clement
# écarté des stigmates |forward|trigger|negated|10|Group[295]|Clement
# écarté des signes |forward|trigger|negated|10|Group[295]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Trigger_Rule
Auxiliary1 -> "a"
Var1 -> "nié" |"dénié" | "renié" | "contredit" | "démentit" | "rejeté" |"réfuté" | "contesté" | "exclu" | "écarté" |"désapprouvé" | "opposé" | "opposée"
Var2 -> "qu'il"
Var3 -> "y avait" |"avait" |"y ait" |"y en ait" | "n'y ait"| "n'y en ait"
Trigger_Rule -> "|forward|trigger|negated|10|Group[297]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# nié qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# nié qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# nié qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# nié qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# nié qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# dénié qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# dénié qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# dénié qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# dénié qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# dénié qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# dénié qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# renié qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# renié qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# renié qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# renié qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# renié qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# renié qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# contredit qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# contredit qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# contredit qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# contredit qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# contredit qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# contredit qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# démentit qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# démentit qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# démentit qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# démentit qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# démentit qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# démentit qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# rejeté qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# rejeté qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# rejeté qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# rejeté qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# rejeté qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# rejeté qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# réfuté qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# réfuté qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# réfuté qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# réfuté qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# réfuté qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# réfuté qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# contesté qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# contesté qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# contesté qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# contesté qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# contesté qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# contesté qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# exclu qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# exclu qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# exclu qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# exclu qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# exclu qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# exclu qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# écarté qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# écarté qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# écarté qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# écarté qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# écarté qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# écarté qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# désapprouvé qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# désapprouvé qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# désapprouvé qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# désapprouvé qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# désapprouvé qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# désapprouvé qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# opposé qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# opposé qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# opposé qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# opposé qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# opposé qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# opposé qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement
# opposée qu'il y avait |forward|trigger|negated|10|Group[297]|Clement
# opposée qu'il avait |forward|trigger|negated|10|Group[297]|Clement
# opposée qu'il y ait |forward|trigger|negated|10|Group[297]|Clement
# opposée qu'il y en ait |forward|trigger|negated|10|Group[297]|Clement
# opposée qu'il n'y ait |forward|trigger|negated|10|Group[297]|Clement
# opposée qu'il n'y en ait |forward|trigger|negated|10|Group[297]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "nié" |"dénié" | "renié" | "contredit" | "démentit" | "refusé" | "rejeté" |"réfuté" | "renvoyé" | "contesté" | "exclu" | "écarté" | "décliné" | "résisté à" | "répugné" | "dit non à" | "retoqué" |"désapprouvé" | "opposé à" | "opposée à"
Var2 -> "l'utilisation" | "l'emploi" | "le maniement" | "l'usage" | "l'exploitation" | "la consommation" | "l'appel"
Trigger_Rule -> "|forward|trigger|negated|10|Group[329]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# nié l'emploi |forward|trigger|negated|10|Group[329]|Clement
# nié le maniement |forward|trigger|negated|10|Group[329]|Clement
# nié l'usage |forward|trigger|negated|10|Group[329]|Clement
# nié l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# nié la consommation |forward|trigger|negated|10|Group[329]|Clement
# nié l'appel |forward|trigger|negated|10|Group[329]|Clement
# dénié l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# dénié l'emploi |forward|trigger|negated|10|Group[329]|Clement
# dénié le maniement |forward|trigger|negated|10|Group[329]|Clement
# dénié l'usage |forward|trigger|negated|10|Group[329]|Clement
# dénié l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# dénié la consommation |forward|trigger|negated|10|Group[329]|Clement
# dénié l'appel |forward|trigger|negated|10|Group[329]|Clement
# renié l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# renié l'emploi |forward|trigger|negated|10|Group[329]|Clement
# renié le maniement |forward|trigger|negated|10|Group[329]|Clement
# renié l'usage |forward|trigger|negated|10|Group[329]|Clement
# renié l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# renié la consommation |forward|trigger|negated|10|Group[329]|Clement
# renié l'appel |forward|trigger|negated|10|Group[329]|Clement
# contredit l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# contredit l'emploi |forward|trigger|negated|10|Group[329]|Clement
# contredit le maniement |forward|trigger|negated|10|Group[329]|Clement
# contredit l'usage |forward|trigger|negated|10|Group[329]|Clement
# contredit l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# contredit la consommation |forward|trigger|negated|10|Group[329]|Clement
# contredit l'appel |forward|trigger|negated|10|Group[329]|Clement
# démentit l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# démentit l'emploi |forward|trigger|negated|10|Group[329]|Clement
# démentit le maniement |forward|trigger|negated|10|Group[329]|Clement
# démentit l'usage |forward|trigger|negated|10|Group[329]|Clement
# démentit l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# démentit la consommation |forward|trigger|negated|10|Group[329]|Clement
# démentit l'appel |forward|trigger|negated|10|Group[329]|Clement
# refusé l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# refusé l'emploi |forward|trigger|negated|10|Group[329]|Clement
# refusé le maniement |forward|trigger|negated|10|Group[329]|Clement
# refusé l'usage |forward|trigger|negated|10|Group[329]|Clement
# refusé l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# refusé la consommation |forward|trigger|negated|10|Group[329]|Clement
# refusé l'appel |forward|trigger|negated|10|Group[329]|Clement
# rejeté l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# rejeté l'emploi |forward|trigger|negated|10|Group[329]|Clement
# rejeté le maniement |forward|trigger|negated|10|Group[329]|Clement
# rejeté l'usage |forward|trigger|negated|10|Group[329]|Clement
# rejeté l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# rejeté la consommation |forward|trigger|negated|10|Group[329]|Clement
# rejeté l'appel |forward|trigger|negated|10|Group[329]|Clement
# réfuté l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# réfuté l'emploi |forward|trigger|negated|10|Group[329]|Clement
# réfuté le maniement |forward|trigger|negated|10|Group[329]|Clement
# réfuté l'usage |forward|trigger|negated|10|Group[329]|Clement
# réfuté l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# réfuté la consommation |forward|trigger|negated|10|Group[329]|Clement
# réfuté l'appel |forward|trigger|negated|10|Group[329]|Clement
# renvoyé l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# renvoyé l'emploi |forward|trigger|negated|10|Group[329]|Clement
# renvoyé le maniement |forward|trigger|negated|10|Group[329]|Clement
# renvoyé l'usage |forward|trigger|negated|10|Group[329]|Clement
# renvoyé l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# renvoyé la consommation |forward|trigger|negated|10|Group[329]|Clement
# renvoyé l'appel |forward|trigger|negated|10|Group[329]|Clement
# contesté l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# contesté l'emploi |forward|trigger|negated|10|Group[329]|Clement
# contesté le maniement |forward|trigger|negated|10|Group[329]|Clement
# contesté l'usage |forward|trigger|negated|10|Group[329]|Clement
# contesté l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# contesté la consommation |forward|trigger|negated|10|Group[329]|Clement
# contesté l'appel |forward|trigger|negated|10|Group[329]|Clement
# exclu l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# exclu l'emploi |forward|trigger|negated|10|Group[329]|Clement
# exclu le maniement |forward|trigger|negated|10|Group[329]|Clement
# exclu l'usage |forward|trigger|negated|10|Group[329]|Clement
# exclu l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# exclu la consommation |forward|trigger|negated|10|Group[329]|Clement
# exclu l'appel |forward|trigger|negated|10|Group[329]|Clement
# écarté l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# écarté l'emploi |forward|trigger|negated|10|Group[329]|Clement
# écarté le maniement |forward|trigger|negated|10|Group[329]|Clement
# écarté l'usage |forward|trigger|negated|10|Group[329]|Clement
# écarté l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# écarté la consommation |forward|trigger|negated|10|Group[329]|Clement
# écarté l'appel |forward|trigger|negated|10|Group[329]|Clement
# décliné l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# décliné l'emploi |forward|trigger|negated|10|Group[329]|Clement
# décliné le maniement |forward|trigger|negated|10|Group[329]|Clement
# décliné l'usage |forward|trigger|negated|10|Group[329]|Clement
# décliné l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# décliné la consommation |forward|trigger|negated|10|Group[329]|Clement
# décliné l'appel |forward|trigger|negated|10|Group[329]|Clement
# résisté à l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# résisté à l'emploi |forward|trigger|negated|10|Group[329]|Clement
# résisté à le maniement |forward|trigger|negated|10|Group[329]|Clement
# résisté à l'usage |forward|trigger|negated|10|Group[329]|Clement
# résisté à l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# résisté à la consommation |forward|trigger|negated|10|Group[329]|Clement
# résisté à l'appel |forward|trigger|negated|10|Group[329]|Clement
# répugné l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# répugné l'emploi |forward|trigger|negated|10|Group[329]|Clement
# répugné le maniement |forward|trigger|negated|10|Group[329]|Clement
# répugné l'usage |forward|trigger|negated|10|Group[329]|Clement
# répugné l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# répugné la consommation |forward|trigger|negated|10|Group[329]|Clement
# répugné l'appel |forward|trigger|negated|10|Group[329]|Clement
# dit non à l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# dit non à l'emploi |forward|trigger|negated|10|Group[329]|Clement
# dit non à le maniement |forward|trigger|negated|10|Group[329]|Clement
# dit non à l'usage |forward|trigger|negated|10|Group[329]|Clement
# dit non à l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# dit non à la consommation |forward|trigger|negated|10|Group[329]|Clement
# dit non à l'appel |forward|trigger|negated|10|Group[329]|Clement
# retoqué l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# retoqué l'emploi |forward|trigger|negated|10|Group[329]|Clement
# retoqué le maniement |forward|trigger|negated|10|Group[329]|Clement
# retoqué l'usage |forward|trigger|negated|10|Group[329]|Clement
# retoqué l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# retoqué la consommation |forward|trigger|negated|10|Group[329]|Clement
# retoqué l'appel |forward|trigger|negated|10|Group[329]|Clement
# désapprouvé l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# désapprouvé l'emploi |forward|trigger|negated|10|Group[329]|Clement
# désapprouvé le maniement |forward|trigger|negated|10|Group[329]|Clement
# désapprouvé l'usage |forward|trigger|negated|10|Group[329]|Clement
# désapprouvé l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# désapprouvé la consommation |forward|trigger|negated|10|Group[329]|Clement
# désapprouvé l'appel |forward|trigger|negated|10|Group[329]|Clement
# opposé à l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# opposé à l'emploi |forward|trigger|negated|10|Group[329]|Clement
# opposé à le maniement |forward|trigger|negated|10|Group[329]|Clement
# opposé à l'usage |forward|trigger|negated|10|Group[329]|Clement
# opposé à l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# opposé à la consommation |forward|trigger|negated|10|Group[329]|Clement
# opposé à l'appel |forward|trigger|negated|10|Group[329]|Clement
# opposée à l'utilisation |forward|trigger|negated|10|Group[329]|Clement
# opposée à l'emploi |forward|trigger|negated|10|Group[329]|Clement
# opposée à le maniement |forward|trigger|negated|10|Group[329]|Clement
# opposée à l'usage |forward|trigger|negated|10|Group[329]|Clement
# opposée à l'exploitation |forward|trigger|negated|10|Group[329]|Clement
# opposée à la consommation |forward|trigger|negated|10|Group[329]|Clement
# opposée à l'appel |forward|trigger|negated|10|Group[329]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "a" | "ait"| "avait"
Var2 -> "eu"
Trigger_Rule -> "|forward|termination|negated|10|Group[429]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a eu |forward|termination|negated|10|Group[429]|Clement
# ait eu |forward|termination|negated|10|Group[429]|Clement
# avait eu |forward|termination|negated|10|Group[429]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->   Var1 Var2 Var3 Trigger_Rule
Var1 -> "n'a"| "n'ait"| "n'avait"| "n'y avait" |"n'y ait" |"n'y en ait"
Var2 -> | "eu" 
Var3 -> "aucun" | "aucune" | "nul" | "nulle"
Trigger_Rule -> "|forward|trigger|negated|10|Group[430]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a aucun |forward|trigger|negated|10|Group[430]|Clement
# n'a aucune |forward|trigger|negated|10|Group[430]|Clement
# n'a nul |forward|trigger|negated|10|Group[430]|Clement
# n'a nulle |forward|trigger|negated|10|Group[430]|Clement
# n'a eu aucun |forward|trigger|negated|10|Group[430]|Clement
# n'a eu aucune |forward|trigger|negated|10|Group[430]|Clement
# n'a eu nul |forward|trigger|negated|10|Group[430]|Clement
# n'a eu nulle |forward|trigger|negated|10|Group[430]|Clement
# n'ait aucun |forward|trigger|negated|10|Group[430]|Clement
# n'ait aucune |forward|trigger|negated|10|Group[430]|Clement
# n'ait nul |forward|trigger|negated|10|Group[430]|Clement
# n'ait nulle |forward|trigger|negated|10|Group[430]|Clement
# n'ait eu aucun |forward|trigger|negated|10|Group[430]|Clement
# n'ait eu aucune |forward|trigger|negated|10|Group[430]|Clement
# n'ait eu nul |forward|trigger|negated|10|Group[430]|Clement
# n'ait eu nulle |forward|trigger|negated|10|Group[430]|Clement
# n'avait aucun |forward|trigger|negated|10|Group[430]|Clement
# n'avait aucune |forward|trigger|negated|10|Group[430]|Clement
# n'avait nul |forward|trigger|negated|10|Group[430]|Clement
# n'avait nulle |forward|trigger|negated|10|Group[430]|Clement
# n'avait eu aucun |forward|trigger|negated|10|Group[430]|Clement
# n'avait eu aucune |forward|trigger|negated|10|Group[430]|Clement
# n'avait eu nul |forward|trigger|negated|10|Group[430]|Clement
# n'avait eu nulle |forward|trigger|negated|10|Group[430]|Clement
# n'y avait aucun |forward|trigger|negated|10|Group[430]|Clement
# n'y avait aucune |forward|trigger|negated|10|Group[430]|Clement
# n'y avait nul |forward|trigger|negated|10|Group[430]|Clement
# n'y avait nulle |forward|trigger|negated|10|Group[430]|Clement
# n'y avait eu aucun |forward|trigger|negated|10|Group[430]|Clement
# n'y avait eu aucune |forward|trigger|negated|10|Group[430]|Clement
# n'y avait eu nul |forward|trigger|negated|10|Group[430]|Clement
# n'y avait eu nulle |forward|trigger|negated|10|Group[430]|Clement
# n'y ait aucun |forward|trigger|negated|10|Group[430]|Clement
# n'y ait aucune |forward|trigger|negated|10|Group[430]|Clement
# n'y ait nul |forward|trigger|negated|10|Group[430]|Clement
# n'y ait nulle |forward|trigger|negated|10|Group[430]|Clement
# n'y ait eu aucun |forward|trigger|negated|10|Group[430]|Clement
# n'y ait eu aucune |forward|trigger|negated|10|Group[430]|Clement
# n'y ait eu nul |forward|trigger|negated|10|Group[430]|Clement
# n'y ait eu nulle |forward|trigger|negated|10|Group[430]|Clement
# n'y en ait aucun |forward|trigger|negated|10|Group[430]|Clement
# n'y en ait aucune |forward|trigger|negated|10|Group[430]|Clement
# n'y en ait nul |forward|trigger|negated|10|Group[430]|Clement
# n'y en ait nulle |forward|trigger|negated|10|Group[430]|Clement
# n'y en ait eu aucun |forward|trigger|negated|10|Group[430]|Clement
# n'y en ait eu aucune |forward|trigger|negated|10|Group[430]|Clement
# n'y en ait eu nul |forward|trigger|negated|10|Group[430]|Clement
# n'y en ait eu nulle |forward|trigger|negated|10|Group[430]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3  Trigger_Rule
Var1 -> "n'a"
Var2 -> "plus"
Var3 -> "d'épisodes" | "fait" | "d'histoire" | "de phase" | "d'accident"
Trigger_Rule -> "|forward|trigger|negated|10|Group[432]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a plus d'épisodes |forward|trigger|negated|10|Group[432]|Clement
# n'a plus fait |forward|trigger|negated|10|Group[432]|Clement
# n'a plus d'histoire |forward|trigger|negated|10|Group[432]|Clement
# n'a plus de phase |forward|trigger|negated|10|Group[432]|Clement
# n'a plus d'accident |forward|trigger|negated|10|Group[432]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "n'a"| "n'ait"| "n'avait"| "n'y avait" |"n'y ait"
Var2 -> "pas"
Var3 -> "eu" | "_"
Var4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[434]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a pas eu de |forward|trigger|negated|10|Group[434]|Clement
# n'a pas _ de |forward|trigger|negated|10|Group[434]|Clement
# n'ait pas eu de |forward|trigger|negated|10|Group[434]|Clement
# n'ait pas _ de |forward|trigger|negated|10|Group[434]|Clement
# n'avait pas eu de |forward|trigger|negated|10|Group[434]|Clement
# n'avait pas _ de |forward|trigger|negated|10|Group[434]|Clement
# n'y avait pas eu de |forward|trigger|negated|10|Group[434]|Clement
# n'y avait pas _ de |forward|trigger|negated|10|Group[434]|Clement
# n'y ait pas eu de |forward|trigger|negated|10|Group[434]|Clement
# n'y ait pas _ de |forward|trigger|negated|10|Group[434]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Var4 Var5 Trigger_Rule
Var1 -> "n'a"
Var2 -> "pas"
Var3 -> "eu" | "_"
Var4 -> "de problème" | "d'ennui" | "de souci" | "de complication" | "de dysfonctionnement" | "de disfonctionnement" | "de soucis" | "de tracas"  | "d'incident" | "de couac"
Var5 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[434]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a pas eu de problème avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas eu d'ennui avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas eu de souci avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas eu de complication avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas eu de dysfonctionnement avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas eu de disfonctionnement avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas eu de soucis avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas eu de tracas avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas eu d'incident avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas eu de couac avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas _ de problème avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas _ d'ennui avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas _ de souci avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas _ de complication avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas _ de dysfonctionnement avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas _ de disfonctionnement avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas _ de soucis avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas _ de tracas avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas _ d'incident avec |forward|trigger|negated|10|Group[434]|Clement
# n'a pas _ de couac avec |forward|trigger|negated|10|Group[434]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Trigger_Rule
Var1 -> "n'a"| "n'ait"| "n'avait"
Var2 -> "signalé" | "indiqué" | "notifié" | "découvert" | "montré" | "dévoilé" | "souligné" | "informé d'" | "révélé" | "signifié" | "déclaré" | "averti d'" | "rapporté" | "témoigné" | "alerté d'"
Var3 -> "aucun" | "aucune" | "nul" | "nulle"
Trigger_Rule -> "|forward|trigger|negated|10|Group[434]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a signalé aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a signalé aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a signalé nul |forward|trigger|negated|10|Group[434]|Clement
# n'a signalé nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a indiqué aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a indiqué aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a indiqué nul |forward|trigger|negated|10|Group[434]|Clement
# n'a indiqué nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a notifié aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a notifié aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a notifié nul |forward|trigger|negated|10|Group[434]|Clement
# n'a notifié nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a découvert aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a découvert aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a découvert nul |forward|trigger|negated|10|Group[434]|Clement
# n'a découvert nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a montré aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a montré aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a montré nul |forward|trigger|negated|10|Group[434]|Clement
# n'a montré nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a dévoilé aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a dévoilé aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a dévoilé nul |forward|trigger|negated|10|Group[434]|Clement
# n'a dévoilé nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a souligné aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a souligné aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a souligné nul |forward|trigger|negated|10|Group[434]|Clement
# n'a souligné nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a informé d' aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a informé d' aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a informé d' nul |forward|trigger|negated|10|Group[434]|Clement
# n'a informé d' nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a révélé aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a révélé aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a révélé nul |forward|trigger|negated|10|Group[434]|Clement
# n'a révélé nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a signifié aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a signifié aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a signifié nul |forward|trigger|negated|10|Group[434]|Clement
# n'a signifié nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a déclaré aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a déclaré aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a déclaré nul |forward|trigger|negated|10|Group[434]|Clement
# n'a déclaré nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a averti d' aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a averti d' aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a averti d' nul |forward|trigger|negated|10|Group[434]|Clement
# n'a averti d' nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a rapporté aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a rapporté aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a rapporté nul |forward|trigger|negated|10|Group[434]|Clement
# n'a rapporté nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a témoigné aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a témoigné aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a témoigné nul |forward|trigger|negated|10|Group[434]|Clement
# n'a témoigné nulle |forward|trigger|negated|10|Group[434]|Clement
# n'a alerté d' aucun |forward|trigger|negated|10|Group[434]|Clement
# n'a alerté d' aucune |forward|trigger|negated|10|Group[434]|Clement
# n'a alerté d' nul |forward|trigger|negated|10|Group[434]|Clement
# n'a alerté d' nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait signalé aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait signalé aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait signalé nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait signalé nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait indiqué aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait indiqué aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait indiqué nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait indiqué nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait notifié aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait notifié aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait notifié nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait notifié nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait découvert aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait découvert aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait découvert nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait découvert nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait montré aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait montré aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait montré nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait montré nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait dévoilé aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait dévoilé aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait dévoilé nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait dévoilé nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait souligné aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait souligné aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait souligné nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait souligné nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait informé d' aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait informé d' aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait informé d' nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait informé d' nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait révélé aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait révélé aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait révélé nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait révélé nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait signifié aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait signifié aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait signifié nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait signifié nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait déclaré aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait déclaré aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait déclaré nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait déclaré nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait averti d' aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait averti d' aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait averti d' nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait averti d' nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait rapporté aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait rapporté aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait rapporté nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait rapporté nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait témoigné aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait témoigné aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait témoigné nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait témoigné nulle |forward|trigger|negated|10|Group[434]|Clement
# n'ait alerté d' aucun |forward|trigger|negated|10|Group[434]|Clement
# n'ait alerté d' aucune |forward|trigger|negated|10|Group[434]|Clement
# n'ait alerté d' nul |forward|trigger|negated|10|Group[434]|Clement
# n'ait alerté d' nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait signalé aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait signalé aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait signalé nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait signalé nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait indiqué aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait indiqué aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait indiqué nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait indiqué nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait notifié aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait notifié aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait notifié nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait notifié nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait découvert aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait découvert aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait découvert nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait découvert nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait montré aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait montré aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait montré nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait montré nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait dévoilé aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait dévoilé aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait dévoilé nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait dévoilé nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait souligné aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait souligné aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait souligné nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait souligné nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait informé d' aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait informé d' aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait informé d' nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait informé d' nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait révélé aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait révélé aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait révélé nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait révélé nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait signifié aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait signifié aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait signifié nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait signifié nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait déclaré aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait déclaré aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait déclaré nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait déclaré nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait averti d' aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait averti d' aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait averti d' nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait averti d' nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait rapporté aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait rapporté aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait rapporté nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait rapporté nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait témoigné aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait témoigné aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait témoigné nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait témoigné nulle |forward|trigger|negated|10|Group[434]|Clement
# n'avait alerté d' aucun |forward|trigger|negated|10|Group[434]|Clement
# n'avait alerté d' aucune |forward|trigger|negated|10|Group[434]|Clement
# n'avait alerté d' nul |forward|trigger|negated|10|Group[434]|Clement
# n'avait alerté d' nulle |forward|trigger|negated|10|Group[434]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Trigger_Rule
Var1 -> "n'a"
Var2 -> "pas"
Var3 -> "observé" | "remarqué" | "noté" | "découvert" | "apercu" | "signalé" | "vu" | "relevé" | "décelé" | "détecté" | "souligné" | "mentionné"
Trigger_Rule -> "|forward|trigger|negated|10|Group[436]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a pas observé |forward|trigger|negated|10|Group[436]|Clement
# n'a pas remarqué |forward|trigger|negated|10|Group[436]|Clement
# n'a pas noté |forward|trigger|negated|10|Group[436]|Clement
# n'a pas découvert |forward|trigger|negated|10|Group[436]|Clement
# n'a pas apercu |forward|trigger|negated|10|Group[436]|Clement
# n'a pas signalé |forward|trigger|negated|10|Group[436]|Clement
# n'a pas vu |forward|trigger|negated|10|Group[436]|Clement
# n'a pas relevé |forward|trigger|negated|10|Group[436]|Clement
# n'a pas décelé |forward|trigger|negated|10|Group[436]|Clement
# n'a pas détecté |forward|trigger|negated|10|Group[436]|Clement
# n'a pas souligné |forward|trigger|negated|10|Group[436]|Clement
# n'a pas mentionné |forward|trigger|negated|10|Group[436]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Trigger_Rule
Var1 -> "n'a" | "n'ait"
Var2 -> "pas"
Var3 -> "exclu" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[438]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a pas exclu |backward|trigger|uncertain|30|Group[438]|Clement
# n'a pas repoussé |backward|trigger|uncertain|30|Group[438]|Clement
# n'a pas rejeté |backward|trigger|uncertain|30|Group[438]|Clement
# n'a pas éliminé |backward|trigger|uncertain|30|Group[438]|Clement
# n'a pas proscrit |backward|trigger|uncertain|30|Group[438]|Clement
# n'ait pas exclu |backward|trigger|uncertain|30|Group[438]|Clement
# n'ait pas repoussé |backward|trigger|uncertain|30|Group[438]|Clement
# n'ait pas rejeté |backward|trigger|uncertain|30|Group[438]|Clement
# n'ait pas éliminé |backward|trigger|uncertain|30|Group[438]|Clement
# n'ait pas proscrit |backward|trigger|uncertain|30|Group[438]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Trigger_Rule
Var1 -> "l'a"
Var2 -> "exclu" | "mise à lécart" | "mis à lécart" |"rendu inenvisageable" | "rendu irréalisable" | "évincé"| "repoussé" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|backward|trigger|negated|10|Group[439]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# l'a exclu |backward|trigger|negated|10|Group[439]|Clement
# l'a mise à lécart |backward|trigger|negated|10|Group[439]|Clement
# l'a mis à lécart |backward|trigger|negated|10|Group[439]|Clement
# l'a rendu inenvisageable |backward|trigger|negated|10|Group[439]|Clement
# l'a rendu irréalisable |backward|trigger|negated|10|Group[439]|Clement
# l'a évincé |backward|trigger|negated|10|Group[439]|Clement
# l'a repoussé |backward|trigger|negated|10|Group[439]|Clement
# l'a rejeté |backward|trigger|negated|10|Group[439]|Clement
# l'a éliminé |backward|trigger|negated|10|Group[439]|Clement
# l'a proscrit |backward|trigger|negated|10|Group[439]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "a"
Var2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Var3 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a exclu pour |forward|trigger|negated|10|Group[439]|Clement
# a refusé pour |forward|trigger|negated|10|Group[439]|Clement
# a repoussé pour |forward|trigger|negated|10|Group[439]|Clement
# a rejeté pour |forward|trigger|negated|10|Group[439]|Clement
# a éliminé pour |forward|trigger|negated|10|Group[439]|Clement
# a proscrit pour |forward|trigger|negated|10|Group[439]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "a"
Var2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit" |  "contredit" | "démentit" | "refusé" | "rejeté" |"réfuté" | "contesté" | "écarté"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a exclu |forward|trigger|negated|10|Group[439]|Clement
# a refusé |forward|trigger|negated|10|Group[439]|Clement
# a repoussé |forward|trigger|negated|10|Group[439]|Clement
# a rejeté |forward|trigger|negated|10|Group[439]|Clement
# a éliminé |forward|trigger|negated|10|Group[439]|Clement
# a proscrit |forward|trigger|negated|10|Group[439]|Clement
# a contredit |forward|trigger|negated|10|Group[439]|Clement
# a démentit |forward|trigger|negated|10|Group[439]|Clement
# a refusé |forward|trigger|negated|10|Group[439]|Clement
# a rejeté |forward|trigger|negated|10|Group[439]|Clement
# a réfuté |forward|trigger|negated|10|Group[439]|Clement
# a contesté |forward|trigger|negated|10|Group[439]|Clement
# a écarté |forward|trigger|negated|10|Group[439]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Patient Trigger_Rule
Var1 -> "a"
Var2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Patient -> "le patient" | "la patiente"| "le souffrant" | "la souffrante"| "le sujet"
Trigger_Rule -> "|forward|trigger|negated|10|Group[457]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a exclu le patient |forward|trigger|negated|10|Group[457]|Clement
# a exclu la patiente |forward|trigger|negated|10|Group[457]|Clement
# a exclu le souffrant |forward|trigger|negated|10|Group[457]|Clement
# a exclu la souffrante |forward|trigger|negated|10|Group[457]|Clement
# a exclu le sujet |forward|trigger|negated|10|Group[457]|Clement
# a refusé le patient |forward|trigger|negated|10|Group[457]|Clement
# a refusé la patiente |forward|trigger|negated|10|Group[457]|Clement
# a refusé le souffrant |forward|trigger|negated|10|Group[457]|Clement
# a refusé la souffrante |forward|trigger|negated|10|Group[457]|Clement
# a refusé le sujet |forward|trigger|negated|10|Group[457]|Clement
# a repoussé le patient |forward|trigger|negated|10|Group[457]|Clement
# a repoussé la patiente |forward|trigger|negated|10|Group[457]|Clement
# a repoussé le souffrant |forward|trigger|negated|10|Group[457]|Clement
# a repoussé la souffrante |forward|trigger|negated|10|Group[457]|Clement
# a repoussé le sujet |forward|trigger|negated|10|Group[457]|Clement
# a rejeté le patient |forward|trigger|negated|10|Group[457]|Clement
# a rejeté la patiente |forward|trigger|negated|10|Group[457]|Clement
# a rejeté le souffrant |forward|trigger|negated|10|Group[457]|Clement
# a rejeté la souffrante |forward|trigger|negated|10|Group[457]|Clement
# a rejeté le sujet |forward|trigger|negated|10|Group[457]|Clement
# a éliminé le patient |forward|trigger|negated|10|Group[457]|Clement
# a éliminé la patiente |forward|trigger|negated|10|Group[457]|Clement
# a éliminé le souffrant |forward|trigger|negated|10|Group[457]|Clement
# a éliminé la souffrante |forward|trigger|negated|10|Group[457]|Clement
# a éliminé le sujet |forward|trigger|negated|10|Group[457]|Clement
# a proscrit le patient |forward|trigger|negated|10|Group[457]|Clement
# a proscrit la patiente |forward|trigger|negated|10|Group[457]|Clement
# a proscrit le souffrant |forward|trigger|negated|10|Group[457]|Clement
# a proscrit la souffrante |forward|trigger|negated|10|Group[457]|Clement
# a proscrit le sujet |forward|trigger|negated|10|Group[457]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "a"
Var2 -> "exclu" | "rejeté" | "éliminé" | "proscrit"
Var3 -> "le patient" | "le client" | "souffrant" | "sujet"
Trigger_Rule -> "|forward|trigger|negated|10|Group[457]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a exclu le patient |forward|trigger|negated|10|Group[457]|Clement
# a exclu le client |forward|trigger|negated|10|Group[457]|Clement
# a exclu souffrant |forward|trigger|negated|10|Group[457]|Clement
# a exclu sujet |forward|trigger|negated|10|Group[457]|Clement
# a rejeté le patient |forward|trigger|negated|10|Group[457]|Clement
# a rejeté le client |forward|trigger|negated|10|Group[457]|Clement
# a rejeté souffrant |forward|trigger|negated|10|Group[457]|Clement
# a rejeté sujet |forward|trigger|negated|10|Group[457]|Clement
# a éliminé le patient |forward|trigger|negated|10|Group[457]|Clement
# a éliminé le client |forward|trigger|negated|10|Group[457]|Clement
# a éliminé souffrant |forward|trigger|negated|10|Group[457]|Clement
# a éliminé sujet |forward|trigger|negated|10|Group[457]|Clement
# a proscrit le patient |forward|trigger|negated|10|Group[457]|Clement
# a proscrit le client |forward|trigger|negated|10|Group[457]|Clement
# a proscrit souffrant |forward|trigger|negated|10|Group[457]|Clement
# a proscrit sujet |forward|trigger|negated|10|Group[457]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "a"
Var2 -> "montré" | "affiché" | "exhibé" | "fait état" | "démontré" | "exposé" | "exhibé" | "dénoté" | "confirmé" | "expliqué" | "découvert" | "dévoilé"
Trigger_Rule -> "|forward|termination|negated|10|Group[463]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a montré |forward|termination|negated|10|Group[463]|Clement
# a affiché |forward|termination|negated|10|Group[463]|Clement
# a exhibé |forward|termination|negated|10|Group[463]|Clement
# a fait état |forward|termination|negated|10|Group[463]|Clement
# a démontré |forward|termination|negated|10|Group[463]|Clement
# a exposé |forward|termination|negated|10|Group[463]|Clement
# a exhibé |forward|termination|negated|10|Group[463]|Clement
# a dénoté |forward|termination|negated|10|Group[463]|Clement
# a confirmé |forward|termination|negated|10|Group[463]|Clement
# a expliqué |forward|termination|negated|10|Group[463]|Clement
# a découvert |forward|termination|negated|10|Group[463]|Clement
# a dévoilé |forward|termination|negated|10|Group[463]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Termin Trigger_Rule
Var1 -> "montre" | "affiche" | "exhibe" | "démontre" | "expose" | "exhibe" | "dénote" | "confirme" | "explique" | "dévoile"
Termin -> "_"|"_ent"
Trigger_Rule -> "|forward|termination|negated|10|Group[463]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# montre _ |forward|termination|negated|10|Group[463]|Clement
# montre _ent |forward|termination|negated|10|Group[463]|Clement
# affiche _ |forward|termination|negated|10|Group[463]|Clement
# affiche _ent |forward|termination|negated|10|Group[463]|Clement
# exhibe _ |forward|termination|negated|10|Group[463]|Clement
# exhibe _ent |forward|termination|negated|10|Group[463]|Clement
# démontre _ |forward|termination|negated|10|Group[463]|Clement
# démontre _ent |forward|termination|negated|10|Group[463]|Clement
# expose _ |forward|termination|negated|10|Group[463]|Clement
# expose _ent |forward|termination|negated|10|Group[463]|Clement
# exhibe _ |forward|termination|negated|10|Group[463]|Clement
# exhibe _ent |forward|termination|negated|10|Group[463]|Clement
# dénote _ |forward|termination|negated|10|Group[463]|Clement
# dénote _ent |forward|termination|negated|10|Group[463]|Clement
# confirme _ |forward|termination|negated|10|Group[463]|Clement
# confirme _ent |forward|termination|negated|10|Group[463]|Clement
# explique _ |forward|termination|negated|10|Group[463]|Clement
# explique _ent |forward|termination|negated|10|Group[463]|Clement
# dévoile _ |forward|termination|negated|10|Group[463]|Clement
# dévoile _ent |forward|termination|negated|10|Group[463]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 ->  "fait état" | "font état" 
Trigger_Rule -> "|forward|termination|negated|10|Group[463]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# fait état |forward|termination|negated|10|Group[463]|Clement
# font état |forward|termination|negated|10|Group[463]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Trigger_Rule
Var1 -> "n'a" | "n'ait"
Var2 -> "pas"
Var3 -> "exprimé" | "manifesté" | "dit" | "signifié" | "témoigné" | "montré" | "expliqué" | "traduit" | "extériorisé" | "révélé" | "formulé" | "exposé" | "affiché" | "signalé"
Trigger_Rule -> "|forward|trigger|negated|10|Group[464]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a pas exprimé |forward|trigger|negated|10|Group[464]|Clement
# n'a pas manifesté |forward|trigger|negated|10|Group[464]|Clement
# n'a pas dit |forward|trigger|negated|10|Group[464]|Clement
# n'a pas signifié |forward|trigger|negated|10|Group[464]|Clement
# n'a pas témoigné |forward|trigger|negated|10|Group[464]|Clement
# n'a pas montré |forward|trigger|negated|10|Group[464]|Clement
# n'a pas expliqué |forward|trigger|negated|10|Group[464]|Clement
# n'a pas traduit |forward|trigger|negated|10|Group[464]|Clement
# n'a pas extériorisé |forward|trigger|negated|10|Group[464]|Clement
# n'a pas révélé |forward|trigger|negated|10|Group[464]|Clement
# n'a pas formulé |forward|trigger|negated|10|Group[464]|Clement
# n'a pas exposé |forward|trigger|negated|10|Group[464]|Clement
# n'a pas affiché |forward|trigger|negated|10|Group[464]|Clement
# n'a pas signalé |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas exprimé |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas manifesté |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas dit |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas signifié |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas témoigné |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas montré |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas expliqué |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas traduit |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas extériorisé |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas révélé |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas formulé |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas exposé |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas affiché |forward|trigger|negated|10|Group[464]|Clement
# n'ait pas signalé |forward|trigger|negated|10|Group[464]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Trigger_Rule
Var1 -> "n'a" | "n'ait"
Var2 -> "exprimé" | "manifesté" | "dit" | "signifié" | "témoigné" | "montré" | "expliqué" | "traduit" | "extériorisé" | "révélé" | "formulé" | "exposé" | "affiché" | "signalé" | "indiqué" | "notifié" | "découvert" | "dévoilé" | "souligné" | "informé" | "déclaré" | "averti" | "rapporté" | "alerté"
Var3 -> "aucun" | "aucune" | "nul" | "nulle"
Trigger_Rule -> "|forward|trigger|negated|10|Group[466]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a exprimé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a exprimé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a exprimé nul |forward|trigger|negated|10|Group[466]|Clement
# n'a exprimé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a manifesté aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a manifesté aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a manifesté nul |forward|trigger|negated|10|Group[466]|Clement
# n'a manifesté nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a dit aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a dit aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a dit nul |forward|trigger|negated|10|Group[466]|Clement
# n'a dit nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a signifié aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a signifié aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a signifié nul |forward|trigger|negated|10|Group[466]|Clement
# n'a signifié nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a témoigné aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a témoigné aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a témoigné nul |forward|trigger|negated|10|Group[466]|Clement
# n'a témoigné nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a montré aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a montré aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a montré nul |forward|trigger|negated|10|Group[466]|Clement
# n'a montré nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a expliqué aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a expliqué aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a expliqué nul |forward|trigger|negated|10|Group[466]|Clement
# n'a expliqué nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a traduit aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a traduit aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a traduit nul |forward|trigger|negated|10|Group[466]|Clement
# n'a traduit nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a extériorisé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a extériorisé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a extériorisé nul |forward|trigger|negated|10|Group[466]|Clement
# n'a extériorisé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a révélé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a révélé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a révélé nul |forward|trigger|negated|10|Group[466]|Clement
# n'a révélé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a formulé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a formulé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a formulé nul |forward|trigger|negated|10|Group[466]|Clement
# n'a formulé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a exposé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a exposé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a exposé nul |forward|trigger|negated|10|Group[466]|Clement
# n'a exposé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a affiché aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a affiché aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a affiché nul |forward|trigger|negated|10|Group[466]|Clement
# n'a affiché nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a signalé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a signalé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a signalé nul |forward|trigger|negated|10|Group[466]|Clement
# n'a signalé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a indiqué aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a indiqué aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a indiqué nul |forward|trigger|negated|10|Group[466]|Clement
# n'a indiqué nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a notifié aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a notifié aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a notifié nul |forward|trigger|negated|10|Group[466]|Clement
# n'a notifié nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a découvert aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a découvert aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a découvert nul |forward|trigger|negated|10|Group[466]|Clement
# n'a découvert nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a dévoilé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a dévoilé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a dévoilé nul |forward|trigger|negated|10|Group[466]|Clement
# n'a dévoilé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a souligné aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a souligné aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a souligné nul |forward|trigger|negated|10|Group[466]|Clement
# n'a souligné nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a informé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a informé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a informé nul |forward|trigger|negated|10|Group[466]|Clement
# n'a informé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a déclaré aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a déclaré aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a déclaré nul |forward|trigger|negated|10|Group[466]|Clement
# n'a déclaré nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a averti aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a averti aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a averti nul |forward|trigger|negated|10|Group[466]|Clement
# n'a averti nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a rapporté aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a rapporté aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a rapporté nul |forward|trigger|negated|10|Group[466]|Clement
# n'a rapporté nulle |forward|trigger|negated|10|Group[466]|Clement
# n'a alerté aucun |forward|trigger|negated|10|Group[466]|Clement
# n'a alerté aucune |forward|trigger|negated|10|Group[466]|Clement
# n'a alerté nul |forward|trigger|negated|10|Group[466]|Clement
# n'a alerté nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait exprimé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait exprimé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait exprimé nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait exprimé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait manifesté aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait manifesté aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait manifesté nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait manifesté nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait dit aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait dit aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait dit nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait dit nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait signifié aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait signifié aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait signifié nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait signifié nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait témoigné aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait témoigné aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait témoigné nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait témoigné nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait montré aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait montré aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait montré nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait montré nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait expliqué aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait expliqué aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait expliqué nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait expliqué nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait traduit aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait traduit aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait traduit nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait traduit nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait extériorisé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait extériorisé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait extériorisé nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait extériorisé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait révélé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait révélé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait révélé nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait révélé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait formulé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait formulé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait formulé nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait formulé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait exposé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait exposé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait exposé nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait exposé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait affiché aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait affiché aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait affiché nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait affiché nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait signalé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait signalé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait signalé nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait signalé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait indiqué aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait indiqué aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait indiqué nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait indiqué nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait notifié aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait notifié aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait notifié nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait notifié nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait découvert aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait découvert aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait découvert nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait découvert nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait dévoilé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait dévoilé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait dévoilé nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait dévoilé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait souligné aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait souligné aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait souligné nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait souligné nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait informé aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait informé aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait informé nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait informé nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait déclaré aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait déclaré aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait déclaré nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait déclaré nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait averti aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait averti aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait averti nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait averti nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait rapporté aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait rapporté aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait rapporté nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait rapporté nulle |forward|trigger|negated|10|Group[466]|Clement
# n'ait alerté aucun |forward|trigger|negated|10|Group[466]|Clement
# n'ait alerté aucune |forward|trigger|negated|10|Group[466]|Clement
# n'ait alerté nul |forward|trigger|negated|10|Group[466]|Clement
# n'ait alerté nulle |forward|trigger|negated|10|Group[466]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "différentiel"
Var2 -> "comprend" | "consiste" | "posséde" | "contient"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[475]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# différentiel comprend |forward|trigger|uncertain|30|Group[475]|Clement
# différentiel consiste |forward|trigger|uncertain|30|Group[475]|Clement
# différentiel posséde |forward|trigger|uncertain|30|Group[475]|Clement
# différentiel contient |forward|trigger|uncertain|30|Group[475]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "diagnostics"
Var2 -> "différentiels"
Var3 -> "comprenent" | "consistenr" | "possédent" | "contienent"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[476]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# diagnostics différentiels comprenent |forward|trigger|uncertain|30|Group[476]|Clement
# diagnostics différentiels consistenr |forward|trigger|uncertain|30|Group[476]|Clement
# diagnostics différentiels possédent |forward|trigger|uncertain|30|Group[476]|Clement
# diagnostics différentiels contienent |forward|trigger|uncertain|30|Group[476]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Var5 Trigger_Rule
Var1 -> "ne"
Var2 -> "semble" | "semblent" | "_"
Var3 -> "pas"
Var4 -> "avoir"
Var5 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[479]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne semble pas avoir de |forward|trigger|negated|10|Group[479]|Clement
# ne semblent pas avoir de |forward|trigger|negated|10|Group[479]|Clement
# ne _ pas avoir de |forward|trigger|negated|10|Group[479]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Termin Var2 Trigger_Rule
Var1 -> "n'exprime" | "ne dit" | "n'expose" | "n'énonce" | "n'affiche" | "n'émet" | "ne signale" | "ne signifie" | "ne déclare" | "ne témoigne" | "ne montre" | "ne manifeste" | "ne découvre" | "ne figure" | "ne traduise"
Termin -> "_"|"_ent"
Var2 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[487]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'exprime _ pas |forward|trigger|negated|10|Group[487]|Clement
# n'exprime _ent pas |forward|trigger|negated|10|Group[487]|Clement
# ne dit _ pas |forward|trigger|negated|10|Group[487]|Clement
# ne dit _ent pas |forward|trigger|negated|10|Group[487]|Clement
# n'expose _ pas |forward|trigger|negated|10|Group[487]|Clement
# n'expose _ent pas |forward|trigger|negated|10|Group[487]|Clement
# n'énonce _ pas |forward|trigger|negated|10|Group[487]|Clement
# n'énonce _ent pas |forward|trigger|negated|10|Group[487]|Clement
# n'affiche _ pas |forward|trigger|negated|10|Group[487]|Clement
# n'affiche _ent pas |forward|trigger|negated|10|Group[487]|Clement
# n'émet _ pas |forward|trigger|negated|10|Group[487]|Clement
# n'émet _ent pas |forward|trigger|negated|10|Group[487]|Clement
# ne signale _ pas |forward|trigger|negated|10|Group[487]|Clement
# ne signale _ent pas |forward|trigger|negated|10|Group[487]|Clement
# ne signifie _ pas |forward|trigger|negated|10|Group[487]|Clement
# ne signifie _ent pas |forward|trigger|negated|10|Group[487]|Clement
# ne déclare _ pas |forward|trigger|negated|10|Group[487]|Clement
# ne déclare _ent pas |forward|trigger|negated|10|Group[487]|Clement
# ne témoigne _ pas |forward|trigger|negated|10|Group[487]|Clement
# ne témoigne _ent pas |forward|trigger|negated|10|Group[487]|Clement
# ne montre _ pas |forward|trigger|negated|10|Group[487]|Clement
# ne montre _ent pas |forward|trigger|negated|10|Group[487]|Clement
# ne manifeste _ pas |forward|trigger|negated|10|Group[487]|Clement
# ne manifeste _ent pas |forward|trigger|negated|10|Group[487]|Clement
# ne découvre _ pas |forward|trigger|negated|10|Group[487]|Clement
# ne découvre _ent pas |forward|trigger|negated|10|Group[487]|Clement
# ne figure _ pas |forward|trigger|negated|10|Group[487]|Clement
# ne figure _ent pas |forward|trigger|negated|10|Group[487]|Clement
# ne traduise _ pas |forward|trigger|negated|10|Group[487]|Clement
# ne traduise _ent pas |forward|trigger|negated|10|Group[487]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Termin Var2 Trigger_Rule
Var1 -> "ne présente" |"n'utilise" | "n'employe" | "ne serve" | "ne recoure" | "ne serve" | "n'use" | "ne prene" | "n'applique" | "ne manipule" | "n'exploite" | "ne manie"
Termin -> "_"|"_ent"
Var2 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[489]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne présente _ pas |forward|trigger|negated|10|Group[489]|Clement
# ne présente _ent pas |forward|trigger|negated|10|Group[489]|Clement
# n'utilise _ pas |forward|trigger|negated|10|Group[489]|Clement
# n'utilise _ent pas |forward|trigger|negated|10|Group[489]|Clement
# n'employe _ pas |forward|trigger|negated|10|Group[489]|Clement
# n'employe _ent pas |forward|trigger|negated|10|Group[489]|Clement
# ne serve _ pas |forward|trigger|negated|10|Group[489]|Clement
# ne serve _ent pas |forward|trigger|negated|10|Group[489]|Clement
# ne recoure _ pas |forward|trigger|negated|10|Group[489]|Clement
# ne recoure _ent pas |forward|trigger|negated|10|Group[489]|Clement
# ne serve _ pas |forward|trigger|negated|10|Group[489]|Clement
# ne serve _ent pas |forward|trigger|negated|10|Group[489]|Clement
# n'use _ pas |forward|trigger|negated|10|Group[489]|Clement
# n'use _ent pas |forward|trigger|negated|10|Group[489]|Clement
# ne prene _ pas |forward|trigger|negated|10|Group[489]|Clement
# ne prene _ent pas |forward|trigger|negated|10|Group[489]|Clement
# n'applique _ pas |forward|trigger|negated|10|Group[489]|Clement
# n'applique _ent pas |forward|trigger|negated|10|Group[489]|Clement
# ne manipule _ pas |forward|trigger|negated|10|Group[489]|Clement
# ne manipule _ent pas |forward|trigger|negated|10|Group[489]|Clement
# n'exploite _ pas |forward|trigger|negated|10|Group[489]|Clement
# n'exploite _ent pas |forward|trigger|negated|10|Group[489]|Clement
# ne manie _ pas |forward|trigger|negated|10|Group[489]|Clement
# ne manie _ent pas |forward|trigger|negated|10|Group[489]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "généralement" | "en général" | "habituellement"
Var2 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[491]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# généralement pas |forward|trigger|negated|10|Group[491]|Clement
# en général pas |forward|trigger|negated|10|Group[491]|Clement
# habituellement pas |forward|trigger|negated|10|Group[491]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "ne"
Var2 -> "fait" | "faisait"
Var3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[493]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne fait pas |forward|trigger|negated|10|Group[493]|Clement
# ne faisait pas |forward|trigger|negated|10|Group[493]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Var3 Trigger_Rule
Var1 -> "ne"
Var2 -> "ressemble" | "s'approche" | "corresponde" | "ne rappelle" | "se recoupe"  | "se rapproche"
Termin -> "_"|"_nt"
Var3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[495]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne ressemble _ pas |forward|trigger|negated|10|Group[495]|Clement
# ne ressemble _nt pas |forward|trigger|negated|10|Group[495]|Clement
# ne s'approche _ pas |forward|trigger|negated|10|Group[495]|Clement
# ne s'approche _nt pas |forward|trigger|negated|10|Group[495]|Clement
# ne corresponde _ pas |forward|trigger|negated|10|Group[495]|Clement
# ne corresponde _nt pas |forward|trigger|negated|10|Group[495]|Clement
# ne ne rappelle _ pas |forward|trigger|negated|10|Group[495]|Clement
# ne ne rappelle _nt pas |forward|trigger|negated|10|Group[495]|Clement
# ne se recoupe _ pas |forward|trigger|negated|10|Group[495]|Clement
# ne se recoupe _nt pas |forward|trigger|negated|10|Group[495]|Clement
# ne se rapproche _ pas |forward|trigger|negated|10|Group[495]|Clement
# ne se rapproche _nt pas |forward|trigger|negated|10|Group[495]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> "n'imite pas" | "n'a aucun rapport avec" | "n'est la réplique de" | "n'ont aucun rapport avec" | "ne sont la réplique de" 
Trigger_Rule -> "|forward|trigger|negated|10|Group[495]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'imite pas |forward|trigger|negated|10|Group[495]|Clement
# n'a aucun rapport avec |forward|trigger|negated|10|Group[495]|Clement
# n'est la réplique de |forward|trigger|negated|10|Group[495]|Clement
# n'ont aucun rapport avec |forward|trigger|negated|10|Group[495]|Clement
# ne sont la réplique de |forward|trigger|negated|10|Group[495]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "doute" | "perplexité" | "hésitation" | "indétermination" | "indécision" | "crainte" | "appréhension" | "supposition" | "inquiétude" | "croyance"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[497]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# doute |forward|trigger|uncertain|30|Group[497]|Clement
# perplexité |forward|trigger|uncertain|30|Group[497]|Clement
# hésitation |forward|trigger|uncertain|30|Group[497]|Clement
# indétermination |forward|trigger|uncertain|30|Group[497]|Clement
# indécision |forward|trigger|uncertain|30|Group[497]|Clement
# crainte |forward|trigger|uncertain|30|Group[497]|Clement
# appréhension |forward|trigger|uncertain|30|Group[497]|Clement
# supposition |forward|trigger|uncertain|30|Group[497]|Clement
# inquiétude |forward|trigger|uncertain|30|Group[497]|Clement
# croyance |forward|trigger|uncertain|30|Group[497]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Trigger_Rule
Var1 -> "en raison" | "à cause" | "pourquoi" | "comme explication" | "comme fondement"
Var2 -> "de" | "d" | "d'"
Trigger_Rule -> "|forward|termination|negated|10|Group[498]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# en raison de |forward|termination|negated|10|Group[498]|Clement
# en raison d |forward|termination|negated|10|Group[498]|Clement
# en raison d' |forward|termination|negated|10|Group[498]|Clement
# à cause de |forward|termination|negated|10|Group[498]|Clement
# à cause d |forward|termination|negated|10|Group[498]|Clement
# à cause d' |forward|termination|negated|10|Group[498]|Clement
# pourquoi de |forward|termination|negated|10|Group[498]|Clement
# pourquoi d |forward|termination|negated|10|Group[498]|Clement
# pourquoi d' |forward|termination|negated|10|Group[498]|Clement
# comme explication de |forward|termination|negated|10|Group[498]|Clement
# comme explication d |forward|termination|negated|10|Group[498]|Clement
# comme explication d' |forward|termination|negated|10|Group[498]|Clement
# comme fondement de |forward|termination|negated|10|Group[498]|Clement
# comme fondement d |forward|termination|negated|10|Group[498]|Clement
# comme fondement d' |forward|termination|negated|10|Group[498]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Termin Var2 Trigger_Rule
Var1 -> "ecchymoses" | "hématome" | "coup" | "blessure" | "meurtrissure" | "cicatrice" | "égratignure" | "escarre" | "contusion" | "entaille" | "éraflure"
Termin -> "_"|"_s"
Var2 -> "à"
Trigger_Rule -> "|forward|termination|negated|10|Group[499]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ecchymoses _ à |forward|termination|negated|10|Group[499]|Clement
# ecchymoses _s à |forward|termination|negated|10|Group[499]|Clement
# hématome _ à |forward|termination|negated|10|Group[499]|Clement
# hématome _s à |forward|termination|negated|10|Group[499]|Clement
# coup _ à |forward|termination|negated|10|Group[499]|Clement
# coup _s à |forward|termination|negated|10|Group[499]|Clement
# blessure _ à |forward|termination|negated|10|Group[499]|Clement
# blessure _s à |forward|termination|negated|10|Group[499]|Clement
# meurtrissure _ à |forward|termination|negated|10|Group[499]|Clement
# meurtrissure _s à |forward|termination|negated|10|Group[499]|Clement
# cicatrice _ à |forward|termination|negated|10|Group[499]|Clement
# cicatrice _s à |forward|termination|negated|10|Group[499]|Clement
# égratignure _ à |forward|termination|negated|10|Group[499]|Clement
# égratignure _s à |forward|termination|negated|10|Group[499]|Clement
# escarre _ à |forward|termination|negated|10|Group[499]|Clement
# escarre _s à |forward|termination|negated|10|Group[499]|Clement
# contusion _ à |forward|termination|negated|10|Group[499]|Clement
# contusion _s à |forward|termination|negated|10|Group[499]|Clement
# entaille _ à |forward|termination|negated|10|Group[499]|Clement
# entaille _s à |forward|termination|negated|10|Group[499]|Clement
# éraflure _ à |forward|termination|negated|10|Group[499]|Clement
# éraflure _s à |forward|termination|negated|10|Group[499]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> "département d'urgences" | "aux urgences" | "département d'urgence"
Trigger_Rule -> "|both|termination|historical|30|Group[501]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# département d'urgences |both|termination|historical|30|Group[501]|Clement
# aux urgences |both|termination|historical|30|Group[501]|Clement
# département d'urgence |both|termination|historical|30|Group[501]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "étiologie" | "étiologie" | "causalité"
Var2 -> "de" | "pour"
Trigger_Rule -> "|forward|termination|negated|10|Group[502]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# étiologie de |forward|termination|negated|10|Group[502]|Clement
# étiologie pour |forward|termination|negated|10|Group[502]|Clement
# étiologie de |forward|termination|negated|10|Group[502]|Clement
# étiologie pour |forward|termination|negated|10|Group[502]|Clement
# causalité de |forward|termination|negated|10|Group[502]|Clement
# causalité pour |forward|termination|negated|10|Group[502]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "exacerbation" | "redoublement" | "intensification" | "recrudescence" | "excitation" | "augmentation" | "irritation" | "aggravation" | "agravation"
Var2 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[504]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# exacerbation de |forward|termination|negated|10|Group[504]|Clement
# redoublement de |forward|termination|negated|10|Group[504]|Clement
# intensification de |forward|termination|negated|10|Group[504]|Clement
# recrudescence de |forward|termination|negated|10|Group[504]|Clement
# excitation de |forward|termination|negated|10|Group[504]|Clement
# augmentation de |forward|termination|negated|10|Group[504]|Clement
# irritation de |forward|termination|negated|10|Group[504]|Clement
# aggravation de |forward|termination|negated|10|Group[504]|Clement
# agravation de |forward|termination|negated|10|Group[504]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "examens" | "consultation" | "observation" | "auscultation" | "examen médical"
Var2 -> "pour"
Var3 -> "évaluer" | "juger" | "apprécier" | "chiffrer" | "calculer" | "quantifier" | "mesurer" | "déterminer" | "expertiser" | "jauger" | "compter" | "examiner" | "recenser"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[505]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# examens pour évaluer |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour juger |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour apprécier |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour chiffrer |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour calculer |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour quantifier |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour mesurer |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour déterminer |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour expertiser |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour jauger |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour compter |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour examiner |forward|trigger|uncertain|30|Group[505]|Clement
# examens pour recenser |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour évaluer |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour juger |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour apprécier |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour chiffrer |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour calculer |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour quantifier |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour mesurer |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour déterminer |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour expertiser |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour jauger |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour compter |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour examiner |forward|trigger|uncertain|30|Group[505]|Clement
# consultation pour recenser |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour évaluer |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour juger |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour apprécier |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour chiffrer |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour calculer |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour quantifier |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour mesurer |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour déterminer |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour expertiser |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour jauger |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour compter |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour examiner |forward|trigger|uncertain|30|Group[505]|Clement
# observation pour recenser |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour évaluer |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour juger |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour apprécier |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour chiffrer |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour calculer |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour quantifier |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour mesurer |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour déterminer |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour expertiser |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour jauger |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour compter |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour examiner |forward|trigger|uncertain|30|Group[505]|Clement
# auscultation pour recenser |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour évaluer |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour juger |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour apprécier |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour chiffrer |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour calculer |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour quantifier |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour mesurer |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour déterminer |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour expertiser |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour jauger |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour compter |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour examiner |forward|trigger|uncertain|30|Group[505]|Clement
# examen médical pour recenser |forward|trigger|uncertain|30|Group[505]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "sauf"
Trigger_Rule -> "|forward|termination|negated|10|Group[510]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sauf |forward|termination|negated|10|Group[510]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "ne parvient" | "n'aboutir" | "ne réussi"
Var2 -> "pas"
Var3 -> "à"
Var4 -> "révéler" | "divulguer" | "déceler" | "trahir" | "dire" | "exposer" | "faire connaître" | "exprimer" | "signaler" | "signifier" | "annoncer" | "développer" | "démasquer" | "afficher" | "déclarer"
Trigger_Rule -> "|forward|trigger|negated|10|Group[512]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne parvient pas à révéler |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à divulguer |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à déceler |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à trahir |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à dire |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à exposer |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à faire connaître |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à exprimer |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à signaler |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à signifier |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à annoncer |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à développer |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à démasquer |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à afficher |forward|trigger|negated|10|Group[512]|Clement
# ne parvient pas à déclarer |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à révéler |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à divulguer |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à déceler |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à trahir |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à dire |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à exposer |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à faire connaître |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à exprimer |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à signaler |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à signifier |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à annoncer |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à développer |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à démasquer |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à afficher |forward|trigger|negated|10|Group[512]|Clement
# n'aboutir pas à déclarer |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à révéler |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à divulguer |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à déceler |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à trahir |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à dire |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à exposer |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à faire connaître |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à exprimer |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à signaler |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à signifier |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à annoncer |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à développer |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à démasquer |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à afficher |forward|trigger|negated|10|Group[512]|Clement
# ne réussi pas à déclarer |forward|trigger|negated|10|Group[512]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "faux"
Var2 -> "négatif"
Trigger_Rule -> "|both|pseudo|negated|10|Group[514]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# faux négatif |both|pseudo|negated|10|Group[514]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "fh" |"f / h"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[530]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# fh |forward|trigger|nonpatient|30|Group[530]|Clement
# f / h |forward|trigger|nonpatient|30|Group[530]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "indication" | "prescription" | "directive" | "renvoi" | "information" | "note" | "recommandation" | "suggestion" | "mention"
Var2 -> "du"
Var3 -> "rapport"
Var4 -> "final"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[531]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# indication du rapport final |both|pseudo|uncertain|30|Group[531]|Clement
# prescription du rapport final |both|pseudo|uncertain|30|Group[531]|Clement
# directive du rapport final |both|pseudo|uncertain|30|Group[531]|Clement
# renvoi du rapport final |both|pseudo|uncertain|30|Group[531]|Clement
# information du rapport final |both|pseudo|uncertain|30|Group[531]|Clement
# note du rapport final |both|pseudo|uncertain|30|Group[531]|Clement
# recommandation du rapport final |both|pseudo|uncertain|30|Group[531]|Clement
# suggestion du rapport final |both|pseudo|uncertain|30|Group[531]|Clement
# mention du rapport final |both|pseudo|uncertain|30|Group[531]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pour"
Var2 -> "présumer" | "soupçonner" | "estimer" | "conjecturer" | "pressentir" | "présager" | "espérer" |"préjuger" | "présupposer" | "prétendre" | "prédire"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[532]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pour présumer |forward|trigger|uncertain|30|Group[532]|Clement
# pour soupçonner |forward|trigger|uncertain|30|Group[532]|Clement
# pour estimer |forward|trigger|uncertain|30|Group[532]|Clement
# pour conjecturer |forward|trigger|uncertain|30|Group[532]|Clement
# pour pressentir |forward|trigger|uncertain|30|Group[532]|Clement
# pour présager |forward|trigger|uncertain|30|Group[532]|Clement
# pour espérer |forward|trigger|uncertain|30|Group[532]|Clement
# pour préjuger |forward|trigger|uncertain|30|Group[532]|Clement
# pour présupposer |forward|trigger|uncertain|30|Group[532]|Clement
# pour prétendre |forward|trigger|uncertain|30|Group[532]|Clement
# pour prédire |forward|trigger|uncertain|30|Group[532]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "mur" | "mûri" | "obstacle" | "bon pour" | "mûr" | "accompli" | "mature" | "apte" | "usagé" | "falaise" | "frontière" | "avancé" | "formé" | "cloisonnement" | "barrières"
Var2 -> "libre"
Trigger_Rule -> "|both|pseudo|negated|10|Group[533]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# mur libre |both|pseudo|negated|10|Group[533]|Clement
# mûri libre |both|pseudo|negated|10|Group[533]|Clement
# obstacle libre |both|pseudo|negated|10|Group[533]|Clement
# bon pour libre |both|pseudo|negated|10|Group[533]|Clement
# mûr libre |both|pseudo|negated|10|Group[533]|Clement
# accompli libre |both|pseudo|negated|10|Group[533]|Clement
# mature libre |both|pseudo|negated|10|Group[533]|Clement
# apte libre |both|pseudo|negated|10|Group[533]|Clement
# usagé libre |both|pseudo|negated|10|Group[533]|Clement
# falaise libre |both|pseudo|negated|10|Group[533]|Clement
# frontière libre |both|pseudo|negated|10|Group[533]|Clement
# avancé libre |both|pseudo|negated|10|Group[533]|Clement
# formé libre |both|pseudo|negated|10|Group[533]|Clement
# cloisonnement libre |both|pseudo|negated|10|Group[533]|Clement
# barrières libre |both|pseudo|negated|10|Group[533]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "de"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[541]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# de |both|pseudo|uncertain|30|Group[541]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Patient Trigger_Rule
Var1 -> "histoire" | "passé" | "souvenir" | "historique"
Patient -> "du patient" | "de la patiente"| "du souffrant" | "de la souffrante"| "du sujet"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[542]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# histoire du patient |both|pseudo|uncertain|30|Group[542]|Clement
# histoire de la patiente |both|pseudo|uncertain|30|Group[542]|Clement
# histoire du souffrant |both|pseudo|uncertain|30|Group[542]|Clement
# histoire de la souffrante |both|pseudo|uncertain|30|Group[542]|Clement
# histoire du sujet |both|pseudo|uncertain|30|Group[542]|Clement
# passé du patient |both|pseudo|uncertain|30|Group[542]|Clement
# passé de la patiente |both|pseudo|uncertain|30|Group[542]|Clement
# passé du souffrant |both|pseudo|uncertain|30|Group[542]|Clement
# passé de la souffrante |both|pseudo|uncertain|30|Group[542]|Clement
# passé du sujet |both|pseudo|uncertain|30|Group[542]|Clement
# souvenir du patient |both|pseudo|uncertain|30|Group[542]|Clement
# souvenir de la patiente |both|pseudo|uncertain|30|Group[542]|Clement
# souvenir du souffrant |both|pseudo|uncertain|30|Group[542]|Clement
# souvenir de la souffrante |both|pseudo|uncertain|30|Group[542]|Clement
# souvenir du sujet |both|pseudo|uncertain|30|Group[542]|Clement
# historique du patient |both|pseudo|uncertain|30|Group[542]|Clement
# historique de la patiente |both|pseudo|uncertain|30|Group[542]|Clement
# historique du souffrant |both|pseudo|uncertain|30|Group[542]|Clement
# historique de la souffrante |both|pseudo|uncertain|30|Group[542]|Clement
# historique du sujet |both|pseudo|uncertain|30|Group[542]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "compte"
Var2 -> "tenu"
Var3 -> "de l'histoire" | "du passé" | "de l'historique" | "du fait"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# compte tenu de l'histoire |forward|termination|negated|10|Group[543]|Clement
# compte tenu du passé |forward|termination|negated|10|Group[543]|Clement
# compte tenu de l'historique |forward|termination|negated|10|Group[543]|Clement
# compte tenu du fait |forward|termination|negated|10|Group[543]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Var5 Trigger_Rule
Var1 -> "compte"
Var2 -> "tenu"
Var3 -> "de"
Var4 -> "son"
Var5 -> "histoire" | "passé" | "historique"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# compte tenu de son histoire |forward|termination|negated|10|Group[543]|Clement
# compte tenu de son passé |forward|termination|negated|10|Group[543]|Clement
# compte tenu de son historique |forward|termination|negated|10|Group[543]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "compte"
Var2 -> "tenu"
Var3 -> "de la gravité" | "du sérieux" | "de la sévérité" | "de l'urgence" | "du caractère" | "de la sériosité"
Var4 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# compte tenu de la gravité de |forward|termination|negated|10|Group[543]|Clement
# compte tenu du sérieux de |forward|termination|negated|10|Group[543]|Clement
# compte tenu de la sévérité de |forward|termination|negated|10|Group[543]|Clement
# compte tenu de l'urgence de |forward|termination|negated|10|Group[543]|Clement
# compte tenu du caractère de |forward|termination|negated|10|Group[543]|Clement
# compte tenu de la sériosité de |forward|termination|negated|10|Group[543]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "étant"
Var2 -> "donné"
Var3 -> "que"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# étant donné que |forward|termination|negated|10|Group[543]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "gram"
Var2 -> "négatif"
Trigger_Rule -> "|both|pseudo|negated|10|Group[550]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# gram négatif |both|pseudo|negated|10|Group[550]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "avoir" |"avait" | "a" | "ait" | "aient"
Var2 -> "un"
Var3 -> "\\w+"
Var4 -> "négatif" |"négative" | "nul" | "nulle"
Trigger_Rule -> "|forward|trigger|negated|10|Group[557]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# avoir un \w+ négatif |forward|trigger|negated|10|Group[557]|Clement
# avoir un \w+ négative |forward|trigger|negated|10|Group[557]|Clement
# avoir un \w+ nul |forward|trigger|negated|10|Group[557]|Clement
# avoir un \w+ nulle |forward|trigger|negated|10|Group[557]|Clement
# avait un \w+ négatif |forward|trigger|negated|10|Group[557]|Clement
# avait un \w+ négative |forward|trigger|negated|10|Group[557]|Clement
# avait un \w+ nul |forward|trigger|negated|10|Group[557]|Clement
# avait un \w+ nulle |forward|trigger|negated|10|Group[557]|Clement
# a un \w+ négatif |forward|trigger|negated|10|Group[557]|Clement
# a un \w+ négative |forward|trigger|negated|10|Group[557]|Clement
# a un \w+ nul |forward|trigger|negated|10|Group[557]|Clement
# a un \w+ nulle |forward|trigger|negated|10|Group[557]|Clement
# ait un \w+ négatif |forward|trigger|negated|10|Group[557]|Clement
# ait un \w+ négative |forward|trigger|negated|10|Group[557]|Clement
# ait un \w+ nul |forward|trigger|negated|10|Group[557]|Clement
# ait un \w+ nulle |forward|trigger|negated|10|Group[557]|Clement
# aient un \w+ négatif |forward|trigger|negated|10|Group[557]|Clement
# aient un \w+ négative |forward|trigger|negated|10|Group[557]|Clement
# aient un \w+ nul |forward|trigger|negated|10|Group[557]|Clement
# aient un \w+ nulle |forward|trigger|negated|10|Group[557]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "avoir" |"avait" | "a" | "ait" | "aient"
Var2 -> "une"
Var3 -> "\\w+"
Var4 -> "négatif" |"négative" | "nul" | "nulle"
Trigger_Rule -> "|forward|trigger|negated|10|Group[557]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# avoir une \w+ négatif |forward|trigger|negated|10|Group[557]|Clement
# avoir une \w+ négative |forward|trigger|negated|10|Group[557]|Clement
# avoir une \w+ nul |forward|trigger|negated|10|Group[557]|Clement
# avoir une \w+ nulle |forward|trigger|negated|10|Group[557]|Clement
# avait une \w+ négatif |forward|trigger|negated|10|Group[557]|Clement
# avait une \w+ négative |forward|trigger|negated|10|Group[557]|Clement
# avait une \w+ nul |forward|trigger|negated|10|Group[557]|Clement
# avait une \w+ nulle |forward|trigger|negated|10|Group[557]|Clement
# a une \w+ négatif |forward|trigger|negated|10|Group[557]|Clement
# a une \w+ négative |forward|trigger|negated|10|Group[557]|Clement
# a une \w+ nul |forward|trigger|negated|10|Group[557]|Clement
# a une \w+ nulle |forward|trigger|negated|10|Group[557]|Clement
# ait une \w+ négatif |forward|trigger|negated|10|Group[557]|Clement
# ait une \w+ négative |forward|trigger|negated|10|Group[557]|Clement
# ait une \w+ nul |forward|trigger|negated|10|Group[557]|Clement
# ait une \w+ nulle |forward|trigger|negated|10|Group[557]|Clement
# aient une \w+ négatif |forward|trigger|negated|10|Group[557]|Clement
# aient une \w+ négative |forward|trigger|negated|10|Group[557]|Clement
# aient une \w+ nul |forward|trigger|negated|10|Group[557]|Clement
# aient une \w+ nulle |forward|trigger|negated|10|Group[557]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "a été"|"ait été"|"était"
Var2 -> "négatif" |"négative" |"nul" | "nulle"
Trigger_Rule -> "|backward|trigger|negated|10|Group[561]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a été négatif |backward|trigger|negated|10|Group[561]|Clement
# a été négative |backward|trigger|negated|10|Group[561]|Clement
# a été nul |backward|trigger|negated|10|Group[561]|Clement
# a été nulle |backward|trigger|negated|10|Group[561]|Clement
# ait été négatif |backward|trigger|negated|10|Group[561]|Clement
# ait été négative |backward|trigger|negated|10|Group[561]|Clement
# ait été nul |backward|trigger|negated|10|Group[561]|Clement
# ait été nulle |backward|trigger|negated|10|Group[561]|Clement
# était négatif |backward|trigger|negated|10|Group[561]|Clement
# était négative |backward|trigger|negated|10|Group[561]|Clement
# était nul |backward|trigger|negated|10|Group[561]|Clement
# était nulle |backward|trigger|negated|10|Group[561]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "ont été"|"aient été"|"ont étaient"
Var2 -> "négatifs" |"négatives" |"nuls" | "nulles"
Trigger_Rule -> "|backward|trigger|negated|10|Group[561]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ont été négatifs |backward|trigger|negated|10|Group[561]|Clement
# ont été négatives |backward|trigger|negated|10|Group[561]|Clement
# ont été nuls |backward|trigger|negated|10|Group[561]|Clement
# ont été nulles |backward|trigger|negated|10|Group[561]|Clement
# aient été négatifs |backward|trigger|negated|10|Group[561]|Clement
# aient été négatives |backward|trigger|negated|10|Group[561]|Clement
# aient été nuls |backward|trigger|negated|10|Group[561]|Clement
# aient été nulles |backward|trigger|negated|10|Group[561]|Clement
# ont étaient négatifs |backward|trigger|negated|10|Group[561]|Clement
# ont étaient négatives |backward|trigger|negated|10|Group[561]|Clement
# ont étaient nuls |backward|trigger|negated|10|Group[561]|Clement
# ont étaient nulles |backward|trigger|negated|10|Group[561]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Trigger_Rule
Var1 -> "été"|"était"
Var2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit" |"écartés" |"évincé" | "supprimé" | "éloigné" | "enlevé" | "arrêté" | "stoppé" | "enrayé" | "contenu" | "suspendu" | "jugulé" | "terminé" | "fini" | "endigué" | "interrompu" | "gelé" | "absent" | "en défaut" | "dénué" | "dépourvu" | "disparu"
Termin -> "_" |"_e" 
Trigger_Rule -> "|backward|trigger|negated|10|Group[561, 563]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# été exclu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été exclu _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été refusé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été refusé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été repoussé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été repoussé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été rejeté _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été rejeté _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été éliminé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été éliminé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été proscrit _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été proscrit _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été écartés _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été écartés _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été évincé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été évincé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été supprimé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été supprimé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été éloigné _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été éloigné _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été enlevé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été enlevé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été arrêté _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été arrêté _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été stoppé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été stoppé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été enrayé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été enrayé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été contenu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été contenu _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été suspendu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été suspendu _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été jugulé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été jugulé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été terminé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été terminé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été fini _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été fini _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été endigué _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été endigué _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été interrompu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été interrompu _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été gelé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été gelé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été absent _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été absent _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été en défaut _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été en défaut _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été dénué _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été dénué _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été dépourvu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été dépourvu _e |backward|trigger|negated|10|Group[561, 563]|Clement
# été disparu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# été disparu _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était exclu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était exclu _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était refusé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était refusé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était repoussé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était repoussé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était rejeté _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était rejeté _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était éliminé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était éliminé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était proscrit _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était proscrit _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était écartés _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était écartés _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était évincé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était évincé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était supprimé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était supprimé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était éloigné _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était éloigné _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était enlevé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était enlevé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était arrêté _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était arrêté _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était stoppé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était stoppé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était enrayé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était enrayé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était contenu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était contenu _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était suspendu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était suspendu _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était jugulé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était jugulé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était terminé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était terminé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était fini _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était fini _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était endigué _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était endigué _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était interrompu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était interrompu _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était gelé _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était gelé _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était absent _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était absent _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était en défaut _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était en défaut _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était dénué _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était dénué _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était dépourvu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était dépourvu _e |backward|trigger|negated|10|Group[561, 563]|Clement
# était disparu _ |backward|trigger|negated|10|Group[561, 563]|Clement
# était disparu _e |backward|trigger|negated|10|Group[561, 563]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Trigger_Rule
Var1 -> "étaient"
Var2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit" |"écarté" |"évincé" | "supprimé" | "éloigné" | "enlevé" | "récusé" | "absent" | "en défaut" | "dénué" | "dépourvu" | "disparu"
Termin -> "_s" |"_es"
Trigger_Rule -> "|backward|trigger|negated|10|Group[561, 563]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# étaient exclu _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient exclu _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient refusé _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient refusé _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient repoussé _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient repoussé _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient rejeté _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient rejeté _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient éliminé _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient éliminé _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient proscrit _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient proscrit _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient écarté _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient écarté _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient évincé _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient évincé _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient supprimé _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient supprimé _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient éloigné _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient éloigné _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient enlevé _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient enlevé _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient récusé _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient récusé _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient absent _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient absent _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient en défaut _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient en défaut _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient dénué _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient dénué _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient dépourvu _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient dépourvu _es |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient disparu _s |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient disparu _es |backward|trigger|negated|10|Group[561, 563]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "été"|"était"
Var2 -> "mis à l'écart" | "mises de coté"
Trigger_Rule -> "|backward|trigger|negated|10|Group[561, 563]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# été mis à l'écart |backward|trigger|negated|10|Group[561, 563]|Clement
# été mises de coté |backward|trigger|negated|10|Group[561, 563]|Clement
# était mis à l'écart |backward|trigger|negated|10|Group[561, 563]|Clement
# était mises de coté |backward|trigger|negated|10|Group[561, 563]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "étaient"
Var2 -> "mises à l'écart" | "mises de coté"
Trigger_Rule -> "|backward|trigger|negated|10|Group[561, 563]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# étaient mises à l'écart |backward|trigger|negated|10|Group[561, 563]|Clement
# étaient mises de coté |backward|trigger|negated|10|Group[561, 563]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> | "n'a"
Var2 -> "pas"
Var3 -> | "eu"
Var4 -> "d'" | "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[569]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas d' |forward|trigger|negated|10|Group[569]|Clement
# pas de |forward|trigger|negated|10|Group[569]|Clement
# pas eu d' |forward|trigger|negated|10|Group[569]|Clement
# pas eu de |forward|trigger|negated|10|Group[569]|Clement
# n'a pas d' |forward|trigger|negated|10|Group[569]|Clement
# n'a pas de |forward|trigger|negated|10|Group[569]|Clement
# n'a pas eu d' |forward|trigger|negated|10|Group[569]|Clement
# n'a pas eu de |forward|trigger|negated|10|Group[569]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Trigger_Rule
Var1 -> "a"
Var2 -> "continué" | "perpétué" | "tenu"
Var3 -> "à"
Trigger_Rule -> "|forward|termination|negated|10|Group[575]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a continué à |forward|termination|negated|10|Group[575]|Clement
# a perpétué à |forward|termination|negated|10|Group[575]|Clement
# a tenu à |forward|termination|negated|10|Group[575]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->   Var1 Trigger_Rule
Var1 -> "son vieux"| "son ancien" | "son vieil" | "sa vielle"| "son ancienne" 
Trigger_Rule -> "|forward|termination|negated|10|Group[576]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# son vieux |forward|termination|negated|10|Group[576]|Clement
# son ancien |forward|termination|negated|10|Group[576]|Clement
# son vieil |forward|termination|negated|10|Group[576]|Clement
# sa vielle |forward|termination|negated|10|Group[576]|Clement
# son ancienne |forward|termination|negated|10|Group[576]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "examen historique"
Trigger_Rule -> "|both|pseudo|historical|30|Group[578]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# examen historique |both|pseudo|historical|30|Group[578]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "histoire" | "passé" | "souvenir" | "historique"
Var2 -> "et"
Trigger_Rule -> "|both|pseudo|historical|30|Group[578]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# histoire et |both|pseudo|historical|30|Group[578]|Clement
# passé et |both|pseudo|historical|30|Group[578]|Clement
# souvenir et |both|pseudo|historical|30|Group[578]|Clement
# historique et |both|pseudo|historical|30|Group[578]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "histoire" | "passé" | "souvenir" | "historique"
Var2 -> "pour"
Trigger_Rule -> "|both|pseudo|historical|30|Group[578]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# histoire pour |both|pseudo|historical|30|Group[578]|Clement
# passé pour |both|pseudo|historical|30|Group[578]|Clement
# souvenir pour |both|pseudo|historical|30|Group[578]|Clement
# historique pour |both|pseudo|historical|30|Group[578]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "histoire" | "passé" | "historique"
Var2 -> "et"
Var3 -> "examen" | "analyse" | "consultation" | "observation" | "auscultation" | "examen médical" | "autopsie" | "dépistage"
Trigger_Rule -> "|both|pseudo|historical|30|Group[578]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# histoire et examen |both|pseudo|historical|30|Group[578]|Clement
# histoire et analyse |both|pseudo|historical|30|Group[578]|Clement
# histoire et consultation |both|pseudo|historical|30|Group[578]|Clement
# histoire et observation |both|pseudo|historical|30|Group[578]|Clement
# histoire et auscultation |both|pseudo|historical|30|Group[578]|Clement
# histoire et examen médical |both|pseudo|historical|30|Group[578]|Clement
# histoire et autopsie |both|pseudo|historical|30|Group[578]|Clement
# histoire et dépistage |both|pseudo|historical|30|Group[578]|Clement
# passé et examen |both|pseudo|historical|30|Group[578]|Clement
# passé et analyse |both|pseudo|historical|30|Group[578]|Clement
# passé et consultation |both|pseudo|historical|30|Group[578]|Clement
# passé et observation |both|pseudo|historical|30|Group[578]|Clement
# passé et auscultation |both|pseudo|historical|30|Group[578]|Clement
# passé et examen médical |both|pseudo|historical|30|Group[578]|Clement
# passé et autopsie |both|pseudo|historical|30|Group[578]|Clement
# passé et dépistage |both|pseudo|historical|30|Group[578]|Clement
# historique et examen |both|pseudo|historical|30|Group[578]|Clement
# historique et analyse |both|pseudo|historical|30|Group[578]|Clement
# historique et consultation |both|pseudo|historical|30|Group[578]|Clement
# historique et observation |both|pseudo|historical|30|Group[578]|Clement
# historique et auscultation |both|pseudo|historical|30|Group[578]|Clement
# historique et examen médical |both|pseudo|historical|30|Group[578]|Clement
# historique et autopsie |both|pseudo|historical|30|Group[578]|Clement
# historique et dépistage |both|pseudo|historical|30|Group[578]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "histoire" | "passé" | "historique"
Var2 -> "de la maladie" | "du malaise" | "du mal" | "du trouble" | "de l'indisposition" | "de la souffrance" | "du syndrome" | "de l'infirmité" | "de l'incommodité" | "de l'atteinte" | "de la tare" | "de la pathologie" | "du traumatisme"
Trigger_Rule -> "|both|pseudo|historical|30|Group[578]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# histoire de la maladie |both|pseudo|historical|30|Group[578]|Clement
# histoire du malaise |both|pseudo|historical|30|Group[578]|Clement
# histoire du mal |both|pseudo|historical|30|Group[578]|Clement
# histoire du trouble |both|pseudo|historical|30|Group[578]|Clement
# histoire de l'indisposition |both|pseudo|historical|30|Group[578]|Clement
# histoire de la souffrance |both|pseudo|historical|30|Group[578]|Clement
# histoire du syndrome |both|pseudo|historical|30|Group[578]|Clement
# histoire de l'infirmité |both|pseudo|historical|30|Group[578]|Clement
# histoire de l'incommodité |both|pseudo|historical|30|Group[578]|Clement
# histoire de l'atteinte |both|pseudo|historical|30|Group[578]|Clement
# histoire de la tare |both|pseudo|historical|30|Group[578]|Clement
# histoire de la pathologie |both|pseudo|historical|30|Group[578]|Clement
# histoire du traumatisme |both|pseudo|historical|30|Group[578]|Clement
# passé de la maladie |both|pseudo|historical|30|Group[578]|Clement
# passé du malaise |both|pseudo|historical|30|Group[578]|Clement
# passé du mal |both|pseudo|historical|30|Group[578]|Clement
# passé du trouble |both|pseudo|historical|30|Group[578]|Clement
# passé de l'indisposition |both|pseudo|historical|30|Group[578]|Clement
# passé de la souffrance |both|pseudo|historical|30|Group[578]|Clement
# passé du syndrome |both|pseudo|historical|30|Group[578]|Clement
# passé de l'infirmité |both|pseudo|historical|30|Group[578]|Clement
# passé de l'incommodité |both|pseudo|historical|30|Group[578]|Clement
# passé de l'atteinte |both|pseudo|historical|30|Group[578]|Clement
# passé de la tare |both|pseudo|historical|30|Group[578]|Clement
# passé de la pathologie |both|pseudo|historical|30|Group[578]|Clement
# passé du traumatisme |both|pseudo|historical|30|Group[578]|Clement
# historique de la maladie |both|pseudo|historical|30|Group[578]|Clement
# historique du malaise |both|pseudo|historical|30|Group[578]|Clement
# historique du mal |both|pseudo|historical|30|Group[578]|Clement
# historique du trouble |both|pseudo|historical|30|Group[578]|Clement
# historique de l'indisposition |both|pseudo|historical|30|Group[578]|Clement
# historique de la souffrance |both|pseudo|historical|30|Group[578]|Clement
# historique du syndrome |both|pseudo|historical|30|Group[578]|Clement
# historique de l'infirmité |both|pseudo|historical|30|Group[578]|Clement
# historique de l'incommodité |both|pseudo|historical|30|Group[578]|Clement
# historique de l'atteinte |both|pseudo|historical|30|Group[578]|Clement
# historique de la tare |both|pseudo|historical|30|Group[578]|Clement
# historique de la pathologie |both|pseudo|historical|30|Group[578]|Clement
# historique du traumatisme |both|pseudo|historical|30|Group[578]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Trigger_Rule
Var1 -> "hist." | "histoire" | "passé" | "souvenir" | "historique"
Var2 -> "de" | "d'un" | "d'une" | "dans" | "pour" | "par"
Trigger_Rule -> "|forward|trigger|historical|30|Group[586]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# hist. de |forward|trigger|historical|30|Group[586]|Clement
# hist. d'un |forward|trigger|historical|30|Group[586]|Clement
# hist. d'une |forward|trigger|historical|30|Group[586]|Clement
# hist. dans |forward|trigger|historical|30|Group[586]|Clement
# hist. pour |forward|trigger|historical|30|Group[586]|Clement
# hist. par |forward|trigger|historical|30|Group[586]|Clement
# histoire de |forward|trigger|historical|30|Group[586]|Clement
# histoire d'un |forward|trigger|historical|30|Group[586]|Clement
# histoire d'une |forward|trigger|historical|30|Group[586]|Clement
# histoire dans |forward|trigger|historical|30|Group[586]|Clement
# histoire pour |forward|trigger|historical|30|Group[586]|Clement
# histoire par |forward|trigger|historical|30|Group[586]|Clement
# passé de |forward|trigger|historical|30|Group[586]|Clement
# passé d'un |forward|trigger|historical|30|Group[586]|Clement
# passé d'une |forward|trigger|historical|30|Group[586]|Clement
# passé dans |forward|trigger|historical|30|Group[586]|Clement
# passé pour |forward|trigger|historical|30|Group[586]|Clement
# passé par |forward|trigger|historical|30|Group[586]|Clement
# souvenir de |forward|trigger|historical|30|Group[586]|Clement
# souvenir d'un |forward|trigger|historical|30|Group[586]|Clement
# souvenir d'une |forward|trigger|historical|30|Group[586]|Clement
# souvenir dans |forward|trigger|historical|30|Group[586]|Clement
# souvenir pour |forward|trigger|historical|30|Group[586]|Clement
# souvenir par |forward|trigger|historical|30|Group[586]|Clement
# historique de |forward|trigger|historical|30|Group[586]|Clement
# historique d'un |forward|trigger|historical|30|Group[586]|Clement
# historique d'une |forward|trigger|historical|30|Group[586]|Clement
# historique dans |forward|trigger|historical|30|Group[586]|Clement
# historique pour |forward|trigger|historical|30|Group[586]|Clement
# historique par |forward|trigger|historical|30|Group[586]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "toutefois" | "cependant" | "néanmoins" | "pourtant"
Trigger_Rule -> "|forward|termination|negated|10|Group[587]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# toutefois |forward|termination|negated|10|Group[587]|Clement
# cependant |forward|termination|negated|10|Group[587]|Clement
# néanmoins |forward|termination|negated|10|Group[587]|Clement
# pourtant |forward|termination|negated|10|Group[587]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "si"
Var2 -> "négatif" |"négative" |"nul" | "nulle"
Trigger_Rule -> "|both|pseudo|conditional|30|Group[590]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# si négatif |both|pseudo|conditional|30|Group[590]|Clement
# si négative |both|pseudo|conditional|30|Group[590]|Clement
# si nul |both|pseudo|conditional|30|Group[590]|Clement
# si nulle |both|pseudo|conditional|30|Group[590]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "si"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[591]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# si |forward|trigger|conditional|30|Group[591]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "en"
Var2 -> "elle" | "lui"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[592]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# en elle |both|pseudo|uncertain|30|Group[592]|Clement
# en lui |both|pseudo|uncertain|30|Group[592]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "dans"
Var2 -> "son" | "sa" | "ses"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[593]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# dans son |both|pseudo|uncertain|30|Group[593]|Clement
# dans sa |both|pseudo|uncertain|30|Group[593]|Clement
# dans ses |both|pseudo|uncertain|30|Group[593]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "autrefois"|"anciennement" | "jadis"
Trigger_Rule -> "|both|trigger|historical|30|Group[594]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# autrefois |both|trigger|historical|30|Group[594]|Clement
# anciennement |both|trigger|historical|30|Group[594]|Clement
# jadis |both|trigger|historical|30|Group[594]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "dans"
Var2 -> "le contexte" | "la situation" | "les circonstances" | "le cadre" |  "la condition" |  "les conditions"
Var3 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[595]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# dans le contexte de |forward|termination|negated|10|Group[595]|Clement
# dans la situation de |forward|termination|negated|10|Group[595]|Clement
# dans les circonstances de |forward|termination|negated|10|Group[595]|Clement
# dans le cadre de |forward|termination|negated|10|Group[595]|Clement
# dans la condition de |forward|termination|negated|10|Group[595]|Clement
# dans les conditions de |forward|termination|negated|10|Group[595]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "incompatible"
Var2 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[596]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# incompatible avec |forward|trigger|negated|10|Group[596]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "indication" | "avertissement" | "suggestion" | "mention"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[598]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# indication |forward|trigger|uncertain|30|Group[598]|Clement
# avertissement |forward|trigger|uncertain|30|Group[598]|Clement
# suggestion |forward|trigger|uncertain|30|Group[598]|Clement
# mention |forward|trigger|uncertain|30|Group[598]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "est"|"était"
Var2 -> "neg"|"nég"|"nég."| "négatif" |"négative" |"nul" | "nulle"
Trigger_Rule -> "|backward|trigger|negated|10|Group[599]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# est neg |backward|trigger|negated|10|Group[599]|Clement
# est nég |backward|trigger|negated|10|Group[599]|Clement
# est nég. |backward|trigger|negated|10|Group[599]|Clement
# est négatif |backward|trigger|negated|10|Group[599]|Clement
# est négative |backward|trigger|negated|10|Group[599]|Clement
# est nul |backward|trigger|negated|10|Group[599]|Clement
# est nulle |backward|trigger|negated|10|Group[599]|Clement
# était neg |backward|trigger|negated|10|Group[599]|Clement
# était nég |backward|trigger|negated|10|Group[599]|Clement
# était nég. |backward|trigger|negated|10|Group[599]|Clement
# était négatif |backward|trigger|negated|10|Group[599]|Clement
# était négative |backward|trigger|negated|10|Group[599]|Clement
# était nul |backward|trigger|negated|10|Group[599]|Clement
# était nulle |backward|trigger|negated|10|Group[599]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sont"|"étaient"
Var2 -> "neg"|"nég"|"nég."| "négatifs" |"négatives" |"nuls" | "nulles"
Trigger_Rule -> "|backward|trigger|negated|10|Group[599]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sont neg |backward|trigger|negated|10|Group[599]|Clement
# sont nég |backward|trigger|negated|10|Group[599]|Clement
# sont nég. |backward|trigger|negated|10|Group[599]|Clement
# sont négatifs |backward|trigger|negated|10|Group[599]|Clement
# sont négatives |backward|trigger|negated|10|Group[599]|Clement
# sont nuls |backward|trigger|negated|10|Group[599]|Clement
# sont nulles |backward|trigger|negated|10|Group[599]|Clement
# étaient neg |backward|trigger|negated|10|Group[599]|Clement
# étaient nég |backward|trigger|negated|10|Group[599]|Clement
# étaient nég. |backward|trigger|negated|10|Group[599]|Clement
# étaient négatifs |backward|trigger|negated|10|Group[599]|Clement
# étaient négatives |backward|trigger|negated|10|Group[599]|Clement
# étaient nuls |backward|trigger|negated|10|Group[599]|Clement
# étaient nulles |backward|trigger|negated|10|Group[599]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Trigger_Rule
Var1 -> "n'est" | "ne sont" | "n'était" | "n'étaient"
Var2 -> "plus"
Trigger_Rule -> "|backward|trigger|negated|10|Group[603]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'est plus |backward|trigger|negated|10|Group[603]|Clement
# ne sont plus |backward|trigger|negated|10|Group[603]|Clement
# n'était plus |backward|trigger|negated|10|Group[603]|Clement
# n'étaient plus |backward|trigger|negated|10|Group[603]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "n'est" | "ne sont" | "n'était" | "n'étaient"
Var2 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[605]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'est pas |forward|trigger|negated|10|Group[605]|Clement
# ne sont pas |forward|trigger|negated|10|Group[605]|Clement
# n'était pas |forward|trigger|negated|10|Group[605]|Clement
# n'étaient pas |forward|trigger|negated|10|Group[605]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Trigger_Rule
Var1 -> "est"  |"était"
Var2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit" |"écarté" |"évincé" | "supprimé" | "éloigné" | "enlevé" | "arrêté" | "stoppé" | "enrayé" | "contenu" | "suspendu" | "jugulé" | "terminé" | "fini" | "endigué" | "interrompu" | "gelé" | "absent" | "en défaut" | "dénué" | "dépourvu" | "disparu"
Termin -> "_"|"_e"
Trigger_Rule -> "|backward|trigger|negated|10|Group[607]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# est exclu _ |backward|trigger|negated|10|Group[607]|Clement
# est exclu _e |backward|trigger|negated|10|Group[607]|Clement
# est refusé _ |backward|trigger|negated|10|Group[607]|Clement
# est refusé _e |backward|trigger|negated|10|Group[607]|Clement
# est repoussé _ |backward|trigger|negated|10|Group[607]|Clement
# est repoussé _e |backward|trigger|negated|10|Group[607]|Clement
# est rejeté _ |backward|trigger|negated|10|Group[607]|Clement
# est rejeté _e |backward|trigger|negated|10|Group[607]|Clement
# est éliminé _ |backward|trigger|negated|10|Group[607]|Clement
# est éliminé _e |backward|trigger|negated|10|Group[607]|Clement
# est proscrit _ |backward|trigger|negated|10|Group[607]|Clement
# est proscrit _e |backward|trigger|negated|10|Group[607]|Clement
# est écarté _ |backward|trigger|negated|10|Group[607]|Clement
# est écarté _e |backward|trigger|negated|10|Group[607]|Clement
# est évincé _ |backward|trigger|negated|10|Group[607]|Clement
# est évincé _e |backward|trigger|negated|10|Group[607]|Clement
# est supprimé _ |backward|trigger|negated|10|Group[607]|Clement
# est supprimé _e |backward|trigger|negated|10|Group[607]|Clement
# est éloigné _ |backward|trigger|negated|10|Group[607]|Clement
# est éloigné _e |backward|trigger|negated|10|Group[607]|Clement
# est enlevé _ |backward|trigger|negated|10|Group[607]|Clement
# est enlevé _e |backward|trigger|negated|10|Group[607]|Clement
# est arrêté _ |backward|trigger|negated|10|Group[607]|Clement
# est arrêté _e |backward|trigger|negated|10|Group[607]|Clement
# est stoppé _ |backward|trigger|negated|10|Group[607]|Clement
# est stoppé _e |backward|trigger|negated|10|Group[607]|Clement
# est enrayé _ |backward|trigger|negated|10|Group[607]|Clement
# est enrayé _e |backward|trigger|negated|10|Group[607]|Clement
# est contenu _ |backward|trigger|negated|10|Group[607]|Clement
# est contenu _e |backward|trigger|negated|10|Group[607]|Clement
# est suspendu _ |backward|trigger|negated|10|Group[607]|Clement
# est suspendu _e |backward|trigger|negated|10|Group[607]|Clement
# est jugulé _ |backward|trigger|negated|10|Group[607]|Clement
# est jugulé _e |backward|trigger|negated|10|Group[607]|Clement
# est terminé _ |backward|trigger|negated|10|Group[607]|Clement
# est terminé _e |backward|trigger|negated|10|Group[607]|Clement
# est fini _ |backward|trigger|negated|10|Group[607]|Clement
# est fini _e |backward|trigger|negated|10|Group[607]|Clement
# est endigué _ |backward|trigger|negated|10|Group[607]|Clement
# est endigué _e |backward|trigger|negated|10|Group[607]|Clement
# est interrompu _ |backward|trigger|negated|10|Group[607]|Clement
# est interrompu _e |backward|trigger|negated|10|Group[607]|Clement
# est gelé _ |backward|trigger|negated|10|Group[607]|Clement
# est gelé _e |backward|trigger|negated|10|Group[607]|Clement
# est absent _ |backward|trigger|negated|10|Group[607]|Clement
# est absent _e |backward|trigger|negated|10|Group[607]|Clement
# est en défaut _ |backward|trigger|negated|10|Group[607]|Clement
# est en défaut _e |backward|trigger|negated|10|Group[607]|Clement
# est dénué _ |backward|trigger|negated|10|Group[607]|Clement
# est dénué _e |backward|trigger|negated|10|Group[607]|Clement
# est dépourvu _ |backward|trigger|negated|10|Group[607]|Clement
# est dépourvu _e |backward|trigger|negated|10|Group[607]|Clement
# est disparu _ |backward|trigger|negated|10|Group[607]|Clement
# est disparu _e |backward|trigger|negated|10|Group[607]|Clement
# était exclu _ |backward|trigger|negated|10|Group[607]|Clement
# était exclu _e |backward|trigger|negated|10|Group[607]|Clement
# était refusé _ |backward|trigger|negated|10|Group[607]|Clement
# était refusé _e |backward|trigger|negated|10|Group[607]|Clement
# était repoussé _ |backward|trigger|negated|10|Group[607]|Clement
# était repoussé _e |backward|trigger|negated|10|Group[607]|Clement
# était rejeté _ |backward|trigger|negated|10|Group[607]|Clement
# était rejeté _e |backward|trigger|negated|10|Group[607]|Clement
# était éliminé _ |backward|trigger|negated|10|Group[607]|Clement
# était éliminé _e |backward|trigger|negated|10|Group[607]|Clement
# était proscrit _ |backward|trigger|negated|10|Group[607]|Clement
# était proscrit _e |backward|trigger|negated|10|Group[607]|Clement
# était écarté _ |backward|trigger|negated|10|Group[607]|Clement
# était écarté _e |backward|trigger|negated|10|Group[607]|Clement
# était évincé _ |backward|trigger|negated|10|Group[607]|Clement
# était évincé _e |backward|trigger|negated|10|Group[607]|Clement
# était supprimé _ |backward|trigger|negated|10|Group[607]|Clement
# était supprimé _e |backward|trigger|negated|10|Group[607]|Clement
# était éloigné _ |backward|trigger|negated|10|Group[607]|Clement
# était éloigné _e |backward|trigger|negated|10|Group[607]|Clement
# était enlevé _ |backward|trigger|negated|10|Group[607]|Clement
# était enlevé _e |backward|trigger|negated|10|Group[607]|Clement
# était arrêté _ |backward|trigger|negated|10|Group[607]|Clement
# était arrêté _e |backward|trigger|negated|10|Group[607]|Clement
# était stoppé _ |backward|trigger|negated|10|Group[607]|Clement
# était stoppé _e |backward|trigger|negated|10|Group[607]|Clement
# était enrayé _ |backward|trigger|negated|10|Group[607]|Clement
# était enrayé _e |backward|trigger|negated|10|Group[607]|Clement
# était contenu _ |backward|trigger|negated|10|Group[607]|Clement
# était contenu _e |backward|trigger|negated|10|Group[607]|Clement
# était suspendu _ |backward|trigger|negated|10|Group[607]|Clement
# était suspendu _e |backward|trigger|negated|10|Group[607]|Clement
# était jugulé _ |backward|trigger|negated|10|Group[607]|Clement
# était jugulé _e |backward|trigger|negated|10|Group[607]|Clement
# était terminé _ |backward|trigger|negated|10|Group[607]|Clement
# était terminé _e |backward|trigger|negated|10|Group[607]|Clement
# était fini _ |backward|trigger|negated|10|Group[607]|Clement
# était fini _e |backward|trigger|negated|10|Group[607]|Clement
# était endigué _ |backward|trigger|negated|10|Group[607]|Clement
# était endigué _e |backward|trigger|negated|10|Group[607]|Clement
# était interrompu _ |backward|trigger|negated|10|Group[607]|Clement
# était interrompu _e |backward|trigger|negated|10|Group[607]|Clement
# était gelé _ |backward|trigger|negated|10|Group[607]|Clement
# était gelé _e |backward|trigger|negated|10|Group[607]|Clement
# était absent _ |backward|trigger|negated|10|Group[607]|Clement
# était absent _e |backward|trigger|negated|10|Group[607]|Clement
# était en défaut _ |backward|trigger|negated|10|Group[607]|Clement
# était en défaut _e |backward|trigger|negated|10|Group[607]|Clement
# était dénué _ |backward|trigger|negated|10|Group[607]|Clement
# était dénué _e |backward|trigger|negated|10|Group[607]|Clement
# était dépourvu _ |backward|trigger|negated|10|Group[607]|Clement
# était dépourvu _e |backward|trigger|negated|10|Group[607]|Clement
# était disparu _ |backward|trigger|negated|10|Group[607]|Clement
# était disparu _e |backward|trigger|negated|10|Group[607]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Trigger_Rule
Var1 -> "sont"|"étaient"
Var2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit" |"écarté" |"évincé" | "supprimé" | "éloigné" | "enlevé" | "arrêté" | "stoppé" | "enrayé" | "contenu" | "suspendu" | "jugulé" | "terminé" | "fini" | "endigué" | "interrompu" | "gelé" | "absent" | "en défaut" | "dénué" | "dépourvu" | "disparu"
Termin -> "_s" |"_es"
Trigger_Rule -> "|backward|trigger|negated|10|Group[607]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sont exclu _s |backward|trigger|negated|10|Group[607]|Clement
# sont exclu _es |backward|trigger|negated|10|Group[607]|Clement
# sont refusé _s |backward|trigger|negated|10|Group[607]|Clement
# sont refusé _es |backward|trigger|negated|10|Group[607]|Clement
# sont repoussé _s |backward|trigger|negated|10|Group[607]|Clement
# sont repoussé _es |backward|trigger|negated|10|Group[607]|Clement
# sont rejeté _s |backward|trigger|negated|10|Group[607]|Clement
# sont rejeté _es |backward|trigger|negated|10|Group[607]|Clement
# sont éliminé _s |backward|trigger|negated|10|Group[607]|Clement
# sont éliminé _es |backward|trigger|negated|10|Group[607]|Clement
# sont proscrit _s |backward|trigger|negated|10|Group[607]|Clement
# sont proscrit _es |backward|trigger|negated|10|Group[607]|Clement
# sont écarté _s |backward|trigger|negated|10|Group[607]|Clement
# sont écarté _es |backward|trigger|negated|10|Group[607]|Clement
# sont évincé _s |backward|trigger|negated|10|Group[607]|Clement
# sont évincé _es |backward|trigger|negated|10|Group[607]|Clement
# sont supprimé _s |backward|trigger|negated|10|Group[607]|Clement
# sont supprimé _es |backward|trigger|negated|10|Group[607]|Clement
# sont éloigné _s |backward|trigger|negated|10|Group[607]|Clement
# sont éloigné _es |backward|trigger|negated|10|Group[607]|Clement
# sont enlevé _s |backward|trigger|negated|10|Group[607]|Clement
# sont enlevé _es |backward|trigger|negated|10|Group[607]|Clement
# sont arrêté _s |backward|trigger|negated|10|Group[607]|Clement
# sont arrêté _es |backward|trigger|negated|10|Group[607]|Clement
# sont stoppé _s |backward|trigger|negated|10|Group[607]|Clement
# sont stoppé _es |backward|trigger|negated|10|Group[607]|Clement
# sont enrayé _s |backward|trigger|negated|10|Group[607]|Clement
# sont enrayé _es |backward|trigger|negated|10|Group[607]|Clement
# sont contenu _s |backward|trigger|negated|10|Group[607]|Clement
# sont contenu _es |backward|trigger|negated|10|Group[607]|Clement
# sont suspendu _s |backward|trigger|negated|10|Group[607]|Clement
# sont suspendu _es |backward|trigger|negated|10|Group[607]|Clement
# sont jugulé _s |backward|trigger|negated|10|Group[607]|Clement
# sont jugulé _es |backward|trigger|negated|10|Group[607]|Clement
# sont terminé _s |backward|trigger|negated|10|Group[607]|Clement
# sont terminé _es |backward|trigger|negated|10|Group[607]|Clement
# sont fini _s |backward|trigger|negated|10|Group[607]|Clement
# sont fini _es |backward|trigger|negated|10|Group[607]|Clement
# sont endigué _s |backward|trigger|negated|10|Group[607]|Clement
# sont endigué _es |backward|trigger|negated|10|Group[607]|Clement
# sont interrompu _s |backward|trigger|negated|10|Group[607]|Clement
# sont interrompu _es |backward|trigger|negated|10|Group[607]|Clement
# sont gelé _s |backward|trigger|negated|10|Group[607]|Clement
# sont gelé _es |backward|trigger|negated|10|Group[607]|Clement
# sont absent _s |backward|trigger|negated|10|Group[607]|Clement
# sont absent _es |backward|trigger|negated|10|Group[607]|Clement
# sont en défaut _s |backward|trigger|negated|10|Group[607]|Clement
# sont en défaut _es |backward|trigger|negated|10|Group[607]|Clement
# sont dénué _s |backward|trigger|negated|10|Group[607]|Clement
# sont dénué _es |backward|trigger|negated|10|Group[607]|Clement
# sont dépourvu _s |backward|trigger|negated|10|Group[607]|Clement
# sont dépourvu _es |backward|trigger|negated|10|Group[607]|Clement
# sont disparu _s |backward|trigger|negated|10|Group[607]|Clement
# sont disparu _es |backward|trigger|negated|10|Group[607]|Clement
# étaient exclu _s |backward|trigger|negated|10|Group[607]|Clement
# étaient exclu _es |backward|trigger|negated|10|Group[607]|Clement
# étaient refusé _s |backward|trigger|negated|10|Group[607]|Clement
# étaient refusé _es |backward|trigger|negated|10|Group[607]|Clement
# étaient repoussé _s |backward|trigger|negated|10|Group[607]|Clement
# étaient repoussé _es |backward|trigger|negated|10|Group[607]|Clement
# étaient rejeté _s |backward|trigger|negated|10|Group[607]|Clement
# étaient rejeté _es |backward|trigger|negated|10|Group[607]|Clement
# étaient éliminé _s |backward|trigger|negated|10|Group[607]|Clement
# étaient éliminé _es |backward|trigger|negated|10|Group[607]|Clement
# étaient proscrit _s |backward|trigger|negated|10|Group[607]|Clement
# étaient proscrit _es |backward|trigger|negated|10|Group[607]|Clement
# étaient écarté _s |backward|trigger|negated|10|Group[607]|Clement
# étaient écarté _es |backward|trigger|negated|10|Group[607]|Clement
# étaient évincé _s |backward|trigger|negated|10|Group[607]|Clement
# étaient évincé _es |backward|trigger|negated|10|Group[607]|Clement
# étaient supprimé _s |backward|trigger|negated|10|Group[607]|Clement
# étaient supprimé _es |backward|trigger|negated|10|Group[607]|Clement
# étaient éloigné _s |backward|trigger|negated|10|Group[607]|Clement
# étaient éloigné _es |backward|trigger|negated|10|Group[607]|Clement
# étaient enlevé _s |backward|trigger|negated|10|Group[607]|Clement
# étaient enlevé _es |backward|trigger|negated|10|Group[607]|Clement
# étaient arrêté _s |backward|trigger|negated|10|Group[607]|Clement
# étaient arrêté _es |backward|trigger|negated|10|Group[607]|Clement
# étaient stoppé _s |backward|trigger|negated|10|Group[607]|Clement
# étaient stoppé _es |backward|trigger|negated|10|Group[607]|Clement
# étaient enrayé _s |backward|trigger|negated|10|Group[607]|Clement
# étaient enrayé _es |backward|trigger|negated|10|Group[607]|Clement
# étaient contenu _s |backward|trigger|negated|10|Group[607]|Clement
# étaient contenu _es |backward|trigger|negated|10|Group[607]|Clement
# étaient suspendu _s |backward|trigger|negated|10|Group[607]|Clement
# étaient suspendu _es |backward|trigger|negated|10|Group[607]|Clement
# étaient jugulé _s |backward|trigger|negated|10|Group[607]|Clement
# étaient jugulé _es |backward|trigger|negated|10|Group[607]|Clement
# étaient terminé _s |backward|trigger|negated|10|Group[607]|Clement
# étaient terminé _es |backward|trigger|negated|10|Group[607]|Clement
# étaient fini _s |backward|trigger|negated|10|Group[607]|Clement
# étaient fini _es |backward|trigger|negated|10|Group[607]|Clement
# étaient endigué _s |backward|trigger|negated|10|Group[607]|Clement
# étaient endigué _es |backward|trigger|negated|10|Group[607]|Clement
# étaient interrompu _s |backward|trigger|negated|10|Group[607]|Clement
# étaient interrompu _es |backward|trigger|negated|10|Group[607]|Clement
# étaient gelé _s |backward|trigger|negated|10|Group[607]|Clement
# étaient gelé _es |backward|trigger|negated|10|Group[607]|Clement
# étaient absent _s |backward|trigger|negated|10|Group[607]|Clement
# étaient absent _es |backward|trigger|negated|10|Group[607]|Clement
# étaient en défaut _s |backward|trigger|negated|10|Group[607]|Clement
# étaient en défaut _es |backward|trigger|negated|10|Group[607]|Clement
# étaient dénué _s |backward|trigger|negated|10|Group[607]|Clement
# étaient dénué _es |backward|trigger|negated|10|Group[607]|Clement
# étaient dépourvu _s |backward|trigger|negated|10|Group[607]|Clement
# étaient dépourvu _es |backward|trigger|negated|10|Group[607]|Clement
# étaient disparu _s |backward|trigger|negated|10|Group[607]|Clement
# étaient disparu _es |backward|trigger|negated|10|Group[607]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "a" |"ont" | "ait" | "aient" | "avait" | "avaient"
Var2 -> "arrêté" | "stoppé" | "terminé" | "fini" | "cessé" | "pris fin" | "gelé" | "disparu" | "fait défaut"
Trigger_Rule -> "|backward|trigger|negated|10|Group[609]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a arrêté |backward|trigger|negated|10|Group[609]|Clement
# a stoppé |backward|trigger|negated|10|Group[609]|Clement
# a terminé |backward|trigger|negated|10|Group[609]|Clement
# a fini |backward|trigger|negated|10|Group[609]|Clement
# a cessé |backward|trigger|negated|10|Group[609]|Clement
# a pris fin |backward|trigger|negated|10|Group[609]|Clement
# a gelé |backward|trigger|negated|10|Group[609]|Clement
# a disparu |backward|trigger|negated|10|Group[609]|Clement
# a fait défaut |backward|trigger|negated|10|Group[609]|Clement
# ont arrêté |backward|trigger|negated|10|Group[609]|Clement
# ont stoppé |backward|trigger|negated|10|Group[609]|Clement
# ont terminé |backward|trigger|negated|10|Group[609]|Clement
# ont fini |backward|trigger|negated|10|Group[609]|Clement
# ont cessé |backward|trigger|negated|10|Group[609]|Clement
# ont pris fin |backward|trigger|negated|10|Group[609]|Clement
# ont gelé |backward|trigger|negated|10|Group[609]|Clement
# ont disparu |backward|trigger|negated|10|Group[609]|Clement
# ont fait défaut |backward|trigger|negated|10|Group[609]|Clement
# ait arrêté |backward|trigger|negated|10|Group[609]|Clement
# ait stoppé |backward|trigger|negated|10|Group[609]|Clement
# ait terminé |backward|trigger|negated|10|Group[609]|Clement
# ait fini |backward|trigger|negated|10|Group[609]|Clement
# ait cessé |backward|trigger|negated|10|Group[609]|Clement
# ait pris fin |backward|trigger|negated|10|Group[609]|Clement
# ait gelé |backward|trigger|negated|10|Group[609]|Clement
# ait disparu |backward|trigger|negated|10|Group[609]|Clement
# ait fait défaut |backward|trigger|negated|10|Group[609]|Clement
# aient arrêté |backward|trigger|negated|10|Group[609]|Clement
# aient stoppé |backward|trigger|negated|10|Group[609]|Clement
# aient terminé |backward|trigger|negated|10|Group[609]|Clement
# aient fini |backward|trigger|negated|10|Group[609]|Clement
# aient cessé |backward|trigger|negated|10|Group[609]|Clement
# aient pris fin |backward|trigger|negated|10|Group[609]|Clement
# aient gelé |backward|trigger|negated|10|Group[609]|Clement
# aient disparu |backward|trigger|negated|10|Group[609]|Clement
# aient fait défaut |backward|trigger|negated|10|Group[609]|Clement
# avait arrêté |backward|trigger|negated|10|Group[609]|Clement
# avait stoppé |backward|trigger|negated|10|Group[609]|Clement
# avait terminé |backward|trigger|negated|10|Group[609]|Clement
# avait fini |backward|trigger|negated|10|Group[609]|Clement
# avait cessé |backward|trigger|negated|10|Group[609]|Clement
# avait pris fin |backward|trigger|negated|10|Group[609]|Clement
# avait gelé |backward|trigger|negated|10|Group[609]|Clement
# avait disparu |backward|trigger|negated|10|Group[609]|Clement
# avait fait défaut |backward|trigger|negated|10|Group[609]|Clement
# avaient arrêté |backward|trigger|negated|10|Group[609]|Clement
# avaient stoppé |backward|trigger|negated|10|Group[609]|Clement
# avaient terminé |backward|trigger|negated|10|Group[609]|Clement
# avaient fini |backward|trigger|negated|10|Group[609]|Clement
# avaient cessé |backward|trigger|negated|10|Group[609]|Clement
# avaient pris fin |backward|trigger|negated|10|Group[609]|Clement
# avaient gelé |backward|trigger|negated|10|Group[609]|Clement
# avaient disparu |backward|trigger|negated|10|Group[609]|Clement
# avaient fait défaut |backward|trigger|negated|10|Group[609]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "est"
Var2 -> "à"
Var3 -> "exclure" | "éliminer" | "rejeter" | "proscrire" | "éloigner" | "supprimer" | "radier"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[611]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# est à exclure |forward|trigger|uncertain|30|Group[611]|Clement
# est à éliminer |forward|trigger|uncertain|30|Group[611]|Clement
# est à rejeter |forward|trigger|uncertain|30|Group[611]|Clement
# est à proscrire |forward|trigger|uncertain|30|Group[611]|Clement
# est à éloigner |forward|trigger|uncertain|30|Group[611]|Clement
# est à supprimer |forward|trigger|uncertain|30|Group[611]|Clement
# est à radier |forward|trigger|uncertain|30|Group[611]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "manque" | "insuffisance" | "défaut" | "déficience" | "pénurie" | "carence" | "privation" | "lacune" | "omission" | "manquement" | "défaillance" | "rareté" | "oubli" | "faute" | "faiblesse"
Var2 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[615]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# manque de |forward|trigger|negated|10|Group[615]|Clement
# insuffisance de |forward|trigger|negated|10|Group[615]|Clement
# défaut de |forward|trigger|negated|10|Group[615]|Clement
# déficience de |forward|trigger|negated|10|Group[615]|Clement
# pénurie de |forward|trigger|negated|10|Group[615]|Clement
# carence de |forward|trigger|negated|10|Group[615]|Clement
# privation de |forward|trigger|negated|10|Group[615]|Clement
# lacune de |forward|trigger|negated|10|Group[615]|Clement
# omission de |forward|trigger|negated|10|Group[615]|Clement
# manquement de |forward|trigger|negated|10|Group[615]|Clement
# défaillance de |forward|trigger|negated|10|Group[615]|Clement
# rareté de |forward|trigger|negated|10|Group[615]|Clement
# oubli de |forward|trigger|negated|10|Group[615]|Clement
# faute de |forward|trigger|negated|10|Group[615]|Clement
# faiblesse de |forward|trigger|negated|10|Group[615]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "manquait" | "oubliait" | "ratait" | "omettait"
Trigger_Rule -> "|forward|trigger|negated|10|Group[617]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# manquait |forward|trigger|negated|10|Group[617]|Clement
# oubliait |forward|trigger|negated|10|Group[617]|Clement
# ratait |forward|trigger|negated|10|Group[617]|Clement
# omettait |forward|trigger|negated|10|Group[617]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Trigger_Rule
Var1 -> "il y a"
Var2 -> "\\> 0"
Var3 -> "année" | "années" | "an" | "ans"
Trigger_Rule -> "|backward|trigger|historical|30|Group[619]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# il y a \> 0 année |backward|trigger|historical|30|Group[619]|Clement
# il y a \> 0 années |backward|trigger|historical|30|Group[619]|Clement
# il y a \> 0 an |backward|trigger|historical|30|Group[619]|Clement
# il y a \> 0 ans |backward|trigger|historical|30|Group[619]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Trigger_Rule
Var1 -> "il y a"
Var2 -> "\\> 1 semaines" | "\\> 13 jours"
Trigger_Rule -> "|backward|trigger|historical|30|Group[619]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# il y a \> 1 semaines |backward|trigger|historical|30|Group[619]|Clement
# il y a \> 13 jours |backward|trigger|historical|30|Group[619]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Seasons Var1 Trigger_Rule
Seasons -> "au printemps"|"le printemps"|"l'été"|"l'automne"|"l'hiver"
Var1 -> "dernier"
Trigger_Rule -> "|backward|trigger|historical|30|Group[626]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# au printemps dernier |backward|trigger|historical|30|Group[626]|Clement
# le printemps dernier |backward|trigger|historical|30|Group[626]|Clement
# l'été dernier |backward|trigger|historical|30|Group[626]|Clement
# l'automne dernier |backward|trigger|historical|30|Group[626]|Clement
# l'hiver dernier |backward|trigger|historical|30|Group[626]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "janvier"|"février"|"mars"|"avril"|"mai"|"juin" |"juillet"|"août"|"septembre"|"octobre"|"novembre"|"décembre"
Var2 -> "dernier"
Trigger_Rule -> "|backward|trigger|historical|30|Group[626]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# janvier dernier |backward|trigger|historical|30|Group[626]|Clement
# février dernier |backward|trigger|historical|30|Group[626]|Clement
# mars dernier |backward|trigger|historical|30|Group[626]|Clement
# avril dernier |backward|trigger|historical|30|Group[626]|Clement
# mai dernier |backward|trigger|historical|30|Group[626]|Clement
# juin dernier |backward|trigger|historical|30|Group[626]|Clement
# juillet dernier |backward|trigger|historical|30|Group[626]|Clement
# août dernier |backward|trigger|historical|30|Group[626]|Clement
# septembre dernier |backward|trigger|historical|30|Group[626]|Clement
# octobre dernier |backward|trigger|historical|30|Group[626]|Clement
# novembre dernier |backward|trigger|historical|30|Group[626]|Clement
# décembre dernier |backward|trigger|historical|30|Group[626]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "en"
Var2 -> "janvier"|"février"|"mars"|"avril"|"mai"|"juin" |"juillet"|"août"|"septembre"|"octobre"|"novembre"|"décembre"
Trigger_Rule -> "|backward|trigger|historical|30|Group[626]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# en janvier |backward|trigger|historical|30|Group[626]|Clement
# en février |backward|trigger|historical|30|Group[626]|Clement
# en mars |backward|trigger|historical|30|Group[626]|Clement
# en avril |backward|trigger|historical|30|Group[626]|Clement
# en mai |backward|trigger|historical|30|Group[626]|Clement
# en juin |backward|trigger|historical|30|Group[626]|Clement
# en juillet |backward|trigger|historical|30|Group[626]|Clement
# en août |backward|trigger|historical|30|Group[626]|Clement
# en septembre |backward|trigger|historical|30|Group[626]|Clement
# en octobre |backward|trigger|historical|30|Group[626]|Clement
# en novembre |backward|trigger|historical|30|Group[626]|Clement
# en décembre |backward|trigger|historical|30|Group[626]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "contributeurs"
Var2 -> "probables"
Var3 -> "à"
Trigger_Rule -> "|forward|termination|negated|10|Group[642]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# contributeurs probables à |forward|termination|negated|10|Group[642]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "contributeur"
Var2 -> "probable"
Var3 -> "à"
Trigger_Rule -> "|forward|termination|negated|10|Group[642]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# contributeur probable à |forward|termination|negated|10|Group[642]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "probablement"
Var2 -> "en"
Var3 -> "cas" | "situation"
Var4 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[642]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# probablement en cas de |forward|termination|negated|10|Group[642]|Clement
# probablement en situation de |forward|termination|negated|10|Group[642]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "probablement"
Trigger_Rule -> "|forward|termination|negated|10|Group[642]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# probablement |forward|termination|negated|10|Group[642]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "élément" | "ingrédient" | "constituant" | "facteur"
Var2 -> "probable"
Var3 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[642]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# élément probable de |forward|termination|negated|10|Group[642]|Clement
# ingrédient probable de |forward|termination|negated|10|Group[642]|Clement
# constituant probable de |forward|termination|negated|10|Group[642]|Clement
# facteur probable de |forward|termination|negated|10|Group[642]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->   Var1 Trigger_Rule
Var1 -> "probablement"| "éventuellement" | "plausiblement" | "possiblement" | "sans doute" | "sûrement"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[646]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# probablement |both|pseudo|uncertain|30|Group[646]|Clement
# éventuellement |both|pseudo|uncertain|30|Group[646]|Clement
# plausiblement |both|pseudo|uncertain|30|Group[646]|Clement
# possiblement |both|pseudo|uncertain|30|Group[646]|Clement
# sans doute |both|pseudo|uncertain|30|Group[646]|Clement
# sûrement |both|pseudo|uncertain|30|Group[646]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Termin Trigger_Rule
Var1 -> "probable"| "éventuel" | "plausible" | "possible"
Termin -> |"_s"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[647]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# probable |forward|trigger|uncertain|30|Group[647]|Clement
# probable _s |forward|trigger|uncertain|30|Group[647]|Clement
# éventuel |forward|trigger|uncertain|30|Group[647]|Clement
# éventuel _s |forward|trigger|uncertain|30|Group[647]|Clement
# plausible |forward|trigger|uncertain|30|Group[647]|Clement
# plausible _s |forward|trigger|uncertain|30|Group[647]|Clement
# possible |forward|trigger|uncertain|30|Group[647]|Clement
# possible _s |forward|trigger|uncertain|30|Group[647]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "chercher" | "scruter" | "sonder" | "essayer" | "explorer" | "rechercher" | "examiner" | "fouiller"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[648]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# chercher |forward|trigger|conditional|30|Group[648]|Clement
# scruter |forward|trigger|conditional|30|Group[648]|Clement
# sonder |forward|trigger|conditional|30|Group[648]|Clement
# essayer |forward|trigger|conditional|30|Group[648]|Clement
# explorer |forward|trigger|conditional|30|Group[648]|Clement
# rechercher |forward|trigger|conditional|30|Group[648]|Clement
# examiner |forward|trigger|conditional|30|Group[648]|Clement
# fouiller |forward|trigger|conditional|30|Group[648]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "peut"
Var2 -> "être"
Var3 -> "\\w+"
Var4 -> "sous-estimé" | "minimisé" | "minoré" | "mésestimé" | "sous-évalué"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[651]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut être \w+ sous-estimé |both|pseudo|uncertain|30|Group[651]|Clement
# peut être \w+ minimisé |both|pseudo|uncertain|30|Group[651]|Clement
# peut être \w+ minoré |both|pseudo|uncertain|30|Group[651]|Clement
# peut être \w+ mésestimé |both|pseudo|uncertain|30|Group[651]|Clement
# peut être \w+ sous-évalué |both|pseudo|uncertain|30|Group[651]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "peut"
Var2 -> "contribuer" | "collaborer" | "concourir" | "participer" | "favoriser" | "prendre part"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[652]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut contribuer |both|pseudo|uncertain|30|Group[652]|Clement
# peut collaborer |both|pseudo|uncertain|30|Group[652]|Clement
# peut concourir |both|pseudo|uncertain|30|Group[652]|Clement
# peut participer |both|pseudo|uncertain|30|Group[652]|Clement
# peut favoriser |both|pseudo|uncertain|30|Group[652]|Clement
# peut prendre part |both|pseudo|uncertain|30|Group[652]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "peut-être"
Var2 -> "dû"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[653]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut-être dû |forward|trigger|uncertain|30|Group[653]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pourrait"
Var2 -> "démasquer" | "révéler" | "dévoiler" | "déceler" | "détecter"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[654]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pourrait démasquer |both|pseudo|uncertain|30|Group[654]|Clement
# pourrait révéler |both|pseudo|uncertain|30|Group[654]|Clement
# pourrait dévoiler |both|pseudo|uncertain|30|Group[654]|Clement
# pourrait déceler |both|pseudo|uncertain|30|Group[654]|Clement
# pourrait détecter |both|pseudo|uncertain|30|Group[654]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "peut"
Var2 -> "être"
Var3 -> "lié" | "connexe" | "relié" | "imbriqué" | "conjoint" | "attaché" | "inhérent" | "rattaché" | "coordonné" | "adjoint" | "assujetti"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[654]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut être lié |both|pseudo|uncertain|30|Group[654]|Clement
# peut être connexe |both|pseudo|uncertain|30|Group[654]|Clement
# peut être relié |both|pseudo|uncertain|30|Group[654]|Clement
# peut être imbriqué |both|pseudo|uncertain|30|Group[654]|Clement
# peut être conjoint |both|pseudo|uncertain|30|Group[654]|Clement
# peut être attaché |both|pseudo|uncertain|30|Group[654]|Clement
# peut être inhérent |both|pseudo|uncertain|30|Group[654]|Clement
# peut être rattaché |both|pseudo|uncertain|30|Group[654]|Clement
# peut être coordonné |both|pseudo|uncertain|30|Group[654]|Clement
# peut être adjoint |both|pseudo|uncertain|30|Group[654]|Clement
# peut être assujetti |both|pseudo|uncertain|30|Group[654]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "peut"
Var2 -> "être"
Var3 -> "sous-estimé" | "minimisé" | "minoré" | "mésestimé" | "déconsidéré" | "méprisé" | "décrié" | "dévalué" | "décrédité" | "discrédité" | "déprécié" | "méjugé" | "dévalorisé" | "sous-évalué"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[654]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut être sous-estimé |both|pseudo|uncertain|30|Group[654]|Clement
# peut être minimisé |both|pseudo|uncertain|30|Group[654]|Clement
# peut être minoré |both|pseudo|uncertain|30|Group[654]|Clement
# peut être mésestimé |both|pseudo|uncertain|30|Group[654]|Clement
# peut être déconsidéré |both|pseudo|uncertain|30|Group[654]|Clement
# peut être méprisé |both|pseudo|uncertain|30|Group[654]|Clement
# peut être décrié |both|pseudo|uncertain|30|Group[654]|Clement
# peut être dévalué |both|pseudo|uncertain|30|Group[654]|Clement
# peut être décrédité |both|pseudo|uncertain|30|Group[654]|Clement
# peut être discrédité |both|pseudo|uncertain|30|Group[654]|Clement
# peut être déprécié |both|pseudo|uncertain|30|Group[654]|Clement
# peut être méjugé |both|pseudo|uncertain|30|Group[654]|Clement
# peut être dévalorisé |both|pseudo|uncertain|30|Group[654]|Clement
# peut être sous-évalué |both|pseudo|uncertain|30|Group[654]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "peut-être" |"peut être" | "peut-etre" |"peut etre"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[659]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut-être |forward|trigger|uncertain|30|Group[659]|Clement
# peut être |forward|trigger|uncertain|30|Group[659]|Clement
# peut-etre |forward|trigger|uncertain|30|Group[659]|Clement
# peut etre |forward|trigger|uncertain|30|Group[659]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "peut"
Var2 -> "représenter" | "symboliser" | "décrire" | "montrer" | "dépeindre" | "figurer" | "exposer" | "signifier" | "exhiber" | "évoquer" | "désigner"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[659]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut représenter |forward|trigger|uncertain|30|Group[659]|Clement
# peut symboliser |forward|trigger|uncertain|30|Group[659]|Clement
# peut décrire |forward|trigger|uncertain|30|Group[659]|Clement
# peut montrer |forward|trigger|uncertain|30|Group[659]|Clement
# peut dépeindre |forward|trigger|uncertain|30|Group[659]|Clement
# peut figurer |forward|trigger|uncertain|30|Group[659]|Clement
# peut exposer |forward|trigger|uncertain|30|Group[659]|Clement
# peut signifier |forward|trigger|uncertain|30|Group[659]|Clement
# peut exhiber |forward|trigger|uncertain|30|Group[659]|Clement
# peut évoquer |forward|trigger|uncertain|30|Group[659]|Clement
# peut désigner |forward|trigger|uncertain|30|Group[659]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "peut" | "pourrait"
Var2 -> "avoir"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[659]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut avoir |forward|trigger|uncertain|30|Group[659]|Clement
# pourrait avoir |forward|trigger|uncertain|30|Group[659]|Clement

# %%
## from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "léger" | "légers" |"légerement" | "doux"| "douce"| "douces"
Trigger_Rule -> "|forward|termination|negated|10|Group[666]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# léger |forward|termination|negated|10|Group[666]|Clement
# légers |forward|termination|negated|10|Group[666]|Clement
# légerement |forward|termination|negated|10|Group[666]|Clement
# doux |forward|termination|negated|10|Group[666]|Clement
# douce |forward|termination|negated|10|Group[666]|Clement
# douces |forward|termination|negated|10|Group[666]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "surveiller" |  "examiner" | "suivre" | "avoir à l'oeil"
Var2 -> "le"
Var3 -> "\\w+"
Var4 -> "pour"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[672]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# surveiller le \w+ pour |forward|trigger|conditional|30|Group[672]|Clement
# examiner le \w+ pour |forward|trigger|conditional|30|Group[672]|Clement
# suivre le \w+ pour |forward|trigger|conditional|30|Group[672]|Clement
# avoir à l'oeil le \w+ pour |forward|trigger|conditional|30|Group[672]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "être à l'affût du" | "faire attention au"
Var2 -> "\\w+"
Var3 -> "pour"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[672]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# être à l'affût du \w+ pour |forward|trigger|conditional|30|Group[672]|Clement
# faire attention au \w+ pour |forward|trigger|conditional|30|Group[672]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "doit"
Var2 -> "être"
Var3 -> "exclu" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Var4 -> "pour"
Trigger_Rule -> "|both|trigger|uncertain|30|Group[678]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# doit être exclu pour |both|trigger|uncertain|30|Group[678]|Clement
# doit être repoussé pour |both|trigger|uncertain|30|Group[678]|Clement
# doit être rejeté pour |both|trigger|uncertain|30|Group[678]|Clement
# doit être éliminé pour |both|trigger|uncertain|30|Group[678]|Clement
# doit être proscrit pour |both|trigger|uncertain|30|Group[678]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "neg"|"nég"| "nég."| "négatifs" |"négatives" |"nuls" | "nulles"
Var2 -> "dans" | "pour" | "par"
Trigger_Rule -> "|forward|trigger|negated|10|Group[682]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# neg dans |forward|trigger|negated|10|Group[682]|Clement
# neg pour |forward|trigger|negated|10|Group[682]|Clement
# neg par |forward|trigger|negated|10|Group[682]|Clement
# nég dans |forward|trigger|negated|10|Group[682]|Clement
# nég pour |forward|trigger|negated|10|Group[682]|Clement
# nég par |forward|trigger|negated|10|Group[682]|Clement
# nég. dans |forward|trigger|negated|10|Group[682]|Clement
# nég. pour |forward|trigger|negated|10|Group[682]|Clement
# nég. par |forward|trigger|negated|10|Group[682]|Clement
# négatifs dans |forward|trigger|negated|10|Group[682]|Clement
# négatifs pour |forward|trigger|negated|10|Group[682]|Clement
# négatifs par |forward|trigger|negated|10|Group[682]|Clement
# négatives dans |forward|trigger|negated|10|Group[682]|Clement
# négatives pour |forward|trigger|negated|10|Group[682]|Clement
# négatives par |forward|trigger|negated|10|Group[682]|Clement
# nuls dans |forward|trigger|negated|10|Group[682]|Clement
# nuls pour |forward|trigger|negated|10|Group[682]|Clement
# nuls par |forward|trigger|negated|10|Group[682]|Clement
# nulles dans |forward|trigger|negated|10|Group[682]|Clement
# nulles pour |forward|trigger|negated|10|Group[682]|Clement
# nulles par |forward|trigger|negated|10|Group[682]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "neg"|"nég"| "nég."| "négatifs" |"négatives" |"nuls" | "nulles"
Trigger_Rule -> "|backward|trigger|negated|10|Group[688]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# neg |backward|trigger|negated|10|Group[688]|Clement
# nég |backward|trigger|negated|10|Group[688]|Clement
# nég. |backward|trigger|negated|10|Group[688]|Clement
# négatifs |backward|trigger|negated|10|Group[688]|Clement
# négatives |backward|trigger|negated|10|Group[688]|Clement
# nuls |backward|trigger|negated|10|Group[688]|Clement
# nulles |backward|trigger|negated|10|Group[688]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "jamais"
Var2 -> "aucun" | "aucune" | "nul" | "nulle"
Trigger_Rule -> "|forward|trigger|negated|10|Group[702]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# jamais aucun |forward|trigger|negated|10|Group[702]|Clement
# jamais aucune |forward|trigger|negated|10|Group[702]|Clement
# jamais nul |forward|trigger|negated|10|Group[702]|Clement
# jamais nulle |forward|trigger|negated|10|Group[702]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "jamais"
Var2 -> "développé" | "manifesté" | "révélé"
Trigger_Rule -> "|forward|trigger|negated|10|Group[704]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# jamais développé |forward|trigger|negated|10|Group[704]|Clement
# jamais manifesté |forward|trigger|negated|10|Group[704]|Clement
# jamais révélé |forward|trigger|negated|10|Group[704]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "jamais"
Var2 -> "eu"
Trigger_Rule -> "|forward|trigger|negated|10|Group[706]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# jamais eu |forward|trigger|negated|10|Group[706]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "non"
Var2 -> "\\w+"
Var3 -> "évident" | "clair" | "indiscutable" | "notoire" | "patent" | "certain" | "indéniable" | "flagrant" | "incontestable" | "sûr" | "assuré"
Var4 -> "d'" | "de" | "d'un" | "d'une"| "dans" | "pour" | "par"
Trigger_Rule -> "|forward|trigger|negated|10|Group[709]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# non \w+ évident d' |forward|trigger|negated|10|Group[709]|Clement
# non \w+ évident de |forward|trigger|negated|10|Group[709]|Clement
# non \w+ évident d'un |forward|trigger|negated|10|Group[709]|Clement
# non \w+ évident d'une |forward|trigger|negated|10|Group[709]|Clement
# non \w+ évident dans |forward|trigger|negated|10|Group[709]|Clement
# non \w+ évident pour |forward|trigger|negated|10|Group[709]|Clement
# non \w+ évident par |forward|trigger|negated|10|Group[709]|Clement
# non \w+ clair d' |forward|trigger|negated|10|Group[709]|Clement
# non \w+ clair de |forward|trigger|negated|10|Group[709]|Clement
# non \w+ clair d'un |forward|trigger|negated|10|Group[709]|Clement
# non \w+ clair d'une |forward|trigger|negated|10|Group[709]|Clement
# non \w+ clair dans |forward|trigger|negated|10|Group[709]|Clement
# non \w+ clair pour |forward|trigger|negated|10|Group[709]|Clement
# non \w+ clair par |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indiscutable d' |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indiscutable de |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indiscutable d'un |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indiscutable d'une |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indiscutable dans |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indiscutable pour |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indiscutable par |forward|trigger|negated|10|Group[709]|Clement
# non \w+ notoire d' |forward|trigger|negated|10|Group[709]|Clement
# non \w+ notoire de |forward|trigger|negated|10|Group[709]|Clement
# non \w+ notoire d'un |forward|trigger|negated|10|Group[709]|Clement
# non \w+ notoire d'une |forward|trigger|negated|10|Group[709]|Clement
# non \w+ notoire dans |forward|trigger|negated|10|Group[709]|Clement
# non \w+ notoire pour |forward|trigger|negated|10|Group[709]|Clement
# non \w+ notoire par |forward|trigger|negated|10|Group[709]|Clement
# non \w+ patent d' |forward|trigger|negated|10|Group[709]|Clement
# non \w+ patent de |forward|trigger|negated|10|Group[709]|Clement
# non \w+ patent d'un |forward|trigger|negated|10|Group[709]|Clement
# non \w+ patent d'une |forward|trigger|negated|10|Group[709]|Clement
# non \w+ patent dans |forward|trigger|negated|10|Group[709]|Clement
# non \w+ patent pour |forward|trigger|negated|10|Group[709]|Clement
# non \w+ patent par |forward|trigger|negated|10|Group[709]|Clement
# non \w+ certain d' |forward|trigger|negated|10|Group[709]|Clement
# non \w+ certain de |forward|trigger|negated|10|Group[709]|Clement
# non \w+ certain d'un |forward|trigger|negated|10|Group[709]|Clement
# non \w+ certain d'une |forward|trigger|negated|10|Group[709]|Clement
# non \w+ certain dans |forward|trigger|negated|10|Group[709]|Clement
# non \w+ certain pour |forward|trigger|negated|10|Group[709]|Clement
# non \w+ certain par |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indéniable d' |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indéniable de |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indéniable d'un |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indéniable d'une |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indéniable dans |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indéniable pour |forward|trigger|negated|10|Group[709]|Clement
# non \w+ indéniable par |forward|trigger|negated|10|Group[709]|Clement
# non \w+ flagrant d' |forward|trigger|negated|10|Group[709]|Clement
# non \w+ flagrant de |forward|trigger|negated|10|Group[709]|Clement
# non \w+ flagrant d'un |forward|trigger|negated|10|Group[709]|Clement
# non \w+ flagrant d'une |forward|trigger|negated|10|Group[709]|Clement
# non \w+ flagrant dans |forward|trigger|negated|10|Group[709]|Clement
# non \w+ flagrant pour |forward|trigger|negated|10|Group[709]|Clement
# non \w+ flagrant par |forward|trigger|negated|10|Group[709]|Clement
# non \w+ incontestable d' |forward|trigger|negated|10|Group[709]|Clement
# non \w+ incontestable de |forward|trigger|negated|10|Group[709]|Clement
# non \w+ incontestable d'un |forward|trigger|negated|10|Group[709]|Clement
# non \w+ incontestable d'une |forward|trigger|negated|10|Group[709]|Clement
# non \w+ incontestable dans |forward|trigger|negated|10|Group[709]|Clement
# non \w+ incontestable pour |forward|trigger|negated|10|Group[709]|Clement
# non \w+ incontestable par |forward|trigger|negated|10|Group[709]|Clement
# non \w+ sûr d' |forward|trigger|negated|10|Group[709]|Clement
# non \w+ sûr de |forward|trigger|negated|10|Group[709]|Clement
# non \w+ sûr d'un |forward|trigger|negated|10|Group[709]|Clement
# non \w+ sûr d'une |forward|trigger|negated|10|Group[709]|Clement
# non \w+ sûr dans |forward|trigger|negated|10|Group[709]|Clement
# non \w+ sûr pour |forward|trigger|negated|10|Group[709]|Clement
# non \w+ sûr par |forward|trigger|negated|10|Group[709]|Clement
# non \w+ assuré d' |forward|trigger|negated|10|Group[709]|Clement
# non \w+ assuré de |forward|trigger|negated|10|Group[709]|Clement
# non \w+ assuré d'un |forward|trigger|negated|10|Group[709]|Clement
# non \w+ assuré d'une |forward|trigger|negated|10|Group[709]|Clement
# non \w+ assuré dans |forward|trigger|negated|10|Group[709]|Clement
# non \w+ assuré pour |forward|trigger|negated|10|Group[709]|Clement
# non \w+ assuré par |forward|trigger|negated|10|Group[709]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "aucun" | "nul" | "sans" 
Var2 -> "\\w+"
Var3 -> "témoignage" | "gage" | "argument" | "critère" | "signe" | "motif" | "fondement" | "stigmate" 
Var4 -> "d'" |"de" | "d'un" | "d'une" | "dans" | "pour" | "par" | "à"
Trigger_Rule -> "|forward|trigger|negated|10|Group[715]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun \w+ témoignage d' |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ témoignage de |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ témoignage d'un |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ témoignage d'une |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ témoignage dans |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ témoignage pour |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ témoignage par |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ témoignage à |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ gage d' |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ gage de |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ gage d'un |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ gage d'une |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ gage dans |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ gage pour |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ gage par |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ gage à |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ argument d' |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ argument de |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ argument d'un |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ argument d'une |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ argument dans |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ argument pour |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ argument par |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ argument à |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ critère d' |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ critère de |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ critère d'un |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ critère d'une |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ critère dans |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ critère pour |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ critère par |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ critère à |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ signe d' |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ signe de |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ signe d'un |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ signe d'une |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ signe dans |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ signe pour |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ signe par |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ signe à |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ motif d' |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ motif de |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ motif d'un |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ motif d'une |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ motif dans |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ motif pour |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ motif par |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ motif à |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ fondement d' |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ fondement de |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ fondement d'un |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ fondement d'une |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ fondement dans |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ fondement pour |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ fondement par |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ fondement à |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ stigmate d' |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ stigmate de |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ stigmate d'un |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ stigmate d'une |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ stigmate dans |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ stigmate pour |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ stigmate par |forward|trigger|negated|10|Group[715]|Clement
# aucun \w+ stigmate à |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ témoignage d' |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ témoignage de |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ témoignage d'un |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ témoignage d'une |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ témoignage dans |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ témoignage pour |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ témoignage par |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ témoignage à |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ gage d' |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ gage de |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ gage d'un |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ gage d'une |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ gage dans |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ gage pour |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ gage par |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ gage à |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ argument d' |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ argument de |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ argument d'un |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ argument d'une |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ argument dans |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ argument pour |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ argument par |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ argument à |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ critère d' |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ critère de |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ critère d'un |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ critère d'une |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ critère dans |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ critère pour |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ critère par |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ critère à |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ signe d' |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ signe de |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ signe d'un |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ signe d'une |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ signe dans |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ signe pour |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ signe par |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ signe à |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ motif d' |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ motif de |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ motif d'un |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ motif d'une |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ motif dans |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ motif pour |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ motif par |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ motif à |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ fondement d' |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ fondement de |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ fondement d'un |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ fondement d'une |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ fondement dans |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ fondement pour |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ fondement par |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ fondement à |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ stigmate d' |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ stigmate de |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ stigmate d'un |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ stigmate d'une |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ stigmate dans |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ stigmate pour |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ stigmate par |forward|trigger|negated|10|Group[715]|Clement
# nul \w+ stigmate à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ témoignage d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ témoignage de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ témoignage d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ témoignage d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ témoignage dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ témoignage pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ témoignage par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ témoignage à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ gage d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ gage de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ gage d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ gage d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ gage dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ gage pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ gage par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ gage à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ argument d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ argument de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ argument d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ argument d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ argument dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ argument pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ argument par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ argument à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ critère d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ critère de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ critère d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ critère d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ critère dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ critère pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ critère par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ critère à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ signe d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ signe de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ signe d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ signe d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ signe dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ signe pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ signe par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ signe à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ motif d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ motif de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ motif d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ motif d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ motif dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ motif pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ motif par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ motif à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ fondement d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ fondement de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ fondement d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ fondement d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ fondement dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ fondement pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ fondement par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ fondement à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ stigmate d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ stigmate de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ stigmate d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ stigmate d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ stigmate dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ stigmate pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ stigmate par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ stigmate à |forward|trigger|negated|10|Group[715]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "aucune" | "nulle"  | "sans" 
Var2 -> "\\w+"
Var3 -> "preuve" | "justification" | "démonstration" | "conviction" | "constatation" | "confirmation" | "assurance" | "évidence" | "marque" | "annonce" | "indication" | "manifestation" | "trace" | "observation"
Var4 -> "d'" |"de" | "d'un" | "d'une" | "dans" | "pour" | "par" | "à"
Trigger_Rule -> "|forward|trigger|negated|10|Group[715]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucune \w+ preuve d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ preuve de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ preuve d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ preuve d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ preuve dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ preuve pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ preuve par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ preuve à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ justification d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ justification de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ justification d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ justification d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ justification dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ justification pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ justification par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ justification à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ démonstration d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ démonstration de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ démonstration d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ démonstration d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ démonstration dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ démonstration pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ démonstration par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ démonstration à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ conviction d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ conviction de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ conviction d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ conviction d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ conviction dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ conviction pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ conviction par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ conviction à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ constatation d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ constatation de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ constatation d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ constatation d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ constatation dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ constatation pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ constatation par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ constatation à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ confirmation d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ confirmation de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ confirmation d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ confirmation d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ confirmation dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ confirmation pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ confirmation par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ confirmation à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ assurance d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ assurance de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ assurance d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ assurance d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ assurance dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ assurance pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ assurance par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ assurance à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ évidence d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ évidence de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ évidence d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ évidence d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ évidence dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ évidence pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ évidence par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ évidence à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ marque d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ marque de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ marque d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ marque d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ marque dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ marque pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ marque par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ marque à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ annonce d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ annonce de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ annonce d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ annonce d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ annonce dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ annonce pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ annonce par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ annonce à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ indication d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ indication de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ indication d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ indication d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ indication dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ indication pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ indication par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ indication à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ manifestation d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ manifestation de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ manifestation d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ manifestation d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ manifestation dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ manifestation pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ manifestation par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ manifestation à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ trace d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ trace de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ trace d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ trace d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ trace dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ trace pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ trace par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ trace à |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ observation d' |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ observation de |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ observation d'un |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ observation d'une |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ observation dans |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ observation pour |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ observation par |forward|trigger|negated|10|Group[715]|Clement
# aucune \w+ observation à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ preuve d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ preuve de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ preuve d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ preuve d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ preuve dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ preuve pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ preuve par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ preuve à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ justification d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ justification de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ justification d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ justification d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ justification dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ justification pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ justification par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ justification à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ démonstration d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ démonstration de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ démonstration d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ démonstration d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ démonstration dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ démonstration pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ démonstration par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ démonstration à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ conviction d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ conviction de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ conviction d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ conviction d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ conviction dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ conviction pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ conviction par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ conviction à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ constatation d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ constatation de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ constatation d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ constatation d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ constatation dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ constatation pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ constatation par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ constatation à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ confirmation d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ confirmation de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ confirmation d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ confirmation d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ confirmation dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ confirmation pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ confirmation par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ confirmation à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ assurance d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ assurance de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ assurance d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ assurance d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ assurance dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ assurance pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ assurance par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ assurance à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ évidence d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ évidence de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ évidence d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ évidence d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ évidence dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ évidence pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ évidence par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ évidence à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ marque d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ marque de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ marque d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ marque d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ marque dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ marque pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ marque par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ marque à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ annonce d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ annonce de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ annonce d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ annonce d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ annonce dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ annonce pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ annonce par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ annonce à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ indication d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ indication de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ indication d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ indication d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ indication dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ indication pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ indication par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ indication à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ manifestation d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ manifestation de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ manifestation d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ manifestation d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ manifestation dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ manifestation pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ manifestation par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ manifestation à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ trace d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ trace de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ trace d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ trace d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ trace dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ trace pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ trace par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ trace à |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ observation d' |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ observation de |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ observation d'un |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ observation d'une |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ observation dans |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ observation pour |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ observation par |forward|trigger|negated|10|Group[715]|Clement
# nulle \w+ observation à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ preuve d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ preuve de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ preuve d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ preuve d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ preuve dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ preuve pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ preuve par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ preuve à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ justification d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ justification de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ justification d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ justification d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ justification dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ justification pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ justification par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ justification à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ démonstration d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ démonstration de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ démonstration d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ démonstration d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ démonstration dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ démonstration pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ démonstration par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ démonstration à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ conviction d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ conviction de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ conviction d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ conviction d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ conviction dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ conviction pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ conviction par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ conviction à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ constatation d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ constatation de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ constatation d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ constatation d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ constatation dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ constatation pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ constatation par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ constatation à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ confirmation d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ confirmation de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ confirmation d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ confirmation d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ confirmation dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ confirmation pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ confirmation par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ confirmation à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ assurance d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ assurance de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ assurance d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ assurance d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ assurance dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ assurance pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ assurance par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ assurance à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ évidence d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ évidence de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ évidence d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ évidence d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ évidence dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ évidence pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ évidence par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ évidence à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ marque d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ marque de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ marque d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ marque d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ marque dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ marque pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ marque par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ marque à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ annonce d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ annonce de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ annonce d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ annonce d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ annonce dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ annonce pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ annonce par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ annonce à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ indication d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ indication de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ indication d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ indication d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ indication dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ indication pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ indication par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ indication à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ manifestation d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ manifestation de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ manifestation d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ manifestation d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ manifestation dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ manifestation pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ manifestation par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ manifestation à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ trace d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ trace de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ trace d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ trace d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ trace dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ trace pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ trace par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ trace à |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ observation d' |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ observation de |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ observation d'un |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ observation d'une |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ observation dans |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ observation pour |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ observation par |forward|trigger|negated|10|Group[715]|Clement
# sans \w+ observation à |forward|trigger|negated|10|Group[715]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "aucun" | "nul"  | "sans" 
Var2 -> "témoignage" | "gage" | "argument" | "critère" | "signe" | "motif" | "fondement"| "signal" | "indice" | "témoignage"| "avertissement" | "stigmate"
Trigger_Rule -> "|forward|trigger|negated|10|Group[715]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun témoignage |forward|trigger|negated|10|Group[715]|Clement
# aucun gage |forward|trigger|negated|10|Group[715]|Clement
# aucun argument |forward|trigger|negated|10|Group[715]|Clement
# aucun critère |forward|trigger|negated|10|Group[715]|Clement
# aucun signe |forward|trigger|negated|10|Group[715]|Clement
# aucun motif |forward|trigger|negated|10|Group[715]|Clement
# aucun fondement |forward|trigger|negated|10|Group[715]|Clement
# aucun signal |forward|trigger|negated|10|Group[715]|Clement
# aucun indice |forward|trigger|negated|10|Group[715]|Clement
# aucun témoignage |forward|trigger|negated|10|Group[715]|Clement
# aucun avertissement |forward|trigger|negated|10|Group[715]|Clement
# aucun stigmate |forward|trigger|negated|10|Group[715]|Clement
# nul témoignage |forward|trigger|negated|10|Group[715]|Clement
# nul gage |forward|trigger|negated|10|Group[715]|Clement
# nul argument |forward|trigger|negated|10|Group[715]|Clement
# nul critère |forward|trigger|negated|10|Group[715]|Clement
# nul signe |forward|trigger|negated|10|Group[715]|Clement
# nul motif |forward|trigger|negated|10|Group[715]|Clement
# nul fondement |forward|trigger|negated|10|Group[715]|Clement
# nul signal |forward|trigger|negated|10|Group[715]|Clement
# nul indice |forward|trigger|negated|10|Group[715]|Clement
# nul témoignage |forward|trigger|negated|10|Group[715]|Clement
# nul avertissement |forward|trigger|negated|10|Group[715]|Clement
# nul stigmate |forward|trigger|negated|10|Group[715]|Clement
# sans témoignage |forward|trigger|negated|10|Group[715]|Clement
# sans gage |forward|trigger|negated|10|Group[715]|Clement
# sans argument |forward|trigger|negated|10|Group[715]|Clement
# sans critère |forward|trigger|negated|10|Group[715]|Clement
# sans signe |forward|trigger|negated|10|Group[715]|Clement
# sans motif |forward|trigger|negated|10|Group[715]|Clement
# sans fondement |forward|trigger|negated|10|Group[715]|Clement
# sans signal |forward|trigger|negated|10|Group[715]|Clement
# sans indice |forward|trigger|negated|10|Group[715]|Clement
# sans témoignage |forward|trigger|negated|10|Group[715]|Clement
# sans avertissement |forward|trigger|negated|10|Group[715]|Clement
# sans stigmate |forward|trigger|negated|10|Group[715]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "aucune" | "nulle" | "sans" 
Var2 -> "preuve" | "justification" | "démonstration" | "conviction" | "constatation" | "confirmation" | "assurance" | "évidence"| "marque" | "preuve" | "indication" | "manifestation" | "trace" | "observation"| "suggestion" | "incitation" | "évocation" | "indication"
Trigger_Rule -> "|forward|trigger|negated|10|Group[715]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucune preuve |forward|trigger|negated|10|Group[715]|Clement
# aucune justification |forward|trigger|negated|10|Group[715]|Clement
# aucune démonstration |forward|trigger|negated|10|Group[715]|Clement
# aucune conviction |forward|trigger|negated|10|Group[715]|Clement
# aucune constatation |forward|trigger|negated|10|Group[715]|Clement
# aucune confirmation |forward|trigger|negated|10|Group[715]|Clement
# aucune assurance |forward|trigger|negated|10|Group[715]|Clement
# aucune évidence |forward|trigger|negated|10|Group[715]|Clement
# aucune marque |forward|trigger|negated|10|Group[715]|Clement
# aucune preuve |forward|trigger|negated|10|Group[715]|Clement
# aucune indication |forward|trigger|negated|10|Group[715]|Clement
# aucune manifestation |forward|trigger|negated|10|Group[715]|Clement
# aucune trace |forward|trigger|negated|10|Group[715]|Clement
# aucune observation |forward|trigger|negated|10|Group[715]|Clement
# aucune suggestion |forward|trigger|negated|10|Group[715]|Clement
# aucune incitation |forward|trigger|negated|10|Group[715]|Clement
# aucune évocation |forward|trigger|negated|10|Group[715]|Clement
# aucune indication |forward|trigger|negated|10|Group[715]|Clement
# nulle preuve |forward|trigger|negated|10|Group[715]|Clement
# nulle justification |forward|trigger|negated|10|Group[715]|Clement
# nulle démonstration |forward|trigger|negated|10|Group[715]|Clement
# nulle conviction |forward|trigger|negated|10|Group[715]|Clement
# nulle constatation |forward|trigger|negated|10|Group[715]|Clement
# nulle confirmation |forward|trigger|negated|10|Group[715]|Clement
# nulle assurance |forward|trigger|negated|10|Group[715]|Clement
# nulle évidence |forward|trigger|negated|10|Group[715]|Clement
# nulle marque |forward|trigger|negated|10|Group[715]|Clement
# nulle preuve |forward|trigger|negated|10|Group[715]|Clement
# nulle indication |forward|trigger|negated|10|Group[715]|Clement
# nulle manifestation |forward|trigger|negated|10|Group[715]|Clement
# nulle trace |forward|trigger|negated|10|Group[715]|Clement
# nulle observation |forward|trigger|negated|10|Group[715]|Clement
# nulle suggestion |forward|trigger|negated|10|Group[715]|Clement
# nulle incitation |forward|trigger|negated|10|Group[715]|Clement
# nulle évocation |forward|trigger|negated|10|Group[715]|Clement
# nulle indication |forward|trigger|negated|10|Group[715]|Clement
# sans preuve |forward|trigger|negated|10|Group[715]|Clement
# sans justification |forward|trigger|negated|10|Group[715]|Clement
# sans démonstration |forward|trigger|negated|10|Group[715]|Clement
# sans conviction |forward|trigger|negated|10|Group[715]|Clement
# sans constatation |forward|trigger|negated|10|Group[715]|Clement
# sans confirmation |forward|trigger|negated|10|Group[715]|Clement
# sans assurance |forward|trigger|negated|10|Group[715]|Clement
# sans évidence |forward|trigger|negated|10|Group[715]|Clement
# sans marque |forward|trigger|negated|10|Group[715]|Clement
# sans preuve |forward|trigger|negated|10|Group[715]|Clement
# sans indication |forward|trigger|negated|10|Group[715]|Clement
# sans manifestation |forward|trigger|negated|10|Group[715]|Clement
# sans trace |forward|trigger|negated|10|Group[715]|Clement
# sans observation |forward|trigger|negated|10|Group[715]|Clement
# sans suggestion |forward|trigger|negated|10|Group[715]|Clement
# sans incitation |forward|trigger|negated|10|Group[715]|Clement
# sans évocation |forward|trigger|negated|10|Group[715]|Clement
# sans indication |forward|trigger|negated|10|Group[715]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "non"
Var2 -> "\\w+"
Var3 -> "évident" | "clair" | "net"
Trigger_Rule -> "|forward|trigger|negated|10|Group[723]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# non \w+ évident |forward|trigger|negated|10|Group[723]|Clement
# non \w+ clair |forward|trigger|negated|10|Group[723]|Clement
# non \w+ net |forward|trigger|negated|10|Group[723]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Var5 Trigger_Rule
Var1 -> "aucun" | "aucune"
Var2 -> "\\w+"
Var3 -> "a"
Var4 -> "été"
Var5 -> "donné" | "prescrit" | "administré" | "prodigué" | "appliqué" | "fait" | "indiqué" | "proposé" | "distribué" | "redonné" | "assené" | "employé" | "inoculé"
Trigger_Rule -> "|forward|termination|negated|10|Group[725]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun \w+ a été donné |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été prescrit |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été administré |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été prodigué |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été appliqué |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été fait |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été indiqué |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été proposé |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été distribué |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été redonné |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été assené |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été employé |forward|termination|negated|10|Group[725]|Clement
# aucun \w+ a été inoculé |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été donné |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été prescrit |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été administré |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été prodigué |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été appliqué |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été fait |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été indiqué |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été proposé |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été distribué |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été redonné |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été assené |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été employé |forward|termination|negated|10|Group[725]|Clement
# aucune \w+ a été inoculé |forward|termination|negated|10|Group[725]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "aucun" | "aucune" | "nul" | "nulle"  | "sans" 
Var2 -> "autre" | "autres"
Trigger_Rule -> "|forward|trigger|negated|10|Group[730]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun autre |forward|trigger|negated|10|Group[730]|Clement
# aucun autres |forward|trigger|negated|10|Group[730]|Clement
# aucune autre |forward|trigger|negated|10|Group[730]|Clement
# aucune autres |forward|trigger|negated|10|Group[730]|Clement
# nul autre |forward|trigger|negated|10|Group[730]|Clement
# nul autres |forward|trigger|negated|10|Group[730]|Clement
# nulle autre |forward|trigger|negated|10|Group[730]|Clement
# nulle autres |forward|trigger|negated|10|Group[730]|Clement
# sans autre |forward|trigger|negated|10|Group[730]|Clement
# sans autres |forward|trigger|negated|10|Group[730]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucun" | "nul"  | "sans" 
Var2 -> "fondement" | "déclencheur" | "départ" | "but"
Var3 -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[734]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun fondement d' |forward|trigger|negated|10|Group[734]|Clement
# aucun fondement de |forward|trigger|negated|10|Group[734]|Clement
# aucun fondement d'un |forward|trigger|negated|10|Group[734]|Clement
# aucun fondement d'une |forward|trigger|negated|10|Group[734]|Clement
# aucun déclencheur d' |forward|trigger|negated|10|Group[734]|Clement
# aucun déclencheur de |forward|trigger|negated|10|Group[734]|Clement
# aucun déclencheur d'un |forward|trigger|negated|10|Group[734]|Clement
# aucun déclencheur d'une |forward|trigger|negated|10|Group[734]|Clement
# aucun départ d' |forward|trigger|negated|10|Group[734]|Clement
# aucun départ de |forward|trigger|negated|10|Group[734]|Clement
# aucun départ d'un |forward|trigger|negated|10|Group[734]|Clement
# aucun départ d'une |forward|trigger|negated|10|Group[734]|Clement
# aucun but d' |forward|trigger|negated|10|Group[734]|Clement
# aucun but de |forward|trigger|negated|10|Group[734]|Clement
# aucun but d'un |forward|trigger|negated|10|Group[734]|Clement
# aucun but d'une |forward|trigger|negated|10|Group[734]|Clement
# nul fondement d' |forward|trigger|negated|10|Group[734]|Clement
# nul fondement de |forward|trigger|negated|10|Group[734]|Clement
# nul fondement d'un |forward|trigger|negated|10|Group[734]|Clement
# nul fondement d'une |forward|trigger|negated|10|Group[734]|Clement
# nul déclencheur d' |forward|trigger|negated|10|Group[734]|Clement
# nul déclencheur de |forward|trigger|negated|10|Group[734]|Clement
# nul déclencheur d'un |forward|trigger|negated|10|Group[734]|Clement
# nul déclencheur d'une |forward|trigger|negated|10|Group[734]|Clement
# nul départ d' |forward|trigger|negated|10|Group[734]|Clement
# nul départ de |forward|trigger|negated|10|Group[734]|Clement
# nul départ d'un |forward|trigger|negated|10|Group[734]|Clement
# nul départ d'une |forward|trigger|negated|10|Group[734]|Clement
# nul but d' |forward|trigger|negated|10|Group[734]|Clement
# nul but de |forward|trigger|negated|10|Group[734]|Clement
# nul but d'un |forward|trigger|negated|10|Group[734]|Clement
# nul but d'une |forward|trigger|negated|10|Group[734]|Clement
# sans fondement d' |forward|trigger|negated|10|Group[734]|Clement
# sans fondement de |forward|trigger|negated|10|Group[734]|Clement
# sans fondement d'un |forward|trigger|negated|10|Group[734]|Clement
# sans fondement d'une |forward|trigger|negated|10|Group[734]|Clement
# sans déclencheur d' |forward|trigger|negated|10|Group[734]|Clement
# sans déclencheur de |forward|trigger|negated|10|Group[734]|Clement
# sans déclencheur d'un |forward|trigger|negated|10|Group[734]|Clement
# sans déclencheur d'une |forward|trigger|negated|10|Group[734]|Clement
# sans départ d' |forward|trigger|negated|10|Group[734]|Clement
# sans départ de |forward|trigger|negated|10|Group[734]|Clement
# sans départ d'un |forward|trigger|negated|10|Group[734]|Clement
# sans départ d'une |forward|trigger|negated|10|Group[734]|Clement
# sans but d' |forward|trigger|negated|10|Group[734]|Clement
# sans but de |forward|trigger|negated|10|Group[734]|Clement
# sans but d'un |forward|trigger|negated|10|Group[734]|Clement
# sans but d'une |forward|trigger|negated|10|Group[734]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucune" | "nulle"  | "sans" 
Var2 -> "cause" | "raison" | "fondement" | "source" | "intention" | "origine"
Var3 -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[734]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucune cause d' |forward|trigger|negated|10|Group[734]|Clement
# aucune cause de |forward|trigger|negated|10|Group[734]|Clement
# aucune cause d'un |forward|trigger|negated|10|Group[734]|Clement
# aucune cause d'une |forward|trigger|negated|10|Group[734]|Clement
# aucune raison d' |forward|trigger|negated|10|Group[734]|Clement
# aucune raison de |forward|trigger|negated|10|Group[734]|Clement
# aucune raison d'un |forward|trigger|negated|10|Group[734]|Clement
# aucune raison d'une |forward|trigger|negated|10|Group[734]|Clement
# aucune fondement d' |forward|trigger|negated|10|Group[734]|Clement
# aucune fondement de |forward|trigger|negated|10|Group[734]|Clement
# aucune fondement d'un |forward|trigger|negated|10|Group[734]|Clement
# aucune fondement d'une |forward|trigger|negated|10|Group[734]|Clement
# aucune source d' |forward|trigger|negated|10|Group[734]|Clement
# aucune source de |forward|trigger|negated|10|Group[734]|Clement
# aucune source d'un |forward|trigger|negated|10|Group[734]|Clement
# aucune source d'une |forward|trigger|negated|10|Group[734]|Clement
# aucune intention d' |forward|trigger|negated|10|Group[734]|Clement
# aucune intention de |forward|trigger|negated|10|Group[734]|Clement
# aucune intention d'un |forward|trigger|negated|10|Group[734]|Clement
# aucune intention d'une |forward|trigger|negated|10|Group[734]|Clement
# aucune origine d' |forward|trigger|negated|10|Group[734]|Clement
# aucune origine de |forward|trigger|negated|10|Group[734]|Clement
# aucune origine d'un |forward|trigger|negated|10|Group[734]|Clement
# aucune origine d'une |forward|trigger|negated|10|Group[734]|Clement
# nulle cause d' |forward|trigger|negated|10|Group[734]|Clement
# nulle cause de |forward|trigger|negated|10|Group[734]|Clement
# nulle cause d'un |forward|trigger|negated|10|Group[734]|Clement
# nulle cause d'une |forward|trigger|negated|10|Group[734]|Clement
# nulle raison d' |forward|trigger|negated|10|Group[734]|Clement
# nulle raison de |forward|trigger|negated|10|Group[734]|Clement
# nulle raison d'un |forward|trigger|negated|10|Group[734]|Clement
# nulle raison d'une |forward|trigger|negated|10|Group[734]|Clement
# nulle fondement d' |forward|trigger|negated|10|Group[734]|Clement
# nulle fondement de |forward|trigger|negated|10|Group[734]|Clement
# nulle fondement d'un |forward|trigger|negated|10|Group[734]|Clement
# nulle fondement d'une |forward|trigger|negated|10|Group[734]|Clement
# nulle source d' |forward|trigger|negated|10|Group[734]|Clement
# nulle source de |forward|trigger|negated|10|Group[734]|Clement
# nulle source d'un |forward|trigger|negated|10|Group[734]|Clement
# nulle source d'une |forward|trigger|negated|10|Group[734]|Clement
# nulle intention d' |forward|trigger|negated|10|Group[734]|Clement
# nulle intention de |forward|trigger|negated|10|Group[734]|Clement
# nulle intention d'un |forward|trigger|negated|10|Group[734]|Clement
# nulle intention d'une |forward|trigger|negated|10|Group[734]|Clement
# nulle origine d' |forward|trigger|negated|10|Group[734]|Clement
# nulle origine de |forward|trigger|negated|10|Group[734]|Clement
# nulle origine d'un |forward|trigger|negated|10|Group[734]|Clement
# nulle origine d'une |forward|trigger|negated|10|Group[734]|Clement
# sans cause d' |forward|trigger|negated|10|Group[734]|Clement
# sans cause de |forward|trigger|negated|10|Group[734]|Clement
# sans cause d'un |forward|trigger|negated|10|Group[734]|Clement
# sans cause d'une |forward|trigger|negated|10|Group[734]|Clement
# sans raison d' |forward|trigger|negated|10|Group[734]|Clement
# sans raison de |forward|trigger|negated|10|Group[734]|Clement
# sans raison d'un |forward|trigger|negated|10|Group[734]|Clement
# sans raison d'une |forward|trigger|negated|10|Group[734]|Clement
# sans fondement d' |forward|trigger|negated|10|Group[734]|Clement
# sans fondement de |forward|trigger|negated|10|Group[734]|Clement
# sans fondement d'un |forward|trigger|negated|10|Group[734]|Clement
# sans fondement d'une |forward|trigger|negated|10|Group[734]|Clement
# sans source d' |forward|trigger|negated|10|Group[734]|Clement
# sans source de |forward|trigger|negated|10|Group[734]|Clement
# sans source d'un |forward|trigger|negated|10|Group[734]|Clement
# sans source d'une |forward|trigger|negated|10|Group[734]|Clement
# sans intention d' |forward|trigger|negated|10|Group[734]|Clement
# sans intention de |forward|trigger|negated|10|Group[734]|Clement
# sans intention d'un |forward|trigger|negated|10|Group[734]|Clement
# sans intention d'une |forward|trigger|negated|10|Group[734]|Clement
# sans origine d' |forward|trigger|negated|10|Group[734]|Clement
# sans origine de |forward|trigger|negated|10|Group[734]|Clement
# sans origine d'un |forward|trigger|negated|10|Group[734]|Clement
# sans origine d'une |forward|trigger|negated|10|Group[734]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pas"
Var2 -> "de changement" | "de variation" | "d'altération" | "d'évolution" | "de transformation" | "de fluctuation" | "de mutation" | "de retournement" | "de renversement" | "d'amélioration" | "de revirement" | "de transition" | "de modulation" | "d'inflexion" | "de différence"
Trigger_Rule -> "|both|pseudo|negated|10|Group[736]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas de changement |both|pseudo|negated|10|Group[736]|Clement
# pas de variation |both|pseudo|negated|10|Group[736]|Clement
# pas d'altération |both|pseudo|negated|10|Group[736]|Clement
# pas d'évolution |both|pseudo|negated|10|Group[736]|Clement
# pas de transformation |both|pseudo|negated|10|Group[736]|Clement
# pas de fluctuation |both|pseudo|negated|10|Group[736]|Clement
# pas de mutation |both|pseudo|negated|10|Group[736]|Clement
# pas de retournement |both|pseudo|negated|10|Group[736]|Clement
# pas de renversement |both|pseudo|negated|10|Group[736]|Clement
# pas d'amélioration |both|pseudo|negated|10|Group[736]|Clement
# pas de revirement |both|pseudo|negated|10|Group[736]|Clement
# pas de transition |both|pseudo|negated|10|Group[736]|Clement
# pas de modulation |both|pseudo|negated|10|Group[736]|Clement
# pas d'inflexion |both|pseudo|negated|10|Group[736]|Clement
# pas de différence |both|pseudo|negated|10|Group[736]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "aucun" | "nul" | "sans" 
Var2 -> "changement" | "retournement" | "renversement" | "revirement"
Trigger_Rule -> "|both|pseudo|negated|10|Group[736]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun changement |both|pseudo|negated|10|Group[736]|Clement
# aucun retournement |both|pseudo|negated|10|Group[736]|Clement
# aucun renversement |both|pseudo|negated|10|Group[736]|Clement
# aucun revirement |both|pseudo|negated|10|Group[736]|Clement
# nul changement |both|pseudo|negated|10|Group[736]|Clement
# nul retournement |both|pseudo|negated|10|Group[736]|Clement
# nul renversement |both|pseudo|negated|10|Group[736]|Clement
# nul revirement |both|pseudo|negated|10|Group[736]|Clement
# sans changement |both|pseudo|negated|10|Group[736]|Clement
# sans retournement |both|pseudo|negated|10|Group[736]|Clement
# sans renversement |both|pseudo|negated|10|Group[736]|Clement
# sans revirement |both|pseudo|negated|10|Group[736]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 ->  "aucune" | "nulle" | "sans" 
Var2 -> "variation" | "altération" | "évolution" | "transformation" | "fluctuation" | "amélioration" | "transition" | "inflexion" | "différence"
Trigger_Rule -> "|both|pseudo|negated|10|Group[736]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucune variation |both|pseudo|negated|10|Group[736]|Clement
# aucune altération |both|pseudo|negated|10|Group[736]|Clement
# aucune évolution |both|pseudo|negated|10|Group[736]|Clement
# aucune transformation |both|pseudo|negated|10|Group[736]|Clement
# aucune fluctuation |both|pseudo|negated|10|Group[736]|Clement
# aucune amélioration |both|pseudo|negated|10|Group[736]|Clement
# aucune transition |both|pseudo|negated|10|Group[736]|Clement
# aucune inflexion |both|pseudo|negated|10|Group[736]|Clement
# aucune différence |both|pseudo|negated|10|Group[736]|Clement
# nulle variation |both|pseudo|negated|10|Group[736]|Clement
# nulle altération |both|pseudo|negated|10|Group[736]|Clement
# nulle évolution |both|pseudo|negated|10|Group[736]|Clement
# nulle transformation |both|pseudo|negated|10|Group[736]|Clement
# nulle fluctuation |both|pseudo|negated|10|Group[736]|Clement
# nulle amélioration |both|pseudo|negated|10|Group[736]|Clement
# nulle transition |both|pseudo|negated|10|Group[736]|Clement
# nulle inflexion |both|pseudo|negated|10|Group[736]|Clement
# nulle différence |both|pseudo|negated|10|Group[736]|Clement
# sans variation |both|pseudo|negated|10|Group[736]|Clement
# sans altération |both|pseudo|negated|10|Group[736]|Clement
# sans évolution |both|pseudo|negated|10|Group[736]|Clement
# sans transformation |both|pseudo|negated|10|Group[736]|Clement
# sans fluctuation |both|pseudo|negated|10|Group[736]|Clement
# sans amélioration |both|pseudo|negated|10|Group[736]|Clement
# sans transition |both|pseudo|negated|10|Group[736]|Clement
# sans inflexion |both|pseudo|negated|10|Group[736]|Clement
# sans différence |both|pseudo|negated|10|Group[736]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucune" | "nulle" | "sans" 
Var2 -> "plainte" | "lamentation" | "protestation"
Var3 -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[737]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucune plainte d' |forward|trigger|negated|10|Group[737]|Clement
# aucune plainte de |forward|trigger|negated|10|Group[737]|Clement
# aucune plainte d'un |forward|trigger|negated|10|Group[737]|Clement
# aucune plainte d'une |forward|trigger|negated|10|Group[737]|Clement
# aucune lamentation d' |forward|trigger|negated|10|Group[737]|Clement
# aucune lamentation de |forward|trigger|negated|10|Group[737]|Clement
# aucune lamentation d'un |forward|trigger|negated|10|Group[737]|Clement
# aucune lamentation d'une |forward|trigger|negated|10|Group[737]|Clement
# aucune protestation d' |forward|trigger|negated|10|Group[737]|Clement
# aucune protestation de |forward|trigger|negated|10|Group[737]|Clement
# aucune protestation d'un |forward|trigger|negated|10|Group[737]|Clement
# aucune protestation d'une |forward|trigger|negated|10|Group[737]|Clement
# nulle plainte d' |forward|trigger|negated|10|Group[737]|Clement
# nulle plainte de |forward|trigger|negated|10|Group[737]|Clement
# nulle plainte d'un |forward|trigger|negated|10|Group[737]|Clement
# nulle plainte d'une |forward|trigger|negated|10|Group[737]|Clement
# nulle lamentation d' |forward|trigger|negated|10|Group[737]|Clement
# nulle lamentation de |forward|trigger|negated|10|Group[737]|Clement
# nulle lamentation d'un |forward|trigger|negated|10|Group[737]|Clement
# nulle lamentation d'une |forward|trigger|negated|10|Group[737]|Clement
# nulle protestation d' |forward|trigger|negated|10|Group[737]|Clement
# nulle protestation de |forward|trigger|negated|10|Group[737]|Clement
# nulle protestation d'un |forward|trigger|negated|10|Group[737]|Clement
# nulle protestation d'une |forward|trigger|negated|10|Group[737]|Clement
# sans plainte d' |forward|trigger|negated|10|Group[737]|Clement
# sans plainte de |forward|trigger|negated|10|Group[737]|Clement
# sans plainte d'un |forward|trigger|negated|10|Group[737]|Clement
# sans plainte d'une |forward|trigger|negated|10|Group[737]|Clement
# sans lamentation d' |forward|trigger|negated|10|Group[737]|Clement
# sans lamentation de |forward|trigger|negated|10|Group[737]|Clement
# sans lamentation d'un |forward|trigger|negated|10|Group[737]|Clement
# sans lamentation d'une |forward|trigger|negated|10|Group[737]|Clement
# sans protestation d' |forward|trigger|negated|10|Group[737]|Clement
# sans protestation de |forward|trigger|negated|10|Group[737]|Clement
# sans protestation d'un |forward|trigger|negated|10|Group[737]|Clement
# sans protestation d'une |forward|trigger|negated|10|Group[737]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucun" | "nul" | "sans" 
Var2 -> "témoignage" | "gage" | "argument" | "signe" | "motif" | "fondement" | "décèlement" | "stigmate"
Var3 -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[746]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun témoignage d' |forward|trigger|negated|10|Group[746]|Clement
# aucun témoignage de |forward|trigger|negated|10|Group[746]|Clement
# aucun témoignage d'un |forward|trigger|negated|10|Group[746]|Clement
# aucun témoignage d'une |forward|trigger|negated|10|Group[746]|Clement
# aucun gage d' |forward|trigger|negated|10|Group[746]|Clement
# aucun gage de |forward|trigger|negated|10|Group[746]|Clement
# aucun gage d'un |forward|trigger|negated|10|Group[746]|Clement
# aucun gage d'une |forward|trigger|negated|10|Group[746]|Clement
# aucun argument d' |forward|trigger|negated|10|Group[746]|Clement
# aucun argument de |forward|trigger|negated|10|Group[746]|Clement
# aucun argument d'un |forward|trigger|negated|10|Group[746]|Clement
# aucun argument d'une |forward|trigger|negated|10|Group[746]|Clement
# aucun signe d' |forward|trigger|negated|10|Group[746]|Clement
# aucun signe de |forward|trigger|negated|10|Group[746]|Clement
# aucun signe d'un |forward|trigger|negated|10|Group[746]|Clement
# aucun signe d'une |forward|trigger|negated|10|Group[746]|Clement
# aucun motif d' |forward|trigger|negated|10|Group[746]|Clement
# aucun motif de |forward|trigger|negated|10|Group[746]|Clement
# aucun motif d'un |forward|trigger|negated|10|Group[746]|Clement
# aucun motif d'une |forward|trigger|negated|10|Group[746]|Clement
# aucun fondement d' |forward|trigger|negated|10|Group[746]|Clement
# aucun fondement de |forward|trigger|negated|10|Group[746]|Clement
# aucun fondement d'un |forward|trigger|negated|10|Group[746]|Clement
# aucun fondement d'une |forward|trigger|negated|10|Group[746]|Clement
# aucun décèlement d' |forward|trigger|negated|10|Group[746]|Clement
# aucun décèlement de |forward|trigger|negated|10|Group[746]|Clement
# aucun décèlement d'un |forward|trigger|negated|10|Group[746]|Clement
# aucun décèlement d'une |forward|trigger|negated|10|Group[746]|Clement
# aucun stigmate d' |forward|trigger|negated|10|Group[746]|Clement
# aucun stigmate de |forward|trigger|negated|10|Group[746]|Clement
# aucun stigmate d'un |forward|trigger|negated|10|Group[746]|Clement
# aucun stigmate d'une |forward|trigger|negated|10|Group[746]|Clement
# nul témoignage d' |forward|trigger|negated|10|Group[746]|Clement
# nul témoignage de |forward|trigger|negated|10|Group[746]|Clement
# nul témoignage d'un |forward|trigger|negated|10|Group[746]|Clement
# nul témoignage d'une |forward|trigger|negated|10|Group[746]|Clement
# nul gage d' |forward|trigger|negated|10|Group[746]|Clement
# nul gage de |forward|trigger|negated|10|Group[746]|Clement
# nul gage d'un |forward|trigger|negated|10|Group[746]|Clement
# nul gage d'une |forward|trigger|negated|10|Group[746]|Clement
# nul argument d' |forward|trigger|negated|10|Group[746]|Clement
# nul argument de |forward|trigger|negated|10|Group[746]|Clement
# nul argument d'un |forward|trigger|negated|10|Group[746]|Clement
# nul argument d'une |forward|trigger|negated|10|Group[746]|Clement
# nul signe d' |forward|trigger|negated|10|Group[746]|Clement
# nul signe de |forward|trigger|negated|10|Group[746]|Clement
# nul signe d'un |forward|trigger|negated|10|Group[746]|Clement
# nul signe d'une |forward|trigger|negated|10|Group[746]|Clement
# nul motif d' |forward|trigger|negated|10|Group[746]|Clement
# nul motif de |forward|trigger|negated|10|Group[746]|Clement
# nul motif d'un |forward|trigger|negated|10|Group[746]|Clement
# nul motif d'une |forward|trigger|negated|10|Group[746]|Clement
# nul fondement d' |forward|trigger|negated|10|Group[746]|Clement
# nul fondement de |forward|trigger|negated|10|Group[746]|Clement
# nul fondement d'un |forward|trigger|negated|10|Group[746]|Clement
# nul fondement d'une |forward|trigger|negated|10|Group[746]|Clement
# nul décèlement d' |forward|trigger|negated|10|Group[746]|Clement
# nul décèlement de |forward|trigger|negated|10|Group[746]|Clement
# nul décèlement d'un |forward|trigger|negated|10|Group[746]|Clement
# nul décèlement d'une |forward|trigger|negated|10|Group[746]|Clement
# nul stigmate d' |forward|trigger|negated|10|Group[746]|Clement
# nul stigmate de |forward|trigger|negated|10|Group[746]|Clement
# nul stigmate d'un |forward|trigger|negated|10|Group[746]|Clement
# nul stigmate d'une |forward|trigger|negated|10|Group[746]|Clement
# sans témoignage d' |forward|trigger|negated|10|Group[746]|Clement
# sans témoignage de |forward|trigger|negated|10|Group[746]|Clement
# sans témoignage d'un |forward|trigger|negated|10|Group[746]|Clement
# sans témoignage d'une |forward|trigger|negated|10|Group[746]|Clement
# sans gage d' |forward|trigger|negated|10|Group[746]|Clement
# sans gage de |forward|trigger|negated|10|Group[746]|Clement
# sans gage d'un |forward|trigger|negated|10|Group[746]|Clement
# sans gage d'une |forward|trigger|negated|10|Group[746]|Clement
# sans argument d' |forward|trigger|negated|10|Group[746]|Clement
# sans argument de |forward|trigger|negated|10|Group[746]|Clement
# sans argument d'un |forward|trigger|negated|10|Group[746]|Clement
# sans argument d'une |forward|trigger|negated|10|Group[746]|Clement
# sans signe d' |forward|trigger|negated|10|Group[746]|Clement
# sans signe de |forward|trigger|negated|10|Group[746]|Clement
# sans signe d'un |forward|trigger|negated|10|Group[746]|Clement
# sans signe d'une |forward|trigger|negated|10|Group[746]|Clement
# sans motif d' |forward|trigger|negated|10|Group[746]|Clement
# sans motif de |forward|trigger|negated|10|Group[746]|Clement
# sans motif d'un |forward|trigger|negated|10|Group[746]|Clement
# sans motif d'une |forward|trigger|negated|10|Group[746]|Clement
# sans fondement d' |forward|trigger|negated|10|Group[746]|Clement
# sans fondement de |forward|trigger|negated|10|Group[746]|Clement
# sans fondement d'un |forward|trigger|negated|10|Group[746]|Clement
# sans fondement d'une |forward|trigger|negated|10|Group[746]|Clement
# sans décèlement d' |forward|trigger|negated|10|Group[746]|Clement
# sans décèlement de |forward|trigger|negated|10|Group[746]|Clement
# sans décèlement d'un |forward|trigger|negated|10|Group[746]|Clement
# sans décèlement d'une |forward|trigger|negated|10|Group[746]|Clement
# sans stigmate d' |forward|trigger|negated|10|Group[746]|Clement
# sans stigmate de |forward|trigger|negated|10|Group[746]|Clement
# sans stigmate d'un |forward|trigger|negated|10|Group[746]|Clement
# sans stigmate d'une |forward|trigger|negated|10|Group[746]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucune" | "nulle" | "sans" 
Var2 -> "preuve" |  "justification" | "démonstration" | "conviction" |  "constatation" | "confirmation" | "assurance" |  "évidence" | "découverte" | "trouvaille" | "révélation" | "constatation"| "marque" | "annonce" | "indication" | "manifestation" | "trace" | "observation"
Var3 -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[746]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucune preuve d' |forward|trigger|negated|10|Group[746]|Clement
# aucune preuve de |forward|trigger|negated|10|Group[746]|Clement
# aucune preuve d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune preuve d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune justification d' |forward|trigger|negated|10|Group[746]|Clement
# aucune justification de |forward|trigger|negated|10|Group[746]|Clement
# aucune justification d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune justification d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune démonstration d' |forward|trigger|negated|10|Group[746]|Clement
# aucune démonstration de |forward|trigger|negated|10|Group[746]|Clement
# aucune démonstration d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune démonstration d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune conviction d' |forward|trigger|negated|10|Group[746]|Clement
# aucune conviction de |forward|trigger|negated|10|Group[746]|Clement
# aucune conviction d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune conviction d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune constatation d' |forward|trigger|negated|10|Group[746]|Clement
# aucune constatation de |forward|trigger|negated|10|Group[746]|Clement
# aucune constatation d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune constatation d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune confirmation d' |forward|trigger|negated|10|Group[746]|Clement
# aucune confirmation de |forward|trigger|negated|10|Group[746]|Clement
# aucune confirmation d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune confirmation d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune assurance d' |forward|trigger|negated|10|Group[746]|Clement
# aucune assurance de |forward|trigger|negated|10|Group[746]|Clement
# aucune assurance d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune assurance d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune évidence d' |forward|trigger|negated|10|Group[746]|Clement
# aucune évidence de |forward|trigger|negated|10|Group[746]|Clement
# aucune évidence d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune évidence d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune découverte d' |forward|trigger|negated|10|Group[746]|Clement
# aucune découverte de |forward|trigger|negated|10|Group[746]|Clement
# aucune découverte d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune découverte d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune trouvaille d' |forward|trigger|negated|10|Group[746]|Clement
# aucune trouvaille de |forward|trigger|negated|10|Group[746]|Clement
# aucune trouvaille d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune trouvaille d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune révélation d' |forward|trigger|negated|10|Group[746]|Clement
# aucune révélation de |forward|trigger|negated|10|Group[746]|Clement
# aucune révélation d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune révélation d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune constatation d' |forward|trigger|negated|10|Group[746]|Clement
# aucune constatation de |forward|trigger|negated|10|Group[746]|Clement
# aucune constatation d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune constatation d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune marque d' |forward|trigger|negated|10|Group[746]|Clement
# aucune marque de |forward|trigger|negated|10|Group[746]|Clement
# aucune marque d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune marque d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune annonce d' |forward|trigger|negated|10|Group[746]|Clement
# aucune annonce de |forward|trigger|negated|10|Group[746]|Clement
# aucune annonce d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune annonce d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune indication d' |forward|trigger|negated|10|Group[746]|Clement
# aucune indication de |forward|trigger|negated|10|Group[746]|Clement
# aucune indication d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune indication d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune manifestation d' |forward|trigger|negated|10|Group[746]|Clement
# aucune manifestation de |forward|trigger|negated|10|Group[746]|Clement
# aucune manifestation d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune manifestation d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune trace d' |forward|trigger|negated|10|Group[746]|Clement
# aucune trace de |forward|trigger|negated|10|Group[746]|Clement
# aucune trace d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune trace d'une |forward|trigger|negated|10|Group[746]|Clement
# aucune observation d' |forward|trigger|negated|10|Group[746]|Clement
# aucune observation de |forward|trigger|negated|10|Group[746]|Clement
# aucune observation d'un |forward|trigger|negated|10|Group[746]|Clement
# aucune observation d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle preuve d' |forward|trigger|negated|10|Group[746]|Clement
# nulle preuve de |forward|trigger|negated|10|Group[746]|Clement
# nulle preuve d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle preuve d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle justification d' |forward|trigger|negated|10|Group[746]|Clement
# nulle justification de |forward|trigger|negated|10|Group[746]|Clement
# nulle justification d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle justification d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle démonstration d' |forward|trigger|negated|10|Group[746]|Clement
# nulle démonstration de |forward|trigger|negated|10|Group[746]|Clement
# nulle démonstration d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle démonstration d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle conviction d' |forward|trigger|negated|10|Group[746]|Clement
# nulle conviction de |forward|trigger|negated|10|Group[746]|Clement
# nulle conviction d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle conviction d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle constatation d' |forward|trigger|negated|10|Group[746]|Clement
# nulle constatation de |forward|trigger|negated|10|Group[746]|Clement
# nulle constatation d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle constatation d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle confirmation d' |forward|trigger|negated|10|Group[746]|Clement
# nulle confirmation de |forward|trigger|negated|10|Group[746]|Clement
# nulle confirmation d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle confirmation d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle assurance d' |forward|trigger|negated|10|Group[746]|Clement
# nulle assurance de |forward|trigger|negated|10|Group[746]|Clement
# nulle assurance d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle assurance d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle évidence d' |forward|trigger|negated|10|Group[746]|Clement
# nulle évidence de |forward|trigger|negated|10|Group[746]|Clement
# nulle évidence d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle évidence d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle découverte d' |forward|trigger|negated|10|Group[746]|Clement
# nulle découverte de |forward|trigger|negated|10|Group[746]|Clement
# nulle découverte d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle découverte d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle trouvaille d' |forward|trigger|negated|10|Group[746]|Clement
# nulle trouvaille de |forward|trigger|negated|10|Group[746]|Clement
# nulle trouvaille d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle trouvaille d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle révélation d' |forward|trigger|negated|10|Group[746]|Clement
# nulle révélation de |forward|trigger|negated|10|Group[746]|Clement
# nulle révélation d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle révélation d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle constatation d' |forward|trigger|negated|10|Group[746]|Clement
# nulle constatation de |forward|trigger|negated|10|Group[746]|Clement
# nulle constatation d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle constatation d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle marque d' |forward|trigger|negated|10|Group[746]|Clement
# nulle marque de |forward|trigger|negated|10|Group[746]|Clement
# nulle marque d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle marque d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle annonce d' |forward|trigger|negated|10|Group[746]|Clement
# nulle annonce de |forward|trigger|negated|10|Group[746]|Clement
# nulle annonce d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle annonce d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle indication d' |forward|trigger|negated|10|Group[746]|Clement
# nulle indication de |forward|trigger|negated|10|Group[746]|Clement
# nulle indication d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle indication d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle manifestation d' |forward|trigger|negated|10|Group[746]|Clement
# nulle manifestation de |forward|trigger|negated|10|Group[746]|Clement
# nulle manifestation d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle manifestation d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle trace d' |forward|trigger|negated|10|Group[746]|Clement
# nulle trace de |forward|trigger|negated|10|Group[746]|Clement
# nulle trace d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle trace d'une |forward|trigger|negated|10|Group[746]|Clement
# nulle observation d' |forward|trigger|negated|10|Group[746]|Clement
# nulle observation de |forward|trigger|negated|10|Group[746]|Clement
# nulle observation d'un |forward|trigger|negated|10|Group[746]|Clement
# nulle observation d'une |forward|trigger|negated|10|Group[746]|Clement
# sans preuve d' |forward|trigger|negated|10|Group[746]|Clement
# sans preuve de |forward|trigger|negated|10|Group[746]|Clement
# sans preuve d'un |forward|trigger|negated|10|Group[746]|Clement
# sans preuve d'une |forward|trigger|negated|10|Group[746]|Clement
# sans justification d' |forward|trigger|negated|10|Group[746]|Clement
# sans justification de |forward|trigger|negated|10|Group[746]|Clement
# sans justification d'un |forward|trigger|negated|10|Group[746]|Clement
# sans justification d'une |forward|trigger|negated|10|Group[746]|Clement
# sans démonstration d' |forward|trigger|negated|10|Group[746]|Clement
# sans démonstration de |forward|trigger|negated|10|Group[746]|Clement
# sans démonstration d'un |forward|trigger|negated|10|Group[746]|Clement
# sans démonstration d'une |forward|trigger|negated|10|Group[746]|Clement
# sans conviction d' |forward|trigger|negated|10|Group[746]|Clement
# sans conviction de |forward|trigger|negated|10|Group[746]|Clement
# sans conviction d'un |forward|trigger|negated|10|Group[746]|Clement
# sans conviction d'une |forward|trigger|negated|10|Group[746]|Clement
# sans constatation d' |forward|trigger|negated|10|Group[746]|Clement
# sans constatation de |forward|trigger|negated|10|Group[746]|Clement
# sans constatation d'un |forward|trigger|negated|10|Group[746]|Clement
# sans constatation d'une |forward|trigger|negated|10|Group[746]|Clement
# sans confirmation d' |forward|trigger|negated|10|Group[746]|Clement
# sans confirmation de |forward|trigger|negated|10|Group[746]|Clement
# sans confirmation d'un |forward|trigger|negated|10|Group[746]|Clement
# sans confirmation d'une |forward|trigger|negated|10|Group[746]|Clement
# sans assurance d' |forward|trigger|negated|10|Group[746]|Clement
# sans assurance de |forward|trigger|negated|10|Group[746]|Clement
# sans assurance d'un |forward|trigger|negated|10|Group[746]|Clement
# sans assurance d'une |forward|trigger|negated|10|Group[746]|Clement
# sans évidence d' |forward|trigger|negated|10|Group[746]|Clement
# sans évidence de |forward|trigger|negated|10|Group[746]|Clement
# sans évidence d'un |forward|trigger|negated|10|Group[746]|Clement
# sans évidence d'une |forward|trigger|negated|10|Group[746]|Clement
# sans découverte d' |forward|trigger|negated|10|Group[746]|Clement
# sans découverte de |forward|trigger|negated|10|Group[746]|Clement
# sans découverte d'un |forward|trigger|negated|10|Group[746]|Clement
# sans découverte d'une |forward|trigger|negated|10|Group[746]|Clement
# sans trouvaille d' |forward|trigger|negated|10|Group[746]|Clement
# sans trouvaille de |forward|trigger|negated|10|Group[746]|Clement
# sans trouvaille d'un |forward|trigger|negated|10|Group[746]|Clement
# sans trouvaille d'une |forward|trigger|negated|10|Group[746]|Clement
# sans révélation d' |forward|trigger|negated|10|Group[746]|Clement
# sans révélation de |forward|trigger|negated|10|Group[746]|Clement
# sans révélation d'un |forward|trigger|negated|10|Group[746]|Clement
# sans révélation d'une |forward|trigger|negated|10|Group[746]|Clement
# sans constatation d' |forward|trigger|negated|10|Group[746]|Clement
# sans constatation de |forward|trigger|negated|10|Group[746]|Clement
# sans constatation d'un |forward|trigger|negated|10|Group[746]|Clement
# sans constatation d'une |forward|trigger|negated|10|Group[746]|Clement
# sans marque d' |forward|trigger|negated|10|Group[746]|Clement
# sans marque de |forward|trigger|negated|10|Group[746]|Clement
# sans marque d'un |forward|trigger|negated|10|Group[746]|Clement
# sans marque d'une |forward|trigger|negated|10|Group[746]|Clement
# sans annonce d' |forward|trigger|negated|10|Group[746]|Clement
# sans annonce de |forward|trigger|negated|10|Group[746]|Clement
# sans annonce d'un |forward|trigger|negated|10|Group[746]|Clement
# sans annonce d'une |forward|trigger|negated|10|Group[746]|Clement
# sans indication d' |forward|trigger|negated|10|Group[746]|Clement
# sans indication de |forward|trigger|negated|10|Group[746]|Clement
# sans indication d'un |forward|trigger|negated|10|Group[746]|Clement
# sans indication d'une |forward|trigger|negated|10|Group[746]|Clement
# sans manifestation d' |forward|trigger|negated|10|Group[746]|Clement
# sans manifestation de |forward|trigger|negated|10|Group[746]|Clement
# sans manifestation d'un |forward|trigger|negated|10|Group[746]|Clement
# sans manifestation d'une |forward|trigger|negated|10|Group[746]|Clement
# sans trace d' |forward|trigger|negated|10|Group[746]|Clement
# sans trace de |forward|trigger|negated|10|Group[746]|Clement
# sans trace d'un |forward|trigger|negated|10|Group[746]|Clement
# sans trace d'une |forward|trigger|negated|10|Group[746]|Clement
# sans observation d' |forward|trigger|negated|10|Group[746]|Clement
# sans observation de |forward|trigger|negated|10|Group[746]|Clement
# sans observation d'un |forward|trigger|negated|10|Group[746]|Clement
# sans observation d'une |forward|trigger|negated|10|Group[746]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "aucun" | "nul" 
Var2 -> "résultat" | "évènement" | "calcul" | "constat"
Var3 -> "n'a"
Var4 -> "indiqué" | "prouvé" | "montré" | "démontré" | "signalé" | "annoncé" | "manifesté" | "révélé" | "témoigné" | "attesté" | "désigné" | "affiché" | "déterminé" | "décelé" | "donné" | "suggéré" | "proposé" | "évoqué" | "fait pensé à" | "sous-entendu" | "supposé" | "laissé envisager"
Trigger_Rule -> "|forward|trigger|negated|10|Group[754]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun résultat n'a indiqué |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a prouvé |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a montré |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a démontré |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a signalé |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a annoncé |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a manifesté |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a révélé |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a témoigné |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a attesté |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a désigné |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a affiché |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a déterminé |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a décelé |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a donné |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a suggéré |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a proposé |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a évoqué |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a fait pensé à |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a sous-entendu |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a supposé |forward|trigger|negated|10|Group[754]|Clement
# aucun résultat n'a laissé envisager |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a indiqué |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a prouvé |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a montré |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a démontré |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a signalé |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a annoncé |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a manifesté |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a révélé |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a témoigné |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a attesté |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a désigné |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a affiché |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a déterminé |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a décelé |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a donné |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a suggéré |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a proposé |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a évoqué |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a fait pensé à |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a sous-entendu |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a supposé |forward|trigger|negated|10|Group[754]|Clement
# aucun évènement n'a laissé envisager |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a indiqué |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a prouvé |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a montré |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a démontré |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a signalé |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a annoncé |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a manifesté |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a révélé |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a témoigné |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a attesté |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a désigné |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a affiché |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a déterminé |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a décelé |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a donné |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a suggéré |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a proposé |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a évoqué |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a fait pensé à |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a sous-entendu |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a supposé |forward|trigger|negated|10|Group[754]|Clement
# aucun calcul n'a laissé envisager |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a indiqué |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a prouvé |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a montré |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a démontré |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a signalé |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a annoncé |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a manifesté |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a révélé |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a témoigné |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a attesté |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a désigné |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a affiché |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a déterminé |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a décelé |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a donné |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a suggéré |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a proposé |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a évoqué |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a fait pensé à |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a sous-entendu |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a supposé |forward|trigger|negated|10|Group[754]|Clement
# aucun constat n'a laissé envisager |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a indiqué |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a prouvé |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a montré |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a démontré |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a signalé |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a annoncé |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a manifesté |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a révélé |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a témoigné |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a attesté |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a désigné |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a affiché |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a déterminé |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a décelé |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a donné |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a suggéré |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a proposé |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a évoqué |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a fait pensé à |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a sous-entendu |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a supposé |forward|trigger|negated|10|Group[754]|Clement
# nul résultat n'a laissé envisager |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a indiqué |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a prouvé |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a montré |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a démontré |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a signalé |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a annoncé |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a manifesté |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a révélé |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a témoigné |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a attesté |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a désigné |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a affiché |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a déterminé |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a décelé |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a donné |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a suggéré |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a proposé |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a évoqué |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a fait pensé à |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a sous-entendu |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a supposé |forward|trigger|negated|10|Group[754]|Clement
# nul évènement n'a laissé envisager |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a indiqué |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a prouvé |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a montré |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a démontré |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a signalé |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a annoncé |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a manifesté |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a révélé |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a témoigné |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a attesté |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a désigné |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a affiché |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a déterminé |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a décelé |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a donné |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a suggéré |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a proposé |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a évoqué |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a fait pensé à |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a sous-entendu |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a supposé |forward|trigger|negated|10|Group[754]|Clement
# nul calcul n'a laissé envisager |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a indiqué |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a prouvé |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a montré |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a démontré |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a signalé |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a annoncé |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a manifesté |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a révélé |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a témoigné |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a attesté |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a désigné |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a affiché |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a déterminé |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a décelé |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a donné |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a suggéré |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a proposé |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a évoqué |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a fait pensé à |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a sous-entendu |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a supposé |forward|trigger|negated|10|Group[754]|Clement
# nul constat n'a laissé envisager |forward|trigger|negated|10|Group[754]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "pas"
Var2 -> "d'histoire" | "de passé" | "d'historique"
Var3 -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[760]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas d'histoire d' |forward|trigger|negated|10|Group[760]|Clement
# pas d'histoire de |forward|trigger|negated|10|Group[760]|Clement
# pas d'histoire d'un |forward|trigger|negated|10|Group[760]|Clement
# pas d'histoire d'une |forward|trigger|negated|10|Group[760]|Clement
# pas de passé d' |forward|trigger|negated|10|Group[760]|Clement
# pas de passé de |forward|trigger|negated|10|Group[760]|Clement
# pas de passé d'un |forward|trigger|negated|10|Group[760]|Clement
# pas de passé d'une |forward|trigger|negated|10|Group[760]|Clement
# pas d'historique d' |forward|trigger|negated|10|Group[760]|Clement
# pas d'historique de |forward|trigger|negated|10|Group[760]|Clement
# pas d'historique d'un |forward|trigger|negated|10|Group[760]|Clement
# pas d'historique d'une |forward|trigger|negated|10|Group[760]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Word Trigger_Rule
Var1 -> "pas"
Var2 -> "d'augmentation" | "d'extension" | "d'amplification" | "d'allongement" | "d'élévation" | "de hausse" | "d'aggravation" | "d'agrandissement" | "d'intensification" | "de redoublement" | "de dilatation" | "de croissance" 
Word -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|both|pseudo|negated|10|Group[764]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas d'augmentation d' |both|pseudo|negated|10|Group[764]|Clement
# pas d'augmentation de |both|pseudo|negated|10|Group[764]|Clement
# pas d'augmentation d'un |both|pseudo|negated|10|Group[764]|Clement
# pas d'augmentation d'une |both|pseudo|negated|10|Group[764]|Clement
# pas d'extension d' |both|pseudo|negated|10|Group[764]|Clement
# pas d'extension de |both|pseudo|negated|10|Group[764]|Clement
# pas d'extension d'un |both|pseudo|negated|10|Group[764]|Clement
# pas d'extension d'une |both|pseudo|negated|10|Group[764]|Clement
# pas d'amplification d' |both|pseudo|negated|10|Group[764]|Clement
# pas d'amplification de |both|pseudo|negated|10|Group[764]|Clement
# pas d'amplification d'un |both|pseudo|negated|10|Group[764]|Clement
# pas d'amplification d'une |both|pseudo|negated|10|Group[764]|Clement
# pas d'allongement d' |both|pseudo|negated|10|Group[764]|Clement
# pas d'allongement de |both|pseudo|negated|10|Group[764]|Clement
# pas d'allongement d'un |both|pseudo|negated|10|Group[764]|Clement
# pas d'allongement d'une |both|pseudo|negated|10|Group[764]|Clement
# pas d'élévation d' |both|pseudo|negated|10|Group[764]|Clement
# pas d'élévation de |both|pseudo|negated|10|Group[764]|Clement
# pas d'élévation d'un |both|pseudo|negated|10|Group[764]|Clement
# pas d'élévation d'une |both|pseudo|negated|10|Group[764]|Clement
# pas de hausse d' |both|pseudo|negated|10|Group[764]|Clement
# pas de hausse de |both|pseudo|negated|10|Group[764]|Clement
# pas de hausse d'un |both|pseudo|negated|10|Group[764]|Clement
# pas de hausse d'une |both|pseudo|negated|10|Group[764]|Clement
# pas d'aggravation d' |both|pseudo|negated|10|Group[764]|Clement
# pas d'aggravation de |both|pseudo|negated|10|Group[764]|Clement
# pas d'aggravation d'un |both|pseudo|negated|10|Group[764]|Clement
# pas d'aggravation d'une |both|pseudo|negated|10|Group[764]|Clement
# pas d'agrandissement d' |both|pseudo|negated|10|Group[764]|Clement
# pas d'agrandissement de |both|pseudo|negated|10|Group[764]|Clement
# pas d'agrandissement d'un |both|pseudo|negated|10|Group[764]|Clement
# pas d'agrandissement d'une |both|pseudo|negated|10|Group[764]|Clement
# pas d'intensification d' |both|pseudo|negated|10|Group[764]|Clement
# pas d'intensification de |both|pseudo|negated|10|Group[764]|Clement
# pas d'intensification d'un |both|pseudo|negated|10|Group[764]|Clement
# pas d'intensification d'une |both|pseudo|negated|10|Group[764]|Clement
# pas de redoublement d' |both|pseudo|negated|10|Group[764]|Clement
# pas de redoublement de |both|pseudo|negated|10|Group[764]|Clement
# pas de redoublement d'un |both|pseudo|negated|10|Group[764]|Clement
# pas de redoublement d'une |both|pseudo|negated|10|Group[764]|Clement
# pas de dilatation d' |both|pseudo|negated|10|Group[764]|Clement
# pas de dilatation de |both|pseudo|negated|10|Group[764]|Clement
# pas de dilatation d'un |both|pseudo|negated|10|Group[764]|Clement
# pas de dilatation d'une |both|pseudo|negated|10|Group[764]|Clement
# pas de croissance d' |both|pseudo|negated|10|Group[764]|Clement
# pas de croissance de |both|pseudo|negated|10|Group[764]|Clement
# pas de croissance d'un |both|pseudo|negated|10|Group[764]|Clement
# pas de croissance d'une |both|pseudo|negated|10|Group[764]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Word Trigger_Rule
Var1 -> "aucun" | "nul"  | "sans" 
Var2 -> "allongement" | "agrandissement" | "redoublement" | "changement" | "changement" | "retournement" | "renversement" | "revirement"
Word -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|both|pseudo|negated|10|Group[764]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun allongement d' |both|pseudo|negated|10|Group[764]|Clement
# aucun allongement de |both|pseudo|negated|10|Group[764]|Clement
# aucun allongement d'un |both|pseudo|negated|10|Group[764]|Clement
# aucun allongement d'une |both|pseudo|negated|10|Group[764]|Clement
# aucun agrandissement d' |both|pseudo|negated|10|Group[764]|Clement
# aucun agrandissement de |both|pseudo|negated|10|Group[764]|Clement
# aucun agrandissement d'un |both|pseudo|negated|10|Group[764]|Clement
# aucun agrandissement d'une |both|pseudo|negated|10|Group[764]|Clement
# aucun redoublement d' |both|pseudo|negated|10|Group[764]|Clement
# aucun redoublement de |both|pseudo|negated|10|Group[764]|Clement
# aucun redoublement d'un |both|pseudo|negated|10|Group[764]|Clement
# aucun redoublement d'une |both|pseudo|negated|10|Group[764]|Clement
# aucun changement d' |both|pseudo|negated|10|Group[764]|Clement
# aucun changement de |both|pseudo|negated|10|Group[764]|Clement
# aucun changement d'un |both|pseudo|negated|10|Group[764]|Clement
# aucun changement d'une |both|pseudo|negated|10|Group[764]|Clement
# aucun changement d' |both|pseudo|negated|10|Group[764]|Clement
# aucun changement de |both|pseudo|negated|10|Group[764]|Clement
# aucun changement d'un |both|pseudo|negated|10|Group[764]|Clement
# aucun changement d'une |both|pseudo|negated|10|Group[764]|Clement
# aucun retournement d' |both|pseudo|negated|10|Group[764]|Clement
# aucun retournement de |both|pseudo|negated|10|Group[764]|Clement
# aucun retournement d'un |both|pseudo|negated|10|Group[764]|Clement
# aucun retournement d'une |both|pseudo|negated|10|Group[764]|Clement
# aucun renversement d' |both|pseudo|negated|10|Group[764]|Clement
# aucun renversement de |both|pseudo|negated|10|Group[764]|Clement
# aucun renversement d'un |both|pseudo|negated|10|Group[764]|Clement
# aucun renversement d'une |both|pseudo|negated|10|Group[764]|Clement
# aucun revirement d' |both|pseudo|negated|10|Group[764]|Clement
# aucun revirement de |both|pseudo|negated|10|Group[764]|Clement
# aucun revirement d'un |both|pseudo|negated|10|Group[764]|Clement
# aucun revirement d'une |both|pseudo|negated|10|Group[764]|Clement
# nul allongement d' |both|pseudo|negated|10|Group[764]|Clement
# nul allongement de |both|pseudo|negated|10|Group[764]|Clement
# nul allongement d'un |both|pseudo|negated|10|Group[764]|Clement
# nul allongement d'une |both|pseudo|negated|10|Group[764]|Clement
# nul agrandissement d' |both|pseudo|negated|10|Group[764]|Clement
# nul agrandissement de |both|pseudo|negated|10|Group[764]|Clement
# nul agrandissement d'un |both|pseudo|negated|10|Group[764]|Clement
# nul agrandissement d'une |both|pseudo|negated|10|Group[764]|Clement
# nul redoublement d' |both|pseudo|negated|10|Group[764]|Clement
# nul redoublement de |both|pseudo|negated|10|Group[764]|Clement
# nul redoublement d'un |both|pseudo|negated|10|Group[764]|Clement
# nul redoublement d'une |both|pseudo|negated|10|Group[764]|Clement
# nul changement d' |both|pseudo|negated|10|Group[764]|Clement
# nul changement de |both|pseudo|negated|10|Group[764]|Clement
# nul changement d'un |both|pseudo|negated|10|Group[764]|Clement
# nul changement d'une |both|pseudo|negated|10|Group[764]|Clement
# nul changement d' |both|pseudo|negated|10|Group[764]|Clement
# nul changement de |both|pseudo|negated|10|Group[764]|Clement
# nul changement d'un |both|pseudo|negated|10|Group[764]|Clement
# nul changement d'une |both|pseudo|negated|10|Group[764]|Clement
# nul retournement d' |both|pseudo|negated|10|Group[764]|Clement
# nul retournement de |both|pseudo|negated|10|Group[764]|Clement
# nul retournement d'un |both|pseudo|negated|10|Group[764]|Clement
# nul retournement d'une |both|pseudo|negated|10|Group[764]|Clement
# nul renversement d' |both|pseudo|negated|10|Group[764]|Clement
# nul renversement de |both|pseudo|negated|10|Group[764]|Clement
# nul renversement d'un |both|pseudo|negated|10|Group[764]|Clement
# nul renversement d'une |both|pseudo|negated|10|Group[764]|Clement
# nul revirement d' |both|pseudo|negated|10|Group[764]|Clement
# nul revirement de |both|pseudo|negated|10|Group[764]|Clement
# nul revirement d'un |both|pseudo|negated|10|Group[764]|Clement
# nul revirement d'une |both|pseudo|negated|10|Group[764]|Clement
# sans allongement d' |both|pseudo|negated|10|Group[764]|Clement
# sans allongement de |both|pseudo|negated|10|Group[764]|Clement
# sans allongement d'un |both|pseudo|negated|10|Group[764]|Clement
# sans allongement d'une |both|pseudo|negated|10|Group[764]|Clement
# sans agrandissement d' |both|pseudo|negated|10|Group[764]|Clement
# sans agrandissement de |both|pseudo|negated|10|Group[764]|Clement
# sans agrandissement d'un |both|pseudo|negated|10|Group[764]|Clement
# sans agrandissement d'une |both|pseudo|negated|10|Group[764]|Clement
# sans redoublement d' |both|pseudo|negated|10|Group[764]|Clement
# sans redoublement de |both|pseudo|negated|10|Group[764]|Clement
# sans redoublement d'un |both|pseudo|negated|10|Group[764]|Clement
# sans redoublement d'une |both|pseudo|negated|10|Group[764]|Clement
# sans changement d' |both|pseudo|negated|10|Group[764]|Clement
# sans changement de |both|pseudo|negated|10|Group[764]|Clement
# sans changement d'un |both|pseudo|negated|10|Group[764]|Clement
# sans changement d'une |both|pseudo|negated|10|Group[764]|Clement
# sans changement d' |both|pseudo|negated|10|Group[764]|Clement
# sans changement de |both|pseudo|negated|10|Group[764]|Clement
# sans changement d'un |both|pseudo|negated|10|Group[764]|Clement
# sans changement d'une |both|pseudo|negated|10|Group[764]|Clement
# sans retournement d' |both|pseudo|negated|10|Group[764]|Clement
# sans retournement de |both|pseudo|negated|10|Group[764]|Clement
# sans retournement d'un |both|pseudo|negated|10|Group[764]|Clement
# sans retournement d'une |both|pseudo|negated|10|Group[764]|Clement
# sans renversement d' |both|pseudo|negated|10|Group[764]|Clement
# sans renversement de |both|pseudo|negated|10|Group[764]|Clement
# sans renversement d'un |both|pseudo|negated|10|Group[764]|Clement
# sans renversement d'une |both|pseudo|negated|10|Group[764]|Clement
# sans revirement d' |both|pseudo|negated|10|Group[764]|Clement
# sans revirement de |both|pseudo|negated|10|Group[764]|Clement
# sans revirement d'un |both|pseudo|negated|10|Group[764]|Clement
# sans revirement d'une |both|pseudo|negated|10|Group[764]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Word Trigger_Rule
Var1 -> "aucune" | "nulle" | "sans" 
Var2 -> "augmentation" | "extension" | "amplification" | "élévation" | "hausse" | "aggravation" | "intensification" | "dilatation" | "croissance" | "variation" | "altération" | "évolution" | "transformation" | "fluctuation" | "mutation" | "amélioration" | "transition" | "modulation" | "inflexion" | "différence"
Word -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|both|pseudo|negated|10|Group[764]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucune augmentation d' |both|pseudo|negated|10|Group[764]|Clement
# aucune augmentation de |both|pseudo|negated|10|Group[764]|Clement
# aucune augmentation d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune augmentation d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune extension d' |both|pseudo|negated|10|Group[764]|Clement
# aucune extension de |both|pseudo|negated|10|Group[764]|Clement
# aucune extension d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune extension d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune amplification d' |both|pseudo|negated|10|Group[764]|Clement
# aucune amplification de |both|pseudo|negated|10|Group[764]|Clement
# aucune amplification d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune amplification d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune élévation d' |both|pseudo|negated|10|Group[764]|Clement
# aucune élévation de |both|pseudo|negated|10|Group[764]|Clement
# aucune élévation d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune élévation d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune hausse d' |both|pseudo|negated|10|Group[764]|Clement
# aucune hausse de |both|pseudo|negated|10|Group[764]|Clement
# aucune hausse d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune hausse d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune aggravation d' |both|pseudo|negated|10|Group[764]|Clement
# aucune aggravation de |both|pseudo|negated|10|Group[764]|Clement
# aucune aggravation d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune aggravation d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune intensification d' |both|pseudo|negated|10|Group[764]|Clement
# aucune intensification de |both|pseudo|negated|10|Group[764]|Clement
# aucune intensification d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune intensification d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune dilatation d' |both|pseudo|negated|10|Group[764]|Clement
# aucune dilatation de |both|pseudo|negated|10|Group[764]|Clement
# aucune dilatation d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune dilatation d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune croissance d' |both|pseudo|negated|10|Group[764]|Clement
# aucune croissance de |both|pseudo|negated|10|Group[764]|Clement
# aucune croissance d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune croissance d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune variation d' |both|pseudo|negated|10|Group[764]|Clement
# aucune variation de |both|pseudo|negated|10|Group[764]|Clement
# aucune variation d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune variation d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune altération d' |both|pseudo|negated|10|Group[764]|Clement
# aucune altération de |both|pseudo|negated|10|Group[764]|Clement
# aucune altération d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune altération d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune évolution d' |both|pseudo|negated|10|Group[764]|Clement
# aucune évolution de |both|pseudo|negated|10|Group[764]|Clement
# aucune évolution d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune évolution d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune transformation d' |both|pseudo|negated|10|Group[764]|Clement
# aucune transformation de |both|pseudo|negated|10|Group[764]|Clement
# aucune transformation d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune transformation d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune fluctuation d' |both|pseudo|negated|10|Group[764]|Clement
# aucune fluctuation de |both|pseudo|negated|10|Group[764]|Clement
# aucune fluctuation d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune fluctuation d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune mutation d' |both|pseudo|negated|10|Group[764]|Clement
# aucune mutation de |both|pseudo|negated|10|Group[764]|Clement
# aucune mutation d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune mutation d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune amélioration d' |both|pseudo|negated|10|Group[764]|Clement
# aucune amélioration de |both|pseudo|negated|10|Group[764]|Clement
# aucune amélioration d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune amélioration d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune transition d' |both|pseudo|negated|10|Group[764]|Clement
# aucune transition de |both|pseudo|negated|10|Group[764]|Clement
# aucune transition d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune transition d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune modulation d' |both|pseudo|negated|10|Group[764]|Clement
# aucune modulation de |both|pseudo|negated|10|Group[764]|Clement
# aucune modulation d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune modulation d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune inflexion d' |both|pseudo|negated|10|Group[764]|Clement
# aucune inflexion de |both|pseudo|negated|10|Group[764]|Clement
# aucune inflexion d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune inflexion d'une |both|pseudo|negated|10|Group[764]|Clement
# aucune différence d' |both|pseudo|negated|10|Group[764]|Clement
# aucune différence de |both|pseudo|negated|10|Group[764]|Clement
# aucune différence d'un |both|pseudo|negated|10|Group[764]|Clement
# aucune différence d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle augmentation d' |both|pseudo|negated|10|Group[764]|Clement
# nulle augmentation de |both|pseudo|negated|10|Group[764]|Clement
# nulle augmentation d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle augmentation d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle extension d' |both|pseudo|negated|10|Group[764]|Clement
# nulle extension de |both|pseudo|negated|10|Group[764]|Clement
# nulle extension d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle extension d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle amplification d' |both|pseudo|negated|10|Group[764]|Clement
# nulle amplification de |both|pseudo|negated|10|Group[764]|Clement
# nulle amplification d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle amplification d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle élévation d' |both|pseudo|negated|10|Group[764]|Clement
# nulle élévation de |both|pseudo|negated|10|Group[764]|Clement
# nulle élévation d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle élévation d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle hausse d' |both|pseudo|negated|10|Group[764]|Clement
# nulle hausse de |both|pseudo|negated|10|Group[764]|Clement
# nulle hausse d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle hausse d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle aggravation d' |both|pseudo|negated|10|Group[764]|Clement
# nulle aggravation de |both|pseudo|negated|10|Group[764]|Clement
# nulle aggravation d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle aggravation d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle intensification d' |both|pseudo|negated|10|Group[764]|Clement
# nulle intensification de |both|pseudo|negated|10|Group[764]|Clement
# nulle intensification d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle intensification d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle dilatation d' |both|pseudo|negated|10|Group[764]|Clement
# nulle dilatation de |both|pseudo|negated|10|Group[764]|Clement
# nulle dilatation d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle dilatation d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle croissance d' |both|pseudo|negated|10|Group[764]|Clement
# nulle croissance de |both|pseudo|negated|10|Group[764]|Clement
# nulle croissance d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle croissance d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle variation d' |both|pseudo|negated|10|Group[764]|Clement
# nulle variation de |both|pseudo|negated|10|Group[764]|Clement
# nulle variation d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle variation d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle altération d' |both|pseudo|negated|10|Group[764]|Clement
# nulle altération de |both|pseudo|negated|10|Group[764]|Clement
# nulle altération d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle altération d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle évolution d' |both|pseudo|negated|10|Group[764]|Clement
# nulle évolution de |both|pseudo|negated|10|Group[764]|Clement
# nulle évolution d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle évolution d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle transformation d' |both|pseudo|negated|10|Group[764]|Clement
# nulle transformation de |both|pseudo|negated|10|Group[764]|Clement
# nulle transformation d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle transformation d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle fluctuation d' |both|pseudo|negated|10|Group[764]|Clement
# nulle fluctuation de |both|pseudo|negated|10|Group[764]|Clement
# nulle fluctuation d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle fluctuation d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle mutation d' |both|pseudo|negated|10|Group[764]|Clement
# nulle mutation de |both|pseudo|negated|10|Group[764]|Clement
# nulle mutation d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle mutation d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle amélioration d' |both|pseudo|negated|10|Group[764]|Clement
# nulle amélioration de |both|pseudo|negated|10|Group[764]|Clement
# nulle amélioration d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle amélioration d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle transition d' |both|pseudo|negated|10|Group[764]|Clement
# nulle transition de |both|pseudo|negated|10|Group[764]|Clement
# nulle transition d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle transition d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle modulation d' |both|pseudo|negated|10|Group[764]|Clement
# nulle modulation de |both|pseudo|negated|10|Group[764]|Clement
# nulle modulation d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle modulation d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle inflexion d' |both|pseudo|negated|10|Group[764]|Clement
# nulle inflexion de |both|pseudo|negated|10|Group[764]|Clement
# nulle inflexion d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle inflexion d'une |both|pseudo|negated|10|Group[764]|Clement
# nulle différence d' |both|pseudo|negated|10|Group[764]|Clement
# nulle différence de |both|pseudo|negated|10|Group[764]|Clement
# nulle différence d'un |both|pseudo|negated|10|Group[764]|Clement
# nulle différence d'une |both|pseudo|negated|10|Group[764]|Clement
# sans augmentation d' |both|pseudo|negated|10|Group[764]|Clement
# sans augmentation de |both|pseudo|negated|10|Group[764]|Clement
# sans augmentation d'un |both|pseudo|negated|10|Group[764]|Clement
# sans augmentation d'une |both|pseudo|negated|10|Group[764]|Clement
# sans extension d' |both|pseudo|negated|10|Group[764]|Clement
# sans extension de |both|pseudo|negated|10|Group[764]|Clement
# sans extension d'un |both|pseudo|negated|10|Group[764]|Clement
# sans extension d'une |both|pseudo|negated|10|Group[764]|Clement
# sans amplification d' |both|pseudo|negated|10|Group[764]|Clement
# sans amplification de |both|pseudo|negated|10|Group[764]|Clement
# sans amplification d'un |both|pseudo|negated|10|Group[764]|Clement
# sans amplification d'une |both|pseudo|negated|10|Group[764]|Clement
# sans élévation d' |both|pseudo|negated|10|Group[764]|Clement
# sans élévation de |both|pseudo|negated|10|Group[764]|Clement
# sans élévation d'un |both|pseudo|negated|10|Group[764]|Clement
# sans élévation d'une |both|pseudo|negated|10|Group[764]|Clement
# sans hausse d' |both|pseudo|negated|10|Group[764]|Clement
# sans hausse de |both|pseudo|negated|10|Group[764]|Clement
# sans hausse d'un |both|pseudo|negated|10|Group[764]|Clement
# sans hausse d'une |both|pseudo|negated|10|Group[764]|Clement
# sans aggravation d' |both|pseudo|negated|10|Group[764]|Clement
# sans aggravation de |both|pseudo|negated|10|Group[764]|Clement
# sans aggravation d'un |both|pseudo|negated|10|Group[764]|Clement
# sans aggravation d'une |both|pseudo|negated|10|Group[764]|Clement
# sans intensification d' |both|pseudo|negated|10|Group[764]|Clement
# sans intensification de |both|pseudo|negated|10|Group[764]|Clement
# sans intensification d'un |both|pseudo|negated|10|Group[764]|Clement
# sans intensification d'une |both|pseudo|negated|10|Group[764]|Clement
# sans dilatation d' |both|pseudo|negated|10|Group[764]|Clement
# sans dilatation de |both|pseudo|negated|10|Group[764]|Clement
# sans dilatation d'un |both|pseudo|negated|10|Group[764]|Clement
# sans dilatation d'une |both|pseudo|negated|10|Group[764]|Clement
# sans croissance d' |both|pseudo|negated|10|Group[764]|Clement
# sans croissance de |both|pseudo|negated|10|Group[764]|Clement
# sans croissance d'un |both|pseudo|negated|10|Group[764]|Clement
# sans croissance d'une |both|pseudo|negated|10|Group[764]|Clement
# sans variation d' |both|pseudo|negated|10|Group[764]|Clement
# sans variation de |both|pseudo|negated|10|Group[764]|Clement
# sans variation d'un |both|pseudo|negated|10|Group[764]|Clement
# sans variation d'une |both|pseudo|negated|10|Group[764]|Clement
# sans altération d' |both|pseudo|negated|10|Group[764]|Clement
# sans altération de |both|pseudo|negated|10|Group[764]|Clement
# sans altération d'un |both|pseudo|negated|10|Group[764]|Clement
# sans altération d'une |both|pseudo|negated|10|Group[764]|Clement
# sans évolution d' |both|pseudo|negated|10|Group[764]|Clement
# sans évolution de |both|pseudo|negated|10|Group[764]|Clement
# sans évolution d'un |both|pseudo|negated|10|Group[764]|Clement
# sans évolution d'une |both|pseudo|negated|10|Group[764]|Clement
# sans transformation d' |both|pseudo|negated|10|Group[764]|Clement
# sans transformation de |both|pseudo|negated|10|Group[764]|Clement
# sans transformation d'un |both|pseudo|negated|10|Group[764]|Clement
# sans transformation d'une |both|pseudo|negated|10|Group[764]|Clement
# sans fluctuation d' |both|pseudo|negated|10|Group[764]|Clement
# sans fluctuation de |both|pseudo|negated|10|Group[764]|Clement
# sans fluctuation d'un |both|pseudo|negated|10|Group[764]|Clement
# sans fluctuation d'une |both|pseudo|negated|10|Group[764]|Clement
# sans mutation d' |both|pseudo|negated|10|Group[764]|Clement
# sans mutation de |both|pseudo|negated|10|Group[764]|Clement
# sans mutation d'un |both|pseudo|negated|10|Group[764]|Clement
# sans mutation d'une |both|pseudo|negated|10|Group[764]|Clement
# sans amélioration d' |both|pseudo|negated|10|Group[764]|Clement
# sans amélioration de |both|pseudo|negated|10|Group[764]|Clement
# sans amélioration d'un |both|pseudo|negated|10|Group[764]|Clement
# sans amélioration d'une |both|pseudo|negated|10|Group[764]|Clement
# sans transition d' |both|pseudo|negated|10|Group[764]|Clement
# sans transition de |both|pseudo|negated|10|Group[764]|Clement
# sans transition d'un |both|pseudo|negated|10|Group[764]|Clement
# sans transition d'une |both|pseudo|negated|10|Group[764]|Clement
# sans modulation d' |both|pseudo|negated|10|Group[764]|Clement
# sans modulation de |both|pseudo|negated|10|Group[764]|Clement
# sans modulation d'un |both|pseudo|negated|10|Group[764]|Clement
# sans modulation d'une |both|pseudo|negated|10|Group[764]|Clement
# sans inflexion d' |both|pseudo|negated|10|Group[764]|Clement
# sans inflexion de |both|pseudo|negated|10|Group[764]|Clement
# sans inflexion d'un |both|pseudo|negated|10|Group[764]|Clement
# sans inflexion d'une |both|pseudo|negated|10|Group[764]|Clement
# sans différence d' |both|pseudo|negated|10|Group[764]|Clement
# sans différence de |both|pseudo|negated|10|Group[764]|Clement
# sans différence d'un |both|pseudo|negated|10|Group[764]|Clement
# sans différence d'une |both|pseudo|negated|10|Group[764]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucun" | "nul" | "sans" 
Var2 -> "avertissement" | "renvoi" | "critère" | "symptôme"
Var3 ->  "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[765]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun avertissement d' |forward|trigger|negated|10|Group[765]|Clement
# aucun avertissement de |forward|trigger|negated|10|Group[765]|Clement
# aucun avertissement d'un |forward|trigger|negated|10|Group[765]|Clement
# aucun avertissement d'une |forward|trigger|negated|10|Group[765]|Clement
# aucun renvoi d' |forward|trigger|negated|10|Group[765]|Clement
# aucun renvoi de |forward|trigger|negated|10|Group[765]|Clement
# aucun renvoi d'un |forward|trigger|negated|10|Group[765]|Clement
# aucun renvoi d'une |forward|trigger|negated|10|Group[765]|Clement
# aucun critère d' |forward|trigger|negated|10|Group[765]|Clement
# aucun critère de |forward|trigger|negated|10|Group[765]|Clement
# aucun critère d'un |forward|trigger|negated|10|Group[765]|Clement
# aucun critère d'une |forward|trigger|negated|10|Group[765]|Clement
# aucun symptôme d' |forward|trigger|negated|10|Group[765]|Clement
# aucun symptôme de |forward|trigger|negated|10|Group[765]|Clement
# aucun symptôme d'un |forward|trigger|negated|10|Group[765]|Clement
# aucun symptôme d'une |forward|trigger|negated|10|Group[765]|Clement
# nul avertissement d' |forward|trigger|negated|10|Group[765]|Clement
# nul avertissement de |forward|trigger|negated|10|Group[765]|Clement
# nul avertissement d'un |forward|trigger|negated|10|Group[765]|Clement
# nul avertissement d'une |forward|trigger|negated|10|Group[765]|Clement
# nul renvoi d' |forward|trigger|negated|10|Group[765]|Clement
# nul renvoi de |forward|trigger|negated|10|Group[765]|Clement
# nul renvoi d'un |forward|trigger|negated|10|Group[765]|Clement
# nul renvoi d'une |forward|trigger|negated|10|Group[765]|Clement
# nul critère d' |forward|trigger|negated|10|Group[765]|Clement
# nul critère de |forward|trigger|negated|10|Group[765]|Clement
# nul critère d'un |forward|trigger|negated|10|Group[765]|Clement
# nul critère d'une |forward|trigger|negated|10|Group[765]|Clement
# nul symptôme d' |forward|trigger|negated|10|Group[765]|Clement
# nul symptôme de |forward|trigger|negated|10|Group[765]|Clement
# nul symptôme d'un |forward|trigger|negated|10|Group[765]|Clement
# nul symptôme d'une |forward|trigger|negated|10|Group[765]|Clement
# sans avertissement d' |forward|trigger|negated|10|Group[765]|Clement
# sans avertissement de |forward|trigger|negated|10|Group[765]|Clement
# sans avertissement d'un |forward|trigger|negated|10|Group[765]|Clement
# sans avertissement d'une |forward|trigger|negated|10|Group[765]|Clement
# sans renvoi d' |forward|trigger|negated|10|Group[765]|Clement
# sans renvoi de |forward|trigger|negated|10|Group[765]|Clement
# sans renvoi d'un |forward|trigger|negated|10|Group[765]|Clement
# sans renvoi d'une |forward|trigger|negated|10|Group[765]|Clement
# sans critère d' |forward|trigger|negated|10|Group[765]|Clement
# sans critère de |forward|trigger|negated|10|Group[765]|Clement
# sans critère d'un |forward|trigger|negated|10|Group[765]|Clement
# sans critère d'une |forward|trigger|negated|10|Group[765]|Clement
# sans symptôme d' |forward|trigger|negated|10|Group[765]|Clement
# sans symptôme de |forward|trigger|negated|10|Group[765]|Clement
# sans symptôme d'un |forward|trigger|negated|10|Group[765]|Clement
# sans symptôme d'une |forward|trigger|negated|10|Group[765]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "aucun" | "nul" | "sans" 
Var2 -> "passé" | "souvenir"
Var3 ->  | "\\w+"
Var4 -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[770]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun passé d' |forward|trigger|negated|10|Group[770]|Clement
# aucun passé de |forward|trigger|negated|10|Group[770]|Clement
# aucun passé d'un |forward|trigger|negated|10|Group[770]|Clement
# aucun passé d'une |forward|trigger|negated|10|Group[770]|Clement
# aucun passé \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# aucun passé \w+ de |forward|trigger|negated|10|Group[770]|Clement
# aucun passé \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# aucun passé \w+ d'une |forward|trigger|negated|10|Group[770]|Clement
# aucun souvenir d' |forward|trigger|negated|10|Group[770]|Clement
# aucun souvenir de |forward|trigger|negated|10|Group[770]|Clement
# aucun souvenir d'un |forward|trigger|negated|10|Group[770]|Clement
# aucun souvenir d'une |forward|trigger|negated|10|Group[770]|Clement
# aucun souvenir \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# aucun souvenir \w+ de |forward|trigger|negated|10|Group[770]|Clement
# aucun souvenir \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# aucun souvenir \w+ d'une |forward|trigger|negated|10|Group[770]|Clement
# nul passé d' |forward|trigger|negated|10|Group[770]|Clement
# nul passé de |forward|trigger|negated|10|Group[770]|Clement
# nul passé d'un |forward|trigger|negated|10|Group[770]|Clement
# nul passé d'une |forward|trigger|negated|10|Group[770]|Clement
# nul passé \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# nul passé \w+ de |forward|trigger|negated|10|Group[770]|Clement
# nul passé \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# nul passé \w+ d'une |forward|trigger|negated|10|Group[770]|Clement
# nul souvenir d' |forward|trigger|negated|10|Group[770]|Clement
# nul souvenir de |forward|trigger|negated|10|Group[770]|Clement
# nul souvenir d'un |forward|trigger|negated|10|Group[770]|Clement
# nul souvenir d'une |forward|trigger|negated|10|Group[770]|Clement
# nul souvenir \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# nul souvenir \w+ de |forward|trigger|negated|10|Group[770]|Clement
# nul souvenir \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# nul souvenir \w+ d'une |forward|trigger|negated|10|Group[770]|Clement
# sans passé d' |forward|trigger|negated|10|Group[770]|Clement
# sans passé de |forward|trigger|negated|10|Group[770]|Clement
# sans passé d'un |forward|trigger|negated|10|Group[770]|Clement
# sans passé d'une |forward|trigger|negated|10|Group[770]|Clement
# sans passé \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# sans passé \w+ de |forward|trigger|negated|10|Group[770]|Clement
# sans passé \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# sans passé \w+ d'une |forward|trigger|negated|10|Group[770]|Clement
# sans souvenir d' |forward|trigger|negated|10|Group[770]|Clement
# sans souvenir de |forward|trigger|negated|10|Group[770]|Clement
# sans souvenir d'un |forward|trigger|negated|10|Group[770]|Clement
# sans souvenir d'une |forward|trigger|negated|10|Group[770]|Clement
# sans souvenir \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# sans souvenir \w+ de |forward|trigger|negated|10|Group[770]|Clement
# sans souvenir \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# sans souvenir \w+ d'une |forward|trigger|negated|10|Group[770]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "aucune" | "nulle" | "sans" 
Var2 -> "histoire" | "historique"
Var3 ->  | "\\w+"
Var4 -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[770]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucune histoire d' |forward|trigger|negated|10|Group[770]|Clement
# aucune histoire de |forward|trigger|negated|10|Group[770]|Clement
# aucune histoire d'un |forward|trigger|negated|10|Group[770]|Clement
# aucune histoire d'une |forward|trigger|negated|10|Group[770]|Clement
# aucune histoire \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# aucune histoire \w+ de |forward|trigger|negated|10|Group[770]|Clement
# aucune histoire \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# aucune histoire \w+ d'une |forward|trigger|negated|10|Group[770]|Clement
# aucune historique d' |forward|trigger|negated|10|Group[770]|Clement
# aucune historique de |forward|trigger|negated|10|Group[770]|Clement
# aucune historique d'un |forward|trigger|negated|10|Group[770]|Clement
# aucune historique d'une |forward|trigger|negated|10|Group[770]|Clement
# aucune historique \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# aucune historique \w+ de |forward|trigger|negated|10|Group[770]|Clement
# aucune historique \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# aucune historique \w+ d'une |forward|trigger|negated|10|Group[770]|Clement
# nulle histoire d' |forward|trigger|negated|10|Group[770]|Clement
# nulle histoire de |forward|trigger|negated|10|Group[770]|Clement
# nulle histoire d'un |forward|trigger|negated|10|Group[770]|Clement
# nulle histoire d'une |forward|trigger|negated|10|Group[770]|Clement
# nulle histoire \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# nulle histoire \w+ de |forward|trigger|negated|10|Group[770]|Clement
# nulle histoire \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# nulle histoire \w+ d'une |forward|trigger|negated|10|Group[770]|Clement
# nulle historique d' |forward|trigger|negated|10|Group[770]|Clement
# nulle historique de |forward|trigger|negated|10|Group[770]|Clement
# nulle historique d'un |forward|trigger|negated|10|Group[770]|Clement
# nulle historique d'une |forward|trigger|negated|10|Group[770]|Clement
# nulle historique \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# nulle historique \w+ de |forward|trigger|negated|10|Group[770]|Clement
# nulle historique \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# nulle historique \w+ d'une |forward|trigger|negated|10|Group[770]|Clement
# sans histoire d' |forward|trigger|negated|10|Group[770]|Clement
# sans histoire de |forward|trigger|negated|10|Group[770]|Clement
# sans histoire d'un |forward|trigger|negated|10|Group[770]|Clement
# sans histoire d'une |forward|trigger|negated|10|Group[770]|Clement
# sans histoire \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# sans histoire \w+ de |forward|trigger|negated|10|Group[770]|Clement
# sans histoire \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# sans histoire \w+ d'une |forward|trigger|negated|10|Group[770]|Clement
# sans historique d' |forward|trigger|negated|10|Group[770]|Clement
# sans historique de |forward|trigger|negated|10|Group[770]|Clement
# sans historique d'un |forward|trigger|negated|10|Group[770]|Clement
# sans historique d'une |forward|trigger|negated|10|Group[770]|Clement
# sans historique \w+ d' |forward|trigger|negated|10|Group[770]|Clement
# sans historique \w+ de |forward|trigger|negated|10|Group[770]|Clement
# sans historique \w+ d'un |forward|trigger|negated|10|Group[770]|Clement
# sans historique \w+ d'une |forward|trigger|negated|10|Group[770]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Trigger_Rule
Var1 -> "n'est" | "n'était"
Var2 -> "plus" | "pas"
Var3 -> "présent" | "actif" | "actuel" | "là"
Trigger_Rule -> "|backward|trigger|negated|10|Group[774]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'est plus présent |backward|trigger|negated|10|Group[774]|Clement
# n'est plus actif |backward|trigger|negated|10|Group[774]|Clement
# n'est plus actuel |backward|trigger|negated|10|Group[774]|Clement
# n'est plus là |backward|trigger|negated|10|Group[774]|Clement
# n'est pas présent |backward|trigger|negated|10|Group[774]|Clement
# n'est pas actif |backward|trigger|negated|10|Group[774]|Clement
# n'est pas actuel |backward|trigger|negated|10|Group[774]|Clement
# n'est pas là |backward|trigger|negated|10|Group[774]|Clement
# n'était plus présent |backward|trigger|negated|10|Group[774]|Clement
# n'était plus actif |backward|trigger|negated|10|Group[774]|Clement
# n'était plus actuel |backward|trigger|negated|10|Group[774]|Clement
# n'était plus là |backward|trigger|negated|10|Group[774]|Clement
# n'était pas présent |backward|trigger|negated|10|Group[774]|Clement
# n'était pas actif |backward|trigger|negated|10|Group[774]|Clement
# n'était pas actuel |backward|trigger|negated|10|Group[774]|Clement
# n'était pas là |backward|trigger|negated|10|Group[774]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Trigger_Rule
Var1 -> "ne sont" | "n'étaient"
Var2 -> "plus" | "pas"
Var3 -> "présents" | "actifs" | "actuels" | "là"
Trigger_Rule -> "|backward|trigger|negated|10|Group[774]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne sont plus présents |backward|trigger|negated|10|Group[774]|Clement
# ne sont plus actifs |backward|trigger|negated|10|Group[774]|Clement
# ne sont plus actuels |backward|trigger|negated|10|Group[774]|Clement
# ne sont plus là |backward|trigger|negated|10|Group[774]|Clement
# ne sont pas présents |backward|trigger|negated|10|Group[774]|Clement
# ne sont pas actifs |backward|trigger|negated|10|Group[774]|Clement
# ne sont pas actuels |backward|trigger|negated|10|Group[774]|Clement
# ne sont pas là |backward|trigger|negated|10|Group[774]|Clement
# n'étaient plus présents |backward|trigger|negated|10|Group[774]|Clement
# n'étaient plus actifs |backward|trigger|negated|10|Group[774]|Clement
# n'étaient plus actuels |backward|trigger|negated|10|Group[774]|Clement
# n'étaient plus là |backward|trigger|negated|10|Group[774]|Clement
# n'étaient pas présents |backward|trigger|negated|10|Group[774]|Clement
# n'étaient pas actifs |backward|trigger|negated|10|Group[774]|Clement
# n'étaient pas actuels |backward|trigger|negated|10|Group[774]|Clement
# n'étaient pas là |backward|trigger|negated|10|Group[774]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "plus" | "pas"
Var2 -> "maintenant" | "actuellement" | "aujourd'hui" | "à présent" | "dèsdésormais" | "présentement"
Trigger_Rule -> "|backward|trigger|negated|10|Group[776]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# plus maintenant |backward|trigger|negated|10|Group[776]|Clement
# plus actuellement |backward|trigger|negated|10|Group[776]|Clement
# plus aujourd'hui |backward|trigger|negated|10|Group[776]|Clement
# plus à présent |backward|trigger|negated|10|Group[776]|Clement
# plus dèsdésormais |backward|trigger|negated|10|Group[776]|Clement
# plus présentement |backward|trigger|negated|10|Group[776]|Clement
# pas maintenant |backward|trigger|negated|10|Group[776]|Clement
# pas actuellement |backward|trigger|negated|10|Group[776]|Clement
# pas aujourd'hui |backward|trigger|negated|10|Group[776]|Clement
# pas à présent |backward|trigger|negated|10|Group[776]|Clement
# pas dèsdésormais |backward|trigger|negated|10|Group[776]|Clement
# pas présentement |backward|trigger|negated|10|Group[776]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucune" | "nulle" | "sans" 
Var2 -> "mention" | "évocation" | "notation" | "signalement" | "note" | "expression" | "référence" | "reflet" | "allusion"
Var3 -> "d'" | "de" | "d'un" | "d'une" | "signalé"
Trigger_Rule -> "|forward|trigger|negated|10|Group[782]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucune mention d' |forward|trigger|negated|10|Group[782]|Clement
# aucune mention de |forward|trigger|negated|10|Group[782]|Clement
# aucune mention d'un |forward|trigger|negated|10|Group[782]|Clement
# aucune mention d'une |forward|trigger|negated|10|Group[782]|Clement
# aucune mention signalé |forward|trigger|negated|10|Group[782]|Clement
# aucune évocation d' |forward|trigger|negated|10|Group[782]|Clement
# aucune évocation de |forward|trigger|negated|10|Group[782]|Clement
# aucune évocation d'un |forward|trigger|negated|10|Group[782]|Clement
# aucune évocation d'une |forward|trigger|negated|10|Group[782]|Clement
# aucune évocation signalé |forward|trigger|negated|10|Group[782]|Clement
# aucune notation d' |forward|trigger|negated|10|Group[782]|Clement
# aucune notation de |forward|trigger|negated|10|Group[782]|Clement
# aucune notation d'un |forward|trigger|negated|10|Group[782]|Clement
# aucune notation d'une |forward|trigger|negated|10|Group[782]|Clement
# aucune notation signalé |forward|trigger|negated|10|Group[782]|Clement
# aucune signalement d' |forward|trigger|negated|10|Group[782]|Clement
# aucune signalement de |forward|trigger|negated|10|Group[782]|Clement
# aucune signalement d'un |forward|trigger|negated|10|Group[782]|Clement
# aucune signalement d'une |forward|trigger|negated|10|Group[782]|Clement
# aucune signalement signalé |forward|trigger|negated|10|Group[782]|Clement
# aucune note d' |forward|trigger|negated|10|Group[782]|Clement
# aucune note de |forward|trigger|negated|10|Group[782]|Clement
# aucune note d'un |forward|trigger|negated|10|Group[782]|Clement
# aucune note d'une |forward|trigger|negated|10|Group[782]|Clement
# aucune note signalé |forward|trigger|negated|10|Group[782]|Clement
# aucune expression d' |forward|trigger|negated|10|Group[782]|Clement
# aucune expression de |forward|trigger|negated|10|Group[782]|Clement
# aucune expression d'un |forward|trigger|negated|10|Group[782]|Clement
# aucune expression d'une |forward|trigger|negated|10|Group[782]|Clement
# aucune expression signalé |forward|trigger|negated|10|Group[782]|Clement
# aucune référence d' |forward|trigger|negated|10|Group[782]|Clement
# aucune référence de |forward|trigger|negated|10|Group[782]|Clement
# aucune référence d'un |forward|trigger|negated|10|Group[782]|Clement
# aucune référence d'une |forward|trigger|negated|10|Group[782]|Clement
# aucune référence signalé |forward|trigger|negated|10|Group[782]|Clement
# aucune reflet d' |forward|trigger|negated|10|Group[782]|Clement
# aucune reflet de |forward|trigger|negated|10|Group[782]|Clement
# aucune reflet d'un |forward|trigger|negated|10|Group[782]|Clement
# aucune reflet d'une |forward|trigger|negated|10|Group[782]|Clement
# aucune reflet signalé |forward|trigger|negated|10|Group[782]|Clement
# aucune allusion d' |forward|trigger|negated|10|Group[782]|Clement
# aucune allusion de |forward|trigger|negated|10|Group[782]|Clement
# aucune allusion d'un |forward|trigger|negated|10|Group[782]|Clement
# aucune allusion d'une |forward|trigger|negated|10|Group[782]|Clement
# aucune allusion signalé |forward|trigger|negated|10|Group[782]|Clement
# nulle mention d' |forward|trigger|negated|10|Group[782]|Clement
# nulle mention de |forward|trigger|negated|10|Group[782]|Clement
# nulle mention d'un |forward|trigger|negated|10|Group[782]|Clement
# nulle mention d'une |forward|trigger|negated|10|Group[782]|Clement
# nulle mention signalé |forward|trigger|negated|10|Group[782]|Clement
# nulle évocation d' |forward|trigger|negated|10|Group[782]|Clement
# nulle évocation de |forward|trigger|negated|10|Group[782]|Clement
# nulle évocation d'un |forward|trigger|negated|10|Group[782]|Clement
# nulle évocation d'une |forward|trigger|negated|10|Group[782]|Clement
# nulle évocation signalé |forward|trigger|negated|10|Group[782]|Clement
# nulle notation d' |forward|trigger|negated|10|Group[782]|Clement
# nulle notation de |forward|trigger|negated|10|Group[782]|Clement
# nulle notation d'un |forward|trigger|negated|10|Group[782]|Clement
# nulle notation d'une |forward|trigger|negated|10|Group[782]|Clement
# nulle notation signalé |forward|trigger|negated|10|Group[782]|Clement
# nulle signalement d' |forward|trigger|negated|10|Group[782]|Clement
# nulle signalement de |forward|trigger|negated|10|Group[782]|Clement
# nulle signalement d'un |forward|trigger|negated|10|Group[782]|Clement
# nulle signalement d'une |forward|trigger|negated|10|Group[782]|Clement
# nulle signalement signalé |forward|trigger|negated|10|Group[782]|Clement
# nulle note d' |forward|trigger|negated|10|Group[782]|Clement
# nulle note de |forward|trigger|negated|10|Group[782]|Clement
# nulle note d'un |forward|trigger|negated|10|Group[782]|Clement
# nulle note d'une |forward|trigger|negated|10|Group[782]|Clement
# nulle note signalé |forward|trigger|negated|10|Group[782]|Clement
# nulle expression d' |forward|trigger|negated|10|Group[782]|Clement
# nulle expression de |forward|trigger|negated|10|Group[782]|Clement
# nulle expression d'un |forward|trigger|negated|10|Group[782]|Clement
# nulle expression d'une |forward|trigger|negated|10|Group[782]|Clement
# nulle expression signalé |forward|trigger|negated|10|Group[782]|Clement
# nulle référence d' |forward|trigger|negated|10|Group[782]|Clement
# nulle référence de |forward|trigger|negated|10|Group[782]|Clement
# nulle référence d'un |forward|trigger|negated|10|Group[782]|Clement
# nulle référence d'une |forward|trigger|negated|10|Group[782]|Clement
# nulle référence signalé |forward|trigger|negated|10|Group[782]|Clement
# nulle reflet d' |forward|trigger|negated|10|Group[782]|Clement
# nulle reflet de |forward|trigger|negated|10|Group[782]|Clement
# nulle reflet d'un |forward|trigger|negated|10|Group[782]|Clement
# nulle reflet d'une |forward|trigger|negated|10|Group[782]|Clement
# nulle reflet signalé |forward|trigger|negated|10|Group[782]|Clement
# nulle allusion d' |forward|trigger|negated|10|Group[782]|Clement
# nulle allusion de |forward|trigger|negated|10|Group[782]|Clement
# nulle allusion d'un |forward|trigger|negated|10|Group[782]|Clement
# nulle allusion d'une |forward|trigger|negated|10|Group[782]|Clement
# nulle allusion signalé |forward|trigger|negated|10|Group[782]|Clement
# sans mention d' |forward|trigger|negated|10|Group[782]|Clement
# sans mention de |forward|trigger|negated|10|Group[782]|Clement
# sans mention d'un |forward|trigger|negated|10|Group[782]|Clement
# sans mention d'une |forward|trigger|negated|10|Group[782]|Clement
# sans mention signalé |forward|trigger|negated|10|Group[782]|Clement
# sans évocation d' |forward|trigger|negated|10|Group[782]|Clement
# sans évocation de |forward|trigger|negated|10|Group[782]|Clement
# sans évocation d'un |forward|trigger|negated|10|Group[782]|Clement
# sans évocation d'une |forward|trigger|negated|10|Group[782]|Clement
# sans évocation signalé |forward|trigger|negated|10|Group[782]|Clement
# sans notation d' |forward|trigger|negated|10|Group[782]|Clement
# sans notation de |forward|trigger|negated|10|Group[782]|Clement
# sans notation d'un |forward|trigger|negated|10|Group[782]|Clement
# sans notation d'une |forward|trigger|negated|10|Group[782]|Clement
# sans notation signalé |forward|trigger|negated|10|Group[782]|Clement
# sans signalement d' |forward|trigger|negated|10|Group[782]|Clement
# sans signalement de |forward|trigger|negated|10|Group[782]|Clement
# sans signalement d'un |forward|trigger|negated|10|Group[782]|Clement
# sans signalement d'une |forward|trigger|negated|10|Group[782]|Clement
# sans signalement signalé |forward|trigger|negated|10|Group[782]|Clement
# sans note d' |forward|trigger|negated|10|Group[782]|Clement
# sans note de |forward|trigger|negated|10|Group[782]|Clement
# sans note d'un |forward|trigger|negated|10|Group[782]|Clement
# sans note d'une |forward|trigger|negated|10|Group[782]|Clement
# sans note signalé |forward|trigger|negated|10|Group[782]|Clement
# sans expression d' |forward|trigger|negated|10|Group[782]|Clement
# sans expression de |forward|trigger|negated|10|Group[782]|Clement
# sans expression d'un |forward|trigger|negated|10|Group[782]|Clement
# sans expression d'une |forward|trigger|negated|10|Group[782]|Clement
# sans expression signalé |forward|trigger|negated|10|Group[782]|Clement
# sans référence d' |forward|trigger|negated|10|Group[782]|Clement
# sans référence de |forward|trigger|negated|10|Group[782]|Clement
# sans référence d'un |forward|trigger|negated|10|Group[782]|Clement
# sans référence d'une |forward|trigger|negated|10|Group[782]|Clement
# sans référence signalé |forward|trigger|negated|10|Group[782]|Clement
# sans reflet d' |forward|trigger|negated|10|Group[782]|Clement
# sans reflet de |forward|trigger|negated|10|Group[782]|Clement
# sans reflet d'un |forward|trigger|negated|10|Group[782]|Clement
# sans reflet d'une |forward|trigger|negated|10|Group[782]|Clement
# sans reflet signalé |forward|trigger|negated|10|Group[782]|Clement
# sans allusion d' |forward|trigger|negated|10|Group[782]|Clement
# sans allusion de |forward|trigger|negated|10|Group[782]|Clement
# sans allusion d'un |forward|trigger|negated|10|Group[782]|Clement
# sans allusion d'une |forward|trigger|negated|10|Group[782]|Clement
# sans allusion signalé |forward|trigger|negated|10|Group[782]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucune" | "nulle" | "sans" 
Var2 -> "\\w+"
Var3 -> "preuve" | "justification" | "démonstration" | "conviction" | "constatation" | "confirmation" | "assurance" |  "évidence"
Trigger_Rule -> "|forward|trigger|negated|10|Group[784]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucune \w+ preuve |forward|trigger|negated|10|Group[784]|Clement
# aucune \w+ justification |forward|trigger|negated|10|Group[784]|Clement
# aucune \w+ démonstration |forward|trigger|negated|10|Group[784]|Clement
# aucune \w+ conviction |forward|trigger|negated|10|Group[784]|Clement
# aucune \w+ constatation |forward|trigger|negated|10|Group[784]|Clement
# aucune \w+ confirmation |forward|trigger|negated|10|Group[784]|Clement
# aucune \w+ assurance |forward|trigger|negated|10|Group[784]|Clement
# aucune \w+ évidence |forward|trigger|negated|10|Group[784]|Clement
# nulle \w+ preuve |forward|trigger|negated|10|Group[784]|Clement
# nulle \w+ justification |forward|trigger|negated|10|Group[784]|Clement
# nulle \w+ démonstration |forward|trigger|negated|10|Group[784]|Clement
# nulle \w+ conviction |forward|trigger|negated|10|Group[784]|Clement
# nulle \w+ constatation |forward|trigger|negated|10|Group[784]|Clement
# nulle \w+ confirmation |forward|trigger|negated|10|Group[784]|Clement
# nulle \w+ assurance |forward|trigger|negated|10|Group[784]|Clement
# nulle \w+ évidence |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ preuve |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ justification |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ démonstration |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ conviction |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ constatation |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ confirmation |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ assurance |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ évidence |forward|trigger|negated|10|Group[784]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucun" | "nul" | "sans" 
Var2 -> "\\w+"
Var3 -> "témoignage" |"gage" | "argument" | "critère" | "signe" | "motif" | "fondement" | "stigmate"
Trigger_Rule -> "|forward|trigger|negated|10|Group[784]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun \w+ témoignage |forward|trigger|negated|10|Group[784]|Clement
# aucun \w+ gage |forward|trigger|negated|10|Group[784]|Clement
# aucun \w+ argument |forward|trigger|negated|10|Group[784]|Clement
# aucun \w+ critère |forward|trigger|negated|10|Group[784]|Clement
# aucun \w+ signe |forward|trigger|negated|10|Group[784]|Clement
# aucun \w+ motif |forward|trigger|negated|10|Group[784]|Clement
# aucun \w+ fondement |forward|trigger|negated|10|Group[784]|Clement
# aucun \w+ stigmate |forward|trigger|negated|10|Group[784]|Clement
# nul \w+ témoignage |forward|trigger|negated|10|Group[784]|Clement
# nul \w+ gage |forward|trigger|negated|10|Group[784]|Clement
# nul \w+ argument |forward|trigger|negated|10|Group[784]|Clement
# nul \w+ critère |forward|trigger|negated|10|Group[784]|Clement
# nul \w+ signe |forward|trigger|negated|10|Group[784]|Clement
# nul \w+ motif |forward|trigger|negated|10|Group[784]|Clement
# nul \w+ fondement |forward|trigger|negated|10|Group[784]|Clement
# nul \w+ stigmate |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ témoignage |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ gage |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ argument |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ critère |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ signe |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ motif |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ fondement |forward|trigger|negated|10|Group[784]|Clement
# sans \w+ stigmate |forward|trigger|negated|10|Group[784]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "pas"
Var2 -> "de"
Var3 -> "nouveau" | "récent" | "nouveauté" | "nouvelle" | "récente" | "jeune" | "nouvel"| "nouveaux" | "récents" | "nouveautés" | "nouvelles" | "récentes" | "jeunes" | "nouvels"
Trigger_Rule -> "|forward|trigger|negated|10|Group[786]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas de nouveau |forward|trigger|negated|10|Group[786]|Clement
# pas de récent |forward|trigger|negated|10|Group[786]|Clement
# pas de nouveauté |forward|trigger|negated|10|Group[786]|Clement
# pas de nouvelle |forward|trigger|negated|10|Group[786]|Clement
# pas de récente |forward|trigger|negated|10|Group[786]|Clement
# pas de jeune |forward|trigger|negated|10|Group[786]|Clement
# pas de nouvel |forward|trigger|negated|10|Group[786]|Clement
# pas de nouveaux |forward|trigger|negated|10|Group[786]|Clement
# pas de récents |forward|trigger|negated|10|Group[786]|Clement
# pas de nouveautés |forward|trigger|negated|10|Group[786]|Clement
# pas de nouvelles |forward|trigger|negated|10|Group[786]|Clement
# pas de récentes |forward|trigger|negated|10|Group[786]|Clement
# pas de jeunes |forward|trigger|negated|10|Group[786]|Clement
# pas de nouvels |forward|trigger|negated|10|Group[786]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Termin Trigger_Rule
Var1 -> "pas"
Var2 -> "\\w+" | "\\w+ \\w+" 
Var3 -> "marque" | "indice" | "manifestation" | "présage" | "syndrome" | "diagnostique" | "stigmate" | "signal" | "signe" |  "diagnostic" | "symptôme"
Termin ->  |"_s"
Trigger_Rule -> "|forward|trigger|negated|10|Group[790]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas \w+ marque |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ marque _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ indice |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ indice _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ manifestation |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ manifestation _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ présage |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ présage _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ syndrome |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ syndrome _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ diagnostique |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ diagnostique _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ stigmate |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ stigmate _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ signal |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ signal _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ signe |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ signe _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ diagnostic |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ diagnostic _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ symptôme |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ symptôme _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ marque |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ marque _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ indice |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ indice _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ manifestation |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ manifestation _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ présage |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ présage _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ syndrome |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ syndrome _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ diagnostique |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ diagnostique _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ stigmate |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ stigmate _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ signal |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ signal _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ signe |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ signe _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ diagnostic |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ diagnostic _s |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ symptôme |forward|trigger|negated|10|Group[790]|Clement
# pas \w+ \w+ symptôme _s |forward|trigger|negated|10|Group[790]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "pas"
Var2 -> "de problème" | "d'ennui" | "de souci" | "de complication" | "de dysfonctionnement" | "de disfonctionnement" | "de soucis" | "de tracas" | "d'incident"
Var3 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[794]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas de problème avec |forward|trigger|negated|10|Group[794]|Clement
# pas d'ennui avec |forward|trigger|negated|10|Group[794]|Clement
# pas de souci avec |forward|trigger|negated|10|Group[794]|Clement
# pas de complication avec |forward|trigger|negated|10|Group[794]|Clement
# pas de dysfonctionnement avec |forward|trigger|negated|10|Group[794]|Clement
# pas de disfonctionnement avec |forward|trigger|negated|10|Group[794]|Clement
# pas de soucis avec |forward|trigger|negated|10|Group[794]|Clement
# pas de tracas avec |forward|trigger|negated|10|Group[794]|Clement
# pas d'incident avec |forward|trigger|negated|10|Group[794]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucun" | "nul" | "sans" 
Var2 -> "problème" | "ennui" | "souci" | "de complication" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "tracas" | "incident"
Var3 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[794]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun problème avec |forward|trigger|negated|10|Group[794]|Clement
# aucun ennui avec |forward|trigger|negated|10|Group[794]|Clement
# aucun souci avec |forward|trigger|negated|10|Group[794]|Clement
# aucun de complication avec |forward|trigger|negated|10|Group[794]|Clement
# aucun dysfonctionnement avec |forward|trigger|negated|10|Group[794]|Clement
# aucun disfonctionnement avec |forward|trigger|negated|10|Group[794]|Clement
# aucun soucis avec |forward|trigger|negated|10|Group[794]|Clement
# aucun tracas avec |forward|trigger|negated|10|Group[794]|Clement
# aucun incident avec |forward|trigger|negated|10|Group[794]|Clement
# nul problème avec |forward|trigger|negated|10|Group[794]|Clement
# nul ennui avec |forward|trigger|negated|10|Group[794]|Clement
# nul souci avec |forward|trigger|negated|10|Group[794]|Clement
# nul de complication avec |forward|trigger|negated|10|Group[794]|Clement
# nul dysfonctionnement avec |forward|trigger|negated|10|Group[794]|Clement
# nul disfonctionnement avec |forward|trigger|negated|10|Group[794]|Clement
# nul soucis avec |forward|trigger|negated|10|Group[794]|Clement
# nul tracas avec |forward|trigger|negated|10|Group[794]|Clement
# nul incident avec |forward|trigger|negated|10|Group[794]|Clement
# sans problème avec |forward|trigger|negated|10|Group[794]|Clement
# sans ennui avec |forward|trigger|negated|10|Group[794]|Clement
# sans souci avec |forward|trigger|negated|10|Group[794]|Clement
# sans de complication avec |forward|trigger|negated|10|Group[794]|Clement
# sans dysfonctionnement avec |forward|trigger|negated|10|Group[794]|Clement
# sans disfonctionnement avec |forward|trigger|negated|10|Group[794]|Clement
# sans soucis avec |forward|trigger|negated|10|Group[794]|Clement
# sans tracas avec |forward|trigger|negated|10|Group[794]|Clement
# sans incident avec |forward|trigger|negated|10|Group[794]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucune"| "nulle" | "sans" 
Var2 -> "complication"
Var3 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[794]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucune complication avec |forward|trigger|negated|10|Group[794]|Clement
# nulle complication avec |forward|trigger|negated|10|Group[794]|Clement
# sans complication avec |forward|trigger|negated|10|Group[794]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pas" | "non"
Var2 -> "récurrent" | "séquentiel" | "répétitif" | "intermittent" | "pérenne" | "périodique" | "cyclique" | "répété"
Trigger_Rule -> "|backward|trigger|negated|10|Group[798]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas récurrent |backward|trigger|negated|10|Group[798]|Clement
# pas séquentiel |backward|trigger|negated|10|Group[798]|Clement
# pas répétitif |backward|trigger|negated|10|Group[798]|Clement
# pas intermittent |backward|trigger|negated|10|Group[798]|Clement
# pas pérenne |backward|trigger|negated|10|Group[798]|Clement
# pas périodique |backward|trigger|negated|10|Group[798]|Clement
# pas cyclique |backward|trigger|negated|10|Group[798]|Clement
# pas répété |backward|trigger|negated|10|Group[798]|Clement
# non récurrent |backward|trigger|negated|10|Group[798]|Clement
# non séquentiel |backward|trigger|negated|10|Group[798]|Clement
# non répétitif |backward|trigger|negated|10|Group[798]|Clement
# non intermittent |backward|trigger|negated|10|Group[798]|Clement
# non pérenne |backward|trigger|negated|10|Group[798]|Clement
# non périodique |backward|trigger|negated|10|Group[798]|Clement
# non cyclique |backward|trigger|negated|10|Group[798]|Clement
# non répété |backward|trigger|negated|10|Group[798]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "non" | "pas"
Var2 -> "rapporté" | "révélé" | "exposé" | "signalé" |  "dévoilé"
Trigger_Rule -> "|backward|trigger|negated|10|Group[802]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# non rapporté |backward|trigger|negated|10|Group[802]|Clement
# non révélé |backward|trigger|negated|10|Group[802]|Clement
# non exposé |backward|trigger|negated|10|Group[802]|Clement
# non signalé |backward|trigger|negated|10|Group[802]|Clement
# non dévoilé |backward|trigger|negated|10|Group[802]|Clement
# pas rapporté |backward|trigger|negated|10|Group[802]|Clement
# pas révélé |backward|trigger|negated|10|Group[802]|Clement
# pas exposé |backward|trigger|negated|10|Group[802]|Clement
# pas signalé |backward|trigger|negated|10|Group[802]|Clement
# pas dévoilé |backward|trigger|negated|10|Group[802]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "pas"
Var2 -> "de"
Var3 -> "résidu" | "reliquat" | "déchet"
Trigger_Rule -> "|forward|trigger|negated|10|Group[804]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas de résidu |forward|trigger|negated|10|Group[804]|Clement
# pas de reliquat |forward|trigger|negated|10|Group[804]|Clement
# pas de déchet |forward|trigger|negated|10|Group[804]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "non" | "pas"
Var2 -> "significatif" | "visible" | "diagnostiqué" | "identifié"
Trigger_Rule -> "|backward|trigger|negated|10|Group[810]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# non significatif |backward|trigger|negated|10|Group[810]|Clement
# non visible |backward|trigger|negated|10|Group[810]|Clement
# non diagnostiqué |backward|trigger|negated|10|Group[810]|Clement
# non identifié |backward|trigger|negated|10|Group[810]|Clement
# pas significatif |backward|trigger|negated|10|Group[810]|Clement
# pas visible |backward|trigger|negated|10|Group[810]|Clement
# pas diagnostiqué |backward|trigger|negated|10|Group[810]|Clement
# pas identifié |backward|trigger|negated|10|Group[810]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "aucun" | "aucune" | "nul" | "nulle" | "sans" 
Trigger_Rule -> "|forward|trigger|negated|10|Group[829]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun |forward|trigger|negated|10|Group[829]|Clement
# aucune |forward|trigger|negated|10|Group[829]|Clement
# nul |forward|trigger|negated|10|Group[829]|Clement
# nulle |forward|trigger|negated|10|Group[829]|Clement
# sans |forward|trigger|negated|10|Group[829]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "ni"
Var2 -> "tout" | "tous" | "toute" | "toutes"
Trigger_Rule -> "|forward|trigger|negated|10|Group[831]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ni tout |forward|trigger|negated|10|Group[831]|Clement
# ni tous |forward|trigger|negated|10|Group[831]|Clement
# ni toute |forward|trigger|negated|10|Group[831]|Clement
# ni toutes |forward|trigger|negated|10|Group[831]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "ni"
Var2 -> "aucun" | "aucun" | "nul" | "nulle"  | "sans" 
Trigger_Rule -> "|forward|trigger|negated|10|Group[833]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ni aucun |forward|trigger|negated|10|Group[833]|Clement
# ni aucun |forward|trigger|negated|10|Group[833]|Clement
# ni nul |forward|trigger|negated|10|Group[833]|Clement
# ni nulle |forward|trigger|negated|10|Group[833]|Clement
# ni sans |forward|trigger|negated|10|Group[833]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "ni"
Trigger_Rule -> "|forward|trigger|negated|10|Group[835]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ni |forward|trigger|negated|10|Group[835]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "ne"
Var2 -> "pas"
Var3 -> "apparaître" | "survenir" | "ressortir" | "naître" | "transparaître" | "se manifester" | "se révéler" | "se dévoiler"
Trigger_Rule -> "|backward|trigger|negated|10|Group[839]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne pas apparaître |backward|trigger|negated|10|Group[839]|Clement
# ne pas survenir |backward|trigger|negated|10|Group[839]|Clement
# ne pas ressortir |backward|trigger|negated|10|Group[839]|Clement
# ne pas naître |backward|trigger|negated|10|Group[839]|Clement
# ne pas transparaître |backward|trigger|negated|10|Group[839]|Clement
# ne pas se manifester |backward|trigger|negated|10|Group[839]|Clement
# ne pas se révéler |backward|trigger|negated|10|Group[839]|Clement
# ne pas se dévoiler |backward|trigger|negated|10|Group[839]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "non" | "pas"
Var2 -> "associé" | "réuni" | "lié" | "groupé" | "composé" | "mélangé" | "mêlé" | "assorti" | "joint" | "relié" | "conjoint"
Var3 -> "à" | "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[843]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# non associé à |forward|trigger|negated|10|Group[843]|Clement
# non associé avec |forward|trigger|negated|10|Group[843]|Clement
# non réuni à |forward|trigger|negated|10|Group[843]|Clement
# non réuni avec |forward|trigger|negated|10|Group[843]|Clement
# non lié à |forward|trigger|negated|10|Group[843]|Clement
# non lié avec |forward|trigger|negated|10|Group[843]|Clement
# non groupé à |forward|trigger|negated|10|Group[843]|Clement
# non groupé avec |forward|trigger|negated|10|Group[843]|Clement
# non composé à |forward|trigger|negated|10|Group[843]|Clement
# non composé avec |forward|trigger|negated|10|Group[843]|Clement
# non mélangé à |forward|trigger|negated|10|Group[843]|Clement
# non mélangé avec |forward|trigger|negated|10|Group[843]|Clement
# non mêlé à |forward|trigger|negated|10|Group[843]|Clement
# non mêlé avec |forward|trigger|negated|10|Group[843]|Clement
# non assorti à |forward|trigger|negated|10|Group[843]|Clement
# non assorti avec |forward|trigger|negated|10|Group[843]|Clement
# non joint à |forward|trigger|negated|10|Group[843]|Clement
# non joint avec |forward|trigger|negated|10|Group[843]|Clement
# non relié à |forward|trigger|negated|10|Group[843]|Clement
# non relié avec |forward|trigger|negated|10|Group[843]|Clement
# non conjoint à |forward|trigger|negated|10|Group[843]|Clement
# non conjoint avec |forward|trigger|negated|10|Group[843]|Clement
# pas associé à |forward|trigger|negated|10|Group[843]|Clement
# pas associé avec |forward|trigger|negated|10|Group[843]|Clement
# pas réuni à |forward|trigger|negated|10|Group[843]|Clement
# pas réuni avec |forward|trigger|negated|10|Group[843]|Clement
# pas lié à |forward|trigger|negated|10|Group[843]|Clement
# pas lié avec |forward|trigger|negated|10|Group[843]|Clement
# pas groupé à |forward|trigger|negated|10|Group[843]|Clement
# pas groupé avec |forward|trigger|negated|10|Group[843]|Clement
# pas composé à |forward|trigger|negated|10|Group[843]|Clement
# pas composé avec |forward|trigger|negated|10|Group[843]|Clement
# pas mélangé à |forward|trigger|negated|10|Group[843]|Clement
# pas mélangé avec |forward|trigger|negated|10|Group[843]|Clement
# pas mêlé à |forward|trigger|negated|10|Group[843]|Clement
# pas mêlé avec |forward|trigger|negated|10|Group[843]|Clement
# pas assorti à |forward|trigger|negated|10|Group[843]|Clement
# pas assorti avec |forward|trigger|negated|10|Group[843]|Clement
# pas joint à |forward|trigger|negated|10|Group[843]|Clement
# pas joint avec |forward|trigger|negated|10|Group[843]|Clement
# pas relié à |forward|trigger|negated|10|Group[843]|Clement
# pas relié avec |forward|trigger|negated|10|Group[843]|Clement
# pas conjoint à |forward|trigger|negated|10|Group[843]|Clement
# pas conjoint avec |forward|trigger|negated|10|Group[843]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1  Var2 Trigger_Rule
Var1 -> "pas" | "non"
Var2 -> "donné" | "prescrit" | "administré" | "prodigué" | "appliqué" | "fait" | "indiqué" | "proposé" | "employé" | "inoculé"
Trigger_Rule -> "|backward|pseudo|negated|10|Group[845]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas donné |backward|pseudo|negated|10|Group[845]|Clement
# pas prescrit |backward|pseudo|negated|10|Group[845]|Clement
# pas administré |backward|pseudo|negated|10|Group[845]|Clement
# pas prodigué |backward|pseudo|negated|10|Group[845]|Clement
# pas appliqué |backward|pseudo|negated|10|Group[845]|Clement
# pas fait |backward|pseudo|negated|10|Group[845]|Clement
# pas indiqué |backward|pseudo|negated|10|Group[845]|Clement
# pas proposé |backward|pseudo|negated|10|Group[845]|Clement
# pas employé |backward|pseudo|negated|10|Group[845]|Clement
# pas inoculé |backward|pseudo|negated|10|Group[845]|Clement
# non donné |backward|pseudo|negated|10|Group[845]|Clement
# non prescrit |backward|pseudo|negated|10|Group[845]|Clement
# non administré |backward|pseudo|negated|10|Group[845]|Clement
# non prodigué |backward|pseudo|negated|10|Group[845]|Clement
# non appliqué |backward|pseudo|negated|10|Group[845]|Clement
# non fait |backward|pseudo|negated|10|Group[845]|Clement
# non indiqué |backward|pseudo|negated|10|Group[845]|Clement
# non proposé |backward|pseudo|negated|10|Group[845]|Clement
# non employé |backward|pseudo|negated|10|Group[845]|Clement
# non inoculé |backward|pseudo|negated|10|Group[845]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "pas"
Var2 -> "été"
Var3 -> "exclu" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[846]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas été exclu |backward|trigger|uncertain|30|Group[846]|Clement
# pas été rejeté |backward|trigger|uncertain|30|Group[846]|Clement
# pas été éliminé |backward|trigger|uncertain|30|Group[846]|Clement
# pas été proscrit |backward|trigger|uncertain|30|Group[846]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pas"
Var2 -> "causer" | "susciter" | "amener" | "entraîner" | "procurer" | "provoquer" | "occasionner" | "donner" | "engendrer" | "créer" | "être cause de" | "déclencher"
Trigger_Rule -> "|both|pseudo|negated|10|Group[847]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas causer |both|pseudo|negated|10|Group[847]|Clement
# pas susciter |both|pseudo|negated|10|Group[847]|Clement
# pas amener |both|pseudo|negated|10|Group[847]|Clement
# pas entraîner |both|pseudo|negated|10|Group[847]|Clement
# pas procurer |both|pseudo|negated|10|Group[847]|Clement
# pas provoquer |both|pseudo|negated|10|Group[847]|Clement
# pas occasionner |both|pseudo|negated|10|Group[847]|Clement
# pas donner |both|pseudo|negated|10|Group[847]|Clement
# pas engendrer |both|pseudo|negated|10|Group[847]|Clement
# pas créer |both|pseudo|negated|10|Group[847]|Clement
# pas être cause de |both|pseudo|negated|10|Group[847]|Clement
# pas déclencher |both|pseudo|negated|10|Group[847]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "pas"
Var2 -> "certain"
Var3 -> "que" | "qu'"
Trigger_Rule -> "|both|pseudo|negated|10|Group[848]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas certain que |both|pseudo|negated|10|Group[848]|Clement
# pas certain qu' |both|pseudo|negated|10|Group[848]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "pas"
Var2 -> "se"
Var3 -> "plaindre"
Var4 -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[850]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas se plaindre d' |forward|trigger|negated|10|Group[850]|Clement
# pas se plaindre de |forward|trigger|negated|10|Group[850]|Clement
# pas se plaindre d'un |forward|trigger|negated|10|Group[850]|Clement
# pas se plaindre d'une |forward|trigger|negated|10|Group[850]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pas" 
Var2 -> "démontrer" | "témoigner" | "prouver" | "attester" | "montrer" | "convaincre" | "indiquer" | "illustrer" | "établir" | "justifier" | "révéler" | "dévoiler" | "déduire" | "conclure" | "garantir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[854]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas démontrer |forward|trigger|negated|10|Group[854]|Clement
# pas témoigner |forward|trigger|negated|10|Group[854]|Clement
# pas prouver |forward|trigger|negated|10|Group[854]|Clement
# pas attester |forward|trigger|negated|10|Group[854]|Clement
# pas montrer |forward|trigger|negated|10|Group[854]|Clement
# pas convaincre |forward|trigger|negated|10|Group[854]|Clement
# pas indiquer |forward|trigger|negated|10|Group[854]|Clement
# pas illustrer |forward|trigger|negated|10|Group[854]|Clement
# pas établir |forward|trigger|negated|10|Group[854]|Clement
# pas justifier |forward|trigger|negated|10|Group[854]|Clement
# pas révéler |forward|trigger|negated|10|Group[854]|Clement
# pas dévoiler |forward|trigger|negated|10|Group[854]|Clement
# pas déduire |forward|trigger|negated|10|Group[854]|Clement
# pas conclure |forward|trigger|negated|10|Group[854]|Clement
# pas garantir |forward|trigger|negated|10|Group[854]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "ne"
Var2 -> "pas"
Var3 -> "exposer" | "présenter" | "révéler" | "afficher" | "exprimer" | "signaler" | "signifier" | "annoncer"| "divulguer" | "déceler" | "dire" | "exposer" | "démasquer" | "afficher" | "déclarer"

Trigger_Rule -> "|forward|trigger|negated|10|Group[857]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne pas exposer |forward|trigger|negated|10|Group[857]|Clement
# ne pas présenter |forward|trigger|negated|10|Group[857]|Clement
# ne pas révéler |forward|trigger|negated|10|Group[857]|Clement
# ne pas afficher |forward|trigger|negated|10|Group[857]|Clement
# ne pas exprimer |forward|trigger|negated|10|Group[857]|Clement
# ne pas signaler |forward|trigger|negated|10|Group[857]|Clement
# ne pas signifier |forward|trigger|negated|10|Group[857]|Clement
# ne pas annoncer |forward|trigger|negated|10|Group[857]|Clement
# ne pas divulguer |forward|trigger|negated|10|Group[857]|Clement
# ne pas déceler |forward|trigger|negated|10|Group[857]|Clement
# ne pas dire |forward|trigger|negated|10|Group[857]|Clement
# ne pas exposer |forward|trigger|negated|10|Group[857]|Clement
# ne pas démasquer |forward|trigger|negated|10|Group[857]|Clement
# ne pas afficher |forward|trigger|negated|10|Group[857]|Clement
# ne pas déclarer |forward|trigger|negated|10|Group[857]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pas"
Var2 -> "augmenter" | "grandir" | "se développer" | "s'accroître" | "s'allonger" | "s'élargir" | "se propager" | "s'amplifier" | "grossir" | "se généraliser" | "s'agrandir"
Trigger_Rule -> "|both|pseudo|negated|10|Group[859]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas augmenter |both|pseudo|negated|10|Group[859]|Clement
# pas grandir |both|pseudo|negated|10|Group[859]|Clement
# pas se développer |both|pseudo|negated|10|Group[859]|Clement
# pas s'accroître |both|pseudo|negated|10|Group[859]|Clement
# pas s'allonger |both|pseudo|negated|10|Group[859]|Clement
# pas s'élargir |both|pseudo|negated|10|Group[859]|Clement
# pas se propager |both|pseudo|negated|10|Group[859]|Clement
# pas s'amplifier |both|pseudo|negated|10|Group[859]|Clement
# pas grossir |both|pseudo|negated|10|Group[859]|Clement
# pas se généraliser |both|pseudo|negated|10|Group[859]|Clement
# pas s'agrandir |both|pseudo|negated|10|Group[859]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "ne"
Var2 -> "pas" | "plus"
Var3 -> "ressentir" | "sentir" | "endurer" | "souffrir" | "subir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[860]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne pas ressentir |forward|trigger|negated|10|Group[860]|Clement
# ne pas sentir |forward|trigger|negated|10|Group[860]|Clement
# ne pas endurer |forward|trigger|negated|10|Group[860]|Clement
# ne pas souffrir |forward|trigger|negated|10|Group[860]|Clement
# ne pas subir |forward|trigger|negated|10|Group[860]|Clement
# ne plus ressentir |forward|trigger|negated|10|Group[860]|Clement
# ne plus sentir |forward|trigger|negated|10|Group[860]|Clement
# ne plus endurer |forward|trigger|negated|10|Group[860]|Clement
# ne plus souffrir |forward|trigger|negated|10|Group[860]|Clement
# ne plus subir |forward|trigger|negated|10|Group[860]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Article  Trigger_Rule
Var1 -> "ne"
Var2 -> "pas"
Var3 -> "avoir"
Article -> "l'" |"le" | "la" | "un" | "une" | "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[864]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne pas avoir l' |forward|trigger|negated|10|Group[864]|Clement
# ne pas avoir le |forward|trigger|negated|10|Group[864]|Clement
# ne pas avoir la |forward|trigger|negated|10|Group[864]|Clement
# ne pas avoir un |forward|trigger|negated|10|Group[864]|Clement
# ne pas avoir une |forward|trigger|negated|10|Group[864]|Clement
# ne pas avoir d' |forward|trigger|negated|10|Group[864]|Clement
# ne pas avoir de |forward|trigger|negated|10|Group[864]|Clement
# ne pas avoir d'un |forward|trigger|negated|10|Group[864]|Clement
# ne pas avoir d'une |forward|trigger|negated|10|Group[864]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pas"
Var2 -> "intéressé" | "attaché" | "concerné" | "intrigué" | "attiré" | "touché" | "curieux" | "affecté" | "motivé"
Trigger_Rule -> "|both|pseudo|negated|10|Group[870]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas intéressé |both|pseudo|negated|10|Group[870]|Clement
# pas attaché |both|pseudo|negated|10|Group[870]|Clement
# pas concerné |both|pseudo|negated|10|Group[870]|Clement
# pas intrigué |both|pseudo|negated|10|Group[870]|Clement
# pas attiré |both|pseudo|negated|10|Group[870]|Clement
# pas touché |both|pseudo|negated|10|Group[870]|Clement
# pas curieux |both|pseudo|negated|10|Group[870]|Clement
# pas affecté |both|pseudo|negated|10|Group[870]|Clement
# pas motivé |both|pseudo|negated|10|Group[870]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pas"
Var2 -> "dedans"
Trigger_Rule -> "|forward|trigger|negated|10|Group[871]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas dedans |forward|trigger|negated|10|Group[871]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "pas"
Var2 -> "connu"
Var3 -> "pour"
Var4 -> "avoir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[875]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas connu pour avoir |forward|trigger|negated|10|Group[875]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pas"
Var2 -> "sur" | "sure" | "sûr" | "sûre" |"nécessairement" | "seulement" | "obligatoirement" | "forcément" | "automatiquement"
Trigger_Rule -> "|both|pseudo|negated|10|Group[877]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas sur |both|pseudo|negated|10|Group[877]|Clement
# pas sure |both|pseudo|negated|10|Group[877]|Clement
# pas sûr |both|pseudo|negated|10|Group[877]|Clement
# pas sûre |both|pseudo|negated|10|Group[877]|Clement
# pas nécessairement |both|pseudo|negated|10|Group[877]|Clement
# pas seulement |both|pseudo|negated|10|Group[877]|Clement
# pas obligatoirement |both|pseudo|negated|10|Group[877]|Clement
# pas forcément |both|pseudo|negated|10|Group[877]|Clement
# pas automatiquement |both|pseudo|negated|10|Group[877]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Trigger_Rule
Var1 -> "pas"
Var2 -> "exclu" | "rejeté" | "éliminé" | "proscrit"
Termin -> "_"|"_s" |"_e" |"_es"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[882]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas exclu _ |backward|trigger|uncertain|30|Group[882]|Clement
# pas exclu _s |backward|trigger|uncertain|30|Group[882]|Clement
# pas exclu _e |backward|trigger|uncertain|30|Group[882]|Clement
# pas exclu _es |backward|trigger|uncertain|30|Group[882]|Clement
# pas rejeté _ |backward|trigger|uncertain|30|Group[882]|Clement
# pas rejeté _s |backward|trigger|uncertain|30|Group[882]|Clement
# pas rejeté _e |backward|trigger|uncertain|30|Group[882]|Clement
# pas rejeté _es |backward|trigger|uncertain|30|Group[882]|Clement
# pas éliminé _ |backward|trigger|uncertain|30|Group[882]|Clement
# pas éliminé _s |backward|trigger|uncertain|30|Group[882]|Clement
# pas éliminé _e |backward|trigger|uncertain|30|Group[882]|Clement
# pas éliminé _es |backward|trigger|uncertain|30|Group[882]|Clement
# pas proscrit _ |backward|trigger|uncertain|30|Group[882]|Clement
# pas proscrit _s |backward|trigger|uncertain|30|Group[882]|Clement
# pas proscrit _e |backward|trigger|uncertain|30|Group[882]|Clement
# pas proscrit _es |backward|trigger|uncertain|30|Group[882]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pas"
Var2 -> "vu"
Trigger_Rule -> "|forward|trigger|negated|10|Group[883]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas vu |forward|trigger|negated|10|Group[883]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pas"
Var2 -> "arrêter"
Trigger_Rule -> "|both|pseudo|negated|10|Group[885]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas arrêter |both|pseudo|negated|10|Group[885]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "ne"
Var2 -> "pas"
Var3 -> "être"
Trigger_Rule -> "|forward|trigger|negated|10|Group[886]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne pas être |forward|trigger|negated|10|Group[886]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> "noté" | "constaté" 
Trigger_Rule -> "|both|termination|historical|30|Group[888, 889]|Clement"|"|both|termination|nonpatient|30|Group[888, 889]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# noté |both|termination|historical|30|Group[888, 889]|Clement
# noté |both|termination|nonpatient|30|Group[888, 889]|Clement
# constaté |both|termination|historical|30|Group[888, 889]|Clement
# constaté |both|termination|nonpatient|30|Group[888, 889]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "ne"
Var2 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[891, 890]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne pas |forward|trigger|negated|10|Group[891, 890]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "maintenant" | "actuellement" | "aujourd'hui" | "à présent" | "dèsdésormais" | "présentement"
Var2 -> "résolu" | "solutionné" | "traité"
Trigger_Rule -> "|backward|trigger|negated|10|Group[892, 893]|Clement"|"|forward|termination|negated|10|Group[892, 893]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# maintenant résolu |backward|trigger|negated|10|Group[892, 893]|Clement
# maintenant résolu |forward|termination|negated|10|Group[892, 893]|Clement
# maintenant solutionné |backward|trigger|negated|10|Group[892, 893]|Clement
# maintenant solutionné |forward|termination|negated|10|Group[892, 893]|Clement
# maintenant traité |backward|trigger|negated|10|Group[892, 893]|Clement
# maintenant traité |forward|termination|negated|10|Group[892, 893]|Clement
# actuellement résolu |backward|trigger|negated|10|Group[892, 893]|Clement
# actuellement résolu |forward|termination|negated|10|Group[892, 893]|Clement
# actuellement solutionné |backward|trigger|negated|10|Group[892, 893]|Clement
# actuellement solutionné |forward|termination|negated|10|Group[892, 893]|Clement
# actuellement traité |backward|trigger|negated|10|Group[892, 893]|Clement
# actuellement traité |forward|termination|negated|10|Group[892, 893]|Clement
# aujourd'hui résolu |backward|trigger|negated|10|Group[892, 893]|Clement
# aujourd'hui résolu |forward|termination|negated|10|Group[892, 893]|Clement
# aujourd'hui solutionné |backward|trigger|negated|10|Group[892, 893]|Clement
# aujourd'hui solutionné |forward|termination|negated|10|Group[892, 893]|Clement
# aujourd'hui traité |backward|trigger|negated|10|Group[892, 893]|Clement
# aujourd'hui traité |forward|termination|negated|10|Group[892, 893]|Clement
# à présent résolu |backward|trigger|negated|10|Group[892, 893]|Clement
# à présent résolu |forward|termination|negated|10|Group[892, 893]|Clement
# à présent solutionné |backward|trigger|negated|10|Group[892, 893]|Clement
# à présent solutionné |forward|termination|negated|10|Group[892, 893]|Clement
# à présent traité |backward|trigger|negated|10|Group[892, 893]|Clement
# à présent traité |forward|termination|negated|10|Group[892, 893]|Clement
# dèsdésormais résolu |backward|trigger|negated|10|Group[892, 893]|Clement
# dèsdésormais résolu |forward|termination|negated|10|Group[892, 893]|Clement
# dèsdésormais solutionné |backward|trigger|negated|10|Group[892, 893]|Clement
# dèsdésormais solutionné |forward|termination|negated|10|Group[892, 893]|Clement
# dèsdésormais traité |backward|trigger|negated|10|Group[892, 893]|Clement
# dèsdésormais traité |forward|termination|negated|10|Group[892, 893]|Clement
# présentement résolu |backward|trigger|negated|10|Group[892, 893]|Clement
# présentement résolu |forward|termination|negated|10|Group[892, 893]|Clement
# présentement solutionné |backward|trigger|negated|10|Group[892, 893]|Clement
# présentement solutionné |forward|termination|negated|10|Group[892, 893]|Clement
# présentement traité |backward|trigger|negated|10|Group[892, 893]|Clement
# présentement traité |forward|termination|negated|10|Group[892, 893]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Termin Var2 Trigger_Rule
Var1 -> "origine" | "début" | "commencement" | "provenance" | "cause" | "formation" | "base" | "fondement" | "prédéterminant" | "raison" | "départ" | "étiologie" | "causalité" | "source" | "point de départ" | "prétexte" | "déclencheur" | "mobile" | "explication"
Termin -> "_s" | "_"
Var2 -> "pour" | "de" | "d'"
Trigger_Rule -> "|forward|termination|negated|10|Group[896]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# origine _s pour |forward|termination|negated|10|Group[896]|Clement
# origine _s de |forward|termination|negated|10|Group[896]|Clement
# origine _s d' |forward|termination|negated|10|Group[896]|Clement
# origine _ pour |forward|termination|negated|10|Group[896]|Clement
# origine _ de |forward|termination|negated|10|Group[896]|Clement
# origine _ d' |forward|termination|negated|10|Group[896]|Clement
# début _s pour |forward|termination|negated|10|Group[896]|Clement
# début _s de |forward|termination|negated|10|Group[896]|Clement
# début _s d' |forward|termination|negated|10|Group[896]|Clement
# début _ pour |forward|termination|negated|10|Group[896]|Clement
# début _ de |forward|termination|negated|10|Group[896]|Clement
# début _ d' |forward|termination|negated|10|Group[896]|Clement
# commencement _s pour |forward|termination|negated|10|Group[896]|Clement
# commencement _s de |forward|termination|negated|10|Group[896]|Clement
# commencement _s d' |forward|termination|negated|10|Group[896]|Clement
# commencement _ pour |forward|termination|negated|10|Group[896]|Clement
# commencement _ de |forward|termination|negated|10|Group[896]|Clement
# commencement _ d' |forward|termination|negated|10|Group[896]|Clement
# provenance _s pour |forward|termination|negated|10|Group[896]|Clement
# provenance _s de |forward|termination|negated|10|Group[896]|Clement
# provenance _s d' |forward|termination|negated|10|Group[896]|Clement
# provenance _ pour |forward|termination|negated|10|Group[896]|Clement
# provenance _ de |forward|termination|negated|10|Group[896]|Clement
# provenance _ d' |forward|termination|negated|10|Group[896]|Clement
# cause _s pour |forward|termination|negated|10|Group[896]|Clement
# cause _s de |forward|termination|negated|10|Group[896]|Clement
# cause _s d' |forward|termination|negated|10|Group[896]|Clement
# cause _ pour |forward|termination|negated|10|Group[896]|Clement
# cause _ de |forward|termination|negated|10|Group[896]|Clement
# cause _ d' |forward|termination|negated|10|Group[896]|Clement
# formation _s pour |forward|termination|negated|10|Group[896]|Clement
# formation _s de |forward|termination|negated|10|Group[896]|Clement
# formation _s d' |forward|termination|negated|10|Group[896]|Clement
# formation _ pour |forward|termination|negated|10|Group[896]|Clement
# formation _ de |forward|termination|negated|10|Group[896]|Clement
# formation _ d' |forward|termination|negated|10|Group[896]|Clement
# base _s pour |forward|termination|negated|10|Group[896]|Clement
# base _s de |forward|termination|negated|10|Group[896]|Clement
# base _s d' |forward|termination|negated|10|Group[896]|Clement
# base _ pour |forward|termination|negated|10|Group[896]|Clement
# base _ de |forward|termination|negated|10|Group[896]|Clement
# base _ d' |forward|termination|negated|10|Group[896]|Clement
# fondement _s pour |forward|termination|negated|10|Group[896]|Clement
# fondement _s de |forward|termination|negated|10|Group[896]|Clement
# fondement _s d' |forward|termination|negated|10|Group[896]|Clement
# fondement _ pour |forward|termination|negated|10|Group[896]|Clement
# fondement _ de |forward|termination|negated|10|Group[896]|Clement
# fondement _ d' |forward|termination|negated|10|Group[896]|Clement
# prédéterminant _s pour |forward|termination|negated|10|Group[896]|Clement
# prédéterminant _s de |forward|termination|negated|10|Group[896]|Clement
# prédéterminant _s d' |forward|termination|negated|10|Group[896]|Clement
# prédéterminant _ pour |forward|termination|negated|10|Group[896]|Clement
# prédéterminant _ de |forward|termination|negated|10|Group[896]|Clement
# prédéterminant _ d' |forward|termination|negated|10|Group[896]|Clement
# raison _s pour |forward|termination|negated|10|Group[896]|Clement
# raison _s de |forward|termination|negated|10|Group[896]|Clement
# raison _s d' |forward|termination|negated|10|Group[896]|Clement
# raison _ pour |forward|termination|negated|10|Group[896]|Clement
# raison _ de |forward|termination|negated|10|Group[896]|Clement
# raison _ d' |forward|termination|negated|10|Group[896]|Clement
# départ _s pour |forward|termination|negated|10|Group[896]|Clement
# départ _s de |forward|termination|negated|10|Group[896]|Clement
# départ _s d' |forward|termination|negated|10|Group[896]|Clement
# départ _ pour |forward|termination|negated|10|Group[896]|Clement
# départ _ de |forward|termination|negated|10|Group[896]|Clement
# départ _ d' |forward|termination|negated|10|Group[896]|Clement
# étiologie _s pour |forward|termination|negated|10|Group[896]|Clement
# étiologie _s de |forward|termination|negated|10|Group[896]|Clement
# étiologie _s d' |forward|termination|negated|10|Group[896]|Clement
# étiologie _ pour |forward|termination|negated|10|Group[896]|Clement
# étiologie _ de |forward|termination|negated|10|Group[896]|Clement
# étiologie _ d' |forward|termination|negated|10|Group[896]|Clement
# causalité _s pour |forward|termination|negated|10|Group[896]|Clement
# causalité _s de |forward|termination|negated|10|Group[896]|Clement
# causalité _s d' |forward|termination|negated|10|Group[896]|Clement
# causalité _ pour |forward|termination|negated|10|Group[896]|Clement
# causalité _ de |forward|termination|negated|10|Group[896]|Clement
# causalité _ d' |forward|termination|negated|10|Group[896]|Clement
# source _s pour |forward|termination|negated|10|Group[896]|Clement
# source _s de |forward|termination|negated|10|Group[896]|Clement
# source _s d' |forward|termination|negated|10|Group[896]|Clement
# source _ pour |forward|termination|negated|10|Group[896]|Clement
# source _ de |forward|termination|negated|10|Group[896]|Clement
# source _ d' |forward|termination|negated|10|Group[896]|Clement
# point de départ _s pour |forward|termination|negated|10|Group[896]|Clement
# point de départ _s de |forward|termination|negated|10|Group[896]|Clement
# point de départ _s d' |forward|termination|negated|10|Group[896]|Clement
# point de départ _ pour |forward|termination|negated|10|Group[896]|Clement
# point de départ _ de |forward|termination|negated|10|Group[896]|Clement
# point de départ _ d' |forward|termination|negated|10|Group[896]|Clement
# prétexte _s pour |forward|termination|negated|10|Group[896]|Clement
# prétexte _s de |forward|termination|negated|10|Group[896]|Clement
# prétexte _s d' |forward|termination|negated|10|Group[896]|Clement
# prétexte _ pour |forward|termination|negated|10|Group[896]|Clement
# prétexte _ de |forward|termination|negated|10|Group[896]|Clement
# prétexte _ d' |forward|termination|negated|10|Group[896]|Clement
# déclencheur _s pour |forward|termination|negated|10|Group[896]|Clement
# déclencheur _s de |forward|termination|negated|10|Group[896]|Clement
# déclencheur _s d' |forward|termination|negated|10|Group[896]|Clement
# déclencheur _ pour |forward|termination|negated|10|Group[896]|Clement
# déclencheur _ de |forward|termination|negated|10|Group[896]|Clement
# déclencheur _ d' |forward|termination|negated|10|Group[896]|Clement
# mobile _s pour |forward|termination|negated|10|Group[896]|Clement
# mobile _s de |forward|termination|negated|10|Group[896]|Clement
# mobile _s d' |forward|termination|negated|10|Group[896]|Clement
# mobile _ pour |forward|termination|negated|10|Group[896]|Clement
# mobile _ de |forward|termination|negated|10|Group[896]|Clement
# mobile _ d' |forward|termination|negated|10|Group[896]|Clement
# explication _s pour |forward|termination|negated|10|Group[896]|Clement
# explication _s de |forward|termination|negated|10|Group[896]|Clement
# explication _s d' |forward|termination|negated|10|Group[896]|Clement
# explication _ pour |forward|termination|negated|10|Group[896]|Clement
# explication _ de |forward|termination|negated|10|Group[896]|Clement
# explication _ d' |forward|termination|negated|10|Group[896]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "autre"
Var2 -> "possibilité" | "cas" | "hypothèse"
Var3 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[900]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# autre possibilité de |forward|termination|negated|10|Group[900]|Clement
# autre cas de |forward|termination|negated|10|Group[900]|Clement
# autre hypothèse de |forward|termination|negated|10|Group[900]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "autres"
Var2 -> "possibilités" | "cas" | "hypothèses"
Var3 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[900]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# autres possibilités de |forward|termination|negated|10|Group[900]|Clement
# autres cas de |forward|termination|negated|10|Group[900]|Clement
# autres hypothèses de |forward|termination|negated|10|Group[900]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Termin Trigger_Rule
Var1 -> "devrait" | "pourrait"
Var2 -> "être"
Var3 -> "exclu" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Termin -> "_"|"_s" |"_e" |"_es"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[901]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# devrait être exclu _ |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être exclu _s |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être exclu _e |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être exclu _es |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être repoussé _ |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être repoussé _s |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être repoussé _e |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être repoussé _es |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être rejeté _ |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être rejeté _s |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être rejeté _e |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être rejeté _es |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être éliminé _ |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être éliminé _s |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être éliminé _e |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être éliminé _es |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être proscrit _ |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être proscrit _s |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être proscrit _e |forward|trigger|uncertain|30|Group[901]|Clement
# devrait être proscrit _es |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être exclu _ |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être exclu _s |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être exclu _e |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être exclu _es |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être repoussé _ |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être repoussé _s |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être repoussé _e |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être repoussé _es |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être rejeté _ |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être rejeté _s |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être rejeté _e |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être rejeté _es |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être éliminé _ |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être éliminé _s |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être éliminé _e |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être éliminé _es |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être proscrit _ |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être proscrit _s |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être proscrit _e |forward|trigger|uncertain|30|Group[901]|Clement
# pourrait être proscrit _es |forward|trigger|uncertain|30|Group[901]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "histoire" | "historique"
Var2 -> "passée" | "finie"
Trigger_Rule -> "|forward|trigger|historical|30|Group[903]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# histoire passée |forward|trigger|historical|30|Group[903]|Clement
# histoire finie |forward|trigger|historical|30|Group[903]|Clement
# historique passée |forward|trigger|historical|30|Group[903]|Clement
# historique finie |forward|trigger|historical|30|Group[903]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 ->  "passé" | "souvenir"
Var2 -> "passé" | "fini"
Trigger_Rule -> "|forward|trigger|historical|30|Group[903]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# passé passé |forward|trigger|historical|30|Group[903]|Clement
# passé fini |forward|trigger|historical|30|Group[903]|Clement
# souvenir passé |forward|trigger|historical|30|Group[903]|Clement
# souvenir fini |forward|trigger|historical|30|Group[903]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "antécédents" | "antérieurs"
Var2 -> "médicaux"
Trigger_Rule -> "|forward|trigger|historical|30|Group[904]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# antécédents médicaux |forward|trigger|historical|30|Group[904]|Clement
# antérieurs médicaux |forward|trigger|historical|30|Group[904]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "antécédent" | "antérieur" | "préexistant" | "passé" | "précédent" | "préliminaire"
Var2 -> "médical"
Trigger_Rule -> "|forward|trigger|historical|30|Group[904]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# antécédent médical |forward|trigger|historical|30|Group[904]|Clement
# antérieur médical |forward|trigger|historical|30|Group[904]|Clement
# préexistant médical |forward|trigger|historical|30|Group[904]|Clement
# passé médical |forward|trigger|historical|30|Group[904]|Clement
# précédent médical |forward|trigger|historical|30|Group[904]|Clement
# préliminaire médical |forward|trigger|historical|30|Group[904]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "hérédité" |"antériorité" | "condition" |"ancienneté" | "antécédence"
Var2 -> "médicale"
Trigger_Rule -> "|forward|trigger|historical|30|Group[904]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# hérédité médicale |forward|trigger|historical|30|Group[904]|Clement
# antériorité médicale |forward|trigger|historical|30|Group[904]|Clement
# condition médicale |forward|trigger|historical|30|Group[904]|Clement
# ancienneté médicale |forward|trigger|historical|30|Group[904]|Clement
# antécédence médicale |forward|trigger|historical|30|Group[904]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Patient Var1 Var2 Var3 Trigger_Rule
Patient -> "patient" | "patiente"| "souffrant" | "souffrante"| "sujet"
Var1 -> "a"
Var2 -> "continué"
Var3 -> "à"
Trigger_Rule -> "|forward|termination|negated|10|Group[905]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# patient a continué à |forward|termination|negated|10|Group[905]|Clement
# patiente a continué à |forward|termination|negated|10|Group[905]|Clement
# souffrant a continué à |forward|termination|negated|10|Group[905]|Clement
# souffrante a continué à |forward|termination|negated|10|Group[905]|Clement
# sujet a continué à |forward|termination|negated|10|Group[905]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Patient Var1 Var2 Trigger_Rule
Patient -> "patient" | "patiente"| "souffrant" | "souffrante"| "sujet"
Var1 -> "n'est" |"n'était"
Var2 -> "pas" | "plus"
Trigger_Rule -> "|forward|trigger|negated|10|Group[906]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# patient n'est pas |forward|trigger|negated|10|Group[906]|Clement
# patient n'est plus |forward|trigger|negated|10|Group[906]|Clement
# patient n'était pas |forward|trigger|negated|10|Group[906]|Clement
# patient n'était plus |forward|trigger|negated|10|Group[906]|Clement
# patiente n'est pas |forward|trigger|negated|10|Group[906]|Clement
# patiente n'est plus |forward|trigger|negated|10|Group[906]|Clement
# patiente n'était pas |forward|trigger|negated|10|Group[906]|Clement
# patiente n'était plus |forward|trigger|negated|10|Group[906]|Clement
# souffrant n'est pas |forward|trigger|negated|10|Group[906]|Clement
# souffrant n'est plus |forward|trigger|negated|10|Group[906]|Clement
# souffrant n'était pas |forward|trigger|negated|10|Group[906]|Clement
# souffrant n'était plus |forward|trigger|negated|10|Group[906]|Clement
# souffrante n'est pas |forward|trigger|negated|10|Group[906]|Clement
# souffrante n'est plus |forward|trigger|negated|10|Group[906]|Clement
# souffrante n'était pas |forward|trigger|negated|10|Group[906]|Clement
# souffrante n'était plus |forward|trigger|negated|10|Group[906]|Clement
# sujet n'est pas |forward|trigger|negated|10|Group[906]|Clement
# sujet n'est plus |forward|trigger|negated|10|Group[906]|Clement
# sujet n'était pas |forward|trigger|negated|10|Group[906]|Clement
# sujet n'était plus |forward|trigger|negated|10|Group[906]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Patient Trigger_Rule
Var1 -> "les"
Patient -> "patients" | "patientes"| "souffrants" | "souffrantes"| "sujets"
Trigger_Rule -> "|both|termination|historical|30|Group[908, 911]|Clement"|"|both|termination|nonpatient|30|Group[908, 911]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# les patients |both|termination|historical|30|Group[908, 911]|Clement
# les patients |both|termination|nonpatient|30|Group[908, 911]|Clement
# les patientes |both|termination|historical|30|Group[908, 911]|Clement
# les patientes |both|termination|nonpatient|30|Group[908, 911]|Clement
# les souffrants |both|termination|historical|30|Group[908, 911]|Clement
# les souffrants |both|termination|nonpatient|30|Group[908, 911]|Clement
# les souffrantes |both|termination|historical|30|Group[908, 911]|Clement
# les souffrantes |both|termination|nonpatient|30|Group[908, 911]|Clement
# les sujets |both|termination|historical|30|Group[908, 911]|Clement
# les sujets |both|termination|nonpatient|30|Group[908, 911]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Patient Trigger_Rule
Patient -> "patient" | "patiente"| "souffrant" | "souffrante"| "sujet"
Trigger_Rule -> "|both|termination|historical|30|Group[908, 911]|Clement"|"|both|termination|nonpatient|30|Group[908, 911]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# patient |both|termination|historical|30|Group[908, 911]|Clement
# patient |both|termination|nonpatient|30|Group[908, 911]|Clement
# patiente |both|termination|historical|30|Group[908, 911]|Clement
# patiente |both|termination|nonpatient|30|Group[908, 911]|Clement
# souffrant |both|termination|historical|30|Group[908, 911]|Clement
# souffrant |both|termination|nonpatient|30|Group[908, 911]|Clement
# souffrante |both|termination|historical|30|Group[908, 911]|Clement
# souffrante |both|termination|nonpatient|30|Group[908, 911]|Clement
# sujet |both|termination|historical|30|Group[908, 911]|Clement
# sujet |both|termination|nonpatient|30|Group[908, 911]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "mauvaise"
Var2 -> "historique"
Trigger_Rule -> "|both|pseudo|historical|30|Group[912]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# mauvaise historique |both|pseudo|historical|30|Group[912]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "possible"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[913]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# possible |backward|trigger|uncertain|30|Group[913]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "possibilité" | "hypothèse" | "probabilité" | "chance"
Var2 -> "de"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[913]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# possibilité de |forward|trigger|uncertain|30|Group[913]|Clement
# hypothèse de |forward|trigger|uncertain|30|Group[913]|Clement
# probabilité de |forward|trigger|uncertain|30|Group[913]|Clement
# chance de |forward|trigger|uncertain|30|Group[913]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "peut-être"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[913]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut-être |forward|trigger|uncertain|30|Group[913]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "possible"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[913, 914]|Clement"|"|forward|trigger|conditional|30|Group[913, 914]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# possible |forward|trigger|uncertain|30|Group[913, 914]|Clement
# possible |forward|trigger|conditional|30|Group[913, 914]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Termin Trigger_Rule
Var1 -> "présente" | "révéle" | "expose" | "étale" |  "affiche" | "exhibe" | "montre"
Termin -> |"nt"
Trigger_Rule -> "|both|termination|historical|30|Group[918, 919]|Clement"|"|both|termination|nonpatient|30|Group[918, 919]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# présente |both|termination|historical|30|Group[918, 919]|Clement
# présente |both|termination|nonpatient|30|Group[918, 919]|Clement
# présente nt |both|termination|historical|30|Group[918, 919]|Clement
# présente nt |both|termination|nonpatient|30|Group[918, 919]|Clement
# révéle |both|termination|historical|30|Group[918, 919]|Clement
# révéle |both|termination|nonpatient|30|Group[918, 919]|Clement
# révéle nt |both|termination|historical|30|Group[918, 919]|Clement
# révéle nt |both|termination|nonpatient|30|Group[918, 919]|Clement
# expose |both|termination|historical|30|Group[918, 919]|Clement
# expose |both|termination|nonpatient|30|Group[918, 919]|Clement
# expose nt |both|termination|historical|30|Group[918, 919]|Clement
# expose nt |both|termination|nonpatient|30|Group[918, 919]|Clement
# étale |both|termination|historical|30|Group[918, 919]|Clement
# étale |both|termination|nonpatient|30|Group[918, 919]|Clement
# étale nt |both|termination|historical|30|Group[918, 919]|Clement
# étale nt |both|termination|nonpatient|30|Group[918, 919]|Clement
# affiche |both|termination|historical|30|Group[918, 919]|Clement
# affiche |both|termination|nonpatient|30|Group[918, 919]|Clement
# affiche nt |both|termination|historical|30|Group[918, 919]|Clement
# affiche nt |both|termination|nonpatient|30|Group[918, 919]|Clement
# exhibe |both|termination|historical|30|Group[918, 919]|Clement
# exhibe |both|termination|nonpatient|30|Group[918, 919]|Clement
# exhibe nt |both|termination|historical|30|Group[918, 919]|Clement
# exhibe nt |both|termination|nonpatient|30|Group[918, 919]|Clement
# montre |both|termination|historical|30|Group[918, 919]|Clement
# montre |both|termination|nonpatient|30|Group[918, 919]|Clement
# montre nt |both|termination|historical|30|Group[918, 919]|Clement
# montre nt |both|termination|nonpatient|30|Group[918, 919]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "en"
Var2 -> "présentant" | "révélant" | "exposant" | "étalant" |  "affichant" | "exhibant" | "montrant" | "mettant en évidence"
Trigger_Rule -> "|both|termination|historical|30|Group[918, 919]|Clement"|"|both|termination|nonpatient|30|Group[918, 919]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# en présentant |both|termination|historical|30|Group[918, 919]|Clement
# en présentant |both|termination|nonpatient|30|Group[918, 919]|Clement
# en révélant |both|termination|historical|30|Group[918, 919]|Clement
# en révélant |both|termination|nonpatient|30|Group[918, 919]|Clement
# en exposant |both|termination|historical|30|Group[918, 919]|Clement
# en exposant |both|termination|nonpatient|30|Group[918, 919]|Clement
# en étalant |both|termination|historical|30|Group[918, 919]|Clement
# en étalant |both|termination|nonpatient|30|Group[918, 919]|Clement
# en affichant |both|termination|historical|30|Group[918, 919]|Clement
# en affichant |both|termination|nonpatient|30|Group[918, 919]|Clement
# en exhibant |both|termination|historical|30|Group[918, 919]|Clement
# en exhibant |both|termination|nonpatient|30|Group[918, 919]|Clement
# en montrant |both|termination|historical|30|Group[918, 919]|Clement
# en montrant |both|termination|nonpatient|30|Group[918, 919]|Clement
# en mettant en évidence |both|termination|historical|30|Group[918, 919]|Clement
# en mettant en évidence |both|termination|nonpatient|30|Group[918, 919]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "probablement" | "apparemment" | "éventuellement" | "plausiblement" | "possiblement" | "sans doute" | "sûrement"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[922]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# probablement |forward|trigger|uncertain|30|Group[922]|Clement
# apparemment |forward|trigger|uncertain|30|Group[922]|Clement
# éventuellement |forward|trigger|uncertain|30|Group[922]|Clement
# plausiblement |forward|trigger|uncertain|30|Group[922]|Clement
# possiblement |forward|trigger|uncertain|30|Group[922]|Clement
# sans doute |forward|trigger|uncertain|30|Group[922]|Clement
# sûrement |forward|trigger|uncertain|30|Group[922]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Termin Trigger_Rule
Var1 -> "présumé" | "soupçonné" | "conjecturé" | "pressenti" | "présagé" | "présupposé"
Termin -> |"_s" |"_e" |"_es"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[923]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# présumé |forward|trigger|uncertain|30|Group[923]|Clement
# présumé _s |forward|trigger|uncertain|30|Group[923]|Clement
# présumé _e |forward|trigger|uncertain|30|Group[923]|Clement
# présumé _es |forward|trigger|uncertain|30|Group[923]|Clement
# soupçonné |forward|trigger|uncertain|30|Group[923]|Clement
# soupçonné _s |forward|trigger|uncertain|30|Group[923]|Clement
# soupçonné _e |forward|trigger|uncertain|30|Group[923]|Clement
# soupçonné _es |forward|trigger|uncertain|30|Group[923]|Clement
# conjecturé |forward|trigger|uncertain|30|Group[923]|Clement
# conjecturé _s |forward|trigger|uncertain|30|Group[923]|Clement
# conjecturé _e |forward|trigger|uncertain|30|Group[923]|Clement
# conjecturé _es |forward|trigger|uncertain|30|Group[923]|Clement
# pressenti |forward|trigger|uncertain|30|Group[923]|Clement
# pressenti _s |forward|trigger|uncertain|30|Group[923]|Clement
# pressenti _e |forward|trigger|uncertain|30|Group[923]|Clement
# pressenti _es |forward|trigger|uncertain|30|Group[923]|Clement
# présagé |forward|trigger|uncertain|30|Group[923]|Clement
# présagé _s |forward|trigger|uncertain|30|Group[923]|Clement
# présagé _e |forward|trigger|uncertain|30|Group[923]|Clement
# présagé _es |forward|trigger|uncertain|30|Group[923]|Clement
# présupposé |forward|trigger|uncertain|30|Group[923]|Clement
# présupposé _s |forward|trigger|uncertain|30|Group[923]|Clement
# présupposé _e |forward|trigger|uncertain|30|Group[923]|Clement
# présupposé _es |forward|trigger|uncertain|30|Group[923]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "antérieur à" | "préexistant à" |"précédent le" | "antécédent" | "préexistant" | "ancien"
Trigger_Rule -> "|forward|termination|negated|10|Group[924]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# antérieur à |forward|termination|negated|10|Group[924]|Clement
# préexistant à |forward|termination|negated|10|Group[924]|Clement
# précédent le |forward|termination|negated|10|Group[924]|Clement
# antécédent |forward|termination|negated|10|Group[924]|Clement
# préexistant |forward|termination|negated|10|Group[924]|Clement
# ancien |forward|termination|negated|10|Group[924]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "prophylaxie"
Trigger_Rule -> "|forward|trigger|conditional|10|Group[928]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# prophylaxie |forward|trigger|conditional|10|Group[928]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "la"
Var2 -> "question"
Var3 -> "était"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[931]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# la question était |forward|trigger|uncertain|30|Group[931]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "en question"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[932]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# en question |backward|trigger|uncertain|30|Group[932]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "se questionne sur"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[932]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# se questionne sur |forward|trigger|uncertain|30|Group[932]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "plutôt que" |"de préférence" | "préférablement"
Trigger_Rule -> "|forward|trigger|negated|10|Group[934]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# plutôt que |forward|trigger|negated|10|Group[934]|Clement
# de préférence |forward|trigger|negated|10|Group[934]|Clement
# préférablement |forward|trigger|negated|10|Group[934]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "raison" | "cause" | "prétexte" | "justification" | "explication" | "fondement" |  "preuve"
Termin -> |"_s"
Var2 -> "d'" | "de" | "d'un" | "d'une" | "pour"
Trigger_Rule -> "|forward|termination|negated|10|Group[936]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# raison d' |forward|termination|negated|10|Group[936]|Clement
# raison de |forward|termination|negated|10|Group[936]|Clement
# raison d'un |forward|termination|negated|10|Group[936]|Clement
# raison d'une |forward|termination|negated|10|Group[936]|Clement
# raison pour |forward|termination|negated|10|Group[936]|Clement
# cause d' |forward|termination|negated|10|Group[936]|Clement
# cause de |forward|termination|negated|10|Group[936]|Clement
# cause d'un |forward|termination|negated|10|Group[936]|Clement
# cause d'une |forward|termination|negated|10|Group[936]|Clement
# cause pour |forward|termination|negated|10|Group[936]|Clement
# prétexte d' |forward|termination|negated|10|Group[936]|Clement
# prétexte de |forward|termination|negated|10|Group[936]|Clement
# prétexte d'un |forward|termination|negated|10|Group[936]|Clement
# prétexte d'une |forward|termination|negated|10|Group[936]|Clement
# prétexte pour |forward|termination|negated|10|Group[936]|Clement
# justification d' |forward|termination|negated|10|Group[936]|Clement
# justification de |forward|termination|negated|10|Group[936]|Clement
# justification d'un |forward|termination|negated|10|Group[936]|Clement
# justification d'une |forward|termination|negated|10|Group[936]|Clement
# justification pour |forward|termination|negated|10|Group[936]|Clement
# explication d' |forward|termination|negated|10|Group[936]|Clement
# explication de |forward|termination|negated|10|Group[936]|Clement
# explication d'un |forward|termination|negated|10|Group[936]|Clement
# explication d'une |forward|termination|negated|10|Group[936]|Clement
# explication pour |forward|termination|negated|10|Group[936]|Clement
# fondement d' |forward|termination|negated|10|Group[936]|Clement
# fondement de |forward|termination|negated|10|Group[936]|Clement
# fondement d'un |forward|termination|negated|10|Group[936]|Clement
# fondement d'une |forward|termination|negated|10|Group[936]|Clement
# fondement pour |forward|termination|negated|10|Group[936]|Clement
# preuve d' |forward|termination|negated|10|Group[936]|Clement
# preuve de |forward|termination|negated|10|Group[936]|Clement
# preuve d'un |forward|termination|negated|10|Group[936]|Clement
# preuve d'une |forward|termination|negated|10|Group[936]|Clement
# preuve pour |forward|termination|negated|10|Group[936]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Termin Trigger_Rule
Var1 -> "rapporte" | "signale" | "indique" | "montre" | "dévoile" | "souligne" | "informe"| "révéle" | "signifie" | "avertisse" | "témoigne" | "alerte"
Termin -> |"_nt"
Trigger_Rule -> "|both|termination|historical|30|Group[940, 941]|Clement"|"|both|termination|nonpatient|30|Group[940, 941]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# rapporte |both|termination|historical|30|Group[940, 941]|Clement
# rapporte |both|termination|nonpatient|30|Group[940, 941]|Clement
# rapporte _nt |both|termination|historical|30|Group[940, 941]|Clement
# rapporte _nt |both|termination|nonpatient|30|Group[940, 941]|Clement
# signale |both|termination|historical|30|Group[940, 941]|Clement
# signale |both|termination|nonpatient|30|Group[940, 941]|Clement
# signale _nt |both|termination|historical|30|Group[940, 941]|Clement
# signale _nt |both|termination|nonpatient|30|Group[940, 941]|Clement
# indique |both|termination|historical|30|Group[940, 941]|Clement
# indique |both|termination|nonpatient|30|Group[940, 941]|Clement
# indique _nt |both|termination|historical|30|Group[940, 941]|Clement
# indique _nt |both|termination|nonpatient|30|Group[940, 941]|Clement
# montre |both|termination|historical|30|Group[940, 941]|Clement
# montre |both|termination|nonpatient|30|Group[940, 941]|Clement
# montre _nt |both|termination|historical|30|Group[940, 941]|Clement
# montre _nt |both|termination|nonpatient|30|Group[940, 941]|Clement
# dévoile |both|termination|historical|30|Group[940, 941]|Clement
# dévoile |both|termination|nonpatient|30|Group[940, 941]|Clement
# dévoile _nt |both|termination|historical|30|Group[940, 941]|Clement
# dévoile _nt |both|termination|nonpatient|30|Group[940, 941]|Clement
# souligne |both|termination|historical|30|Group[940, 941]|Clement
# souligne |both|termination|nonpatient|30|Group[940, 941]|Clement
# souligne _nt |both|termination|historical|30|Group[940, 941]|Clement
# souligne _nt |both|termination|nonpatient|30|Group[940, 941]|Clement
# informe |both|termination|historical|30|Group[940, 941]|Clement
# informe |both|termination|nonpatient|30|Group[940, 941]|Clement
# informe _nt |both|termination|historical|30|Group[940, 941]|Clement
# informe _nt |both|termination|nonpatient|30|Group[940, 941]|Clement
# révéle |both|termination|historical|30|Group[940, 941]|Clement
# révéle |both|termination|nonpatient|30|Group[940, 941]|Clement
# révéle _nt |both|termination|historical|30|Group[940, 941]|Clement
# révéle _nt |both|termination|nonpatient|30|Group[940, 941]|Clement
# signifie |both|termination|historical|30|Group[940, 941]|Clement
# signifie |both|termination|nonpatient|30|Group[940, 941]|Clement
# signifie _nt |both|termination|historical|30|Group[940, 941]|Clement
# signifie _nt |both|termination|nonpatient|30|Group[940, 941]|Clement
# avertisse |both|termination|historical|30|Group[940, 941]|Clement
# avertisse |both|termination|nonpatient|30|Group[940, 941]|Clement
# avertisse _nt |both|termination|historical|30|Group[940, 941]|Clement
# avertisse _nt |both|termination|nonpatient|30|Group[940, 941]|Clement
# témoigne |both|termination|historical|30|Group[940, 941]|Clement
# témoigne |both|termination|nonpatient|30|Group[940, 941]|Clement
# témoigne _nt |both|termination|historical|30|Group[940, 941]|Clement
# témoigne _nt |both|termination|nonpatient|30|Group[940, 941]|Clement
# alerte |both|termination|historical|30|Group[940, 941]|Clement
# alerte |both|termination|nonpatient|30|Group[940, 941]|Clement
# alerte _nt |both|termination|historical|30|Group[940, 941]|Clement
# alerte _nt |both|termination|nonpatient|30|Group[940, 941]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Termin Trigger_Rule
Var1 -> "rapporté" | "signalé" | "indiqué" | "montré" | "dévoilé" | "souligné" | "informé"| "révélé" | "signifié" | "averti" | "témoigné" | "alerté"
Termin -> |"_s" |"_e" |"_es"
Trigger_Rule -> "|both|termination|historical|30|Group[940, 941]|Clement"|"|both|termination|nonpatient|30|Group[940, 941]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# rapporté |both|termination|historical|30|Group[940, 941]|Clement
# rapporté |both|termination|nonpatient|30|Group[940, 941]|Clement
# rapporté _s |both|termination|historical|30|Group[940, 941]|Clement
# rapporté _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# rapporté _e |both|termination|historical|30|Group[940, 941]|Clement
# rapporté _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# rapporté _es |both|termination|historical|30|Group[940, 941]|Clement
# rapporté _es |both|termination|nonpatient|30|Group[940, 941]|Clement
# signalé |both|termination|historical|30|Group[940, 941]|Clement
# signalé |both|termination|nonpatient|30|Group[940, 941]|Clement
# signalé _s |both|termination|historical|30|Group[940, 941]|Clement
# signalé _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# signalé _e |both|termination|historical|30|Group[940, 941]|Clement
# signalé _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# signalé _es |both|termination|historical|30|Group[940, 941]|Clement
# signalé _es |both|termination|nonpatient|30|Group[940, 941]|Clement
# indiqué |both|termination|historical|30|Group[940, 941]|Clement
# indiqué |both|termination|nonpatient|30|Group[940, 941]|Clement
# indiqué _s |both|termination|historical|30|Group[940, 941]|Clement
# indiqué _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# indiqué _e |both|termination|historical|30|Group[940, 941]|Clement
# indiqué _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# indiqué _es |both|termination|historical|30|Group[940, 941]|Clement
# indiqué _es |both|termination|nonpatient|30|Group[940, 941]|Clement
# montré |both|termination|historical|30|Group[940, 941]|Clement
# montré |both|termination|nonpatient|30|Group[940, 941]|Clement
# montré _s |both|termination|historical|30|Group[940, 941]|Clement
# montré _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# montré _e |both|termination|historical|30|Group[940, 941]|Clement
# montré _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# montré _es |both|termination|historical|30|Group[940, 941]|Clement
# montré _es |both|termination|nonpatient|30|Group[940, 941]|Clement
# dévoilé |both|termination|historical|30|Group[940, 941]|Clement
# dévoilé |both|termination|nonpatient|30|Group[940, 941]|Clement
# dévoilé _s |both|termination|historical|30|Group[940, 941]|Clement
# dévoilé _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# dévoilé _e |both|termination|historical|30|Group[940, 941]|Clement
# dévoilé _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# dévoilé _es |both|termination|historical|30|Group[940, 941]|Clement
# dévoilé _es |both|termination|nonpatient|30|Group[940, 941]|Clement
# souligné |both|termination|historical|30|Group[940, 941]|Clement
# souligné |both|termination|nonpatient|30|Group[940, 941]|Clement
# souligné _s |both|termination|historical|30|Group[940, 941]|Clement
# souligné _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# souligné _e |both|termination|historical|30|Group[940, 941]|Clement
# souligné _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# souligné _es |both|termination|historical|30|Group[940, 941]|Clement
# souligné _es |both|termination|nonpatient|30|Group[940, 941]|Clement
# informé |both|termination|historical|30|Group[940, 941]|Clement
# informé |both|termination|nonpatient|30|Group[940, 941]|Clement
# informé _s |both|termination|historical|30|Group[940, 941]|Clement
# informé _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# informé _e |both|termination|historical|30|Group[940, 941]|Clement
# informé _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# informé _es |both|termination|historical|30|Group[940, 941]|Clement
# informé _es |both|termination|nonpatient|30|Group[940, 941]|Clement
# révélé |both|termination|historical|30|Group[940, 941]|Clement
# révélé |both|termination|nonpatient|30|Group[940, 941]|Clement
# révélé _s |both|termination|historical|30|Group[940, 941]|Clement
# révélé _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# révélé _e |both|termination|historical|30|Group[940, 941]|Clement
# révélé _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# révélé _es |both|termination|historical|30|Group[940, 941]|Clement
# révélé _es |both|termination|nonpatient|30|Group[940, 941]|Clement
# signifié |both|termination|historical|30|Group[940, 941]|Clement
# signifié |both|termination|nonpatient|30|Group[940, 941]|Clement
# signifié _s |both|termination|historical|30|Group[940, 941]|Clement
# signifié _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# signifié _e |both|termination|historical|30|Group[940, 941]|Clement
# signifié _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# signifié _es |both|termination|historical|30|Group[940, 941]|Clement
# signifié _es |both|termination|nonpatient|30|Group[940, 941]|Clement
# averti |both|termination|historical|30|Group[940, 941]|Clement
# averti |both|termination|nonpatient|30|Group[940, 941]|Clement
# averti _s |both|termination|historical|30|Group[940, 941]|Clement
# averti _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# averti _e |both|termination|historical|30|Group[940, 941]|Clement
# averti _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# averti _es |both|termination|historical|30|Group[940, 941]|Clement
# averti _es |both|termination|nonpatient|30|Group[940, 941]|Clement
# témoigné |both|termination|historical|30|Group[940, 941]|Clement
# témoigné |both|termination|nonpatient|30|Group[940, 941]|Clement
# témoigné _s |both|termination|historical|30|Group[940, 941]|Clement
# témoigné _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# témoigné _e |both|termination|historical|30|Group[940, 941]|Clement
# témoigné _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# témoigné _es |both|termination|historical|30|Group[940, 941]|Clement
# témoigné _es |both|termination|nonpatient|30|Group[940, 941]|Clement
# alerté |both|termination|historical|30|Group[940, 941]|Clement
# alerté |both|termination|nonpatient|30|Group[940, 941]|Clement
# alerté _s |both|termination|historical|30|Group[940, 941]|Clement
# alerté _s |both|termination|nonpatient|30|Group[940, 941]|Clement
# alerté _e |both|termination|historical|30|Group[940, 941]|Clement
# alerté _e |both|termination|nonpatient|30|Group[940, 941]|Clement
# alerté _es |both|termination|historical|30|Group[940, 941]|Clement
# alerté _es |both|termination|nonpatient|30|Group[940, 941]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "risque" | "chance"
Var2 -> "de"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[947]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# risque de |forward|trigger|conditional|30|Group[947]|Clement
# chance de |forward|trigger|conditional|30|Group[947]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Trigger_Rule
Var1 -> "l'éliminer" | "l'écarter" | "l'évincer" | "l'exclure"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[955]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# l'éliminer |backward|trigger|uncertain|30|Group[955]|Clement
# l'écarter |backward|trigger|uncertain|30|Group[955]|Clement
# l'évincer |backward|trigger|uncertain|30|Group[955]|Clement
# l'exclure |backward|trigger|uncertain|30|Group[955]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "éliminer" | "écarter" | "évincer" | "exclure"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[955]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# éliminer |forward|trigger|uncertain|30|Group[955]|Clement
# écarter |forward|trigger|uncertain|30|Group[955]|Clement
# évincer |forward|trigger|uncertain|30|Group[955]|Clement
# exclure |forward|trigger|uncertain|30|Group[955]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "exclut" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit" | "écarte"
Var2 -> "pour"| "par" | "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[977]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# exclut pour |forward|trigger|negated|10|Group[977]|Clement
# exclut par |forward|trigger|negated|10|Group[977]|Clement
# exclut contre |forward|trigger|negated|10|Group[977]|Clement
# refusé pour |forward|trigger|negated|10|Group[977]|Clement
# refusé par |forward|trigger|negated|10|Group[977]|Clement
# refusé contre |forward|trigger|negated|10|Group[977]|Clement
# repoussé pour |forward|trigger|negated|10|Group[977]|Clement
# repoussé par |forward|trigger|negated|10|Group[977]|Clement
# repoussé contre |forward|trigger|negated|10|Group[977]|Clement
# rejeté pour |forward|trigger|negated|10|Group[977]|Clement
# rejeté par |forward|trigger|negated|10|Group[977]|Clement
# rejeté contre |forward|trigger|negated|10|Group[977]|Clement
# éliminé pour |forward|trigger|negated|10|Group[977]|Clement
# éliminé par |forward|trigger|negated|10|Group[977]|Clement
# éliminé contre |forward|trigger|negated|10|Group[977]|Clement
# proscrit pour |forward|trigger|negated|10|Group[977]|Clement
# proscrit par |forward|trigger|negated|10|Group[977]|Clement
# proscrit contre |forward|trigger|negated|10|Group[977]|Clement
# écarte pour |forward|trigger|negated|10|Group[977]|Clement
# écarte par |forward|trigger|negated|10|Group[977]|Clement
# écarte contre |forward|trigger|negated|10|Group[977]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "exclut" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit" | "écarte"
Trigger_Rule -> "|backward|trigger|negated|10|Group[979]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# exclut |backward|trigger|negated|10|Group[979]|Clement
# refusé |backward|trigger|negated|10|Group[979]|Clement
# repoussé |backward|trigger|negated|10|Group[979]|Clement
# rejeté |backward|trigger|negated|10|Group[979]|Clement
# éliminé |backward|trigger|negated|10|Group[979]|Clement
# proscrit |backward|trigger|negated|10|Group[979]|Clement
# écarte |backward|trigger|negated|10|Group[979]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Patient Trigger_Rule
Var1 -> "exclut" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit" | "écarte"
Patient -> "le patient" | "la patiente"| "le souffrant" | "la souffrante"| "le sujet"
Trigger_Rule -> "|forward|trigger|negated|10|Group[985]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# exclut le patient |forward|trigger|negated|10|Group[985]|Clement
# exclut la patiente |forward|trigger|negated|10|Group[985]|Clement
# exclut le souffrant |forward|trigger|negated|10|Group[985]|Clement
# exclut la souffrante |forward|trigger|negated|10|Group[985]|Clement
# exclut le sujet |forward|trigger|negated|10|Group[985]|Clement
# refusé le patient |forward|trigger|negated|10|Group[985]|Clement
# refusé la patiente |forward|trigger|negated|10|Group[985]|Clement
# refusé le souffrant |forward|trigger|negated|10|Group[985]|Clement
# refusé la souffrante |forward|trigger|negated|10|Group[985]|Clement
# refusé le sujet |forward|trigger|negated|10|Group[985]|Clement
# repoussé le patient |forward|trigger|negated|10|Group[985]|Clement
# repoussé la patiente |forward|trigger|negated|10|Group[985]|Clement
# repoussé le souffrant |forward|trigger|negated|10|Group[985]|Clement
# repoussé la souffrante |forward|trigger|negated|10|Group[985]|Clement
# repoussé le sujet |forward|trigger|negated|10|Group[985]|Clement
# rejeté le patient |forward|trigger|negated|10|Group[985]|Clement
# rejeté la patiente |forward|trigger|negated|10|Group[985]|Clement
# rejeté le souffrant |forward|trigger|negated|10|Group[985]|Clement
# rejeté la souffrante |forward|trigger|negated|10|Group[985]|Clement
# rejeté le sujet |forward|trigger|negated|10|Group[985]|Clement
# éliminé le patient |forward|trigger|negated|10|Group[985]|Clement
# éliminé la patiente |forward|trigger|negated|10|Group[985]|Clement
# éliminé le souffrant |forward|trigger|negated|10|Group[985]|Clement
# éliminé la souffrante |forward|trigger|negated|10|Group[985]|Clement
# éliminé le sujet |forward|trigger|negated|10|Group[985]|Clement
# proscrit le patient |forward|trigger|negated|10|Group[985]|Clement
# proscrit la patiente |forward|trigger|negated|10|Group[985]|Clement
# proscrit le souffrant |forward|trigger|negated|10|Group[985]|Clement
# proscrit la souffrante |forward|trigger|negated|10|Group[985]|Clement
# proscrit le sujet |forward|trigger|negated|10|Group[985]|Clement
# écarte le patient |forward|trigger|negated|10|Group[985]|Clement
# écarte la patiente |forward|trigger|negated|10|Group[985]|Clement
# écarte le souffrant |forward|trigger|negated|10|Group[985]|Clement
# écarte la souffrante |forward|trigger|negated|10|Group[985]|Clement
# écarte le sujet |forward|trigger|negated|10|Group[985]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->   Var1  Trigger_Rule
Var1 -> "l'exclut" | "le refuse"| "la refuse" | "le repousse" | "la repousse" | "le rejete"| "la rejete" | "l'élimine" | "le proscrit" | "la proscrit"
Trigger_Rule -> "|backward|trigger|negated|10|Group[987]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# l'exclut |backward|trigger|negated|10|Group[987]|Clement
# le refuse |backward|trigger|negated|10|Group[987]|Clement
# la refuse |backward|trigger|negated|10|Group[987]|Clement
# le repousse |backward|trigger|negated|10|Group[987]|Clement
# la repousse |backward|trigger|negated|10|Group[987]|Clement
# le rejete |backward|trigger|negated|10|Group[987]|Clement
# la rejete |backward|trigger|negated|10|Group[987]|Clement
# l'élimine |backward|trigger|negated|10|Group[987]|Clement
# le proscrit |backward|trigger|negated|10|Group[987]|Clement
# la proscrit |backward|trigger|negated|10|Group[987]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "exclut" | "interdit" | "proscrit" | "éloigne" | "rejete" | "évince" | "écarte" | "empêche" | "écarte"
Trigger_Rule -> "|forward|trigger|negated|10|Group[997]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# exclut |forward|trigger|negated|10|Group[997]|Clement
# interdit |forward|trigger|negated|10|Group[997]|Clement
# proscrit |forward|trigger|negated|10|Group[997]|Clement
# éloigne |forward|trigger|negated|10|Group[997]|Clement
# rejete |forward|trigger|negated|10|Group[997]|Clement
# évince |forward|trigger|negated|10|Group[997]|Clement
# écarte |forward|trigger|negated|10|Group[997]|Clement
# empêche |forward|trigger|negated|10|Group[997]|Clement
# écarte |forward|trigger|negated|10|Group[997]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "secondaire" | "secondaires"
Trigger_Rule -> "|forward|termination|negated|10|Group[1004]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# secondaire |forward|termination|negated|10|Group[1004]|Clement
# secondaires |forward|termination|negated|10|Group[1004]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Var1 Var2 Var3 Trigger_Rule
Var1 -> "a"
Var2 -> "continué" | "perpétuer" | "tenu"
Var3 -> "à"
Trigger_Rule -> "|forward|termination|negated|10|Group[1006]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a continué à |forward|termination|negated|10|Group[1006]|Clement
# a perpétuer à |forward|termination|negated|10|Group[1006]|Clement
# a tenu à |forward|termination|negated|10|Group[1006]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Pronoun Trigger_Rule
Var1 -> "devrait" | "pourrait"
Pronoun -> "_-il" | "_-elle"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[1009]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# devrait _-il |forward|trigger|conditional|30|Group[1009]|Clement
# devrait _-elle |forward|trigger|conditional|30|Group[1009]|Clement
# pourrait _-il |forward|trigger|conditional|30|Group[1009]|Clement
# pourrait _-elle |forward|trigger|conditional|30|Group[1009]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "montre" | "indique" | "expose" | "témoigne" | "signale" | "manifeste" | "révéle"
Var2 -> "une"
Var3 -> "question" | "interpellation"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1013]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# montre une question |forward|trigger|uncertain|30|Group[1013]|Clement
# montre une interpellation |forward|trigger|uncertain|30|Group[1013]|Clement
# indique une question |forward|trigger|uncertain|30|Group[1013]|Clement
# indique une interpellation |forward|trigger|uncertain|30|Group[1013]|Clement
# expose une question |forward|trigger|uncertain|30|Group[1013]|Clement
# expose une interpellation |forward|trigger|uncertain|30|Group[1013]|Clement
# témoigne une question |forward|trigger|uncertain|30|Group[1013]|Clement
# témoigne une interpellation |forward|trigger|uncertain|30|Group[1013]|Clement
# signale une question |forward|trigger|uncertain|30|Group[1013]|Clement
# signale une interpellation |forward|trigger|uncertain|30|Group[1013]|Clement
# manifeste une question |forward|trigger|uncertain|30|Group[1013]|Clement
# manifeste une interpellation |forward|trigger|uncertain|30|Group[1013]|Clement
# révéle une question |forward|trigger|uncertain|30|Group[1013]|Clement
# révéle une interpellation |forward|trigger|uncertain|30|Group[1013]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Depuis Seasons Trigger_Rule
Depuis -> "depuis" | "dès" | "à partir de"
Seasons -> "le printemps"|"l'été"|"l'automne"|"l'hiver" 
Trigger_Rule -> "|backward|trigger|historical|30|Group[1015]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# depuis le printemps |backward|trigger|historical|30|Group[1015]|Clement
# depuis l'été |backward|trigger|historical|30|Group[1015]|Clement
# depuis l'automne |backward|trigger|historical|30|Group[1015]|Clement
# depuis l'hiver |backward|trigger|historical|30|Group[1015]|Clement
# dès le printemps |backward|trigger|historical|30|Group[1015]|Clement
# dès l'été |backward|trigger|historical|30|Group[1015]|Clement
# dès l'automne |backward|trigger|historical|30|Group[1015]|Clement
# dès l'hiver |backward|trigger|historical|30|Group[1015]|Clement
# à partir de le printemps |backward|trigger|historical|30|Group[1015]|Clement
# à partir de l'été |backward|trigger|historical|30|Group[1015]|Clement
# à partir de l'automne |backward|trigger|historical|30|Group[1015]|Clement
# à partir de l'hiver |backward|trigger|historical|30|Group[1015]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Depuis Month Trigger_Rule
Depuis -> "depuis" | "dès" | "à partir de"
Month -> "janvier"|"février"|"mars"|"avril"|"mai"|"juin" |"juillet"|"août"|"septembre"|"octobre"|"novembre"|"décembre"
Trigger_Rule -> "|backward|trigger|historical|30|Group[1015]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# depuis janvier |backward|trigger|historical|30|Group[1015]|Clement
# depuis février |backward|trigger|historical|30|Group[1015]|Clement
# depuis mars |backward|trigger|historical|30|Group[1015]|Clement
# depuis avril |backward|trigger|historical|30|Group[1015]|Clement
# depuis mai |backward|trigger|historical|30|Group[1015]|Clement
# depuis juin |backward|trigger|historical|30|Group[1015]|Clement
# depuis juillet |backward|trigger|historical|30|Group[1015]|Clement
# depuis août |backward|trigger|historical|30|Group[1015]|Clement
# depuis septembre |backward|trigger|historical|30|Group[1015]|Clement
# depuis octobre |backward|trigger|historical|30|Group[1015]|Clement
# depuis novembre |backward|trigger|historical|30|Group[1015]|Clement
# depuis décembre |backward|trigger|historical|30|Group[1015]|Clement
# dès janvier |backward|trigger|historical|30|Group[1015]|Clement
# dès février |backward|trigger|historical|30|Group[1015]|Clement
# dès mars |backward|trigger|historical|30|Group[1015]|Clement
# dès avril |backward|trigger|historical|30|Group[1015]|Clement
# dès mai |backward|trigger|historical|30|Group[1015]|Clement
# dès juin |backward|trigger|historical|30|Group[1015]|Clement
# dès juillet |backward|trigger|historical|30|Group[1015]|Clement
# dès août |backward|trigger|historical|30|Group[1015]|Clement
# dès septembre |backward|trigger|historical|30|Group[1015]|Clement
# dès octobre |backward|trigger|historical|30|Group[1015]|Clement
# dès novembre |backward|trigger|historical|30|Group[1015]|Clement
# dès décembre |backward|trigger|historical|30|Group[1015]|Clement
# à partir de janvier |backward|trigger|historical|30|Group[1015]|Clement
# à partir de février |backward|trigger|historical|30|Group[1015]|Clement
# à partir de mars |backward|trigger|historical|30|Group[1015]|Clement
# à partir de avril |backward|trigger|historical|30|Group[1015]|Clement
# à partir de mai |backward|trigger|historical|30|Group[1015]|Clement
# à partir de juin |backward|trigger|historical|30|Group[1015]|Clement
# à partir de juillet |backward|trigger|historical|30|Group[1015]|Clement
# à partir de août |backward|trigger|historical|30|Group[1015]|Clement
# à partir de septembre |backward|trigger|historical|30|Group[1015]|Clement
# à partir de octobre |backward|trigger|historical|30|Group[1015]|Clement
# à partir de novembre |backward|trigger|historical|30|Group[1015]|Clement
# à partir de décembre |backward|trigger|historical|30|Group[1015]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "histoire" | "historique"
Var2 -> "sociale"
Trigger_Rule -> "|both|pseudo|historical|30|Group[1040]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# histoire sociale |both|pseudo|historical|30|Group[1040]|Clement
# historique sociale |both|pseudo|historical|30|Group[1040]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Member Trigger_Rule
Var1 -> "le rapport" 
Member -> "du parent" | "des parents" | "du père" | "du beau-père" | "de la mère" |"de la belle-mère" | "du papa" | "de la maman" |"du fils" |"des fils" | "du beau-fils" | "du garçon" | "des garçons" | "de la fille" | "de la belle-fille" | "des filles" | "du frère"| "des frères" |"de la soeur" |"des soeurs" |"de la sœur" |"des sœurs" | "de la fratrie" | "de l'oncle"| "du tonton"| "des oncles" |"de la tante" | "de la tata"|"des tantes" |" de la grand-mère" | "du grand-père" |"du cousin" |"des cousins" |"de la famille" |"du colocataire" | "des colocataires" | "du voisin" | "des voisins"
Trigger_Rule -> "|both|termination|historical|30|Group[1041, 1042]|Clement"|"|both|termination|nonpatient|30|Group[1041, 1042]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# le rapport du parent |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du parent |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des parents |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des parents |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du père |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du père |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du beau-père |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du beau-père |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de la mère |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de la mère |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de la belle-mère |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de la belle-mère |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du papa |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du papa |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de la maman |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de la maman |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du fils |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du fils |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des fils |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des fils |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du beau-fils |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du beau-fils |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du garçon |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du garçon |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des garçons |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des garçons |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de la fille |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de la fille |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de la belle-fille |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de la belle-fille |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des filles |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des filles |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du frère |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du frère |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des frères |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des frères |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de la soeur |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de la soeur |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des soeurs |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des soeurs |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de la sœur |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de la sœur |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des sœurs |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des sœurs |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de la fratrie |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de la fratrie |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de l'oncle |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de l'oncle |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du tonton |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du tonton |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des oncles |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des oncles |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de la tante |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de la tante |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de la tata |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de la tata |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des tantes |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des tantes |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport  de la grand-mère |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport  de la grand-mère |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du grand-père |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du grand-père |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du cousin |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du cousin |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des cousins |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des cousins |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport de la famille |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport de la famille |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du colocataire |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du colocataire |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des colocataires |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des colocataires |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport du voisin |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport du voisin |both|termination|nonpatient|30|Group[1041, 1042]|Clement
# le rapport des voisins |both|termination|historical|30|Group[1041, 1042]|Clement
# le rapport des voisins |both|termination|nonpatient|30|Group[1041, 1042]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "parler" | "bavarder" | "discuter" | "dialoguer" | "communiquer" | "s'entretenir"
Var2 -> "avec"
Var3 -> "la famille" | "le cercle familial" | "l'entourage" | "les parents" | "la belle-famille"
Trigger_Rule -> "|both|termination|historical|30|Group[1053, 1054]|Clement"|"|both|termination|nonpatient|30|Group[1053, 1054]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# parler avec la famille |both|termination|historical|30|Group[1053, 1054]|Clement
# parler avec la famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# parler avec le cercle familial |both|termination|historical|30|Group[1053, 1054]|Clement
# parler avec le cercle familial |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# parler avec l'entourage |both|termination|historical|30|Group[1053, 1054]|Clement
# parler avec l'entourage |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# parler avec les parents |both|termination|historical|30|Group[1053, 1054]|Clement
# parler avec les parents |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# parler avec la belle-famille |both|termination|historical|30|Group[1053, 1054]|Clement
# parler avec la belle-famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# bavarder avec la famille |both|termination|historical|30|Group[1053, 1054]|Clement
# bavarder avec la famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# bavarder avec le cercle familial |both|termination|historical|30|Group[1053, 1054]|Clement
# bavarder avec le cercle familial |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# bavarder avec l'entourage |both|termination|historical|30|Group[1053, 1054]|Clement
# bavarder avec l'entourage |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# bavarder avec les parents |both|termination|historical|30|Group[1053, 1054]|Clement
# bavarder avec les parents |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# bavarder avec la belle-famille |both|termination|historical|30|Group[1053, 1054]|Clement
# bavarder avec la belle-famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# discuter avec la famille |both|termination|historical|30|Group[1053, 1054]|Clement
# discuter avec la famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# discuter avec le cercle familial |both|termination|historical|30|Group[1053, 1054]|Clement
# discuter avec le cercle familial |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# discuter avec l'entourage |both|termination|historical|30|Group[1053, 1054]|Clement
# discuter avec l'entourage |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# discuter avec les parents |both|termination|historical|30|Group[1053, 1054]|Clement
# discuter avec les parents |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# discuter avec la belle-famille |both|termination|historical|30|Group[1053, 1054]|Clement
# discuter avec la belle-famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# dialoguer avec la famille |both|termination|historical|30|Group[1053, 1054]|Clement
# dialoguer avec la famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# dialoguer avec le cercle familial |both|termination|historical|30|Group[1053, 1054]|Clement
# dialoguer avec le cercle familial |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# dialoguer avec l'entourage |both|termination|historical|30|Group[1053, 1054]|Clement
# dialoguer avec l'entourage |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# dialoguer avec les parents |both|termination|historical|30|Group[1053, 1054]|Clement
# dialoguer avec les parents |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# dialoguer avec la belle-famille |both|termination|historical|30|Group[1053, 1054]|Clement
# dialoguer avec la belle-famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# communiquer avec la famille |both|termination|historical|30|Group[1053, 1054]|Clement
# communiquer avec la famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# communiquer avec le cercle familial |both|termination|historical|30|Group[1053, 1054]|Clement
# communiquer avec le cercle familial |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# communiquer avec l'entourage |both|termination|historical|30|Group[1053, 1054]|Clement
# communiquer avec l'entourage |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# communiquer avec les parents |both|termination|historical|30|Group[1053, 1054]|Clement
# communiquer avec les parents |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# communiquer avec la belle-famille |both|termination|historical|30|Group[1053, 1054]|Clement
# communiquer avec la belle-famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# s'entretenir avec la famille |both|termination|historical|30|Group[1053, 1054]|Clement
# s'entretenir avec la famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# s'entretenir avec le cercle familial |both|termination|historical|30|Group[1053, 1054]|Clement
# s'entretenir avec le cercle familial |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# s'entretenir avec l'entourage |both|termination|historical|30|Group[1053, 1054]|Clement
# s'entretenir avec l'entourage |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# s'entretenir avec les parents |both|termination|historical|30|Group[1053, 1054]|Clement
# s'entretenir avec les parents |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# s'entretenir avec la belle-famille |both|termination|historical|30|Group[1053, 1054]|Clement
# s'entretenir avec la belle-famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "s'adresser"
Var2 -> "à la famille" | "au cercle familial" | "à l'entourage" | "aux parents" | "à la belle-famille"
Trigger_Rule -> "|both|termination|historical|30|Group[1053, 1054]|Clement"|"|both|termination|nonpatient|30|Group[1053, 1054]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# s'adresser à la famille |both|termination|historical|30|Group[1053, 1054]|Clement
# s'adresser à la famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# s'adresser au cercle familial |both|termination|historical|30|Group[1053, 1054]|Clement
# s'adresser au cercle familial |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# s'adresser à l'entourage |both|termination|historical|30|Group[1053, 1054]|Clement
# s'adresser à l'entourage |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# s'adresser aux parents |both|termination|historical|30|Group[1053, 1054]|Clement
# s'adresser aux parents |both|termination|nonpatient|30|Group[1053, 1054]|Clement
# s'adresser à la belle-famille |both|termination|historical|30|Group[1053, 1054]|Clement
# s'adresser à la belle-famille |both|termination|nonpatient|30|Group[1053, 1054]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "encore" |"toujours"
Trigger_Rule -> "|forward|termination|negated|10|Group[1060]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# encore |forward|termination|negated|10|Group[1060]|Clement
# toujours |forward|termination|negated|10|Group[1060]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "arrêté" | "terminé" | "fini" | "cessé"
Var2 -> "de"
Var3 -> "prendre" | "manger" | "boire"
Trigger_Rule -> "|both|pseudo|negated|10|Group[1061]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# arrêté de prendre |both|pseudo|negated|10|Group[1061]|Clement
# arrêté de manger |both|pseudo|negated|10|Group[1061]|Clement
# arrêté de boire |both|pseudo|negated|10|Group[1061]|Clement
# terminé de prendre |both|pseudo|negated|10|Group[1061]|Clement
# terminé de manger |both|pseudo|negated|10|Group[1061]|Clement
# terminé de boire |both|pseudo|negated|10|Group[1061]|Clement
# fini de prendre |both|pseudo|negated|10|Group[1061]|Clement
# fini de manger |both|pseudo|negated|10|Group[1061]|Clement
# fini de boire |both|pseudo|negated|10|Group[1061]|Clement
# cessé de prendre |both|pseudo|negated|10|Group[1061]|Clement
# cessé de manger |both|pseudo|negated|10|Group[1061]|Clement
# cessé de boire |both|pseudo|negated|10|Group[1061]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Termin Var2 Var3 Trigger_Rule
Var1 -> "étude" | "examen" | "expérimentation" | "enquête" | "analyse"
Termin -> |"_s" 
Var2 -> "pour"
Var3 -> "évaluer" | "juger" | "apprécier" | "chiffrer" | "calculer" | "quantifier" | "mesurer" | "déterminer" | "expertiser"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1062]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# étude pour évaluer |forward|trigger|uncertain|30|Group[1062]|Clement
# étude pour juger |forward|trigger|uncertain|30|Group[1062]|Clement
# étude pour apprécier |forward|trigger|uncertain|30|Group[1062]|Clement
# étude pour chiffrer |forward|trigger|uncertain|30|Group[1062]|Clement
# étude pour calculer |forward|trigger|uncertain|30|Group[1062]|Clement
# étude pour quantifier |forward|trigger|uncertain|30|Group[1062]|Clement
# étude pour mesurer |forward|trigger|uncertain|30|Group[1062]|Clement
# étude pour déterminer |forward|trigger|uncertain|30|Group[1062]|Clement
# étude pour expertiser |forward|trigger|uncertain|30|Group[1062]|Clement
# étude _s pour évaluer |forward|trigger|uncertain|30|Group[1062]|Clement
# étude _s pour juger |forward|trigger|uncertain|30|Group[1062]|Clement
# étude _s pour apprécier |forward|trigger|uncertain|30|Group[1062]|Clement
# étude _s pour chiffrer |forward|trigger|uncertain|30|Group[1062]|Clement
# étude _s pour calculer |forward|trigger|uncertain|30|Group[1062]|Clement
# étude _s pour quantifier |forward|trigger|uncertain|30|Group[1062]|Clement
# étude _s pour mesurer |forward|trigger|uncertain|30|Group[1062]|Clement
# étude _s pour déterminer |forward|trigger|uncertain|30|Group[1062]|Clement
# étude _s pour expertiser |forward|trigger|uncertain|30|Group[1062]|Clement
# examen pour évaluer |forward|trigger|uncertain|30|Group[1062]|Clement
# examen pour juger |forward|trigger|uncertain|30|Group[1062]|Clement
# examen pour apprécier |forward|trigger|uncertain|30|Group[1062]|Clement
# examen pour chiffrer |forward|trigger|uncertain|30|Group[1062]|Clement
# examen pour calculer |forward|trigger|uncertain|30|Group[1062]|Clement
# examen pour quantifier |forward|trigger|uncertain|30|Group[1062]|Clement
# examen pour mesurer |forward|trigger|uncertain|30|Group[1062]|Clement
# examen pour déterminer |forward|trigger|uncertain|30|Group[1062]|Clement
# examen pour expertiser |forward|trigger|uncertain|30|Group[1062]|Clement
# examen _s pour évaluer |forward|trigger|uncertain|30|Group[1062]|Clement
# examen _s pour juger |forward|trigger|uncertain|30|Group[1062]|Clement
# examen _s pour apprécier |forward|trigger|uncertain|30|Group[1062]|Clement
# examen _s pour chiffrer |forward|trigger|uncertain|30|Group[1062]|Clement
# examen _s pour calculer |forward|trigger|uncertain|30|Group[1062]|Clement
# examen _s pour quantifier |forward|trigger|uncertain|30|Group[1062]|Clement
# examen _s pour mesurer |forward|trigger|uncertain|30|Group[1062]|Clement
# examen _s pour déterminer |forward|trigger|uncertain|30|Group[1062]|Clement
# examen _s pour expertiser |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation pour évaluer |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation pour juger |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation pour apprécier |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation pour chiffrer |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation pour calculer |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation pour quantifier |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation pour mesurer |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation pour déterminer |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation pour expertiser |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation _s pour évaluer |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation _s pour juger |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation _s pour apprécier |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation _s pour chiffrer |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation _s pour calculer |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation _s pour quantifier |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation _s pour mesurer |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation _s pour déterminer |forward|trigger|uncertain|30|Group[1062]|Clement
# expérimentation _s pour expertiser |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête pour évaluer |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête pour juger |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête pour apprécier |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête pour chiffrer |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête pour calculer |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête pour quantifier |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête pour mesurer |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête pour déterminer |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête pour expertiser |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête _s pour évaluer |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête _s pour juger |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête _s pour apprécier |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête _s pour chiffrer |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête _s pour calculer |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête _s pour quantifier |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête _s pour mesurer |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête _s pour déterminer |forward|trigger|uncertain|30|Group[1062]|Clement
# enquête _s pour expertiser |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse pour évaluer |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse pour juger |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse pour apprécier |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse pour chiffrer |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse pour calculer |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse pour quantifier |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse pour mesurer |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse pour déterminer |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse pour expertiser |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse _s pour évaluer |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse _s pour juger |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse _s pour apprécier |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse _s pour chiffrer |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse _s pour calculer |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse _s pour quantifier |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse _s pour mesurer |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse _s pour déterminer |forward|trigger|uncertain|30|Group[1062]|Clement
# analyse _s pour expertiser |forward|trigger|uncertain|30|Group[1062]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "étude" | "examen" | "expérimentation" | "enquête" | "analyse" | "exploration" | "observation" | "expertise" | "rapport" | "investigation"
Var2 -> "pour"
Var3 -> "évaluer" | "juger" | "apprécier" | "chiffrer" | "calculer" | "quantifier" | "mesurer" | "déterminer" | "expertiser" | "jauger" | "compter" | "peser" | "comparer" | "examiner" | "recenser"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1063]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# étude pour évaluer |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour juger |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour apprécier |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour chiffrer |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour calculer |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour quantifier |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour mesurer |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour déterminer |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour expertiser |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour jauger |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour compter |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour peser |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour comparer |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour examiner |forward|trigger|uncertain|30|Group[1063]|Clement
# étude pour recenser |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour évaluer |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour juger |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour apprécier |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour chiffrer |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour calculer |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour quantifier |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour mesurer |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour déterminer |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour expertiser |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour jauger |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour compter |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour peser |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour comparer |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour examiner |forward|trigger|uncertain|30|Group[1063]|Clement
# examen pour recenser |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour évaluer |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour juger |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour apprécier |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour chiffrer |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour calculer |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour quantifier |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour mesurer |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour déterminer |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour expertiser |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour jauger |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour compter |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour peser |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour comparer |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour examiner |forward|trigger|uncertain|30|Group[1063]|Clement
# expérimentation pour recenser |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour évaluer |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour juger |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour apprécier |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour chiffrer |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour calculer |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour quantifier |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour mesurer |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour déterminer |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour expertiser |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour jauger |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour compter |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour peser |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour comparer |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour examiner |forward|trigger|uncertain|30|Group[1063]|Clement
# enquête pour recenser |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour évaluer |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour juger |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour apprécier |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour chiffrer |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour calculer |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour quantifier |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour mesurer |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour déterminer |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour expertiser |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour jauger |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour compter |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour peser |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour comparer |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour examiner |forward|trigger|uncertain|30|Group[1063]|Clement
# analyse pour recenser |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour évaluer |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour juger |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour apprécier |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour chiffrer |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour calculer |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour quantifier |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour mesurer |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour déterminer |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour expertiser |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour jauger |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour compter |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour peser |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour comparer |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour examiner |forward|trigger|uncertain|30|Group[1063]|Clement
# exploration pour recenser |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour évaluer |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour juger |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour apprécier |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour chiffrer |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour calculer |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour quantifier |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour mesurer |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour déterminer |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour expertiser |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour jauger |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour compter |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour peser |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour comparer |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour examiner |forward|trigger|uncertain|30|Group[1063]|Clement
# observation pour recenser |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour évaluer |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour juger |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour apprécier |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour chiffrer |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour calculer |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour quantifier |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour mesurer |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour déterminer |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour expertiser |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour jauger |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour compter |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour peser |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour comparer |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour examiner |forward|trigger|uncertain|30|Group[1063]|Clement
# expertise pour recenser |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour évaluer |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour juger |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour apprécier |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour chiffrer |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour calculer |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour quantifier |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour mesurer |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour déterminer |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour expertiser |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour jauger |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour compter |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour peser |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour comparer |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour examiner |forward|trigger|uncertain|30|Group[1063]|Clement
# rapport pour recenser |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour évaluer |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour juger |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour apprécier |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour chiffrer |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour calculer |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour quantifier |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour mesurer |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour déterminer |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour expertiser |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour jauger |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour compter |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour peser |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour comparer |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour examiner |forward|trigger|uncertain|30|Group[1063]|Clement
# investigation pour recenser |forward|trigger|uncertain|30|Group[1063]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "apparition" | "arrivée" | "éclosion" | "manifestation" | "éruption" | "naissance" | "survenue" | "émergence" | "poussée"
Var2 -> "soudaine"
Var3 -> "de"
Trigger_Rule -> "|both|pseudo|historical|30|Group[1064]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# apparition soudaine de |both|pseudo|historical|30|Group[1064]|Clement
# arrivée soudaine de |both|pseudo|historical|30|Group[1064]|Clement
# éclosion soudaine de |both|pseudo|historical|30|Group[1064]|Clement
# manifestation soudaine de |both|pseudo|historical|30|Group[1064]|Clement
# éruption soudaine de |both|pseudo|historical|30|Group[1064]|Clement
# naissance soudaine de |both|pseudo|historical|30|Group[1064]|Clement
# survenue soudaine de |both|pseudo|historical|30|Group[1064]|Clement
# émergence soudaine de |both|pseudo|historical|30|Group[1064]|Clement
# poussée soudaine de |both|pseudo|historical|30|Group[1064]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "évocateur" | "évocatoire" | "allusif"
Var2 -> "de"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1089]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# évocateur de |forward|trigger|uncertain|30|Group[1089]|Clement
# évocatoire de |forward|trigger|uncertain|30|Group[1089]|Clement
# allusif de |forward|trigger|uncertain|30|Group[1089]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "suggérer" | "évoquer" | "susciter" | "faire penser à" | "sous-entendre" | "supposer" | "envisager"| "soupçonner" | "pressentir" | "deviner" | "douter" | "présumer" | "entrevoir" | "sentir" | "conjecturer" | "penser" | "imaginer" | "subodorer" | "croire"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1090]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# suggérer |forward|trigger|uncertain|30|Group[1090]|Clement
# évoquer |forward|trigger|uncertain|30|Group[1090]|Clement
# susciter |forward|trigger|uncertain|30|Group[1090]|Clement
# faire penser à |forward|trigger|uncertain|30|Group[1090]|Clement
# sous-entendre |forward|trigger|uncertain|30|Group[1090]|Clement
# supposer |forward|trigger|uncertain|30|Group[1090]|Clement
# envisager |forward|trigger|uncertain|30|Group[1090]|Clement
# soupçonner |forward|trigger|uncertain|30|Group[1090]|Clement
# pressentir |forward|trigger|uncertain|30|Group[1090]|Clement
# deviner |forward|trigger|uncertain|30|Group[1090]|Clement
# douter |forward|trigger|uncertain|30|Group[1090]|Clement
# présumer |forward|trigger|uncertain|30|Group[1090]|Clement
# entrevoir |forward|trigger|uncertain|30|Group[1090]|Clement
# sentir |forward|trigger|uncertain|30|Group[1090]|Clement
# conjecturer |forward|trigger|uncertain|30|Group[1090]|Clement
# penser |forward|trigger|uncertain|30|Group[1090]|Clement
# imaginer |forward|trigger|uncertain|30|Group[1090]|Clement
# subodorer |forward|trigger|uncertain|30|Group[1090]|Clement
# croire |forward|trigger|uncertain|30|Group[1090]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "suggéré" | "évoqué" | "suscité" | "fait penser à" | "sous-entendu" | "supposé" | "envisagé" | "soupçonné" | "pressenti" | "deviné" | "douté" | "présumé" | "entrevu" | "senti" | "conjecturé" | "pensé" | "imaginé" | "subodoré" | "cru"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1091]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# suggéré |forward|trigger|uncertain|30|Group[1091]|Clement
# évoqué |forward|trigger|uncertain|30|Group[1091]|Clement
# suscité |forward|trigger|uncertain|30|Group[1091]|Clement
# fait penser à |forward|trigger|uncertain|30|Group[1091]|Clement
# sous-entendu |forward|trigger|uncertain|30|Group[1091]|Clement
# supposé |forward|trigger|uncertain|30|Group[1091]|Clement
# envisagé |forward|trigger|uncertain|30|Group[1091]|Clement
# soupçonné |forward|trigger|uncertain|30|Group[1091]|Clement
# pressenti |forward|trigger|uncertain|30|Group[1091]|Clement
# deviné |forward|trigger|uncertain|30|Group[1091]|Clement
# douté |forward|trigger|uncertain|30|Group[1091]|Clement
# présumé |forward|trigger|uncertain|30|Group[1091]|Clement
# entrevu |forward|trigger|uncertain|30|Group[1091]|Clement
# senti |forward|trigger|uncertain|30|Group[1091]|Clement
# conjecturé |forward|trigger|uncertain|30|Group[1091]|Clement
# pensé |forward|trigger|uncertain|30|Group[1091]|Clement
# imaginé |forward|trigger|uncertain|30|Group[1091]|Clement
# subodoré |forward|trigger|uncertain|30|Group[1091]|Clement
# cru |forward|trigger|uncertain|30|Group[1091]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "suggére" | "évoque" | "suscite" | "fait penser à" | "sous-entends" | "suppose" | "envisage" | "soupçonne" | "pressentis" | "devine" | "doute" | "présume" | "entrevois" | "sens" | "conjecture" | "pense" | "imagine" | "subodore" | "crois"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1091]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# suggére |forward|trigger|uncertain|30|Group[1091]|Clement
# évoque |forward|trigger|uncertain|30|Group[1091]|Clement
# suscite |forward|trigger|uncertain|30|Group[1091]|Clement
# fait penser à |forward|trigger|uncertain|30|Group[1091]|Clement
# sous-entends |forward|trigger|uncertain|30|Group[1091]|Clement
# suppose |forward|trigger|uncertain|30|Group[1091]|Clement
# envisage |forward|trigger|uncertain|30|Group[1091]|Clement
# soupçonne |forward|trigger|uncertain|30|Group[1091]|Clement
# pressentis |forward|trigger|uncertain|30|Group[1091]|Clement
# devine |forward|trigger|uncertain|30|Group[1091]|Clement
# doute |forward|trigger|uncertain|30|Group[1091]|Clement
# présume |forward|trigger|uncertain|30|Group[1091]|Clement
# entrevois |forward|trigger|uncertain|30|Group[1091]|Clement
# sens |forward|trigger|uncertain|30|Group[1091]|Clement
# conjecture |forward|trigger|uncertain|30|Group[1091]|Clement
# pense |forward|trigger|uncertain|30|Group[1091]|Clement
# imagine |forward|trigger|uncertain|30|Group[1091]|Clement
# subodore |forward|trigger|uncertain|30|Group[1091]|Clement
# crois |forward|trigger|uncertain|30|Group[1091]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "soupçon" | "doute" | "suspicion" | "crainte" | "croyance" | "présomption"  | "supposition"
Var2 -> "de"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1092]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# soupçon de |forward|trigger|uncertain|30|Group[1092]|Clement
# doute de |forward|trigger|uncertain|30|Group[1092]|Clement
# suspicion de |forward|trigger|uncertain|30|Group[1092]|Clement
# crainte de |forward|trigger|uncertain|30|Group[1092]|Clement
# croyance de |forward|trigger|uncertain|30|Group[1092]|Clement
# présomption de |forward|trigger|uncertain|30|Group[1092]|Clement
# supposition de |forward|trigger|uncertain|30|Group[1092]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "méfiant" | "soupçonneux" | "timoré" | "prudent" | "suspicieux" | "dubitatif" | "douteux" | "avec méfiance" | "suspect" | "précautionneux" | "sceptique"
Var2 -> "pour"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1093]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# méfiant pour |forward|trigger|uncertain|30|Group[1093]|Clement
# soupçonneux pour |forward|trigger|uncertain|30|Group[1093]|Clement
# timoré pour |forward|trigger|uncertain|30|Group[1093]|Clement
# prudent pour |forward|trigger|uncertain|30|Group[1093]|Clement
# suspicieux pour |forward|trigger|uncertain|30|Group[1093]|Clement
# dubitatif pour |forward|trigger|uncertain|30|Group[1093]|Clement
# douteux pour |forward|trigger|uncertain|30|Group[1093]|Clement
# avec méfiance pour |forward|trigger|uncertain|30|Group[1093]|Clement
# suspect pour |forward|trigger|uncertain|30|Group[1093]|Clement
# précautionneux pour |forward|trigger|uncertain|30|Group[1093]|Clement
# sceptique pour |forward|trigger|uncertain|30|Group[1093]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Deter Trigger_Rule
Var1 -> "évaluer" | "apprécier" | "mesurer" | "déterminer" | "jauger"
Deter -> "tout" | "tous" | "toute" | "toutes"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1100]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# évaluer tout |forward|trigger|uncertain|30|Group[1100]|Clement
# évaluer tous |forward|trigger|uncertain|30|Group[1100]|Clement
# évaluer toute |forward|trigger|uncertain|30|Group[1100]|Clement
# évaluer toutes |forward|trigger|uncertain|30|Group[1100]|Clement
# apprécier tout |forward|trigger|uncertain|30|Group[1100]|Clement
# apprécier tous |forward|trigger|uncertain|30|Group[1100]|Clement
# apprécier toute |forward|trigger|uncertain|30|Group[1100]|Clement
# apprécier toutes |forward|trigger|uncertain|30|Group[1100]|Clement
# mesurer tout |forward|trigger|uncertain|30|Group[1100]|Clement
# mesurer tous |forward|trigger|uncertain|30|Group[1100]|Clement
# mesurer toute |forward|trigger|uncertain|30|Group[1100]|Clement
# mesurer toutes |forward|trigger|uncertain|30|Group[1100]|Clement
# déterminer tout |forward|trigger|uncertain|30|Group[1100]|Clement
# déterminer tous |forward|trigger|uncertain|30|Group[1100]|Clement
# déterminer toute |forward|trigger|uncertain|30|Group[1100]|Clement
# déterminer toutes |forward|trigger|uncertain|30|Group[1100]|Clement
# jauger tout |forward|trigger|uncertain|30|Group[1100]|Clement
# jauger tous |forward|trigger|uncertain|30|Group[1100]|Clement
# jauger toute |forward|trigger|uncertain|30|Group[1100]|Clement
# jauger toutes |forward|trigger|uncertain|30|Group[1100]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "exclure" | "rejeter" | "proscrire" | "supprimer" | "radier"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1101]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# exclure |forward|trigger|negated|10|Group[1101]|Clement
# rejeter |forward|trigger|negated|10|Group[1101]|Clement
# proscrire |forward|trigger|negated|10|Group[1101]|Clement
# supprimer |forward|trigger|negated|10|Group[1101]|Clement
# radier |forward|trigger|negated|10|Group[1101]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pour"
Var2 -> "prévenir" | "anticiper" | "empêcher" | "éviter" | "se prémunir contre"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[1103]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pour prévenir |forward|trigger|conditional|30|Group[1103]|Clement
# pour anticiper |forward|trigger|conditional|30|Group[1103]|Clement
# pour empêcher |forward|trigger|conditional|30|Group[1103]|Clement
# pour éviter |forward|trigger|conditional|30|Group[1103]|Clement
# pour se prémunir contre |forward|trigger|conditional|30|Group[1103]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "maintenant" | "actuellement" | "aujourd'hui" | "à présent" | "dèsdésormais" | "présentement"
Trigger_Rule -> "|both|termination|historical|30|Group[1104, 1105]|Clement"|"|both|termination|nonpatient|30|Group[1104, 1105]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# maintenant |both|termination|historical|30|Group[1104, 1105]|Clement
# maintenant |both|termination|nonpatient|30|Group[1104, 1105]|Clement
# actuellement |both|termination|historical|30|Group[1104, 1105]|Clement
# actuellement |both|termination|nonpatient|30|Group[1104, 1105]|Clement
# aujourd'hui |both|termination|historical|30|Group[1104, 1105]|Clement
# aujourd'hui |both|termination|nonpatient|30|Group[1104, 1105]|Clement
# à présent |both|termination|historical|30|Group[1104, 1105]|Clement
# à présent |both|termination|nonpatient|30|Group[1104, 1105]|Clement
# dèsdésormais |both|termination|historical|30|Group[1104, 1105]|Clement
# dèsdésormais |both|termination|nonpatient|30|Group[1104, 1105]|Clement
# présentement |both|termination|historical|30|Group[1104, 1105]|Clement
# présentement |both|termination|nonpatient|30|Group[1104, 1105]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "traitement" | "soins" | "cure" | "intervention" | "soin"
Var2 -> "d'" | "de" | "d'un" | "d'une" | "pour"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[1106]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# traitement d' |both|pseudo|uncertain|30|Group[1106]|Clement
# traitement de |both|pseudo|uncertain|30|Group[1106]|Clement
# traitement d'un |both|pseudo|uncertain|30|Group[1106]|Clement
# traitement d'une |both|pseudo|uncertain|30|Group[1106]|Clement
# traitement pour |both|pseudo|uncertain|30|Group[1106]|Clement
# soins d' |both|pseudo|uncertain|30|Group[1106]|Clement
# soins de |both|pseudo|uncertain|30|Group[1106]|Clement
# soins d'un |both|pseudo|uncertain|30|Group[1106]|Clement
# soins d'une |both|pseudo|uncertain|30|Group[1106]|Clement
# soins pour |both|pseudo|uncertain|30|Group[1106]|Clement
# cure d' |both|pseudo|uncertain|30|Group[1106]|Clement
# cure de |both|pseudo|uncertain|30|Group[1106]|Clement
# cure d'un |both|pseudo|uncertain|30|Group[1106]|Clement
# cure d'une |both|pseudo|uncertain|30|Group[1106]|Clement
# cure pour |both|pseudo|uncertain|30|Group[1106]|Clement
# intervention d' |both|pseudo|uncertain|30|Group[1106]|Clement
# intervention de |both|pseudo|uncertain|30|Group[1106]|Clement
# intervention d'un |both|pseudo|uncertain|30|Group[1106]|Clement
# intervention d'une |both|pseudo|uncertain|30|Group[1106]|Clement
# intervention pour |both|pseudo|uncertain|30|Group[1106]|Clement
# soin d' |both|pseudo|uncertain|30|Group[1106]|Clement
# soin de |both|pseudo|uncertain|30|Group[1106]|Clement
# soin d'un |both|pseudo|uncertain|30|Group[1106]|Clement
# soin d'une |both|pseudo|uncertain|30|Group[1106]|Clement
# soin pour |both|pseudo|uncertain|30|Group[1106]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "événement" | "épisode" | "incident" | "fait"
Var2 -> "déclencheur"
Var3 -> "d'" | "de" | "d'un" | "d'une" | "pour"
Trigger_Rule -> "|forward|termination|negated|10|Group[1107]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# événement déclencheur d' |forward|termination|negated|10|Group[1107]|Clement
# événement déclencheur de |forward|termination|negated|10|Group[1107]|Clement
# événement déclencheur d'un |forward|termination|negated|10|Group[1107]|Clement
# événement déclencheur d'une |forward|termination|negated|10|Group[1107]|Clement
# événement déclencheur pour |forward|termination|negated|10|Group[1107]|Clement
# épisode déclencheur d' |forward|termination|negated|10|Group[1107]|Clement
# épisode déclencheur de |forward|termination|negated|10|Group[1107]|Clement
# épisode déclencheur d'un |forward|termination|negated|10|Group[1107]|Clement
# épisode déclencheur d'une |forward|termination|negated|10|Group[1107]|Clement
# épisode déclencheur pour |forward|termination|negated|10|Group[1107]|Clement
# incident déclencheur d' |forward|termination|negated|10|Group[1107]|Clement
# incident déclencheur de |forward|termination|negated|10|Group[1107]|Clement
# incident déclencheur d'un |forward|termination|negated|10|Group[1107]|Clement
# incident déclencheur d'une |forward|termination|negated|10|Group[1107]|Clement
# incident déclencheur pour |forward|termination|negated|10|Group[1107]|Clement
# fait déclencheur d' |forward|termination|negated|10|Group[1107]|Clement
# fait déclencheur de |forward|termination|negated|10|Group[1107]|Clement
# fait déclencheur d'un |forward|termination|negated|10|Group[1107]|Clement
# fait déclencheur d'une |forward|termination|negated|10|Group[1107]|Clement
# fait déclencheur pour |forward|termination|negated|10|Group[1107]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "dose" | "mesure" | "quantité" | "proportion" | "dôse"
Var2 -> "incertaine"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[1109]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# dose incertaine |both|pseudo|uncertain|30|Group[1109]|Clement
# mesure incertaine |both|pseudo|uncertain|30|Group[1109]|Clement
# quantité incertaine |both|pseudo|uncertain|30|Group[1109]|Clement
# proportion incertaine |both|pseudo|uncertain|30|Group[1109]|Clement
# dôse incertaine |both|pseudo|uncertain|30|Group[1109]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "pas"
Var2 -> "clair" | "sûr" | "certain" | "garanti"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1110]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pas clair |forward|trigger|uncertain|30|Group[1110]|Clement
# pas sûr |forward|trigger|uncertain|30|Group[1110]|Clement
# pas certain |forward|trigger|uncertain|30|Group[1110]|Clement
# pas garanti |forward|trigger|uncertain|30|Group[1110]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "peu"
Var2 -> "probable" | "plausible"
Trigger_Rule -> "|backward|trigger|negated|10|Group[1112]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peu probable |backward|trigger|negated|10|Group[1112]|Clement
# peu plausible |backward|trigger|negated|10|Group[1112]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "noter" | "constater" | "relever" | "remarquer" | "observer"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans noter |forward|trigger|negated|10|Group[1117]|Clement
# sans constater |forward|trigger|negated|10|Group[1117]|Clement
# sans relever |forward|trigger|negated|10|Group[1117]|Clement
# sans remarquer |forward|trigger|negated|10|Group[1117]|Clement
# sans observer |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "aucun" | "aucune" | "nul" | "nulle" | "sans"
Var2 -> "indication" | "avertissement" | "prescription" | "directive" | "annotation" | "explication" | "renvoi" | "information" | "note" | "recommandation" | "critère" | "notation" | "suggestion" | "mention" | "symptôme"
Var3 -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun indication d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun indication de |forward|trigger|negated|10|Group[1117]|Clement
# aucun indication d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun indication d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun avertissement d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun avertissement de |forward|trigger|negated|10|Group[1117]|Clement
# aucun avertissement d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun avertissement d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun prescription d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun prescription de |forward|trigger|negated|10|Group[1117]|Clement
# aucun prescription d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun prescription d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun directive d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun directive de |forward|trigger|negated|10|Group[1117]|Clement
# aucun directive d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun directive d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun annotation d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun annotation de |forward|trigger|negated|10|Group[1117]|Clement
# aucun annotation d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun annotation d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun explication d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun explication de |forward|trigger|negated|10|Group[1117]|Clement
# aucun explication d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun explication d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun renvoi d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun renvoi de |forward|trigger|negated|10|Group[1117]|Clement
# aucun renvoi d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun renvoi d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun information d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun information de |forward|trigger|negated|10|Group[1117]|Clement
# aucun information d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun information d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun note d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun note de |forward|trigger|negated|10|Group[1117]|Clement
# aucun note d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun note d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun recommandation d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun recommandation de |forward|trigger|negated|10|Group[1117]|Clement
# aucun recommandation d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun recommandation d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun critère d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun critère de |forward|trigger|negated|10|Group[1117]|Clement
# aucun critère d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun critère d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun notation d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun notation de |forward|trigger|negated|10|Group[1117]|Clement
# aucun notation d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun notation d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun suggestion d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun suggestion de |forward|trigger|negated|10|Group[1117]|Clement
# aucun suggestion d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun suggestion d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun mention d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun mention de |forward|trigger|negated|10|Group[1117]|Clement
# aucun mention d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun mention d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucun symptôme d' |forward|trigger|negated|10|Group[1117]|Clement
# aucun symptôme de |forward|trigger|negated|10|Group[1117]|Clement
# aucun symptôme d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucun symptôme d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune indication d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune indication de |forward|trigger|negated|10|Group[1117]|Clement
# aucune indication d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune indication d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune avertissement d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune avertissement de |forward|trigger|negated|10|Group[1117]|Clement
# aucune avertissement d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune avertissement d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune prescription d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune prescription de |forward|trigger|negated|10|Group[1117]|Clement
# aucune prescription d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune prescription d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune directive d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune directive de |forward|trigger|negated|10|Group[1117]|Clement
# aucune directive d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune directive d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune annotation d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune annotation de |forward|trigger|negated|10|Group[1117]|Clement
# aucune annotation d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune annotation d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune explication d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune explication de |forward|trigger|negated|10|Group[1117]|Clement
# aucune explication d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune explication d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune renvoi d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune renvoi de |forward|trigger|negated|10|Group[1117]|Clement
# aucune renvoi d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune renvoi d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune information d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune information de |forward|trigger|negated|10|Group[1117]|Clement
# aucune information d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune information d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune note d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune note de |forward|trigger|negated|10|Group[1117]|Clement
# aucune note d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune note d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune recommandation d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune recommandation de |forward|trigger|negated|10|Group[1117]|Clement
# aucune recommandation d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune recommandation d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune critère d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune critère de |forward|trigger|negated|10|Group[1117]|Clement
# aucune critère d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune critère d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune notation d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune notation de |forward|trigger|negated|10|Group[1117]|Clement
# aucune notation d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune notation d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune suggestion d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune suggestion de |forward|trigger|negated|10|Group[1117]|Clement
# aucune suggestion d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune suggestion d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune mention d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune mention de |forward|trigger|negated|10|Group[1117]|Clement
# aucune mention d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune mention d'une |forward|trigger|negated|10|Group[1117]|Clement
# aucune symptôme d' |forward|trigger|negated|10|Group[1117]|Clement
# aucune symptôme de |forward|trigger|negated|10|Group[1117]|Clement
# aucune symptôme d'un |forward|trigger|negated|10|Group[1117]|Clement
# aucune symptôme d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul indication d' |forward|trigger|negated|10|Group[1117]|Clement
# nul indication de |forward|trigger|negated|10|Group[1117]|Clement
# nul indication d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul indication d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul avertissement d' |forward|trigger|negated|10|Group[1117]|Clement
# nul avertissement de |forward|trigger|negated|10|Group[1117]|Clement
# nul avertissement d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul avertissement d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul prescription d' |forward|trigger|negated|10|Group[1117]|Clement
# nul prescription de |forward|trigger|negated|10|Group[1117]|Clement
# nul prescription d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul prescription d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul directive d' |forward|trigger|negated|10|Group[1117]|Clement
# nul directive de |forward|trigger|negated|10|Group[1117]|Clement
# nul directive d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul directive d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul annotation d' |forward|trigger|negated|10|Group[1117]|Clement
# nul annotation de |forward|trigger|negated|10|Group[1117]|Clement
# nul annotation d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul annotation d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul explication d' |forward|trigger|negated|10|Group[1117]|Clement
# nul explication de |forward|trigger|negated|10|Group[1117]|Clement
# nul explication d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul explication d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul renvoi d' |forward|trigger|negated|10|Group[1117]|Clement
# nul renvoi de |forward|trigger|negated|10|Group[1117]|Clement
# nul renvoi d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul renvoi d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul information d' |forward|trigger|negated|10|Group[1117]|Clement
# nul information de |forward|trigger|negated|10|Group[1117]|Clement
# nul information d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul information d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul note d' |forward|trigger|negated|10|Group[1117]|Clement
# nul note de |forward|trigger|negated|10|Group[1117]|Clement
# nul note d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul note d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul recommandation d' |forward|trigger|negated|10|Group[1117]|Clement
# nul recommandation de |forward|trigger|negated|10|Group[1117]|Clement
# nul recommandation d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul recommandation d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul critère d' |forward|trigger|negated|10|Group[1117]|Clement
# nul critère de |forward|trigger|negated|10|Group[1117]|Clement
# nul critère d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul critère d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul notation d' |forward|trigger|negated|10|Group[1117]|Clement
# nul notation de |forward|trigger|negated|10|Group[1117]|Clement
# nul notation d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul notation d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul suggestion d' |forward|trigger|negated|10|Group[1117]|Clement
# nul suggestion de |forward|trigger|negated|10|Group[1117]|Clement
# nul suggestion d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul suggestion d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul mention d' |forward|trigger|negated|10|Group[1117]|Clement
# nul mention de |forward|trigger|negated|10|Group[1117]|Clement
# nul mention d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul mention d'une |forward|trigger|negated|10|Group[1117]|Clement
# nul symptôme d' |forward|trigger|negated|10|Group[1117]|Clement
# nul symptôme de |forward|trigger|negated|10|Group[1117]|Clement
# nul symptôme d'un |forward|trigger|negated|10|Group[1117]|Clement
# nul symptôme d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle indication d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle indication de |forward|trigger|negated|10|Group[1117]|Clement
# nulle indication d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle indication d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle avertissement d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle avertissement de |forward|trigger|negated|10|Group[1117]|Clement
# nulle avertissement d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle avertissement d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle prescription d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle prescription de |forward|trigger|negated|10|Group[1117]|Clement
# nulle prescription d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle prescription d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle directive d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle directive de |forward|trigger|negated|10|Group[1117]|Clement
# nulle directive d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle directive d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle annotation d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle annotation de |forward|trigger|negated|10|Group[1117]|Clement
# nulle annotation d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle annotation d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle explication d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle explication de |forward|trigger|negated|10|Group[1117]|Clement
# nulle explication d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle explication d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle renvoi d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle renvoi de |forward|trigger|negated|10|Group[1117]|Clement
# nulle renvoi d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle renvoi d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle information d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle information de |forward|trigger|negated|10|Group[1117]|Clement
# nulle information d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle information d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle note d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle note de |forward|trigger|negated|10|Group[1117]|Clement
# nulle note d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle note d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle recommandation d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle recommandation de |forward|trigger|negated|10|Group[1117]|Clement
# nulle recommandation d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle recommandation d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle critère d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle critère de |forward|trigger|negated|10|Group[1117]|Clement
# nulle critère d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle critère d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle notation d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle notation de |forward|trigger|negated|10|Group[1117]|Clement
# nulle notation d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle notation d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle suggestion d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle suggestion de |forward|trigger|negated|10|Group[1117]|Clement
# nulle suggestion d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle suggestion d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle mention d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle mention de |forward|trigger|negated|10|Group[1117]|Clement
# nulle mention d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle mention d'une |forward|trigger|negated|10|Group[1117]|Clement
# nulle symptôme d' |forward|trigger|negated|10|Group[1117]|Clement
# nulle symptôme de |forward|trigger|negated|10|Group[1117]|Clement
# nulle symptôme d'un |forward|trigger|negated|10|Group[1117]|Clement
# nulle symptôme d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans indication d' |forward|trigger|negated|10|Group[1117]|Clement
# sans indication de |forward|trigger|negated|10|Group[1117]|Clement
# sans indication d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans indication d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans avertissement d' |forward|trigger|negated|10|Group[1117]|Clement
# sans avertissement de |forward|trigger|negated|10|Group[1117]|Clement
# sans avertissement d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans avertissement d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans prescription d' |forward|trigger|negated|10|Group[1117]|Clement
# sans prescription de |forward|trigger|negated|10|Group[1117]|Clement
# sans prescription d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans prescription d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans directive d' |forward|trigger|negated|10|Group[1117]|Clement
# sans directive de |forward|trigger|negated|10|Group[1117]|Clement
# sans directive d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans directive d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans annotation d' |forward|trigger|negated|10|Group[1117]|Clement
# sans annotation de |forward|trigger|negated|10|Group[1117]|Clement
# sans annotation d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans annotation d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans explication d' |forward|trigger|negated|10|Group[1117]|Clement
# sans explication de |forward|trigger|negated|10|Group[1117]|Clement
# sans explication d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans explication d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans renvoi d' |forward|trigger|negated|10|Group[1117]|Clement
# sans renvoi de |forward|trigger|negated|10|Group[1117]|Clement
# sans renvoi d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans renvoi d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans information d' |forward|trigger|negated|10|Group[1117]|Clement
# sans information de |forward|trigger|negated|10|Group[1117]|Clement
# sans information d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans information d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans note d' |forward|trigger|negated|10|Group[1117]|Clement
# sans note de |forward|trigger|negated|10|Group[1117]|Clement
# sans note d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans note d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans recommandation d' |forward|trigger|negated|10|Group[1117]|Clement
# sans recommandation de |forward|trigger|negated|10|Group[1117]|Clement
# sans recommandation d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans recommandation d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans critère d' |forward|trigger|negated|10|Group[1117]|Clement
# sans critère de |forward|trigger|negated|10|Group[1117]|Clement
# sans critère d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans critère d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans notation d' |forward|trigger|negated|10|Group[1117]|Clement
# sans notation de |forward|trigger|negated|10|Group[1117]|Clement
# sans notation d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans notation d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans suggestion d' |forward|trigger|negated|10|Group[1117]|Clement
# sans suggestion de |forward|trigger|negated|10|Group[1117]|Clement
# sans suggestion d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans suggestion d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans mention d' |forward|trigger|negated|10|Group[1117]|Clement
# sans mention de |forward|trigger|negated|10|Group[1117]|Clement
# sans mention d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans mention d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans symptôme d' |forward|trigger|negated|10|Group[1117]|Clement
# sans symptôme de |forward|trigger|negated|10|Group[1117]|Clement
# sans symptôme d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans symptôme d'une |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "aucun" | "aucune" | "nul" | "nulle" | "sans"
Var2 -> "douleur" | "souffrance" | "mal" | "supplice" | "nuisance" | "nouvel"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# aucun douleur |forward|trigger|negated|10|Group[1117]|Clement
# aucun souffrance |forward|trigger|negated|10|Group[1117]|Clement
# aucun mal |forward|trigger|negated|10|Group[1117]|Clement
# aucun supplice |forward|trigger|negated|10|Group[1117]|Clement
# aucun nuisance |forward|trigger|negated|10|Group[1117]|Clement
# aucun nouvel |forward|trigger|negated|10|Group[1117]|Clement
# aucune douleur |forward|trigger|negated|10|Group[1117]|Clement
# aucune souffrance |forward|trigger|negated|10|Group[1117]|Clement
# aucune mal |forward|trigger|negated|10|Group[1117]|Clement
# aucune supplice |forward|trigger|negated|10|Group[1117]|Clement
# aucune nuisance |forward|trigger|negated|10|Group[1117]|Clement
# aucune nouvel |forward|trigger|negated|10|Group[1117]|Clement
# nul douleur |forward|trigger|negated|10|Group[1117]|Clement
# nul souffrance |forward|trigger|negated|10|Group[1117]|Clement
# nul mal |forward|trigger|negated|10|Group[1117]|Clement
# nul supplice |forward|trigger|negated|10|Group[1117]|Clement
# nul nuisance |forward|trigger|negated|10|Group[1117]|Clement
# nul nouvel |forward|trigger|negated|10|Group[1117]|Clement
# nulle douleur |forward|trigger|negated|10|Group[1117]|Clement
# nulle souffrance |forward|trigger|negated|10|Group[1117]|Clement
# nulle mal |forward|trigger|negated|10|Group[1117]|Clement
# nulle supplice |forward|trigger|negated|10|Group[1117]|Clement
# nulle nuisance |forward|trigger|negated|10|Group[1117]|Clement
# nulle nouvel |forward|trigger|negated|10|Group[1117]|Clement
# sans douleur |forward|trigger|negated|10|Group[1117]|Clement
# sans souffrance |forward|trigger|negated|10|Group[1117]|Clement
# sans mal |forward|trigger|negated|10|Group[1117]|Clement
# sans supplice |forward|trigger|negated|10|Group[1117]|Clement
# sans nuisance |forward|trigger|negated|10|Group[1117]|Clement
# sans nouvel |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "monter" | "élever" | "rehausser" | "relever" | "hausser" | "remonter" | "réhausser" | "intensifier" | "accroître" | "accentuer" | "amplifier"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans monter |forward|trigger|negated|10|Group[1117]|Clement
# sans élever |forward|trigger|negated|10|Group[1117]|Clement
# sans rehausser |forward|trigger|negated|10|Group[1117]|Clement
# sans relever |forward|trigger|negated|10|Group[1117]|Clement
# sans hausser |forward|trigger|negated|10|Group[1117]|Clement
# sans remonter |forward|trigger|negated|10|Group[1117]|Clement
# sans réhausser |forward|trigger|negated|10|Group[1117]|Clement
# sans intensifier |forward|trigger|negated|10|Group[1117]|Clement
# sans accroître |forward|trigger|negated|10|Group[1117]|Clement
# sans accentuer |forward|trigger|negated|10|Group[1117]|Clement
# sans amplifier |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "nouveau" | "récent" | "nouvelle" | "récente" | "nouvel"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans nouveau |forward|trigger|negated|10|Group[1117]|Clement
# sans récent |forward|trigger|negated|10|Group[1117]|Clement
# sans nouvelle |forward|trigger|negated|10|Group[1117]|Clement
# sans récente |forward|trigger|negated|10|Group[1117]|Clement
# sans nouvel |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "avoir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans avoir |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "certains"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans certains |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "beaucoup"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans beaucoup |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "éprouver" | "ressentir" | "sentir" | "souffrir" | "endurer"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans éprouver |forward|trigger|negated|10|Group[1117]|Clement
# sans ressentir |forward|trigger|negated|10|Group[1117]|Clement
# sans sentir |forward|trigger|negated|10|Group[1117]|Clement
# sans souffrir |forward|trigger|negated|10|Group[1117]|Clement
# sans endurer |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "remarquer" | "considérer" | "noter" | "observer" | "constater" | "distinguer" | "découvrir" | "observer" | "percevoir" | "voir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans remarquer |forward|trigger|negated|10|Group[1117]|Clement
# sans considérer |forward|trigger|negated|10|Group[1117]|Clement
# sans noter |forward|trigger|negated|10|Group[1117]|Clement
# sans observer |forward|trigger|negated|10|Group[1117]|Clement
# sans constater |forward|trigger|negated|10|Group[1117]|Clement
# sans distinguer |forward|trigger|negated|10|Group[1117]|Clement
# sans découvrir |forward|trigger|negated|10|Group[1117]|Clement
# sans observer |forward|trigger|negated|10|Group[1117]|Clement
# sans percevoir |forward|trigger|negated|10|Group[1117]|Clement
# sans voir |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "augmentation" | "extension" | "amplification" | "allongement" | "addition" | "élévation" | "hausse" | "aggravation" | "agrandissement" | "intensification" | "redoublement" | "dilatation" | "croissance" | "développement" | "montée"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans augmentation |forward|trigger|negated|10|Group[1117]|Clement
# sans extension |forward|trigger|negated|10|Group[1117]|Clement
# sans amplification |forward|trigger|negated|10|Group[1117]|Clement
# sans allongement |forward|trigger|negated|10|Group[1117]|Clement
# sans addition |forward|trigger|negated|10|Group[1117]|Clement
# sans élévation |forward|trigger|negated|10|Group[1117]|Clement
# sans hausse |forward|trigger|negated|10|Group[1117]|Clement
# sans aggravation |forward|trigger|negated|10|Group[1117]|Clement
# sans agrandissement |forward|trigger|negated|10|Group[1117]|Clement
# sans intensification |forward|trigger|negated|10|Group[1117]|Clement
# sans redoublement |forward|trigger|negated|10|Group[1117]|Clement
# sans dilatation |forward|trigger|negated|10|Group[1117]|Clement
# sans croissance |forward|trigger|negated|10|Group[1117]|Clement
# sans développement |forward|trigger|negated|10|Group[1117]|Clement
# sans montée |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 ->  "net" | "clair"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans net |forward|trigger|negated|10|Group[1117]|Clement
# sans clair |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "utiliser" | "exploiter" | "manipuler" | "user"| "recourir" | "manier" | "se servir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans utiliser |forward|trigger|negated|10|Group[1117]|Clement
# sans exploiter |forward|trigger|negated|10|Group[1117]|Clement
# sans manipuler |forward|trigger|negated|10|Group[1117]|Clement
# sans user |forward|trigger|negated|10|Group[1117]|Clement
# sans recourir |forward|trigger|negated|10|Group[1117]|Clement
# sans manier |forward|trigger|negated|10|Group[1117]|Clement
# sans se servir |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "rapport" | "correspondance" | "relation" | "ressemblance" | "analogie" | "corrélation" | "concordance" | "rapprochement"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans rapport |forward|trigger|negated|10|Group[1117]|Clement
# sans correspondance |forward|trigger|negated|10|Group[1117]|Clement
# sans relation |forward|trigger|negated|10|Group[1117]|Clement
# sans ressemblance |forward|trigger|negated|10|Group[1117]|Clement
# sans analogie |forward|trigger|negated|10|Group[1117]|Clement
# sans corrélation |forward|trigger|negated|10|Group[1117]|Clement
# sans concordance |forward|trigger|negated|10|Group[1117]|Clement
# sans rapprochement |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "évidence" | "certitude"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans évidence |forward|trigger|negated|10|Group[1117]|Clement
# sans certitude |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "sans"
Var2 -> "mention" | "évocation" | "notation" | "signalement" | "note" | "expression" | "référence" | "allusion"
Var3 -> "d'" | "de" | "d'un" | "d'une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans mention d' |forward|trigger|negated|10|Group[1117]|Clement
# sans mention de |forward|trigger|negated|10|Group[1117]|Clement
# sans mention d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans mention d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans évocation d' |forward|trigger|negated|10|Group[1117]|Clement
# sans évocation de |forward|trigger|negated|10|Group[1117]|Clement
# sans évocation d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans évocation d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans notation d' |forward|trigger|negated|10|Group[1117]|Clement
# sans notation de |forward|trigger|negated|10|Group[1117]|Clement
# sans notation d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans notation d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans signalement d' |forward|trigger|negated|10|Group[1117]|Clement
# sans signalement de |forward|trigger|negated|10|Group[1117]|Clement
# sans signalement d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans signalement d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans note d' |forward|trigger|negated|10|Group[1117]|Clement
# sans note de |forward|trigger|negated|10|Group[1117]|Clement
# sans note d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans note d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans expression d' |forward|trigger|negated|10|Group[1117]|Clement
# sans expression de |forward|trigger|negated|10|Group[1117]|Clement
# sans expression d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans expression d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans référence d' |forward|trigger|negated|10|Group[1117]|Clement
# sans référence de |forward|trigger|negated|10|Group[1117]|Clement
# sans référence d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans référence d'une |forward|trigger|negated|10|Group[1117]|Clement
# sans allusion d' |forward|trigger|negated|10|Group[1117]|Clement
# sans allusion de |forward|trigger|negated|10|Group[1117]|Clement
# sans allusion d'un |forward|trigger|negated|10|Group[1117]|Clement
# sans allusion d'une |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Article Trigger_Rule
Var1 -> "sans"
Article -> "l'" | "le" | "la" | "un" | "une"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans l' |forward|trigger|negated|10|Group[1117]|Clement
# sans le |forward|trigger|negated|10|Group[1117]|Clement
# sans la |forward|trigger|negated|10|Group[1117]|Clement
# sans un |forward|trigger|negated|10|Group[1117]|Clement
# sans une |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "périphérique"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans périphérique |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "plus"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1117]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans plus |forward|trigger|negated|10|Group[1117]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "souhaiter" | "convoiter" | "réclamer" | "tenir à" 
Trigger_Rule -> "|forward|trigger|conditional|30|Group[1129]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# souhaiter |forward|trigger|conditional|30|Group[1129]|Clement
# convoiter |forward|trigger|conditional|30|Group[1129]|Clement
# réclamer |forward|trigger|conditional|30|Group[1129]|Clement
# tenir à |forward|trigger|conditional|30|Group[1129]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Word Var3 Trigger_Rule
Var1 -> "a" | "ont" 
Var2 -> "été"
Word -> "\\w+"
Var3 -> "négatif" | "négatifs" | "négative" | "négatives" 

Trigger_Rule -> "|backward|trigger|negated|10|Group[1130, 1131]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a été \w+ négatif |backward|trigger|negated|10|Group[1130, 1131]|Clement
# a été \w+ négatifs |backward|trigger|negated|10|Group[1130, 1131]|Clement
# a été \w+ négative |backward|trigger|negated|10|Group[1130, 1131]|Clement
# a été \w+ négatives |backward|trigger|negated|10|Group[1130, 1131]|Clement
# ont été \w+ négatif |backward|trigger|negated|10|Group[1130, 1131]|Clement
# ont été \w+ négatifs |backward|trigger|negated|10|Group[1130, 1131]|Clement
# ont été \w+ négative |backward|trigger|negated|10|Group[1130, 1131]|Clement
# ont été \w+ négatives |backward|trigger|negated|10|Group[1130, 1131]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "a" | "ont" 
Var2 -> "été"
Var3 -> "trouvée" | "trouvé" | "reconnu" | "résolu" | "détecté" | "relevé" | "vu"
Trigger_Rule -> "|both|termination|historical|30|Group[1132, 1133]|Clement"|"|both|termination|nonpatient|30|Group[1132, 1133]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a été trouvée |both|termination|historical|30|Group[1132, 1133]|Clement
# a été trouvée |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# a été trouvé |both|termination|historical|30|Group[1132, 1133]|Clement
# a été trouvé |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# a été reconnu |both|termination|historical|30|Group[1132, 1133]|Clement
# a été reconnu |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# a été résolu |both|termination|historical|30|Group[1132, 1133]|Clement
# a été résolu |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# a été détecté |both|termination|historical|30|Group[1132, 1133]|Clement
# a été détecté |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# a été relevé |both|termination|historical|30|Group[1132, 1133]|Clement
# a été relevé |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# a été vu |both|termination|historical|30|Group[1132, 1133]|Clement
# a été vu |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# ont été trouvée |both|termination|historical|30|Group[1132, 1133]|Clement
# ont été trouvée |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# ont été trouvé |both|termination|historical|30|Group[1132, 1133]|Clement
# ont été trouvé |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# ont été reconnu |both|termination|historical|30|Group[1132, 1133]|Clement
# ont été reconnu |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# ont été résolu |both|termination|historical|30|Group[1132, 1133]|Clement
# ont été résolu |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# ont été détecté |both|termination|historical|30|Group[1132, 1133]|Clement
# ont été détecté |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# ont été relevé |both|termination|historical|30|Group[1132, 1133]|Clement
# ont été relevé |both|termination|nonpatient|30|Group[1132, 1133]|Clement
# ont été vu |both|termination|historical|30|Group[1132, 1133]|Clement
# ont été vu |both|termination|nonpatient|30|Group[1132, 1133]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Word Var2 Trigger_Rule
Var1 -> "était"
Word -> "\\w+"
Var2 -> "suspecté" | "pressenti" | "conjecturé"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[1134]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# était \w+ suspecté |backward|trigger|uncertain|30|Group[1134]|Clement
# était \w+ pressenti |backward|trigger|uncertain|30|Group[1134]|Clement
# était \w+ conjecturé |backward|trigger|uncertain|30|Group[1134]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Word Var2 Trigger_Rule
Var1 -> "étaient"
Word -> "\\w+"
Var2 -> "suspectés" | "pressentis" | "conjecturés"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[1134]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# étaient \w+ suspectés |backward|trigger|uncertain|30|Group[1134]|Clement
# étaient \w+ pressentis |backward|trigger|uncertain|30|Group[1134]|Clement
# étaient \w+ conjecturés |backward|trigger|uncertain|30|Group[1134]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "a"| "ont" 
Var2 -> "été"
Var3 -> "chargé" | "délégué" | "confié"
Trigger_Rule -> "|both|termination|historical|30|Group[1135, 1136]|Clement"|"|both|termination|nonpatient|30|Group[1135, 1136]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a été chargé |both|termination|historical|30|Group[1135, 1136]|Clement
# a été chargé |both|termination|nonpatient|30|Group[1135, 1136]|Clement
# a été délégué |both|termination|historical|30|Group[1135, 1136]|Clement
# a été délégué |both|termination|nonpatient|30|Group[1135, 1136]|Clement
# a été confié |both|termination|historical|30|Group[1135, 1136]|Clement
# a été confié |both|termination|nonpatient|30|Group[1135, 1136]|Clement
# ont été chargé |both|termination|historical|30|Group[1135, 1136]|Clement
# ont été chargé |both|termination|nonpatient|30|Group[1135, 1136]|Clement
# ont été délégué |both|termination|historical|30|Group[1135, 1136]|Clement
# ont été délégué |both|termination|nonpatient|30|Group[1135, 1136]|Clement
# ont été confié |both|termination|historical|30|Group[1135, 1136]|Clement
# ont été confié |both|termination|nonpatient|30|Group[1135, 1136]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "était"
Var2 -> "négatif" | "négative" | "nulle"
Trigger_Rule -> "|backward|trigger|negated|10|Group[1137]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# était négatif |backward|trigger|negated|10|Group[1137]|Clement
# était négative |backward|trigger|negated|10|Group[1137]|Clement
# était nulle |backward|trigger|negated|10|Group[1137]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "étaitent"
Var2 -> "négatifs" | "négatives" | "nulles"
Trigger_Rule -> "|backward|trigger|negated|10|Group[1137]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# étaitent négatifs |backward|trigger|negated|10|Group[1137]|Clement
# étaitent négatives |backward|trigger|negated|10|Group[1137]|Clement
# étaitent nulles |backward|trigger|negated|10|Group[1137]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->   Var1 Var2 Trigger_Rule
Var1 -> "n'était" | "n'étaient"
Var2 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1141]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'était pas |forward|trigger|negated|10|Group[1141]|Clement
# n'étaient pas |forward|trigger|negated|10|Group[1141]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Termin Trigger_Rule
Var1 -> "a"
Var2 -> "été"
Var3 -> "arrêté" | "stoppé" | "enrayé" | "contenu" | "suspendu" | "jugulé" | "terminé" | "fini" | "endigué" | "cesseé" | "interrompu"
Termin -> |"_e"
Trigger_Rule -> "|backward|trigger|negated|10|Group[1145]|Clement"|"|forward|termination|negated|10|Group[1147, 1148]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a été arrêté |backward|trigger|negated|10|Group[1145]|Clement
# a été arrêté |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été arrêté _e |backward|trigger|negated|10|Group[1145]|Clement
# a été arrêté _e |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été stoppé |backward|trigger|negated|10|Group[1145]|Clement
# a été stoppé |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été stoppé _e |backward|trigger|negated|10|Group[1145]|Clement
# a été stoppé _e |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été enrayé |backward|trigger|negated|10|Group[1145]|Clement
# a été enrayé |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été enrayé _e |backward|trigger|negated|10|Group[1145]|Clement
# a été enrayé _e |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été contenu |backward|trigger|negated|10|Group[1145]|Clement
# a été contenu |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été contenu _e |backward|trigger|negated|10|Group[1145]|Clement
# a été contenu _e |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été suspendu |backward|trigger|negated|10|Group[1145]|Clement
# a été suspendu |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été suspendu _e |backward|trigger|negated|10|Group[1145]|Clement
# a été suspendu _e |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été jugulé |backward|trigger|negated|10|Group[1145]|Clement
# a été jugulé |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été jugulé _e |backward|trigger|negated|10|Group[1145]|Clement
# a été jugulé _e |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été terminé |backward|trigger|negated|10|Group[1145]|Clement
# a été terminé |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été terminé _e |backward|trigger|negated|10|Group[1145]|Clement
# a été terminé _e |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été fini |backward|trigger|negated|10|Group[1145]|Clement
# a été fini |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été fini _e |backward|trigger|negated|10|Group[1145]|Clement
# a été fini _e |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été endigué |backward|trigger|negated|10|Group[1145]|Clement
# a été endigué |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été endigué _e |backward|trigger|negated|10|Group[1145]|Clement
# a été endigué _e |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été cesseé |backward|trigger|negated|10|Group[1145]|Clement
# a été cesseé |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été cesseé _e |backward|trigger|negated|10|Group[1145]|Clement
# a été cesseé _e |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été interrompu |backward|trigger|negated|10|Group[1145]|Clement
# a été interrompu |forward|termination|negated|10|Group[1147, 1148]|Clement
# a été interrompu _e |backward|trigger|negated|10|Group[1145]|Clement
# a été interrompu _e |forward|termination|negated|10|Group[1147, 1148]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Termin Trigger_Rule
Var1 -> "ont"
Var2 -> "été"
Var3 -> "arrêté" | "stoppé" | "enrayé" | "contenu" | "suspendu" | "jugulé" | "terminé" | "fini" | "endigué" | "cesseé" | "interrompu"
Termin -> "_s"|"_es"
Trigger_Rule -> "|backward|trigger|negated|10|Group[1145]|Clement"|"forward|termination|negated|10|Group[1147, 1148]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ont été arrêté _s |backward|trigger|negated|10|Group[1145]|Clement
# ont été arrêté _s forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été arrêté _es |backward|trigger|negated|10|Group[1145]|Clement
# ont été arrêté _es forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été stoppé _s |backward|trigger|negated|10|Group[1145]|Clement
# ont été stoppé _s forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été stoppé _es |backward|trigger|negated|10|Group[1145]|Clement
# ont été stoppé _es forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été enrayé _s |backward|trigger|negated|10|Group[1145]|Clement
# ont été enrayé _s forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été enrayé _es |backward|trigger|negated|10|Group[1145]|Clement
# ont été enrayé _es forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été contenu _s |backward|trigger|negated|10|Group[1145]|Clement
# ont été contenu _s forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été contenu _es |backward|trigger|negated|10|Group[1145]|Clement
# ont été contenu _es forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été suspendu _s |backward|trigger|negated|10|Group[1145]|Clement
# ont été suspendu _s forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été suspendu _es |backward|trigger|negated|10|Group[1145]|Clement
# ont été suspendu _es forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été jugulé _s |backward|trigger|negated|10|Group[1145]|Clement
# ont été jugulé _s forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été jugulé _es |backward|trigger|negated|10|Group[1145]|Clement
# ont été jugulé _es forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été terminé _s |backward|trigger|negated|10|Group[1145]|Clement
# ont été terminé _s forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été terminé _es |backward|trigger|negated|10|Group[1145]|Clement
# ont été terminé _es forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été fini _s |backward|trigger|negated|10|Group[1145]|Clement
# ont été fini _s forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été fini _es |backward|trigger|negated|10|Group[1145]|Clement
# ont été fini _es forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été endigué _s |backward|trigger|negated|10|Group[1145]|Clement
# ont été endigué _s forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été endigué _es |backward|trigger|negated|10|Group[1145]|Clement
# ont été endigué _es forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été cesseé _s |backward|trigger|negated|10|Group[1145]|Clement
# ont été cesseé _s forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été cesseé _es |backward|trigger|negated|10|Group[1145]|Clement
# ont été cesseé _es forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été interrompu _s |backward|trigger|negated|10|Group[1145]|Clement
# ont été interrompu _s forward|termination|negated|10|Group[1147, 1148]|Clement
# ont été interrompu _es |backward|trigger|negated|10|Group[1145]|Clement
# ont été interrompu _es forward|termination|negated|10|Group[1147, 1148]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Termin Var4 Trigger_Rule
Var1 -> "a"
Var2 -> "été"
Var3 -> "arrêté" | "stoppé" | "enrayé" | "contenu" | "suspendu" | "jugulé" | "terminé" | "fini" | "endigué" | "cesseé" | "interrompu"
Termin -> |"_e"
Var4 -> "en raison de"
Trigger_Rule -> "|forward|termination|negated|10|Group[1145]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a été arrêté en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été arrêté _e en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été stoppé en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été stoppé _e en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été enrayé en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été enrayé _e en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été contenu en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été contenu _e en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été suspendu en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été suspendu _e en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été jugulé en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été jugulé _e en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été terminé en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été terminé _e en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été fini en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été fini _e en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été endigué en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été endigué _e en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été cesseé en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été cesseé _e en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été interrompu en raison de |forward|termination|negated|10|Group[1145]|Clement
# a été interrompu _e en raison de |forward|termination|negated|10|Group[1145]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Termin Var4 Trigger_Rule
Var1 -> "ont"
Var2 -> "été"
Var3 -> "arrêté" | "stoppé" | "enrayé" | "contenu" | "suspendu" | "jugulé" | "terminé" | "fini" | "endigué" | "cesseé" | "interrompu"
Termin -> "_s"|"_es"
Var4 -> "en raison de"
Trigger_Rule -> "|forward|termination|negated|10|Group[1145]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ont été arrêté _s en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été arrêté _es en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été stoppé _s en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été stoppé _es en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été enrayé _s en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été enrayé _es en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été contenu _s en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été contenu _es en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été suspendu _s en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été suspendu _es en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été jugulé _s en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été jugulé _es en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été terminé _s en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été terminé _es en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été fini _s en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été fini _es en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été endigué _s en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été endigué _es en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été cesseé _s en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été cesseé _es en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été interrompu _s en raison de |forward|termination|negated|10|Group[1145]|Clement
# ont été interrompu _es en raison de |forward|termination|negated|10|Group[1145]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Trigger_Rule
Var1 -> "était"
Var2 -> "soupçonné" | "flairé" | "pressentié" | "présumé" | "entrevu" | "senti" | "redouté" | "conjecturé" | "imaginé" | "subodoré" | "cru"
Termin -> |"_e"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[1149]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# était soupçonné |backward|trigger|uncertain|30|Group[1149]|Clement
# était soupçonné _e |backward|trigger|uncertain|30|Group[1149]|Clement
# était flairé |backward|trigger|uncertain|30|Group[1149]|Clement
# était flairé _e |backward|trigger|uncertain|30|Group[1149]|Clement
# était pressentié |backward|trigger|uncertain|30|Group[1149]|Clement
# était pressentié _e |backward|trigger|uncertain|30|Group[1149]|Clement
# était présumé |backward|trigger|uncertain|30|Group[1149]|Clement
# était présumé _e |backward|trigger|uncertain|30|Group[1149]|Clement
# était entrevu |backward|trigger|uncertain|30|Group[1149]|Clement
# était entrevu _e |backward|trigger|uncertain|30|Group[1149]|Clement
# était senti |backward|trigger|uncertain|30|Group[1149]|Clement
# était senti _e |backward|trigger|uncertain|30|Group[1149]|Clement
# était redouté |backward|trigger|uncertain|30|Group[1149]|Clement
# était redouté _e |backward|trigger|uncertain|30|Group[1149]|Clement
# était conjecturé |backward|trigger|uncertain|30|Group[1149]|Clement
# était conjecturé _e |backward|trigger|uncertain|30|Group[1149]|Clement
# était imaginé |backward|trigger|uncertain|30|Group[1149]|Clement
# était imaginé _e |backward|trigger|uncertain|30|Group[1149]|Clement
# était subodoré |backward|trigger|uncertain|30|Group[1149]|Clement
# était subodoré _e |backward|trigger|uncertain|30|Group[1149]|Clement
# était cru |backward|trigger|uncertain|30|Group[1149]|Clement
# était cru _e |backward|trigger|uncertain|30|Group[1149]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Termin Trigger_Rule
Var1 -> "étaient"
Var2 -> "soupçonné" | "flairé" | "pressentié" | "présumé" | "entrevu" | "senti" | "redouté" | "conjecturé" | "imaginé" | "subodoré" | "cru"
Termin -> "_s" |"_es"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[1149]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# étaient soupçonné _s |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient soupçonné _es |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient flairé _s |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient flairé _es |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient pressentié _s |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient pressentié _es |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient présumé _s |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient présumé _es |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient entrevu _s |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient entrevu _es |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient senti _s |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient senti _es |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient redouté _s |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient redouté _es |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient conjecturé _s |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient conjecturé _es |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient imaginé _s |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient imaginé _es |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient subodoré _s |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient subodoré _es |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient cru _s |backward|trigger|uncertain|30|Group[1149]|Clement
# étaient cru _es |backward|trigger|uncertain|30|Group[1149]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Termin Trigger_Rule
Var1 -> "a"
Var2 -> "été"
Var3 -> "instruit" | "informé" | "renseigné" | "examiné" | "expliqué" | "montré" | "soigné" | "éclairci" | "expliqué"
Termin -> |"_e"
Trigger_Rule -> "|both|termination|historical|30|Group[1152, 1153]|Clement"|"|both|termination|nonpatient|30|Group[1152, 1153]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a été instruit |both|termination|historical|30|Group[1152, 1153]|Clement
# a été instruit |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été instruit _e |both|termination|historical|30|Group[1152, 1153]|Clement
# a été instruit _e |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été informé |both|termination|historical|30|Group[1152, 1153]|Clement
# a été informé |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été informé _e |both|termination|historical|30|Group[1152, 1153]|Clement
# a été informé _e |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été renseigné |both|termination|historical|30|Group[1152, 1153]|Clement
# a été renseigné |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été renseigné _e |both|termination|historical|30|Group[1152, 1153]|Clement
# a été renseigné _e |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été examiné |both|termination|historical|30|Group[1152, 1153]|Clement
# a été examiné |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été examiné _e |both|termination|historical|30|Group[1152, 1153]|Clement
# a été examiné _e |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été expliqué |both|termination|historical|30|Group[1152, 1153]|Clement
# a été expliqué |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été expliqué _e |both|termination|historical|30|Group[1152, 1153]|Clement
# a été expliqué _e |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été montré |both|termination|historical|30|Group[1152, 1153]|Clement
# a été montré |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été montré _e |both|termination|historical|30|Group[1152, 1153]|Clement
# a été montré _e |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été soigné |both|termination|historical|30|Group[1152, 1153]|Clement
# a été soigné |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été soigné _e |both|termination|historical|30|Group[1152, 1153]|Clement
# a été soigné _e |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été éclairci |both|termination|historical|30|Group[1152, 1153]|Clement
# a été éclairci |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été éclairci _e |both|termination|historical|30|Group[1152, 1153]|Clement
# a été éclairci _e |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été expliqué |both|termination|historical|30|Group[1152, 1153]|Clement
# a été expliqué |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# a été expliqué _e |both|termination|historical|30|Group[1152, 1153]|Clement
# a été expliqué _e |both|termination|nonpatient|30|Group[1152, 1153]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Termin Trigger_Rule
Var1 -> "ont"
Var2 -> "été"
Var3 -> "instruit" | "informé" | "renseigné" | "examiné" | "expliqué" | "montré" | "soigné" | "éclairci" | "expliqué"
Termin -> "_s"|"_es"
Trigger_Rule -> "|both|termination|historical|30|Group[1152, 1153]|Clement"|"|both|termination|nonpatient|30|Group[1152, 1153]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ont été instruit _s |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été instruit _s |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été instruit _es |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été instruit _es |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été informé _s |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été informé _s |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été informé _es |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été informé _es |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été renseigné _s |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été renseigné _s |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été renseigné _es |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été renseigné _es |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été examiné _s |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été examiné _s |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été examiné _es |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été examiné _es |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été expliqué _s |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été expliqué _s |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été expliqué _es |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été expliqué _es |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été montré _s |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été montré _s |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été montré _es |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été montré _es |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été soigné _s |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été soigné _s |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été soigné _es |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été soigné _es |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été éclairci _s |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été éclairci _s |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été éclairci _es |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été éclairci _es |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été expliqué _s |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été expliqué _s |both|termination|nonpatient|30|Group[1152, 1153]|Clement
# ont été expliqué _es |both|termination|historical|30|Group[1152, 1153]|Clement
# ont été expliqué _es |both|termination|nonpatient|30|Group[1152, 1153]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Var5 Trigger_Rule
Var1 -> "ce"
Var2 -> "qui"
Var3 -> "doit"
Var4 -> "être"
Var5 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1157]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ce qui doit être exclu |forward|trigger|uncertain|30|Group[1157]|Clement
# ce qui doit être refusé |forward|trigger|uncertain|30|Group[1157]|Clement
# ce qui doit être repoussé |forward|trigger|uncertain|30|Group[1157]|Clement
# ce qui doit être rejeté |forward|trigger|uncertain|30|Group[1157]|Clement
# ce qui doit être éliminé |forward|trigger|uncertain|30|Group[1157]|Clement
# ce qui doit être proscrit |forward|trigger|uncertain|30|Group[1157]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Var4 Trigger_Rule
Var1 -> "si"
Var2 -> "oui"
Var3 -> "ou"
Var4 -> "non"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1158, 1159]|Clement"|"|forward|pseudo|negated|30|Group[1158, 1159]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# si oui ou non |forward|trigger|uncertain|30|Group[1158, 1159]|Clement
# si oui ou non |forward|pseudo|negated|30|Group[1158, 1159]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "lequel"
Trigger_Rule -> "|both|termination|historical|30|Group[1160, 1161]|Clement"|"|both|termination|nonpatient|30|Group[1160, 1161]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# lequel |both|termination|historical|30|Group[1160, 1161]|Clement
# lequel |both|termination|nonpatient|30|Group[1160, 1161]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "tandis"
Var2 -> "que"
Trigger_Rule -> "|forward|termination|negated|10|Group[1162]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# tandis que |forward|termination|negated|10|Group[1162]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "qui"
Var2 -> "n'est pas"
Var3 -> "présent"
Trigger_Rule -> "|forward|termination|negated|10|Group[1163]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# qui n'est pas présent |forward|termination|negated|10|Group[1163]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "qui"
Var2 -> "ne sont pas"
Var3 -> "présents"
Trigger_Rule -> "|forward|termination|negated|10|Group[1163]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# qui ne sont pas présents |forward|termination|negated|10|Group[1163]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "sera"
Var2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Var3 -> "pour"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1164]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sera exclu pour |forward|trigger|uncertain|30|Group[1164]|Clement
# sera refusé pour |forward|trigger|uncertain|30|Group[1164]|Clement
# sera repoussé pour |forward|trigger|uncertain|30|Group[1164]|Clement
# sera rejeté pour |forward|trigger|uncertain|30|Group[1164]|Clement
# sera éliminé pour |forward|trigger|uncertain|30|Group[1164]|Clement
# sera proscrit pour |forward|trigger|uncertain|30|Group[1164]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Member Trigger_Rule
Var1 -> "avec"
Var2 -> "\\w+"
Member -> "parent" | "parents" | "père" | "beau-père" | "mère" |"belle-mère" | "papa" | "maman" |"fils" | "beau-fils" | "garçon" | "fille" | "belle-fille" | "filles" | "frère"| "frères" |"soeur" |"soeurs" |"sœur" |"sœurs" | "fratrie" | "oncle" | "tonton"| "oncles" |"tante" |"tata"  |"tantes" |"grand-mère" | "grand-père" |"cousin" |"cousins" |"famille" |"colocataire" | "colocataires" | "voisin" | "voisins"
Trigger_Rule -> "|both|termination|historical|30|Group[1166, 1167]|Clement"|"|both|termination|nonpatient|30|Group[1166, 1167]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# avec \w+ parent |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ parent |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ parents |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ parents |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ père |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ père |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ beau-père |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ beau-père |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ mère |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ mère |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ belle-mère |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ belle-mère |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ papa |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ papa |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ maman |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ maman |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ fils |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ fils |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ beau-fils |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ beau-fils |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ garçon |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ garçon |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ fille |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ fille |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ belle-fille |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ belle-fille |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ filles |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ filles |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ frère |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ frère |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ frères |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ frères |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ soeur |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ soeur |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ soeurs |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ soeurs |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ sœur |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ sœur |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ sœurs |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ sœurs |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ fratrie |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ fratrie |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ oncle |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ oncle |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ tonton |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ tonton |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ oncles |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ oncles |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ tante |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ tante |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ tata |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ tata |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ tantes |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ tantes |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ grand-mère |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ grand-mère |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ grand-père |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ grand-père |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ cousin |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ cousin |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ cousins |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ cousins |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ famille |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ famille |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ colocataire |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ colocataire |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ colocataires |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ colocataires |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ voisin |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ voisin |both|termination|nonpatient|30|Group[1166, 1167]|Clement
# avec \w+ voisins |both|termination|historical|30|Group[1166, 1167]|Clement
# avec \w+ voisins |both|termination|nonpatient|30|Group[1166, 1167]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "supplément" | "excédent" | "appoint" | "addition" | "surcroît" | "extra" | "surplus" | "additif" | "rallonge" | "ajout" | "avenant" | "excès" | "ajut" | "adjuvant"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1181]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans supplément |forward|trigger|negated|10|Group[1181]|Clement
# sans excédent |forward|trigger|negated|10|Group[1181]|Clement
# sans appoint |forward|trigger|negated|10|Group[1181]|Clement
# sans addition |forward|trigger|negated|10|Group[1181]|Clement
# sans surcroît |forward|trigger|negated|10|Group[1181]|Clement
# sans extra |forward|trigger|negated|10|Group[1181]|Clement
# sans surplus |forward|trigger|negated|10|Group[1181]|Clement
# sans additif |forward|trigger|negated|10|Group[1181]|Clement
# sans rallonge |forward|trigger|negated|10|Group[1181]|Clement
# sans ajout |forward|trigger|negated|10|Group[1181]|Clement
# sans avenant |forward|trigger|negated|10|Group[1181]|Clement
# sans excès |forward|trigger|negated|10|Group[1181]|Clement
# sans ajut |forward|trigger|negated|10|Group[1181]|Clement
# sans adjuvant |forward|trigger|negated|10|Group[1181]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "causer" | "susciter" | "amener" | "entraîner" | "provoquer" | "occasionner" | "donner" | "engendrer" | "créer" | "être cause de" | "déclencher"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1181]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans causer |forward|trigger|negated|10|Group[1181]|Clement
# sans susciter |forward|trigger|negated|10|Group[1181]|Clement
# sans amener |forward|trigger|negated|10|Group[1181]|Clement
# sans entraîner |forward|trigger|negated|10|Group[1181]|Clement
# sans provoquer |forward|trigger|negated|10|Group[1181]|Clement
# sans occasionner |forward|trigger|negated|10|Group[1181]|Clement
# sans donner |forward|trigger|negated|10|Group[1181]|Clement
# sans engendrer |forward|trigger|negated|10|Group[1181]|Clement
# sans créer |forward|trigger|negated|10|Group[1181]|Clement
# sans être cause de |forward|trigger|negated|10|Group[1181]|Clement
# sans déclencher |forward|trigger|negated|10|Group[1181]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "devenir" | "rendre" | "donner"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1181]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans devenir |forward|trigger|negated|10|Group[1181]|Clement
# sans rendre |forward|trigger|negated|10|Group[1181]|Clement
# sans donner |forward|trigger|negated|10|Group[1181]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "être"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1181]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans être |forward|trigger|negated|10|Group[1181]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "difficultés" | "mal" | "embarras" | "empêchement" | "obstacle" | "complication" | "problème" | "ennui" | "accroc" | "contrariété" | "résistance" | "complexité" | "tracas" | "objection" | "peine"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[1207]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans difficultés |both|pseudo|uncertain|30|Group[1207]|Clement
# sans mal |both|pseudo|uncertain|30|Group[1207]|Clement
# sans embarras |both|pseudo|uncertain|30|Group[1207]|Clement
# sans empêchement |both|pseudo|uncertain|30|Group[1207]|Clement
# sans obstacle |both|pseudo|uncertain|30|Group[1207]|Clement
# sans complication |both|pseudo|uncertain|30|Group[1207]|Clement
# sans problème |both|pseudo|uncertain|30|Group[1207]|Clement
# sans ennui |both|pseudo|uncertain|30|Group[1207]|Clement
# sans accroc |both|pseudo|uncertain|30|Group[1207]|Clement
# sans contrariété |both|pseudo|uncertain|30|Group[1207]|Clement
# sans résistance |both|pseudo|uncertain|30|Group[1207]|Clement
# sans complexité |both|pseudo|uncertain|30|Group[1207]|Clement
# sans tracas |both|pseudo|uncertain|30|Group[1207]|Clement
# sans objection |both|pseudo|uncertain|30|Group[1207]|Clement
# sans peine |both|pseudo|uncertain|30|Group[1207]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "peine" | "tristesse" | "douleur" | "souffrance" | "affliction" | "inquiétude" | "tourment" | "désolation" | "amertume" | "malheur" | "détresse" | "misère" | "difficulté" | "agonie" | "regret"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[1207, 1208]|Clement"|"|both|pseudo|negated|10|Group[1207, 1208]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans peine |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans peine |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans tristesse |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans tristesse |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans douleur |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans douleur |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans souffrance |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans souffrance |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans affliction |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans affliction |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans inquiétude |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans inquiétude |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans tourment |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans tourment |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans désolation |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans désolation |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans amertume |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans amertume |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans malheur |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans malheur |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans détresse |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans détresse |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans misère |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans misère |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans difficulté |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans difficulté |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans agonie |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans agonie |both|pseudo|negated|10|Group[1207, 1208]|Clement
# sans regret |both|pseudo|uncertain|30|Group[1207, 1208]|Clement
# sans regret |both|pseudo|negated|10|Group[1207, 1208]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "aucun" | "aucune" | "nul" | "nulle" |
Trigger_Rule -> "|forward|trigger|negated|10|Group[1243]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans aucun |forward|trigger|negated|10|Group[1243]|Clement
# sans aucune |forward|trigger|negated|10|Group[1243]|Clement
# sans nul |forward|trigger|negated|10|Group[1243]|Clement
# sans nulle |forward|trigger|negated|10|Group[1243]|Clement
# sans |forward|trigger|negated|10|Group[1243]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "sans"
Var2 -> "succès" | "effet" | "résultats" | "aboutissement"
Trigger_Rule -> "|backward|trigger|negated|10|Group[1269, 1270]|Clement"|"|forward|termination|negated|10|Group[1269, 1270]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans succès |backward|trigger|negated|10|Group[1269, 1270]|Clement
# sans succès |forward|termination|negated|10|Group[1269, 1270]|Clement
# sans effet |backward|trigger|negated|10|Group[1269, 1270]|Clement
# sans effet |forward|termination|negated|10|Group[1269, 1270]|Clement
# sans résultats |backward|trigger|negated|10|Group[1269, 1270]|Clement
# sans résultats |forward|termination|negated|10|Group[1269, 1270]|Clement
# sans aboutissement |backward|trigger|negated|10|Group[1269, 1270]|Clement
# sans aboutissement |forward|termination|negated|10|Group[1269, 1270]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "sans"
Var2 -> "pour"
Var3 -> "autant"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1283]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sans pour autant |forward|trigger|negated|10|Group[1283]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "inquiet"
Var2 -> "pour"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1285]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# inquiet pour |forward|trigger|uncertain|30|Group[1285]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "inquiétant" | "troublant" | "menaçant" | "préoccupant"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[1285]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# inquiétant |forward|trigger|uncertain|30|Group[1285]|Clement
# troublant |forward|trigger|uncertain|30|Group[1285]|Clement
# menaçant |forward|trigger|uncertain|30|Group[1285]|Clement
# préoccupant |forward|trigger|uncertain|30|Group[1285]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "donné"
Trigger_Rule -> "|forward|termination|uncertain|4|Group[1288, 1289]|Clement"|"|forward|termination|conditional|4|Group[1288, 1289]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# donné |forward|termination|uncertain|4|Group[1288, 1289]|Clement
# donné |forward|termination|conditional|4|Group[1288, 1289]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Trigger_Rule
Var1 -> "négatif"
Trigger_Rule -> "|forward|trigger|negated|10|Group[1292]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# négatif |forward|trigger|negated|10|Group[1292]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "risque"
Var2 -> "élevé"
Var3 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|20|Group[1317]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# risque élevé pour |forward|trigger|negated|20|Group[1317]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Var3 Trigger_Rule
Var1 -> "à"
Var2 -> "risque" 
Var3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|20|Group[1318]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# à risque de |forward|trigger|negated|20|Group[1318]|Clement

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Var1 Var2 Trigger_Rule
Var1 -> "surveillé" | "examiné" | "suivi"
Var2 -> "pour"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[1320]|Clement"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# surveillé pour |forward|trigger|conditional|30|Group[1320]|Clement
# examiné pour |forward|trigger|conditional|30|Group[1320]|Clement
# suivi pour |forward|trigger|conditional|30|Group[1320]|Clement
