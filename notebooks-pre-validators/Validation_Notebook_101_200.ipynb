# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adposition1 Determiner2 Trigger_Rule
Adposition1 -> "par"
Determiner2 -> "le"
Trigger_Rule -> "|forward|termination|negated|10|Group[174]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# par le |forward|termination|negated|10|Group[174]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adposition1 Verb2 Trigger_Rule
Adposition1 -> "c"
Verb2 -> "w"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[175]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# c w |both|pseudo|uncertain|30|Group[175]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Auxiliary2 Verb3 Adposition4 Trigger_Rule
Verb1 -> "peut"
Auxiliary2 -> "être"
Verb3 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Adposition4 -> "pour" | " "
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut être exclu pour |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION
# peut être exclu   |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION
# peut être refusé pour |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION
# peut être refusé   |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION
# peut être repoussé pour |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION
# peut être repoussé   |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION
# peut être rejeté pour |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION
# peut être rejeté   |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION
# peut être éliminé pour |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION
# peut être éliminé   |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION
# peut être proscrit pour |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION
# peut être proscrit   |forward|trigger|uncertain|30|Group[176]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Auxiliary2 Verb3 Trigger_Rule
Verb1 -> "peut"
Auxiliary2 -> "être"
Verb3 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[177]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut être exclu |backward|trigger|uncertain|30|Group[177]|PRE-VALIDATION
# peut être refusé |backward|trigger|uncertain|30|Group[177]|PRE-VALIDATION
# peut être repoussé |backward|trigger|uncertain|30|Group[177]|PRE-VALIDATION
# peut être rejeté |backward|trigger|uncertain|30|Group[177]|PRE-VALIDATION
# peut être éliminé |backward|trigger|uncertain|30|Group[177]|PRE-VALIDATION
# peut être proscrit |backward|trigger|uncertain|30|Group[177]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb3 Adposition4 Trigger_Rule
Auxiliary1 -> "peut"
Verb3 -> "l'éliminer" | "l'écarter" | "l'évincer" | "l'exclure" | "l'chasser" | "proscrire" | "rejeter" | "repousser" | "l'enlever" | "l'éloigner" | "retirer" | "l'omettre" | "l'ôter" | "l'obmettre" | "récuser"
Adposition4 -> "contre" | "pour" | " "
Trigger_Rule -> "|forward|trigger|negated|10|Group[179]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut l'éliminer contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'éliminer pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'éliminer   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'écarter contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'écarter pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'écarter   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'évincer contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'évincer pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'évincer   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'exclure contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'exclure pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'exclure   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'chasser contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'chasser pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'chasser   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut proscrire contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut proscrire pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut proscrire   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut rejeter contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut rejeter pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut rejeter   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut repousser contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut repousser pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut repousser   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'enlever contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'enlever pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'enlever   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'éloigner contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'éloigner pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'éloigner   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut retirer contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut retirer pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut retirer   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'omettre contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'omettre pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'omettre   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'ôter contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'ôter pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'ôter   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'obmettre contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'obmettre pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut l'obmettre   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut récuser contre |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut récuser pour |forward|trigger|negated|10|Group[179]|PRE-VALIDATION
# peut récuser   |forward|trigger|negated|10|Group[179]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Noun4 Trigger_Rule
Auxiliary1 -> "peut"
Verb2 -> "exclure" | "éliminer" | "rejeter" | "proscrire" | "éloigner" | "supprimer" | "radier"
Noun4 -> "la patinet contre" | "la patinet pour" | "le patinet"
Trigger_Rule -> "|forward|trigger|negated|10|Group[196]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# peut exclure la patinet contre |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut exclure la patinet pour |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut exclure le patinet |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut éliminer la patinet contre |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut éliminer la patinet pour |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut éliminer le patinet |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut rejeter la patinet contre |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut rejeter la patinet pour |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut rejeter le patinet |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut proscrire la patinet contre |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut proscrire la patinet pour |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut proscrire le patinet |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut éloigner la patinet contre |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut éloigner la patinet pour |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut éloigner le patinet |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut supprimer la patinet contre |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut supprimer la patinet pour |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut supprimer le patinet |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut radier la patinet contre |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut radier la patinet pour |forward|trigger|negated|10|Group[196]|PRE-VALIDATION
# peut radier le patinet |forward|trigger|negated|10|Group[196]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG


cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Auxiliary4 Adverb5 Verb6 Trigger_Rule
Adverb1 -> "ne"
Auxiliary2 -> "peut"
Adverb3 -> "pas"
Auxiliary4 -> "être"
Adverb5 -> "totalement"
Verb6 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne peut pas être totalement exclu |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être totalement refusé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être totalement repoussé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être totalement rejeté |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être totalement éliminé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être totalement proscrit |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Auxiliary4 Adverb5 Verb6 Trigger_Rule
Adverb1 -> "ne"
Auxiliary2 -> "peut"
Adverb3 -> "pas"
Auxiliary4 -> "être"
Adverb5 -> "complètement" | "totalement" | " "
Verb6 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne peut pas être complètement exclu |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être complètement refusé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être complètement repoussé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être complètement rejeté |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être complètement éliminé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être complètement proscrit |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être totalement exclu |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être totalement refusé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être totalement repoussé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être totalement rejeté |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être totalement éliminé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être totalement proscrit |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être   exclu |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être   refusé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être   repoussé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être   rejeté |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être   éliminé |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION
# ne peut pas être   proscrit |backward|trigger|uncertain|30|Group[202]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Auxiliary2 Verb3 Trigger_Rule
Adverb1 -> "Ne"
Auxiliary2 -> "peux"
Verb3 -> "voir" | "apercevoir" | "saisir" | "percevoir" | "constater" | "considérer" | "concevoir" | "remarquer" | "trouver" | "rencontrer" | "découvrir" | "vérifier" | "distinguer" | "entrevoir" | "discerner"
Trigger_Rule -> "|forward|trigger|negated|10|Group[205]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# Ne peux voir |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux apercevoir |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux saisir |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux percevoir |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux constater |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux considérer |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux concevoir |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux remarquer |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux trouver |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux rencontrer |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux découvrir |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux vérifier |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux distinguer |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux entrevoir |forward|trigger|negated|10|Group[205]|PRE-VALIDATION
# Ne peux discerner |forward|trigger|negated|10|Group[205]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Auxiliary2 Adverb3 Trigger_Rule
Adverb1 -> "ne"
Auxiliary2 -> "peux"
Adverb3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[207]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne peux pas |forward|trigger|negated|10|Group[207]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adposition2 Trigger_Rule
Noun1 -> "cause" | "causes" | "raison" | "prétexte" | "fondement" | "source" | "intention" | "origine" | "but" | "déclencheur" | "départ"
Adposition2 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[209]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# cause de |forward|termination|negated|10|Group[209]|PRE-VALIDATION
# causes de |forward|termination|negated|10|Group[209]|PRE-VALIDATION
# raison de |forward|termination|negated|10|Group[209]|PRE-VALIDATION
# prétexte de |forward|termination|negated|10|Group[209]|PRE-VALIDATION
# fondement de |forward|termination|negated|10|Group[209]|PRE-VALIDATION
# source de |forward|termination|negated|10|Group[209]|PRE-VALIDATION
# intention de |forward|termination|negated|10|Group[209]|PRE-VALIDATION
# origine de |forward|termination|negated|10|Group[209]|PRE-VALIDATION
# but de |forward|termination|negated|10|Group[209]|PRE-VALIDATION
# déclencheur de |forward|termination|negated|10|Group[209]|PRE-VALIDATION
# départ de |forward|termination|negated|10|Group[209]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "vérifié" | "confirmé" | "contrôlé" | "examiné" | "constaté" | "avéré" | "prouvé" | "testé" | "expertisé" | "éprouvé" | "inspecté" | "attesté" | "réviser"
Adposition2 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[213]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# vérifié pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# confirmé pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# contrôlé pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# examiné pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# constaté pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# avéré pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# prouvé pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# testé pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# expertisé pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# éprouvé pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# inspecté pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# attesté pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION
# réviser pour |forward|trigger|negated|10|Group[213]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adjective1 Adposition2 Trigger_Rule
Adjective1 -> "libre"
Adposition2 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[215]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# libre de |forward|trigger|negated|10|Group[215]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "revenir" | "regagner" | "rentrer" | "reparaître" | "reprendre" | "repasser" | "recommencer" | "retomber" | "récidiver" | "retrouver" | "ressurgir" | "ressortir" | "reconduire" | "ramener" | "remettre"
Adposition2 -> "à" | "pour"
Trigger_Rule -> "|forward|trigger|conditional|30|Group[217]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# revenir à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# revenir pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# regagner à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# regagner pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# rentrer à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# rentrer pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# reparaître à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# reparaître pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# reprendre à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# reprendre pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# repasser à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# repasser pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# recommencer à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# recommencer pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# retomber à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# retomber pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# récidiver à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# récidiver pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# retrouver à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# retrouver pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# ressurgir à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# ressurgir pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# ressortir à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# ressortir pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# reconduire à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# reconduire pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# ramener à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# ramener pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# remettre à |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION
# remettre pour |forward|trigger|conditional|30|Group[217]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Pronoun1 Verb2 Trigger_Rule
Pronoun1 -> "se"
Verb2 -> "plaint"
Trigger_Rule -> "|both|termination|historical|30|Group[219]|PRE-VALIDATION"|"|both|termination|nonpatient|30|Group[220]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# se plaint |both|termination|historical|30|Group[219]|PRE-VALIDATION
# se plaint |both|termination|nonpatient|30|Group[220]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "concerné" | "intéresser" | "impliquer" | "être du ressort" | "être relatif à" | "porter sur"
Adposition2 -> "pour"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[221, 223]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# concerné pour |forward|trigger|uncertain|30|Group[221, 223]|PRE-VALIDATION
# intéresser pour |forward|trigger|uncertain|30|Group[221, 223]|PRE-VALIDATION
# impliquer pour |forward|trigger|uncertain|30|Group[221, 223]|PRE-VALIDATION
# être du ressort pour |forward|trigger|uncertain|30|Group[221, 223]|PRE-VALIDATION
# être relatif à pour |forward|trigger|uncertain|30|Group[221, 223]|PRE-VALIDATION
# porter sur pour |forward|trigger|uncertain|30|Group[221, 223]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "préoccupé" | "songeur" | "tourmenté" | "anxieux" | "inquiet" | "hanté" | "tracassé" | "absorbé" | "abstrait" | "ennuyé" | "angoissé" | "embarrassé" | "rongé" | "occupé" | "agité"
Adposition2 -> "par"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# préoccupé par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# songeur par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# tourmenté par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# anxieux par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# inquiet par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# hanté par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# tracassé par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# absorbé par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# abstrait par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# ennuyé par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# angoissé par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# embarrassé par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# rongé par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# occupé par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION
# agité par |forward|trigger|uncertain|30|Group[222]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "concernant" | "relatif à" | "sujet" | "propos" | "afférent" | "relative" | "relativement à" | "à propos de" | "sur"
Adposition2 -> "pour"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[224]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# concernant pour |forward|trigger|uncertain|30|Group[224]|PRE-VALIDATION
# relatif à pour |forward|trigger|uncertain|30|Group[224]|PRE-VALIDATION
# sujet pour |forward|trigger|uncertain|30|Group[224]|PRE-VALIDATION
# propos pour |forward|trigger|uncertain|30|Group[224]|PRE-VALIDATION
# afférent pour |forward|trigger|uncertain|30|Group[224]|PRE-VALIDATION
# relative pour |forward|trigger|uncertain|30|Group[224]|PRE-VALIDATION
# relativement à pour |forward|trigger|uncertain|30|Group[224]|PRE-VALIDATION
# à propos de pour |forward|trigger|uncertain|30|Group[224]|PRE-VALIDATION
# sur pour |forward|trigger|uncertain|30|Group[224]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Adposition2 Trigger_Rule
Verb1 -> "cohérent" | "homogène" | "harmonieux" | "ordonné" | "rationnel" | "compréhensible" | "consistant" | "uni" | "en accord" | "rationel" | "rationnelle" | "cohérent"
Adposition2 -> "avec"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# cohérent avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION
# homogène avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION
# harmonieux avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION
# ordonné avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION
# rationnel avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION
# compréhensible avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION
# consistant avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION
# uni avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION
# en accord avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION
# rationel avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION
# rationnelle avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION
# cohérent avec |both|pseudo|uncertain|30|Group[225]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Auxiliary2 Verb3 Trigger_Rule
Verb1 -> "pourrait"
Auxiliary2 -> "être"
Verb3 -> "soit"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[226]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pourrait être soit |forward|trigger|uncertain|30|Group[226]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Auxiliary2 Trigger_Rule
Verb1 -> "pourrait"
Auxiliary2 -> "être"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[227]|PRE-VALIDATION"|"|forward|trigger|uncertain|30|Group[665]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pourrait être |backward|trigger|uncertain|30|Group[227]|PRE-VALIDATION
# pourrait être |forward|trigger|uncertain|30|Group[665]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Auxiliary2 Verb3 Trigger_Rule
Verb1 -> "pourrait"
Auxiliary2 -> "être"
Verb3 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[228]|PRE-VALIDATION"|"|backward|trigger|uncertain|30|Group[230]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pourrait être exclu |forward|trigger|uncertain|30|Group[228]|PRE-VALIDATION
# pourrait être exclu |backward|trigger|uncertain|30|Group[230]|PRE-VALIDATION
# pourrait être refusé |forward|trigger|uncertain|30|Group[228]|PRE-VALIDATION
# pourrait être refusé |backward|trigger|uncertain|30|Group[230]|PRE-VALIDATION
# pourrait être repoussé |forward|trigger|uncertain|30|Group[228]|PRE-VALIDATION
# pourrait être repoussé |backward|trigger|uncertain|30|Group[230]|PRE-VALIDATION
# pourrait être rejeté |forward|trigger|uncertain|30|Group[228]|PRE-VALIDATION
# pourrait être rejeté |backward|trigger|uncertain|30|Group[230]|PRE-VALIDATION
# pourrait être éliminé |forward|trigger|uncertain|30|Group[228]|PRE-VALIDATION
# pourrait être éliminé |backward|trigger|uncertain|30|Group[230]|PRE-VALIDATION
# pourrait être proscrit |forward|trigger|uncertain|30|Group[228]|PRE-VALIDATION
# pourrait être proscrit |backward|trigger|uncertain|30|Group[230]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Auxiliary2 Verb3 Adposition4 Trigger_Rule
Verb1 -> "pourrait"
Auxiliary2 -> "être"
Verb3 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Adposition4 -> "pour"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[229]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pourrait être exclu pour |forward|trigger|uncertain|30|Group[229]|PRE-VALIDATION
# pourrait être refusé pour |forward|trigger|uncertain|30|Group[229]|PRE-VALIDATION
# pourrait être repoussé pour |forward|trigger|uncertain|30|Group[229]|PRE-VALIDATION
# pourrait être rejeté pour |forward|trigger|uncertain|30|Group[229]|PRE-VALIDATION
# pourrait être éliminé pour |forward|trigger|uncertain|30|Group[229]|PRE-VALIDATION
# pourrait être proscrit pour |forward|trigger|uncertain|30|Group[229]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Trigger_Rule
Verb1 -> "décide" | "réglé" | "arrêté" | "convaincu" | "choisi" | "décrété" | "convenu" | "conclu" | "tranché" | "décréter" | "statuer" | "choisir" | "arbitrer"
Trigger_Rule -> "|both|termination|historical|30|Group[245]|PRE-VALIDATION"|"|both|termination|nonpatient|30|Group[246]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# décide |both|termination|historical|30|Group[245]|PRE-VALIDATION
# décide |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# réglé |both|termination|historical|30|Group[245]|PRE-VALIDATION
# réglé |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# arrêté |both|termination|historical|30|Group[245]|PRE-VALIDATION
# arrêté |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# convaincu |both|termination|historical|30|Group[245]|PRE-VALIDATION
# convaincu |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# choisi |both|termination|historical|30|Group[245]|PRE-VALIDATION
# choisi |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# décrété |both|termination|historical|30|Group[245]|PRE-VALIDATION
# décrété |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# convenu |both|termination|historical|30|Group[245]|PRE-VALIDATION
# convenu |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# conclu |both|termination|historical|30|Group[245]|PRE-VALIDATION
# conclu |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# tranché |both|termination|historical|30|Group[245]|PRE-VALIDATION
# tranché |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# décréter |both|termination|historical|30|Group[245]|PRE-VALIDATION
# décréter |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# statuer |both|termination|historical|30|Group[245]|PRE-VALIDATION
# statuer |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# choisir |both|termination|historical|30|Group[245]|PRE-VALIDATION
# choisir |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# arbitrer |both|termination|historical|30|Group[245]|PRE-VALIDATION
# arbitrer |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Trigger_Rule
Verb1 -> "décider" | "déterminer" | "ordonner" | "trancher" | "statuer" | "disposer" | "prononcer" | "arrêter" | "conclure" | "décréter" | "commander" | "choisir" | "arbitrer"
Trigger_Rule -> "|both|termination|historical|30|Group[245]|PRE-VALIDATION"|"|both|termination|nonpatient|30|Group[246]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# décider |both|termination|historical|30|Group[245]|PRE-VALIDATION
# décider |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# déterminer |both|termination|historical|30|Group[245]|PRE-VALIDATION
# déterminer |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# ordonner |both|termination|historical|30|Group[245]|PRE-VALIDATION
# ordonner |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# trancher |both|termination|historical|30|Group[245]|PRE-VALIDATION
# trancher |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# statuer |both|termination|historical|30|Group[245]|PRE-VALIDATION
# statuer |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# disposer |both|termination|historical|30|Group[245]|PRE-VALIDATION
# disposer |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# prononcer |both|termination|historical|30|Group[245]|PRE-VALIDATION
# prononcer |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# arrêter |both|termination|historical|30|Group[245]|PRE-VALIDATION
# arrêter |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# conclure |both|termination|historical|30|Group[245]|PRE-VALIDATION
# conclure |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# décréter |both|termination|historical|30|Group[245]|PRE-VALIDATION
# décréter |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# commander |both|termination|historical|30|Group[245]|PRE-VALIDATION
# commander |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# choisir |both|termination|historical|30|Group[245]|PRE-VALIDATION
# choisir |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION
# arbitrer |both|termination|historical|30|Group[245]|PRE-VALIDATION
# arbitrer |both|termination|nonpatient|30|Group[246]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "décline" | "dédaigner" | "dégénérer" | "régresser" | "dépérir" | "déchoir" | "décroître" | "faiblir" | "diminuer" | "dégringoler" | "fléchir" | "baisser" | "descendre" | "se ramollir" | "se rapetisser"
Trigger_Rule -> "|forward|trigger|negated|10|Group[252]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# décline |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# dédaigner |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# dégénérer |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# régresser |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# dépérir |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# déchoir |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# décroître |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# faiblir |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# diminuer |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# dégringoler |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# fléchir |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# baisser |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# descendre |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# se ramollir |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# se rapetisser |forward|trigger|negated|10|Group[252]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Trigger_Rule
Verb1 -> "diminué" | "affaiblir" | "baisser" | "amoindrir" | "atténuer" | "décliner" | "amenuiser" | "ralentir" | "tempérer" | "tomber" | "faiblir" | "alléger" | "rétrécir" | "décroître" | "adoucir"
Trigger_Rule -> "|forward|trigger|negated|10|Group[252]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# diminué |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# affaiblir |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# baisser |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# amoindrir |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# atténuer |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# décliner |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# amenuiser |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# ralentir |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# tempérer |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# tomber |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# faiblir |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# alléger |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# rétrécir |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# décroître |forward|trigger|negated|10|Group[252]|PRE-VALIDATION
# adoucir |forward|trigger|negated|10|Group[252]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Adjective2 Trigger_Rule
Verb1 -> "refusé" | "rejeter" | "renvoyer" | "contester" | "dédaigner" | "exclure" | "écarter" | "décliner" | "résister" | "répugner" | "dire non" | "retoquer" | "s'opposer" | "désapprouver"
Adjective2 -> "actif"
Trigger_Rule -> "|forward|trigger|negated|10|Group[255]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# refusé actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# rejeter actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# renvoyer actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# contester actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# dédaigner actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# exclure actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# écarter actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# décliner actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# résister actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# répugner actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# dire non actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# retoquer actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# s'opposer actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION
# désapprouver actif |forward|trigger|negated|10|Group[255]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Determiner2 -> "toute"
Noun3 -> "anormale" | "aberrant" | "étonnant" | "inhabituel" | "étrange" | "inaccoutumé" | "singulier" | "insolite" | "irrégulier" | "anomal" | "exceptionnel" | "paradoxal" | "surprenant" | "déséquilibré" | "excentrique"
Trigger_Rule -> "|forward|trigger|negated|10|Group[257]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# nié toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contesté toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# rejeté toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# dénié toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# renié toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# disconvenu toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# contredit toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démentir toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refuser toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuter toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# refusé toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# désapprouvé toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# démenti toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# réfuté toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute anormale |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute aberrant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute étonnant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute inhabituel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute étrange |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute inaccoutumé |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute singulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute insolite |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute irrégulier |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute anomal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute exceptionnel |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute paradoxal |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute surprenant |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute déséquilibré |forward|trigger|negated|10|Group[257]|PRE-VALIDATION
# impensé toute excentrique |forward|trigger|negated|10|Group[257]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Adverb3 Adverb4 Adposition5 Determiner6 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Adverb3 -> "tout"
Adverb4 -> "changement"
Adposition5 -> "dans"
Determiner6 -> "le"
Trigger_Rule -> "|forward|trigger|negated|10|Group[260]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a nié tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a contesté tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a rejeté tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a dénié tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a renié tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a disconvenu tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a contredit tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a démentir tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a refuser tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a réfuter tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a refusé tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a désapprouvé tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a démenti tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a réfuté tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION
# a impensé tout changement dans le |forward|trigger|negated|10|Group[260]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Noun4 Adjective5 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Determiner3 -> "tout"
Noun4 -> "risque" | "dangereux" | "chance"
Adjective5 -> "élevé"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a nié tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a nié tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a nié tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a contesté tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a contesté tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a contesté tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a rejeté tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a rejeté tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a rejeté tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a dénié tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a dénié tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a dénié tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a renié tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a renié tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a renié tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a disconvenu tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a disconvenu tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a disconvenu tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a contredit tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a contredit tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a contredit tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a démentir tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a démentir tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a démentir tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a refuser tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a refuser tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a refuser tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a réfuter tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a réfuter tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a réfuter tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a refusé tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a refusé tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a refusé tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a désapprouvé tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a désapprouvé tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a désapprouvé tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a démenti tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a démenti tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a démenti tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a réfuté tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a réfuté tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a réfuté tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a impensé tout risque élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a impensé tout dangereux élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a impensé tout chance élevé |forward|trigger|negated|10|Group[264]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Determiner2 -> "toute"
Noun3 -> "récente" | "nouveau" | "jeune" | "proche" | "actuel" | "récent"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé toute récente |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé toute nouveau |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé toute jeune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé toute proche |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé toute actuel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé toute récent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Determiner2 -> "tout"
Noun3 -> "problème" | "ennui" | "souci" | "complication" | "histoire" | "anomalie" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "mal" | "trouble"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# nié tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contesté tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeté tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dénié tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renié tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# disconvenu tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contredit tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démentir tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refuser tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuter tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# refusé tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouvé tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# démenti tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# réfuté tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé tout problème |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé tout ennui |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé tout souci |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé tout complication |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé tout histoire |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé tout anomalie |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé tout dysfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé tout disfonctionnement |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé tout soucis |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé tout mal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# impensé tout trouble |forward|trigger|negated|10|Group[264]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Noun4 Adposition5 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Determiner3 -> "toute"
Noun4 -> "histoire" | "passé" | "souvenir" | "historique"
Adposition5 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a nié toute histoire de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a nié toute passé de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a nié toute souvenir de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a nié toute historique de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a contesté toute histoire de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a contesté toute passé de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a contesté toute souvenir de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a contesté toute historique de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a rejeté toute histoire de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a rejeté toute passé de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a rejeté toute souvenir de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a rejeté toute historique de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a dénié toute histoire de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a dénié toute passé de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a dénié toute souvenir de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a dénié toute historique de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a renié toute histoire de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a renié toute passé de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a renié toute souvenir de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a renié toute historique de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a disconvenu toute histoire de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# a disconvenu toute passé de |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
#
|forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dédaigner tout classique |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dédaigner tout présent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dédaigner tout commune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dédaigner tout régulier |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dédaigner tout en cours |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout courant |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout habituel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout fréquent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout connu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout répandu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout normal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout classique |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout présent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout commune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout régulier |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout en cours |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout courant |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout habituel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout fréquent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout connu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout répandu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout normal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout classique |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout présent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout commune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout régulier |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout en cours |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout courant |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout habituel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout fréquent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout connu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout répandu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout normal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout classique |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout présent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout commune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout régulier |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout en cours |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout courant |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout habituel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout fréquent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout connu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout répandu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout normal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout classique |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout présent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout commune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout régulier |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout en cours |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout courant |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout habituel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout fréquent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout connu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout répandu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout normal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout classique |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout présent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout commune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout régulier |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout en cours |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout courant |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout habituel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout fréquent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout connu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout répandu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout normal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout classique |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout présent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout commune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout régulier |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout en cours |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout courant |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout habituel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout fréquent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout connu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout répandu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout normal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout classique |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout présent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout commune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout régulier |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout en cours |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout courant |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout habituel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout fréquent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout connu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout répandu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout normal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout classique |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout présent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout commune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout régulier |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout en cours |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout courant |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout habituel |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout fréquent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout connu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout répandu |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout normal |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout classique |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout présent |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout commune |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout régulier |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout en cours |forward|trigger|negated|10|Group[264]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Adverb2 Adjective3 Trigger_Rule
Verb1 -> "refusé" | "rejeter" | "renvoyer" | "contester" | "dédaigner" | "exclure" | "écarter" | "décliner" | "résister" | "répugner" | "dire non" | "retoquer" | "s'opposer" | "désapprouver"
Adverb2 -> "tout"
Adjective3 -> "autre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[264]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# refusé tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# rejeter tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# renvoyer tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# contester tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dédaigner tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# exclure tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# écarter tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# décliner tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# résister tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# répugner tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# dire non tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# retoquer tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# s'opposer tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION
# désapprouver tout autre |forward|trigger|negated|10|Group[264]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Adverb2 Trigger_Rule
Verb1 -> "refusé" | "rejeter" | "renvoyer" | "contester" | "dédaigner" | "exclure" | "écarter" | "décliner" | "résister" | "répugner" | "dire non" | "retoquer" | "s'opposer" | "désapprouver"
Adverb2 -> "tout"
Trigger_Rule -> "|forward|trigger|negated|10|Group[285]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# refusé tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# rejeter tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# renvoyer tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# contester tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# dédaigner tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# exclure tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# écarter tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# décliner tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# résister tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# répugner tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# dire non tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# retoquer tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# s'opposer tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION
# désapprouver tout |forward|trigger|negated|10|Group[285]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Verb2 Trigger_Rule
Verb1 -> "courant" | "habituel" | "fréquent" | "connu" | "répandu" | "normal" | "classique" | "présent" | "commune" | "régulier" | "en cours"
Verb2 -> "refusé" | "rejeter" | "renvoyer" | "contester" | "dédaigner" | "exclure" | "écarter" | "décliner" | "résister" | "répugner" | "dire non" | "retoquer" | "s'opposer" | "désapprouver"
Trigger_Rule -> "|forward|trigger|negated|10|Group[287]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# courant refusé |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant rejeter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant renvoyer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant contester |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant dédaigner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant exclure |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant écarter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant décliner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant résister |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant répugner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant dire non |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant retoquer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant s'opposer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# courant désapprouver |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel refusé |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel rejeter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel renvoyer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel contester |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel dédaigner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel exclure |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel écarter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel décliner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel résister |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel répugner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel dire non |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel retoquer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel s'opposer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# habituel désapprouver |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent refusé |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent rejeter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent renvoyer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent contester |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent dédaigner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent exclure |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent écarter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent décliner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent résister |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent répugner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent dire non |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent retoquer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent s'opposer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# fréquent désapprouver |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu refusé |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu rejeter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu renvoyer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu contester |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu dédaigner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu exclure |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu écarter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu décliner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu résister |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu répugner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu dire non |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu retoquer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu s'opposer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# connu désapprouver |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu refusé |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu rejeter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu renvoyer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu contester |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu dédaigner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu exclure |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu écarter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu décliner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu résister |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu répugner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu dire non |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu retoquer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu s'opposer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# répandu désapprouver |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal refusé |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal rejeter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal renvoyer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal contester |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal dédaigner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal exclure |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal écarter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal décliner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal résister |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal répugner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal dire non |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal retoquer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal s'opposer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# normal désapprouver |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique refusé |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique rejeter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique renvoyer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique contester |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique dédaigner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique exclure |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique écarter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique décliner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique résister |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique répugner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique dire non |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique retoquer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique s'opposer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# classique désapprouver |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent refusé |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent rejeter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent renvoyer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent contester |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent dédaigner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent exclure |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent écarter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent décliner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent résister |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent répugner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent dire non |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent retoquer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent s'opposer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# présent désapprouver |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune refusé |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune rejeter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune renvoyer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune contester |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune dédaigner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune exclure |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune écarter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune décliner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune résister |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune répugner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune dire non |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune retoquer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune s'opposer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# commune désapprouver |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier refusé |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier rejeter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier renvoyer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier contester |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier dédaigner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier exclure |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier écarter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier décliner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier résister |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier répugner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier dire non |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier retoquer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier s'opposer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# régulier désapprouver |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours refusé |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours rejeter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours renvoyer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours contester |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours dédaigner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours exclure |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours écarter |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours décliner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours résister |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours répugner |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours dire non |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours retoquer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours s'opposer |forward|trigger|negated|10|Group[287]|PRE-VALIDATION
# en cours désapprouver |forward|trigger|negated|10|Group[287]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Verb2 Trigger_Rule
Adverb1 -> "jamais"
Verb2 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Trigger_Rule -> "|forward|trigger|negated|10|Group[289]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# jamais nié |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais contesté |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais rejeté |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais dénié |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais renié |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais disconvenu |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais contredit |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais démentir |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais refuser |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais réfuter |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais refusé |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais désapprouvé |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais démenti |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais réfuté |forward|trigger|negated|10|Group[289]|PRE-VALIDATION
# jamais impensé |forward|trigger|negated|10|Group[289]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adjective3 Noun4 Adposition5 Trigger_Rule
Noun1 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Adjective3 -> "d'autres"
Noun4 -> "symptômes" | "marque" | "indice" | "manifestation" | "présage" | "prodrome" | "syndrome" | "diagnostique" | "stigmate" | "signal" | "signe prognostique" | "signe avant-coureur" | "diagnostic" | "symptôme" | "affection"
Adposition5 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[291]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié d'autres symptômes de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres marque de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres indice de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres manifestation de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres présage de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres prodrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres syndrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres diagnostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres stigmate de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres signal de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres signe prognostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres signe avant-coureur de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres diagnostic de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres symptôme de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# nié d'autres affection de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# contesté d'autres symptômes de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# contesté d'autres marque de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# contesté d'autres indice de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# contesté d'autres manifestation de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# contesté d'autres présage de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
#
|forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuter d'autres présage de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuter d'autres prodrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuter d'autres syndrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuter d'autres diagnostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuter d'autres stigmate de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuter d'autres signal de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuter d'autres signe prognostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuter d'autres signe avant-coureur de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuter d'autres diagnostic de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuter d'autres symptôme de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuter d'autres affection de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres symptômes de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres marque de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres indice de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres manifestation de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres présage de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres prodrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres syndrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres diagnostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres stigmate de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres signal de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres signe prognostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres signe avant-coureur de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres diagnostic de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres symptôme de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# refusé d'autres affection de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres symptômes de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres marque de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres indice de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres manifestation de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres présage de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres prodrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres syndrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres diagnostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres stigmate de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres signal de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres signe prognostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres signe avant-coureur de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres diagnostic de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres symptôme de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# désapprouvé d'autres affection de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres symptômes de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres marque de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres indice de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres manifestation de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres présage de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres prodrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres syndrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres diagnostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres stigmate de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres signal de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres signe prognostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres signe avant-coureur de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres diagnostic de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres symptôme de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# démenti d'autres affection de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres symptômes de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres marque de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres indice de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres manifestation de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres présage de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres prodrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres syndrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres diagnostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres stigmate de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres signal de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres signe prognostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres signe avant-coureur de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres diagnostic de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres symptôme de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# réfuté d'autres affection de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres symptômes de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres marque de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres indice de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres manifestation de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres présage de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres prodrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres syndrome de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres diagnostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres stigmate de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres signal de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres signe prognostique de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres signe avant-coureur de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres diagnostic de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres symptôme de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION
# impensé d'autres affection de |forward|trigger|negated|10|Group[291]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Noun2 Adposition3 Trigger_Rule
Adverb1 -> "nié"
Noun2 -> "problèmes" | "question" | "ennui" | "souci" | "complication" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "tracas" | "problème" | "incident" | "couac"
Adposition3 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[293]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié problèmes avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION
# nié question avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION
# nié ennui avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION
# nié souci avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION
# nié complication avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION
# nié dysfonctionnement avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION
# nié disfonctionnement avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION
# nié soucis avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION
# nié tracas avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION
# nié problème avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION
# nié incident avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION
# nié couac avec |forward|trigger|negated|10|Group[293]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Noun2 Adposition3 Trigger_Rule
Adverb1 -> "nié"
Noun2 -> "symptômes" | "marque" | "indice" | "manifestation" | "présage" | "prodrome" | "syndrome" | "diagnostique" | "stigmate" | "signal" | "signe prognostique" | "signe avant-coureur" | "diagnostic" | "symptôme" | "affection"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[295]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié symptômes de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié marque de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié indice de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié manifestation de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié présage de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié prodrome de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié syndrome de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié diagnostique de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié stigmate de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié signal de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié signe prognostique de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié signe avant-coureur de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié diagnostic de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié symptôme de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION
# nié affection de |forward|trigger|negated|10|Group[295]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Sub3 Pronoun5 Verb6 Noun8 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Sub3 -> "qu'il"
Pronoun5 -> "y"
Verb6 -> "avait"
Noun8 -> "un courant" | "habituel" | "fréquent" | "connu" | "répandu" | "normal" | "classique" | "présent" | "commune" | "régulier" | "en cours"
Trigger_Rule -> "|forward|trigger|negated|10|Group[297]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a nié qu'il y avait un courant |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a nié qu'il y avait habituel |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a nié qu'il y avait fréquent |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a nié qu'il y avait connu |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a nié qu'il y avait répandu |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a nié qu'il y avait normal |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a nié qu'il y avait classique |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a nié qu'il y avait présent |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a nié qu'il y avait commune |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a nié qu'il y avait régulier |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a nié qu'il y avait en cours |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a contesté qu'il y avait un courant |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a contesté qu'il y avait habituel |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a contesté qu'il y avait fréquent |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a contesté qu'il y avait connu |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a contesté qu'il y avait répandu |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a contesté qu'il y avait normal |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a contesté qu'il y avait classique |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a contesté qu'il y avait présent |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a contesté qu'il y avait commune |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a contesté qu'il y avait régulier |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a contesté qu'il y avait en cours |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a rejeté qu'il y avait un courant |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a rejeté qu'il y avait habituel |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a rejeté qu'il y avait fréquent |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a rejeté qu'il y avait connu |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a rejeté qu'il y avait répandu |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a rejeté qu'il y avait normal |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
# a rejeté qu'il y avait classique |forward|trigger|negated|10|Group[297]|PRE-VALIDATION
#
|forward|trigger|negated|10|Group[300]|PRE-VALIDATION
# a réfuté qu'il y avait une histoire de |forward|trigger|negated|10|Group[300]|PRE-VALIDATION
# a réfuté qu'il y avait passé de |forward|trigger|negated|10|Group[300]|PRE-VALIDATION
# a réfuté qu'il y avait souvenir de |forward|trigger|negated|10|Group[300]|PRE-VALIDATION
# a réfuté qu'il y avait une historique de |forward|trigger|negated|10|Group[300]|PRE-VALIDATION
# a impensé qu'il y avait une histoire de |forward|trigger|negated|10|Group[300]|PRE-VALIDATION
# a impensé qu'il y avait passé de |forward|trigger|negated|10|Group[300]|PRE-VALIDATION
# a impensé qu'il y avait souvenir de |forward|trigger|negated|10|Group[300]|PRE-VALIDATION
# a impensé qu'il y avait une historique de |forward|trigger|negated|10|Group[300]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Subordinating_conjunction3 Pronoun5 Verb6 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Subordinating_conjunction3 -> "qu'il"
Pronoun5 -> "y"
Verb6 -> "avait"
Trigger_Rule -> "|forward|trigger|negated|10|Group[301]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a nié qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a contesté qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a rejeté qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a dénié qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a renié qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a disconvenu qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a contredit qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a démentir qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a refuser qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a réfuter qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a refusé qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a désapprouvé qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a démenti qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a réfuté qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION
# a impensé qu'il y avait |forward|trigger|negated|10|Group[301]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1  Pronoun3 Pronoun4 Auxiliary5 Adverb6 Verb7 Noun9 Adposition10 Trigger_Rule
Adverb1 -> "nié"
Pronoun3 -> "qu'il"
Pronoun4 -> "y"
Auxiliary5 -> "ait"
Adverb6 -> "jamais"
Verb7 -> "eu"
Noun9 -> "l'histoire" | "passé" | "souvenir" | "l'historique"
Adposition10 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[303]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[303]|PRE-VALIDATION
# nié qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[303]|PRE-VALIDATION
# nié qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[303]|PRE-VALIDATION
# nié qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[303]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Pronoun4 Pronoun5 Verb6 Adverb7 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Pronoun4 -> "qu'il"
Pronoun5 -> "y"
Verb6 -> "avait"
Adverb7 -> "jamais"
Trigger_Rule -> "|forward|trigger|negated|10|Group[305]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
#
|forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a désapprouvé qu' il y avait des incident de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a désapprouvé qu' il y avait des couac de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des problèmes de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des question de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des ennui de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des souci de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des complication de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des disfonctionnement de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des soucis de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des tracas de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des problème de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des incident de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a démenti qu' il y avait des couac de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des problèmes de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des question de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des ennui de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des souci de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des complication de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des disfonctionnement de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des soucis de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des tracas de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des problème de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des incident de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a réfuté qu' il y avait des couac de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des problèmes de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des question de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des ennui de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des souci de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des complication de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des disfonctionnement de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des soucis de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des tracas de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des problème de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des incident de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION
# a impensé qu' il y avait des couac de |forward|trigger|negated|10|Group[309]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Trigger_Rule
Adverb1 -> "nié"
Pronoun3 -> "qu'il"
Pronoun4 -> "y"
Verb5 -> "avait"
Determiner6 -> "des"
Noun7 -> "problèmes" | "question" | "ennui" | "souci" | "complication" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "tracas" | "problème" | "incident" | "couac"
Trigger_Rule -> "|forward|trigger|negated|10|Group[311]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié qu'il y avait des problèmes |forward|trigger|negated|10|Group[311]|PRE-VALIDATION
# nié qu'il y avait des question |forward|trigger|negated|10|Group[311]|PRE-VALIDATION
# nié qu'il y avait des ennui |forward|trigger|negated|10|Group[311]|PRE-VALIDATION
# nié qu'il y avait des souci |forward|trigger|negated|10|Group[311]|PRE-VALIDATION
# nié qu'il y avait des complication |forward|trigger|negated|10|Group[311]|PRE-VALIDATION
# nié qu'il y avait des dysfonctionnement |forward|trigger|negated|10|Group[311]|PRE-VALIDATION
# nié qu'il y avait des disfonctionnement |forward|trigger|negated|10|Group[311]|PRE-VALIDATION
# nié qu'il y avait des soucis |forward|trigger|negated|10|Group[311]|PRE-VALIDATION
# nié qu'il y avait des tracas |forward|trigger|negated|10|Group[311]|PRE-VALIDATION
# nié qu'il y avait des problème |forward|trigger|negated|10|Group[311]|PRE-VALIDATION
# nié qu'il y avait des incident |forward|trigger|negated|10|Group[311]|PRE-VALIDATION
# nié qu'il y avait des couac |forward|trigger|negated|10|Group[311]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Adposition8 Trigger_Rule
Adverb1 -> "nié"
Pronoun3 -> "qu'il"
Pronoun4 -> "y"
Verb5 -> "avait"
Determiner6 -> "des"
Noun7 -> "problèmes" | "question" | "ennui" | "souci" | "complication" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "tracas" | "problème" | "incident" | "couac"
Adposition8 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[323]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié qu'il y avait des problèmes de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION
# nié qu'il y avait des question de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION
# nié qu'il y avait des ennui de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION
# nié qu'il y avait des souci de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION
# nié qu'il y avait des complication de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION
# nié qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION
# nié qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION
# nié qu'il y avait des soucis de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION
# nié qu'il y avait des tracas de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION
# nié qu'il y avait des problème de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION
# nié qu'il y avait des incident de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION
# nié qu'il y avait des couac de |forward|trigger|negated|10|Group[323]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Determiner3 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Determiner3 -> "cette"
Trigger_Rule -> "|forward|trigger|negated|10|Group[327]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a nié cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a contesté cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a rejeté cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a dénié cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a renié cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a disconvenu cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a contredit cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a démentir cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a refuser cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a réfuter cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a refusé cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a désapprouvé cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a démenti cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a réfuté cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION
# a impensé cette |forward|trigger|negated|10|Group[327]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Noun3 Adjective5 Trigger_Rule
Verb1 -> "refusé" | "rejeter" | "renvoyer" | "contester" | "dédaigner" | "exclure" | "écarter" | "décliner" | "résister" | "répugner" | "dire non" | "retoquer" | "s'opposer" | "désapprouver"
Noun3 -> "l'utilisation" | "l'emploi" | "maniement" | "l'usage" | "l'exploitation" | "consommation" | "l'appel"
Adjective5 -> "d'autres"
Trigger_Rule -> "|forward|trigger|negated|10|Group[329]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# refusé l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# refusé l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# refusé maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# refusé l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# refusé l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# refusé consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# refusé l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# rejeter l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# rejeter l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# rejeter maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# rejeter l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# rejeter l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# rejeter consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# rejeter l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# renvoyer l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# renvoyer l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# renvoyer maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# renvoyer l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# renvoyer l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# renvoyer consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# renvoyer l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# contester l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# contester l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# contester maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# contester l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# contester l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# contester consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# contester l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dédaigner l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dédaigner l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dédaigner maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dédaigner l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dédaigner l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dédaigner consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dédaigner l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# exclure l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# exclure l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# exclure maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# exclure l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# exclure l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# exclure consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# exclure l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# écarter l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# écarter l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# écarter maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# écarter l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# écarter l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# écarter consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# écarter l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# décliner l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# décliner l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# décliner maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# décliner l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# décliner l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# décliner consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# décliner l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# résister l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# résister l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# résister maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# résister l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# résister l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# résister consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# résister l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# répugner l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# répugner l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# répugner maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# répugner l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# répugner l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# répugner consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# répugner l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dire non l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dire non l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dire non maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dire non l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dire non l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dire non consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# dire non l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# retoquer l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# retoquer l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# retoquer maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# retoquer l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# retoquer l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# retoquer consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# retoquer l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# s'opposer l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# s'opposer l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# s'opposer maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# s'opposer l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# s'opposer l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# s'opposer consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# s'opposer l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# désapprouver l'utilisation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# désapprouver l'emploi d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# désapprouver maniement d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# désapprouver l'usage d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# désapprouver l'exploitation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# désapprouver consommation d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION
# désapprouver l'appel d'autres |forward|trigger|negated|10|Group[329]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Verb2 Adposition3 Trigger_Rule
Noun1 -> "utilisation" | "emploi" | "maniement" | "usage" | "exploitation" | "consommation" | "appel"
Verb2 -> "refusée" | "rejeter" | "renvoyer" | "contester" | "nier" | "évincer" | "dédaigner" | "dénier" | "exclure" | "écarter" | "débouter" | "décliner" | "se rebeller" | "éliminer" | "résister"
Adposition3 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[331]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# utilisation refusée de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation rejeter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation renvoyer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation contester de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation nier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation évincer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation dédaigner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation dénier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation exclure de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation écarter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation débouter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation décliner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation se rebeller de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation éliminer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# utilisation résister de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi refusée de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi rejeter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi renvoyer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi contester de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi nier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi évincer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi dédaigner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi dénier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi exclure de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi écarter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi débouter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi décliner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi se rebeller de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi éliminer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# emploi résister de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement refusée de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement rejeter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement renvoyer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement contester de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement nier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement évincer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement dédaigner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement dénier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement exclure de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement écarter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement débouter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement décliner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement se rebeller de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement éliminer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# maniement résister de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage refusée de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage rejeter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage renvoyer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage contester de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage nier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage évincer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage dédaigner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage dénier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage exclure de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage écarter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage débouter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage décliner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage se rebeller de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage éliminer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# usage résister de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation refusée de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation rejeter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation renvoyer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation contester de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation nier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation évincer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation dédaigner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation dénier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation exclure de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation écarter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation débouter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation décliner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation se rebeller de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation éliminer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# exploitation résister de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation refusée de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation rejeter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation renvoyer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation contester de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation nier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation évincer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation dédaigner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation dénier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation exclure de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation écarter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation débouter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation décliner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation se rebeller de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation éliminer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# consommation résister de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel refusée de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel rejeter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel renvoyer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel contester de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel nier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel évincer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel dédaigner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel dénier de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel exclure de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel écarter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel débouter de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel décliner de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel se rebeller de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel éliminer de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION
# appel résister de |forward|trigger|negated|10|Group[331]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "nié" | "contesté" | "rejeté" | "dénié" | "renié" | "disconvenu" | "contredit" | "démentir" | "refuser" | "réfuter" | "refusé" | "désapprouvé" | "démenti" | "réfuté" | "impensé"
Trigger_Rule -> "|forward|trigger|negated|10|Group[333]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nié |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# contesté |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# rejeté |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# dénié |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# renié |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# disconvenu |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# contredit |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# démentir |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# refuser |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# réfuter |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# refusé |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# désapprouvé |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# démenti |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# réfuté |forward|trigger|negated|10|Group[333]|PRE-VALIDATION
# impensé |forward|trigger|negated|10|Group[333]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Adjective2 -> "actif"
Trigger_Rule -> "|forward|trigger|negated|10|Group[335]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# refuser actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# désavouer actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# contredire actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# renier actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# discuter actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# réfuter actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# contester actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# critiquer actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# dénier actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# rejeter actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# contesté actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# rejeté actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION
# dénié actif |forward|trigger|negated|10|Group[335]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adverb2 Adjective3 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Adverb2 -> "tout"
Adjective3 -> "anormal"
Trigger_Rule -> "|forward|trigger|negated|10|Group[337]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# refuser tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# désavouer tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# contredire tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# renier tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# discuter tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# réfuter tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# contester tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# critiquer tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# dénier tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# rejeter tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# contesté tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# rejeté tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# dénié tout anormal |forward|trigger|negated|10|Group[337]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Adverb2 Adverb3 Adposition4 Determiner5 Trigger_Rule
Verb1 -> "refuse" | "répudier" | "dédaigner" | "dénier" | "résister" | "rebeller" | "récuser" | "opposer" | "exclure" | "repousser" | "dit non" | "retourner" | "écarter" | "boycotter" | "débouter"
Adverb2 -> "tout"
Adverb3 -> "changement"
Adposition4 -> "dans"
Determiner5 -> "la"
Trigger_Rule -> "|forward|trigger|negated|10|Group[337]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# refuse tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# répudier tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# dédaigner tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# dénier tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# résister tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# rebeller tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# récuser tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# opposer tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# exclure tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# repousser tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# dit non tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# retourner tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# écarter tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# boycotter tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# débouter tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adverb2 Adverb3 Adposition4 Determiner5 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Adverb2 -> "tout"
Adverb3 -> "changement"
Adposition4 -> "dans"
Determiner5 -> "la"
Trigger_Rule -> "|forward|trigger|negated|10|Group[337]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# refuser tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# désavouer tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# contredire tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# renier tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# discuter tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# réfuter tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# contester tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# critiquer tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# dénier tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# rejeter tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# contesté tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# rejeté tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION
# dénié tout changement dans la |forward|trigger|negated|10|Group[337]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adverb2 Adjective3 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Adverb2 -> "tout"
Adjective3 -> "courant"
Trigger_Rule -> "|forward|trigger|negated|10|Group[343]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# refuser tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# désavouer tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# contredire tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# renier tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# discuter tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# réfuter tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# contester tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# critiquer tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# dénier tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# rejeter tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# contesté tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# rejeté tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION
# dénié tout courant |forward|trigger|negated|10|Group[343]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adjective4 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
# contester toute autre |forward|trigger|negated|10|Group[351]|PRE-VALIDATION
# critiquer toute autre |forward|trigger|negated|10|Group[351]|PRE-VALIDATION
# dénier toute autre |forward|trigger|negated|10|Group[351]|PRE-VALIDATION
# rejeter toute autre |forward|trigger|negated|10|Group[351]|PRE-VALIDATION
# contesté toute autre |forward|trigger|negated|10|Group[351]|PRE-VALIDATION
# rejeté toute autre |forward|trigger|negated|10|Group[351]|PRE-VALIDATION
# dénié toute autre |forward|trigger|negated|10|Group[351]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adposition4 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Determiner2 -> "tout"
Noun3 -> "problème" | "ennui" | "souci" | "complication" | "histoire" | "anomalie" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "mal" | "trouble"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[353]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# nie tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# nie tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# nie tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# nie tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# nie tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# nie tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# nie tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# nie tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# nie tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# nie tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# refuser tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# refuser tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# refuser tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# refuser tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# refuser tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# refuser tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# refuser tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# refuser tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# refuser tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# refuser tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# refuser tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# désavouer tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# désavouer tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# désavouer tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# désavouer tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# désavouer tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# désavouer tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# désavouer tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# désavouer tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# désavouer tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# désavouer tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# désavouer tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contredire tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contredire tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contredire tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contredire tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contredire tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contredire tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contredire tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contredire tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contredire tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contredire tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contredire tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# renier tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# renier tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# renier tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# renier tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# renier tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# renier tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# renier tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# renier tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# renier tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# renier tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# renier tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# discuter tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# discuter tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# discuter tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# discuter tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# discuter tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# discuter tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# discuter tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# discuter tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# discuter tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# discuter tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# discuter tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# réfuter tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# réfuter tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# réfuter tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# réfuter tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# réfuter tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# réfuter tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# réfuter tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# réfuter tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# réfuter tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# réfuter tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# réfuter tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contester tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contester tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contester tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contester tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contester tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contester tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contester tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contester tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contester tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contester tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contester tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# critiquer tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# critiquer tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# critiquer tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# critiquer tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# critiquer tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# critiquer tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# critiquer tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# critiquer tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# critiquer tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# critiquer tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# critiquer tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénier tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénier tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénier tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénier tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénier tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénier tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénier tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénier tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénier tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénier tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénier tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeter tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeter tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeter tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeter tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeter tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeter tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeter tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeter tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeter tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeter tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeter tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contesté tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contesté tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contesté tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contesté tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contesté tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contesté tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contesté tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contesté tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contesté tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contesté tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# contesté tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeté tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeté tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeté tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeté tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeté tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeté tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeté tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeté tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeté tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeté tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# rejeté tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénié tout problème de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénié tout ennui de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénié tout souci de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénié tout complication de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénié tout histoire de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénié tout anomalie de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénié tout dysfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénié tout disfonctionnement de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénié tout soucis de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénié tout mal de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION
# dénié tout trouble de |forward|trigger|negated|10|Group[353]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adverb2 Noun3 Adposition4 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Adverb2 -> "tout"
Noun3 -> "problème" | "ennui" | "souci" | "complication" | "histoire" | "anomalie" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "mal" | "trouble"
Adposition4 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[355]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie tout problème avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# nie tout ennui avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# nie tout souci avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# nie tout complication avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# nie tout histoire avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# nie tout anomalie avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# nie tout dysfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# nie tout disfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# nie tout soucis avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# nie tout mal avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# nie tout trouble avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# refuser tout problème avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# refuser tout ennui avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# refuser tout souci avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# refuser tout complication avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# refuser tout histoire avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# refuser tout anomalie avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# refuser tout dysfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# refuser tout disfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# refuser tout soucis avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# refuser tout mal avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# refuser tout trouble avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# désavouer tout problème avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# désavouer tout ennui avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# désavouer tout souci avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# désavouer tout complication avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# désavouer tout histoire avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# désavouer tout anomalie avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# désavouer tout dysfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# désavouer tout disfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# désavouer tout soucis avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# désavouer tout mal avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# désavouer tout trouble avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contredire tout problème avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contredire tout ennui avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contredire tout souci avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contredire tout complication avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contredire tout histoire avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contredire tout anomalie avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contredire tout dysfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contredire tout disfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contredire tout soucis avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contredire tout mal avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contredire tout trouble avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# renier tout problème avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# renier tout ennui avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# renier tout souci avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# renier tout complication avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# renier tout histoire avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# renier tout anomalie avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# renier tout dysfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# renier tout disfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# renier tout soucis avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# renier tout mal avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# renier tout trouble avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# discuter tout problème avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# discuter tout ennui avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# discuter tout souci avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# discuter tout complication avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# discuter tout histoire avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# discuter tout anomalie avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# discuter tout dysfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# discuter tout disfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# discuter tout soucis avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# discuter tout mal avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# discuter tout trouble avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# réfuter tout problème avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# réfuter tout ennui avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# réfuter tout souci avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# réfuter tout complication avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# réfuter tout histoire avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# réfuter tout anomalie avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# réfuter tout dysfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# réfuter tout disfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# réfuter tout soucis avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# réfuter tout mal avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# réfuter tout trouble avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contester tout problème avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contester tout ennui avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contester tout souci avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contester tout complication avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contester tout histoire avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contester tout anomalie avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contester tout dysfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contester tout disfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contester tout soucis avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contester tout mal avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# contester tout trouble avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# critiquer tout problème avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# critiquer tout ennui avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# critiquer tout souci avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# critiquer tout complication avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# critiquer tout histoire avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# critiquer tout anomalie avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# critiquer tout dysfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# critiquer tout disfonctionnement avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# critiquer tout soucis avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# critiquer tout mal avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# critiquer tout trouble avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# dénier tout problème avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# dénier tout ennui avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# dénier tout souci avec |forward|trigger|negated|10|Group[355]|PRE-VALIDATION
# d
forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# critiquer tout histoire |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# critiquer tout anomalie |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# critiquer tout dysfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# critiquer tout disfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# critiquer tout soucis |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# critiquer tout mal |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# critiquer tout trouble |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénier tout problème |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénier tout ennui |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénier tout souci |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénier tout complication |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénier tout histoire |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénier tout anomalie |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénier tout dysfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénier tout disfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénier tout soucis |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénier tout mal |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénier tout trouble |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeter tout problème |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeter tout ennui |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeter tout souci |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeter tout complication |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeter tout histoire |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeter tout anomalie |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeter tout dysfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeter tout disfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeter tout soucis |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeter tout mal |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeter tout trouble |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# contesté tout problème |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# contesté tout ennui |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# contesté tout souci |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# contesté tout complication |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# contesté tout histoire |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# contesté tout anomalie |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# contesté tout dysfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# contesté tout disfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# contesté tout soucis |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# contesté tout mal |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# contesté tout trouble |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeté tout problème |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeté tout ennui |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeté tout souci |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeté tout complication |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeté tout histoire |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeté tout anomalie |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeté tout dysfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeté tout disfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeté tout soucis |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeté tout mal |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# rejeté tout trouble |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénié tout problème |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénié tout ennui |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénié tout souci |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénié tout complication |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénié tout histoire |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénié tout anomalie |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénié tout dysfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénié tout disfonctionnement |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénié tout soucis |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénié tout mal |forward|trigger|negated|10|Group[357]|PRE-VALIDATION
# dénié tout trouble |forward|trigger|negated|10|Group[357]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Determiner2 Adjective3 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Determiner2 -> "toute"
Adjective3 -> "récente"
Trigger_Rule -> "|forward|trigger|negated|10|Group[359]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# refuser toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# désavouer toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# contredire toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# renier toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# discuter toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# réfuter toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# contester toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# critiquer toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# dénier toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# rejeter toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# contesté toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# rejeté toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION
# dénié toute récente |forward|trigger|negated|10|Group[359]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

#  Item Number     : 194
#  French Term     : nie toute importance
#  English Term(s) : ['denies any significant']
#  Index(es)       : [400]
#  Grouping(s)     : [361]


cfg_grammar= """
S ->  Noun1 Adjective2 Noun3 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Adjective2 -> "toute"
Noun3 -> "importance" | "ostentation" | "profondeur" | "signifiance" | "urgence"
Trigger_Rule -> "|forward|trigger|negated|10|Group[361]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# nie toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# nie toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# nie toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# nie toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# refuser toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# refuser toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# refuser toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# refuser toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# refuser toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# désavouer toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# désavouer toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# désavouer toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# désavouer toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# désavouer toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contredire toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contredire toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contredire toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contredire toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contredire toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# renier toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# renier toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# renier toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# renier toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# renier toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# discuter toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# discuter toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# discuter toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# discuter toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# discuter toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# réfuter toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# réfuter toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# réfuter toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# réfuter toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# réfuter toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contester toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contester toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contester toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contester toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contester toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# critiquer toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# critiquer toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# critiquer toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# critiquer toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# critiquer toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# dénier toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# dénier toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# dénier toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# dénier toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# dénier toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# rejeter toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# rejeter toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# rejeter toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# rejeter toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# rejeter toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contesté toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contesté toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contesté toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contesté toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# contesté toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# rejeté toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# rejeté toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# rejeté toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# rejeté toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# rejeté toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# dénié toute importance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# dénié toute ostentation |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# dénié toute profondeur |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# dénié toute signifiance |forward|trigger|negated|10|Group[361]|PRE-VALIDATION
# dénié toute urgence |forward|trigger|negated|10|Group[361]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adposition4 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Determiner2 -> "tout"
Noun3 -> "symptôme"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[363]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# refuser tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# désavouer tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# contredire tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# renier tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# discuter tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# réfuter tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# contester tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# critiquer tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# dénier tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# rejeter tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# contesté tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# rejeté tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION
# dénié tout symptôme de |forward|trigger|negated|10|Group[363]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Determiner2 -> "tout"
Noun3 -> "abus" | "excès" | "exagération" | "surabondance" | "débordement" | "trop" | "débauche" | "démesure" | "disproportion" | "surnombre" | "surpassement"
Trigger_Rule -> "|forward|trigger|negated|10|Group[367]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie tout abus |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# nie tout excès |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# nie tout exagération |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# nie tout surabondance |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# nie tout débordement |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# nie tout trop |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# nie tout débauche |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# nie tout démesure |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# nie tout disproportion |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# nie tout surnombre |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# nie tout surpassement |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# refuser tout abus |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# refuser tout excès |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
# refuser tout exagération |forward|trigger|negated|10|Group[367]|PRE-VALIDATION
|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# refuser tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# désavouer tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# contredire tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# renier tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# discuter tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# réfuter tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# contester tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# critiquer tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# dénier tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# rejeter tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# contesté tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# rejeté tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION
# dénié tout |forward|trigger|negated|10|Group[369]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Verb2 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Verb2 -> "courant" | "habituel" | "fréquent" | "connu" | "répandu" | "normal" | "classique" | "présent" | "commune" | "régulier" | "en cours"
Trigger_Rule -> "|forward|trigger|negated|10|Group[371]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# nie habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# nie fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# nie connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# nie répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# nie normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# nie classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# nie présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# nie commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# nie régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# nie en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# refuser courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# refuser habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# refuser fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# refuser connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# refuser répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# refuser normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# refuser classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# refuser présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# refuser commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# refuser régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# refuser en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# désavouer courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# désavouer habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# désavouer fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# désavouer connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# désavouer répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# désavouer normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# désavouer classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# désavouer présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# désavouer commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# désavouer régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# désavouer en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contredire courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contredire habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contredire fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contredire connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contredire répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contredire normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contredire classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contredire présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contredire commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contredire régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contredire en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# renier courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# renier habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# renier fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# renier connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# renier répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# renier normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# renier classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# renier présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# renier commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# renier régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# renier en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# discuter courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# discuter habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# discuter fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# discuter connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# discuter répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# discuter normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# discuter classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# discuter présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# discuter commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# discuter régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# discuter en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# réfuter courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# réfuter habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# réfuter fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# réfuter connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# réfuter répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# réfuter normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# réfuter classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# réfuter présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# réfuter commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# réfuter régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# réfuter en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contester courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contester habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contester fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contester connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contester répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contester normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contester classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contester présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contester commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contester régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contester en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# critiquer courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# critiquer habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# critiquer fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# critiquer connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# critiquer répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# critiquer normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# critiquer classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# critiquer présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# critiquer commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# critiquer régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# critiquer en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénier courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénier habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénier fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénier connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénier répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénier normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénier classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénier présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénier commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénier régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénier en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeter courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeter habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeter fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeter connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeter répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeter normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeter classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeter présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeter commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeter régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeter en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contesté courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contesté habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contesté fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contesté connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contesté répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contesté normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contesté classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contesté présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contesté commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contesté régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# contesté en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeté courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeté habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeté fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeté connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeté répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeté normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeté classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeté présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeté commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeté régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# rejeté en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénié courant |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénié habituel |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénié fréquent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénié connu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénié répandu |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénié normal |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénié classique |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénié présent |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénié commune |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénié régulier |forward|trigger|negated|10|Group[371]|PRE-VALIDATION
# dénié en cours |forward|trigger|negated|10|Group[371]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adverb2 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Adverb2 -> "jamais"
Trigger_Rule -> "|forward|trigger|negated|10|Group[373]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# refuser jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# désavouer jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# contredire jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# renier jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# discuter jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# réfuter jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# contester jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# critiquer jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# dénier jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# rejeter jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# contesté jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# rejeté jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION
# dénié jamais |forward|trigger|negated|10|Group[373]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Adposition4 Trigger_Rule
Adverb1 -> "nie"
Determiner2 -> "les"
Noun3 -> "problèmes" | "question" | "ennui" | "souci" | "complication" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "tracas" | "problème" | "incident" | "couac"
Adposition4 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[375]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie les problèmes avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
# nie les question avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
# nie les ennui avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
# nie les souci avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
# nie les complication avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
# nie les dysfonctionnement avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
# nie les disfonctionnement avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
# nie les soucis avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
# nie les tracas avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
# nie les problème avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
# nie les incident avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
# nie les couac avec |forward|trigger|negated|10|Group[375]|PRE-VALIDATION
