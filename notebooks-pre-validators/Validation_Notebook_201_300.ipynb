# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Adjective2 -> "significatif"
Trigger_Rule -> "|forward|trigger|negated|10|Group[377]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# refuser significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# désavouer significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# contredire significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# renier significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# discuter significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# réfuter significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# contester significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# critiquer significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# dénier significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# rejeter significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# contesté significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# rejeté significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION
# dénié significatif |forward|trigger|negated|10|Group[377]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Determiner2 Noun3 Adposition4 Trigger_Rule
Adverb1 -> "nie"
Determiner2 -> "les"
Noun3 -> "symptômes" | "marque" | "indice" | "manifestation" | "présage" | "prodrome" | "syndrome" | "diagnostique" | "stigmate" | "signal" | "signe prognostique" | "signe avant-coureur" | "diagnostic" | "symptôme" | "affection"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[379]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie les symptômes de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les marque de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les indice de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les manifestation de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les présage de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les prodrome de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les syndrome de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les diagnostique de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les stigmate de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les signal de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les signe prognostique de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les signe avant-coureur de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les diagnostic de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les symptôme de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION
# nie les affection de |forward|trigger|negated|10|Group[379]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1  Pronoun3 Pronoun4 Verb5 Noun7 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Pronoun3 -> "qu'il"
Pronoun4 -> "y"
Verb5 -> "avait"
Noun7 -> "du courant" | "habituel" | "fréquent" | "connu" | "répandu" | "normal" | "classique" | "présent" | "commune" | "régulier" | "en cours"
Trigger_Rule -> "|forward|trigger|negated|10|Group[381]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# nie qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# nie qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# nie qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# nie qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# nie qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# nie qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# nie qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# nie qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# nie qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# nie qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# refuser qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# refuser qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# refuser qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# refuser qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# refuser qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# refuser qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# refuser qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# refuser qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# refuser qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# refuser qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# refuser qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# désavouer qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# désavouer qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# désavouer qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# désavouer qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# désavouer qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# désavouer qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# désavouer qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# désavouer qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# désavouer qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# désavouer qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# désavouer qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contredire qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contredire qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contredire qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contredire qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contredire qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contredire qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contredire qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contredire qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contredire qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contredire qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contredire qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# renier qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# renier qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# renier qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# renier qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# renier qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# renier qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# renier qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# renier qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# renier qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# renier qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# renier qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# discuter qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# discuter qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# discuter qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# discuter qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# discuter qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# discuter qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# discuter qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# discuter qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# discuter qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# discuter qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# discuter qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# réfuter qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# réfuter qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# réfuter qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# réfuter qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# réfuter qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# réfuter qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# réfuter qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# réfuter qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# réfuter qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# réfuter qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# réfuter qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contester qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contester qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contester qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contester qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contester qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contester qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contester qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contester qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contester qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contester qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contester qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# critiquer qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# critiquer qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# critiquer qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# critiquer qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# critiquer qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# critiquer qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# critiquer qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# critiquer qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# critiquer qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# critiquer qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# critiquer qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénier qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénier qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénier qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénier qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénier qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénier qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénier qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénier qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénier qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénier qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénier qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeter qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeter qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeter qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeter qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeter qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeter qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeter qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeter qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeter qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeter qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeter qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contesté qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contesté qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contesté qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contesté qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contesté qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contesté qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contesté qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contesté qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contesté qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contesté qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# contesté qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeté qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeté qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeté qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeté qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeté qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeté qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeté qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeté qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeté qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeté qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# rejeté qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénié qu'il y avait du courant |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénié qu'il y avait habituel |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénié qu'il y avait fréquent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénié qu'il y avait connu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénié qu'il y avait répandu |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénié qu'il y avait normal |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénié qu'il y avait classique |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénié qu'il y avait présent |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénié qu'il y avait commune |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénié qu'il y avait régulier |forward|trigger|negated|10|Group[381]|PRE-VALIDATION
# dénié qu'il y avait en cours |forward|trigger|negated|10|Group[381]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Adposition8 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Pronoun3 -> "qu'il"
Pronoun4 -> "y"
Verb5 -> "ait"
Determiner6 -> "des"
Noun7 -> "antécédents" | "antérieur" | "préalable" | "préexistant" | "passé" | "hérédité" | "précurseur" | "précédente" | "antériorité" | "préliminaire" | "condition" | "premier" | "antan" | "ancienneté" | "antécédence"
Adposition8 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[383]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# nie qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# refuser qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# désavouer qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contredire qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# renier qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# discuter qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# réfuter qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contester qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# critiquer qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénier qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeter qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# contesté qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# rejeté qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des antécédents de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des antérieur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des préalable de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des préexistant de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des passé de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des hérédité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des précurseur de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des précédente de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des antériorité de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des préliminaire de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des condition de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des premier de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des antan de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des ancienneté de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION
# dénié qu'il y ait des antécédence de |forward|trigger|negated|10|Group[383]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Pronoun2 Pronoun3 Verb4 Determiner5 Adjective6 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Pronoun2 -> "il"
Pronoun3 -> "y"
Verb4 -> "avait"
Determiner5 -> "aucune"
Adjective6 -> "récente"
Trigger_Rule -> "|forward|trigger|negated|10|Group[385]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# refuser il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# désavouer il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# contredire il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# renier il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# discuter il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# réfuter il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# contester il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# critiquer il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# dénier il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# rejeter il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# contesté il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# rejeté il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION
# dénié il y avait aucune récente |forward|trigger|negated|10|Group[385]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Pronoun3 Pronoun4 Pronoun5 Verb6 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Pronoun3 -> "qu'il"
Pronoun4 -> "y"
Pronoun5 -> "en"
Verb6 -> "ait"
Trigger_Rule -> "|forward|trigger|negated|10|Group[387]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# refuser qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# désavouer qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# contredire qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# renier qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# discuter qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# réfuter qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# contester qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# critiquer qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# dénier qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# rejeter qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# contesté qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# rejeté qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION
# dénié qu'il y en ait |forward|trigger|negated|10|Group[387]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Pronoun3 Pronoun4 Auxiliary5 Adverb6 Verb7 Noun9 Adposition10 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Pronoun3 -> "qu'il"
Pronoun4 -> "y"
Auxiliary5 -> "ait"
Adverb6 -> "jamais"
Verb7 -> "eu"
Noun9 -> "l'histoire" | "passé" | "souvenir" | "l'historique"
Adposition10 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[389]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# nie qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# nie qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# nie qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# refuser qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# refuser qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# refuser qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# refuser qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# désavouer qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# désavouer qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# désavouer qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# désavouer qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contredire qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contredire qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contredire qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contredire qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# renier qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# renier qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# renier qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# renier qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# discuter qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# discuter qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# discuter qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# discuter qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# réfuter qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# réfuter qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# réfuter qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# réfuter qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contester qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contester qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contester qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contester qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# critiquer qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# critiquer qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# critiquer qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# critiquer qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# dénier qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# dénier qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# dénier qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# dénier qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# rejeter qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# rejeter qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# rejeter qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# rejeter qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contesté qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contesté qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contesté qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# contesté qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# rejeté qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# rejeté qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# rejeté qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# rejeté qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# dénié qu'il y ait jamais eu l'histoire de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# dénié qu'il y ait jamais eu passé de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# dénié qu'il y ait jamais eu souvenir de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION
# dénié qu'il y ait jamais eu l'historique de |forward|trigger|negated|10|Group[389]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Pronoun2 Pronoun3 Verb4 Adverb5 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Pronoun2 -> "il"
Pronoun3 -> "y"
Verb4 -> "avait"
Adverb5 -> "jamais"
Trigger_Rule -> "|forward|trigger|negated|10|Group[391]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# refuser il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# désavouer il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# contredire il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# renier il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# discuter il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# réfuter il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# contester il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# critiquer il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# dénier il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# rejeter il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# contesté il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# rejeté il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION
# dénié il y avait jamais |forward|trigger|negated|10|Group[391]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Adposition8 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Pronoun3 -> "qu'il"
Pronoun4 -> "y"
Verb5 -> "avait"
Determiner6 -> "une"
Noun7 -> "histoire" | "passé" | "souvenir" | "historique"
Adposition8 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[393]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# nie qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# nie qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# nie qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# refuser qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# refuser qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# refuser qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# refuser qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# désavouer qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# désavouer qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# désavouer qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# désavouer qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contredire qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contredire qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contredire qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contredire qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# renier qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# renier qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# renier qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# renier qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# discuter qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# discuter qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# discuter qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# discuter qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# réfuter qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# réfuter qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# réfuter qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# réfuter qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contester qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contester qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contester qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contester qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# critiquer qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# critiquer qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# critiquer qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# critiquer qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# dénier qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# dénier qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# dénier qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# dénier qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# rejeter qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# rejeter qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# rejeter qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# rejeter qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contesté qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contesté qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contesté qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# contesté qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# rejeté qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# rejeté qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# rejeté qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# rejeté qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# dénié qu'il y avait une histoire de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# dénié qu'il y avait une passé de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# dénié qu'il y avait une souvenir de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION
# dénié qu'il y avait une historique de |forward|trigger|negated|10|Group[393]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Adposition8 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Pronoun3 -> "qu'il"
Pronoun4 -> "y"
Verb5 -> "avait"
Determiner6 -> "des"
Noun7 -> "problèmes" | "question" | "ennui" | "souci" | "complication" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "tracas" | "problème" | "incident" | "couac"
Adposition8 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[395]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# nie qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# nie qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# nie qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# nie qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# nie qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# nie qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# nie qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# nie qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# nie qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# nie qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# nie qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# refuser qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# désavouer qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contredire qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# renier qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# discuter qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# réfuter qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contester qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# critiquer qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénier qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeter qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# contesté qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# rejeté qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des problèmes de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des question de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des ennui de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des souci de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des complication de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des dysfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des disfonctionnement de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des soucis de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des tracas de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des problème de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des incident de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION
# dénié qu'il y avait des couac de |forward|trigger|negated|10|Group[395]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Subordinating_conjunction2 Pronoun3 Pronoun4 Verb5 Determiner6 Noun7 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Subordinating_conjunction2 -> "qu'"
Pronoun3 -> "il"
Pronoun4 -> "y"
Verb5 -> "avait"
Determiner6 -> "des"
Noun7 -> "problèmes" | "question" | "ennui" | "souci" | "complication" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "tracas" | "problème" | "incident" | "couac"
Trigger_Rule -> "|forward|trigger|negated|10|Group[397]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# nie qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# nie qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# nie qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# nie qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# nie qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# nie qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# nie qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# nie qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# nie qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# nie qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# nie qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# refuser qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# désavouer qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contredire qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# renier qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# discuter qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# réfuter qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contester qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# critiquer qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénier qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeter qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# contesté qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# rejeté qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des problèmes |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des question |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des ennui |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des souci |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des complication |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des dysfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des disfonctionnement |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des soucis |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des tracas |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des problème |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des incident |forward|trigger|negated|10|Group[397]|PRE-VALIDATION
# dénié qu' il y avait des couac |forward|trigger|negated|10|Group[397]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Pronoun3 Pronoun4 Auxiliary5 Verb6 Determiner7 Noun8 Adposition9 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Pronoun3 -> "qu'il"
Pronoun4 -> "y"
Auxiliary5 -> "ait"
Verb6 -> "eu"
Determiner7 -> "des"
Noun8 -> "antécédents" | "antérieur" | "préalable" | "préexistant" | "passé" | "hérédité" | "précurseur" | "précédente" | "antériorité" | "préliminaire" | "condition" | "premier" | "antan" | "ancienneté" | "antécédence"
Adposition9 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[399]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# nie qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# refuser qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# désavouer qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contredire qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# renier qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# discuter qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# réfuter qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contester qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# critiquer qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénier qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeter qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# contesté qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# rejeté qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des antécédents de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des antérieur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des préalable de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des préexistant de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des passé de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des hérédité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des précurseur de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des précédente de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des antériorité de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des préliminaire de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des condition de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des premier de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des antan de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des ancienneté de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION
# dénié qu'il y ait eu des antécédence de |forward|trigger|negated|10|Group[399]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Pronoun2 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Pronoun2 -> "cela"
Trigger_Rule -> "|forward|trigger|negated|10|Group[413]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# refuser cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# désavouer cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# contredire cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# renier cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# discuter cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# réfuter cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# contester cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# critiquer cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# dénier cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# rejeter cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# contesté cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# rejeté cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION
# dénié cela |forward|trigger|negated|10|Group[413]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Adjective2 -> "vrai"
Trigger_Rule -> "|forward|trigger|negated|10|Group[415]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# refuser vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# désavouer vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# contredire vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# renier vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# discuter vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# réfuter vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# contester vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# critiquer vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# dénier vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# rejeter vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# contesté vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# rejeté vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION
# dénié vrai |forward|trigger|negated|10|Group[415]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Noun3 Adposition4 Adjective5 Trigger_Rule
Verb1 -> "refuse" | "répudier" | "dédaigner" | "dénier" | "résister" | "rebeller" | "récuser" | "opposer" | "exclure" | "repousser" | "dit non" | "retourner" | "écarter" | "boycotter" | "débouter"
Noun3 -> "l'utilisation" | "l'emploi" | "maniement" | "l'usage" | "l'exploitation" | "consommation" | "l'appel"
Adposition4 -> "d'"
Adjective5 -> "autres"
Trigger_Rule -> "|forward|trigger|negated|10|Group[417]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# refuse l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# refuse l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# refuse maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# refuse l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# refuse l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# refuse consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# refuse l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# répudier l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# répudier l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# répudier maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# répudier l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# répudier l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# répudier consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# répudier l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dédaigner l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dédaigner l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dédaigner maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dédaigner l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dédaigner l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dédaigner consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dédaigner l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dénier l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dénier l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dénier maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dénier l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dénier l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dénier consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dénier l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# résister l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# résister l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# résister maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# résister l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# résister l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# résister consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# résister l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# rebeller l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# rebeller l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# rebeller maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# rebeller l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# rebeller l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# rebeller consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# rebeller l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# récuser l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# récuser l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# récuser maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# récuser l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# récuser l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# récuser consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# récuser l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# opposer l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# opposer l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# opposer maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# opposer l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# opposer l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# opposer consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# opposer l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# exclure l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# exclure l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# exclure maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# exclure l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# exclure l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# exclure consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# exclure l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# repousser l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# repousser l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# repousser maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# repousser l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# repousser l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# repousser consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# repousser l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dit non l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dit non l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dit non maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dit non l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dit non l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dit non consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# dit non l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# retourner l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# retourner l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# retourner maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# retourner l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# retourner l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# retourner consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# retourner l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# écarter l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# écarter l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# écarter maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# écarter l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# écarter l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# écarter consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# écarter l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# boycotter l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# boycotter l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# boycotter maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# boycotter l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# boycotter l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# boycotter consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# boycotter l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# débouter l'utilisation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# débouter l'emploi d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# débouter maniement d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# débouter l'usage d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# débouter l'exploitation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# débouter consommation d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION
# débouter l'appel d' autres |forward|trigger|negated|10|Group[417]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Noun3 Adposition4 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Noun3 -> "l'utilisation" | "l'emploi" | "maniement" | "l'usage" | "l'exploitation" | "consommation" | "l'appel"
Adposition4 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[419]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# nie l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# nie maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# nie l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# nie l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# nie consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# nie l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# refuser l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# refuser l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# refuser maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# refuser l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# refuser l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# refuser consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# refuser l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# désavouer l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# désavouer l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# désavouer maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# désavouer l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# désavouer l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# désavouer consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# désavouer l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contredire l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contredire l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contredire maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contredire l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contredire l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contredire consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contredire l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# renier l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# renier l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# renier maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# renier l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# renier l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# renier consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# renier l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# discuter l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# discuter l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# discuter maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# discuter l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# discuter l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# discuter consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# discuter l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# réfuter l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# réfuter l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# réfuter maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# réfuter l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# réfuter l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# réfuter consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# réfuter l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contester l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contester l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contester maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contester l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contester l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contester consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contester l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# critiquer l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# critiquer l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# critiquer maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# critiquer l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# critiquer l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# critiquer consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# critiquer l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénier l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénier l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénier maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénier l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénier l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénier consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénier l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeter l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeter l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeter maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeter l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeter l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeter consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeter l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contesté l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contesté l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contesté maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contesté l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contesté l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contesté consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# contesté l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeté l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeté l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeté maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeté l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeté l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeté consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# rejeté l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénié l'utilisation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénié l'emploi de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénié maniement de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénié l'usage de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénié l'exploitation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénié consommation de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION
# dénié l'appel de |forward|trigger|negated|10|Group[419]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "nie" | "refuser" | "désavouer" | "contredire" | "renier" | "discuter" | "réfuter" | "contester" | "critiquer" | "dénier" | "rejeter" | "contesté" | "rejeté" | "dénié"
Trigger_Rule -> "|forward|trigger|negated|10|Group[421]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nie |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# refuser |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# désavouer |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# contredire |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# renier |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# discuter |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# réfuter |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# contester |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# critiquer |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# dénier |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# rejeter |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# contesté |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# rejeté |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# dénié |forward|trigger|negated|10|Group[421]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Trigger_Rule
Adverb1 -> "nier" | "denise" | "nier"
Trigger_Rule -> "|forward|trigger|negated|10|Group[421]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# nier |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# denise |forward|trigger|negated|10|Group[421]|PRE-VALIDATION
# nier |forward|trigger|negated|10|Group[421]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "eu"
Trigger_Rule -> "|forward|termination|negated|10|Group[429]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a eu |forward|termination|negated|10|Group[429]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->   Auxiliary2 Verb3 Determiner4 Noun5 Adposition6 Trigger_Rule
Auxiliary2 -> "n'a"
Verb3 -> "eu"
Determiner4 -> "aucun"
Noun5 -> "épisode" | "moment" | "phase" | "événement" | "évènement" | "séquence" | "suite" | "période"
Adposition6 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[430]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a eu aucun épisode de |forward|trigger|negated|10|Group[430]|PRE-VALIDATION
# n'a eu aucun moment de |forward|trigger|negated|10|Group[430]|PRE-VALIDATION
# n'a eu aucun phase de |forward|trigger|negated|10|Group[430]|PRE-VALIDATION
# n'a eu aucun événement de |forward|trigger|negated|10|Group[430]|PRE-VALIDATION
# n'a eu aucun évènement de |forward|trigger|negated|10|Group[430]|PRE-VALIDATION
# n'a eu aucun séquence de |forward|trigger|negated|10|Group[430]|PRE-VALIDATION
# n'a eu aucun suite de |forward|trigger|negated|10|Group[430]|PRE-VALIDATION
# n'a eu aucun période de |forward|trigger|negated|10|Group[430]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Verb2 Adverb3 Noun5 Adposition6 Trigger_Rule
Verb2 -> "n'a"
Adverb3 -> "plus"
Noun5 -> "d'épisodes" | "fait" | "d'histoire" | "phase" | "d'accident" | "d'événement" | "d'époque" | "d'évènement" | "séquence" | "suite" | "mésaventure" | "période"
Adposition6 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[432]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a plus d'épisodes de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION
# n'a plus fait de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION
# n'a plus d'histoire de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION
# n'a plus phase de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION
# n'a plus d'accident de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION
# n'a plus d'événement de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION
# n'a plus d'époque de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION
# n'a plus d'évènement de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION
# n'a plus séquence de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION
# n'a plus suite de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION
# n'a plus mésaventure de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION
# n'a plus période de |forward|trigger|negated|10|Group[432]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Adverb3 Verb4 Adposition5 Noun6 Trigger_Rule
Auxiliary2 -> "n'a"
Adverb3 -> "pas"
Verb4 -> "eu"
Adposition5 -> "de"
Noun6 -> "problèmes" | "question" | "ennui" | "souci" | "complication" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "tracas" | "problème" | "incident" | "couac"
Trigger_Rule -> "|forward|trigger|negated|10|Group[434]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a pas eu de problèmes |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de question |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de ennui |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de souci |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de complication |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de dysfonctionnement |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de disfonctionnement |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de soucis |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de tracas |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de problème |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de incident |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de couac |forward|trigger|negated|10|Group[434]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Adverb3 Verb4 Adposition5 Noun6 Adposition7 Trigger_Rule
Auxiliary2 -> "n'a"
Adverb3 -> "pas"
Verb4 -> "eu"
Adposition5 -> "de"
Noun6 -> "problèmes" | "question" | "ennui" | "souci" | "complication" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "tracas" | "problème" | "incident" | "couac"
Adposition7 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[434]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a pas eu de problèmes avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de question avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de tracas avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de incident avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a pas eu de couac avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Verb3 Determiner4 Noun5 Adposition6 Trigger_Rule
Auxiliary2 -> "n'a"
Verb3 -> "signalé" | "indiqué" | "notifié" | "découvert" | "montré" | "dévoilé" | "souligné" | "informé" | "révélé" | "signifié" | "déclaré" | "averti" | "rapporté" | "témoigné" | "alerté"
Determiner4 -> "aucun"
Noun5 -> "problème" | "ennui" | "souci" | "complication" | "histoire" | "anomalie" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "mal" | "trouble"
Adposition6 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[434]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a signalé aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signalé aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signalé aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signalé aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signalé aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signalé aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signalé aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signalé aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signalé aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signalé aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signalé aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a indiqué aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a indiqué aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a indiqué aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a indiqué aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a indiqué aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a indiqué aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a indiqué aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a indiqué aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a indiqué aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a indiqué aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a indiqué aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a notifié aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a notifié aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a notifié aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a notifié aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a notifié aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a notifié aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a notifié aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a notifié aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a notifié aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a notifié aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a notifié aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a découvert aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a découvert aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a découvert aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a découvert aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a découvert aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a découvert aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a découvert aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a découvert aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a découvert aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a découvert aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a découvert aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a montré aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a montré aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a montré aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a montré aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a montré aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a montré aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a montré aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a montré aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a montré aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a montré aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a montré aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a dévoilé aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a dévoilé aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a dévoilé aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a dévoilé aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a dévoilé aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a dévoilé aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a dévoilé aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a dévoilé aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a dévoilé aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a dévoilé aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a dévoilé aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a souligné aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a souligné aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a souligné aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a souligné aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a souligné aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a souligné aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a souligné aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a souligné aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a souligné aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a souligné aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a souligné aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a informé aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a informé aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a informé aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a informé aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a informé aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a informé aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a informé aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a informé aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a informé aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a informé aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a informé aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a révélé aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a révélé aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a révélé aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a révélé aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a révélé aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a révélé aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a révélé aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a révélé aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a révélé aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a révélé aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a révélé aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signifié aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signifié aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signifié aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signifié aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signifié aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signifié aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signifié aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signifié aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signifié aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signifié aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a signifié aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a déclaré aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a déclaré aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a déclaré aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a déclaré aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a déclaré aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a déclaré aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a déclaré aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a déclaré aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a déclaré aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a déclaré aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a déclaré aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a averti aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a averti aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a averti aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a averti aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a averti aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a averti aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a averti aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a averti aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a averti aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a averti aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a averti aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a rapporté aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a rapporté aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a rapporté aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a rapporté aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a rapporté aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a rapporté aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a rapporté aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a rapporté aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a rapporté aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a rapporté aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a rapporté aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a témoigné aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a témoigné aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a témoigné aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a témoigné aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a témoigné aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a témoigné aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a témoigné aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a témoigné aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a témoigné aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a témoigné aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a témoigné aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a alerté aucun problème avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a alerté aucun ennui avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a alerté aucun souci avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a alerté aucun complication avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a alerté aucun histoire avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a alerté aucun anomalie avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a alerté aucun dysfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a alerté aucun disfonctionnement avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a alerté aucun soucis avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a alerté aucun mal avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION
# n'a alerté aucun trouble avec |forward|trigger|negated|10|Group[434]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Adverb3 Verb4 Determiner5 Trigger_Rule
Auxiliary2 -> "n'a"
Adverb3 -> "pas"
Verb4 -> "observé" | "remarquer" | "noter" | "découvrir" | "apercevoir" | "signaler" | "voir" | "relever" | "enregistrer" | "déceler" | "détecter" | "souligner" | "mentionner"
Determiner5 -> "un" | "une" | "les"
Trigger_Rule -> "|forward|trigger|negated|10|Group[436]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a pas observé un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas observé une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas observé les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas remarquer un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas remarquer une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas remarquer les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas noter un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas noter une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas noter les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas découvrir un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas découvrir une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas découvrir les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas apercevoir un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas apercevoir une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas apercevoir les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas signaler un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas signaler une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas signaler les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas voir un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas voir une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas voir les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas relever un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas relever une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas relever les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas enregistrer un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas enregistrer une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas enregistrer les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas déceler un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas déceler une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas déceler les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas détecter un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas détecter une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas détecter les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas souligner un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas souligner une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas souligner les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas mentionner un |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas mentionner une |forward|trigger|negated|10|Group[436]|PRE-VALIDATION
# n'a pas mentionner les |forward|trigger|negated|10|Group[436]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Adverb3 Verb4 Trigger_Rule
Auxiliary2 -> "n'a"
Adverb3 -> "pas"
Verb4 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|backward|trigger|uncertain|30|Group[438]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a pas exclu |backward|trigger|uncertain|30|Group[438]|PRE-VALIDATION
# n'a pas refusé |backward|trigger|uncertain|30|Group[438]|PRE-VALIDATION
# n'a pas repoussé |backward|trigger|uncertain|30|Group[438]|PRE-VALIDATION
# n'a pas rejeté |backward|trigger|uncertain|30|Group[438]|PRE-VALIDATION
# n'a pas éliminé |backward|trigger|uncertain|30|Group[438]|PRE-VALIDATION
# n'a pas proscrit |backward|trigger|uncertain|30|Group[438]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Pronoun1 Verb3 Adposition4 Trigger_Rule
Pronoun1 -> "l'a"
Verb3 -> "exclue" | "mise à lécart" | "inenvisageable" | "irréalisable" | "évincé"
Adposition4 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# l'a exclue contre |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# l'a mise à lécart contre |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# l'a inenvisageable contre |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# l'a irréalisable contre |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# l'a évincé contre |forward|trigger|negated|10|Group[439]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Adposition3 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Adposition3 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a exclu pour |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a refusé pour |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a repoussé pour |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a rejeté pour |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a éliminé pour |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a proscrit pour |forward|trigger|negated|10|Group[439]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Adposition3 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Adposition3 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a exclu contre |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a refusé contre |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a repoussé contre |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a rejeté contre |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a éliminé contre |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a proscrit contre |forward|trigger|negated|10|Group[439]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a exclu |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a refusé |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a repoussé |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a rejeté |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a éliminé |forward|trigger|negated|10|Group[439]|PRE-VALIDATION
# a proscrit |forward|trigger|negated|10|Group[439]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Pronoun1 Auxiliary2 Verb3 Adposition4 Trigger_Rule
Pronoun1 -> "l'"
Auxiliary2 -> "a"
Verb3 -> "exclue" | "mise à lécart" | "inenvisageable" | "irréalisable" | "évincé"
Adposition4 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439, 441]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# l' a exclue pour |forward|trigger|negated|10|Group[439, 441]|PRE-VALIDATION
# l' a mise à lécart pour |forward|trigger|negated|10|Group[439, 441]|PRE-VALIDATION
# l' a inenvisageable pour |forward|trigger|negated|10|Group[439, 441]|PRE-VALIDATION
# l' a irréalisable pour |forward|trigger|negated|10|Group[439, 441]|PRE-VALIDATION
# l' a évincé pour |forward|trigger|negated|10|Group[439, 441]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Verb3 Trigger_Rule
Auxiliary2 -> "l'a"
Verb3 -> "exclue" | "mise à lécart" | "inenvisageable" | "irréalisable" | "évincé"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439, 443]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# l'a exclue |forward|trigger|negated|10|Group[439, 443]|PRE-VALIDATION
# l'a mise à lécart |forward|trigger|negated|10|Group[439, 443]|PRE-VALIDATION
# l'a inenvisageable |forward|trigger|negated|10|Group[439, 443]|PRE-VALIDATION
# l'a irréalisable |forward|trigger|negated|10|Group[439, 443]|PRE-VALIDATION
# l'a évincé |forward|trigger|negated|10|Group[439, 443]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Verb3 Adposition4 Trigger_Rule
Auxiliary2 -> "l'a"
Verb3 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Adposition4 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439, 445]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# l'a exclu contre |forward|trigger|negated|10|Group[439, 445]|PRE-VALIDATION
# l'a refusé contre |forward|trigger|negated|10|Group[439, 445]|PRE-VALIDATION
# l'a repoussé contre |forward|trigger|negated|10|Group[439, 445]|PRE-VALIDATION
# l'a rejeté contre |forward|trigger|negated|10|Group[439, 445]|PRE-VALIDATION
# l'a éliminé contre |forward|trigger|negated|10|Group[439, 445]|PRE-VALIDATION
# l'a proscrit contre |forward|trigger|negated|10|Group[439, 445]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Verb3 Adposition4 Trigger_Rule
Auxiliary2 -> "l'a"
Verb3 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Adposition4 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439, 447]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# l'a exclu pour |forward|trigger|negated|10|Group[439, 447]|PRE-VALIDATION
# l'a refusé pour |forward|trigger|negated|10|Group[439, 447]|PRE-VALIDATION
# l'a repoussé pour |forward|trigger|negated|10|Group[439, 447]|PRE-VALIDATION
# l'a rejeté pour |forward|trigger|negated|10|Group[439, 447]|PRE-VALIDATION
# l'a éliminé pour |forward|trigger|negated|10|Group[439, 447]|PRE-VALIDATION
# l'a proscrit pour |forward|trigger|negated|10|Group[439, 447]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Verb3 Trigger_Rule
Auxiliary2 -> "l'a"
Verb3 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Trigger_Rule -> "|forward|trigger|negated|10|Group[439, 449]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# l'a exclu |forward|trigger|negated|10|Group[439, 449]|PRE-VALIDATION
# l'a refusé |forward|trigger|negated|10|Group[439, 449]|PRE-VALIDATION
# l'a repoussé |forward|trigger|negated|10|Group[439, 449]|PRE-VALIDATION
# l'a rejeté |forward|trigger|negated|10|Group[439, 449]|PRE-VALIDATION
# l'a éliminé |forward|trigger|negated|10|Group[439, 449]|PRE-VALIDATION
# l'a proscrit |forward|trigger|negated|10|Group[439, 449]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Noun4 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Noun4 -> "le patient" | "client" | "souffrant" | "sujet"
Trigger_Rule -> "|forward|trigger|negated|10|Group[457]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a exclu le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a exclu client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a exclu souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a exclu sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Noun4 Adposition5 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Noun4 -> "le patient" | "le client" | "souffrant" | "sujet"
Adposition5 -> "pour"
Trigger_Rule -> "|forward|trigger|negated|10|Group[457]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a exclu le patient pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a exclu le client pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a exclu souffrant pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a exclu sujet pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé le patient pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé le client pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé souffrant pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé sujet pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé le patient pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé le client pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé souffrant pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé sujet pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté le patient pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté le client pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté souffrant pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté sujet pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé le patient pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé le client pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé souffrant pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé sujet pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit le patient pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit le client pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit souffrant pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit sujet pour |forward|trigger|negated|10|Group[457]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2  Noun4 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "exclu" | "refusé" | "repoussé" | "rejeté" | "éliminé" | "proscrit"
Noun4 -> "le patient" | "le client" | "souffrant" | "le sujet"
Adposition5 -> "contre"
Trigger_Rule -> "|forward|trigger|negated|10|Group[457]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a exclu le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a exclu le client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a exclu souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a exclu le sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé le client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a refusé le sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé le client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a repoussé le sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté le client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a rejeté le sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé le client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a éliminé le sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit le patient |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit le client |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit souffrant |forward|trigger|negated|10|Group[457]|PRE-VALIDATION
# a proscrit le sujet |forward|trigger|negated|10|Group[457]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Auxiliary1 Verb2 Trigger_Rule
Auxiliary1 -> "a"
Verb2 -> "montré" | "affiché" | "exhibition" | "état" | "démonstration" | "exposition" | "livré" | "dénudé" | "exhibé" | "dénoté" | "confirmé" | "expliqué" | "découvert" | "affecté" | "dévoilé"
Trigger_Rule -> "|forward|termination|negated|10|Group[463]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# a montré |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a affiché |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a exhibition |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a état |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a démonstration |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a exposition |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a livré |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a dénudé |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a exhibé |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a dénoté |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a confirmé |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a expliqué |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a découvert |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a affecté |forward|termination|negated|10|Group[463]|PRE-VALIDATION
# a dévoilé |forward|termination|negated|10|Group[463]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Adverb3 Verb4 Trigger_Rule
Auxiliary2 -> "n'a"
Adverb3 -> "pas"
Verb4 -> "exprimer" | "manifester" | "dire" | "signifier" | "témoigner" | "montrer" | "expliquer" | "traduire" | "extérioriser" | "révéler" | "formuler" | "exposer" | "afficher" | "émettre" | "signaler"
Trigger_Rule -> "|forward|trigger|negated|10|Group[464]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a pas exprimer |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas manifester |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas dire |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas signifier |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas témoigner |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas montrer |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas expliquer |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas traduire |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas extérioriser |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas révéler |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas formuler |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas exposer |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas afficher |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas émettre |forward|trigger|negated|10|Group[464]|PRE-VALIDATION
# n'a pas signaler |forward|trigger|negated|10|Group[464]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Verb3 Determiner4 Trigger_Rule
Auxiliary2 -> "n'a"
Verb3 -> "exprimé" | "manifester" | "dire" | "signifier" | "témoigner" | "montrer" | "expliquer" | "traduire" | "extérioriser" | "révéler" | "formuler" | "exposer" | "afficher" | "émettre" | "signaler"
Determiner4 -> "aucune"
Trigger_Rule -> "|forward|trigger|negated|10|Group[466]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a exprimé aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a manifester aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a dire aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a signifier aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a témoigner aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a montrer aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a expliquer aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a traduire aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a extérioriser aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a révéler aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a formuler aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a exposer aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a afficher aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a émettre aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION
# n'a signaler aucune |forward|trigger|negated|10|Group[466]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Auxiliary2 Verb3 Determiner4 Trigger_Rule
Auxiliary2 -> "n'a"
Verb3 -> "signalé" | "indiqué" | "notifié" | "découvert" | "montré" | "dévoilé" | "souligné" | "informé" | "révélé" | "signifié" | "déclaré" | "averti" | "rapporté" | "témoigné" | "alerté"
Determiner4 -> "aucun"
Trigger_Rule -> "|forward|trigger|negated|10|Group[472]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'a signalé aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a indiqué aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a notifié aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a découvert aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a montré aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a dévoilé aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a souligné aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a informé aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a révélé aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a signifié aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a déclaré aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a averti aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a rapporté aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a témoigné aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION
# n'a alerté aucun |forward|trigger|negated|10|Group[472]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adjective1 Verb2 Adverb3 Trigger_Rule
Adjective1 -> "différentiel"
Verb2 -> "comprend" | "consister" | "posséder" | "contient"
Adverb3 -> "également"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[475]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# différentiel comprend également |forward|trigger|uncertain|30|Group[475]|PRE-VALIDATION
# différentiel consister également |forward|trigger|uncertain|30|Group[475]|PRE-VALIDATION
# différentiel posséder également |forward|trigger|uncertain|30|Group[475]|PRE-VALIDATION
# différentiel contient également |forward|trigger|uncertain|30|Group[475]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Pronoun1 Adjective2 Verb3 Adverb4 Trigger_Rule
Pronoun1 -> "diagnostics"
Adjective2 -> "différentiels"
Verb3 -> "comprend" | "consister" | "posséder" | "contient"
Adverb4 -> "également"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[476]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# diagnostics différentiels comprend également |forward|trigger|uncertain|30|Group[476]|PRE-VALIDATION
# diagnostics différentiels consister également |forward|trigger|uncertain|30|Group[476]|PRE-VALIDATION
# diagnostics différentiels posséder également |forward|trigger|uncertain|30|Group[476]|PRE-VALIDATION
# diagnostics différentiels contient également |forward|trigger|uncertain|30|Group[476]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Determiner1 Noun2 Adjective3 Verb4 Trigger_Rule
Determiner1 -> "les"
Noun2 -> "diagnostics" | "diagnostique" | "symptomatique" | "symptôme" | "diagnose" | "diagnostic"
Adjective3 -> "différentiels"
Verb4 -> "comprennent" | "comporter" | "traduire" | "expliquer"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# les diagnostics différentiels comprennent |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnostics différentiels comporter |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnostics différentiels traduire |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnostics différentiels expliquer |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnostique différentiels comprennent |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnostique différentiels comporter |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnostique différentiels traduire |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnostique différentiels expliquer |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les symptomatique différentiels comprennent |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les symptomatique différentiels comporter |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les symptomatique différentiels traduire |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les symptomatique différentiels expliquer |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les symptôme différentiels comprennent |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les symptôme différentiels comporter |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les symptôme différentiels traduire |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les symptôme différentiels expliquer |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnose différentiels comprennent |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnose différentiels comporter |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnose différentiels traduire |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnose différentiels expliquer |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnostic différentiels comprennent |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnostic différentiels comporter |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnostic différentiels traduire |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION
# les diagnostic différentiels expliquer |forward|trigger|uncertain|30|Group[477]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adjective1 Verb2 Trigger_Rule
Adjective1 -> "différentiel"
Verb2 -> "comprend" | "consister" | "posséder" | "contient"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[478]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# différentiel comprend |forward|trigger|uncertain|30|Group[478]|PRE-VALIDATION
# différentiel consister |forward|trigger|uncertain|30|Group[478]|PRE-VALIDATION
# différentiel posséder |forward|trigger|uncertain|30|Group[478]|PRE-VALIDATION
# différentiel contient |forward|trigger|uncertain|30|Group[478]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Verb4 Adposition5 Noun6 Adposition7 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "semble"
Adverb3 -> "pas"
Verb4 -> "avoir"
Adposition5 -> "de"
Noun6 -> "problèmes" | "question" | "ennui" | "souci" | "complication" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "tracas" | "problème" | "incident" | "couac"
Adposition7 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[479]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne semble pas avoir de problèmes de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de question de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de ennui de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de souci de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de complication de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de dysfonctionnement de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de disfonctionnement de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de soucis de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de tracas de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de problème de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de incident de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de couac de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Verb4 Noun6 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "semble"
Adverb3 -> "pas"
Verb4 -> "avoir"
Noun6 -> "d'étrange" | "d'bizarre" | "d'extraordinaire" | "d'curieux" | "d'insolite" | "d'exceptionnel" | "d'incroyable" | "d'surprenant" | "d'étonnant" | "d'énigmatique" | "d'inaccoutumé" | "d'inexplicable" | "d'incompréhensible" | "d'inquiétant" | "d'invraisemblable"
Trigger_Rule -> "|forward|trigger|negated|10|Group[479]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne semble pas avoir d'étrange |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'bizarre |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'extraordinaire |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'curieux |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'insolite |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'exceptionnel |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'incroyable |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'surprenant |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'étonnant |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'énigmatique |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'inaccoutumé |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'inexplicable |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'incompréhensible |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'inquiétant |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir d'invraisemblable |forward|trigger|negated|10|Group[479]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Verb4 Adposition5 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "semble"
Adverb3 -> "pas"
Verb4 -> "avoir"
Adposition5 -> "de"
Trigger_Rule -> "|forward|trigger|negated|10|Group[479]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne semble pas avoir de |forward|trigger|negated|10|Group[479]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Verb4 Adposition5 Noun6 Adposition7 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "semble"
Adverb3 -> "pas"
Verb4 -> "avoir"
Adposition5 -> "de"
Noun6 -> "problèmes" | "question" | "ennui" | "souci" | "complication" | "dysfonctionnement" | "disfonctionnement" | "soucis" | "tracas" | "problème" | "incident" | "couac"
Adposition7 -> "avec"
Trigger_Rule -> "|forward|trigger|negated|10|Group[479]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne semble pas avoir de problèmes avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de question avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de ennui avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de souci avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de complication avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de dysfonctionnement avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de disfonctionnement avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de soucis avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de tracas avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de problème avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de incident avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION
# ne semble pas avoir de couac avec |forward|trigger|negated|10|Group[479]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Verb2 Adverb3 Trigger_Rule
Verb2 -> "n'exprime" | "ne dire" | "n'exposer" | "n'énoncer" | "n'afficher" | "n'émettre" | "ne signaler" | "ne signifier" | "ne déclarer" | "ne témoigner" | "ne montrer" | "ne manifester" | "ne découvrir" | "ne figurer" | "ne traduire"
Adverb3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[487]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'exprime pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# ne dire pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# n'exposer pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# n'énoncer pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# n'afficher pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# n'émettre pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# ne signaler pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# ne signifier pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# ne déclarer pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# ne témoigner pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# ne montrer pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# ne manifester pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# ne découvrir pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# ne figurer pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION
# ne traduire pas |forward|trigger|negated|10|Group[487]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S -> Verb2 Adverb3 Trigger_Rule
Verb2 -> "n'utilise" | "n'employé" | "ne servi" | "ne recourir" | "ne servir" | "n'user" | "ne prendre" | "n'appliquer" | "ne manipuler" | "n'exploiter" | "ne manier" | "n'employer"
Adverb3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[489]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# n'utilise pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION
# n'employé pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION
# ne servi pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION
# ne recourir pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION
# ne servir pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION
# n'user pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION
# ne prendre pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION
# n'appliquer pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION
# ne manipuler pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION
# n'exploiter pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION
# ne manier pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION
# n'employer pas |forward|trigger|negated|10|Group[489]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Adverb2 Trigger_Rule
Adverb1 -> "généralement"
Adverb2 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[491]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# généralement pas |forward|trigger|negated|10|Group[491]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "fait"
Adverb3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[493]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne fait pas |forward|trigger|negated|10|Group[493]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "ressemble" | "approcher" | "correspondre" | "imiter" | "rappeler" | "se recouper" | "avoir un rapport" | "être la réplique de" | "se rapprocher"
Adverb3 -> "pas"
Trigger_Rule -> "|forward|trigger|negated|10|Group[495]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne ressemble pas |forward|trigger|negated|10|Group[495]|PRE-VALIDATION
# ne approcher pas |forward|trigger|negated|10|Group[495]|PRE-VALIDATION
# ne correspondre pas |forward|trigger|negated|10|Group[495]|PRE-VALIDATION
# ne imiter pas |forward|trigger|negated|10|Group[495]|PRE-VALIDATION
# ne rappeler pas |forward|trigger|negated|10|Group[495]|PRE-VALIDATION
# ne se recouper pas |forward|trigger|negated|10|Group[495]|PRE-VALIDATION
# ne avoir un rapport pas |forward|trigger|negated|10|Group[495]|PRE-VALIDATION
# ne être la réplique de pas |forward|trigger|negated|10|Group[495]|PRE-VALIDATION
# ne se rapprocher pas |forward|trigger|negated|10|Group[495]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Trigger_Rule
Noun1 -> "doute" | "perplexité" | "hésitation" | "indétermination" | "indécision" | "crainte" | "appréhension" | "supposition" | "inquiétude" | "croyance"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[497]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# doute |forward|trigger|uncertain|30|Group[497]|PRE-VALIDATION
# perplexité |forward|trigger|uncertain|30|Group[497]|PRE-VALIDATION
# hésitation |forward|trigger|uncertain|30|Group[497]|PRE-VALIDATION
# indétermination |forward|trigger|uncertain|30|Group[497]|PRE-VALIDATION
# indécision |forward|trigger|uncertain|30|Group[497]|PRE-VALIDATION
# crainte |forward|trigger|uncertain|30|Group[497]|PRE-VALIDATION
# appréhension |forward|trigger|uncertain|30|Group[497]|PRE-VALIDATION
# supposition |forward|trigger|uncertain|30|Group[497]|PRE-VALIDATION
# inquiétude |forward|trigger|uncertain|30|Group[497]|PRE-VALIDATION
# croyance |forward|trigger|uncertain|30|Group[497]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adposition1 Noun2 Adposition3 Trigger_Rule
Adposition1 -> "en"
Noun2 -> "raison" | "cause" | "pourquoi" | "mobile" | "explication" | "fondement"
Adposition3 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[498]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# en raison de |forward|termination|negated|10|Group[498]|PRE-VALIDATION
# en cause de |forward|termination|negated|10|Group[498]|PRE-VALIDATION
# en pourquoi de |forward|termination|negated|10|Group[498]|PRE-VALIDATION
# en mobile de |forward|termination|negated|10|Group[498]|PRE-VALIDATION
# en explication de |forward|termination|negated|10|Group[498]|PRE-VALIDATION
# en fondement de |forward|termination|negated|10|Group[498]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adposition2 Trigger_Rule
Noun1 -> "ecchymoses" | "bleu" | "tache" | "hématome" | "coup" | "blessure" | "meurtrissure" | "cicatrice" | "égratignure" | "escarre" | "contusionné" | "entaillé" | "éraflure"
Adposition2 -> "à"
Trigger_Rule -> "|forward|termination|negated|10|Group[499]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ecchymoses à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# bleu à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# tache à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# hématome à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# coup à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# blessure à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# meurtrissure à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# cicatrice à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# égratignure à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# escarre à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# contusionné à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# entaillé à |forward|termination|negated|10|Group[499]|PRE-VALIDATION
# éraflure à |forward|termination|negated|10|Group[499]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Trigger_Rule
Verb1 -> "ed"
Trigger_Rule -> "|both|termination|historical|30|Group[500]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ed |both|termination|historical|30|Group[500]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Noun3 Trigger_Rule
Verb1 -> "département" | "secteur"
Noun3 -> "d'urgence" | "d'impératif" | "de gravité" | "de crise" | "de secours"
Trigger_Rule -> "|both|termination|historical|30|Group[501]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# département d'urgence |both|termination|historical|30|Group[501]|PRE-VALIDATION
# département d'impératif |both|termination|historical|30|Group[501]|PRE-VALIDATION
# département de gravité |both|termination|historical|30|Group[501]|PRE-VALIDATION
# département de crise |both|termination|historical|30|Group[501]|PRE-VALIDATION
# département de secours |both|termination|historical|30|Group[501]|PRE-VALIDATION
# secteur d'urgence |both|termination|historical|30|Group[501]|PRE-VALIDATION
# secteur d'impératif |both|termination|historical|30|Group[501]|PRE-VALIDATION
# secteur de gravité |both|termination|historical|30|Group[501]|PRE-VALIDATION
# secteur de crise |both|termination|historical|30|Group[501]|PRE-VALIDATION
# secteur de secours |both|termination|historical|30|Group[501]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adposition2 Trigger_Rule
Noun1 -> "étiologie" | "étiologie" | "étiopathie" | "causalité"
Adposition2 -> "de" | "pour"
Trigger_Rule -> "|forward|termination|negated|10|Group[502]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# étiologie de |forward|termination|negated|10|Group[502]|PRE-VALIDATION
# étiologie pour |forward|termination|negated|10|Group[502]|PRE-VALIDATION
# étiologie de |forward|termination|negated|10|Group[502]|PRE-VALIDATION
# étiologie pour |forward|termination|negated|10|Group[502]|PRE-VALIDATION
# étiopathie de |forward|termination|negated|10|Group[502]|PRE-VALIDATION
# étiopathie pour |forward|termination|negated|10|Group[502]|PRE-VALIDATION
# causalité de |forward|termination|negated|10|Group[502]|PRE-VALIDATION
# causalité pour |forward|termination|negated|10|Group[502]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adposition2 Trigger_Rule
Noun1 -> "exacerbation" | "redoublement" | "intensification" | "recrudescence" | "excitation" | "augmentation" | "irritation" | "aggravation" | "agravation"
Adposition2 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[504]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# exacerbation de |forward|termination|negated|10|Group[504]|PRE-VALIDATION
# redoublement de |forward|termination|negated|10|Group[504]|PRE-VALIDATION
# intensification de |forward|termination|negated|10|Group[504]|PRE-VALIDATION
# recrudescence de |forward|termination|negated|10|Group[504]|PRE-VALIDATION
# excitation de |forward|termination|negated|10|Group[504]|PRE-VALIDATION
# augmentation de |forward|termination|negated|10|Group[504]|PRE-VALIDATION
# irritation de |forward|termination|negated|10|Group[504]|PRE-VALIDATION
# aggravation de |forward|termination|negated|10|Group[504]|PRE-VALIDATION
# agravation de |forward|termination|negated|10|Group[504]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adposition2 Verb3 Trigger_Rule
Noun1 -> "examens" | "consultation" | "observation" | "étude" | "auscultation" | "examen médical"
Adposition2 -> "à"
Verb3 -> "évaluer" | "juger" | "apprécier" | "chiffrer" | "calculer" | "quantifier" | "mesurer" | "déterminer" | "expertiser" | "jauger" | "compter" | "peser" | "comparer" | "examiner" | "recenser"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# examens à évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examens à recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation à recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation à recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude à recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation à recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical à recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Verb2 Trigger_Rule
Noun1 -> "examen" | "analyse" | "consultation" | "observation" | "vérification" | "recherche" | "étude" | "auscultation" | "examen médical" | "autopsie" | "dépistage" | "interrogatoire"
Verb2 -> "évaluer" | "juger" | "apprécier" | "chiffrer" | "calculer" | "quantifier" | "mesurer" | "déterminer" | "expertiser" | "jauger" | "compter" | "peser" | "comparer" | "examiner" | "recenser"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# examen évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adposition2 Verb3 Trigger_Rule
Noun1 -> "examen" | "analyse" | "consultation" | "observation" | "vérification" | "recherche" | "étude" | "auscultation" | "examen médical" | "autopsie" | "dépistage" | "interrogatoire"
Adposition2 -> "pour"
Verb3 -> "évaluer" | "juger" | "apprécier" | "chiffrer" | "calculer" | "quantifier" | "mesurer" | "déterminer" | "expertiser" | "jauger" | "compter" | "peser" | "comparer" | "examiner" | "recenser"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# examen pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# analyse pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# consultation pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# observation pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# vérification pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# recherche pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# étude pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# auscultation pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# examen médical pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# autopsie pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# dépistage pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour évaluer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour juger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour apprécier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour chiffrer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour calculer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour quantifier |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour mesurer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour déterminer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour expertiser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour jauger |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour compter |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour peser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour comparer |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour examiner |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION
# interrogatoire pour recenser |forward|trigger|uncertain|30|Group[505]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adposition1 Trigger_Rule
Adposition1 -> "sauf"
Trigger_Rule -> "|forward|termination|negated|10|Group[510]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# sauf |forward|termination|negated|10|Group[510]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adposition2 Noun3 Trigger_Rule
Noun1 -> "f"
Adposition2 -> "/"
Noun3 -> "h"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[511]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# f / h |forward|trigger|nonpatient|30|Group[511]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adverb1 Verb2 Adverb3 Adposition4 Verb5 Trigger_Rule
Adverb1 -> "ne"
Verb2 -> "parvient" | "aboutir" | "atteindre" | "accéder" | "réussir" | "se pousser" | "finir par" | "se rendre" | "déboucher"
Adverb3 -> "pas"
Adposition4 -> "à"
Verb5 -> "révéler" | "divulguer" | "déceler" | "trahir" | "dire" | "exposer" | "faire connaître" | "exprimer" | "signaler" | "signifier" | "annoncer" | "développer" | "démasquer" | "afficher" | "déclarer"
Trigger_Rule -> "|forward|trigger|negated|10|Group[512]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# ne parvient pas à révéler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à divulguer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à déceler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à trahir |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à dire |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à exposer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à faire connaître |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à exprimer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à signaler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à signifier |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à annoncer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à développer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à démasquer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à afficher |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne parvient pas à déclarer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à révéler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à divulguer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à déceler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à trahir |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à dire |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à exposer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à faire connaître |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à exprimer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à signaler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à signifier |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à annoncer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à développer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à démasquer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à afficher |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne aboutir pas à déclarer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à révéler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à divulguer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à déceler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à trahir |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à dire |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à exposer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à faire connaître |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à exprimer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à signaler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à signifier |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à annoncer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à développer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à démasquer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à afficher |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne atteindre pas à déclarer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à révéler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à divulguer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à déceler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à trahir |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à dire |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à exposer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à faire connaître |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à exprimer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à signaler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à signifier |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à annoncer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à développer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à démasquer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à afficher |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne accéder pas à déclarer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à révéler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à divulguer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à déceler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à trahir |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à dire |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à exposer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à faire connaître |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à exprimer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à signaler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à signifier |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à annoncer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à développer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à démasquer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à afficher |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne réussir pas à déclarer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à révéler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à divulguer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à déceler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à trahir |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à dire |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à exposer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à faire connaître |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à exprimer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à signaler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à signifier |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à annoncer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à développer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à démasquer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à afficher |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se pousser pas à déclarer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à révéler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à divulguer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à déceler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à trahir |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à dire |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à exposer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à faire connaître |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à exprimer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à signaler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à signifier |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à annoncer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à développer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à démasquer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à afficher |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne finir par pas à déclarer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à révéler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à divulguer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à déceler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à trahir |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à dire |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à exposer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à faire connaître |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à exprimer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à signaler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à signifier |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à annoncer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à développer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à démasquer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à afficher |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne se rendre pas à déclarer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à révéler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à divulguer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à déceler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à trahir |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à dire |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à exposer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à faire connaître |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à exprimer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à signaler |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à signifier |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à annoncer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à développer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à démasquer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à afficher |forward|trigger|negated|10|Group[512]|PRE-VALIDATION
# ne déboucher pas à déclarer |forward|trigger|negated|10|Group[512]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adjective1 Adjective2 Trigger_Rule
Adjective1 -> "faux"
Adjective2 -> "négatif"
Trigger_Rule -> "|both|pseudo|negated|10|Group[514]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# faux négatif |both|pseudo|negated|10|Group[514]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adposition1 Trigger_Rule
Adposition1 -> "fh"
Trigger_Rule -> "|forward|trigger|nonpatient|30|Group[530]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# fh |forward|trigger|nonpatient|30|Group[530]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Adjective4 Trigger_Rule
Noun1 -> "indication" | "avertissement" | "prescription" | "directive" | "annotation" | "explication" | "renvoi" | "information" | "note" | "recommandation" | "critère" | "notation" | "suggestion" | "mention" | "symptôme"
Determiner2 -> "du"
Noun3 -> "rapport" | "correspondance" | "relation" | "accord" | "ressemblance" | "affinité" | "récit" | "analogie" | "corrélation" | "concordance" | "conformité" | "parenté" | "exposé" | "rapprochement" | "témoignage"
Adjective4 -> "final"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# indication du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# indication du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# avertissement du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# prescription du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# directive du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# annotation du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# explication du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# renvoi du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# information du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# note du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# recommandation du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# critère du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# notation du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# suggestion du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# mention du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du rapport final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du correspondance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du relation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du accord final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du ressemblance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du affinité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du récit final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du analogie final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du corrélation final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du concordance final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du conformité final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du parenté final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du exposé final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du rapprochement final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION
# symptôme du témoignage final |both|pseudo|uncertain|30|Group[531]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adposition1 Noun2 Trigger_Rule
Adposition1 -> "pour"
Noun2 -> "présumé" | "soupçonner" | "estimer" | "conjecturer" | "pressentir" | "présager" | "espérer" | "attendre" | "compter" | "préjuger" | "présupposer" | "prétendre" | "prédire"
Trigger_Rule -> "|forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# pour présumé |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour soupçonner |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour estimer |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour conjecturer |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour pressentir |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour présager |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour espérer |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour attendre |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour compter |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour préjuger |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour présupposer |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour prétendre |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION
# pour prédire |forward|trigger|uncertain|30|Group[532]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "mur" | "mûri" | "obstacle" | "bon pour" | "mûr" | "accompli" | "mature" | "apte" | "usagé" | "falaise" | "frontière" | "avancé" | "formé" | "cloisonnement" | "barrières"
Adjective2 -> "libre"
Trigger_Rule -> "|both|pseudo|negated|10|Group[533]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# mur libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# mûri libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# obstacle libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# bon pour libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# mûr libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# accompli libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# mature libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# apte libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# usagé libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# falaise libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# frontière libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# avancé libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# formé libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# cloisonnement libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# barrières libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Verb2 Trigger_Rule
Noun1 -> "air" | "aspect" | "apparence" | "extérieur" | "genre" | "allure" | "expression" | "mine" | "démarche" | "masque" | "manières" | "impression" | "manière" | "ressemblance" | "oxygène"
Verb2 -> "gratuit" | "public"
Trigger_Rule -> "|both|pseudo|negated|10|Group[533]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# air gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# air public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# aspect gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# aspect public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# apparence gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# apparence public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# extérieur gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# extérieur public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# genre gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# genre public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# allure gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# allure public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# expression gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# expression public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# mine gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# mine public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# démarche gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# démarche public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# masque gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# masque public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# manières gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# manières public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# impression gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# impression public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# manière gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# manière public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# ressemblance gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# ressemblance public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# oxygène gratuit |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# oxygène public |both|pseudo|negated|10|Group[533]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adjective1 Noun2 Trigger_Rule
Adjective1 -> "libre"
Noun2 -> "t"
Trigger_Rule -> "|both|pseudo|negated|10|Group[533]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# libre t |both|pseudo|negated|10|Group[533]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "fluide" | "coulant" | "clair" | "limpide" | "liquoreux" | "aqueuse"
Adjective2 -> "libre"
Trigger_Rule -> "|both|pseudo|negated|10|Group[533]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# fluide libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# coulant libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# clair libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# limpide libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# liquoreux libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# aqueuse libre |both|pseudo|negated|10|Group[533]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "eau" | "H2O" | "eau minérale" | "distribution de l'eau" | "source"
Adjective2 -> "gratuite"
Trigger_Rule -> "|both|pseudo|negated|10|Group[533]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# eau gratuite |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# H2O gratuite |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# eau minérale gratuite |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# distribution de l'eau gratuite |both|pseudo|negated|10|Group[533]|PRE-VALIDATION
# source gratuite |both|pseudo|negated|10|Group[533]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adjective1 Trigger_Rule
Adjective1 -> "libre"
Trigger_Rule -> "|backward|trigger|negated|10|Group[540]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# libre |backward|trigger|negated|10|Group[540]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Adposition1 Trigger_Rule
Adposition1 -> "de"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[541]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# de |both|pseudo|uncertain|30|Group[541]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Adjective2 Noun5 Trigger_Rule
Verb1 -> "donné" | "prescrit" | "administré" | "prodigué" | "appliqué" | "fait" | "indiqué" | "proposé" | "distribué" | "redonné" | "assené" | "employé" | "inoculé"
Adjective2 -> "\\w+"
Noun5 -> "histoire" | "passé" | "souvenir" | "historique"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# donné \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# donné \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# donné \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# donné \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# prescrit \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# prescrit \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# prescrit \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# prescrit \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# administré \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# administré \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# administré \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# administré \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# prodigué \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# prodigué \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# prodigué \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# prodigué \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# appliqué \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# appliqué \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# appliqué \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# appliqué \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# fait \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# fait \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# fait \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# fait \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# indiqué \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# indiqué \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# indiqué \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# indiqué \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# proposé \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# proposé \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# proposé \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# proposé \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# distribué \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# distribué \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# distribué \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# distribué \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# redonné \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# redonné \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# redonné \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# redonné \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# assené \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# assené \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# assené \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# assené \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# employé \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# employé \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# employé \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# employé \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# inoculé \w+ histoire |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# inoculé \w+ passé |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# inoculé \w+ souvenir |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# inoculé \w+ historique |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Determiner2 Noun3 Trigger_Rule
Noun1 -> "histoire" | "passé" | "souvenir" | "historique"
Determiner2 -> "du"
Noun3 -> "patient" | "client" | "souffrant" | "sujet"
Trigger_Rule -> "|both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# histoire du patient |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# histoire du client |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# histoire du souffrant |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# histoire du sujet |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# passé du patient |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# passé du client |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# passé du souffrant |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# passé du sujet |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# souvenir du patient |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# souvenir du client |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# souvenir du souffrant |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# souvenir du sujet |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# historique du patient |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# historique du client |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# historique du souffrant |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION
# historique du sujet |both|pseudo|uncertain|30|Group[542]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Verb2 Adposition3 Noun5 Trigger_Rule
Noun1 -> "compte"
Verb2 -> "tenu"
Adposition3 -> "de"
Noun5 -> "l'histoire" | "passé" | "souvenir" | "l'historique"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# compte tenu de l'histoire |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de passé |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de souvenir |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de l'historique |forward|termination|negated|10|Group[543]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Verb2 Determiner3 Noun4 Trigger_Rule
Noun1 -> "compte"
Verb2 -> "tenu"
Determiner3 -> "du"
Noun4 -> "fait"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# compte tenu du fait |forward|termination|negated|10|Group[543]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Verb2 Adposition3 Determiner4 Noun5 Trigger_Rule
Noun1 -> "compte"
Verb2 -> "tenu"
Adposition3 -> "de"
Determiner4 -> "son"
Noun5 -> "histoire" | "passé" | "souvenir" | "historique"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# compte tenu de son histoire |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de son passé |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de son souvenir |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de son historique |forward|termination|negated|10|Group[543]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Verb2 Adposition3 Determiner4 Noun5 Adposition6 Trigger_Rule
Noun1 -> "compte"
Verb2 -> "tenu"
Adposition3 -> "de"
Determiner4 -> "la"
Noun5 -> "gravité" | "sérieux" | "sévérité" | "grandeur" | "poids" | "urgence" | "caractère" | "sériosité"
Adposition6 -> "de"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# compte tenu de la gravité de |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de la sérieux de |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de la sévérité de |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de la grandeur de |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de la poids de |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de la urgence de |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de la caractère de |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# compte tenu de la sériosité de |forward|termination|negated|10|Group[543]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Verb1 Verb2 Subordinating_conjunction3 Trigger_Rule
Verb1 -> "étant"
Verb2 -> "donné" | "prescrit" | "administré" | "prodigué" | "appliqué" | "fait" | "indiqué" | "proposé" | "distribué" | "redonné" | "assené" | "employé" | "inoculé"
Subordinating_conjunction3 -> "que"
Trigger_Rule -> "|forward|termination|negated|10|Group[543]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# étant donné que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant prescrit que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant administré que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant prodigué que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant appliqué que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant fait que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant indiqué que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant proposé que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant distribué que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant redonné que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant assené que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant employé que |forward|termination|negated|10|Group[543]|PRE-VALIDATION
# étant inoculé que |forward|termination|negated|10|Group[543]|PRE-VALIDATION

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

cfg_grammar= """
S ->  Noun1 Adjective2 Trigger_Rule
Noun1 -> "gram"
Adjective2 -> "négatif"
Trigger_Rule -> "|both|pseudo|negated|10|Group[550]|PRE-VALIDATION"
"""

for sentence in generate(CFG.fromstring(cfg_grammar), n=1000):
    print(' '.join(sentence))
# Out:
# gram négatif |both|pseudo|negated|10|Group[550]|PRE-VALIDATION
